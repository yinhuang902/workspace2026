# %%
from time import perf_counter  

from modeling import build_models_from_csv
from bundles import BaseBundle, MSBundle
from utils import (
    tighten_bounds_one_model,
    MIN_DIST, ACTIVE_TOL, GAP_STOP_TOL,
)
from simplex_specialstart import run_pid_simplex_3d

# setup scenario number and target_nodes
csv_path       = "data-debug.csv"
max_scenarios  = 1
target_nodes   = 40


bounds={
    "Kp": (-1, 0),
    "Ki": (-101, -99),
    "Kd": (0, 1),
    "x": (-2.5, 2.5),
    "u": (-5.0, 5.0),
    "e": (None, None),
    "I": (None, None),
}
bounds={
    "Kp": (-10.0, 10.0),
    "Ki": (-100.0, 100.0),
    "Kd": (-100.0, 1000.0),
    "x": (-2.5, 2.5),
    "u": (-5.0, 5.0),
    "e": (None, None),
    "I": (None, None),
}

weights = (10.0, 0.01)


# ====== stage 1：load data and generate models ======
T   = 15.0          
nfe = 20            

t_load0 = perf_counter()
model_list, first_stg_vars_list, m_tmpl_list, nfe = build_models_from_csv(
    csv_path=csv_path,
    T=T,
    nfe=nfe,
    weights=weights,
    bounds=bounds,
    sp0=0.0,
    sp1=0.5,
    tau_xs_col="tau_xs",
    tau_us_col="tau_us",
    tau_ds_col="tau_ds",          
    disturb_prefix="disturbance_",
    setpoint_change_col="setpoint_change",
    max_scenarios=max_scenarios,
    skip=0,
)
t_load1 = perf_counter()
print(f"[Time] Data load & scenario build: {t_load1 - t_load0:.3f}s")


# ====== stage 1.5：FBBT / OBBT ======
# same as snog: FBBT open,OBBT open
obbt_solver_opts = {
    "NonConvex": 2,
    "MIPGap": 1,     
    "TimeLimit": 15   
}
for m, yvars in zip(model_list, first_stg_vars_list):
    tighten_bounds_one_model(m, yvars,
                             use_fbbt=False,
                             use_obbt=False,
                             obbt_solver_name="gurobi",
                             obbt_solver_opts=obbt_solver_opts,
                             max_rounds=3, tol=1e-6, verbose=True)

# ====== stage 2: Persistent Solver Packaging ======
ub_options = {
    'NonConvex': 2,        
}
lb_options = {
    'NonConvex': 2,
    'MIPGap': 1e-1,            
    'TimeLimit': 15    
}

t_wrap0 = perf_counter()
base_bundles = [BaseBundle(m, ub_options) for m in model_list]  
ms_bundles   = [MSBundle(m, yvars, lb_options) for m, yvars in zip(model_list, first_stg_vars_list)]  # LB 侧
t_wrap1 = perf_counter()
print(f"[Time] Persistent wrapper (GurobiPersistent) setup: {t_wrap1 - t_wrap0:.3f}s")

# ====== stage 3：main loop ======
agg_bundle = None  

t_run0 = perf_counter()
hist = run_pid_simplex_3d(
    base_bundles=base_bundles,
    ms_bundles=ms_bundles,
    model_list=model_list,
    first_vars_list=first_stg_vars_list,
    target_nodes=target_nodes,
    min_dist=0,
    active_tol=ACTIVE_TOL,
    verbose=True,
    agg_bundle=agg_bundle,
    gap_stop_tol=1e-3,
    plot_every=2,
    use_exact_opt=False,
    exact_solver_name="gurobi",
    exact_solver_opts={"NonConvex": 2, "TimeLimit": 60},
)
t_run1 = perf_counter()
print(f"[Time] Main loop total: {t_run1 - t_run0:.3f}s")

# ====== print output ======
print("\n==== Done ====")
print(f"Total nodes: {len(hist['nodes'])}")
print(f"Best UB: {min(hist['UB_hist']) if hist['UB_hist'] else None}")
print(f"Last LB: {hist['LB_hist'][-1] if hist['LB_hist'] else None}")
# Out:
# [Time] Data load & scenario build: 0.009s
# [Tighten] rounds=1, changed=False
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2689754
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 15
# [Time] Persistent wrapper (GurobiPersistent) setup: 0.556s
# [Precompute] File exact_opt_precomputed.csv not found; true optima will not be plotted.
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 1000.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 1000.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 1000.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 1000.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i5-14400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 108 rows, 134 columns and 308 nonzeros
# Model fingerprint: 0xa50f704c
# Model has 42 quadratic objective terms
# Model has 21 quadratic constraints
# Coefficient statistics:
#   Matrix range     [6e-01, 1e+06]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [7e-03, 2e+01]
#   Bounds range     [2e+00, 1e+06]
#   RHS range        [6e-02, 1e+00]
# Presolve removed 23 rows and 24 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 48 rows and 51 columns
# Presolve time: 0.01s
# Presolved: 324 rows, 144 columns, 988 nonzeros
# Presolved model has 41 quadratic objective terms
# Presolved model has 61 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 144 continuous, 0 integer (0 binary)
# Found heuristic solution: objective -918839.3357
#
# Explored 0 nodes (0 simplex iterations) in 0.05 seconds (0.01 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: -918839
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective -9.188393356734e+05, best bound -9.999995738342e+05, gap 8.8329%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i5-14400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 108 rows, 134 columns and 308 nonzeros
# Model fingerprint: 0x3e478642
# Model has 42 quadratic objective terms
# Model has 21 quadratic constraints
# Coefficient statistics:
#   Matrix range     [6e-01, 1e+06]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [7e-03, 2e+01]
#   Bounds range     [2e+00, 1e+06]
#   RHS range        [6e-02, 1e+00]
# Presolve removed 23 rows and 24 columns
#
# Continuous model is non-convex -- solving as a MIP
#
#
# MIP start from previous solve produced solution with objective 2.18836 (0.09s)
# MIP start from previous solve produced solution with objective 1.01089 (0.09s)
# Loaded MIP start from previous solve with objective 1.01089
#
# Presolve removed 48 rows and 51 columns
# Presolve time: 0.00s
# Presolved: 324 rows, 144 columns, 988 nonzeros
# Presolved model has 41 quadratic objective terms
# Presolved model has 61 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 144 continuous, 0 integer (0 binary)
#
# Explored 0 nodes (0 simplex iterations) in 0.17 seconds (0.10 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 1.01089 2.18836
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 1.010894585622e+00, best bound 9.375000000000e-01, gap 7.2604%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i5-14400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 3 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0xd8ae95f4
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+06]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 9e+05]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 2 rows, 5 columns, 9 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0108946e+00   0.000000e+00   0.000000e+00      0s
#        0    1.0108946e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.010894586e+00
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i5-14400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 108 rows, 134 columns and 308 nonzeros
# Model fingerprint: 0x807a2fb9
# Model has 42 quadratic objective terms
# Model has 21 quadratic constraints
# Coefficient statistics:
#   Matrix range     [6e-01, 1e+06]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [7e-03, 2e+01]
#   Bounds range     [2e+00, 1e+06]
#   RHS range        [6e-02, 1e+00]
# Presolve removed 23 rows and 24 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 47 rows and 50 columns
# Presolve time: 0.00s
# Presolved: 325 rows, 145 columns, 992 nonzeros
# Presolved model has 41 quadratic objective terms
# Presolved model has 61 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 145 continuous, 0 integer (0 binary)
# Found heuristic solution: objective -596659.7051
# Root relaxation presolved: 320 rows, 141 columns, 978 nonzeros
# Root relaxation presolved model has 40 quadratic objective terms
#
#
# Root relaxation: objective -9.746036e+05, 762 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 -974603.61    0   40 -596659.71 -974603.61  63.3%     -    0s
#      0     0 -973967.75    0   40 -596659.71 -973967.75  63.2%     -    0s
#      0     0 -930396.62    0   40 -596659.71 -930396.62  55.9%     -    0s
#      0     2 -930396.62    0   40 -596659.71 -930396.62  55.9%     -    0s
#
# Cutting planes:
#   RLT: 1
#
# Explored 35 nodes (4534 simplex iterations) in 0.18 seconds (0.12 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: -596660
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective -5.966597050740e+05, best bound -6.463924984995e+05, gap 8.3352%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i5-14400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 108 rows, 134 columns and 308 nonzeros
# Model fingerprint: 0x874cf109
# Model has 42 quadratic objective terms
# Model has 21 quadratic constraints
# Coefficient statistics:
#   Matrix range     [6e-01, 1e+06]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [7e-03, 2e+01]
#   Bounds range     [2e+00, 1e+06]
#   RHS range        [6e-02, 1e+00]
# Presolve removed 23 rows and 24 columns
#
# Continuous model is non-convex -- solving as a MIP
#
#
# MIP start from previous solve produced solution with objective 15.5221 (0.04s)
# MIP start from previous solve produced solution with objective 1.00004 (0.12s)
# MIP start from previous solve produced solution with objective 0.999987 (0.12s)
# MIP start from previous solve produced solution with objective 0.998961 (0.23s)
# Loaded MIP start from previous solve with objective 0.998961
#
# Presolve removed 47 rows and 50 columns
# Presolve time: 0.00s
# Presolved: 325 rows, 145 columns, 992 nonzeros
# Presolved model has 41 quadratic objective terms
# Presolved model has 61 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 145 continuous, 0 integer (0 binary)
#
# Explored 0 nodes (0 simplex iterations) in 0.26 seconds (0.21 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 4: 0.998961 0.999987 1.00004 15.5221
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 9.989607242063e-01, best bound 9.375000000000e-01, gap 6.1525%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i5-14400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 3 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0xcc837cf0
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+06]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+05]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 2 rows, 5 columns, 9 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9896072e-01   0.000000e+00   0.000000e+00      0s
#        0    9.9896072e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  9.989607242e-01
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i5-14400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 108 rows, 134 columns and 308 nonzeros
# Model fingerprint: 0x36a5eda9
# Model has 42 quadratic objective terms
# Model has 21 quadratic constraints
# Coefficient statistics:
#   Matrix range     [6e-01, 1e+06]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [7e-03, 2e+01]
#   Bounds range     [3e+00, 1e+06]
#   RHS range        [6e-02, 1e+00]
# Presolve removed 23 rows and 24 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 48 rows and 51 columns
# Presolve time: 0.00s
# Presolved: 324 rows, 144 columns, 988 nonzeros
# Presolved model has 41 quadratic objective terms
# Presolved model has 61 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 144 continuous, 0 integer (0 binary)
# Found heuristic solution: objective -614708.5146
# Root relaxation presolved: 319 rows, 140 columns, 974 nonzeros
# Root relaxation presolved model has 40 quadratic objective terms
#
#
# Root relaxation: objective -9.752797e+05, 764 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 -975279.68    0   21 -614708.51 -975279.68  58.7%     -    0s
#      0     0 -931311.33    0   21 -614708.51 -931311.33  51.5%     -    0s
#      0     2 -931311.33    0   21 -614708.51 -931311.33  51.5%     -    0s
#
# Explored 33 nodes (3261 simplex iterations) in 0.13 seconds (0.09 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: -614709
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective -6.147085146023e+05, best bound -6.710716567315e+05, gap 9.1691%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i5-14400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 108 rows, 134 columns and 308 nonzeros
# Model fingerprint: 0x7a707071
# Model has 42 quadratic objective terms
# Model has 21 quadratic constraints
# Coefficient statistics:
#   Matrix range     [6e-01, 1e+06]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [7e-03, 2e+01]
#   Bounds range     [3e+00, 1e+06]
#   RHS range        [6e-02, 1e+00]
# Presolve removed 23 rows and 24 columns
#
# Continuous model is non-convex -- solving as a MIP
#
#
# MIP start from previous solve produced solution with objective 17.8606 (0.04s)
# Loaded MIP start from previous solve with objective 17.8606
#
# Presolve removed 48 rows and 51 columns
# Presolve time: 0.00s
# Presolved: 324 rows, 144 columns, 988 nonzeros
# Presolved model has 41 quadratic objective terms
# Presolved model has 61 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 144 continuous, 0 integer (0 binary)
# Found heuristic solution: objective 12.0119181
# Root relaxation presolved: 319 rows, 140 columns, 974 nonzeros
# Root relaxation presolved model has 40 quadratic objective terms
#
#
# Root relaxation: objective 9.896966e-01, 372 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.98970    0   41   12.01192    0.98970  91.8%     -    0s
#      0     0    0.98970    0   41   12.01192    0.98970  91.8%     -    0s
#      0     0    0.98970    0   41   12.01192    0.98970  91.8%     -    0s
#      0     0    0.98970    0   41   12.01192    0.98970  91.8%     -    0s
#      0     0    0.98970    0   41   12.01192    0.98970  91.8%     -    0s
# H    0     0                       1.9019146    0.98970  48.0%     -    0s
# H    0     0                       1.7108711    0.98970  42.2%     -    0s
# H    0     0                       1.6282585    0.98970  39.2%     -    0s
#      0     0    0.98970    0   41    1.62826    0.98970  39.2%     -    0s
#      0     2    0.98970    0   41    1.62826    0.98970  39.2%     -    0s
# H    3     6                       1.3130235    0.98970  24.6%  14.3    0s
# H    4     6                       1.0311660    0.98970  4.02%   103    0s
#
# Cutting planes:
#   RLT: 17
#
# Explored 7 nodes (998 simplex iterations) in 0.28 seconds (0.18 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 7: 1.03117 1.31302 1.62826 ... 17.8606
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 1.031166048737e+00, best bound 9.896966096528e-01, gap 4.0216%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i5-14400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 3 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0xa059fd2f
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+06]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+05]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 2 rows, 5 columns, 9 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0311660e+00   0.000000e+00   0.000000e+00      0s
#        0    1.0311660e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.031166049e+00
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i5-14400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 108 rows, 134 columns and 308 nonzeros
# Model fingerprint: 0x82b56595
# Model has 42 quadratic objective terms
# Model has 21 quadratic constraints
# Coefficient statistics:
#   Matrix range     [6e-01, 1e+06]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [7e-03, 2e+01]
#   Bounds range     [3e+00, 1e+06]
#   RHS range        [6e-02, 1e+00]
# Presolve removed 23 rows and 24 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 48 rows and 51 columns
# Presolve time: 0.00s
# Presolved: 324 rows, 144 columns, 988 nonzeros
# Presolved model has 41 quadratic objective terms
# Presolved model has 61 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 144 continuous, 0 integer (0 binary)
# Found heuristic solution: objective -501138.2163
# Root relaxation presolved: 319 rows, 140 columns, 974 nonzeros
# Root relaxation presolved model has 40 quadratic objective terms
#
#
# Root relaxation: objective -9.880914e+05, 423 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 -988091.36    0   41 -501138.22 -988091.36  97.2%     -    0s
#      0     0 -987702.16    0   41 -501138.22 -987702.16  97.1%     -    0s
#      0     0 -971133.75    0   41 -501138.22 -971133.75  93.8%     -    0s
#      0     2 -971133.75    0   41 -501138.22 -971133.75  93.8%     -    0s
# H    6     6                    -909090.9907 -970538.77  6.76%   231    0s
#
# Cutting planes:
#   RLT: 2
#
# Explored 7 nodes (1812 simplex iterations) in 0.12 seconds (0.07 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: -909091 -501138
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective -9.090909906688e+05, best bound -9.705387725782e+05, gap 6.7593%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i5-14400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 108 rows, 134 columns and 308 nonzeros
# Model fingerprint: 0x790fcdfa
# Model has 42 quadratic objective terms
# Model has 21 quadratic constraints
# Coefficient statistics:
#   Matrix range     [6e-01, 1e+06]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [7e-03, 2e+01]
#   Bounds range     [3e+00, 1e+06]
#   RHS range        [6e-02, 1e+00]
# Presolve removed 23 rows and 24 columns
#
# Continuous model is non-convex -- solving as a MIP
#
#
# MIP start from previous solve produced solution with objective 2.88957 (0.02s)
# MIP start from previous solve produced solution with objective 1.0794 (0.12s)
# MIP start from previous solve produced solution with objective 1.01723 (0.12s)
# Loaded MIP start from previous solve with objective 1.01723
#
# Presolve removed 48 rows and 51 columns
# Presolve time: 0.00s
# Presolved: 324 rows, 144 columns, 988 nonzeros
# Presolved model has 41 quadratic objective terms
# Presolved model has 61 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 144 continuous, 0 integer (0 binary)
#
# Explored 0 nodes (0 simplex iterations) in 0.14 seconds (0.09 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 3: 1.01723 1.0794 2.88957
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 1.017234081862e+00, best bound 9.375000000000e-01, gap 7.8383%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i5-14400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 3 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0x2522d9fc
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+06]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 9e+05]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 2 rows, 5 columns, 9 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0172341e+00   0.000000e+00   0.000000e+00      0s
#        0    1.0172341e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.017234082e+00
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i5-14400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 108 rows, 134 columns and 308 nonzeros
# Model fingerprint: 0x429fa3dd
# Model has 42 quadratic objective terms
# Model has 21 quadratic constraints
# Coefficient statistics:
#   Matrix range     [6e-01, 1e+06]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [7e-03, 2e+01]
#   Bounds range     [3e+00, 1e+06]
#   RHS range        [6e-02, 1e+00]
# Presolve removed 23 rows and 24 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 48 rows and 51 columns
# Presolve time: 0.00s
# Presolved: 324 rows, 144 columns, 988 nonzeros
# Presolved model has 41 quadratic objective terms
# Presolved model has 61 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 144 continuous, 0 integer (0 binary)
# Root relaxation presolved: 319 rows, 140 columns, 974 nonzeros
# Root relaxation presolved model has 40 quadratic objective terms
#
#
# Root relaxation: objective -9.941609e+05, 431 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 -994160.85    0   41          - -994160.85      -     -    0s
#      0     0 -972228.32    0   41          - -972228.32      -     -    0s
# H    0     0                    -925331.4973 -972228.32  5.07%     -    0s
#
# Explored 1 nodes (431 simplex iterations) in 0.14 seconds (0.08 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: -925331
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective -9.253314973390e+05, best bound -9.722283225655e+05, gap 5.0681%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i5-14400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 108 rows, 134 columns and 308 nonzeros
# Model fingerprint: 0x4b0631e7
# Model has 42 quadratic objective terms
# Model has 21 quadratic constraints
# Coefficient statistics:
#   Matrix range     [6e-01, 1e+06]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [7e-03, 2e+01]
#   Bounds range     [3e+00, 1e+06]
#   RHS range        [6e-02, 1e+00]
# Presolve removed 23 rows and 24 columns
#
# Continuous model is non-convex -- solving as a MIP
#
#
# MIP start from previous solve produced solution with objective 10.3088 (0.03s)
# Loaded MIP start from previous solve with objective 10.3088
#
# Presolve removed 48 rows and 51 columns
# Presolve time: 0.00s
# Presolved: 324 rows, 144 columns, 988 nonzeros
# Presolved model has 41 quadratic objective terms
# Presolved model has 61 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 144 continuous, 0 integer (0 binary)
# Found heuristic solution: objective 1.2877575
# Root relaxation presolved: 319 rows, 140 columns, 974 nonzeros
# Root relaxation presolved model has 40 quadratic objective terms
#
#
# Root relaxation: objective 9.896966e-01, 327 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.98970    0   61    1.28776    0.98970  23.1%     -    0s
#      0     0    0.98970    0   61    1.28776    0.98970  23.1%     -    0s
#      0     0    0.98970    0   61    1.28776    0.98970  23.1%     -    0s
#      0     0    0.98970    0   61    1.28776    0.98970  23.1%     -    0s
#      0     0    0.98970    0   61    1.28776    0.98970  23.1%     -    0s
#      0     0    0.98970    0   61    1.28776    0.98970  23.1%     -    0s
#      0     0    0.98970    0   61    1.28776    0.98970  23.1%     -    0s
#      0     2    0.98970    0   61    1.28776    0.98970  23.1%     -    0s
# H    4     6                       1.0222257    0.98970  3.18%  18.3    0s
#
# Cutting planes:
#   RLT: 22
#
# Explored 7 nodes (563 simplex iterations) in 0.36 seconds (0.21 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 3: 1.02223 1.28776 10.3088
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 1.022225712993e+00, best bound 9.896966096528e-01, gap 3.1822%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i5-14400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 3 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0xa4d527e9
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+06]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 9e+05]
# Presolve removed 1 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 2 rows, 4 columns, 7 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0222257e+00   0.000000e+00   0.000000e+00      0s
#        0    1.0222257e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.022225713e+00
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i5-14400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 108 rows, 134 columns and 308 nonzeros
# Model fingerprint: 0x558f8fbf
# Model has 42 quadratic objective terms
# Model has 21 quadratic constraints
# Coefficient statistics:
#   Matrix range     [6e-01, 1e+06]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [7e-03, 2e+01]
#   Bounds range     [3e+00, 1e+06]
#   RHS range        [6e-02, 1e+00]
# Presolve removed 23 rows and 24 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 48 rows and 51 columns
# Presolve time: 0.00s
# Presolved: 324 rows, 144 columns, 988 nonzeros
# Presolved model has 41 quadratic objective terms
# Presolved model has 61 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 144 continuous, 0 integer (0 binary)
# Found heuristic solution: objective -607655.7312
# Root relaxation presolved: 319 rows, 140 columns, 974 nonzeros
# Root relaxation presolved model has 40 quadratic objective terms
#
#
# Root relaxation: objective -9.786058e+05, 852 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 -978605.84    0   40 -607655.73 -978605.84  61.0%     -    0s
#      0     0 -978073.16    0   40 -607655.73 -978073.16  61.0%     -    0s
#      0     0 -897700.20    0   40 -607655.73 -897700.20  47.7%     -    0s
#      0     2 -897700.20    0   40 -607655.73 -897700.20  47.7%     -    0s
#
# Cutting planes:
#   RLT: 1
#
# Explored 37 nodes (3601 simplex iterations) in 0.15 seconds (0.11 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: -607656
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective -6.076557311786e+05, best bound -6.428442935507e+05, gap 5.7909%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i5-14400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 108 rows, 134 columns and 308 nonzeros
# Model fingerprint: 0x537ee076
# Model has 42 quadratic objective terms
# Model has 21 quadratic constraints
# Coefficient statistics:
#   Matrix range     [6e-01, 1e+06]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [7e-03, 2e+01]
#   Bounds range     [3e+00, 1e+06]
#   RHS range        [6e-02, 1e+00]
# Presolve removed 23 rows and 24 columns
#
# Continuous model is non-convex -- solving as a MIP
#
#
# MIP start from previous solve produced solution with objective 14.6049 (0.04s)
# MIP start from previous solve produced solution with objective 1.00375 (0.13s)
# MIP start from previous solve produced solution with objective 1.00375 (0.21s)
# Loaded MIP start from previous solve with objective 1.00375
#
# Presolve removed 48 rows and 51 columns
# Presolve time: 0.00s
# Presolved: 324 rows, 144 columns, 988 nonzeros
# Presolved model has 41 quadratic objective terms
# Presolved model has 61 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 144 continuous, 0 integer (0 binary)
#
# Explored 0 nodes (0 simplex iterations) in 0.26 seconds (0.20 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 1.00375 14.6049
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 1.003751292200e+00, best bound 9.375000000000e-01, gap 6.6004%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i5-14400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 3 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0x957149e8
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+06]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+05]
# Presolve removed 1 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 2 rows, 4 columns, 7 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0037513e+00   0.000000e+00   0.000000e+00      0s
#        0    1.0037513e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.003751292e+00
# [Iter 0] #simplices = 6, #active = 6, bad-quality cut = 0
# == [Iter 0] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.010895e+00      8.116066e+04     -9.188393e+05      1.010895e+00     [2.28e+00, 1.00e+06]    [-9.19e+05, 8.12e+04]     1
# T1            9.989607e-01      4.033403e+05     -5.966597e+05      9.989607e-01     [2.28e+00, 1.00e+06]    [-5.97e+05, 4.03e+05]     1
# T2            1.031166e+00      3.852915e+05     -6.147085e+05      1.031166e+00     [2.79e+00, 1.00e+06]    [-6.15e+05, 3.85e+05]     1
# T3            1.017234e+00      9.090901e+04     -9.090910e+05      1.017234e+00     [2.79e+00, 1.00e+06]    [-9.09e+05, 9.09e+04]     1
# T4            1.022226e+00      7.466850e+04     -9.253315e+05      1.022226e+00     [2.79e+00, 1.00e+06]    [-9.25e+05, 7.47e+04]     2
# T5            1.003751e+00      3.923443e+05     -6.076557e+05      1.003751e+00     [2.79e+00, 1.00e+06]    [-6.08e+05, 3.92e+05]     2
#
# == [Iter 0] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
#   (none)
# [Iter 0] created=6 (cum=6), active=6, active+UB=2, ms_recomputed=6
# [DEBUG] about to call _debug_plot_lb_simplex_scatter, iter=0, simplex=1
# [DEBUG] _debug_plot_lb_simplex_scatter: enter, iter=0, simplex=1
# [DEBUG] (from scatter helper) LB simplex 1:
#     vert 0 (node 3): sum(As+ms) = -5.966471e+05, sum(c_s) = 9.989607e-01
#     vert 1 (node 1): sum(As+ms) = 4.033403e+05, sum(c_s) = 9.989607e-01
#     vert 2 (node 4): sum(As+ms) = -5.966569e+05, sum(c_s) = 9.989607e-01
#     vert 3 (node 0): sum(As+ms) = -5.966574e+05, sum(c_s) = 9.989607e-01
# [DEBUG] _debug_plot_lb_simplex_scatter: n_samples=300, outdir=lb_debug_plots1
# [DEBUG] Iter 0, simplex 1: Points with A_sum+ms_total > c_total = 12/300 (0.040)
# [DEBUG] LB simplex scatter saved to: lb_debug_plots1\lb_simplex_iter_0.html
# [DEBUG] _debug_plot_lb_simplex_scatter: exit, iter=0
# [Iter 0] Optimality abs-gap: 1.281882e+00 (56.202%)
# [Iter 0] Active simplex ratio = 1.000000
# [Iter 0] UB node (-10.0, -100.0, -100.0) is in simplices [0, 1]
# [Iter 0] LB = 0.998961 = UB(2.280843) + ms_b(-5.967e+05) from T1
# Chosen node (-10.0, -19.38024962110186, 1000.0) with ms=-5.967e+05 (simp T1, scene 0, rank #1, source=ms(dist))
# [Iter 0] LB simplex = T1, next node simplex = T1, scene 0
# [Selected Simp Info] Iter 0 | Simplex T1 Vertices:
#   v0: (-10.0, 100.0, 1000.0)
#   v1: (-10.0, -100.0, 1000.0)
#   v2: (10.0, -100.0, -100.0)
#   v3: (-10.0, -100.0, -100.0)
#   -> New Point: (-10.0, -19.38024962110186, 1000.0)
# [Iter 0] candidate rank #1: T1, scene=0, ms=-5.967e+05
# == ms candidates (sorted by (ms, -dist)) ==
# rank   simp   scene           ms    mind(all)                             pt
# ----------------------------------------------------------------------------
#    1     T1       0  -5.9666e+05     8.06e+01 (-10.0000, -19.3802, 1000.0000)
#
# [Iter 0] per_tet=6, active after q_cut=6, tri_is_None=False
# [Iter 0] bad-quality active simplices (q < 1e-09): 0
# [Iter 0] evaluating Q for scenario 0
#
# [Iter 0] Next Point Details:
# Simplex   Scene   Type    As             ms             As+ms          Q              (Kp, Ki, Kd)
# --------------------------------------------------------------------------------------------------------------------
# T1        0       ms(dist)5.9691e+05     -5.9666e+05    2.4662e+02     2.4662e+02     (-10.0000, -19.3802, 1000.0000)
#
# [Iter 0] subdivision type = edge (code=2) on simplex T1
#            edge local verts = (3, 1)
# [Iter 0] Elapsed: 3.928s
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i5-14400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 3 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0xd8ae95f4
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+06]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 9e+05]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 2 rows, 5 columns, 9 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0108946e+00   0.000000e+00   0.000000e+00      0s
#        0    1.0108946e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.010894586e+00
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i5-14400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 3 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0xa059fd2f
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+06]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+05]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 2 rows, 5 columns, 9 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0311660e+00   0.000000e+00   0.000000e+00      0s
#        0    1.0311660e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.031166049e+00
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i5-14400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 3 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0x2522d9fc
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+06]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 9e+05]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 2 rows, 5 columns, 9 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0172341e+00   0.000000e+00   0.000000e+00      0s
#        0    1.0172341e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.017234082e+00
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i5-14400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 3 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0xa4d527e9
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+06]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 9e+05]
# Presolve removed 1 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 2 rows, 4 columns, 7 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0222257e+00   0.000000e+00   0.000000e+00      0s
#        0    1.0222257e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.022225713e+00
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i5-14400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 3 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0x957149e8
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+06]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+05]
# Presolve removed 1 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 2 rows, 4 columns, 7 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0037513e+00   0.000000e+00   0.000000e+00      0s
#        0    1.0037513e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.003751292e+00
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i5-14400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 108 rows, 134 columns and 308 nonzeros
# Model fingerprint: 0x24c1b776
# Model has 42 quadratic objective terms
# Model has 21 quadratic constraints
# Coefficient statistics:
#   Matrix range     [6e-01, 1e+06]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [7e-03, 2e+01]
#   Bounds range     [2e+00, 1e+06]
#   RHS range        [6e-02, 1e+00]
# Presolve removed 23 rows and 24 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 47 rows and 50 columns
# Presolve time: 0.00s
# Presolved: 325 rows, 145 columns, 992 nonzeros
# Presolved model has 41 quadratic objective terms
# Presolved model has 61 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 145 continuous, 0 integer (0 binary)
# Found heuristic solution: objective -0.7529429
# Root relaxation presolved: 320 rows, 141 columns, 978 nonzeros
# Root relaxation presolved model has 40 quadratic objective terms
#
#
# Root relaxation: objective -9.746036e+05, 510 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 -974603.61    0   40   -0.75294 -974603.61      -     -    0s
#      0     0 -973967.75    0   40   -0.75294 -973967.75      -     -    0s
#      0     0 -806569.90    0   40   -0.75294 -806569.90      -     -    0s
#      0     2 -806569.90    0   40   -0.75294 -806569.90      -     -    0s
# *   39    34               5    -86373.34595 -766345.41   787%  28.1    0s
# *   49    40               6    -90691.96055 -766345.41   745%  38.7    0s
# *   85    74               7    -90907.79643 -676332.16   644%  31.3    0s
# H  499   462                    -90910.51145 -118343.37  30.2%  49.6    0s
# H  528   462                    -90910.56274 -118343.37  30.2%  52.5    0s
# H  725   534                    -90910.62550 -111263.44  22.4%  56.6    0s
# *  950   638              39    -105803.8655 -109686.15  3.67%  46.6    0s
#
# Cutting planes:
#   RLT: 1
#
# Explored 1113 nodes (47294 simplex iterations) in 0.36 seconds (0.24 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 8: -105804 -90910.6 -90910.6 ... -0.752943
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective -1.058038654883e+05, best bound -1.096861500331e+05, gap 3.6693%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i5-14400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 108 rows, 134 columns and 308 nonzeros
# Model fingerprint: 0x0b5ff26c
# Model has 42 quadratic objective terms
# Model has 21 quadratic constraints
# Coefficient statistics:
#   Matrix range     [6e-01, 1e+06]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [7e-03, 2e+01]
#   Bounds range     [2e+00, 1e+06]
#   RHS range        [6e-02, 1e+00]
# Presolve removed 23 rows and 24 columns
#
# Continuous model is non-convex -- solving as a MIP
#
#
# MIP start from previous solve produced solution with objective 2.39268 (0.01s)
# MIP start from previous solve produced solution with objective 2.17558 (0.07s)
# MIP start from previous solve produced solution with objective 1.78725 (0.07s)
# MIP start from previous solve produced solution with objective 1.47849 (0.07s)
# MIP start from previous solve produced solution with objective 0.997836 (0.11s)
# MIP start from previous solve produced solution with objective 0.996612 (0.11s)
# MIP start from previous solve produced solution with objective 0.99652 (0.11s)
# MIP start from previous solve produced solution with objective 0.996507 (0.18s)
# MIP start from previous solve produced solution with objective 0.996498 (0.18s)
# MIP start from previous solve produced solution with objective 0.996289 (0.20s)
# MIP start from previous solve produced solution with objective 0.996268 (0.20s)
# MIP start from previous solve produced solution with objective 0.996111 (0.22s)
# ...
# Model fingerprint: 0x25ab50cb
# Model has 42 quadratic objective terms
# Model has 21 quadratic constraints
# Coefficient statistics:
#   Matrix range     [6e-01, 1e+02]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [7e-03, 2e+01]
#   Bounds range     [1e+00, 1e+03]
#   RHS range        [6e-02, 1e+00]
# Presolve removed 23 rows and 24 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 46 rows and 47 columns
# Presolve time: 0.00s
# Presolved: 326 rows, 147 columns, 1004 nonzeros
# Presolved model has 41 quadratic objective terms
# Presolved model has 61 bilinear constraint(s)
# Variable types: 147 continuous, 0 integer (0 binary)
# Found heuristic solution: objective -0.0034525
# Root relaxation presolved: 325 rows, 146 columns, 1002 nonzeros
# Root relaxation presolved model has 41 quadratic objective terms
#
#
# Root relaxation: objective -5.157817e-03, 586 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   -0.00516    0   42   -0.00345   -0.00516  49.4%     -    0s
#
# Explored 1 nodes (586 simplex iterations) in 0.19 seconds (0.12 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: -0.00345253
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective -3.452529903030e-03, best bound -3.623256793121e-03, gap 4.9450%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i5-14400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 108 rows, 134 columns and 308 nonzeros
# Model fingerprint: 0x0afa14ed
# Model has 42 quadratic objective terms
# Model has 21 quadratic constraints
# Coefficient statistics:
#   Matrix range     [6e-01, 1e+02]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [7e-03, 2e+01]
#   Bounds range     [1e+00, 1e+03]
#   RHS range        [6e-02, 1e+00]
# Presolve removed 23 rows and 24 columns
#
# Continuous model is non-convex -- solving as a MIP
#
#
# MIP start from previous solve produced solution with objective 0.996085 (0.02s)
# Loaded MIP start from previous solve with objective 0.996085
#
# Presolve removed 46 rows and 47 columns
# Presolve time: 0.00s
# Presolved: 326 rows, 147 columns, 1004 nonzeros
# Presolved model has 41 quadratic objective terms
# Presolved model has 61 bilinear constraint(s)
# Variable types: 147 continuous, 0 integer (0 binary)
#
# Explored 0 nodes (0 simplex iterations) in 0.04 seconds (0.02 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 0.996085
#
# Optimal solution found (tolerance 1.00e-01)
# Warning: max constraint violation (4.4305e-06) exceeds tolerance
# Best objective 9.960846271893e-01, best bound 9.471005619687e-01, gap 4.9177%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i5-14400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 3 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0x5f0cc494
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e-03, 1e+00]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 2 rows, 5 columns, 9 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9608463e-01   0.000000e+00   0.000000e+00      0s
#        0    9.9608463e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  9.960846272e-01
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i5-14400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 108 rows, 134 columns and 308 nonzeros
# Model fingerprint: 0x968536df
# Model has 42 quadratic objective terms
# Model has 21 quadratic constraints
# Coefficient statistics:
#   Matrix range     [6e-01, 1e+02]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [7e-03, 2e+01]
#   Bounds range     [1e+00, 1e+03]
#   RHS range        [6e-02, 1e+00]
# Presolve removed 23 rows and 24 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 46 rows and 47 columns
# Presolve time: 0.00s
# Presolved: 326 rows, 148 columns, 1000 nonzeros
# Presolved model has 41 quadratic objective terms
# Presolved model has 61 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 148 continuous, 0 integer (0 binary)
# Found heuristic solution: objective -0.0064806
# Root relaxation presolved: 321 rows, 144 columns, 986 nonzeros
# Root relaxation presolved model has 40 quadratic objective terms
#
#
# Root relaxation: objective -8.182699e-03, 541 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   -0.00818    0   61   -0.00648   -0.00818  26.3%     -    0s
#      0     0   -0.00816    0   61   -0.00648   -0.00816  25.9%     -    0s
#
# Cutting planes:
#   RLT: 3
#
# Explored 1 nodes (556 simplex iterations) in 0.22 seconds (0.14 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: -0.00648055
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective -6.480553949609e-03, best bound -6.811738351599e-03, gap 5.1104%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i5-14400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 108 rows, 134 columns and 308 nonzeros
# Model fingerprint: 0x3b420075
# Model has 42 quadratic objective terms
# Model has 21 quadratic constraints
# Coefficient statistics:
#   Matrix range     [6e-01, 1e+02]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [7e-03, 2e+01]
#   Bounds range     [1e+00, 1e+03]
#   RHS range        [6e-02, 1e+00]
# Presolve removed 23 rows and 24 columns
#
# Continuous model is non-convex -- solving as a MIP
#
#
# MIP start from previous solve produced solution with objective 0.996578 (0.06s)
# MIP start from previous solve produced solution with objective 0.996014 (0.07s)
# Loaded MIP start from previous solve with objective 0.996014
#
# Presolve removed 46 rows and 47 columns
# Presolve time: 0.00s
# Presolved: 326 rows, 148 columns, 1000 nonzeros
# Presolved model has 41 quadratic objective terms
# Presolved model has 61 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 148 continuous, 0 integer (0 binary)
#
# Explored 0 nodes (0 simplex iterations) in 0.11 seconds (0.07 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 0.996014 0.996578
#
# Optimal solution found (tolerance 1.00e-01)
# Warning: max constraint violation (4.4217e-06) exceeds tolerance
# Best objective 9.960139000012e-01, best bound 9.463069903571e-01, gap 4.9906%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i5-14400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 3 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0x87084843
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-03, 1e+00]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 2 rows, 5 columns, 9 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9601390e-01   3.859342e-03   0.000000e+00      0s
#        1    9.9601390e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  9.960139000e-01
# [Iter 13] #simplices = 22, #active = 2, bad-quality cut = 0
# == [Iter 13] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T24           9.960846e-01      1.006914e+00     -3.452530e-03      9.960846e-01     [9.96e-01, 1.01e+00]     [9.93e-01, 1.01e+00]     0
# T25           9.960139e-01      9.998732e-01     -6.480554e-03      9.960139e-01     [9.96e-01, 1.01e+00]     [9.90e-01, 1.00e+00]     0
#
# == [Iter 13] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.010895e+00      8.116066e+04     -9.188393e+05      1.010895e+00     [2.28e+00, 1.00e+06]    [-9.19e+05, 8.12e+04]     1
# T1            1.031166e+00      3.852915e+05     -6.147085e+05      1.031166e+00     [2.79e+00, 1.00e+06]    [-6.15e+05, 3.85e+05]     1
# T2            1.017234e+00      9.090901e+04     -9.090910e+05      1.017234e+00     [2.79e+00, 1.00e+06]    [-9.09e+05, 9.09e+04]     1
# T3            1.022226e+00      7.466850e+04     -9.253315e+05      1.022226e+00     [2.79e+00, 1.00e+06]    [-9.25e+05, 7.47e+04]     2
# T4            1.003751e+00      3.923443e+05     -6.076557e+05      1.003751e+00     [2.79e+00, 1.00e+06]    [-6.08e+05, 3.92e+05]     2
# T5            9.976726e-01      7.699306e+01     -1.696225e+02      9.976726e-01     [2.28e+00, 2.47e+02]    [-1.67e+02, 7.70e+01]     0
# T6            9.972225e-01      1.199134e+02     -1.267022e+02      9.972225e-01     [2.28e+00, 2.47e+02]    [-1.24e+02, 1.20e+02]     0
# T7            9.993672e-01      8.989365e+05     -1.010635e+05      9.993672e-01     [2.79e+00, 1.00e+06]    [-1.01e+05, 8.99e+05]     1
# T8            3.747739e+01      9.993080e+05     -6.919628e+02      3.747739e+01     [3.75e+01, 1.00e+06]    [-6.54e+02, 9.99e+05]     1
# T9            9.979278e-01      1.122367e+02     -1.343788e+02      9.979278e-01     [1.37e+00, 2.47e+02]    [-1.33e+02, 1.12e+02]     0
# T10           1.367125e+00      1.500116e+02     -9.660398e+01      1.367125e+00     [1.37e+00, 2.47e+02]    [-9.52e+01, 1.50e+02]     0
# T11           9.966005e-01      2.121659e+02     -3.444967e+01      9.966005e-01     [1.37e+00, 2.47e+02]    [-3.31e+01, 2.12e+02]     0
# T13           1.367125e+00      4.404032e+01     -9.661016e+01      1.367125e+00     [1.37e+00, 1.41e+02]    [-9.52e+01, 4.40e+01]     0
# T15           1.367125e+00      1.582222e+01     -2.165517e+01      1.367125e+00     [1.37e+00, 3.75e+01]    [-2.03e+01, 1.58e+01]     0
# T18           9.986441e-01      1.646529e+00     -7.768463e-01      9.986441e-01     [9.99e-01, 2.42e+00]     [2.22e-01, 1.65e+00]     0
# T19           9.965909e-01      1.806132e+00     -4.747107e-01      9.965909e-01     [9.99e-01, 2.28e+00]     [5.24e-01, 1.81e+00]     0
# T20           9.986426e-01      1.424599e+00     -2.992280e-01      9.986426e-01     [9.99e-01, 1.72e+00]     [6.99e-01, 1.42e+00]     0
# T21           9.986452e-01      1.222287e+00     -1.448381e-01      9.986452e-01     [9.99e-01, 1.37e+00]     [8.54e-01, 1.22e+00]     0
# T22           9.986426e-01      1.083708e+00     -3.241134e-02      9.986426e-01     [9.99e-01, 1.12e+00]     [9.66e-01, 1.08e+00]     0
# T23           9.986595e-01      1.037567e+00     -1.381097e-02      9.986595e-01     [9.99e-01, 1.05e+00]     [9.85e-01, 1.04e+00]     0
#
# [Iter 13] created=22 (cum=207), active=2, active+UB=2, ms_recomputed=2
# [DEBUG] about to call _debug_plot_lb_simplex_scatter, iter=13, simplex=25
# [DEBUG] _debug_plot_lb_simplex_scatter: enter, iter=13, simplex=25
# [DEBUG] (from scatter helper) LB simplex 25:
#     vert 0 (node 15): sum(As+ms) = 9.998732e-01, sum(c_s) = 9.960139e-01
#     vert 1 (node 20): sum(As+ms) = 9.896041e-01, sum(c_s) = 9.960139e-01
#     vert 2 (node 19): sum(As+ms) = 9.944344e-01, sum(c_s) = 9.960139e-01
#     vert 3 (node 14): sum(As+ms) = 9.921621e-01, sum(c_s) = 9.960139e-01
# [DEBUG] _debug_plot_lb_simplex_scatter: n_samples=300, outdir=lb_debug_plots1
# [DEBUG] Iter 13, simplex 25: Points with A_sum+ms_total > c_total = 45/300 (0.150)
# [DEBUG] LB simplex scatter saved to: lb_debug_plots1\lb_simplex_iter_13.html
# [DEBUG] _debug_plot_lb_simplex_scatter: exit, iter=13
# [Iter 13] Optimality abs-gap: 7.073882e-05 (0.007%)
# [Iter 13] Stop: UB-LB gap 7.101688e-05 <= tol 1.000000e-03.
#
# ===== Simplex search summary (per-scenario) =====
#   Time (s)  # Nodes             LB             UB   Rel. Gap   Abs. Gap   #simplex    #active   Split       Selection
# ---------------------------------------------------------------------------------------------------------------------
#      2.633        8    0.998960724    2.280842598   56.2021%    1.28188          6          6    none        ms(dist)
#      5.182        9    0.996034026    2.280842598   56.3304%    1.28481          7          7    edge        ms(dist)
#      6.710       10    0.996150743    2.280842598   56.3253%    1.28469          9          9    face        ms(dist)
#      8.453       11    0.996372707    2.280842598   56.3156%    1.28447         10          9    edge        ms(dist)
#     11.651       12    0.996533489    1.367125219   27.1074%    0.37059         13         12interior        ms(dist)
#     13.007       13    0.996015643    1.367125219   27.1453%    0.37111         14         13interior        ms(dist)
#     14.790       14    0.996010802    1.367125219   27.1456%    0.37111         15         14interior        ms(dist)
#     16.784       15    0.996008073    0.998642632    0.2638%    0.00263         16          5    edge        ms(dist)
#     18.626       16    0.996030546    0.998642632    0.2616%    0.00261         17          6    edge        ms(dist)
#     19.959       17    0.996003470    0.998642632    0.2643%    0.00264         18          7    edge        ms(dist)
#     21.078       18    0.996003464    0.998642632    0.2643%    0.00264         19          7    edge        ms(dist)
#     22.131       19    0.996009206    0.998642632    0.2637%    0.00263         20          8    edge        ms(dist)
#     23.084       20    0.996006355    0.998642632    0.2640%    0.00264         21          8    edge        ms(dist)
#     24.113       21    0.996013900    0.996084639    0.0071%    0.00007         22          2    edge             N/A
# [Time] Main loop total: 24.343s
#
# ==== Done ====
# Total nodes: 21
# Best UB: 0.9960846388203253
# Last LB: 0.9960139000012315

# %%
timing = hist["timing"]
iter_ms_time = timing["iter_ms_time"]
iter_q_time = timing["iter_Q_new_time"]
iter_total_time = timing["iter_total_time"]

init_q_time = timing["init_Q_time"]
total_ms_time = sum(iter_ms_time)
total_q_time = sum(iter_q_time)
total_iter_time = sum(iter_total_time)

# ✅ NEW: Add c_s timing
total_cs_time = sum(sum(b.solve_const_time_hist) for b in ms_bundles)
total_subproblem_time = total_ms_time + total_cs_time

print(f"Init Q time:        {init_q_time:.3f} s")
print(f"Total MS time:      {total_ms_time:.3f} s")
print(f"Total c_s time:     {total_cs_time:.3f} s")
print(f"Total Q-new time:   {total_q_time:.3f} s")
print(f"Total iter runtime: {total_iter_time:.3f} s")
print(f"\nBreakdown:")
print(f"  MS subproblems:   {100.0 * total_ms_time / total_iter_time:.1f}%")
print(f"  c_s subproblems:  {100.0 * total_cs_time / total_iter_time:.1f}%")
print(f"  Q evaluations:    {100.0 * total_q_time / total_iter_time:.1f}%")
print(f"  Other overhead:   {100.0 * (1 - (total_ms_time + total_cs_time + total_q_time) / total_iter_time):.1f}%")
# Out:
# Init Q time:        0.051 s
# Total MS time:      504.366 s
# Total c_s time:     7.554 s
# Total Q-new time:   0.098 s
# Total iter runtime: 508.816 s
#
# Breakdown:
#   MS subproblems:   99.1%
#   c_s subproblems:  1.5%
#   Q evaluations:    0.0%
#   Other overhead:   -0.6%

# %%
timing = hist["timing"]
iter_ms_time = timing["iter_ms_time"]
iter_q_time = timing["iter_Q_new_time"]
iter_total_time = timing["iter_total_time"]

init_q_time   = timing["init_Q_time"]
total_ms_time = sum(iter_ms_time)
total_q_time  = sum(iter_q_time)
total_iter_time = sum(iter_total_time)

print(f"Init Q time:        {init_q_time:.3f} s")
print(f"Total MS time:      {total_ms_time:.3f} s")
print(f"Total Q-new time:   {total_q_time:.3f} s")
print(f"Total iter runtime: {total_iter_time:.3f} s")
print(f"Share MS:           {100.0 * total_ms_time / total_iter_time:.1f}%")
print(f"Share Q-new:        {100.0 * total_q_time / total_iter_time:.1f}%")
# Out:
# Init Q time:        0.048 s
# Total MS time:      91.333 s
# Total Q-new time:   0.000 s
# Total iter runtime: 91.517 s
# Share MS:           99.8%
# Share Q-new:        0.0%

# %%
iter_ms_times_detail = hist["iter_ms_times_detail"]
per_iter_ms_counts   = hist["per_iter_ms_counts"]

for it, per_scene_times in enumerate(iter_ms_times_detail):
    print(f"\nIter {it}:")

    iter_total_time = 0.0
    iter_total_calls = 0

    for s, times in enumerate(per_scene_times):
        scene_total = sum(times) if times else 0.0
        scene_calls = len(times)
        iter_total_time  += scene_total
        iter_total_calls += scene_calls

        row = [s] + [f"{dt:.2f}" for dt in times] + [f"sum={scene_total:.2f}"]
        print(row)

    expected_calls = per_iter_ms_counts[it]
    if expected_calls != iter_total_calls:
        print(f"[WARN] Iter {it}: 统计到的调用次数={iter_total_calls}，"
              f"per_iter_ms_counts={expected_calls}")

    print(f"Iter {it} total ms time = {iter_total_time:.2f}s, "
          f"total ms solves = {iter_total_calls}")
# Out:
# Iter 0:
# [0, '15.02', '15.02', '15.02', '15.02', '15.02', '15.02', 'sum=90.10']
# Iter 0 total ms time = 90.10s, total ms solves = 6
#
# Iter 1:
# [0, '15.02', '15.02', '15.02', 'sum=45.06']
# Iter 1 total ms time = 45.06s, total ms solves = 3
#
# Iter 2:
# [0, '15.02', '15.02', 'sum=30.04']
# Iter 2 total ms time = 30.04s, total ms solves = 2
#
# Iter 3:
# [0, '15.02', '15.02', '15.02', 'sum=45.06']
# Iter 3 total ms time = 45.06s, total ms solves = 3
#
# Iter 4:
# [0, '15.02', '15.02', 'sum=30.03']
# Iter 4 total ms time = 30.03s, total ms solves = 2
#
# Iter 5:
# [0, '15.01', '15.02', 'sum=30.03']
# Iter 5 total ms time = 30.03s, total ms solves = 2
#
# Iter 6:
# [0, '15.02', '15.02', 'sum=30.04']
# Iter 6 total ms time = 30.04s, total ms solves = 2
#
# Iter 7:
# [0, '15.03', '15.02', 'sum=30.04']
# Iter 7 total ms time = 30.04s, total ms solves = 2
#
# Iter 8:
# [0, '15.02', '15.02', '15.02', '15.02', 'sum=60.08']
# Iter 8 total ms time = 60.08s, total ms solves = 4
#
# Iter 9:
# [0, '15.02', '15.02', '15.02', 'sum=45.07']
# Iter 9 total ms time = 45.07s, total ms solves = 3
#
# Iter 10:
# [0, '15.02', '15.02', 'sum=30.04']
# Iter 10 total ms time = 30.04s, total ms solves = 2
#
# Iter 11:
# [0, '15.02', '15.02', 'sum=30.04']
# Iter 11 total ms time = 30.04s, total ms solves = 2

# %%
# debug_constant_cut.py
import numpy as np
import pyomo.environ as pyo

from modeling import build_models_from_csv
from bundles import BaseBundle, MSBundle
from utils import evaluate_Q_at


def build_scenario_models(csv_path: str,
                          max_scenarios: int = 1,
                          skip: int = 0):
    """
    和主代码一致：用 build_models_from_csv 从 csv 构建场景模型。
    modeling.build_models_from_csv 的签名为：

        def build_models_from_csv(csv_path: str, h: float = 0.2,
                                  weights=(1.0, 0.01), bounds=None,
                                  sp0: float = 0.0, sp1: float = 0.5,
                                  ku_col: str = "tau_us",
                                  tau_col: str = "tau_xs",
                                  disturb_prefix: str = "disturbance_",
                                  setpoint_change_col: str = "setpoint_change",
                                  max_scenarios=None, skip=0):

    这里我们用默认的 h / weights / bounds，保证和原模型构建逻辑一致。
    """
    model_list, first_stg_vars_list, m_tmpl_list, T = build_models_from_csv(
        csv_path=csv_path,
        max_scenarios=max_scenarios,
        skip=skip,
    )
    return model_list, first_stg_vars_list, T


def debug_constant_cut_for_tetra(csv_path: str):
    # 1) 构建场景模型，只取场景 0
    print("=== 构建场景模型（从 CSV） ===")
    model_list, first_stg_vars_list, T = build_scenario_models(
        csv_path=csv_path,
        max_scenarios=1,
        skip=0,
    )
    m0 = model_list[0]
    first_vars0 = first_stg_vars_list[0]
    print(f"  已加载场景 0，时间步 T = {T}")
    print(f"  第一阶段变量个数 = {len(first_vars0)} "
          f"（应至少包含 Kp, Ki, Kd 三个）")

    # 2) 构建 BaseBundle，用来在 4 个顶点上求 Q_0
    print("\n=== 构建 BaseBundle，用于顶点上 Q_0 评估 ===")
    base_opts = {
        "NonConvex": 2,
        "MIPGap": 0.2,
        "TimeLimit": 600,   # 顶点评估给宽松一点
    }
    base_bundle0 = BaseBundle(m0, options=base_opts)

    # 3) 定义出错的四个顶点（给的是 (Kp, Ki, Kd)）
    print("\n=== 出错 tetra 的 4 个顶点（场景 0） ===")
    tet_vertices = [
        (-10.0,  100.0, 1000.0),  # v0
        (-10.0, -100.0, 1000.0),  # v1
        ( 10.0, -100.0, -100.0),  # v2
        (-10.0, -100.0, -100.0),  # v3
    ]
    for j, v in enumerate(tet_vertices):
        print(f"  v{j} = {v}")

    # 4) 在这 4 个顶点上分别求 Q_0(v_j)
    print("\n=== 在 4 个顶点上计算 Q_0 ===")
    fverts_scene0 = []
    for j, v in enumerate(tet_vertices):
        q_val = evaluate_Q_at(base_bundle0, first_vars0, v)
        fverts_scene0.append(q_val)
        print(f"  Q_0(v{j}) at K={v} -> {q_val:.6e}")

    fverts_scene0 = list(map(float, fverts_scene0))

    # 5) 构建 MSBundle，用来搭建带 lam 的子模型（和原 ms 完全同构）
    print("\n=== 构建 MSBundle（场景 0）并灌入 tetra ===")
    lb_options = {
        "NonConvex": 2,
        "MIPGap": 0.2,
        "TimeLimit": 15,    # 这就是你 ms / constant-cut 里用的 TimeLimit
    }
    ms_bundle0 = MSBundle(m0, first_vars0, options=lb_options)

    # update_tetra 会：
    #   - 把 link_kp/link_ki/link_kd 的系数改成对应的顶点坐标
    #   - 把 As_def 里的系数改成顶点上的 f_j = Q_s(v_j)
    ms_bundle0.update_tetra(tet_vertices, fverts_scene0)
    print("  已调用 ms_bundle.update_tetra(...)")

    # 6) 在 **同一个 clone 模型** 上改写目标函数为 constant-cut 版本：
    #    原来： obj = obj_expr - As
    #    现在： obj = obj_expr
    print("\n=== 在 MSBundle 的 clone 模型上改写目标为 constant-cut ===")
    m_cc = ms_bundle0.model  # 这是 clone + lam + link + As_def 的模型

    # 删除旧 obj，改成纯 obj_expr
    if hasattr(m_cc, "obj"):
        m_cc.del_component(m_cc.obj)
    m_cc.obj = pyo.Objective(expr=m_cc.obj_expr, sense=pyo.minimize)

    # 告诉 GurobiPersistent 新的目标
    ms_bundle0.gp.set_objective(m_cc.obj)

    # 7) 求解 constant-cut 模型，输出 Gurobi 日志和结果
    print("\n=== 求解 constant-cut 模型（K 在上述 tetra 内） ===")
    # 注意：GurobiPersistent 的参数在 MSBundle.__init__ 里已经设置过，
    # 这里直接 solve 即可；要看完整 log，就 tee=True。
    res = ms_bundle0.gp.solve(load_solutions=True, tee=True)

    status = res.solver.status
    term = res.solver.termination_condition
    obj_val = float(pyo.value(m_cc.obj))

    print("\n=== constant-cut 求解结果 ===")
    print(f"  solver.status              = {status}")
    print(f"  solver.termination_condition = {term}")
    print(f"  constant-cut objective Q_0  = {obj_val:.6e}")

    # 8) 打印一下 lam 和对应的 (Kp, Ki, Kd)，确认解确实在 tetra 内
    lam = np.array([pyo.value(m_cc.lam[j]) for j in m_cc.lam_index], dtype=float)
    print("\n=== barycentric 权重（lam）及其对应的 Kp,Ki,Kd ===")
    for j, val in enumerate(lam):
        print(f"  lam[{j}] = {val:.6e}")
    print(f"  sum(lam) = {lam.sum():.6e}")

    V = np.array(tet_vertices, dtype=float)
    K_opt = lam @ V
    print(f"\n  由 lam * V 得到的 K_opt = (Kp, Ki, Kd) = {tuple(map(float, K_opt))}")

    # 同时打印模型里 Kp/Ki/Kd 的值核对一下
    Kp_var = m_cc.find_component(first_vars0[0].name)
    Ki_var = m_cc.find_component(first_vars0[1].name)
    Kd_var = m_cc.find_component(first_vars0[2].name)
    print("  模型中变量取值：")
    print(f"    Kp = {float(pyo.value(Kp_var)):.6e}")
    print(f"    Ki = {float(pyo.value(Ki_var)):.6e}")
    print(f"    Kd = {float(pyo.value(Kd_var)):.6e}")


if __name__ == "__main__":
    # 这里改成你实际用的 CSV 文件名，比如 "data copy.csv"
    csv_path = "data.csv"
    debug_constant_cut_for_tetra(csv_path)
# Out:
# === 构建场景模型（从 CSV） ===
#   已加载场景 0，时间步 T = 20
#   第一阶段变量个数 = 3 （应至少包含 Kp, Ki, Kd 三个）
#
# === 构建 BaseBundle，用于顶点上 Q_0 评估 ===
# Set parameter MIPGap to value 0.2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 600
#
# === 出错 tetra 的 4 个顶点（场景 0） ===
#   v0 = (-10.0, 100.0, 1000.0)
#   v1 = (-10.0, -100.0, 1000.0)
#   v2 = (10.0, -100.0, -100.0)
#   v3 = (-10.0, -100.0, -100.0)
#
# === 在 4 个顶点上计算 Q_0 ===
#   Q_0(v0) at K=(-10.0, 100.0, 1000.0) -> 1.397547e+00
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasibleOrUnbounded
#     - message from solver: <undefined>
#   Q_0(v1) at K=(-10.0, -100.0, 1000.0) -> 1.397547e+00
#   Q_0(v2) at K=(10.0, -100.0, -100.0) -> 4.186112e-01
#   Q_0(v3) at K=(-10.0, -100.0, -100.0) -> 3.671763e-01
#
# === 构建 MSBundle（场景 0）并灌入 tetra ===
# Set parameter MIPGap to value 0.2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 15
#   已调用 ms_bundle.update_tetra(...)
#
# === 在 MSBundle 的 clone 模型上改写目标为 constant-cut ===
#
# === 求解 constant-cut 模型（K 在上述 tetra 内） ===
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) Gold 6226R CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 32 physical cores, 64 logical processors, using up to 32 threads
#
# Optimize a model with 68 rows, 92 columns and 188 nonzeros
# Model fingerprint: 0x6fe549a8
# Model has 42 quadratic objective terms
# Model has 21 quadratic constraints
# Coefficient statistics:
#   Matrix range     [4e-01, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [7e-03, 2e+00]
#   Bounds range     [2e+00, 1e+03]
#   RHS range        [5e-02, 1e+00]
# Presolve removed 4 rows and 4 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 27 rows and 30 columns
# Presolve time: 0.00s
# Presolved: 306 rows, 123 columns, 960 nonzeros
# Presolved model has 41 quadratic objective terms
# Presolved model has 61 bilinear constraint(s)
# Variable types: 123 continuous, 0 integer (0 binary)
# Found heuristic solution: objective 1.4296402
# Root relaxation presolved: 306 rows, 123 columns, 960 nonzeros
# Root relaxation presolved model has 41 quadratic objective terms
#
#
# Root relaxation: objective 1.453433e-01, 475 iterations, 0.02 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.14534    0   61    1.42964    0.14534  89.8%     -    0s
#      0     0    0.14534    0   61    1.42964    0.14534  89.8%     -    0s
#      0     0    0.14534    0   61    1.42964    0.14534  89.8%     -    0s
#      0     0    0.14534    0   61    1.42964    0.14534  89.8%     -    0s
#      0     0    0.14534    0   61    1.42964    0.14534  89.8%     -    0s
# H    0     0                       0.1464106    0.14534  0.73%     -    0s
#
# Cutting planes:
#   RLT: 20
#
# Explored 1 nodes (816 simplex iterations) in 0.18 seconds (0.04 work units)
# Thread count was 32 (of 64 available processors)
#
# Solution count 2: 0.146411 1.42964
#
# Optimal solution found (tolerance 2.00e-01)
# Best objective 1.464106420383e-01, best bound 1.453433163499e-01, gap 0.7290%
#
# === constant-cut 求解结果 ===
#   solver.status              = ok
#   solver.termination_condition = optimal
#   constant-cut objective Q_0  = 1.464106e-01
#
# === barycentric 权重（lam）及其对应的 Kp,Ki,Kd ===
#   lam[0] = 6.598061e-02
#   lam[1] = 2.492848e-02
#   lam[2] = 5.014117e-01
#   lam[3] = 4.076792e-01
#   sum(lam) = 1.000000e+00
#
#   由 lam * V 得到的 K_opt = (Kp, Ki, Kd) = (0.028233509384378963, -86.8038787955224, -2.842170943040401e-14)
#   模型中变量取值：
#     Kp = 2.823351e-02
#     Ki = -8.680388e+01
#     Kd = 0.000000e+00

# %%
a = 0.7323830480978786
b = 0.6195866823895512
(a-b)/a
# Out:
# 0.15401280245532506

# %%
LB_hist = hist["LB_hist"]
lb_c_agg_hist = hist["lb_c_agg_hist"]
lb_c_per_scene_hist = hist["lb_c_per_scene_hist"]

for it, (lb, c_agg, c_scene) in enumerate(zip(LB_hist, lb_c_agg_hist, lb_c_per_scene_hist)):
    print(f"Iter {it:3d} | LB_global = {lb:.6f}")
    print(f"           c_agg (sum of finite c_s) = {c_agg:.6f}")
    print(f"           c_per_scene = {c_scene}")
    print()
# Out:
# Iter   0 | LB_global = 0.110240
#            c_agg (sum of finite c_s) = 0.110240
#            c_per_scene = [0.11024042469447069]
#
# Iter   1 | LB_global = 0.110240
#            c_agg (sum of finite c_s) = 0.110240
#            c_per_scene = [0.11024042469447069]
#
# Iter   2 | LB_global = 0.110240
#            c_agg (sum of finite c_s) = 0.110240
#            c_per_scene = [0.11024042469447069]
#
# Iter   3 | LB_global = 0.110240
#            c_agg (sum of finite c_s) = 0.110240
#            c_per_scene = [0.11024042469447069]
#
# Iter   4 | LB_global = 0.110240
#            c_agg (sum of finite c_s) = 0.110240
#            c_per_scene = [0.11024042469447069]
#
# Iter   5 | LB_global = 0.110240
#            c_agg (sum of finite c_s) = 0.110240
#            c_per_scene = [0.11024042469447069]
#
# Iter   6 | LB_global = 0.110240
#            c_agg (sum of finite c_s) = 0.110240
#            c_per_scene = [0.11024042469447069]
#
# Iter   7 | LB_global = 0.110240
#            c_agg (sum of finite c_s) = 0.110240
#            c_per_scene = [0.11024042469447069]
#
# Iter   8 | LB_global = 0.110240
#            c_agg (sum of finite c_s) = 0.110240
#            c_per_scene = [0.11024042469447069]
#
# Iter   9 | LB_global = 0.110240
#            c_agg (sum of finite c_s) = 0.110240
#            c_per_scene = [0.11024042469447069]
#
# Iter  10 | LB_global = 0.110240
#            c_agg (sum of finite c_s) = 0.110240
#            c_per_scene = [0.11024042469447069]
#
# Iter  11 | LB_global = 0.110240
#            c_agg (sum of finite c_s) = 0.110240
#            c_per_scene = [0.11024042469447069]

# %%
import matplotlib.pyplot as plt

LB_hist = hist["LB_hist"]

plt.figure()
plt.plot(range(len(LB_hist)), LB_hist, marker="o")
plt.xlabel("Iteration")
plt.ylabel("Global lower bound")
plt.title("Global LB per iteration")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

timing = hist["timing"]

iter_total_time = timing["iter_total_time"]
iter_ms_time    = timing["iter_ms_time"]
iter_q_time     = timing["iter_Q_new_time"]
iters = list(range(len(iter_total_time)))  # 0,1,2,...,n-1

plt.figure(figsize=(8, 5))

plt.plot(iters, iter_total_time, marker="o", label="Total per iteration")
plt.plot(iters, iter_ms_time,    marker="s", label="MS time per iteration")
plt.plot(iters, iter_q_time,     marker="^", label="New-node Q-eval time per iteration")

plt.xlabel("Iteration")
plt.ylabel("Time (seconds)")
# plt.yscale("log")

plt.title("Per-iteration time breakdown")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
init_q_time   = timing["init_Q_time"]
total_ms_time = sum(iter_ms_time)
total_q_time  = sum(iter_q_time)
total_iter_time = sum(iter_total_time)

print(f"Init Q time:        {init_q_time:.3f} s")
print(f"Total MS time:      {total_ms_time:.3f} s")
print(f"Total Q-new time:   {total_q_time:.3f} s")
print(f"Total iter runtime: {total_iter_time:.3f} s")
print(f"Share MS:           {100.0 * total_ms_time / total_iter_time:.1f}%")
print(f"Share Q-new:        {100.0 * total_q_time / total_iter_time:.1f}%")
# Out:
# Init Q time:        0.487 s
# Total MS time:      69.770 s
# Total Q-new time:   0.767 s
# Total iter runtime: 72.508 s
# Share MS:           96.2%
# Share Q-new:        1.1%

# %%
timing = hist["timing"]
per_iter_scene = timing["iter_ms_time_per_scene"]   # [iter][scene]

if not per_iter_scene:
    print("iter_ms_time_per_scene 是空的，没有记录到任何 ms 时间。")
else:
    num_iters = len(per_iter_scene)
    num_scenarios = len(per_iter_scene[0])

    # 打一行表头
    header = "Iter  total_ms  " + "  ".join(f"s{str(s).rjust(2)}" for s in range(num_scenarios))
    print(header)
    print("-" * len(header))

    for it, times_per_scene in enumerate(per_iter_scene):
        total_ms = sum(times_per_scene)
        # 每个场景的时间，保留 3 位小数
        scene_strs = [f"{t:7.3f}" for t in times_per_scene]
        line = f"{it:4d}  {total_ms:8.3f}  " + "  ".join(scene_strs)
        print(line)
# Out:
# Iter  total_ms  s 0
# -------------------
#    0     2.723    2.723
#    1     1.846    1.846
#    2     2.910    2.910
#    3     3.385    3.385
#    4     3.003    3.003
#    5     2.670    2.670
#    6     3.450    3.450
#    7     4.474    4.474
#    8    11.431   11.431
#    9    11.532   11.532
#   10    11.582   11.582
#   11    10.498   10.498

# %%
timing = hist["timing"]
calls_per_iter = timing["iter_ms_calls_per_scene"]   # [iter][scene]

num_iters = len(calls_per_iter)
S = len(ms_bundles)

if num_iters == 0:
    raise RuntimeError("iter_ms_calls_per_scene 是空的，说明你还没记录 per-scene 调用次数。")

# 防御性检查：timing 里的场景数要和 ms_bundles 一致
if len(calls_per_iter[0]) != S:
    raise RuntimeError(
        f"场景数不一致：timing 里是 {len(calls_per_iter[0])}，ms_bundles 里是 {S}"
    )

# offsets[s] 记录：场景 s 的 solve_time_hist 已经用到哪一条（前缀长度）
offsets = [0] * S

# 你想要的两个结果：
# iter_ms_times_detail[it][s] = list of dt for this iter & scene
iter_ms_times_detail: list[list[list[float]]] = []
# 每轮总共解了多少次 ms 子问题
per_iter_ms_counts: list[int] = []

for it in range(num_iters):
    calls_this_iter = calls_per_iter[it]   # 长度 S
    if len(calls_this_iter) != S:
        raise RuntimeError(f"第 {it} 轮 calls 的场景数不等于 S。")

    per_scene_times_this_iter: list[list[float]] = []
    total_calls_this_iter = 0

    for s in range(S):
        n_calls = calls_this_iter[s]
        start = offsets[s]
        end = start + n_calls

        # 从该场景的 solve_time_hist 中切出这一轮的那一段
        times_slice = ms_bundles[s].solve_time_hist[start:end]

        if len(times_slice) != n_calls:
            print(
                f"[WARN] iter {it}, scene {s}: "
                f"期待 {n_calls} 次，切出来 {len(times_slice)} 次"
            )

        per_scene_times_this_iter.append(list(times_slice))
        offsets[s] = end
        total_calls_this_iter += n_calls

    iter_ms_times_detail.append(per_scene_times_this_iter)
    per_iter_ms_counts.append(total_calls_this_iter)

# 全局计数 sanity check
total_from_counts = sum(per_iter_ms_counts)
total_from_hist = sum(len(b.solve_time_hist) for b in ms_bundles)

print(f"sum(per_iter_ms_counts)     = {total_from_counts}")
print(f"sum(len(b.solve_time_hist)) = {total_from_hist}")
if total_from_counts == total_from_hist:
    print("✅ 计数一致，还原 OK。")
else:
    print("⚠️ 计数不一致，说明 timing 或 solve_time_hist 有问题。")
# Out:
# sum(per_iter_ms_counts)     = 50
# sum(len(b.solve_time_hist)) = 50
# ✅ 计数一致，还原 OK。

# %%
for it, per_scene_times in enumerate(iter_ms_times_detail):
    print(f"\nIter {it}:")
    
    iter_total_time = 0.0      # 这一轮所有场景的总时间
    iter_total_calls = 0       # 这一轮总共求解了多少次 ms 子问题

    for s, times in enumerate(per_scene_times):
        scene_total = sum(times) if times else 0.0
        scene_calls = len(times)
        iter_total_time += scene_total
        iter_total_calls += scene_calls

        # 场景号 + 每次求解时间（两位小数）+ 该场景总时间
        row = [s] + [f"{dt:.2f}" for dt in times] + [f"sum={scene_total:.2f}"]
        print(row)

    # 如果你已经有 per_iter_ms_counts，也可以用它来核对：
    expected_calls = per_iter_ms_counts[it]
    if expected_calls != iter_total_calls:
        print(
            f"[WARN] Iter {it}: 统计到的调用次数={iter_total_calls}，"
            f"per_iter_ms_counts={expected_calls}"
        )

    # 这一轮所有场景的总时间 + 总调用次数
    print(f"Iter {it} total ms time = {iter_total_time:.2f}s, "
          f"total ms solves = {iter_total_calls}")
# Out:
# Iter 0:
# [0, '0.06', '0.61', '0.62', '0.32', '0.32', '0.79', 'sum=2.72']
# Iter 0 total ms time = 2.72s, total ms solves = 6
#
# Iter 1:
# [0, '0.59', '0.62', '0.31', '0.33', 'sum=1.85']
# Iter 1 total ms time = 1.85s, total ms solves = 4
#
# Iter 2:
# [0, '0.68', '1.03', '0.49', '0.70', 'sum=2.91']
# Iter 2 total ms time = 2.91s, total ms solves = 4
#
# Iter 3:
# [0, '0.78', '0.81', '1.06', '0.74', 'sum=3.38']
# Iter 3 total ms time = 3.38s, total ms solves = 4
#
# Iter 4:
# [0, '0.61', '0.94', '0.49', '0.95', 'sum=3.00']
# Iter 4 total ms time = 3.00s, total ms solves = 4
#
# Iter 5:
# [0, '0.62', '0.75', '0.50', '0.80', 'sum=2.67']
# Iter 5 total ms time = 2.67s, total ms solves = 4
#
# Iter 6:
# [0, '1.35', '0.86', '0.64', '0.61', 'sum=3.45']
# Iter 6 total ms time = 3.45s, total ms solves = 4
#
# Iter 7:
# [0, '0.90', '0.87', '0.83', '1.87', 'sum=4.47']
# Iter 7 total ms time = 4.47s, total ms solves = 4
#
# Iter 8:
# [0, '5.05', '0.64', '5.05', '0.69', 'sum=11.43']
# Iter 8 total ms time = 11.43s, total ms solves = 4
#
# Iter 9:
# [0, '5.05', '0.93', '5.05', '0.51', 'sum=11.53']
# Iter 9 total ms time = 11.53s, total ms solves = 4
#
# Iter 10:
# [0, '5.05', '0.65', '5.05', '0.83', 'sum=11.58']
# Iter 10 total ms time = 11.58s, total ms solves = 4
#
# Iter 11:
# [0, '4.40', '0.52', '0.53', '5.05', 'sum=10.50']
# Iter 11 total ms time = 10.50s, total ms solves = 4

# %%
for it, per_scene_times in enumerate(iter_ms_times_detail):
    print(f"\nIter {it}:")
    
    iter_total_time = 0.0      # 这一轮所有场景的总时间
    iter_total_calls = 0       # 这一轮总共求解了多少次 ms 子问题

    for s, times in enumerate(per_scene_times):
        scene_total = sum(times) if times else 0.0
        scene_calls = len(times)
        iter_total_time += scene_total
        iter_total_calls += scene_calls

        # 场景号 + 每次求解时间（两位小数）+ 该场景总时间
        row = [s] + [f"{dt:.2f}" for dt in times] + [f"sum={scene_total:.2f}"]
        print(row)

    # 如果你已经有 per_iter_ms_counts，也可以用它来核对：
    expected_calls = per_iter_ms_counts[it]
    if expected_calls != iter_total_calls:
        print(
            f"[WARN] Iter {it}: 统计到的调用次数={iter_total_calls}，"
            f"per_iter_ms_counts={expected_calls}"
        )

    # 这一轮所有场景的总时间 + 总调用次数
    print(f"Iter {it} total ms time = {iter_total_time:.2f}s, "
          f"total ms solves = {iter_total_calls}")
# Out:
# Iter 0:
# [0, '0.06', '0.61', '0.62', '0.32', '0.32', '0.79', 'sum=2.72']
# Iter 0 total ms time = 2.72s, total ms solves = 6
#
# Iter 1:
# [0, '0.59', '0.62', '0.31', '0.33', 'sum=1.85']
# Iter 1 total ms time = 1.85s, total ms solves = 4
#
# Iter 2:
# [0, '0.68', '1.03', '0.49', '0.70', 'sum=2.91']
# Iter 2 total ms time = 2.91s, total ms solves = 4
#
# Iter 3:
# [0, '0.78', '0.81', '1.06', '0.74', 'sum=3.38']
# Iter 3 total ms time = 3.38s, total ms solves = 4
#
# Iter 4:
# [0, '0.61', '0.94', '0.49', '0.95', 'sum=3.00']
# Iter 4 total ms time = 3.00s, total ms solves = 4
#
# Iter 5:
# [0, '0.62', '0.75', '0.50', '0.80', 'sum=2.67']
# Iter 5 total ms time = 2.67s, total ms solves = 4
#
# Iter 6:
# [0, '1.35', '0.86', '0.64', '0.61', 'sum=3.45']
# Iter 6 total ms time = 3.45s, total ms solves = 4
#
# Iter 7:
# [0, '0.90', '0.87', '0.83', '1.87', 'sum=4.47']
# Iter 7 total ms time = 4.47s, total ms solves = 4
#
# Iter 8:
# [0, '5.05', '0.64', '5.05', '0.69', 'sum=11.43']
# Iter 8 total ms time = 11.43s, total ms solves = 4
#
# Iter 9:
# [0, '5.05', '0.93', '5.05', '0.51', 'sum=11.53']
# Iter 9 total ms time = 11.53s, total ms solves = 4
#
# Iter 10:
# [0, '5.05', '0.65', '5.05', '0.83', 'sum=11.58']
# Iter 10 total ms time = 11.58s, total ms solves = 4
#
# Iter 11:
# [0, '4.40', '0.52', '0.53', '5.05', 'sum=10.50']
# Iter 11 total ms time = 10.50s, total ms solves = 4

# %%
# 假设你先跑了一遍：
# res = run_pid_simplex_3d(...)
iter_q_times_detail = hist["iter_q_times_detail"]
per_iter_q_counts   = hist["per_iter_q_counts"]

for it, per_scene_times in enumerate(iter_q_times_detail):
    print(f"\n[Q_s] Iter {it}:")
    
    iter_total_time = 0.0      # 这一轮所有场景 Q_s 的总时间
    iter_total_calls = 0       # 这一轮总共求解了多少次 Q_s

    for s, times in enumerate(per_scene_times):
        scene_total = sum(times) if times else 0.0
        scene_calls = len(times)
        iter_total_time += scene_total
        iter_total_calls += scene_calls

        # 场景号 + 每次求解时间（两位小数）+ 该场景总时间
        row = [s] + [f"{dt:.2f}" for dt in times] + [f"sum={scene_total:.2f}"]
        print(row)

    # 如果你想核对 per_iter_q_counts，也可以这么用：
    expected_calls = per_iter_q_counts[it]
    if expected_calls != iter_total_calls:
        print(
            f"[WARN][Q_s] Iter {it}: 统计到的调用次数={iter_total_calls}，"
            f"per_iter_q_counts={expected_calls}"
        )

    # 这一轮所有场景的总时间 + 总调用次数
    print(f"[Q_s] Iter {it} total Q_s time = {iter_total_time:.2f}s, "
          f"total Q_s solves = {iter_total_calls}")
# Out:
# [Q_s] Iter 0:
# [0, '0.07', 'sum=0.07']
# [Q_s] Iter 0 total Q_s time = 0.07s, total Q_s solves = 1
#
# [Q_s] Iter 1:
# [0, '0.06', 'sum=0.06']
# [Q_s] Iter 1 total Q_s time = 0.06s, total Q_s solves = 1
#
# [Q_s] Iter 2:
# [0, '0.07', 'sum=0.07']
# [Q_s] Iter 2 total Q_s time = 0.07s, total Q_s solves = 1
#
# [Q_s] Iter 3:
# [0, '0.07', 'sum=0.07']
# [Q_s] Iter 3 total Q_s time = 0.07s, total Q_s solves = 1
#
# [Q_s] Iter 4:
# [0, '0.07', 'sum=0.07']
# [Q_s] Iter 4 total Q_s time = 0.07s, total Q_s solves = 1
#
# [Q_s] Iter 5:
# [0, '0.06', 'sum=0.06']
# [Q_s] Iter 5 total Q_s time = 0.06s, total Q_s solves = 1
#
# [Q_s] Iter 6:
# [0, '0.03', 'sum=0.03']
# [Q_s] Iter 6 total Q_s time = 0.03s, total Q_s solves = 1
#
# [Q_s] Iter 7:
# [0, '0.06', 'sum=0.06']
# [Q_s] Iter 7 total Q_s time = 0.06s, total Q_s solves = 1
#
# [Q_s] Iter 8:
# [0, '0.07', 'sum=0.07']
# [Q_s] Iter 8 total Q_s time = 0.07s, total Q_s solves = 1
#
# [Q_s] Iter 9:
# [0, '0.07', 'sum=0.07']
# [Q_s] Iter 9 total Q_s time = 0.07s, total Q_s solves = 1
#
# [Q_s] Iter 10:
# [0, '0.06', 'sum=0.06']
# [Q_s] Iter 10 total Q_s time = 0.06s, total Q_s solves = 1
#
# [Q_s] Iter 11:
# [0, '0.07', 'sum=0.07']
# [Q_s] Iter 11 total Q_s time = 0.07s, total Q_s solves = 1

# %%
for it in range(len(iter_ms_times_detail)):
    print(f"\n========== Iter {it} ==========")

    # --- 打印 ms 时间 ---
    ms_scene_times = iter_ms_times_detail[it]
    ms_total_time = sum(sum(ts) for ts in ms_scene_times)
    ms_total_calls = sum(len(ts) for ts in ms_scene_times)
    print("[ms] per-scene detail:")
    for s, times in enumerate(ms_scene_times):
        row = [s] + [f"{dt:.2f}" for dt in times] + [f"sum={sum(times):.2f}"]
        print(row)
    print(f"[ms] total time = {ms_total_time:.2f}s, total solves = {ms_total_calls}")

    # --- 打印 Q_s 时间 ---
    q_scene_times = iter_q_times_detail[it]
    q_total_time = sum(sum(ts) for ts in q_scene_times)
    q_total_calls = sum(len(ts) for ts in q_scene_times)
    print("[Q_s] per-scene detail:")
    for s, times in enumerate(q_scene_times):
        row = [s] + [f"{dt:.2f}" for dt in times] + [f"sum={sum(times):.2f}"]
        print(row)
    print(f"[Q_s] total time = {q_total_time:.2f}s, total solves = {q_total_calls}")

    print(f"[ms_tot/Q_s] ratio = {ms_total_time/q_total_time:.2f}, [ms_perscen/Q_s] ratio = {(ms_total_time*q_total_calls)/(q_total_time*ms_total_calls):.2f}")
# Out:
# ========== Iter 0 ==========
# [ms] per-scene detail:
# [0, '0.06', '0.61', '0.62', '0.32', '0.32', '0.79', 'sum=2.72']
# [ms] total time = 2.72s, total solves = 6
# [Q_s] per-scene detail:
# [0, '0.07', 'sum=0.07']
# [Q_s] total time = 0.07s, total solves = 1
# [ms_tot/Q_s] ratio = 37.97, [ms_perscen/Q_s] ratio = 6.33
#
# ========== Iter 1 ==========
# [ms] per-scene detail:
# [0, '0.59', '0.62', '0.31', '0.33', 'sum=1.85']
# [ms] total time = 1.85s, total solves = 4
# [Q_s] per-scene detail:
# [0, '0.06', 'sum=0.06']
# [Q_s] total time = 0.06s, total solves = 1
# [ms_tot/Q_s] ratio = 29.91, [ms_perscen/Q_s] ratio = 7.48
#
# ========== Iter 2 ==========
# [ms] per-scene detail:
# [0, '0.68', '1.03', '0.49', '0.70', 'sum=2.91']
# [ms] total time = 2.91s, total solves = 4
# [Q_s] per-scene detail:
# [0, '0.07', 'sum=0.07']
# [Q_s] total time = 0.07s, total solves = 1
# [ms_tot/Q_s] ratio = 41.82, [ms_perscen/Q_s] ratio = 10.46
#
# ========== Iter 3 ==========
# [ms] per-scene detail:
# [0, '0.78', '0.81', '1.06', '0.74', 'sum=3.38']
# [ms] total time = 3.38s, total solves = 4
# [Q_s] per-scene detail:
# [0, '0.07', 'sum=0.07']
# [Q_s] total time = 0.07s, total solves = 1
# [ms_tot/Q_s] ratio = 45.91, [ms_perscen/Q_s] ratio = 11.48
#
# ========== Iter 4 ==========
# [ms] per-scene detail:
# [0, '0.61', '0.94', '0.49', '0.95', 'sum=3.00']
# [ms] total time = 3.00s, total solves = 4
# [Q_s] per-scene detail:
# [0, '0.07', 'sum=0.07']
# [Q_s] total time = 0.07s, total solves = 1
# [ms_tot/Q_s] ratio = 43.59, [ms_perscen/Q_s] ratio = 10.90
#
# ========== Iter 5 ==========
# [ms] per-scene detail:
# [0, '0.62', '0.75', '0.50', '0.80', 'sum=2.67']
# [ms] total time = 2.67s, total solves = 4
# [Q_s] per-scene detail:
# [0, '0.06', 'sum=0.06']
# [Q_s] total time = 0.06s, total solves = 1
# [ms_tot/Q_s] ratio = 41.90, [ms_perscen/Q_s] ratio = 10.48
#
# ========== Iter 6 ==========
# [ms] per-scene detail:
# [0, '1.35', '0.86', '0.64', '0.61', 'sum=3.45']
# [ms] total time = 3.45s, total solves = 4
# [Q_s] per-scene detail:
# [0, '0.03', 'sum=0.03']
# [Q_s] total time = 0.03s, total solves = 1
# [ms_tot/Q_s] ratio = 114.44, [ms_perscen/Q_s] ratio = 28.61
#
# ========== Iter 7 ==========
# [ms] per-scene detail:
# [0, '0.90', '0.87', '0.83', '1.87', 'sum=4.47']
# [ms] total time = 4.47s, total solves = 4
# [Q_s] per-scene detail:
# [0, '0.06', 'sum=0.06']
# [Q_s] total time = 0.06s, total solves = 1
# [ms_tot/Q_s] ratio = 70.65, [ms_perscen/Q_s] ratio = 17.66
#
# ========== Iter 8 ==========
# [ms] per-scene detail:
# [0, '5.05', '0.64', '5.05', '0.69', 'sum=11.43']
# [ms] total time = 11.43s, total solves = 4
# [Q_s] per-scene detail:
# [0, '0.07', 'sum=0.07']
# [Q_s] total time = 0.07s, total solves = 1
# [ms_tot/Q_s] ratio = 167.30, [ms_perscen/Q_s] ratio = 41.83
#
# ========== Iter 9 ==========
# [ms] per-scene detail:
# [0, '5.05', '0.93', '5.05', '0.51', 'sum=11.53']
# [ms] total time = 11.53s, total solves = 4
# [Q_s] per-scene detail:
# [0, '0.07', 'sum=0.07']
# [Q_s] total time = 0.07s, total solves = 1
# [ms_tot/Q_s] ratio = 160.11, [ms_perscen/Q_s] ratio = 40.03
#
# ========== Iter 10 ==========
# [ms] per-scene detail:
# [0, '5.05', '0.65', '5.05', '0.83', 'sum=11.58']
# [ms] total time = 11.58s, total solves = 4
# [Q_s] per-scene detail:
# [0, '0.06', 'sum=0.06']
# [Q_s] total time = 0.06s, total solves = 1
# [ms_tot/Q_s] ratio = 208.98, [ms_perscen/Q_s] ratio = 52.25
#
# ========== Iter 11 ==========
# [ms] per-scene detail:
# [0, '4.40', '0.52', '0.53', '5.05', 'sum=10.50']
# [ms] total time = 10.50s, total solves = 4
# [Q_s] per-scene detail:
# [0, '0.07', 'sum=0.07']
# [Q_s] total time = 0.07s, total solves = 1
# [ms_tot/Q_s] ratio = 154.01, [ms_perscen/Q_s] ratio = 38.50
