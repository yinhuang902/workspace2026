# %%
from time import perf_counter  

from modeling import build_models_from_csv
from bundles import BaseBundle, MSBundle
from utils import (
    tighten_bounds_one_model,
    MIN_DIST, ACTIVE_TOL, GAP_STOP_TOL,
)
from simplex_specialstart import run_pid_simplex_3d

# setup scenario number and target_nodes
csv_path       = "data500.csv"
max_scenarios  = 1
target_nodes   = 50

bounds={
    "Kp": (-10.0, 10.0),
    "Ki": (-100.0, 100.0),
    "Kd": (-100.0, 1000.0),
    "x": (-2.5, 2.5),
    "u": (-5.0, 5.0),
    "e": (None, None),
    "I": (None, None),
}

weights = (10.0, 0.01)


# ====== stage 1：load data and generate models ======
T   = 15.0          
nfe = 20            

t_load0 = perf_counter()
model_list, first_stg_vars_list, m_tmpl_list, nfe = build_models_from_csv(
    csv_path=csv_path,
    T=T,
    nfe=nfe,
    weights=weights,
    bounds=bounds,
    sp0=0.0,
    sp1=0.5,
    tau_xs_col="tau_xs",
    tau_us_col="tau_us",
    tau_ds_col="tau_ds",          
    disturb_prefix="disturbance_",
    setpoint_change_col="setpoint_change",
    max_scenarios=max_scenarios,
    skip=0,
)
t_load1 = perf_counter()
print(f"[Time] Data load & scenario build: {t_load1 - t_load0:.3f}s")


# ====== stage 1.5：FBBT / OBBT ======
# same as snog: FBBT open,OBBT open
obbt_solver_opts = {
    "NonConvex": 2,
    "MIPGap": 1,     
    "TimeLimit": 15   
}
for m, yvars in zip(model_list, first_stg_vars_list):
    tighten_bounds_one_model(m, yvars,
                             use_fbbt=False,
                             use_obbt=False,
                             obbt_solver_name="gurobi",
                             obbt_solver_opts=obbt_solver_opts,
                             max_rounds=3, tol=1e-6, verbose=True)

# ====== stage 2: Persistent Solver Packaging ======
ub_options = {
    'NonConvex': 2,        
}
lb_options = {
    'NonConvex': 2,
    'MIPGap': 1e-1,            
    'TimeLimit': 15    
}

t_wrap0 = perf_counter()
base_bundles = [BaseBundle(m, ub_options) for m in model_list]  
ms_bundles   = [MSBundle(m, yvars, lb_options) for m, yvars in zip(model_list, first_stg_vars_list)]  # LB 侧
t_wrap1 = perf_counter()
print(f"[Time] Persistent wrapper (GurobiPersistent) setup: {t_wrap1 - t_wrap0:.3f}s")

# ====== stage 3：main loop ======
agg_bundle = None  

t_run0 = perf_counter()
hist = run_pid_simplex_3d(
    base_bundles=base_bundles,
    ms_bundles=ms_bundles,
    model_list=model_list,
    first_vars_list=first_stg_vars_list,
    target_nodes=target_nodes,
    min_dist=0,
    active_tol=ACTIVE_TOL,
    verbose=True,
    agg_bundle=agg_bundle,
    gap_stop_tol=1e-3,
    plot_every=2,
    use_exact_opt=False,
    exact_solver_name="gurobi",
    exact_solver_opts={"NonConvex": 2, "TimeLimit": 60},
)
t_run1 = perf_counter()
print(f"[Time] Main loop total: {t_run1 - t_run0:.3f}s")

# ====== print output ======
print("\n==== Done ====")
print(f"Total nodes: {len(hist['nodes'])}")
print(f"Best UB: {min(hist['UB_hist']) if hist['UB_hist'] else None}")
print(f"Last LB: {hist['LB_hist'][-1] if hist['LB_hist'] else None}")
# Out:
# [Time] Data load & scenario build: 0.012s
# [Tighten] rounds=1, changed=False
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2689754
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 15
# [Time] Persistent wrapper (GurobiPersistent) setup: 0.033s
# [Precompute] File exact_opt_precomputed.csv not found; true optima will not be plotted.
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 1000.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 1000.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: AMD Ryzen 9 7900X 12-Core Processor, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 12 physical cores, 24 logical processors, using up to 24 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 109 rows, 135 columns and 309 nonzeros
# Model fingerprint: 0xb7aab053
# Model has 42 quadratic objective terms
# Model has 21 quadratic constraints
# Coefficient statistics:
#   Matrix range     [6e-01, 1e+10]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [7e-03, 2e+01]
#   Bounds range     [2e+00, 1e+10]
#   RHS range        [6e-02, 1e+00]
# Warning: Model contains large matrix coefficients
# Warning: Model contains large bounds
# Presolve removed 24 rows and 25 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 49 rows and 50 columns
# Presolve time: 0.00s
# Presolved: 324 rows, 146 columns, 991 nonzeros
# Presolved model has 41 quadratic objective terms
# Presolved model has 61 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 146 continuous, 0 integer (0 binary)
# Root relaxation presolved: 319 rows, 142 columns, 977 nonzeros
# Root relaxation presolved model has 40 quadratic objective terms
#
#
# Root relaxation: objective -9.896466e+09, 486 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 -9.896e+09    0   21          - -9.896e+09      -     -    0s
#      0     0 -9.642e+09    0   21          - -9.642e+09      -     -    0s
#      0     2 -9.642e+09    0   21          - -9.642e+09      -     -    0s
# *    6     6               2    -8.88672e+09 -9.642e+09  8.50%   227    0s
#
# Explored 7 nodes (1847 simplex iterations) in 0.13 seconds (0.10 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 1: -8.88672e+09
#
# Optimal solution found (tolerance 1.00e-01)
# Warning: max constraint violation (1.9073e-06) exceeds tolerance
# Best objective -8.886721093087e+09, best bound -9.641894768206e+09, gap 8.4978%
# Set parameter TimeLimit to value 5
# [Gurobi] Solving MS (Quadratic) for scenario None...
# Set parameter OutputFlag to value 1
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: AMD Ryzen 9 7900X 12-Core Processor, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 12 physical cores, 24 logical processors, using up to 24 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 108 rows, 135 columns and 308 nonzeros
# Model fingerprint: 0x47e68918
# Model has 42 quadratic objective terms
# Model has 22 quadratic constraints
# Coefficient statistics:
#   Matrix range     [6e-01, 1e+10]
#   QMatrix range    [1e+00, 2e+10]
#   QLMatrix range   [1e+00, 1e+10]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [7e-03, 2e+01]
#   Bounds range     [2e+00, 1e+10]
#   RHS range        [6e-02, 1e+00]
# Warning: Model contains large matrix coefficients
# Warning: Model contains large bounds
# Warning: Quadratic constraints contain large coefficient range
# Warning: Quadratic constraints contain large coefficients on linear part
# Presolve removed 23 rows and 24 columns
#
# Continuous model is non-convex -- solving as a MIP
#
#
# MIP start from previous solve produced solution with objective 15.522 (0.03s)
# MIP start from previous solve produced solution with objective 13.5666 (0.09s)
# Loaded MIP start from previous solve with objective 13.5666
#
# Presolve removed 45 rows and 46 columns
# Presolve time: 0.00s
# Presolved: 364 rows, 160 columns, 1082 nonzeros
# Presolved model has 41 quadratic objective terms
# Presolved model has 71 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 160 continuous, 0 integer (0 binary)
# Found heuristic solution: objective 13.0632870
# Root relaxation presolved: 346 rows, 154 columns, 1051 nonzeros
# Root relaxation presolved model has 40 quadratic objective terms
#
#
# Root relaxation: objective 9.896966e-01, 335 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.98970    0   64   13.06329    0.98970  92.4%     -    0s
#      0     0    0.98970    0   64   13.06329    0.98970  92.4%     -    0s
#      0     0    0.98970    0   64   13.06329    0.98970  92.4%     -    0s
#      0     0    0.98970    0   64   13.06329    0.98970  92.4%     -    0s
#      0     0    0.98970    0   64   13.06329    0.98970  92.4%     -    0s
# H    0     0                       1.0320258    0.98970  4.10%     -    0s
#
# Cutting planes:
#   RLT: 21
#
# Explored 1 nodes (391 simplex iterations) in 0.27 seconds (0.21 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 4: 1.03203 13.0633 13.5666 15.522
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 1.032025786545e+00, best bound 9.896966096528e-01, gap 4.1016%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: AMD Ryzen 9 7900X 12-Core Processor, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 12 physical cores, 24 logical processors, using up to 24 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 3 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0x672c8447
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 9e+09]
# Warning: Model contains large matrix coefficients
# Warning: Model contains large rhs
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 2 rows, 5 columns, 9 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0320258e+00   0.000000e+00   0.000000e+00      0s
#        0    1.0320258e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.032025787e+00
# [BaseBundle.eval_at] Infeasible/Error for K=(0.0, -100.0, 450.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 450.0): status=warning, term=infeasibleOrUnbounded
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: AMD Ryzen 9 7900X 12-Core Processor, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 12 physical cores, 24 logical processors, using up to 24 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 108 rows, 135 columns and 308 nonzeros
# Model fingerprint: 0xca013703
# Model has 42 quadratic objective terms
# Model has 22 quadratic constraints
# Coefficient statistics:
#   Matrix range     [6e-01, 1e+10]
#   QMatrix range    [1e+00, 2e+10]
#   QLMatrix range   [1e+00, 1e+10]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [7e-03, 2e+01]
#   Bounds range     [2e+00, 1e+10]
#   RHS range        [6e-02, 1e+00]
# Warning: Model contains large matrix coefficients
# Warning: Model contains large bounds
# Warning: Quadratic constraints contain large coefficient range
# Warning: Quadratic constraints contain large coefficients on linear part
# Presolve removed 23 rows and 24 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 45 rows and 46 columns
# Presolve time: 0.00s
# Presolved: 364 rows, 160 columns, 1082 nonzeros
# Presolved model has 41 quadratic objective terms
# Presolved model has 71 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 160 continuous, 0 integer (0 binary)
# Root relaxation presolved: 346 rows, 154 columns, 1051 nonzeros
# Root relaxation presolved model has 40 quadratic objective terms
#
#
# Root relaxation: objective -9.746273e+09, 751 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 -9.746e+09    0   43          - -9.746e+09      -     -    0s
#      0     0 -8.865e+09    0   44          - -8.865e+09      -     -    0s
#      0     0 -7.193e+09    0   44          - -7.193e+09      -     -    0s
#      0     0 -6.132e+09    0   44          - -6.132e+09      -     -    0s
# H    0     0                    -5.10398e+09 -6.132e+09  20.1%     -    0s
#      0     2 -6.132e+09    0   44 -5.104e+09 -6.132e+09  20.1%     -    0s
#
# Cutting planes:
#   RLT: 1
#   PSD: 1
#
# Explored 3 nodes (1329 simplex iterations) in 0.12 seconds (0.08 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 1: -5.10398e+09
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective -5.103978885097e+09, best bound -5.534267358982e+09, gap 8.4305%
# Set parameter TimeLimit to value 5
# [Gurobi] Solving MS (Quadratic) for scenario None...
# WARNING: Loading a SolverResults object with an 'aborted' status, but
# containing a solution
# Set parameter OutputFlag to value 1
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: AMD Ryzen 9 7900X 12-Core Processor, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 12 physical cores, 24 logical processors, using up to 24 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 108 rows, 135 columns and 308 nonzeros
# Model fingerprint: 0x6f7f5a0e
# Model has 42 quadratic objective terms
# Model has 22 quadratic constraints
# Coefficient statistics:
#   Matrix range     [6e-01, 1e+10]
#   QMatrix range    [1e+00, 4e+10]
#   QLMatrix range   [1e+00, 1e+10]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [7e-03, 2e+01]
#   Bounds range     [2e+00, 1e+10]
#   RHS range        [6e-02, 1e+00]
# Warning: Model contains large matrix coefficients
# Warning: Model contains large bounds
# Warning: Quadratic constraints contain large coefficient range
# Warning: Quadratic constraints contain large coefficients on linear part
# Presolve removed 23 rows and 24 columns
#
# Continuous model is non-convex -- solving as a MIP
#
#
# MIP start from previous solve produced solution with objective 15.4723 (0.03s)
# MIP start from previous solve produced solution with objective 14.4803 (0.07s)
# MIP start from previous solve produced solution with objective 14.3592 (0.08s)
# MIP start from previous solve produced solution with objective 14.3587 (0.09s)
# MIP start from previous solve produced solution with objective 14.3587 (0.09s)
# MIP start from previous solve produced solution with objective 14.3587 (0.09s)
# MIP start from previous solve produced solution with objective 13.218 (0.10s)
# MIP start from previous solve produced solution with objective 13.2118 (0.12s)
# MIP start from previous solve produced solution with objective 13.2115 (0.12s)
# MIP start from previous solve produced solution with objective 13.2115 (0.13s)
# Loaded MIP start from previous solve with objective 13.2115
#
# Presolve removed 45 rows and 46 columns
# Presolve time: 0.00s
# Presolved: 364 rows, 160 columns, 1082 nonzeros
# Presolved model has 41 quadratic objective terms
# Presolved model has 71 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 160 continuous, 0 integer (0 binary)
# Root relaxation presolved: 346 rows, 154 columns, 1051 nonzeros
# Root relaxation presolved model has 40 quadratic objective terms
#
#
# Root relaxation: objective 9.896966e-01, 405 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.98970    0   64   13.21147    0.98970  92.5%     -    0s
#      0     0    0.98970    0   64   13.21147    0.98970  92.5%     -    0s
#      0     0    0.98970    0   64   13.21147    0.98970  92.5%     -    0s
#      0     0    0.98970    0   64   13.21147    0.98970  92.5%     -    0s
#      0     0    0.98970    0   64   13.21147    0.98970  92.5%     -    0s
#      0     0    0.98970    0   64   13.21147    0.98970  92.5%     -    0s
#      0     0    0.98970    0   64   13.21147    0.98970  92.5%     -    0s
# H    0     0                       1.7455206    0.98970  43.3%     -    0s
#      0     0    0.98970    0   64    1.74552    0.98970  43.3%     -    0s
#      0     2    0.98970    0   64    1.74552    0.98970  43.3%     -    0s
# H    4     8                       1.0137039    0.98970  2.37%   156    0s
#
# Cutting planes:
#   RLT: 20
#   PSD: 1
#
# Explored 7 nodes (1504 simplex iterations) in 0.33 seconds (0.23 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 10: 1.0137 1.74552 13.2115 ... 14.3592
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 1.013703948637e+00, best bound 9.896966096528e-01, gap 2.3683%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: AMD Ryzen 9 7900X 12-Core Processor, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 12 physical cores, 24 logical processors, using up to 24 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 3 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0x906f2286
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+09]
# Warning: Model contains large matrix coefficients
# Warning: Model contains large rhs
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 2 rows, 5 columns, 9 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0137039e+00   0.000000e+00   0.000000e+00      0s
#        0    1.0137039e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.013703949e+00
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 450.0): status=warning, term=infeasibleOrUnbounded
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: AMD Ryzen 9 7900X 12-Core Processor, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 12 physical cores, 24 logical processors, using up to 24 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 108 rows, 135 columns and 308 nonzeros
# Model fingerprint: 0xf94b4989
# Model has 42 quadratic objective terms
# Model has 22 quadratic constraints
# Coefficient statistics:
#   Matrix range     [6e-01, 1e+10]
#   QMatrix range    [1e+00, 4e+10]
#   QLMatrix range   [1e+00, 1e+10]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [7e-03, 2e+01]
#   Bounds range     [2e+00, 1e+10]
#   RHS range        [6e-02, 1e+00]
# Warning: Model contains large matrix coefficients
# Warning: Model contains large bounds
# Warning: Quadratic constraints contain large coefficient range
# Warning: Quadratic constraints contain large coefficients on linear part
# Presolve removed 23 rows and 24 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 45 rows and 46 columns
# Presolve time: 0.00s
# Presolved: 364 rows, 160 columns, 1084 nonzeros
# Presolved model has 41 quadratic objective terms
# Presolved model has 71 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 160 continuous, 0 integer (0 binary)
# Root relaxation presolved: 345 rows, 155 columns, 1049 nonzeros
# Root relaxation presolved model has 40 quadratic objective terms
#
#
# Root relaxation: objective -9.753028e+09, 683 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 -9.753e+09    0   24          - -9.753e+09      -     -    0s
#      0     0 -7.336e+09    0   24          - -7.336e+09      -     -    0s
#      0     0 -5.105e+09    0   64          - -5.105e+09      -     -    0s
# H    0     0                    -5.10514e+09 -5.105e+09  0.00%     -    0s
#
# Explored 1 nodes (785 simplex iterations) in 0.12 seconds (0.07 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 1: -5.10514e+09
#
# Optimal solution found (tolerance 1.00e-01)
# Warning: max constraint violation (1.6279e-06) exceeds tolerance
# Best objective -5.105142503437e+09, best bound -5.105142548087e+09, gap 0.0000%
# Set parameter TimeLimit to value 5
# [Gurobi] Solving MS (Quadratic) for scenario None...
# WARNING: Loading a SolverResults object with an 'aborted' status, but
# containing a solution
# Set parameter OutputFlag to value 1
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: AMD Ryzen 9 7900X 12-Core Processor, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 12 physical cores, 24 logical processors, using up to 24 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 108 rows, 135 columns and 308 nonzeros
# Model fingerprint: 0x4421d3e7
# Model has 42 quadratic objective terms
# Model has 22 quadratic constraints
# Coefficient statistics:
#   Matrix range     [6e-01, 1e+10]
#   QMatrix range    [1e+00, 4e+10]
#   QLMatrix range   [1e+00, 1e+10]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [7e-03, 2e+01]
#   Bounds range     [3e+00, 1e+10]
#   RHS range        [6e-02, 1e+00]
# Warning: Model contains large matrix coefficients
# Warning: Model contains large bounds
# Warning: Quadratic constraints contain large coefficient range
# Warning: Quadratic constraints contain large coefficients on linear part
# Presolve removed 23 rows and 24 columns
#
# Continuous model is non-convex -- solving as a MIP
#
#
# MIP start from previous solve produced solution with objective 26.7647 (0.03s)
# MIP start from previous solve produced solution with objective 17.8606 (0.12s)
# MIP start from previous solve produced solution with objective 2.31036 (0.15s)
# MIP start from previous solve produced solution with objective 2.31025 (0.15s)
# MIP start from previous solve produced solution with objective 1.00802 (0.15s)
# MIP start from previous solve produced solution with objective 1.00565 (0.15s)
# Loaded MIP start from previous solve with objective 1.00565
#
# Presolve removed 45 rows and 46 columns
# Presolve time: 0.00s
# Presolved: 364 rows, 160 columns, 1084 nonzeros
# Presolved model has 41 quadratic objective terms
# Presolved model has 71 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 160 continuous, 0 integer (0 binary)
#
# Explored 0 nodes (0 simplex iterations) in 0.16 seconds (0.13 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 6: 1.00565 1.00802 2.31025 ... 26.7647
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 1.005652549994e+00, best bound 9.375000000000e-01, gap 6.7769%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: AMD Ryzen 9 7900X 12-Core Processor, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 12 physical cores, 24 logical processors, using up to 24 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 3 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0x90888eba
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+09]
# Warning: Model contains large matrix coefficients
# Warning: Model contains large rhs
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 2 rows, 5 columns, 9 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0056525e+00   0.000000e+00   0.000000e+00      0s
#        0    1.0056525e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.005652550e+00
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: AMD Ryzen 9 7900X 12-Core Processor, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 12 physical cores, 24 logical processors, using up to 24 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 108 rows, 135 columns and 308 nonzeros
# Model fingerprint: 0x59ed8a93
# Model has 42 quadratic objective terms
# Model has 22 quadratic constraints
# Coefficient statistics:
#   Matrix range     [6e-01, 1e+10]
#   QMatrix range    [1e+00, 4e+10]
#   QLMatrix range   [1e+00, 1e+10]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [7e-03, 2e+01]
#   Bounds range     [3e+00, 1e+10]
#   RHS range        [6e-02, 1e+00]
# Warning: Model contains large matrix coefficients
# Warning: Model contains large bounds
# Warning: Quadratic constraints contain large coefficient range
# Warning: Quadratic constraints contain large coefficients on linear part
# Presolve removed 23 rows and 24 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 45 rows and 46 columns
# Presolve time: 0.00s
# Presolved: 364 rows, 160 columns, 1082 nonzeros
# Presolved model has 41 quadratic objective terms
# Presolved model has 71 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 160 continuous, 0 integer (0 binary)
# Root relaxation presolved: 346 rows, 154 columns, 1051 nonzeros
# Root relaxation presolved model has 40 quadratic objective terms
#
#
# Root relaxation: objective -9.880947e+09, 573 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 -9.881e+09    0   44          - -9.881e+09      -     -    0s
#      0     0 -9.877e+09    0   44          - -9.877e+09      -     -    0s
#      0     0 -9.877e+09    0   44          - -9.877e+09      -     -    0s
#      0     0 -9.709e+09    0   43          - -9.709e+09      -     -    0s
#      0     2 -9.709e+09    0   43          - -9.709e+09      -     -    0s
# *  206   178              13    -5.00000e+09 -9.166e+09  83.3%  64.5    0s
# H  336   272                    -9.07107e+09 -9.160e+09  0.98%  59.1    0s
#
# Cutting planes:
#   RLT: 2
#   PSD: 1
#
# Explored 385 nodes (22539 simplex iterations) in 0.20 seconds (0.17 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: -9.07107e+09 -5e+09
#
# Optimal solution found (tolerance 1.00e-01)
# Warning: max constraint violation (1.7561e-06) exceeds tolerance
# Best objective -9.071074451102e+09, best bound -9.159691419420e+09, gap 0.9769%
# Set parameter TimeLimit to value 5
# [Gurobi] Solving MS (Quadratic) for scenario None...
# Set parameter OutputFlag to value 1
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: AMD Ryzen 9 7900X 12-Core Processor, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 12 physical cores, 24 logical processors, using up to 24 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 108 rows, 135 columns and 308 nonzeros
# Model fingerprint: 0x5f4c4070
# Model has 42 quadratic objective terms
# Model has 22 quadratic constraints
# Coefficient statistics:
#   Matrix range     [6e-01, 1e+10]
#   QMatrix range    [1e+00, 2e+10]
#   QLMatrix range   [1e+00, 1e+10]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [7e-03, 2e+01]
#   Bounds range     [3e+00, 1e+10]
#   RHS range        [6e-02, 1e+00]
# Warning: Model contains large matrix coefficients
# Warning: Model contains large bounds
# Warning: Quadratic constraints contain large coefficient range
# Warning: Quadratic constraints contain large coefficients on linear part
# Presolve removed 23 rows and 24 columns
#
# Continuous model is non-convex -- solving as a MIP
#
#
# MIP start from previous solve produced solution with objective 26.7647 (0.03s)
# MIP start from previous solve produced solution with objective 1.01435 (0.11s)
# MIP start from previous solve produced solution with objective 1.01426 (0.11s)
# MIP start from previous solve produced solution with objective 1.01425 (0.11s)
# MIP start from previous solve produced solution with objective 1.01425 (0.13s)
# MIP start from previous solve produced solution with objective 1.01425 (0.13s)
# MIP start from previous solve produced solution with objective 1.01425 (0.13s)
# MIP start from previous solve produced solution with objective 1.01267 (0.13s)
# Loaded MIP start from previous solve with objective 1.01267
#
# Presolve removed 45 rows and 46 columns
# Presolve time: 0.00s
# Presolved: 364 rows, 160 columns, 1082 nonzeros
# Presolved model has 41 quadratic objective terms
# Presolved model has 71 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 160 continuous, 0 integer (0 binary)
#
# Explored 0 nodes (0 simplex iterations) in 0.14 seconds (0.12 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 8: 1.01267 1.01425 1.01425 ... 26.7647
#
# Optimal solution found (tolerance 1.00e-01)
# Warning: max constraint violation (1.0192e-06) exceeds tolerance
# Best objective 1.012672087613e+00, best bound 9.375000000000e-01, gap 7.4231%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: AMD Ryzen 9 7900X 12-Core Processor, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 12 physical cores, 24 logical processors, using up to 24 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 3 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0x53721869
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 9e+09]
# Warning: Model contains large matrix coefficients
# Warning: Model contains large rhs
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 2 rows, 5 columns, 9 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0126721e+00   0.000000e+00   0.000000e+00      0s
#        0    1.0126721e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.012672088e+00
# [BaseBundle.eval_at] Infeasible/Error for K=(0.0, 100.0, -100.0): status=error, term=error
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: AMD Ryzen 9 7900X 12-Core Processor, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 12 physical cores, 24 logical processors, using up to 24 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 108 rows, 135 columns and 308 nonzeros
# Model fingerprint: 0x40a5d0e6
# Model has 42 quadratic objective terms
# Model has 22 quadratic constraints
# Coefficient statistics:
#   Matrix range     [6e-01, 1e+10]
#   QMatrix range    [1e+00, 2e+10]
#   QLMatrix range   [1e+00, 1e+10]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [7e-03, 2e+01]
#   Bounds range     [3e+00, 1e+10]
#   RHS range        [6e-02, 1e+00]
# Warning: Model contains large matrix coefficients
# Warning: Model contains large bounds
# Warning: Quadratic constraints contain large coefficient range
# Warning: Quadratic constraints contain large coefficients on linear part
# Presolve removed 23 rows and 24 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 45 rows and 46 columns
# Presolve time: 0.00s
# Presolved: 364 rows, 160 columns, 1082 nonzeros
# Presolved model has 41 quadratic objective terms
# Presolved model has 71 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 160 continuous, 0 integer (0 binary)
# Root relaxation presolved: 346 rows, 154 columns, 1051 nonzeros
# Root relaxation presolved model has 40 quadratic objective terms
#
#
# Root relaxation: objective -9.941632e+09, 533 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 -9.942e+09    0   47          - -9.942e+09      -     -    0s
#      0     0 -9.916e+09    0   47          - -9.916e+09      -     -    0s
#      0     0 -9.907e+09    0   47          - -9.907e+09      -     -    0s
#      0     0 -9.903e+09    0   47          - -9.903e+09      -     -    0s
# H    0     0                    -9.09091e+09 -9.903e+09  8.93%     -    0s
#
# Cutting planes:
#   RLT: 4
#   PSD: 1
#
# Explored 1 nodes (562 simplex iterations) in 0.12 seconds (0.08 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 1: -9.09091e+09
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective -9.090909091056e+09, best bound -9.902827169705e+09, gap 8.9311%
# Set parameter TimeLimit to value 5
# [Gurobi] Solving MS (Quadratic) for scenario None...
# Set parameter OutputFlag to value 1
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: AMD Ryzen 9 7900X 12-Core Processor, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 12 physical cores, 24 logical processors, using up to 24 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 108 rows, 135 columns and 308 nonzeros
# Model fingerprint: 0x90680d03
# Model has 42 quadratic objective terms
# Model has 22 quadratic constraints
# Coefficient statistics:
#   Matrix range     [6e-01, 1e+10]
#   QMatrix range    [1e+00, 4e+10]
#   QLMatrix range   [1e+00, 1e+10]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [7e-03, 2e+01]
#   Bounds range     [3e+00, 1e+10]
#   RHS range        [6e-02, 1e+00]
# Warning: Model contains large matrix coefficients
# Warning: Model contains large bounds
# Warning: Quadratic constraints contain large coefficient range
# Warning: Quadratic constraints contain large coefficients on linear part
# Presolve removed 23 rows and 24 columns
#
# Continuous model is non-convex -- solving as a MIP
#
#
# MIP start from previous solve produced solution with objective 15.5226 (0.03s)
# MIP start from previous solve produced solution with objective 15.5086 (0.09s)
# MIP start from previous solve produced solution with objective 13.2361 (0.09s)
# MIP start from previous solve produced solution with objective 1.17037 (0.09s)
# Loaded MIP start from previous solve with objective 1.17037
#
# Presolve removed 45 rows and 46 columns
# Presolve time: 0.00s
# Presolved: 364 rows, 160 columns, 1082 nonzeros
# Presolved model has 41 quadratic objective terms
# Presolved model has 71 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 160 continuous, 0 integer (0 binary)
# Root relaxation presolved: 347 rows, 154 columns, 1054 nonzeros
# Root relaxation presolved model has 40 quadratic objective terms
#
#
# Root relaxation: objective 9.896966e-01, 391 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.98970    0   64    1.17037    0.98970  15.4%     -    0s
#      0     0    0.98970    0   64    1.17037    0.98970  15.4%     -    0s
#      0     0    0.98970    0   64    1.17037    0.98970  15.4%     -    0s
#      0     0    0.98970    0   64    1.17037    0.98970  15.4%     -    0s
#      0     0    0.98970    0   64    1.17037    0.98970  15.4%     -    0s
# H    0     0                       1.1699310    0.98970  15.4%     -    0s
#      0     0    0.98970    0   64    1.16993    0.98970  15.4%     -    0s
#      0     2    0.98970    0   64    1.16993    0.98970  15.4%     -    0s
# H    3     6                       1.0752404    0.98970  7.96%  32.0    0s
#
# Cutting planes:
#   RLT: 23
#
# Explored 7 nodes (654 simplex iterations) in 0.30 seconds (0.21 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 6: 1.07524 1.16993 1.17037 ... 15.5226
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 1.075240441625e+00, best bound 9.896966096528e-01, gap 7.9558%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: AMD Ryzen 9 7900X 12-Core Processor, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 12 physical cores, 24 logical processors, using up to 24 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 3 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0xca510437
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 9e+09]
# Warning: Model contains large matrix coefficients
# Warning: Model contains large rhs
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 1 rows and 1 columns
# Presolve time: 0.01s
# Presolved: 2 rows, 4 columns, 7 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0752404e+00   0.000000e+00   0.000000e+00      0s
#        0    1.0752404e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.075240442e+00
# [BaseBundle.eval_at] Infeasible/Error for K=(0.0, -100.0, 1000.0): status=warning, term=infeasibleOrUnbounded
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: AMD Ryzen 9 7900X 12-Core Processor, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 12 physical cores, 24 logical processors, using up to 24 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 108 rows, 135 columns and 308 nonzeros
# Model fingerprint: 0x7332267f
# Model has 42 quadratic objective terms
# Model has 22 quadratic constraints
# Coefficient statistics:
#   Matrix range     [6e-01, 1e+10]
#   QMatrix range    [1e+00, 4e+10]
#   QLMatrix range   [1e+00, 1e+10]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [7e-03, 2e+01]
#   Bounds range     [3e+00, 1e+10]
#   RHS range        [6e-02, 1e+00]
# Warning: Model contains large matrix coefficients
# Warning: Model contains large bounds
# Warning: Quadratic constraints contain large coefficient range
# Warning: Quadratic constraints contain large coefficients on linear part
# Presolve removed 23 rows and 24 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 45 rows and 46 columns
# Presolve time: 0.00s
# Presolved: 364 rows, 160 columns, 1084 nonzeros
# Presolved model has 41 quadratic objective terms
# Presolved model has 71 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 160 continuous, 0 integer (0 binary)
# Root relaxation presolved: 345 rows, 155 columns, 1049 nonzeros
# Root relaxation presolved model has 40 quadratic objective terms
#
#
# Root relaxation: objective -9.786288e+09, 883 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 -9.786e+09    0   46          - -9.786e+09      -     -    0s
#      0     0 -6.878e+09    0   64          - -6.878e+09      -     -    0s
#      0     0 -6.878e+09    0   64          - -6.878e+09      -     -    0s
#      0     0 -6.878e+09    0   64          - -6.878e+09      -     -    0s
#      0     0 -6.878e+09    0   64          - -6.878e+09      -     -    0s
#      0     0 -6.878e+09    0   64          - -6.878e+09      -     -    0s
#      0     0 -4.052e+09    0   47          - -4.052e+09      -     -    0s
#      0     2 -4.052e+09    0   47          - -4.052e+09      -     -    0s
# *   39    34               7     -12.3283705 -443.48358  3497%   119    0s
# *  149    78              12     -29.1146038 -172.75042   493%  55.6    0s
# *  150    78              12     -29.1641727 -172.75042   492%  55.5    0s
# H  212    80                     -29.1641727 -145.63040   399%  43.4    0s
# H  219    80                     -29.1641729 -143.35269   392%  42.8    0s
# *  295   128              15     -29.1891941 -124.10970   325%  35.3    0s
# *  297   128              16     -29.1895888 -124.10970   325%  35.1    0s
# *  298   128              16     -29.1896512 -124.10970   325%  35.0    0s
# *  857   334              63     -29.1897006 -119.40875   309%  18.7    0s
# H 2181   449                     -29.1897061  -90.02620   208%  13.0    0s
# H17125   923                    -5.04133e+09 -5.041e+09  0.00%   7.7    1s
#
# Explored 17125 nodes (133916 simplex iterations) in 1.35 seconds (1.36 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 8: -5.04133e+09 -29.1897 -29.1897 ... -12.3284
# No other solutions better than -5.04133e+09
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective -5.041325907760e+09, best bound -5.041325907760e+09, gap 0.0000%
# Set parameter TimeLimit to value 5
# [Gurobi] Solving MS (Quadratic) for scenario None...
# Set parameter OutputFlag to value 1
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: AMD Ryzen 9 7900X 12-Core Processor, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 12 physical cores, 24 logical processors, using up to 24 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 108 rows, 135 columns and 308 nonzeros
# Model fingerprint: 0x70109931
# Model has 42 quadratic objective terms
# Model has 22 quadratic constraints
# Coefficient statistics:
#   Matrix range     [6e-01, 1e+10]
#   QMatrix range    [1e+00, 4e+10]
#   QLMatrix range   [1e+00, 1e+10]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [7e-03, 2e+01]
#   Bounds range     [3e+00, 1e+10]
#   RHS range        [6e-02, 1e+00]
# Warning: Model contains large matrix coefficients
# Warning: Model contains large bounds
# Warning: Quadratic constraints contain large coefficient range
# Warning: Quadratic constraints contain large coefficients on linear part
# Presolve removed 23 rows and 24 columns
#
# Continuous model is non-convex -- solving as a MIP
#
#
# MIP start from previous solve produced solution with objective 15.4392 (0.04s)
# MIP start from previous solve produced solution with objective 14.3587 (0.09s)
# MIP start from previous solve produced solution with objective 13.198 (0.11s)
# Loaded MIP start from previous solve with objective 13.198
#
# Presolve removed 45 rows and 46 columns
# Presolve time: 0.00s
# Presolved: 364 rows, 160 columns, 1084 nonzeros
# Presolved model has 41 quadratic objective terms
# Presolved model has 71 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 160 continuous, 0 integer (0 binary)
# Root relaxation presolved: 345 rows, 155 columns, 1049 nonzeros
# Root relaxation presolved model has 40 quadratic objective terms
#
#
# Root relaxation: objective 9.896966e-01, 335 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.98970    0   65   13.19797    0.98970  92.5%     -    0s
#      0     0    0.98970    0   64   13.19797    0.98970  92.5%     -    0s
#      0     0    0.98970    0   64   13.19797    0.98970  92.5%     -    0s
#      0     0    0.98970    0   64   13.19797    0.98970  92.5%     -    0s
#      0     0    0.98970    0   64   13.19797    0.98970  92.5%     -    0s
#      0     0    0.98970    0   64   13.19797    0.98970  92.5%     -    0s
# H    0     0                       1.9299560    0.98970  48.7%     -    0s
# H    0     0                       1.8794851    0.98970  47.3%     -    0s
#      0     0    0.98970    0   64    1.87949    0.98970  47.3%     -    0s
#      0     2    0.98970    0   64    1.87949    0.98970  47.3%     -    0s
# H    4     6                       1.0177697    0.98970  2.76%   125    0s
#
# Cutting planes:
#   RLT: 19
#
# Explored 7 nodes (968 simplex iterations) in 0.33 seconds (0.21 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 6: 1.01777 1.87949 1.92996 ... 15.4392
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 1.017769722345e+00, best bound 9.896966096528e-01, gap 2.7583%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: AMD Ryzen 9 7900X 12-Core Processor, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 12 physical cores, 24 logical processors, using up to 24 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 3 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0x0a327675
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+09]
# Warning: Model contains large matrix coefficients
# Warning: Model contains large rhs
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 1 rows and 1 columns
# Presolve time: 0.01s
# Presolved: 2 rows, 4 columns, 7 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0177697e+00   0.000000e+00   0.000000e+00      0s
#        0    1.0177697e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.017769722e+00
# [Iter 0] #simplices = 6, #active = 6, bad-quality cut = 0
# == [Iter 0] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms)                Range(Aq)             Range(Aq+ms) #InfV
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# T0            1.032026e+00      1.113279e+09     -8.886721e+09      1.032026e+00     [2.28e+00, 1.00e+10]    [-8.89e+09, 1.11e+09]     [2.28e+00, 1.00e+10]    [-1.18e+09, 8.82e+09]     1
# T1            1.013704e+00      4.896021e+09     -5.103979e+09      1.013704e+00     [2.28e+00, 1.00e+10]    [-5.10e+09, 4.90e+09]     [2.28e+00, 1.00e+10]    [-2.91e+09, 7.09e+09]     1
# T2            1.005653e+00      4.894857e+09     -5.105143e+09      1.005653e+00     [2.79e+00, 1.00e+10]    [-5.11e+09, 4.89e+09]     [2.79e+00, 1.00e+10]    [-2.86e+09, 7.14e+09]     1
# T3            1.012672e+00      9.289255e+08     -9.071074e+09      1.012672e+00     [2.79e+00, 1.00e+10]    [-9.07e+09, 9.29e+08]     [2.79e+00, 1.00e+10]    [-7.44e+09, 2.56e+09]     1
# T4            1.075240e+00      9.090909e+08     -9.090909e+09      1.075240e+00     [2.79e+00, 1.00e+10]    [-9.09e+09, 9.09e+08]     [2.79e+00, 1.00e+10]    [-2.08e+01, 1.00e+10]     2
# T5            1.017770e+00      4.958674e+09     -5.041326e+09      1.017770e+00     [2.79e+00, 1.00e+10]    [-5.04e+09, 4.96e+09]     [2.79e+00, 1.00e+10]    [-2.88e+09, 7.12e+09]     2
#
# == [Iter 0] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
#   (none)
# [Iter 0] created=6 (cum=6), active=6, active+UB=2, ms_recomputed=6
# [DEBUG] about to call _debug_plot_lb_simplex_scatter, iter=0, simplex=2
# [DEBUG] _debug_plot_lb_simplex_scatter: enter, iter=0, simplex=2
# [DEBUG] (from scatter helper) LB simplex 2:
#     vert 0 (node 3): sum(As+ms) = -5.105142e+09, sum(c_s) = 1.005653e+00
#     vert 1 (node 5): sum(As+ms) = 4.894857e+09, sum(c_s) = 1.005653e+00
#     vert 2 (node 7): sum(As+ms) = -5.105142e+09, sum(c_s) = 1.005653e+00
#     vert 3 (node 4): sum(As+ms) = -5.105143e+09, sum(c_s) = 1.005653e+00
# ...
# Set parameter TimeLimit to value 5
# [Gurobi] Solving MS (Quadratic) for scenario None...
# Set parameter OutputFlag to value 1
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: AMD Ryzen 9 7900X 12-Core Processor, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 12 physical cores, 24 logical processors, using up to 24 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 108 rows, 135 columns and 308 nonzeros
# Model fingerprint: 0xc9153bb9
# Model has 42 quadratic objective terms
# Model has 22 quadratic constraints
# Coefficient statistics:
#   Matrix range     [6e-01, 1e+10]
#   QMatrix range    [1e+00, 4e+10]
#   QLMatrix range   [1e+00, 1e+10]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [7e-03, 2e+01]
#   Bounds range     [1e+00, 1e+10]
#   RHS range        [6e-02, 1e+00]
# Warning: Model contains large matrix coefficients
# Warning: Model contains large bounds
# Warning: Quadratic constraints contain large coefficient range
# Warning: Quadratic constraints contain large coefficients on linear part
# Presolve removed 23 rows and 24 columns
#
# Continuous model is non-convex -- solving as a MIP
#
#
# MIP start from previous solve produced solution with objective 8.52146 (0.06s)
# Loaded MIP start from previous solve with objective 8.52146
#
# Presolve removed 45 rows and 46 columns
# Presolve time: 0.00s
# Presolved: 364 rows, 160 columns, 1087 nonzeros
# Presolved model has 41 quadratic objective terms
# Presolved model has 71 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 160 continuous, 0 integer (0 binary)
# Root relaxation presolved: 343 rows, 156 columns, 1045 nonzeros
# Root relaxation presolved model has 40 quadratic objective terms
#
#
# Root relaxation: objective 9.896966e-01, 365 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.98970    0   64    8.52146    0.98970  88.4%     -    0s
#      0     0    0.98970    0   64    8.52146    0.98970  88.4%     -    0s
#      0     0    0.98970    0   64    8.52146    0.98970  88.4%     -    0s
#      0     0    0.98970    0   64    8.52146    0.98970  88.4%     -    0s
#      0     0    0.98970    0   64    8.52146    0.98970  88.4%     -    0s
# H    0     0                       1.0677361    0.98970  7.31%     -    0s
#
# Cutting planes:
#   RLT: 21
#
# Explored 1 nodes (421 simplex iterations) in 0.36 seconds (0.28 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 2: 1.06774 8.52146
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 1.067736137211e+00, best bound 9.896966096528e-01, gap 7.3089%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: AMD Ryzen 9 7900X 12-Core Processor, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 12 physical cores, 24 logical processors, using up to 24 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 3 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0x82a5e5f6
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 9e+09]
# Warning: Model contains large matrix coefficients
# Warning: Model contains large rhs
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 2 rows, 5 columns, 9 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0677361e+00   0.000000e+00   0.000000e+00      0s
#        0    1.0677361e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.067736137e+00
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: AMD Ryzen 9 7900X 12-Core Processor, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 12 physical cores, 24 logical processors, using up to 24 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 108 rows, 135 columns and 308 nonzeros
# Model fingerprint: 0x0e15f821
# Model has 42 quadratic objective terms
# Model has 22 quadratic constraints
# Coefficient statistics:
#   Matrix range     [6e-01, 1e+10]
#   QMatrix range    [1e+00, 4e+10]
#   QLMatrix range   [1e+00, 1e+10]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [7e-03, 2e+01]
#   Bounds range     [1e+00, 1e+10]
#   RHS range        [6e-02, 1e+00]
# Warning: Model contains large matrix coefficients
# Warning: Model contains large bounds
# Warning: Quadratic constraints contain large coefficient range
# Warning: Quadratic constraints contain large coefficients on linear part
# Presolve removed 23 rows and 24 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 45 rows and 46 columns
# Presolve time: 0.00s
# Presolved: 364 rows, 160 columns, 1085 nonzeros
# Presolved model has 41 quadratic objective terms
# Presolved model has 71 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 160 continuous, 0 integer (0 binary)
# Root relaxation presolved: 345 rows, 155 columns, 1050 nonzeros
# Root relaxation presolved model has 40 quadratic objective terms
#
#
# Root relaxation: objective -9.880947e+09, 533 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 -9.881e+09    0   44          - -9.881e+09      -     -    0s
#      0     0 -5.000e+09    0   43          - -5.000e+09      -     -    0s
#      0     0 -5.000e+09    0   67          - -5.000e+09      -     -    0s
#      0     0 -3.855e+09    0   67          - -3.855e+09      -     -    0s
#      0     0 -3.855e+09    0   67          - -3.855e+09      -     -    0s
#      0     0 infeasible    0               - infeasible      -     -    0s
#
# Cutting planes:
#   RLT: 7
#   PSD: 3
#
# Explored 1 nodes (1157 simplex iterations) in 0.06 seconds (0.02 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 0
#
# Model is infeasible or unbounded
# Best objective -, best bound -, gap -
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasibleOrUnbounded
#     - message from solver: <undefined>
# [Subproblem solving issue] MS Problem is infeasibleOrUnbounded! Scenario: None. Exiting.
# [Subproblem solving issue] MS Problem not optimal. Status: warning, Term: infeasibleOrUnbounded. Ignoring simplex.
# Set parameter TimeLimit to value 5
# [Gurobi] Solving MS (Quadratic) for scenario None...
# Set parameter OutputFlag to value 1
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: AMD Ryzen 9 7900X 12-Core Processor, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 12 physical cores, 24 logical processors, using up to 24 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 108 rows, 135 columns and 308 nonzeros
# Model fingerprint: 0x86763e1d
# Model has 42 quadratic objective terms
# Model has 22 quadratic constraints
# Coefficient statistics:
#   Matrix range     [6e-01, 1e+10]
#   QMatrix range    [1e+00, 4e+10]
#   QLMatrix range   [1e+00, 1e+10]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [7e-03, 2e+01]
#   Bounds range     [1e+00, 1e+10]
#   RHS range        [6e-02, 1e+00]
# Warning: Model contains large matrix coefficients
# Warning: Model contains large bounds
# Warning: Quadratic constraints contain large coefficient range
# Warning: Quadratic constraints contain large coefficients on linear part
# Presolve removed 23 rows and 24 columns
#
# Continuous model is non-convex -- solving as a MIP
#
#
# MIP start from previous solve produced solution with objective 10.6298 (0.04s)
# MIP start from previous solve produced solution with objective 1.05694 (0.14s)
# MIP start from previous solve produced solution with objective 1.00037 (0.20s)
# Loaded MIP start from previous solve with objective 1.00037
#
# Presolve removed 45 rows and 46 columns
# Presolve time: 0.00s
# Presolved: 364 rows, 160 columns, 1085 nonzeros
# Presolved model has 41 quadratic objective terms
# Presolved model has 71 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 160 continuous, 0 integer (0 binary)
#
# Explored 0 nodes (0 simplex iterations) in 0.21 seconds (0.18 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 3: 1.00037 1.05694 10.6298
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 1.000366355182e+00, best bound 9.375000000000e-01, gap 6.2843%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: AMD Ryzen 9 7900X 12-Core Processor, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 12 physical cores, 24 logical processors, using up to 24 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 3 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0x96153f64
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 9e+09]
# Warning: Model contains large matrix coefficients
# Warning: Model contains large rhs
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 2 rows, 5 columns, 9 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0003664e+00   0.000000e+00   0.000000e+00      0s
#        0    1.0003664e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.000366355e+00
# [Iter 3] #simplices = 13, #active = 0, bad-quality cut = 0
# == [Iter 3] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
#   (none)
# == [Iter 3] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms)                Range(Aq)             Range(Aq+ms) #InfV
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# T0            1.032026e+00      1.113279e+09     -8.886721e+09      1.032026e+00     [2.28e+00, 1.00e+10]    [-8.89e+09, 1.11e+09]     [2.28e+00, 1.00e+10]    [-1.18e+09, 8.82e+09]     1
# T1            1.013704e+00      4.896021e+09     -5.103979e+09      1.013704e+00     [2.28e+00, 1.00e+10]    [-5.10e+09, 4.90e+09]     [2.28e+00, 1.00e+10]    [-2.91e+09, 7.09e+09]     1
# T2            1.075240e+00      9.090909e+08     -9.090909e+09      1.075240e+00     [2.79e+00, 1.00e+10]    [-9.09e+09, 9.09e+08]     [2.79e+00, 1.00e+10]    [-2.08e+01, 1.00e+10]     2
# T3            1.017770e+00      4.958674e+09     -5.041326e+09      1.017770e+00     [2.79e+00, 1.00e+10]    [-5.04e+09, 4.96e+09]     [2.79e+00, 1.00e+10]    [-2.88e+09, 7.12e+09]     2
# T4            1.075240e+00     -1.005227e+04     -1.011101e+04      1.075240e+00     [2.79e+00, 5.87e+01]   [-1.01e+04, -1.01e+04]     [2.79e+00, 1.00e+10]    [-1.01e+04, 1.00e+10]     0
# T5            1.016953e+00      3.947268e+09     -6.052732e+09      1.016953e+00     [2.79e+00, 1.00e+10]    [-6.05e+09, 3.95e+09]     [2.79e+00, 1.00e+10]    [-5.70e+09, 4.30e+09]     1
# T6            1.024002e+00     -5.506788e+09     -5.506788e+09      1.024002e+00     [2.79e+00, 2.33e+02]   [-5.51e+09, -5.51e+09]     [2.79e+00, 1.00e+10]    [-5.51e+09, 4.49e+09]     0
# T7            2.124215e+00      5.986980e+09     -4.013020e+09      2.124215e+00     [2.79e+00, 1.00e+10]    [-4.01e+09, 5.99e+09]     [2.79e+00, 1.00e+10]    [-4.01e+09, 5.99e+09]     1
# T8            1.117025e+01      4.474619e+09     -5.525381e+09      1.117025e+01     [1.12e+01, 1.00e+10]    [-5.53e+09, 4.47e+09]     [1.12e+01, 1.00e+10]    [-5.53e+09, 4.47e+09]     1
# T9            1.001740e+00      1.348612e+09     -8.651388e+09      1.001740e+00     [9.99e-01, 1.00e+10]    [-8.65e+09, 1.35e+09]     [9.99e-01, 1.00e+10]    [-7.54e+09, 2.46e+09]     1
# T10           1.015714e+00     -9.870389e+09     -9.870389e+09      1.015714e+00     [9.99e-01, 1.26e+01]   [-9.87e+09, -9.87e+09]     [9.99e-01, 1.00e+10]    [-9.87e+09, 1.30e+08]     0
# T11           1.067736e+00      9.090909e+08     -9.090909e+09      1.067736e+00     [9.99e-01, 1.00e+10]    [-9.09e+09, 9.09e+08]     [9.99e-01, 1.00e+10]    [-3.18e+03, 1.00e+10]     1
# T12           1.000366e+00      9.337989e+08     -9.066201e+09      1.000366e+00     [9.99e-01, 1.00e+10]    [-9.07e+09, 9.34e+08]     [9.99e-01, 1.00e+10]    [-9.07e+09, 9.34e+08]     1
#
# [Iter 3] created=13 (cum=36), active=0, active+UB=0, ms_recomputed=4
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 89
#      86 agg_bundle = None
#      88 t_run0 = perf_counter()
# ---> 89 hist = run_pid_simplex_3d(
#      90     base_bundles=base_bundles,
#      91     ms_bundles=ms_bundles,
#      92     model_list=model_list,
#      93     first_vars_list=first_stg_vars_list,
#      94     target_nodes=target_nodes,
#      95     min_dist=0,
#      96     active_tol=ACTIVE_TOL,
#      97     verbose=True,
#      98     agg_bundle=agg_bundle,
#      99     gap_stop_tol=1e-3,
#     100     plot_every=2,
#     101     use_exact_opt=False,
#     102     exact_solver_name="gurobi",
#     103     exact_solver_opts={"NonConvex": 2, "TimeLimit": 60},
#     104 )
#     105 t_run1 = perf_counter()
#     106 print(f"[Time] Main loop total: {t_run1 - t_run0:.3f}s")
#
# File c:\Users\Administrator\Desktop\workspace2026\102\pid_simplex_mixmscs\simplex_specialstart.py:1038, in run_pid_simplex_3d(base_bundles, ms_bundles, model_list, first_vars_list, target_nodes, min_dist, active_tol, verbose, agg_bundle, gap_stop_tol, tracker, plot_every, use_exact_opt, exact_solver_name, exact_solver_opts)
#    1034 # ======= Consistency check: selected simplex LB(=LB_global) should not exceed UB_global =======
#    1035 # Theoretically surrogate is underestimator, so LB_global <= UB_global should always hold
#    1036 # Add small tolerance to prevent pure numerical error
#    1037 if LB_global > UB_global + 1e-8:
# -> 1038     raise RuntimeError(
#    1039         f"[run_pid_simplex_3d] LB of selected simplex exceeds UB at iter={it}, "
#    1040         f"simplex={lb_simp_rec['simplex_index']}: "
#    1041         f"LB={LB_global:.6e}, UB={UB_global:.6e}"
#    1042     )
#    1043 # =======================================================================
#    1044
#    1045
#    1046
#    1047 # === Debug: Drawblue-red scatter cloud from LB-simplex ===
#    1048 # ==================================================
#    1049 if DEBUG_LB_SIMPLEX_SCATTER and lb_simp_rec is not None:
#
# RuntimeError: [run_pid_simplex_3d] LB of selected simplex exceeds UB at iter=3, simplex=12: LB=1.000366e+00, UB=9.990223e-01
