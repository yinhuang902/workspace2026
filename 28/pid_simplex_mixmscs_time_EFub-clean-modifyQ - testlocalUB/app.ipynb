# %%
from time import perf_counter  

from modeling import build_models_from_csv
from bundles import BaseBundle, MSBundle
from utils import (
    tighten_bounds_one_model,
    MIN_DIST, ACTIVE_TOL, GAP_STOP_TOL,
)
from simplex_specialstart import run_pid_simplex_3d

# setup scenario number and target_nodesk
csv_path       = "data.csv"
max_scenarios  = 20
target_nodes   = 1000

bounds={
    "Kp": (-10.0, 10.0),
    "Ki": (-100.0, 100.0),
    "Kd": (-100.0, 100.0),
    "x": (-2.5, 2.5),
    "u": (-5.0, 5.0),
    "e": (None, None),
    "I": (None, None),
}

weights = (10.0, 0.01)


# ====== stage 1：load data and generate models ======
T   = 15.0          
nfe = 20            

t_load0 = perf_counter()
model_list, first_stg_vars_list, m_tmpl_list, nfe = build_models_from_csv(
    csv_path=csv_path,
    T=T,
    nfe=nfe,
    weights=weights,
    bounds=bounds,
    sp0=0.0,
    sp1=0.5,
    tau_xs_col="tau_xs",
    tau_us_col="tau_us",
    tau_ds_col="tau_ds",          
    disturb_prefix="disturbance_",
    setpoint_change_col="setpoint_change",
    max_scenarios=max_scenarios,
    skip=0,
)
t_load1 = perf_counter()
print(f"[Time] Data load & scenario build: {t_load1 - t_load0:.3f}s")


# ====== stage 1.5：FBBT / OBBT ======
# same as snog: FBBT open,OBBT open
obbt_solver_opts = {
    "NonConvex": 2,
    "MIPGap": 1,     
    "TimeLimit": 15   
}
for m, yvars in zip(model_list, first_stg_vars_list):
    tighten_bounds_one_model(m, yvars,
                             use_fbbt=False,
                             use_obbt=False,
                             obbt_solver_name="gurobi",
                             obbt_solver_opts=obbt_solver_opts,
                             max_rounds=3, tol=1e-6, verbose=True)

# ====== stage 2: Persistent Solver Packaging ======
ub_options = {
    'NonConvex': 2,      
}
lb_options = {
    'NonConvex': 2,
    'MIPGap': 1e-3,            
    'TimeLimit': 120 
}

t_wrap0 = perf_counter()
base_bundles = [BaseBundle(m, ub_options) for m in model_list]  
ms_bundles   = [MSBundle(m, yvars, lb_options) for m, yvars in zip(model_list, first_stg_vars_list)]  
t_wrap1 = perf_counter()
print(f"[Time] Persistent wrapper (GurobiPersistent) setup: {t_wrap1 - t_wrap0:.3f}s")

# ====== stage 3：main loop ======
agg_bundle = None  

t_run0 = perf_counter()
hist = run_pid_simplex_3d(
    base_bundles=base_bundles,
    ms_bundles=ms_bundles,
    model_list=model_list,
    first_vars_list=first_stg_vars_list,
    target_nodes=target_nodes,
    min_dist=0,
    active_tol=ACTIVE_TOL,
    verbose=True,
    agg_bundle=agg_bundle,
    gap_stop_tol=1e-6,
    use_exact_opt=False,
    exact_solver_name="gurobi",
    exact_solver_opts={"NonConvex": 2, "TimeLimit": 60},
    time_limit=60*60*2,
    enable_3d_plot=False,   
    plot_every=None,        
)
t_run1 = perf_counter()
print(f"[Time] Main loop total: {t_run1 - t_run0:.3f}s")

# ====== print output ======
print("\n==== Done ====")
print(f"Total nodes: {len(hist['nodes'])}")
print(f"Best UB: {min(hist['UB_hist']) if hist['UB_hist'] else None}")
print(f"Last LB: {hist['LB_hist'][-1] if hist['LB_hist'] else None}")
# Out:
# [Time] Data load & scenario build: 0.206s
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2689754
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter MIPGap to value 0.001
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Set parameter MIPGap to value 0.001
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Set parameter MIPGap to value 0.001
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Set parameter MIPGap to value 0.001
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Set parameter MIPGap to value 0.001
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Set parameter MIPGap to value 0.001
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Set parameter MIPGap to value 0.001
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Set parameter MIPGap to value 0.001
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Set parameter MIPGap to value 0.001
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Set parameter MIPGap to value 0.001
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Set parameter MIPGap to value 0.001
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Set parameter MIPGap to value 0.001
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Set parameter MIPGap to value 0.001
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Set parameter MIPGap to value 0.001
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Set parameter MIPGap to value 0.001
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Set parameter MIPGap to value 0.001
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Set parameter MIPGap to value 0.001
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Set parameter MIPGap to value 0.001
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Set parameter MIPGap to value 0.001
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Set parameter MIPGap to value 0.001
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# [Time] Persistent wrapper (GurobiPersistent) setup: 2.164s
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=warning, term=other
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=warning, term=other
# [TIMING] Pre-loop vertex Q evals: 3.33s  (8 nodes x 20 scenarios = 160 solves)
# [EF-UB] Initialized ipopt EF with 20 scenarios, time_ub=60.0s
#
# ======================================================================
# [TIMING] === Pre-loop phase summary ===
#   corners_and_mesh               :       0.00s
#   vertex_Q_evals                 :       3.33s
#   exact_optima                   :       0.00s
#   ef_init                        :       0.12s
#   TOTAL                          :       3.45s
# ======================================================================
#
# Set parameter MIPGap to value 0.1
# Set parameter MIPGap to value 0.1
# Set parameter MIPGap to value 0.1
# Set parameter MIPGap to value 0.1
# Set parameter MIPGap to value 0.1
# Set parameter MIPGap to value 0.1
# Set parameter MIPGap to value 0.1
# Set parameter MIPGap to value 0.1
# Set parameter MIPGap to value 0.1
# Set parameter MIPGap to value 0.1
# Set parameter MIPGap to value 0.1
# Set parameter MIPGap to value 0.1
# Set parameter MIPGap to value 0.1
# Set parameter MIPGap to value 0.1
# Set parameter MIPGap to value 0.1
# Set parameter MIPGap to value 0.1
# Set parameter MIPGap to value 0.1
# Set parameter MIPGap to value 0.1
# Set parameter MIPGap to value 0.1
# Set parameter MIPGap to value 0.1
# [Iter 0] MIPGap overridden to 0.1 (original: 0.001)
# Discarded solution information
# [Invariant] MS scen None: dual=-5.500707e+09 > primal=-5.500707e+09
# Discarded solution information
# Discarded solution information
# [Invariant] MS scen None: dual=-5.481254e+09 > primal=-5.481254e+09
# Discarded solution information
# Discarded solution information
# [Invariant] MS scen None: dual=-5.194287e+09 > primal=-5.194287e+09
# Discarded solution information
# Discarded solution information
# Discarded solution information
# Discarded solution information
# Discarded solution information
# Discarded solution information
# Discarded solution information
# Discarded solution information
# Discarded solution information
# Discarded solution information
# Discarded solution information
# Discarded solution information
# Discarded solution information
# [Invariant] MS scen None: dual=-5.193884e+09 > primal=-5.193884e+09
# Discarded solution information
# Discarded solution information
# [Invariant] MS scen None: dual=-6.026920e+09 > primal=-6.026920e+09
# [Invariant] MS scen None: dual=-6.044831e+09 > primal=-6.044831e+09
# [Invariant] MS scen None: dual=-6.009929e+09 > primal=-6.009929e+09
# [Invariant] MS scen None: dual=-5.983412e+09 > primal=-5.983412e+09
# [Invariant] MS scen None: dual=-6.017156e+09 > primal=-6.017156e+09
# [Invariant] MS scen None: dual=-6.039632e+09 > primal=-6.039632e+09
# [Invariant] MS scen None: dual=-5.628277e+09 > primal=-5.628277e+09
# [Invariant] MS scen None: dual=-5.631814e+09 > primal=-5.631814e+09
# [Invariant] MS scen None: dual=-5.660837e+09 > primal=-5.660837e+09
# [Invariant] MS scen None: dual=-5.616388e+09 > primal=-5.616388e+09
# [Invariant] MS scen None: dual=-5.612241e+09 > primal=-5.612241e+09
# [Invariant] MS scen None: dual=-5.625887e+09 > primal=-5.625887e+09
# [Invariant] MS scen None: dual=-5.931173e+09 > primal=-5.931173e+09
# [Invariant] MS scen None: dual=-5.944271e+09 > primal=-5.944271e+09
# [Invariant] MS scen None: dual=-5.905520e+09 > primal=-5.905520e+09
# [Invariant] MS scen None: dual=-5.872932e+09 > primal=-5.872932e+09
# [Invariant] MS scen None: dual=-5.929519e+09 > primal=-5.929519e+09
# [Invariant] MS scen None: dual=-5.849699e+09 > primal=-5.849699e+09
# [Invariant] MS scen None: dual=-5.942323e+09 > primal=-5.942323e+09
# [Invariant] MS scen None: dual=-5.822231e+09 > primal=-5.822231e+09
# [Invariant] MS scen None: dual=-5.851105e+09 > primal=-5.851105e+09
# [Invariant] MS scen None: dual=-5.935716e+09 > primal=-5.935716e+09
# [Invariant] MS scen None: dual=-5.742972e+09 > primal=-5.742972e+09
# [Invariant] MS scen None: dual=-5.777262e+09 > primal=-5.777262e+09
# [Invariant] MS scen None: dual=-5.769900e+09 > primal=-5.769900e+09
# [Invariant] MS scen None: dual=-5.774641e+09 > primal=-5.774641e+09
# [Invariant] MS scen None: dual=-5.789952e+09 > primal=-5.789952e+09
# [Bundle] MS scen None: infeasibleOrUnbounded. ms_val=nan.
# [Bundle] MS scen None: not optimal. Status=warning, Term=infeasibleOrUnbounded.
# [Invariant] MS scen None: dual=-5.842821e+09 > primal=-5.842821e+09
# [Invariant] MS scen None: dual=-5.868426e+09 > primal=-5.868426e+09
# [Invariant] MS scen None: dual=-5.881849e+09 > primal=-5.881849e+09
# [Invariant] MS scen None: dual=-5.000000e+09 > primal=-5.000000e+09
# [Invariant] MS scen None: dual=-5.857186e+09 > primal=-5.857186e+09
# [Invariant] MS scen None: dual=-5.861173e+09 > primal=-5.861173e+09
# [Iter 0] MIPGap restored to 0.001
# [Iter 0] #simplices = 6, #active = 6, bad-quality cut = 0, bad-shape cut = 0
# == [Iter 0] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.076765e+00      4.670976e+09     -1.065805e+11      2.153530e+01     [4.46e+01, 2.00e+11]    [-1.07e+11, 9.34e+10]     1
# T1            9.786611e-01      3.982876e+09     -1.203425e+11      1.957322e+01     [4.46e+01, 2.00e+11]    [-1.20e+11, 7.97e+10]     1
# T2            9.844449e-01      4.364059e+09     -1.127188e+11      1.968890e+01     [4.43e+01, 2.00e+11]    [-1.13e+11, 8.73e+10]     1
# T3            9.811815e-01      4.091555e+09     -1.181689e+11      1.962363e+01     [4.43e+01, 2.00e+11]    [-1.18e+11, 8.18e+10]     1
# T4            1.015796e+00      4.252759e+09     -1.149448e+11      2.031592e+01     [5.42e+01, 2.00e+11]    [-1.15e+11, 8.51e+10]     2
# T5            1.008047e+00               inf               inf      2.016093e+01     [5.42e+01, 2.00e+11]               [inf, inf]     2
#
# == [Iter 0] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
#   (none)
# [Iter 0] created=6 (cum=6), active=6, active+UB=2, ms_recomputed=6
# [Iter 0] UB-simplex selection: UB_node in simplices [2, 3], chose T3 (LB=0.981181453)
# [Iter 0] EF-ipopt: ok=True, ef_obj=0.9814847628660429, true_obj=9.814848e-01, time=0.553s
# [Iter 0] EF-UB improved by ipopt: 9.814848e-01 (per-scen), K=(9.99970964924666, 99.99950031183559, 1.495159234725032)
# [Iter 0] Pre-split gap: 5.647414e-02 (0.288%)
# [Iter 0] Active simplex ratio = 1.000000
# [Iter 0] UB point (9.99970964924666, 99.99950031183559, 1.495159234725032) is geometrically in simplices [3]
#   T3 verts=[3, 6, 7, 4]: λ=[0.000015, 0.492522, 0.507461, 0.000002], LB=19.623629059, c_s=[0.9973765252119483, 0.945925302390501, 0.9562434219662743, 1.0700789655348955, 0.969111394288256, 0.9429058099610992, 1.0130539300419803, 0.9468372560418407, 1.0163403472292267, 0.9573057849019528, 0.9652324418112033, 1.0376538578449814, 0.9524420351110123, 0.9790994988856474, 0.9960731589292047, 1.0781156565461407, 0.9555505146203404, 0.9551766221318504, 0.9407108253990726, 0.9483957106473886]
#
# == [Iter 0] CS DUAL vs PRIMAL diagnostic (simplices containing UB point) ==
#   --- T3 ---
#     scen 0: status=time_limit, dual=0.997376525, primal=0.997376525  ✓ dual ≤ primal (gap=1.110223e-16)
#              cs_primal_K=(9.999231675757967, 99.99864227385171, 1.3957947968559532)
#              indep_Q(cs_K)=0.997376525  → dual ≤ indep_Q (consistent, diff=2.363576e-11)
#     scen 1: status=time_limit, dual=0.945925302, primal=0.945925302  ✓ dual ≤ primal (gap=2.220446e-16)
#              cs_primal_K=(9.748601892459291, 99.3371937563071, -0.00014153839499255234)
#              indep_Q(cs_K)=0.945925321  → dual ≤ indep_Q (consistent, diff=1.844701e-08)
#     scen 2: status=time_limit, dual=0.956243422, primal=0.956243422  ✓ dual ≤ primal (gap=0.000000e+00)
#              cs_primal_K=(9.999994936241917, 91.70368911358257, 2.3482370383557245)
#              indep_Q(cs_K)=0.956243425  → dual ≤ indep_Q (consistent, diff=3.320104e-09)
#     scen 3: status=time_limit, dual=1.070078966, primal=1.070078966  ✓ dual ≤ primal (gap=4.440892e-16)
#              cs_primal_K=(9.999767793104557, 99.99959011225656, 1.0237424050442065)
#              indep_Q(cs_K)=1.070078975  → dual ≤ indep_Q (consistent, diff=9.700088e-09)
#     scen 4: status=time_limit, dual=0.969111394, primal=0.969111394  ✓ dual ≤ primal (gap=-1.110223e-16)
#              cs_primal_K=(9.998630746717616, 99.99755347461445, 0.667112188497135)
#              indep_Q(cs_K)=0.969111394  → dual ≤ indep_Q (consistent, diff=2.112739e-10)
#     scen 5: status=optimal, dual=0.942905810, primal=0.942905810  ✓ dual ≤ primal (gap=-1.110223e-16)
#              cs_primal_K=(9.98862742410999, 99.97745475643757, 0.5273124057362578)
#              indep_Q(cs_K)=0.942905887  → dual ≤ indep_Q (consistent, diff=7.746286e-08)
#     scen 6: status=time_limit, dual=1.013053930, primal=1.013053930  ✓ dual ≤ primal (gap=2.220446e-16)
#              cs_primal_K=(9.999220491647536, 99.99893376588902, 2.6318398488971173)
#              indep_Q(cs_K)=1.013053940  → dual ≤ indep_Q (consistent, diff=9.692861e-09)
#     scen 7: status=optimal, dual=0.946837256, primal=0.946837256  ✓ dual ≤ primal (gap=-1.110223e-16)
#              cs_primal_K=(9.982035697163088, 99.97196033037748, 0.9166215881748107)
#              indep_Q(cs_K)=0.946837270  → dual ≤ indep_Q (consistent, diff=1.371134e-08)
#     scen 8: status=time_limit, dual=1.016340347, primal=1.016340347  ✓ dual ≤ primal (gap=-2.220446e-16)
#              cs_primal_K=(9.99964360841667, 99.99932811934511, 2.062198227421095)
#              indep_Q(cs_K)=1.016340395  → dual ≤ indep_Q (consistent, diff=4.815818e-08)
#     scen 9: status=time_limit, dual=0.957305785, primal=0.957305785  ✓ dual ≤ primal (gap=-1.110223e-16)
#              cs_primal_K=(9.9974342985267, 99.99567975787635, 1.4998092832885586)
#              indep_Q(cs_K)=0.957305786  → dual ≤ indep_Q (consistent, diff=1.134159e-09)
#     scen 10: status=time_limit, dual=0.965232442, primal=0.965232442  ✓ dual ≤ primal (gap=1.110223e-16)
#              cs_primal_K=(9.998649358080746, 99.99745922419221, 0.637582006935839)
#              indep_Q(cs_K)=0.965232495  → dual ≤ indep_Q (consistent, diff=5.276669e-08)
#     scen 11: status=time_limit, dual=1.037653858, primal=1.037653858  ✓ dual ≤ primal (gap=4.440892e-16)
#              cs_primal_K=(9.9993548161267, 99.99912429060556, 2.454107893424599)
#              indep_Q(cs_K)=1.037653860  → dual ≤ indep_Q (consistent, diff=2.491055e-09)
#     scen 12: status=time_limit, dual=0.952442035, primal=0.952442035  ✓ dual ≤ primal (gap=-2.220446e-16)
#              cs_primal_K=(9.754667863331647, 99.0737801489194, -2.4344811975813408e-06)
#              indep_Q(cs_K)=0.952442038  → dual ≤ indep_Q (consistent, diff=2.474661e-09)
#     scen 13: status=time_limit, dual=0.979099499, primal=0.979099499  ✓ dual ≤ primal (gap=-1.110223e-16)
#              cs_primal_K=(10.0, 83.37571208580093, -0.00012450092634539714)
#              indep_Q(cs_K)=0.979100111  → dual ≤ indep_Q (consistent, diff=6.117996e-07)
#     scen 14: status=time_limit, dual=0.996073159, primal=0.996073159  ✓ dual ≤ primal (gap=2.220446e-16)
#              cs_primal_K=(9.99910667855692, 99.99854081814986, 2.631633570744075)
#              indep_Q(cs_K)=0.996073166  → dual ≤ indep_Q (consistent, diff=7.087733e-09)
#     scen 15: status=time_limit, dual=1.078115657, primal=1.078115657  ✓ dual ≤ primal (gap=2.220446e-16)
#              cs_primal_K=(9.999719602903856, 99.99955852195487, 4.0524007439509075)
#              indep_Q(cs_K)=1.078115658  → dual ≤ indep_Q (consistent, diff=1.269142e-09)
#     scen 16: status=time_limit, dual=0.955550515, primal=0.955550515  ✓ dual ≤ primal (gap=1.110223e-16)
#              cs_primal_K=(9.715596444274674, 98.09631955158974, -4.654941062038008e-05)
#              indep_Q(cs_K)=0.955550592  → dual ≤ indep_Q (consistent, diff=7.721202e-08)
#     scen 17: status=time_limit, dual=0.955176622, primal=0.955176622  ✓ dual ≤ primal (gap=2.220446e-16)
#              cs_primal_K=(10.0, 99.72227695980875, -0.0003143886644498015)
#              indep_Q(cs_K)=0.955176663  → dual ≤ indep_Q (consistent, diff=4.124900e-08)
#     scen 18: status=optimal, dual=0.940710825, primal=0.940710825  ✓ dual ≤ primal (gap=2.220446e-16)
#              cs_primal_K=(3.6118903878585518, 100.0, -0.0001317591586711569)
#              indep_Q(cs_K)=0.940710833  → dual ≤ indep_Q (consistent, diff=7.309270e-09)
#     scen 19: status=time_limit, dual=0.948395711, primal=0.948395711  ✓ dual ≤ primal (gap=2.220446e-16)
#              cs_primal_K=(9.996413855644393, 99.99436036262556, 0.4724517465434281)
#              indep_Q(cs_K)=0.948395721  → dual ≤ indep_Q (consistent, diff=9.881529e-09)
#   sum(c_s_dual)=19.623629059, UB_total=392.593914239, UB_per_scen=19.629695712
#
#   == Per-scenario Q_s at K_EF = (9.99970964924666, 99.99950031183559, 1.495159234725032) ==
#     scen 0: Q_s(K_EF)=0.997384389, c_s_dual=0.997376525  ✓ Q_s(K_EF) > c_s_dual (diff=7.863586e-06)
#     scen 1: Q_s(K_EF)=0.945484186, c_s_dual=0.945925302  ⚠ Q_s(K_EF) < c_s_dual → GUROBI CS DUAL IS WRONG
#     scen 2: Q_s(K_EF)=0.956222866, c_s_dual=0.956243422  ⚠ Q_s(K_EF) < c_s_dual → GUROBI CS DUAL IS WRONG
#     scen 3: Q_s(K_EF)=1.070280428, c_s_dual=1.070078966  ✓ Q_s(K_EF) > c_s_dual (diff=2.014627e-04)
#     scen 4: Q_s(K_EF)=0.969662045, c_s_dual=0.969111394  ✓ Q_s(K_EF) > c_s_dual (diff=5.506506e-04)
#     scen 5: Q_s(K_EF)=0.943646277, c_s_dual=0.942905810  ✓ Q_s(K_EF) > c_s_dual (diff=7.404675e-04)
#     scen 6: Q_s(K_EF)=1.014182332, c_s_dual=1.013053930  ✓ Q_s(K_EF) > c_s_dual (diff=1.128402e-03)
#     scen 7: Q_s(K_EF)=0.947107999, c_s_dual=0.946837256  ✓ Q_s(K_EF) > c_s_dual (diff=2.707431e-04)
#     scen 8: Q_s(K_EF)=1.016614612, c_s_dual=1.016340347  ✓ Q_s(K_EF) > c_s_dual (diff=2.742648e-04)
#     scen 9: Q_s(K_EF)=0.957305509, c_s_dual=0.957305785  ⚠ Q_s(K_EF) < c_s_dual → GUROBI CS DUAL IS WRONG
#     scen 10: Q_s(K_EF)=0.965837447, c_s_dual=0.965232442  ✓ Q_s(K_EF) > c_s_dual (diff=6.050052e-04)
#     scen 11: Q_s(K_EF)=1.038479478, c_s_dual=1.037653858  ✓ Q_s(K_EF) > c_s_dual (diff=8.256198e-04)
#     scen 12: Q_s(K_EF)=0.952272485, c_s_dual=0.952442035  ⚠ Q_s(K_EF) < c_s_dual → GUROBI CS DUAL IS WRONG
#     scen 13: Q_s(K_EF)=0.974554959, c_s_dual=0.979099499  ⚠ Q_s(K_EF) < c_s_dual → GUROBI CS DUAL IS WRONG
#     scen 14: Q_s(K_EF)=0.997120623, c_s_dual=0.996073159  ✓ Q_s(K_EF) > c_s_dual (diff=1.047464e-03)
#     scen 15: Q_s(K_EF)=1.083856447, c_s_dual=1.078115657  ✓ Q_s(K_EF) > c_s_dual (diff=5.740791e-03)
#     scen 16: Q_s(K_EF)=0.955111750, c_s_dual=0.955550515  ⚠ Q_s(K_EF) < c_s_dual → GUROBI CS DUAL IS WRONG
#     scen 17: Q_s(K_EF)=0.954144626, c_s_dual=0.955176622  ⚠ Q_s(K_EF) < c_s_dual → GUROBI CS DUAL IS WRONG
#     scen 18: Q_s(K_EF)=0.941226349, c_s_dual=0.940710825  ✓ Q_s(K_EF) > c_s_dual (diff=5.155234e-04)
#     scen 19: Q_s(K_EF)=0.949200904, c_s_dual=0.948395711  ✓ Q_s(K_EF) > c_s_dual (diff=8.051938e-04)
#     SUM Q_s(K_EF)=19.629695712, sum(c_s)=19.623629059, diff=6.066652e-03
#
# [Iter 0] LB = 19.573222 = UB(19.629696) + ms_b(-1.182e+11) from T3
# [Iter 0] Scene 0: Switched to c_s point. dist_ms_c=2.00e+01 < 1000.0, dist_c_verts=9.86e+01 > 1e-06
# [Iter 0] Scene 1: Switched to c_s point. dist_ms_c=1.89e+01 < 1000.0, dist_c_verts=1.00e+02 > 1e-06
# [Iter 0] Scene 2: Switched to c_s point. dist_ms_c=2.21e+01 < 1000.0, dist_c_verts=9.80e+01 > 1e-06
# [Iter 0] Scene 3: Switched to c_s point. dist_ms_c=1.70e+01 < 1000.0, dist_c_verts=9.90e+01 > 1e-06
# [Iter 0] Scene 4: Switched to c_s point. dist_ms_c=1.94e+01 < 1000.0, dist_c_verts=9.93e+01 > 1e-06
# [Iter 0] Scene 5: Switched to c_s point. dist_ms_c=1.92e+01 < 1000.0, dist_c_verts=9.95e+01 > 1e-06
# [Iter 0] Scene 6: Switched to c_s point. dist_ms_c=2.01e+01 < 1000.0, dist_c_verts=9.74e+01 > 1e-06
# [Iter 0] Scene 7: Switched to c_s point. dist_ms_c=1.93e+01 < 1000.0, dist_c_verts=9.91e+01 > 1e-06
# [Iter 0] Scene 8: Switched to c_s point. dist_ms_c=1.99e+01 < 1000.0, dist_c_verts=9.79e+01 > 1e-06
# [Iter 0] Scene 9: Switched to c_s point. dist_ms_c=2.01e+01 < 1000.0, dist_c_verts=9.85e+01 > 1e-06
# [Iter 0] Scene 10: Switched to c_s point. dist_ms_c=1.94e+01 < 1000.0, dist_c_verts=9.94e+01 > 1e-06
# [Iter 0] Scene 11: Switched to c_s point. dist_ms_c=1.94e+01 < 1000.0, dist_c_verts=9.75e+01 > 1e-06
# [Iter 0] Scene 12: Switched to c_s point. dist_ms_c=1.89e+01 < 1000.0, dist_c_verts=1.00e+02 > 1e-06
# [Iter 0] Scene 13: Switched to c_s point. dist_ms_c=2.50e+01 < 1000.0, dist_c_verts=1.01e+02 > 1e-06
# [Iter 0] Scene 14: Switched to c_s point. dist_ms_c=1.91e+01 < 1000.0, dist_c_verts=9.74e+01 > 1e-06
# [Iter 0] Scene 15: Switched to c_s point. dist_ms_c=2.11e+01 < 1000.0, dist_c_verts=9.59e+01 > 1e-06
# [Iter 0] Scene 16: Switched to c_s point. dist_ms_c=1.90e+01 < 1000.0, dist_c_verts=1.00e+02 > 1e-06
# [Iter 0] Scene 17: Switched to c_s point. dist_ms_c=1.88e+01 < 1000.0, dist_c_verts=1.00e+02 > 1e-06
# [Iter 0] Scene 18: Switched to c_s point. dist_ms_c=2.01e+01 < 1000.0, dist_c_verts=1.00e+02 > 1e-06
# [Iter 0] Scene 19: Switched to c_s point. dist_ms_c=1.92e+01 < 1000.0, dist_c_verts=9.95e+01 > 1e-06
# Chosen node (3.6118903878585504, 100.00000000000001, -0.00013175915866980858) with ms=-5.951e+09 (simp T3, scene 18, rank #1, source=c_s)
# [Iter 0] LB simplex = T3, next node simplex = T3, scene 18
# [Selected Simp Info] Iter 0 | Simplex T3 Vertices:
#   v0: (-10.0, 100.0, 100.0)
#   v1: (10.0, 100.0, -100.0)
#   v2: (10.0, 100.0, 100.0)
#   v3: (10.0, -100.0, -100.0)
#   -> New Point: (3.6118903878585504, 100.00000000000001, -0.00013175915866980858)
# [Iter 0] candidate rank #1: T3, scene=18, ms=-5.951e+09
# == ms candidates (sorted by (ms, -dist)) ==
# rank   simp   scene           ms    mind(all)                             pt
# ----------------------------------------------------------------------------
#    1     T3      18  -5.9513e+09     1.00e+02    (3.6119, 100.0000, -0.0001)
#    2     T3       1  -5.9443e+09     1.00e+02     (9.7486, 99.3372, -0.0001)
#    3     T3      16  -5.9434e+09     1.00e+02     (9.7156, 98.0963, -0.0000)
#    4     T3      12  -5.9423e+09     1.00e+02     (9.7547, 99.0738, -0.0000)
#    5     T3      17  -5.9397e+09     1.00e+02    (10.0000, 99.7223, -0.0003)
#    6     T3       4  -5.9391e+09     9.93e+01      (9.9986, 99.9976, 0.6671)
#    7     T3      10  -5.9364e+09     9.94e+01      (9.9986, 99.9975, 0.6376)
#    8     T3      13  -5.9359e+09     1.01e+02    (10.0000, 83.3757, -0.0001)
#    9     T3      19  -5.9357e+09     9.95e+01      (9.9964, 99.9944, 0.4725)
#   10     T3       5  -5.9319e+09     9.95e+01      (9.9886, 99.9775, 0.5273)
#
# [Iter 0] per_tet=6, active after q_cut=6, tri_is_None=False
# [Iter 0] bad-quality active simplices (q < 0): 0
# [Iter 0] evaluating Q for scenario 0
# [Iter 0] evaluating Q for scenario 1
# [Iter 0] evaluating Q for scenario 2
# [Iter 0] evaluating Q for scenario 3
# [Iter 0] evaluating Q for scenario 4
# [Iter 0] evaluating Q for scenario 5
# [Iter 0] evaluating Q for scenario 6
# [Iter 0] evaluating Q for scenario 7
# [Iter 0] evaluating Q for scenario 8
# [Iter 0] evaluating Q for scenario 9
# [Iter 0] evaluating Q for scenario 10
# [Iter 0] evaluating Q for scenario 11
# [Iter 0] evaluating Q for scenario 12
# [Iter 0] evaluating Q for scenario 13
# [Iter 0] evaluating Q for scenario 14
# [Iter 0] evaluating Q for scenario 15
# [Iter 0] evaluating Q for scenario 16
# [Iter 0] evaluating Q for scenario 17
# [Iter 0] evaluating Q for scenario 18
# [Iter 0] evaluating Q for scenario 19
#
# [Iter 0] Next Point Details:
# Simplex   Scene   Type    As             ms             As+ms          Q              (Kp, Ki, Kd)
# --------------------------------------------------------------------------------------------------------------------
# T3        18      c_s     5.0000e+09     -5.9513e+09    -9.5130e+08    9.4071e-01     (3.6119, 100.0000, -0.0001)
#
# [Iter 0] subdivision type = face (code=3) on simplex T3
#            face local verts = (3, 6, 7)
# [Iter 0] Elapsed: 428.953s
# [Invariant] MS scen None: dual=-5.929164e+09 > primal=-5.929164e+09
# [Invariant] MS scen None: dual=-5.800260e+09 > primal=-5.800260e+09
# [Invariant] MS scen None: dual=-5.940064e+09 > primal=-5.940064e+09
# [Invariant] MS scen None: dual=-5.933120e+09 > primal=-5.933120e+09
# [Invariant] MS scen None: dual=-5.914440e+09 > primal=-5.914440e+09
# [Invariant] MS scen None: dual=-5.946872e+09 > primal=-5.946872e+09
# [Invariant] MS scen None: dual=-5.827277e+09 > primal=-5.827277e+09
# [Invariant] MS scen None: dual=-5.761783e+09 > primal=-5.761783e+09
# [Invariant] MS scen None: dual=-5.635953e+09 > primal=-5.635953e+09
# [Invariant] MS scen None: dual=-5.768071e+09 > primal=-5.768071e+09
# [Invariant] MS scen None: dual=-5.709290e+09 > primal=-5.709290e+09
# [Invariant] MS scen None: dual=-5.773279e+09 > primal=-5.773279e+09
# [Invariant] MS scen None: dual=-5.690758e+09 > primal=-5.690758e+09
# [Invariant] MS scen None: dual=-5.783897e+09 > primal=-5.783897e+09
# [Invariant] MS scen None: dual=-5.788355e+09 > primal=-5.788355e+09
# [Invariant] MS scen None: dual=-5.772152e+09 > primal=-5.772152e+09
# ======================================================================
# [Iter 0] LB SPLIT DIAGNOSTIC
#   Selected (parent) simplex: (3, 4, 6, 7)
#   Parent LB: 0.981181453 (per-scen)
#   EF ef_obj(IPOPT): 0.049074238, true_obj(recalc): 0.981484786, used=min=0.049074238 (per-scen)
#   Simplex volume: 1.333333e+05
#   Children (3):
#     T5 (4, 6, 7, 8): LB = 0.980777670
#     T6 (3, 4, 7, 8): LB = 0.982756003
#     T7 (3, 4, 6, 8): LB = 0.982268185
#   New global LB: 0.978661079 (from T1 (0, 1, 3, 4))
#   Location: OUTSIDE
#   Avg CS point Q-value: 0.981812019 (per-scen), point=(np.float64(9.639429378546142), np.float64(98.56185787120924), np.float64(1.1660041286416716))
#   Current UB: 0.981484786 (per-scen)
#   UB point: (9.99970964924666, 99.99950031183559, 1.495159234725032)
#   UB source: EF_ipopt
#   UB simplex: (3, 4, 6, 7)
#   EF-IPOPT: ok=True, status=ok, term=optimal, time=0.553s, ef_obj=0.9814847628660429, true_obj(per-scen)=0.981484786
# ======================================================================
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -18.192137366290773): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -18.192137366290773): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -18.192137366290773): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -18.192137366290773): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -18.192137366290773): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -18.192137366290773): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -18.192137366290773): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(1.4927749906792969, 100.00000000000003, -14.924510363648912): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(1.4927749906792969, 100.00000000000003, -14.924510363648912): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(1.4927749906792969, 100.00000000000003, -14.924510363648912): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(1.4927749906792969, 100.00000000000003, -14.924510363648912): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(1.4927749906792969, 100.00000000000003, -14.924510363648912): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(1.4927749906792969, 100.00000000000003, -14.924510363648912): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(1.4927749906792969, 100.00000000000003, -14.924510363648912): status=warning, term=infeasibleOrUnbounded
#
# ======================================================================
# [TIMING] === Iter 0 phase breakdown (total 3032.08s) ===
#   1_vertex_UB                    :       0.00s  (  0.0%)
#   2_evaluate_all_tetra           :     427.41s  ( 14.1%)  #######
#   3_active_filter_print          :       0.00s  (  0.0%)
#   4_LB_selection                 :       0.00s  (  0.0%)
#   5_EF_UB_solve                  :       1.28s  (  0.0%)
#   6_candidate_selection          :       0.00s  (  0.0%)
#   7_Q_eval_new_node              :       0.26s  (  0.0%)
#   8_mesh_subdivide               :       0.00s  (  0.0%)
#   9_end_of_iter_reeval           :    2603.13s  ( 85.9%)  ##########################################
#   TOTAL                          :    3032.08s
#   #simplices=6, #scenarios=20, total_ms_pairs=120
#   fresh ms solves=120, cache hits=0
# ======================================================================
#
# [Iter 1] #simplices = 8, #active = 2, bad-quality cut = 0, bad-shape cut = 0
# == [Iter 1] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T1            9.786611e-01      3.982876e+09     -1.203425e+11      1.957322e+01     [4.46e+01, 2.00e+11]    [-1.20e+11, 7.97e+10]     1
# T5            9.807777e-01      4.090393e+09     -1.181921e+11      1.961555e+01     [1.97e+01, 2.00e+11]    [-1.18e+11, 8.18e+10]     1
#
# == [Iter 1] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.076765e+00      4.670976e+09     -1.065805e+11      2.153530e+01     [4.46e+01, 2.00e+11]    [-1.07e+11, 9.34e+10]     1
# T2            9.844449e-01      4.364059e+09     -1.127188e+11      1.968890e+01     [4.43e+01, 2.00e+11]    [-1.13e+11, 8.73e+10]     1
# T3            1.015796e+00      4.252759e+09     -1.149448e+11      2.031592e+01     [5.42e+01, 2.00e+11]    [-1.15e+11, 8.51e+10]     2
# T4            1.008047e+00               inf               inf      2.016093e+01     [5.42e+01, 2.00e+11]               [inf, inf]     2
# T6            9.827560e-01      1.359741e+00     -2.728785e+01      1.965512e+01     [1.97e+01, 5.45e+01]    [-7.58e+00, 2.72e+01]     0
# T7            9.822682e-01      4.254223e+09     -1.149155e+11      1.964536e+01     [1.97e+01, 2.00e+11]    [-1.15e+11, 8.51e+10]     1
#
# [Iter 1] created=8 (cum=17), active=2, active+UB=1, ms_recomputed=0
# [Iter 1] UB-simplex selection: UB_node in simplices [5, 6, 7], chose T5 (LB=0.980777670)
# [Iter 1] EF-ipopt: ok=True, ef_obj=0.9814847628671373, true_obj=9.814848e-01, time=0.428s
# [Iter 1] Pre-split gap: 5.647414e-02 (0.288%)
# [Iter 1] Active simplex ratio = 0.219901
# [Iter 1] UB point (3.6118903878585504, 100.00000000000001, -0.00013175915866980858) is geometrically in simplices [5, 6, 7]
#   T5 verts=[8, 6, 7, 4]: λ=[1.000000, -0.000000, 0.000000, -0.000000], LB=19.615553408, c_s=[0.9973765252109266, 0.9452014538046043, 0.9559881883388753, 1.07007863319451, 0.9691110637140297, 0.942905483822641, 1.0130536023265766, 0.9468369302753559, 1.0163400405325367, 0.9573054569291016, 0.9652324404606997, 1.037653533572153, 0.9519153558164379, 0.9745300851962125, 0.9960728312991155, 1.078143846279328, 0.954813715314247, 0.954166325588302, 0.9404325038362102, 0.9483953920426408]
#   T6 verts=[3, 8, 7, 4]: λ=[0.000000, 1.000000, -0.000000, -0.000000], LB=19.655120051, c_s=[1.0081542804955426, 0.9453235649364633, 0.9561586018456685, 1.075344186053462, 0.9708711601316543, 0.9430140908489143, 1.0145300641922061, 0.9469038911250331, 1.0197545934196721, 0.9603314322904075, 0.96613827369677, 1.0394803943934212, 0.9531072605237014, 0.9752081856579284, 0.9973991091800423, 1.0822190647806373, 0.9564842823785674, 0.9555027772234362, 0.9404612261520369, 0.948733611586781]
#   T7 verts=[3, 6, 8, 4]: λ=[0.000000, -0.000000, 1.000000, -0.000000], LB=19.645363694, c_s=[1.000277407219104, 0.9453277069810188, 0.9561713862498583, 1.0755521888314385, 0.970567217818611, 0.9430161820553649, 1.0146701987889037, 0.9469910252785031, 1.0200302858577857, 0.9585161392319643, 0.967149702839954, 1.0396490779527447, 0.9521206331538471, 0.9752505063418835, 0.9975269272559703, 1.0828528322142714, 0.9555122887854779, 0.9547594230566502, 0.9406834350761897, 0.9487391285450241]
#
# == [Iter 1] CS DUAL vs PRIMAL diagnostic (simplices containing UB point) ==
#   --- T5 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.999231680495209, 99.99864227387893, 1.3957937784760923)
#              indep_Q(cs_K)=0.997376525
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.999938858778266, 99.99988852799564, 0.8992690291067533)
#              indep_Q(cs_K)=0.945201454
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.99995779360896, 99.99994136828728, 2.031976201677608)
#              indep_Q(cs_K)=0.955988190
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.999998871154457, 99.99999617616754, 1.0237374529529701)
#              indep_Q(cs_K)=1.070078648
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.99998626073625, 99.99997467243551, 0.6671052052350497)
#              indep_Q(cs_K)=0.969111068
#     scen 5: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.99986716197074, 99.99977454718207, 0.5273230241174085)
#              indep_Q(cs_K)=0.942905561
#     scen 6: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.999995276015612, 99.9999935392717, 2.631842069200827)
#              indep_Q(cs_K)=1.013053612
#     scen 7: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.999770423052608, 99.99971959924395, 0.9166488813285617)
#              indep_Q(cs_K)=0.946836944
#     scen 8: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.999996432759001, 99.99999328122483, 2.0621924935062212)
#              indep_Q(cs_K)=1.016340068
#     scen 9: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.999984444593238, 99.99997381644167, 1.499815703522044)
#              indep_Q(cs_K)=0.957305458
#     scen 10: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.998652866001873, 99.99745922150734, 0.6375810271653424)
#              indep_Q(cs_K)=0.965232494
#     scen 11: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.999993484297558, 99.99999124306716, 2.454106598959603)
#              indep_Q(cs_K)=1.037653534
#     scen 12: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.589164679878321, 99.26456011113842, 0.7875134688426271)
#              indep_Q(cs_K)=0.951915356
#     scen 13: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(10.0, 100.0, 1.6688075748543079)
#              indep_Q(cs_K)=0.974530111
#     scen 14: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.99999458626781, 99.99999115834868, 2.6316373926053878)
#              indep_Q(cs_K)=0.996072839
#     scen 15: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.975838399557867, 99.96181954882522, 4.052533082170148)
#              indep_Q(cs_K)=1.078143848
#     scen 16: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.999984499144396, 99.99997164708182, 0.868311543718956)
#              indep_Q(cs_K)=0.954813717
#     scen 17: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(10.0, 100.0, 1.5306890621578755)
#              indep_Q(cs_K)=0.954166326
#     scen 18: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.958503131911417, 99.92869877772819, 0.4864166835997984)
#              indep_Q(cs_K)=0.940432512
#     scen 19: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.999962209373088, 99.9999436036438, 0.4724579923303132)
#              indep_Q(cs_K)=0.948395394
#   sum(c_s_dual)=0.000000000, UB_total=392.593914239, UB_per_scen=19.629695712
#
#   == Per-scenario Q_s at K_EF = (3.6118903878585504, 100.00000000000001, -0.00013175915866980858) ==
#     scen 0: Q_s(K_EF)=1.001261056, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.946218214, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.960753013, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.076910566, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.970538749, c_s_dual=N/A
#     scen 5: Q_s(K_EF)=0.943305820, c_s_dual=N/A
#     scen 6: Q_s(K_EF)=1.023024986, c_s_dual=N/A
#     scen 7: Q_s(K_EF)=0.947828415, c_s_dual=N/A
#     scen 8: Q_s(K_EF)=1.025234368, c_s_dual=N/A
#     scen 9: Q_s(K_EF)=0.960064455, c_s_dual=N/A
#     scen 10: Q_s(K_EF)=0.966660756, c_s_dual=N/A
#     scen 11: Q_s(K_EF)=1.047187915, c_s_dual=N/A
#     scen 12: Q_s(K_EF)=0.952742938, c_s_dual=N/A
#     scen 13: Q_s(K_EF)=0.978511569, c_s_dual=N/A
#     scen 14: Q_s(K_EF)=1.004873351, c_s_dual=N/A
#     scen 15: Q_s(K_EF)=1.102512040, c_s_dual=N/A
#     scen 16: Q_s(K_EF)=0.956031205, c_s_dual=N/A
#     scen 17: Q_s(K_EF)=0.956104985, c_s_dual=N/A
#     scen 18: Q_s(K_EF)=0.940710833, c_s_dual=N/A
#     scen 19: Q_s(K_EF)=0.948947020, c_s_dual=N/A
#     SUM Q_s(K_EF)=19.709422254, sum(c_s)=0.000000000, diff=1.970942e+01
#   --- T6 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(4.220428098411807, 71.52580823030458, 0.4201884875573868)
#              indep_Q(cs_K)=1.008154299
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(3.6698205361192238, 99.99990652986715, 0.9073093295889187)
#              indep_Q(cs_K)=0.945323565
#     scen 2: status=?, dual=N/A, primal=N/A
# ...
#              indep_Q(cs_K)=0.948095999
#   sum(c_s_dual)=0.000000000, UB_total=391.560240176, UB_per_scen=19.578012009
#
#   == Per-scenario Q_s at K_EF = (-9.999647341295516, -99.99933244291763, 0.9375610024010701) ==
#     scen 0: Q_s(K_EF)=0.996002738, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945143974, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.956336349, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054834334, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968580109, c_s_dual=N/A
#     scen 5: Q_s(K_EF)=0.942951254, c_s_dual=N/A
#     scen 6: Q_s(K_EF)=1.011623517, c_s_dual=N/A
#     scen 7: Q_s(K_EF)=0.946722524, c_s_dual=N/A
#     scen 8: Q_s(K_EF)=1.010824559, c_s_dual=N/A
#     scen 9: Q_s(K_EF)=0.957007328, c_s_dual=N/A
#     scen 10: Q_s(K_EF)=0.964683767, c_s_dual=N/A
#     scen 11: Q_s(K_EF)=1.034578720, c_s_dual=N/A
#     scen 12: Q_s(K_EF)=0.951778299, c_s_dual=N/A
#     scen 13: Q_s(K_EF)=0.974293377, c_s_dual=N/A
#     scen 14: Q_s(K_EF)=0.994016909, c_s_dual=N/A
#     scen 15: Q_s(K_EF)=1.071598559, c_s_dual=N/A
#     scen 16: Q_s(K_EF)=0.954547667, c_s_dual=N/A
#     scen 17: Q_s(K_EF)=0.953582310, c_s_dual=N/A
#     scen 18: Q_s(K_EF)=0.940609408, c_s_dual=N/A
#     scen 19: Q_s(K_EF)=0.948296309, c_s_dual=N/A
#     SUM Q_s(K_EF)=19.578012009, sum(c_s)=0.000000000, diff=1.957801e+01
#
# [Iter 8] LB = 19.573222 = UB(19.578012) + ms_b(-1.203e+11) from T1
# [Iter 8] Scene 0: Switched to c_s point. dist_ms_c=1.95e+01 < 1000.0, dist_c_verts=9.91e+01 > 1e-06
# [Iter 8] Scene 1: Switched to c_s point. dist_ms_c=1.93e+01 < 1000.0, dist_c_verts=9.92e+01 > 1e-06
# [Iter 8] Scene 2: Switched to c_s point. dist_ms_c=1.89e+01 < 1000.0, dist_c_verts=9.84e+01 > 1e-06
# [Iter 8] Scene 3: Switched to c_s point. dist_ms_c=2.05e+01 < 1000.0, dist_c_verts=9.97e+01 > 1e-06
# [Iter 8] Scene 4: Switched to c_s point. dist_ms_c=1.98e+01 < 1000.0, dist_c_verts=9.96e+01 > 1e-06
# [Iter 8] Scene 5: Switched to c_s point. dist_ms_c=1.99e+01 < 1000.0, dist_c_verts=9.95e+01 > 1e-06
# [Iter 8] Scene 6: Switched to c_s point. dist_ms_c=1.88e+01 < 1000.0, dist_c_verts=9.80e+01 > 1e-06
# [Iter 8] Scene 7: Switched to c_s point. dist_ms_c=1.89e+01 < 1000.0, dist_c_verts=9.92e+01 > 1e-06
# [Iter 8] Scene 8: Switched to c_s point. dist_ms_c=2.00e+01 < 1000.0, dist_c_verts=9.93e+01 > 1e-06
# [Iter 8] Scene 9: Switched to c_s point. dist_ms_c=1.91e+01 < 1000.0, dist_c_verts=9.87e+01 > 1e-06
# [Iter 8] Scene 10: Switched to c_s point. dist_ms_c=2.00e+01 < 1000.0, dist_c_verts=9.97e+01 > 1e-06
# [Iter 8] Scene 11: Switched to c_s point. dist_ms_c=1.97e+01 < 1000.0, dist_c_verts=9.89e+01 > 1e-06
# [Iter 8] Scene 12: Switched to c_s point. dist_ms_c=1.94e+01 < 1000.0, dist_c_verts=9.93e+01 > 1e-06
# [Iter 8] Scene 13: Switched to c_s point. dist_ms_c=1.89e+01 < 1000.0, dist_c_verts=9.87e+01 > 1e-06
# [Iter 8] Scene 14: Switched to c_s point. dist_ms_c=1.87e+01 < 1000.0, dist_c_verts=9.79e+01 > 1e-06
# [Iter 8] Scene 15: Switched to c_s point. dist_ms_c=1.85e+01 < 1000.0, dist_c_verts=9.81e+01 > 1e-06
# [Iter 8] Scene 16: Switched to c_s point. dist_ms_c=1.93e+01 < 1000.0, dist_c_verts=9.93e+01 > 1e-06
# [Iter 8] Scene 17: Switched to c_s point. dist_ms_c=1.94e+01 < 1000.0, dist_c_verts=9.92e+01 > 1e-06
# [Iter 8] Scene 18: Switched to c_s point. dist_ms_c=1.95e+01 < 1000.0, dist_c_verts=9.95e+01 > 1e-06
# [Iter 8] Scene 19: Switched to c_s point. dist_ms_c=1.98e+01 < 1000.0, dist_c_verts=9.95e+01 > 1e-06
# Chosen node (-9.999584732526554, -99.999191433985, 0.3476309591590474) with ms=-6.045e+09 (simp T1, scene 3, rank #1, source=c_s)
# [Iter 8] LB simplex = T1, next node simplex = T1, scene 3
# [Selected Simp Info] Iter 8 | Simplex T1 Vertices:
#   v0: (-10.0, 100.0, 100.0)
#   v1: (-10.0, -100.0, 100.0)
#   v2: (10.0, -100.0, -100.0)
#   v3: (-10.0, -100.0, -100.0)
#   -> New Point: (-9.999584732526554, -99.999191433985, 0.3476309591590474)
# [Iter 8] candidate rank #1: T1, scene=3, ms=-6.045e+09
# == ms candidates (sorted by (ms, -dist)) ==
# rank   simp   scene           ms    mind(all)                             pt
# ----------------------------------------------------------------------------
#    1     T1       3  -6.0448e+09     9.97e+01    (-9.9996, -99.9992, 0.3476)
#    2     T1      14  -6.0430e+09     9.79e+01    (-9.9989, -99.9980, 2.1253)
#    3     T1      11  -6.0396e+09     9.89e+01    (-9.9994, -99.9989, 1.1393)
#    4     T1       6  -6.0382e+09     9.80e+01    (-9.9993, -99.9988, 1.9641)
#    5     T1       8  -6.0335e+09     9.93e+01    (-9.9996, -99.9992, 0.6637)
#    6     T1       2  -6.0269e+09     9.84e+01    (-9.9940, -99.9902, 1.6483)
#    7     T1       0  -6.0196e+09     9.91e+01    (-9.9992, -99.9985, 0.9388)
#    8     T1      15  -6.0181e+09     9.81e+01    (-9.9997, -99.9995, 1.8523)
#    9     T1       9  -6.0172e+09     9.87e+01    (-9.9974, -99.9953, 1.2699)
#   10     T1       5  -6.0171e+09     9.95e+01    (-9.9867, -99.9722, 0.4841)
#
# [Iter 8] per_tet=17, active after q_cut=8, tri_is_None=False
# [Iter 8] bad-quality active simplices (q < 0): 0
# [Iter 8] evaluating Q for scenario 0
# [Iter 8] evaluating Q for scenario 1
# [Iter 8] evaluating Q for scenario 2
# [Iter 8] evaluating Q for scenario 3
# [Iter 8] evaluating Q for scenario 4
# [Iter 8] evaluating Q for scenario 5
# [Iter 8] evaluating Q for scenario 6
# [Iter 8] evaluating Q for scenario 7
# [Iter 8] evaluating Q for scenario 8
# [Iter 8] evaluating Q for scenario 9
# [Iter 8] evaluating Q for scenario 10
# [Iter 8] evaluating Q for scenario 11
# [Iter 8] evaluating Q for scenario 12
# [Iter 8] evaluating Q for scenario 13
# [Iter 8] evaluating Q for scenario 14
# [Iter 8] evaluating Q for scenario 15
# [Iter 8] evaluating Q for scenario 16
# [Iter 8] evaluating Q for scenario 17
# [Iter 8] evaluating Q for scenario 18
# [Iter 8] evaluating Q for scenario 19
#
# [Iter 8] Next Point Details:
# Simplex   Scene   Type    As             ms             As+ms          Q              (Kp, Ki, Kd)
# --------------------------------------------------------------------------------------------------------------------
# T1        3       c_s     5.0173e+09     -6.0448e+09    -1.0275e+09    1.0546e+00     (-9.9996, -99.9992, 0.3476)
#
# [Iter 8] subdivision type = interior (code=1) on simplex T1
# [Iter 8] Elapsed: 1.347s
# [Invariant] MS scen None: dual=-6.019616e+09 > primal=-6.019616e+09
# [Invariant] MS scen None: dual=-6.022316e+09 > primal=-6.022316e+09
# [Invariant] MS scen None: dual=-6.035244e+09 > primal=-6.035244e+09
# [Invariant] MS scen None: dual=-6.017154e+09 > primal=-6.017154e+09
# [Invariant] MS scen None: dual=-6.039785e+09 > primal=-6.039785e+09
# [Invariant] MS scen None: dual=-6.012726e+09 > primal=-6.012726e+09
# [Invariant] MS scen None: dual=-6.009359e+09 > primal=-6.009359e+09
# [Invariant] MS scen None: dual=-5.997823e+09 > primal=-5.997823e+09
# [Invariant] MS scen None: dual=-6.012289e+09 > primal=-6.012289e+09
# [Invariant] MS scen None: dual=-6.019309e+09 > primal=-6.019309e+09
# [Invariant] MS scen None: dual=-6.026365e+09 > primal=-6.026365e+09
# [Invariant] MS scen None: dual=-6.021768e+09 > primal=-6.021768e+09
# [Invariant] MS scen None: dual=-6.012594e+09 > primal=-6.012594e+09
# [Invariant] MS scen None: dual=-6.043714e+09 > primal=-6.043714e+09
# [Invariant] MS scen None: dual=-6.018405e+09 > primal=-6.018405e+09
# [Invariant] MS scen None: dual=-5.996035e+09 > primal=-5.996035e+09
# [Invariant] MS scen None: dual=-5.849704e+09 > primal=-5.849704e+09
# [Invariant] MS scen None: dual=-5.880642e+09 > primal=-5.880642e+09
# [Invariant] MS scen None: dual=-5.863129e+09 > primal=-5.863129e+09
# [Invariant] MS scen None: dual=-5.856877e+09 > primal=-5.856877e+09
# [Invariant] MS scen None: dual=-5.879095e+09 > primal=-5.879095e+09
# [Invariant] MS scen None: dual=-5.852404e+09 > primal=-5.852404e+09
# [Invariant] MS scen None: dual=-5.887641e+09 > primal=-5.887641e+09
# [Invariant] MS scen None: dual=-5.838887e+09 > primal=-5.838887e+09
# [Invariant] MS scen None: dual=-5.850863e+09 > primal=-5.850863e+09
# ======================================================================
# [Iter 8] LB SPLIT DIAGNOSTIC
#   Selected (parent) simplex: (0, 1, 3, 4)
#   Parent LB: 0.978661079 (per-scen)
#   EF ef_obj(IPOPT): 0.048945029, true_obj(recalc): 0.978900600, used=min=0.048945029 (per-scen)
#   Simplex volume: 1.333333e+05
#   Children (4):
#     T28 (0, 1, 4, 16): LB = 0.978660759
#     T29 (0, 3, 4, 16): LB = 0.978778039
#     T30 (0, 1, 3, 16): LB = 0.978680933
#     T31 (1, 3, 4, 16): LB = 0.978900358
#   New global LB: 0.978660759 (from T28 (0, 1, 4, 16))
#   Location: INSIDE
#   Avg CS point Q-value: 0.978902775 (per-scen), point=(np.float64(-9.994079455046231), np.float64(-99.98932771084552), np.float64(0.9619740439774287))
#   Current UB: 0.978900600 (per-scen)
#   UB point: (-9.999647341295516, -99.99933244291763, 0.9375610024010701)
#   UB source: EF_ipopt
#   UB simplex: (0, 1, 3, 4)
#   EF-IPOPT: ok=True, status=ok, term=optimal, time=0.409s, ef_obj=0.9789005774012383, true_obj(per-scen)=0.978900600
# ======================================================================
# [BaseBundle.eval_at] Infeasible/Error for K=(-9.997612515612866, -100.0, 20.386776207536855): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-9.997612515612866, -100.0, 20.386776207536855): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-9.997612515612866, -100.0, 20.386776207536855): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-9.997612515612866, -100.0, 20.386776207536855): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-9.997612515612866, -100.0, 20.386776207536855): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-9.997612515612866, -100.0, 20.386776207536855): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-9.997612515612866, -100.0, 20.386776207536855): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-9.997612515612866, -100.0, 20.386776207536855): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-9.997612515612866, -100.0, 20.386776207536855): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-9.997612515612866, -100.0, 20.386776207536855): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-9.997612515612866, -100.0, 20.386776207536855): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-9.997612515612866, -100.0, 20.386776207536855): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 20.37672543413138): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 20.37672543413138): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 20.37672543413138): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 20.37672543413138): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 20.37672543413138): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 20.37672543413138): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 20.37672543413138): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 20.37672543413138): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 20.37672543413138): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 20.37672543413138): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 20.37672543413138): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-1.7206410229096203, -99.99999994018422, 17.199038493473285): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-1.7206410229096203, -99.99999994018422, 17.199038493473285): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-1.7206410229096203, -99.99999994018422, 17.199038493473285): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-1.7206410229096203, -99.99999994018422, 17.199038493473285): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-1.7206410229096203, -99.99999994018422, 17.199038493473285): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-1.7206410229096203, -99.99999994018422, 17.199038493473285): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-1.7206410229096203, -99.99999994018422, 17.199038493473285): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-1.7206410229096203, -99.99999994018422, 17.199038493473285): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-1.7206410229096203, -99.99999994018422, 17.199038493473285): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-1.7206410229096203, -99.99999994018422, 17.199038493473285): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-1.7206410229096203, -99.99999994018422, 17.199038493473285): status=warning, term=infeasibleOrUnbounded
#
# ======================================================================
# [TIMING] === Iter 8 phase breakdown (total 2631.52s) ===
#   1_vertex_UB                    :       0.00s  (  0.0%)
#   2_evaluate_all_tetra           :       0.00s  (  0.0%)
#   3_active_filter_print          :       0.00s  (  0.0%)
#   4_LB_selection                 :       0.00s  (  0.0%)
#   5_EF_UB_solve                  :       1.13s  (  0.0%)
#   6_candidate_selection          :       0.00s  (  0.0%)
#   7_Q_eval_new_node              :       0.21s  (  0.0%)
#   8_mesh_subdivide               :       0.00s  (  0.0%)
#   9_end_of_iter_reeval           :    2630.18s  ( 99.9%)  #################################################
#   TOTAL                          :    2631.52s
#   #simplices=17, #scenarios=20, total_ms_pairs=340
#   fresh ms solves=0, cache hits=340
# ======================================================================
#
# [Iter 8] Stop: Time limit reached (7833.58s >= 7200.00s).
#
# ===== Simplex search summary (per-scenario) =====
#   Time (s)  # Nodes             LB             UB   Rel. Gap   Abs. Gap   #simplex    #active   Split       Selection
# ---------------------------------------------------------------------------------------------------------------------
#    428.296        8    0.978661079    0.981484786    0.2877%    0.00282          6          6    none             c_s
#   3032.825        9    0.978661079    0.981484786    0.2877%    0.00282          8          2    face             c_s
#   4688.977       10    0.978661079    0.981484786    0.2877%    0.00282         11          4interior             c_s
#   4928.224       11    0.978661079    0.981484786    0.2877%    0.00282         14          6interior             c_s
#   5093.494       12    0.978661079    0.981484786    0.2877%    0.00282         17          8interior             c_s
#   5123.689       13    0.978661079    0.981484785    0.2877%    0.00282         17          8interior             c_s
#   5173.809       14    0.978661079    0.981484785    0.2877%    0.00282         18          9interior             c_s
#   5200.790       15    0.978661079    0.981484785    0.2877%    0.00282         18          9interior             c_s
#   5202.669       16    0.978660759    0.978900600    0.0245%    0.00024         17          8interior             c_s
# [Time] Main loop total: 7836.913s
#
# ==== Done ====
# Total nodes: 17
# Best UB: 19.578012008801988
# Last LB: 19.57321517659822
