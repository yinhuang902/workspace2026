# %%
from time import perf_counter  

from modeling import build_models_from_csv
from bundles import BaseBundle, MSBundle
from utils import (
    tighten_bounds_one_model,
    MIN_DIST, ACTIVE_TOL, GAP_STOP_TOL,
)
from simplex_specialstart import run_pid_simplex_3d

# setup scenario number and target_nodesk
csv_path       = "data.csv"
max_scenarios  = 3
target_nodes   = 1000

bounds={
    "Kp": (-10.0, 10.0),
    "Ki": (-100.0, 100.0),
    "Kd": (-100.0, 100.0),
    "x": (-2.5, 2.5),
    "u": (-5.0, 5.0),
    "e": (None, None),
    "I": (None, None),
}

weights = (10.0, 0.01)


# ====== stage 1：load data and generate models ======
T   = 15.0          
nfe = 20            

t_load0 = perf_counter()
model_list, first_stg_vars_list, m_tmpl_list, nfe = build_models_from_csv(
    csv_path=csv_path,
    T=T,
    nfe=nfe,
    weights=weights,
    bounds=bounds,
    sp0=0.0,
    sp1=0.5,
    tau_xs_col="tau_xs",
    tau_us_col="tau_us",
    tau_ds_col="tau_ds",          
    disturb_prefix="disturbance_",
    setpoint_change_col="setpoint_change",
    max_scenarios=max_scenarios,
    skip=0,
)
t_load1 = perf_counter()
print(f"[Time] Data load & scenario build: {t_load1 - t_load0:.3f}s")


# ====== stage 1.5：FBBT / OBBT ======
# same as snog: FBBT open,OBBT open
obbt_solver_opts = {
    "NonConvex": 2,
    "MIPGap": 1,     
    "TimeLimit": 15   
}
for m, yvars in zip(model_list, first_stg_vars_list):
    tighten_bounds_one_model(m, yvars,
                             use_fbbt=False,
                             use_obbt=False,
                             obbt_solver_name="gurobi",
                             obbt_solver_opts=obbt_solver_opts,
                             max_rounds=3, tol=1e-6, verbose=True)

# ====== stage 2: Persistent Solver Packaging ======
ub_options = {
    'NonConvex': 2,      
}
lb_options = {
    'NonConvex': 2,
    'MIPGap': 1e-1,            
    'TimeLimit': 15 
}

t_wrap0 = perf_counter()
base_bundles = [BaseBundle(m, ub_options) for m in model_list]  
ms_bundles   = [MSBundle(m, yvars, lb_options) for m, yvars in zip(model_list, first_stg_vars_list)]  
t_wrap1 = perf_counter()
print(f"[Time] Persistent wrapper (GurobiPersistent) setup: {t_wrap1 - t_wrap0:.3f}s")

# ====== stage 3：main loop ======
agg_bundle = None  

t_run0 = perf_counter()
hist = run_pid_simplex_3d(
    base_bundles=base_bundles,
    ms_bundles=ms_bundles,
    model_list=model_list,
    first_vars_list=first_stg_vars_list,
    target_nodes=target_nodes,
    min_dist=0,
    active_tol=ACTIVE_TOL,
    verbose=True,
    agg_bundle=agg_bundle,
    gap_stop_tol=1e-6,
    use_exact_opt=False,
    exact_solver_name="gurobi",
    exact_solver_opts={"NonConvex": 2, "TimeLimit": 60},
    time_limit=60*60*7,
    enable_3d_plot=False,   
    plot_every=None,        
)
t_run1 = perf_counter()
print(f"[Time] Main loop total: {t_run1 - t_run0:.3f}s")

# ====== print output ======
print("\n==== Done ====")
print(f"Total nodes: {len(hist['nodes'])}")
print(f"Best UB: {min(hist['UB_hist']) if hist['UB_hist'] else None}")
print(f"Last LB: {hist['LB_hist'][-1] if hist['LB_hist'] else None}")
# Out:
# [Time] Data load & scenario build: 0.021s
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2689754
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 15
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 15
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 15
# [Time] Persistent wrapper (GurobiPersistent) setup: 1.501s
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=warning, term=infeasibleOrUnbounded
# [TIMING] Pre-loop vertex Q evals: 0.74s  (8 nodes x 3 scenarios = 24 solves)
# [EF-UB] Initialized ipopt EF with 3 scenarios, time_ub=60.0s
#
# ======================================================================
# [TIMING] === Pre-loop phase summary ===
#   corners_and_mesh               :       0.00s
#   vertex_Q_evals                 :       0.74s
#   exact_optima                   :       0.00s
#   ef_init                        :       0.02s
#   TOTAL                          :       0.77s
# ======================================================================
#
# [Iter 0] MIPGap overridden to 0.1 (original: 0.1)
# Discarded solution information
# [Invariant] MS scen None: dual=-5.500707e+09 > primal=-5.500707e+09
# Discarded solution information
# Discarded solution information
# [Invariant] MS scen None: dual=-5.481254e+09 > primal=-5.481254e+09
# [Invariant] MS scen None: dual=-5.806922e+09 > primal=-5.806922e+09
# [Invariant] MS scen None: dual=-5.817119e+09 > primal=-5.817119e+09
# [Invariant] MS scen None: dual=-5.596691e+09 > primal=-5.596691e+09
# [Invariant] MS scen None: dual=-5.719282e+09 > primal=-5.719282e+09
# [Invariant] MS scen None: dual=-5.724298e+09 > primal=-5.724298e+09
# [Bundle] MS scen None: infeasibleOrUnbounded. ms_val=nan.
# [Bundle] MS scen None: not optimal. Status=warning, Term=infeasibleOrUnbounded.
# [Iter 0] MIPGap restored to 0.1
# [Iter 0] #simplices = 6, #active = 6, bad-quality cut = 0, bad-shape cut = 0
# == [Iter 0] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.025632e+00      4.607881e+09     -1.617636e+10      3.076897e+00     [6.69e+00, 3.00e+10]    [-1.62e+10, 1.38e+10]     1
# T1            9.658374e-01      4.116368e+09     -1.765089e+10      2.897512e+00     [6.69e+00, 3.00e+10]    [-1.77e+10, 1.23e+10]     1
# T2            9.697088e-01      4.393099e+09     -1.682070e+10      2.909126e+00     [6.56e+00, 3.00e+10]    [-1.68e+10, 1.32e+10]     1
# T3            9.665306e-01      4.221519e+09     -1.733544e+10      2.899592e+00     [6.56e+00, 3.00e+10]    [-1.73e+10, 1.27e+10]     1
# T4            9.755887e-01      4.270667e+09     -1.718800e+10      2.926766e+00     [8.03e+00, 3.00e+10]    [-1.72e+10, 1.28e+10]     2
# T5            9.671093e-01               inf               inf      2.901328e+00     [8.03e+00, 3.00e+10]               [inf, inf]     2
#
# == [Iter 0] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
#   (none)
# [Iter 0] created=6 (cum=6), active=6, active+UB=2, ms_recomputed=6
# [Iter 0] UB-simplex selection: UB_node in simplices [2, 3], chose T3 (LB=0.966530645)
# [Iter 0] EF-ipopt: ok=True, ef_obj=0.96636228392473, true_obj=9.663623e-01, time=0.112s
# [Iter 0] EF-UB improved by ipopt: 9.663623e-01 (per-scen), K=(9.999860487194258, 99.99975846542533, 1.4521399363588756)
# [Iter 0] Pre-split gap: 1.574696e-03 (0.054%)
# [Iter 0] Active simplex ratio = 1.000000
# [Iter 0] UB point (9.999860487194258, 99.99975846542533, 1.4521399363588756) is geometrically in simplices [3]
#   T3 verts=[3, 6, 7, 4]: λ=[0.000007, 0.492738, 0.507254, 0.000001], LB=2.899591936, c_s=[0.9973765252119483, 0.945971989084273, 0.9562434219662743]
#
# == [Iter 0] CS DUAL vs PRIMAL diagnostic (simplices containing UB point) ==
#   --- T3 ---
#     scen 0: status=time_limit, dual=0.997376525, primal=0.997376525  ✓ dual ≤ primal (gap=1.110223e-16)
#              cs_primal_K=(9.999231675757967, 99.99864227385171, 1.3957947968559532)
#              indep_Q(cs_K)=0.997376525  → dual ≤ indep_Q (consistent, diff=2.363576e-11)
#     scen 1: status=time_limit, dual=0.945971989, primal=0.945971989  ✓ dual ≤ primal (gap=3.330669e-16)
#              cs_primal_K=(8.673584102133287, 99.47783248669006, -0.001693959858312535)
#              indep_Q(cs_K)=0.945971991  → dual ≤ indep_Q (consistent, diff=2.050739e-09)
#     scen 2: status=time_limit, dual=0.956243422, primal=0.956243422  ✓ dual ≤ primal (gap=0.000000e+00)
#              cs_primal_K=(9.999994936241917, 91.70368911358257, 2.3482370383557245)
#              indep_Q(cs_K)=0.956243425  → dual ≤ indep_Q (consistent, diff=3.320104e-09)
#   sum(c_s_dual)=2.899591936, UB_total=8.697260675, UB_per_scen=2.899086892
#
#   == Per-scenario Q_s at K_EF = (9.999860487194258, 99.99975846542533, 1.4521399363588756) ==
#     scen 0: Q_s(K_EF)=0.997378857, c_s_dual=0.997376525  ✓ Q_s(K_EF) > c_s_dual (diff=2.331459e-06)
#     scen 1: Q_s(K_EF)=0.945445387, c_s_dual=0.945971989  ⚠ Q_s(K_EF) < c_s_dual → GUROBI CS DUAL IS WRONG
#     scen 2: Q_s(K_EF)=0.956262648, c_s_dual=0.956243422  ✓ Q_s(K_EF) > c_s_dual (diff=1.922569e-05)
#     SUM Q_s(K_EF)=2.899086892, sum(c_s)=2.899591936, diff=-5.050445e-04
#
# [Iter 0] LB = 2.897512 = UB(2.899087) + ms_b(-1.734e+10) from T3
# [Iter 0] Scene 0: Switched to c_s point. dist_ms_c=1.87e+01 < 1000.0, dist_c_verts=9.86e+01 > 1e-06
# [Iter 0] Scene 1: Switched to c_s point. dist_ms_c=1.61e+01 < 1000.0, dist_c_verts=1.00e+02 > 1e-06
# [Iter 0] Scene 2: Switched to c_s point. dist_ms_c=2.10e+01 < 1000.0, dist_c_verts=9.80e+01 > 1e-06
# Chosen node (9.999994936241917, 91.70368911358257, 2.3482370383557245) with ms=-5.840e+09 (simp T3, scene 2, rank #1, source=c_s)
# [Iter 0] LB simplex = T3, next node simplex = T3, scene 2
# [Selected Simp Info] Iter 0 | Simplex T3 Vertices:
#   v0: (-10.0, 100.0, 100.0)
#   v1: (10.0, 100.0, -100.0)
#   v2: (10.0, 100.0, 100.0)
#   v3: (10.0, -100.0, -100.0)
#   -> New Point: (9.999994936241917, 91.70368911358257, 2.3482370383557245)
# [Iter 0] candidate rank #1: T3, scene=2, ms=-5.840e+09
# == ms candidates (sorted by (ms, -dist)) ==
# rank   simp   scene           ms    mind(all)                             pt
# ----------------------------------------------------------------------------
#    1     T3       2  -5.8396e+09     9.80e+01     (10.0000, 91.7037, 2.3482)
#    2     T3       0  -5.7766e+09     9.86e+01      (9.9992, 99.9986, 1.3958)
#    3     T3       1  -5.7193e+09     1.00e+02     (8.6736, 99.4778, -0.0017)
#
# [Iter 0] per_tet=6, active after q_cut=6, tri_is_None=False
# [Iter 0] bad-quality active simplices (q < 0): 0
# [Iter 0] evaluating Q for scenario 0
# [Iter 0] evaluating Q for scenario 1
# [Iter 0] evaluating Q for scenario 2
#
# [Iter 0] Next Point Details:
# Simplex   Scene   Type    As             ms             As+ms          Q              (Kp, Ki, Kd)
# --------------------------------------------------------------------------------------------------------------------
# T3        2       c_s     4.4678e+09     -5.8396e+09    -1.3718e+09    9.5624e-01     (10.0000, 91.7037, 2.3482)
#
# [Iter 0] subdivision type = interior (code=1) on simplex T3
# [Iter 0] Elapsed: 69.038s
# [Invariant] MS scen None: dual=-5.878353e+09 > primal=-5.878353e+09
# [Invariant] MS scen None: dual=-5.483775e+09 > primal=-5.483775e+09
# [Invariant] MS scen None: dual=-5.624451e+09 > primal=-5.624451e+09
# [Invariant] MS scen None: dual=-5.688788e+09 > primal=-5.688788e+09
# ======================================================================
# [Iter 0] LB SPLIT DIAGNOSTIC
#   Selected (parent) simplex: (3, 4, 6, 7)
#   Parent LB: 0.966530645 (per-scen)
#   EF ef_obj(IPOPT): 0.322120761, true_obj(recalc): 0.966362297, used=min=0.322120761 (per-scen)
#   Simplex volume: 1.333333e+05
#   Children (4):
#     T5 (4, 6, 7, 8): LB = 0.966189047
#     T6 (3, 4, 7, 8): LB = 0.967963837
#     T7 (3, 4, 6, 8): LB = 0.967209679
#     T8 (3, 6, 7, 8): LB = 0.966189092
#   New global LB: 0.965837399 (from T1 (0, 1, 3, 4))
#   Location: OUTSIDE
#   Avg CS point Q-value: 0.966599785 (per-scen), point=(np.float64(9.557603571377724), np.float64(97.06005462470812), np.float64(1.2474459584511217))
#   Current UB: 0.966362297 (per-scen)
#   UB point: (9.999860487194258, 99.99975846542533, 1.4521399363588756)
#   UB source: EF_ipopt
#   UB simplex: (3, 4, 6, 7)
#   EF-IPOPT: ok=True, status=ok, term=optimal, time=0.112s, ef_obj=0.96636228392473, true_obj(per-scen)=0.966362297
# ======================================================================
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -18.185794931006274): status=warning, term=infeasibleOrUnbounded
#
# ======================================================================
# [TIMING] === Iter 0 phase breakdown (total 155.87s) ===
#   1_vertex_UB                    :       0.00s  (  0.0%)
#   2_evaluate_all_tetra           :      68.79s  ( 44.1%)  ######################
#   3_active_filter_print          :       0.00s  (  0.0%)
#   4_LB_selection                 :       0.00s  (  0.0%)
#   5_EF_UB_solve                  :       0.21s  (  0.1%)
#   6_candidate_selection          :       0.00s  (  0.0%)
#   7_Q_eval_new_node              :       0.03s  (  0.0%)
#   8_mesh_subdivide               :       0.00s  (  0.0%)
#   9_end_of_iter_reeval           :      86.83s  ( 55.7%)  ###########################
#   TOTAL                          :     155.87s
#   #simplices=6, #scenarios=3, total_ms_pairs=18
#   fresh ms solves=18, cache hits=0
# ======================================================================
#
# [Iter 1] #simplices = 9, #active = 3, bad-quality cut = 0, bad-shape cut = 0
# == [Iter 1] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T1            9.658374e-01      4.116368e+09     -1.765089e+10      2.897512e+00     [6.69e+00, 3.00e+10]    [-1.77e+10, 1.23e+10]     1
# T5            9.661890e-01      4.090710e+09     -1.772787e+10      2.898567e+00     [2.90e+00, 3.00e+10]    [-1.77e+10, 1.23e+10]     1
# T8            9.661891e-01      4.238272e+09     -1.728518e+10      2.898567e+00     [2.90e+00, 3.00e+10]    [-1.73e+10, 1.27e+10]     1
#
# == [Iter 1] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.025632e+00      4.607881e+09     -1.617636e+10      3.076897e+00     [6.69e+00, 3.00e+10]    [-1.62e+10, 1.38e+10]     1
# T2            9.697088e-01      4.393099e+09     -1.682070e+10      2.909126e+00     [6.56e+00, 3.00e+10]    [-1.68e+10, 1.32e+10]     1
# T3            9.755887e-01      4.270667e+09     -1.718800e+10      2.926766e+00     [8.03e+00, 3.00e+10]    [-1.72e+10, 1.28e+10]     2
# T4            9.671093e-01               inf               inf      2.901328e+00     [8.03e+00, 3.00e+10]               [inf, inf]     2
# T6            9.679638e-01      1.288643e+00     -4.329139e+00      2.903892e+00     [2.90e+00, 8.20e+00]    [-1.43e+00, 3.87e+00]     0
# T7            9.672097e-01      4.434713e+09     -1.669586e+10      2.901629e+00     [2.90e+00, 3.00e+10]    [-1.67e+10, 1.33e+10]     1
#
# [Iter 1] created=9 (cum=19), active=3, active+UB=2, ms_recomputed=0
# [Iter 1] UB-simplex selection: UB_node in simplices [5, 6, 7, 8], chose T5 (LB=0.966189047)
# [Iter 1] EF-ipopt: ok=True, ef_obj=0.9663622738958584, true_obj=9.663623e-01, time=0.133s
# [Iter 1] EF-UB improved by ipopt: 9.663623e-01 (per-scen), K=(9.999999999898348, 99.99971012237032, 1.45213983251335)
# [Iter 1] Pre-split gap: 1.574666e-03 (0.054%)
# [Iter 1] Active simplex ratio = 0.173580
# [Iter 1] UB point (9.999999999898348, 99.99971012237032, 1.45213983251335) is geometrically in simplices [5, 8]
#   T5 verts=[8, 6, 7, 4]: λ=[0.000020, 0.492729, 0.507250, 0.000001], LB=2.898567142, c_s=[0.9973768447429899, 0.9452021095722893, 0.9559881878396173]
#   T8 verts=[3, 6, 7, 8]: λ=[-0.000000, 0.492722, 0.507243, 0.000035], LB=2.898567277, c_s=[0.9973766885492271, 0.9452019456781853, 0.9559886427553811]
#
# == [Iter 1] CS DUAL vs PRIMAL diagnostic (simplices containing UB point) ==
#   --- T5 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(10.0, 99.99463340042628, 1.3957971124296873)
#              indep_Q(cs_K)=0.997376848
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(10.0, 99.92674406594791, 0.899243404642381)
#              indep_Q(cs_K)=0.945202110
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(10.0, 100.0, 2.030568687805298)
#              indep_Q(cs_K)=0.955988188
#   sum(c_s_dual)=0.000000000, UB_total=8.697260585, UB_per_scen=2.899086862
#
#   == Per-scenario Q_s at K_EF = (9.999999999898348, 99.99971012237032, 1.45213983251335) ==
#     scen 0: Q_s(K_EF)=0.997378833, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945445385, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.956262644, c_s_dual=N/A
#     SUM Q_s(K_EF)=2.899086862, sum(c_s)=0.000000000, diff=2.899087e+00
#   --- T8 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.998463107850093, 99.99864515026731, 1.3957952098010908)
#              indep_Q(cs_K)=0.997376690
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.97985581075986, 99.98170997309717, 0.8992800371262623)
#              indep_Q(cs_K)=0.945201946
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(10.0, 100.0, 2.007936507936508)
#              indep_Q(cs_K)=0.955988644
#   sum(c_s_dual)=0.000000000, UB_total=8.697260585, UB_per_scen=2.899086862
#
#   == Per-scenario Q_s at K_EF = (9.999999999898348, 99.99971012237032, 1.45213983251335) ==
#     scen 0: Q_s(K_EF)=0.997378833, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945445385, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.956262644, c_s_dual=N/A
#     SUM Q_s(K_EF)=2.899086862, sum(c_s)=0.000000000, diff=2.899087e+00
#
# [Iter 1] LB = 2.897512 = UB(2.899087) + ms_b(-1.773e+10) from T5
# [Iter 1] Scene 0: Switched to c_s point. dist_ms_c=1.90e+01 < 1000.0, dist_c_verts=8.35e+00 > 1e-06
# [Iter 1] Scene 1: Switched to c_s point. dist_ms_c=1.98e+01 < 1000.0, dist_c_verts=8.35e+00 > 1e-06
# [Iter 1] Scene 2: Switched to c_s point. dist_ms_c=2.01e+01 < 1000.0, dist_c_verts=8.30e+00 > 1e-06
# Chosen node (10.000000000000002, 99.9267440659479, 0.8992434046423766) with ms=-5.946e+09 (simp T5, scene 1, rank #1, source=c_s)
# [Iter 1] LB simplex = T5, next node simplex = T5, scene 1
# [Selected Simp Info] Iter 1 | Simplex T5 Vertices:
#   v0: (9.999994936241917, 91.70368911358257, 2.3482370383557245)
#   v1: (10.0, 100.0, -100.0)
#   v2: (10.0, 100.0, 100.0)
#   v3: (10.0, -100.0, -100.0)
#   -> New Point: (10.000000000000002, 99.9267440659479, 0.8992434046423766)
# [Iter 1] candidate rank #1: T5, scene=1, ms=-5.946e+09
# == ms candidates (sorted by (ms, -dist)) ==
# rank   simp   scene           ms    mind(all)                             pt
# ----------------------------------------------------------------------------
#    1     T5       1  -5.9465e+09     8.35e+00     (10.0000, 99.9267, 0.8992)
#    2     T5       2  -5.9031e+09     8.30e+00    (10.0000, 100.0000, 2.0306)
#    3     T5       0  -5.8784e+09     8.35e+00     (10.0000, 99.9946, 1.3958)
#
# [Iter 1] per_tet=9, active after q_cut=3, tri_is_None=False
# [Iter 1] bad-quality active simplices (q < 0): 0
# [Iter 1] evaluating Q for scenario 0
# [Iter 1] evaluating Q for scenario 1
# [Iter 1] evaluating Q for scenario 2
#
# [Iter 1] Next Point Details:
# Simplex   Scene   Type    As             ms             As+ms          Q              (Kp, Ki, Kd)
# --------------------------------------------------------------------------------------------------------------------
# T5        1       c_s     4.9514e+09     -5.9465e+09    -9.9509e+08    9.4520e-01     (10.0000, 99.9267, 0.8992)
#
# [Iter 1] subdivision type = face (code=3) on simplex T5
#            face local verts = (6, 7, 4)
# [Iter 1] Elapsed: 0.359s
# [Invariant] MS scen None: dual=-5.015785e+09 > primal=-5.015785e+09
# ======================================================================
# [Iter 1] LB SPLIT DIAGNOSTIC
#   Selected (parent) simplex: (4, 6, 7, 8)
#   Parent LB: 0.966189047 (per-scen)
#   EF ef_obj(IPOPT): 0.322120758, true_obj(recalc): 0.966362287, used=min=0.322120758 (per-scen)
#   Simplex volume: 3.375839e-02
#   Children (3):
#     T8 (4, 7, 8, 9): LB = 0.966192201
#     T9 (4, 6, 8, 9): LB = 0.966298344
#   New global LB: 0.965837399 (from T1 (0, 1, 3, 4))
#   Location: OUTSIDE
#   Avg CS point Q-value: 0.966363706 (per-scen), point=(np.float64(10.0), np.float64(99.9737924887914), np.float64(1.4418697349591223))
#   Current UB: 0.966362287 (per-scen)
#   UB point: (9.999999999898348, 99.99971012237032, 1.45213983251335)
#   UB source: EF_ipopt
#   UB simplex: (4, 6, 7, 8)
#   EF-IPOPT: ok=True, status=ok, term=optimal, time=0.133s, ef_obj=0.9663622738958584, true_obj(per-scen)=0.966362287
# ======================================================================
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 0.30158571125214, -100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 0.30158571125214, -100.0): status=warning, term=infeasibleOrUnbounded
#
# ======================================================================
# [TIMING] === Iter 1 phase breakdown (total 22.19s) ===
#   1_vertex_UB                    :       0.00s  (  0.0%)
#   2_evaluate_all_tetra           :       0.00s  (  0.0%)
#   3_active_filter_print          :       0.00s  (  0.0%)
#   4_LB_selection                 :       0.00s  (  0.0%)
#   5_EF_UB_solve                  :       0.32s  (  1.4%)
#   6_candidate_selection          :       0.00s  (  0.0%)
#   7_Q_eval_new_node              :       0.04s  (  0.2%)
#   8_mesh_subdivide               :       0.00s  (  0.0%)
#   9_end_of_iter_reeval           :      21.83s  ( 98.4%)  #################################################
#   TOTAL                          :      22.19s
#   #simplices=9, #scenarios=3, total_ms_pairs=27
#   fresh ms solves=0, cache hits=27
# ======================================================================
#
# [Iter 2] #simplices = 10, #active = 4, bad-quality cut = 0, bad-shape cut = 0
# == [Iter 2] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T1            9.658374e-01      4.116368e+09     -1.765089e+10      2.897512e+00     [6.69e+00, 3.00e+10]    [-1.77e+10, 1.23e+10]     1
# T7            9.661891e-01      4.238272e+09     -1.728518e+10      2.898567e+00     [2.90e+00, 3.00e+10]    [-1.73e+10, 1.27e+10]     1
# T8            9.661922e-01      1.327975e+00     -4.211143e+00      2.898577e+00     [2.90e+00, 8.20e+00]    [-1.31e+00, 3.98e+00]     0
# T9            9.662983e-01      4.984921e+09     -1.504524e+10      2.898895e+00     [2.90e+00, 3.00e+10]    [-1.50e+10, 1.50e+10]     1
#
# == [Iter 2] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.025632e+00      4.607881e+09     -1.617636e+10      3.076897e+00     [6.69e+00, 3.00e+10]    [-1.62e+10, 1.38e+10]     1
# T2            9.697088e-01      4.393099e+09     -1.682070e+10      2.909126e+00     [6.56e+00, 3.00e+10]    [-1.68e+10, 1.32e+10]     1
# T3            9.755887e-01      4.270667e+09     -1.718800e+10      2.926766e+00     [8.03e+00, 3.00e+10]    [-1.72e+10, 1.28e+10]     2
# T4            9.671093e-01               inf               inf      2.901328e+00     [8.03e+00, 3.00e+10]               [inf, inf]     2
# T5            9.679638e-01      1.288643e+00     -4.329139e+00      2.903892e+00     [2.90e+00, 8.20e+00]    [-1.43e+00, 3.87e+00]     0
# T6            9.672097e-01      4.434713e+09     -1.669586e+10      2.901629e+00     [2.90e+00, 3.00e+10]    [-1.67e+10, 1.33e+10]     1
#
# [Iter 2] created=10 (cum=31), active=4, active+UB=2, ms_recomputed=0
# [Iter 2] UB-simplex selection: UB_node in simplices [7, 8, 9], chose T7 (LB=0.966189092)
# [Iter 2] EF-ipopt: ok=True, ef_obj=0.9663622839551342, true_obj=9.663623e-01, time=0.099s
# [Iter 2] Pre-split gap: 1.574666e-03 (0.054%)
# [Iter 2] Active simplex ratio = 0.173580
# [Iter 2] UB point (10.000000000000002, 99.9267440659479, 0.8992434046423766) is geometrically in simplices [7, 8, 9]
#   T7 verts=[3, 6, 7, 8]: λ=[-0.000000, 0.491192, 0.499978, 0.008830], LB=2.898567277, c_s=[0.9973766885492271, 0.9452019456781853, 0.9559886427553811]
#   T8 verts=[9, 7, 4, 8]: λ=[1.000000, 0.000000, -0.000000, -0.000000], LB=2.898576604, c_s=[0.9973850650522763, 0.9452021139963319, 0.9559894249876546]
#   T9 verts=[6, 9, 4, 8]: λ=[0.000000, 1.000000, 0.000000, -0.000000], LB=2.898895032, c_s=[0.9975885276858524, 0.945202108317453, 0.9561043962253545]
#
# == [Iter 2] CS DUAL vs PRIMAL diagnostic (simplices containing UB point) ==
#   --- T7 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.998463107850093, 99.99864515026731, 1.3957952098010908)
#              indep_Q(cs_K)=0.997376690
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.97985581075986, 99.98170997309717, 0.8992800371262623)
#              indep_Q(cs_K)=0.945201946
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(10.0, 100.0, 2.007936507936508)
#              indep_Q(cs_K)=0.955988644
#   sum(c_s_dual)=0.000000000, UB_total=8.697260585, UB_per_scen=2.899086862
#
#   == Per-scenario Q_s at K_EF = (10.000000000000002, 99.9267440659479, 0.8992434046423766) ==
#     scen 0: Q_s(K_EF)=0.997594012, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945202110, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.957070715, c_s_dual=N/A
#     SUM Q_s(K_EF)=2.899866837, sum(c_s)=0.000000000, diff=2.899867e+00
#   --- T8 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.999999999986626, 99.92708993913512, 1.395934267438398)
#              indep_Q(cs_K)=0.997385066
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.999999999813365, 99.9263184303117, 0.9000962699515981)
#              indep_Q(cs_K)=0.945202115
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.999999999924633, 99.92744412680513, 2.031875353276053)
#              indep_Q(cs_K)=0.955989427
#   sum(c_s_dual)=0.000000000, UB_total=8.697260585, UB_per_scen=2.899086862
#
#   == Per-scenario Q_s at K_EF = (10.000000000000002, 99.9267440659479, 0.8992434046423766) ==
#     scen 0: Q_s(K_EF)=0.997594012, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945202110, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.957070715, c_s_dual=N/A
#     SUM Q_s(K_EF)=2.899866837, sum(c_s)=0.000000000, diff=2.899867e+00
#   --- T9 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(10.0, 99.47571962356538, 0.9787189218859279)
#              indep_Q(cs_K)=0.997588547
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(10.0, 99.92674445120517, 0.8987127695814882)
#              indep_Q(cs_K)=0.945202110
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(10.0, 93.91620227231627, 1.958367640658221)
#              indep_Q(cs_K)=0.956104398
#   sum(c_s_dual)=0.000000000, UB_total=8.697260585, UB_per_scen=2.899086862
#
#   == Per-scenario Q_s at K_EF = (10.000000000000002, 99.9267440659479, 0.8992434046423766) ==
#     scen 0: Q_s(K_EF)=0.997594012, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945202110, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.957070715, c_s_dual=N/A
#     SUM Q_s(K_EF)=2.899866837, sum(c_s)=0.000000000, diff=2.899867e+00
#
# [Iter 2] LB = 2.897512 = UB(2.899087) + ms_b(-1.729e+10) from T7
# [Iter 2] Scene 0: Switched to c_s point. dist_ms_c=1.83e+01 < 1000.0, dist_c_verts=8.35e+00 > 1e-06
# [Iter 2] Scene 1: Switched to c_s point. dist_ms_c=1.80e+01 < 1000.0, dist_c_verts=8.40e+00 > 1e-06
# [Iter 2] Scene 2: Switched to c_s point. dist_ms_c=1.80e+01 < 1000.0, dist_c_verts=8.30e+00 > 1e-06
# Chosen node (9.97985581075986, 99.98170997309717, 0.8992800371262623) with ms=-5.854e+09 (simp T7, scene 1, rank #1, source=c_s)
# [Iter 2] LB simplex = T7, next node simplex = T7, scene 1
# [Selected Simp Info] Iter 2 | Simplex T7 Vertices:
#   v0: (-10.0, 100.0, 100.0)
#   v1: (10.0, 100.0, -100.0)
#   v2: (10.0, 100.0, 100.0)
#   v3: (9.999994936241917, 91.70368911358257, 2.3482370383557245)
#   -> New Point: (9.97985581075986, 99.98170997309717, 0.8992800371262623)
# [Iter 2] candidate rank #1: T7, scene=1, ms=-5.854e+09
# == ms candidates (sorted by (ms, -dist)) ==
# rank   simp   scene           ms    mind(all)                             pt
# ----------------------------------------------------------------------------
#    1     T7       1  -5.8536e+09     5.85e-02      (9.9799, 99.9817, 0.8993)
#    2     T7       0  -5.7428e+09     5.02e-01      (9.9985, 99.9986, 1.3958)
#    3     T7       2  -5.6888e+09     1.11e+00    (10.0000, 100.0000, 2.0079)
#
# [Iter 2] per_tet=10, active after q_cut=4, tri_is_None=False
# [Iter 2] bad-quality active simplices (q < 0): 0
# [Iter 2] evaluating Q for scenario 0
# [Iter 2] evaluating Q for scenario 1
# [Iter 2] evaluating Q for scenario 2
#
# [Iter 2] Next Point Details:
# Simplex   Scene   Type    As             ms             As+ms          Q              (Kp, Ki, Kd)
# --------------------------------------------------------------------------------------------------------------------
# T7        1       c_s     4.9443e+09     -5.8536e+09    -9.0934e+08    9.4520e-01     (9.9799, 99.9817, 0.8993)
#
# [Iter 2] subdivision type = interior (code=1) on simplex T7
# [Iter 2] Elapsed: 0.354s
# [Invariant] MS scen None: dual=-5.886004e+09 > primal=-5.886004e+09
# [Invariant] MS scen None: dual=-5.860693e+09 > primal=-5.860693e+09
# [Invariant] MS scen None: dual=-5.711362e+09 > primal=-5.711362e+09
# [Invariant] MS scen None: dual=-5.831300e+09 > primal=-5.831300e+09
# [Invariant] MS scen None: dual=-5.829068e+09 > primal=-5.829068e+09
# [Invariant] MS scen None: dual=-5.676560e+09 > primal=-5.676560e+09
# ======================================================================
# [Iter 2] LB SPLIT DIAGNOSTIC
#   Selected (parent) simplex: (3, 6, 7, 8)
#   Parent LB: 0.966189092 (per-scen)
#   EF ef_obj(IPOPT): 0.322120761, true_obj(recalc): 0.966362297, used=min=0.322120761 (per-scen)
#   Simplex volume: 5.530874e+03
#   Children (4):
#     T10 (6, 7, 8, 10): LB = 0.966188775
#     T11 (3, 7, 8, 10): LB = 0.966191209
#     T12 (3, 6, 8, 10): LB = 0.966200046
#     T13 (3, 6, 7, 10): LB = 0.966190976
#   New global LB: 0.965837399 (from T1 (0, 1, 3, 4))
#   Location: OUTSIDE
#   Avg CS point Q-value: 0.966363516 (per-scen), point=(np.float64(9.992772972869984), np.float64(99.99345170778815), np.float64(1.434337251621287))
#   Current UB: 0.966362287 (per-scen)
#   UB point: (10.000000000000002, 99.9267440659479, 0.8992434046423766)
#   UB source: unknown
#   UB simplex: None
#   EF-IPOPT: ok=True, status=ok, term=optimal, time=0.099s, ef_obj=0.9663622839551342, true_obj(per-scen)=0.966362297
# ======================================================================
#
# ======================================================================
# [TIMING] === Iter 2 phase breakdown (total 30.44s) ===
#   1_vertex_UB                    :       0.00s  (  0.0%)
#   2_evaluate_all_tetra           :       0.00s  (  0.0%)
#   3_active_filter_print          :       0.00s  (  0.0%)
#   4_LB_selection                 :       0.00s  (  0.0%)
#   5_EF_UB_solve                  :       0.32s  (  1.1%)
#   6_candidate_selection          :       0.00s  (  0.0%)
#   7_Q_eval_new_node              :       0.03s  (  0.1%)
#   8_mesh_subdivide               :       0.00s  (  0.0%)
#   9_end_of_iter_reeval           :      30.09s  ( 98.8%)  #################################################
#   TOTAL                          :      30.44s
#   #simplices=10, #scenarios=3, total_ms_pairs=30
#   fresh ms solves=0, cache hits=30
# ======================================================================
#
# [Iter 3] #simplices = 13, #active = 7, bad-quality cut = 0, bad-shape cut = 0
# == [Iter 3] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T1            9.658374e-01      4.116368e+09     -1.765089e+10      2.897512e+00     [6.69e+00, 3.00e+10]    [-1.77e+10, 1.23e+10]     1
# T7            9.661922e-01      1.327975e+00     -4.211143e+00      2.898577e+00     [2.90e+00, 8.20e+00]    [-1.31e+00, 3.98e+00]     0
# T8            9.662983e-01      4.984921e+09     -1.504524e+10      2.898895e+00     [2.90e+00, 3.00e+10]    [-1.50e+10, 1.50e+10]     1
# T10           9.661888e-01      4.116718e+09     -1.764985e+10      2.898566e+00     [2.90e+00, 3.00e+10]    [-1.76e+10, 1.24e+10]     1
# T11           9.661912e-01      2.448693e+00     -6.823964e-01      2.898574e+00     [2.90e+00, 8.03e+00]     [2.22e+00, 7.35e+00]     0
# T12           9.662000e-01      4.286184e+09     -1.714145e+10      2.898600e+00     [2.90e+00, 3.00e+10]    [-1.71e+10, 1.29e+10]     1
# T13           9.661910e-01      4.221024e+09     -1.733693e+10      2.898573e+00     [2.90e+00, 3.00e+10]    [-1.73e+10, 1.27e+10]     1
#
# == [Iter 3] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.025632e+00      4.607881e+09     -1.617636e+10      3.076897e+00     [6.69e+00, 3.00e+10]    [-1.62e+10, 1.38e+10]     1
# T2            9.697088e-01      4.393099e+09     -1.682070e+10      2.909126e+00     [6.56e+00, 3.00e+10]    [-1.68e+10, 1.32e+10]     1
# T3            9.755887e-01      4.270667e+09     -1.718800e+10      2.926766e+00     [8.03e+00, 3.00e+10]    [-1.72e+10, 1.28e+10]     2
# T4            9.671093e-01               inf               inf      2.901328e+00     [8.03e+00, 3.00e+10]               [inf, inf]     2
# T5            9.679638e-01      1.288643e+00     -4.329139e+00      2.903892e+00     [2.90e+00, 8.20e+00]    [-1.43e+00, 3.87e+00]     0
# T6            9.672097e-01      4.434713e+09     -1.669586e+10      2.901629e+00     [2.90e+00, 3.00e+10]    [-1.67e+10, 1.33e+10]     1
#
# [Iter 3] created=13 (cum=48), active=7, active+UB=4, ms_recomputed=0
# [Iter 3] UB-simplex selection: UB_node in simplices [10, 11, 12, 13], chose T10 (LB=0.966188775)
# [Iter 3] EF-ipopt: ok=True, ef_obj=0.966362283916889, true_obj=9.663623e-01, time=0.125s
# [Iter 3] Pre-split gap: 1.574666e-03 (0.054%)
# [Iter 3] Active simplex ratio = 0.173580
# [Iter 3] UB point (9.97985581075986, 99.98170997309717, 0.8992800371262623) is geometrically in simplices [10, 11, 12, 13]
#   T10 verts=[10, 6, 7, 8]: λ=[1.000000, -0.000000, 0.000000, -0.000000], LB=2.898566325, c_s=[0.9973761989526582, 0.9452014558034774, 0.9559886706084623]
#   T11 verts=[3, 10, 7, 8]: λ=[0.000000, 1.000000, 0.000000, -0.000000], LB=2.898573628, c_s=[0.9973827132282013, 0.9452019456933605, 0.955988969035612]
#   T12 verts=[3, 6, 10, 8]: λ=[0.000000, -0.000000, 1.000000, -0.000000], LB=2.898600139, c_s=[0.9974037795895995, 0.9452019500802914, 0.9559944089175979]
#   T13 verts=[3, 6, 7, 10]: λ=[0.000000, -0.000000, 0.000000, 1.000000], LB=2.898572929, c_s=[0.9973820181249868, 0.9452019462685444, 0.9559889643968523]
#
# == [Iter 3] CS DUAL vs PRIMAL diagnostic (simplices containing UB point) ==
#   --- T10 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.999993525207769, 99.99998029988635, 1.3957906527654853)
#              indep_Q(cs_K)=0.997376199
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.999944275953805, 99.99965583082064, 0.8992689418724734)
#              indep_Q(cs_K)=0.945201456
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.995256778001862, 99.97820597257463, 2.0319375121805607)
#              indep_Q(cs_K)=0.955988672
#   sum(c_s_dual)=0.000000000, UB_total=8.697260585, UB_per_scen=2.899086862
#
#   == Per-scenario Q_s at K_EF = (9.97985581075986, 99.98170997309717, 0.8992800371262623) ==
#     scen 0: Q_s(K_EF)=0.997591553, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945201946, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.957070028, c_s_dual=N/A
#     SUM Q_s(K_EF)=2.899863528, sum(c_s)=0.000000000, diff=2.899864e+00
#   --- T11 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.979957055125166, 99.98180189847292, 1.3973586331097592)
#              indep_Q(cs_K)=0.997382718
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.97985581221421, 99.98170997441765, 0.8992871918930416)
#              indep_Q(cs_K)=0.945201946
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.980043801938642, 99.98186001378026, 2.0319327873402786)
#              indep_Q(cs_K)=0.955988970
#   sum(c_s_dual)=0.000000000, UB_total=8.697260585, UB_per_scen=2.899086862
#
#   == Per-scenario Q_s at K_EF = (9.97985581075986, 99.98170997309717, 0.8992800371262623) ==
#     scen 0: Q_s(K_EF)=0.997591553, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945201946, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.957070028, c_s_dual=N/A
#     SUM Q_s(K_EF)=2.899863528, sum(c_s)=0.000000000, diff=2.899864e+00
#   --- T12 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.884886997023155, 99.98178832666571, 1.369711410350748)
#              indep_Q(cs_K)=0.997403847
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.979721987722533, 99.98153946045157, 0.8983843602004403)
#              indep_Q(cs_K)=0.945201951
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.752117096248302, 99.98188114154262, 2.028644820936233)
#              indep_Q(cs_K)=0.955994409
#   sum(c_s_dual)=0.000000000, UB_total=8.697260585, UB_per_scen=2.899086862
#
#   == Per-scenario Q_s at K_EF = (9.97985581075986, 99.98170997309717, 0.8992800371262623) ==
#     scen 0: Q_s(K_EF)=0.997591553, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945201946, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.957070028, c_s_dual=N/A
#     SUM Q_s(K_EF)=2.899863528, sum(c_s)=0.000000000, diff=2.899864e+00
#   --- T13 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(10.0, 100.0, 1.4801694937814815)
#              indep_Q(cs_K)=0.997382027
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.979812052861538, 99.98172581887074, 0.8993051104320116)
#              indep_Q(cs_K)=0.945201947
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.980085886862788, 99.9819188719544, 2.031155198563493)
#              indep_Q(cs_K)=0.955988968
#   sum(c_s_dual)=0.000000000, UB_total=8.697260585, UB_per_scen=2.899086862
#
#   == Per-scenario Q_s at K_EF = (9.97985581075986, 99.98170997309717, 0.8992800371262623) ==
#     scen 0: Q_s(K_EF)=0.997591553, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945201946, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.957070028, c_s_dual=N/A
#     SUM Q_s(K_EF)=2.899863528, sum(c_s)=0.000000000, diff=2.899864e+00
#
# [Iter 3] LB = 2.897512 = UB(2.899087) + ms_b(-1.765e+10) from T10
# [Iter 3] Scene 0: Switched to c_s point. dist_ms_c=1.91e+01 < 1000.0, dist_c_verts=4.97e-01 > 1e-06
# [Iter 3] Scene 1: Switched to c_s point. dist_ms_c=1.90e+01 < 1000.0, dist_c_verts=2.69e-02 > 1e-06
# [Iter 3] Scene 2: Switched to c_s point. dist_ms_c=1.92e+01 < 1000.0, dist_c_verts=1.13e+00 > 1e-06
# Chosen node (9.999944275953805, 99.99965583082064, 0.8992689418724734) with ms=-5.903e+09 (simp T10, scene 1, rank #1, source=c_s)
# [Iter 3] LB simplex = T10, next node simplex = T10, scene 1
# [Selected Simp Info] Iter 3 | Simplex T10 Vertices:
#   v0: (9.97985581075986, 99.98170997309717, 0.8992800371262623)
#   v1: (10.0, 100.0, -100.0)
#   v2: (10.0, 100.0, 100.0)
#   v3: (9.999994936241917, 91.70368911358257, 2.3482370383557245)
#   -> New Point: (9.999944275953805, 99.99965583082064, 0.8992689418724734)
# [Iter 3] candidate rank #1: T10, scene=1, ms=-5.903e+09
# == ms candidates (sorted by (ms, -dist)) ==
# rank   simp   scene           ms    mind(all)                             pt
# ----------------------------------------------------------------------------
#    1    T10       1  -5.9031e+09     2.69e-02      (9.9999, 99.9997, 0.8993)
#    2    T10       0  -5.8860e+09     4.97e-01    (10.0000, 100.0000, 1.3958)
#    3    T10       2  -5.8607e+09     1.13e+00      (9.9953, 99.9782, 2.0319)
#
# [Iter 3] per_tet=13, active after q_cut=7, tri_is_None=False
# [Iter 3] bad-quality active simplices (q < 0): 0
# [Iter 3] evaluating Q for scenario 0
# [Iter 3] evaluating Q for scenario 1
# [Iter 3] evaluating Q for scenario 2
#
# [Iter 3] Next Point Details:
# Simplex   Scene   Type    As             ms             As+ms          Q              (Kp, Ki, Kd)
# --------------------------------------------------------------------------------------------------------------------
# T10       1       c_s     4.9412e+09     -5.9031e+09    -9.6199e+08    9.4520e-01     (9.9999, 99.9997, 0.8993)
#
# [Iter 3] subdivision type = interior (code=1) on simplex T10
# [Iter 3] Elapsed: 0.477s
# [Invariant] MS scen None: dual=-1.903107e+09 > primal=-1.903107e+09
# [Invariant] MS scen None: dual=-1.938398e+09 > primal=-1.938398e+09
# [Invariant] MS scen None: dual=-1.886224e+09 > primal=-1.886224e+09
# ======================================================================
# [Iter 3] LB SPLIT DIAGNOSTIC
#   Selected (parent) simplex: (6, 7, 8, 10)
#   Parent LB: 0.966188775 (per-scen)
#   EF ef_obj(IPOPT): 0.322120761, true_obj(recalc): 0.966362297, used=min=0.322120761 (per-scen)
#   Simplex volume: 5.570745e+00
#   Children (4):
#     T13 (6, 7, 8, 11): LB = 0.966188758
#     T14 (7, 8, 10, 11): LB = 0.966188636
#     T15 (6, 8, 10, 11): LB = 0.966295093
#     T16 (6, 7, 10, 11): LB = 0.966188774
#   New global LB: 0.965837399 (from T1 (0, 1, 3, 4))
#   Location: OUTSIDE
#   Avg CS point Q-value: 0.966362869 (per-scen), point=(np.float64(9.998398193054477), np.float64(99.9926140344272), np.float64(1.4423323689395062))
#   Current UB: 0.966362287 (per-scen)
#   UB point: (9.97985581075986, 99.98170997309717, 0.8992800371262623)
#   UB source: unknown
#   UB simplex: None
#   EF-IPOPT: ok=True, status=ok, term=optimal, time=0.125s, ef_obj=0.966362283916889, true_obj(per-scen)=0.966362297
# ======================================================================
# [BaseBundle.eval_at] Infeasible/Error for K=(9.999131441769519, 97.94752698729765, -18.006551606476688): status=warning, term=infeasibleOrUnbounded
#
# ======================================================================
# [TIMING] === Iter 3 phase breakdown (total 21.01s) ===
#   1_vertex_UB                    :       0.00s  (  0.0%)
#   2_evaluate_all_tetra           :       0.00s  (  0.0%)
#   3_active_filter_print          :       0.00s  (  0.0%)
#   4_LB_selection                 :       0.00s  (  0.0%)
#   5_EF_UB_solve                  :       0.42s  (  2.0%)
#   6_candidate_selection          :       0.00s  (  0.0%)
#   7_Q_eval_new_node              :       0.05s  (  0.3%)
#   8_mesh_subdivide               :       0.00s  (  0.0%)
#   9_end_of_iter_reeval           :      20.53s  ( 97.7%)  ################################################
#   TOTAL                          :      21.01s
#   #simplices=13, #scenarios=3, total_ms_pairs=39
#   fresh ms solves=0, cache hits=39
# ======================================================================
#
# [Iter 4] #simplices = 16, #active = 10, bad-quality cut = 0, bad-shape cut = 0
# == [Iter 4] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T1            9.658374e-01      4.116368e+09     -1.765089e+10      2.897512e+00     [6.69e+00, 3.00e+10]    [-1.77e+10, 1.23e+10]     1
# T7            9.661922e-01      1.327975e+00     -4.211143e+00      2.898577e+00     [2.90e+00, 8.20e+00]    [-1.31e+00, 3.98e+00]     0
# T8            9.662983e-01      4.984921e+09     -1.504524e+10      2.898895e+00     [2.90e+00, 3.00e+10]    [-1.50e+10, 1.50e+10]     1
# T10           9.661912e-01      2.448693e+00     -6.823964e-01      2.898574e+00     [2.90e+00, 8.03e+00]     [2.22e+00, 7.35e+00]     0
# T11           9.662000e-01      4.286184e+09     -1.714145e+10      2.898600e+00     [2.90e+00, 3.00e+10]    [-1.71e+10, 1.29e+10]     1
# T12           9.661910e-01      4.221024e+09     -1.733693e+10      2.898573e+00     [2.90e+00, 3.00e+10]    [-1.73e+10, 1.27e+10]     1
# T13           9.661888e-01      4.116580e+09     -1.765026e+10      2.898566e+00     [2.90e+00, 3.00e+10]    [-1.77e+10, 1.23e+10]     1
# T14           9.661886e-01      2.084368e+00     -3.082257e-01      2.898566e+00     [2.90e+00, 6.56e+00]     [2.59e+00, 6.25e+00]     0
# T15           9.662951e-01      8.090757e+09     -5.727730e+09      2.898885e+00     [2.90e+00, 3.00e+10]    [-5.73e+09, 2.43e+10]     1
# T16           9.661888e-01      4.118309e+09     -1.764507e+10      2.898566e+00     [2.90e+00, 3.00e+10]    [-1.76e+10, 1.24e+10]     1
#
# == [Iter 4] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.025632e+00      4.607881e+09     -1.617636e+10      3.076897e+00     [6.69e+00, 3.00e+10]    [-1.62e+10, 1.38e+10]     1
# T2            9.697088e-01      4.393099e+09     -1.682070e+10      2.909126e+00     [6.56e+00, 3.00e+10]    [-1.68e+10, 1.32e+10]     1
# T3            9.755887e-01      4.270667e+09     -1.718800e+10      2.926766e+00     [8.03e+00, 3.00e+10]    [-1.72e+10, 1.28e+10]     2
# T4            9.671093e-01               inf               inf      2.901328e+00     [8.03e+00, 3.00e+10]               [inf, inf]     2
# T5            9.679638e-01      1.288643e+00     -4.329139e+00      2.903892e+00     [2.90e+00, 8.20e+00]    [-1.43e+00, 3.87e+00]     0
# T6            9.672097e-01      4.434713e+09     -1.669586e+10      2.901629e+00     [2.90e+00, 3.00e+10]    [-1.67e+10, 1.33e+10]     1
#
# [Iter 4] created=16 (cum=68), active=10, active+UB=4, ms_recomputed=0
# [Iter 4] UB-simplex selection: UB_node in simplices [13, 14, 15, 16], chose T14 (LB=0.966188636)
# [Iter 4] EF-ipopt: ok=True, ef_obj=0.9663622849861244, true_obj=9.663623e-01, time=0.088s
# [Iter 4] Pre-split gap: 1.574666e-03 (0.054%)
# [Iter 4] Active simplex ratio = 0.173580
# [Iter 4] UB point (9.999944275953805, 99.99965583082064, 0.8992689418724734) is geometrically in simplices [13, 14, 15, 16]
#   T13 verts=[11, 6, 7, 8]: λ=[1.000000, -0.000000, 0.000000, 0.000000], LB=2.898566274, c_s=[0.9973761989205262, 0.9452015585083874, 0.9559885162199271]
#   T14 verts=[10, 11, 7, 8]: λ=[0.000000, 1.000000, 0.000000, -0.000000], LB=2.898565909, c_s=[0.9973762514160197, 0.9452014609048723, 0.9559881967187055]
#   T15 verts=[10, 6, 11, 8]: λ=[0.000000, -0.000000, 1.000000, -0.000000], LB=2.898885278, c_s=[0.9975798036330223, 0.9452014609647836, 0.9561040134018092]
#   T16 verts=[10, 6, 7, 11]: λ=[0.000000, 0.000000, 0.000000, 1.000000], LB=2.898566322, c_s=[0.9973766300066979, 0.9452015005201594, 0.9559881916305263]
#
# == [Iter 4] CS DUAL vs PRIMAL diagnostic (simplices containing UB point) ==
#   --- T13 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.999997680505992, 99.99997322273305, 1.3957906523595214)
#              indep_Q(cs_K)=0.997376199
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.999944282124414, 99.99965586893227, 0.8880958481362792)
#              indep_Q(cs_K)=0.945201559
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.999980203862682, 99.9806906682163, 2.0319462731463473)
#              indep_Q(cs_K)=0.955988518
#   sum(c_s_dual)=0.000000000, UB_total=8.697260585, UB_per_scen=2.899086862
#
#   == Per-scenario Q_s at K_EF = (9.999944275953805, 99.99965583082064, 0.8992689418724734) ==
#     scen 0: Q_s(K_EF)=0.997584806, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945201456, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.957068342, c_s_dual=N/A
#     SUM Q_s(K_EF)=2.899854604, sum(c_s)=0.000000000, diff=2.899855e+00
#   --- T14 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.999939241802851, 99.9996445827714, 1.3957945606265523)
#              indep_Q(cs_K)=0.997376251
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.999828077182663, 99.99941691763159, 0.9004033642380893)
#              indep_Q(cs_K)=0.945201461
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.99989922037625, 99.99953049210153, 2.0319778510874986)
#              indep_Q(cs_K)=0.955988198
#   sum(c_s_dual)=0.000000000, UB_total=8.697260585, UB_per_scen=2.899086862
#
#   == Per-scenario Q_s at K_EF = (9.999944275953805, 99.99965583082064, 0.8992689418724734) ==
#     scen 0: Q_s(K_EF)=0.997584806, c_s_dual=N/A
# ...
# T37           9.661886e-01      4.116580e+09     -1.765026e+10      2.898566e+00     [2.90e+00, 3.00e+10]    [-1.77e+10, 1.23e+10]     1
# T40           9.661888e-01      4.118309e+09     -1.764507e+10      2.898566e+00     [2.90e+00, 3.00e+10]    [-1.76e+10, 1.24e+10]     1
# T42           9.662194e-01      9.670816e-01     -1.418702e-03      2.898658e+00     [2.90e+00, 2.90e+00]     [2.90e+00, 2.90e+00]     0
# T45           9.662195e-01      9.670818e-01     -1.418210e-03      2.898658e+00     [2.90e+00, 2.90e+00]     [2.90e+00, 2.90e+00]     0
# T102          9.661888e-01      9.670818e-01     -1.418209e-03      2.898567e+00     [2.90e+00, 2.90e+00]     [2.90e+00, 2.90e+00]     0
# T111          9.658212e-01      2.507101e+00     -6.737667e-01      2.897464e+00     [2.90e+00, 8.20e+00]     [2.22e+00, 7.52e+00]     0
# T142          9.660425e-01      8.203030e+09     -5.390911e+09      2.898127e+00     [2.90e+00, 3.00e+10]    [-5.39e+09, 2.46e+10]     1
# T147          9.658872e-01      2.508340e+00     -6.700494e-01      2.897661e+00     [2.90e+00, 8.20e+00]     [2.23e+00, 7.53e+00]     0
# T150          9.658878e-01      2.508351e+00     -6.700162e-01      2.897664e+00     [2.90e+00, 8.20e+00]     [2.23e+00, 7.53e+00]     0
# T153          9.658878e-01      2.508351e+00     -6.700165e-01      2.897664e+00     [2.90e+00, 8.20e+00]     [2.23e+00, 7.53e+00]     0
# T161          9.658877e-01      2.508348e+00     -6.700242e-01      2.897663e+00     [2.90e+00, 8.20e+00]     [2.23e+00, 7.53e+00]     0
# T175          9.658878e-01      2.508350e+00     -6.700171e-01      2.897664e+00     [2.90e+00, 8.20e+00]     [2.23e+00, 7.53e+00]     0
# T178          9.658878e-01      2.508351e+00     -6.700167e-01      2.897664e+00     [2.90e+00, 8.20e+00]     [2.23e+00, 7.53e+00]     0
# T222          9.658212e-01      2.507101e+00     -6.737667e-01      2.897464e+00     [2.90e+00, 8.20e+00]     [2.22e+00, 7.52e+00]     0
#
# [Iter 82] created=45 (cum=2822), active=12, active+UB=0, ms_recomputed=0
# [Iter 82] UB-simplex selection: UB_node OUTSIDE mesh, fallback to min-LB simplex T231 (LB=0.965687231)
# [Iter 82] EF-ipopt: ok=True, ef_obj=0.9658017940938889, true_obj=9.658018e-01, time=0.152s
# [Iter 82] Pre-split gap: 3.436281e-04 (0.012%)
# [Iter 82] Active simplex ratio = 0.166667
# [Iter 82] UB point (-9.999983705753847, -99.99997783789564, 0.9388390879139868) is NOT inside any simplex (outside mesh)
# [Iter 82] LB = 2.897062 = UB(2.897405) + ms_b(-6.926e-01) from T231
# [Iter 82] Scene 0: Switched to c_s point. dist_ms_c=4.36e+01 < 1000.0, dist_c_verts=1.12e-03 > 1e-06
# [Iter 82] Scene 1: Switched to c_s point. dist_ms_c=4.35e+01 < 1000.0, dist_c_verts=2.57e-04 > 1e-06
# [Iter 82] Scene 2: Switched to c_s point. dist_ms_c=4.57e+01 < 1000.0, dist_c_verts=1.67e-03 > 1e-06
# Chosen node (-9.994465183034196, -99.99999547874349, 0.7911138486440012) with ms=-2.362e-01 (simp T231, scene 1, rank #1, source=c_s)
# [Iter 82] LB simplex = T231, next node simplex = T231, scene 1
# [Selected Simp Info] Iter 82 | Simplex T231 Vertices:
#   v0: (-9.999876178976505, -99.99999886640641, 1.6482323763638749)
#   v1: (10.0, -100.0, -100.0)
#   v2: (-9.994722124023106, -99.9999955820031, 0.7911090664996759)
#   v3: (-9.998830913234869, -99.9999808381837, 0.9388260736070384)
#   -> New Point: (-9.994465183034196, -99.99999547874349, 0.7911138486440012)
# [Iter 82] candidate rank #1: T231, scene=1, ms=-2.362e-01
# == ms candidates (sorted by (ms, -dist)) ==
# rank   simp   scene           ms    mind(all)                             pt
# ----------------------------------------------------------------------------
#    1   T231       1  -2.3623e-01     2.57e-04   (-9.9945, -100.0000, 0.7911)
#    2   T231       0  -2.3483e-01     1.12e-03   (-9.9988, -100.0000, 0.9399)
#    3   T231       2  -2.2154e-01     1.67e-03   (-9.9998, -100.0000, 1.6466)
#
# [Iter 82] per_tet=45, active after q_cut=12, tri_is_None=False
# [Iter 82] bad-quality active simplices (q < 0): 0
# [Iter 82] evaluating Q for scenario 0
# [Iter 82] evaluating Q for scenario 1
# [Iter 82] evaluating Q for scenario 2
#
# [Iter 82] Next Point Details:
# Simplex   Scene   Type    As             ms             As+ms          Q              (Kp, Ki, Kd)
# --------------------------------------------------------------------------------------------------------------------
# T231      1       c_s     9.4515e-01     -2.3623e-01    7.0892e-01     9.4513e-01     (-9.9945, -100.0000, 0.7911)
#
# [Iter 82] subdivision type = interior (code=1) on simplex T231
# [Iter 82] Elapsed: 0.255s
# ======================================================================
# [Iter 82] LB SPLIT DIAGNOSTIC
#   Selected (parent) simplex: (4, 44, 45, 89)
#   Parent LB: 0.965687231 (per-scen)
#   EF ef_obj(IPOPT): 0.321933931, true_obj(recalc): 0.965801831, used=min=0.321933931 (per-scen)
#   Simplex volume: 4.222465e-05
#   Children (4):
#     T234 (4, 44, 45, 90): LB = 0.965687232
#   New global LB: 0.965687232 (from T234 (4, 44, 45, 90))
#   Location: INSIDE
#   Avg CS point Q-value: 0.965802019 (per-scen), point=(np.float64(-9.997701819243993), np.float64(-99.99999174316906), np.float64(1.125875530192001))
#   Current UB: 0.965801773 (per-scen)
#   UB point: (-9.999983705753847, -99.99997783789564, 0.9388390879139868)
#   UB source: avgCS_new_simplex
#   UB simplex: (0, 4, 45, 66)
#   EF-IPOPT: ok=True, status=ok, term=optimal, time=0.152s, ef_obj=0.9658017940938889, true_obj(per-scen)=0.965801831
# ======================================================================
#
# ======================================================================
# [TIMING] === Iter 82 phase breakdown (total 5.42s) ===
#   1_vertex_UB                    :       0.00s  (  0.0%)
#   2_evaluate_all_tetra           :       0.01s  (  0.2%)
#   3_active_filter_print          :       0.00s  (  0.1%)
#   4_LB_selection                 :       0.00s  (  0.0%)
#   5_EF_UB_solve                  :       0.20s  (  3.6%)  #
#   6_candidate_selection          :       0.00s  (  0.0%)
#   7_Q_eval_new_node              :       0.04s  (  0.7%)
#   8_mesh_subdivide               :       0.00s  (  0.0%)
#   9_end_of_iter_reeval           :       5.17s  ( 95.3%)  ###############################################
#   TOTAL                          :       5.42s
#   #simplices=45, #scenarios=3, total_ms_pairs=135
#   fresh ms solves=0, cache hits=135
# ======================================================================
#
# [Iter 83] #simplices = 45, #active = 12, bad-quality cut = 0, bad-shape cut = 0
# == [Iter 83] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T105          9.656881e-01      1.334575e+00     -4.191343e+00      2.897064e+00     [2.90e+00, 8.20e+00]    [-1.29e+00, 4.00e+00]     0
# T106          9.656874e-01      4.026941e+09     -1.791918e+10      2.897062e+00     [2.90e+00, 3.00e+10]    [-1.79e+10, 1.21e+10]     1
# T107          9.656987e-01      4.154166e+09     -1.753750e+10      2.897096e+00     [2.90e+00, 3.00e+10]    [-1.75e+10, 1.25e+10]     1
# T108          9.656874e-01      4.255454e+09     -1.723364e+10      2.897062e+00     [2.90e+00, 3.00e+10]    [-1.72e+10, 1.28e+10]     1
# T110          9.656874e-01      4.283531e+09     -1.714941e+10      2.897062e+00     [2.90e+00, 3.00e+10]    [-1.71e+10, 1.29e+10]     1
# T130          9.656873e-01      2.127489e+00     -3.109740e-01      2.897062e+00     [2.90e+00, 6.69e+00]     [2.59e+00, 6.38e+00]     0
# T133          9.656874e-01      2.127489e+00     -3.109740e-01      2.897062e+00     [2.90e+00, 6.69e+00]     [2.59e+00, 6.38e+00]     0
# T138          9.656934e-01      8.098229e+09     -5.705312e+09      2.897080e+00     [2.90e+00, 3.00e+10]    [-5.71e+09, 2.43e+10]     1
# T144          9.656977e-01      4.191571e+09     -1.742529e+10      2.897093e+00     [2.90e+00, 3.00e+10]    [-1.74e+10, 1.26e+10]     1
# T223          9.656874e-01      2.500892e+00     -6.923935e-01      2.897062e+00     [2.90e+00, 8.20e+00]     [2.21e+00, 7.50e+00]     0
# T225          9.656873e-01      2.500892e+00     -6.923935e-01      2.897062e+00     [2.90e+00, 8.20e+00]     [2.21e+00, 7.50e+00]     0
# T234          9.656872e-01      2.500821e+00     -6.926055e-01      2.897062e+00     [2.90e+00, 8.20e+00]     [2.20e+00, 7.50e+00]     0
#
# == [Iter 83] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.025632e+00      4.607881e+09     -1.617636e+10      3.076897e+00     [6.69e+00, 3.00e+10]    [-1.62e+10, 1.38e+10]     1
# T1            9.697088e-01      4.393099e+09     -1.682070e+10      2.909126e+00     [6.56e+00, 3.00e+10]    [-1.68e+10, 1.32e+10]     1
# T2            9.755887e-01      4.270667e+09     -1.718800e+10      2.926766e+00     [8.03e+00, 3.00e+10]    [-1.72e+10, 1.28e+10]     2
# T3            9.671093e-01               inf               inf      2.901328e+00     [8.03e+00, 3.00e+10]               [inf, inf]     2
# T4            9.679638e-01      1.288643e+00     -4.329139e+00      2.903892e+00     [2.90e+00, 8.20e+00]    [-1.43e+00, 3.87e+00]     0
# T5            9.672097e-01      4.434713e+09     -1.669586e+10      2.901629e+00     [2.90e+00, 3.00e+10]    [-1.67e+10, 1.33e+10]     1
# T6            9.661922e-01      1.327975e+00     -4.211143e+00      2.898577e+00     [2.90e+00, 8.20e+00]    [-1.31e+00, 3.98e+00]     0
# T7            9.662983e-01      4.984921e+09     -1.504524e+10      2.898895e+00     [2.90e+00, 3.00e+10]    [-1.50e+10, 1.50e+10]     1
# T9            9.661912e-01      2.448693e+00     -6.823964e-01      2.898574e+00     [2.90e+00, 8.03e+00]     [2.22e+00, 7.35e+00]     0
# T10           9.662000e-01      4.286184e+09     -1.714145e+10      2.898600e+00     [2.90e+00, 3.00e+10]    [-1.71e+10, 1.29e+10]     1
# T11           9.661910e-01      4.221024e+09     -1.733693e+10      2.898573e+00     [2.90e+00, 3.00e+10]    [-1.73e+10, 1.27e+10]     1
# T12           9.662951e-01      8.090757e+09     -5.727730e+09      2.898885e+00     [2.90e+00, 3.00e+10]    [-5.73e+09, 2.43e+10]     1
# T13           9.661900e-01      2.084474e+00     -3.079068e-01      2.898570e+00     [2.90e+00, 6.56e+00]     [2.59e+00, 6.25e+00]     0
# T14           9.666267e-01      2.094411e+00     -2.780948e-01      2.899880e+00     [2.90e+00, 6.56e+00]     [2.62e+00, 6.28e+00]     0
# T15           9.662215e-01      9.670818e-01     -1.418346e-03      2.898566e+00     [2.90e+00, 2.90e+00]     [2.90e+00, 2.90e+00]     0
# T17           9.666267e-01      2.094411e+00     -2.780951e-01      2.899880e+00     [2.90e+00, 6.56e+00]     [2.62e+00, 6.28e+00]     0
# T20           9.666267e-01      2.094411e+00     -2.780952e-01      2.899880e+00     [2.90e+00, 6.56e+00]     [2.62e+00, 6.28e+00]     0
# T23           9.666267e-01      2.094411e+00     -2.780952e-01      2.899880e+00     [2.90e+00, 6.56e+00]     [2.62e+00, 6.28e+00]     0
# T26           9.666267e-01      2.094411e+00     -2.780952e-01      2.899880e+00     [2.90e+00, 6.56e+00]     [2.62e+00, 6.28e+00]     0
# T37           9.661886e-01      4.116580e+09     -1.765026e+10      2.898566e+00     [2.90e+00, 3.00e+10]    [-1.77e+10, 1.23e+10]     1
# T40           9.661888e-01      4.118309e+09     -1.764507e+10      2.898566e+00     [2.90e+00, 3.00e+10]    [-1.76e+10, 1.24e+10]     1
# T42           9.662194e-01      9.670816e-01     -1.418702e-03      2.898658e+00     [2.90e+00, 2.90e+00]     [2.90e+00, 2.90e+00]     0
# T45           9.662195e-01      9.670818e-01     -1.418210e-03      2.898658e+00     [2.90e+00, 2.90e+00]     [2.90e+00, 2.90e+00]     0
# T102          9.661888e-01      9.670818e-01     -1.418209e-03      2.898567e+00     [2.90e+00, 2.90e+00]     [2.90e+00, 2.90e+00]     0
# T111          9.658212e-01      2.507101e+00     -6.737667e-01      2.897464e+00     [2.90e+00, 8.20e+00]     [2.22e+00, 7.52e+00]     0
# T142          9.660425e-01      8.203030e+09     -5.390911e+09      2.898127e+00     [2.90e+00, 3.00e+10]    [-5.39e+09, 2.46e+10]     1
# T147          9.658872e-01      2.508340e+00     -6.700494e-01      2.897661e+00     [2.90e+00, 8.20e+00]     [2.23e+00, 7.53e+00]     0
# T150          9.658878e-01      2.508351e+00     -6.700162e-01      2.897664e+00     [2.90e+00, 8.20e+00]     [2.23e+00, 7.53e+00]     0
# T153          9.658878e-01      2.508351e+00     -6.700165e-01      2.897664e+00     [2.90e+00, 8.20e+00]     [2.23e+00, 7.53e+00]     0
# T161          9.658877e-01      2.508348e+00     -6.700242e-01      2.897663e+00     [2.90e+00, 8.20e+00]     [2.23e+00, 7.53e+00]     0
# T175          9.658878e-01      2.508350e+00     -6.700171e-01      2.897664e+00     [2.90e+00, 8.20e+00]     [2.23e+00, 7.53e+00]     0
# T178          9.658878e-01      2.508351e+00     -6.700167e-01      2.897664e+00     [2.90e+00, 8.20e+00]     [2.23e+00, 7.53e+00]     0
# T222          9.658212e-01      2.507101e+00     -6.737667e-01      2.897464e+00     [2.90e+00, 8.20e+00]     [2.22e+00, 7.52e+00]     0
#
# [Iter 83] created=45 (cum=2868), active=12, active+UB=0, ms_recomputed=0
# [Iter 83] UB-simplex selection: UB_node OUTSIDE mesh, fallback to min-LB simplex T234 (LB=0.965687232)
# [Iter 83] EF-ipopt: ok=True, ef_obj=0.9658017940976809, true_obj=9.658018e-01, time=0.134s
# [Iter 83] Pre-split gap: 3.436238e-04 (0.012%)
# [Iter 83] Active simplex ratio = 0.166667
# [Iter 83] UB point (-9.999983705753847, -99.99997783789564, 0.9388390879139868) is NOT inside any simplex (outside mesh)
# [Iter 83] LB = 2.897062 = UB(2.897405) + ms_b(-6.926e-01) from T234
# [Iter 83] Scene 0: Switched to c_s point. dist_ms_c=4.36e+01 < 1000.0, dist_c_verts=1.15e-03 > 1e-06
# [Iter 83] Scene 1: Switched to c_s point. dist_ms_c=4.35e+01 < 1000.0, dist_c_verts=2.56e-04 > 1e-06
# [Iter 83] Scene 2: Switched to c_s point. dist_ms_c=4.57e+01 < 1000.0, dist_c_verts=1.67e-03 > 1e-06
# Chosen node (-9.99420883258943, -99.99999537540954, 0.7911185989721148) with ms=-2.362e-01 (simp T234, scene 1, rank #1, source=c_s)
# [Iter 83] LB simplex = T234, next node simplex = T234, scene 1
# [Selected Simp Info] Iter 83 | Simplex T234 Vertices:
#   v0: (-9.999876178976505, -99.99999886640641, 1.6482323763638749)
#   v1: (10.0, -100.0, -100.0)
#   v2: (-9.994465183034196, -99.99999547874349, 0.7911138486440012)
#   v3: (-9.998830913234869, -99.9999808381837, 0.9388260736070384)
#   -> New Point: (-9.99420883258943, -99.99999537540954, 0.7911185989721148)
# [Iter 83] candidate rank #1: T234, scene=1, ms=-2.362e-01
# == ms candidates (sorted by (ms, -dist)) ==
# rank   simp   scene           ms    mind(all)                             pt
# ----------------------------------------------------------------------------
#    1   T234       1  -2.3623e-01     2.56e-04   (-9.9942, -100.0000, 0.7911)
#    2   T234       0  -2.3483e-01     1.15e-03   (-9.9988, -100.0000, 0.9400)
#    3   T234       2  -2.2154e-01     1.67e-03   (-9.9998, -100.0000, 1.6466)
#
# [Iter 83] per_tet=45, active after q_cut=12, tri_is_None=False
# [Iter 83] bad-quality active simplices (q < 0): 0
# [Iter 83] evaluating Q for scenario 0
# [Iter 83] evaluating Q for scenario 1
# [Iter 83] evaluating Q for scenario 2
#
# [Iter 83] Next Point Details:
# Simplex   Scene   Type    As             ms             As+ms          Q              (Kp, Ki, Kd)
# --------------------------------------------------------------------------------------------------------------------
# T234      1       c_s     9.4515e-01     -2.3623e-01    7.0892e-01     9.4513e-01     (-9.9942, -100.0000, 0.7911)
#
# [Iter 83] subdivision type = interior (code=1) on simplex T234
# [Iter 83] Elapsed: 0.236s
