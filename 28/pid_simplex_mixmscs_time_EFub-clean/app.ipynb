# %%
from time import perf_counter  

from modeling import build_models_from_csv
from bundles import BaseBundle, MSBundle
from utils import (
    tighten_bounds_one_model,
    MIN_DIST, ACTIVE_TOL, GAP_STOP_TOL,
)
from simplex_specialstart import run_pid_simplex_3d

# setup scenario number and target_nodesk
csv_path       = "data.csv"
max_scenarios  = 2
target_nodes   = 1000

bounds={
    "Kp": (-10.0, 10.0),
    "Ki": (-100.0, 100.0),
    "Kd": (-100.0, 100.0),
    "x": (-2.5, 2.5),
    "u": (-5.0, 5.0),
    "e": (None, None),
    "I": (None, None),
}

weights = (10.0, 0.01)


# ====== stage 1：load data and generate models ======
T   = 15.0          
nfe = 20            

t_load0 = perf_counter()
model_list, first_stg_vars_list, m_tmpl_list, nfe = build_models_from_csv(
    csv_path=csv_path,
    T=T,
    nfe=nfe,
    weights=weights,
    bounds=bounds,
    sp0=0.0,
    sp1=0.5,
    tau_xs_col="tau_xs",
    tau_us_col="tau_us",
    tau_ds_col="tau_ds",          
    disturb_prefix="disturbance_",
    setpoint_change_col="setpoint_change",
    max_scenarios=max_scenarios,
    skip=0,
)
t_load1 = perf_counter()
print(f"[Time] Data load & scenario build: {t_load1 - t_load0:.3f}s")


# ====== stage 1.5：FBBT / OBBT ======
# same as snog: FBBT open,OBBT open
obbt_solver_opts = {
    "NonConvex": 2,
    "MIPGap": 1,     
    "TimeLimit": 15   
}
for m, yvars in zip(model_list, first_stg_vars_list):
    tighten_bounds_one_model(m, yvars,
                             use_fbbt=False,
                             use_obbt=False,
                             obbt_solver_name="gurobi",
                             obbt_solver_opts=obbt_solver_opts,
                             max_rounds=3, tol=1e-6, verbose=True)

# ====== stage 2: Persistent Solver Packaging ======
ub_options = {
    'NonConvex': 2,      
}
lb_options = {
    'NonConvex': 2,
    'MIPGap': 1e-3,            
    'TimeLimit': 15 
}

t_wrap0 = perf_counter()
base_bundles = [BaseBundle(m, ub_options) for m in model_list]  
ms_bundles   = [MSBundle(m, yvars, lb_options) for m, yvars in zip(model_list, first_stg_vars_list)]  
t_wrap1 = perf_counter()
print(f"[Time] Persistent wrapper (GurobiPersistent) setup: {t_wrap1 - t_wrap0:.3f}s")

# ====== stage 3：main loop ======
agg_bundle = None  

t_run0 = perf_counter()
hist = run_pid_simplex_3d(
    base_bundles=base_bundles,
    ms_bundles=ms_bundles,
    model_list=model_list,
    first_vars_list=first_stg_vars_list,
    target_nodes=target_nodes,
    min_dist=0,
    active_tol=ACTIVE_TOL,
    verbose=True,
    agg_bundle=agg_bundle,
    gap_stop_tol=1e-6,
    use_exact_opt=False,
    exact_solver_name="gurobi",
    exact_solver_opts={"NonConvex": 2, "TimeLimit": 60},
    time_limit=60*5*1,
    enable_3d_plot=False,   
    plot_every=None,        
)
t_run1 = perf_counter()
print(f"[Time] Main loop total: {t_run1 - t_run0:.3f}s")

# ====== print output ======
print("\n==== Done ====")
print(f"Total nodes: {len(hist['nodes'])}")
print(f"Best UB: {min(hist['UB_hist']) if hist['UB_hist'] else None}")
print(f"Last LB: {hist['LB_hist'][-1] if hist['LB_hist'] else None}")
# Out:
# [Time] Data load & scenario build: 0.011s
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter MIPGap to value 0.001
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 15
# Set parameter MIPGap to value 0.001
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 15
# [Time] Persistent wrapper (GurobiPersistent) setup: 0.084s
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [TIMING] Pre-loop vertex Q evals: 0.41s  (8 nodes x 2 scenarios = 16 solves)
# [EF-UB] Initialized ipopt EF with 2 scenarios, time_ub=60.0s
#
# ======================================================================
# [TIMING] === Pre-loop phase summary ===
#   corners_and_mesh               :       0.00s
#   vertex_Q_evals                 :       0.41s
#   exact_optima                   :       0.00s
#   ef_init                        :       0.02s
#   TOTAL                          :       0.43s
# ======================================================================
#
# Set parameter MIPGap to value 0.1
# Set parameter MIPGap to value 0.1
# [Iter 0] MIPGap overridden to 0.1 (original: 0.001)
# Discarded solution information
# [Invariant] MS scen None: dual=-5.500707e+09 > primal=-5.500707e+09
# Discarded solution information
# [Invariant] MS scen None: dual=-5.806922e+09 > primal=-5.806922e+09
# [Invariant] MS scen None: dual=-5.817119e+09 > primal=-5.817119e+09
# [Invariant] MS scen None: dual=-5.596691e+09 > primal=-5.596691e+09
# [Invariant] MS scen None: dual=-5.719282e+09 > primal=-5.719282e+09
# [Invariant] MS scen None: dual=-5.724298e+09 > primal=-5.724298e+09
# [Bundle] MS scen None: infeasibleOrUnbounded. ms_val=nan.
# [Bundle] MS scen None: not optimal. Status=warning, Term=infeasibleOrUnbounded.
# [Iter 0] MIPGap restored to 0.001
# [Iter 0] #simplices = 6, #active = 6, bad-quality cut = 0
# == [Iter 0] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.002053e+00      4.652448e+09     -1.069510e+10      2.004105e+00     [4.49e+00, 2.00e+10]    [-1.07e+10, 9.30e+09]     1
# T1            9.980698e-01      4.187980e+09     -1.162404e+10      1.996140e+00     [4.49e+00, 2.00e+10]    [-1.16e+10, 8.38e+09]     1
# T2            1.030855e+00      4.410782e+09     -1.117844e+10      2.061709e+00     [4.37e+00, 2.00e+10]    [-1.12e+10, 8.82e+09]     1
# T3            9.831696e-01      4.252078e+09     -1.149584e+10      1.966339e+00     [4.37e+00, 2.00e+10]    [-1.15e+10, 8.50e+09]     1
# T4            1.027945e+00      4.275657e+09     -1.144869e+10      2.055890e+00     [5.34e+00, 2.00e+10]    [-1.14e+10, 8.55e+09]     2
# T5            9.948611e-01               inf               inf      1.989722e+00     [5.34e+00, 2.00e+10]               [inf, inf]     2
#
# == [Iter 0] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
#   (none)
# [Iter 0] created=6 (cum=6), active=6, active+UB=2, ms_recomputed=6
# [Iter 0] EF-ipopt: ok=True, ef_obj=0.9725087407557611, true_obj=9.725088e-01, time=0.096s
# [Iter 0] EF-UB improved by ipopt: 9.725088e-01 (per-scen), K=(9.99993804110578, 99.99988652923159, -3.9393789079483395e-06)
# [Iter 0] Pre-split gap: -2.132162e-02 (-1.096%)
# [Iter 0] Active simplex ratio = 1.000000
# [Iter 0] UB point (9.99993804110578, 99.99988652923159, -3.9393789079483395e-06) is geometrically in simplices [3]
#   T3 verts=[3, 6, 7, 4]: λ=[0.000003, 0.499999, 0.499997, 0.000001], LB=1.966339130, c_s=[0.9973765252119483, 0.9689626047948585]
#
# == [Iter 0] CS DUAL vs PRIMAL diagnostic (simplices containing UB point) ==
#   --- T3 ---
#     scen 0: status=optimal, dual=0.997376525, primal=0.997376525  ✓ dual ≤ primal (gap=1.110223e-16)
#              cs_primal_K=(9.999231675757967, 99.99864227385171, 1.3957947968559532)
#              indep_Q(cs_K)=0.997376525  → dual ≤ indep_Q (consistent, diff=2.363576e-11)
#     scen 1: status=optimal, dual=0.968962605, primal=0.968962605  ✓ dual ≤ primal (gap=-3.330669e-16)
#              cs_primal_K=(9.999999572689289, 1.1097568111452458, 1.0423394345803618)
#              indep_Q(cs_K)=0.968962976  → dual ≤ indep_Q (consistent, diff=3.712762e-07)
#   sum(c_s_dual)=1.966339130, UB_total=3.890035030, UB_per_scen=1.945017515
#
#   == Per-scenario Q_s at K_EF = (9.99993804110578, 99.99988652923159, -3.9393789079483395e-06) ==
#     scen 0: Q_s(K_EF)=0.999116698, c_s_dual=0.997376525  ✓ Q_s(K_EF) > c_s_dual (diff=1.740172e-03)
#     scen 1: Q_s(K_EF)=0.945900817, c_s_dual=0.968962605  ⚠ Q_s(K_EF) < c_s_dual → GUROBI CS DUAL IS WRONG
#     SUM Q_s(K_EF)=1.945017515, sum(c_s)=1.966339130, diff=-2.132162e-02
#
# [Iter 0] LB = 1.966339 = UB(1.945018) + ms_b(-1.150e+10) from T3
# Chosen node (2.018813556047649, 100.0, -15.531258309043011) with ms=-5.777e+09 (simp T3, scene 0, rank #1, source=ms(dist))
# [Iter 0] LB simplex = T3, next node simplex = T3, scene 0
# [Selected Simp Info] Iter 0 | Simplex T3 Vertices:
#   v0: (-10.0, 100.0, 100.0)
#   v1: (10.0, 100.0, -100.0)
#   v2: (10.0, 100.0, 100.0)
#   v3: (10.0, -100.0, -100.0)
#   -> New Point: (2.018813556047649, 100.0, -15.531258309043011)
# [Iter 0] candidate rank #1: T3, scene=0, ms=-5.777e+09
# == ms candidates (sorted by (ms, -dist)) ==
# rank   simp   scene           ms    mind(all)                             pt
# ----------------------------------------------------------------------------
#    1     T3       0  -5.7766e+09     8.48e+01   (2.0188, 100.0000, -15.5313)
#    2     T3       1  -5.7193e+09     8.60e+01   (1.4386, 100.0000, -14.3856)
#
# [Iter 0] per_tet=6, active after q_cut=6, tri_is_None=False
# [Iter 0] bad-quality active simplices (q < 0): 0
# [Iter 0] evaluating Q for scenario 0
# [Iter 0] evaluating Q for scenario 1
#
# [Iter 0] Next Point Details:
# Simplex   Scene   Type    As             ms             As+ms          Q              (Kp, Ki, Kd)
# --------------------------------------------------------------------------------------------------------------------
# T3        0       ms(dist)5.7766e+09     -5.7766e+09    1.6171e+02     1.6171e+02     (2.0188, 100.0000, -15.5313)
#
# [Iter 0] subdivision type = face (code=3) on simplex T3
#            face local verts = (3, 6, 7)
# [Iter 0] Elapsed: 12.285s
# ======================================================================
# [Iter 0] LB SPLIT DIAGNOSTIC
#   Selected (parent) simplex: (3, 4, 6, 7)
#   Parent LB: 0.983169565 (per-scen)
#   EF true_obj: 0.972508757 (per-scen)
#   Simplex volume: 1.333333e+05
#   Children (3):
#     T5 (4, 6, 7, 8): LB = 0.971421021
#     T6 (3, 4, 7, 8): LB = 0.972218981
#     T7 (3, 4, 6, 8): LB = 0.972730029
#   New global LB: 0.971421021 (from T5 (4, 6, 7, 8))
#   Location: INSIDE
# ======================================================================
# [BaseBundle.eval_at] Infeasible/Error for K=(9.999999999999998, 99.99999999999999, -18.746614777658124): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(1.5449980312739564, 100.0000000000002, -15.449963329430421): status=warning, term=infeasibleOrUnbounded
#
# ======================================================================
# [TIMING] === Iter 0 phase breakdown (total 51.50s) ===
#   1_vertex_UB                    :       0.00s  (  0.0%)
#   2_evaluate_all_tetra           :      12.07s  ( 23.4%)  ###########
#   3_active_filter_print          :       0.00s  (  0.0%)
#   4_LB_selection                 :       0.00s  (  0.0%)
#   5_EF_UB_solve                  :       0.18s  (  0.3%)
#   6_candidate_selection          :       0.00s  (  0.0%)
#   7_Q_eval_new_node              :       0.03s  (  0.1%)
#   8_mesh_subdivide               :       0.00s  (  0.0%)
#   9_end_of_iter_reeval           :      39.21s  ( 76.1%)  ######################################
#   TOTAL                          :      51.50s
#   #simplices=6, #scenarios=2, total_ms_pairs=12
#   fresh ms solves=12, cache hits=0
# ======================================================================
#
# [Iter 1] #simplices = 8, #active = 2, bad-quality cut = 0
# == [Iter 1] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T5            9.714210e-01      4.062669e+09     -1.187466e+10      1.942842e+00     [4.37e+00, 2.00e+10]    [-1.19e+10, 8.13e+09]     1
# T6            9.722190e-01      6.047226e+00     -2.327182e+02      1.944438e+00     [4.37e+00, 2.45e+02]    [-2.28e+02, 1.21e+01]     0
#
# == [Iter 1] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.002053e+00      4.652448e+09     -1.069510e+10      2.004105e+00     [4.49e+00, 2.00e+10]    [-1.07e+10, 9.30e+09]     1
# T1            9.980698e-01      4.187980e+09     -1.162404e+10      1.996140e+00     [4.49e+00, 2.00e+10]    [-1.16e+10, 8.38e+09]     1
# T2            1.030855e+00      4.410782e+09     -1.117844e+10      2.061709e+00     [4.37e+00, 2.00e+10]    [-1.12e+10, 8.82e+09]     1
# T3            1.027945e+00      4.275657e+09     -1.144869e+10      2.055890e+00     [5.34e+00, 2.00e+10]    [-1.14e+10, 8.55e+09]     2
# T4            9.948611e-01               inf               inf      1.989722e+00     [5.34e+00, 2.00e+10]               [inf, inf]     2
# T7            9.727300e-01      4.227523e+09     -1.154495e+10      1.945460e+00     [5.34e+00, 2.00e+10]    [-1.15e+10, 8.46e+09]     1
#
# [Iter 1] created=8 (cum=17), active=2, active+UB=2, ms_recomputed=0
# [Iter 1] EF-ipopt: ok=True, ef_obj=0.9713395115897239, true_obj=9.713396e-01, time=0.082s
# [Iter 1] EF-UB improved by ipopt: 9.713396e-01 (per-scen), K=(9.999914717778038, 99.99985027171408, 1.1526584885098299)
# [Iter 1] Pre-split gap: -1.628835e-04 (-0.008%)
# [Iter 1] Active simplex ratio = 0.162786
# [Iter 1] UB point (9.999914717778038, 99.99985027171408, 1.1526584885098299) is geometrically in simplices [5]
#   T5 verts=[8, 6, 7, 4]: λ=[0.000011, 0.494230, 0.505759, 0.000001], LB=1.942842041, c_s=[0.9976402599200571, 0.9452017815009689]
#
# == [Iter 1] CS DUAL vs PRIMAL diagnostic (simplices containing UB point) ==
#   --- T5 ---
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 89
#      86 agg_bundle = None
#      88 t_run0 = perf_counter()
# ---> 89 hist = run_pid_simplex_3d(
#      90     base_bundles=base_bundles,
#      91     ms_bundles=ms_bundles,
#      92     model_list=model_list,
#      93     first_vars_list=first_stg_vars_list,
#      94     target_nodes=target_nodes,
#      95     min_dist=0,
#      96     active_tol=ACTIVE_TOL,
#      97     verbose=True,
#      98     agg_bundle=agg_bundle,
#      99     gap_stop_tol=1e-6,
#     100     use_exact_opt=False,
#     101     exact_solver_name="gurobi",
#     102     exact_solver_opts={"NonConvex": 2, "TimeLimit": 60},
#     103     time_limit=60*5*1,
#     104     enable_3d_plot=False,
#     105     plot_every=None,
#     106 )
#     107 t_run1 = perf_counter()
#     108 print(f"[Time] Main loop total: {t_run1 - t_run0:.3f}s")
#
# File c:\Users\pc\Desktop\GitWorkspace2026\28\pid_simplex_mixmscs_time_EFub-clean\simplex_specialstart.py:1564, in run_pid_simplex_3d(base_bundles, ms_bundles, model_list, first_vars_list, target_nodes, min_dist, active_tol, verbose, agg_bundle, gap_stop_tol, tracker, enable_3d_plot, plot_every, use_exact_opt, exact_solver_name, exact_solver_opts, time_limit, enable_ef_ub, ef_time_ub)
#    1562 for _s_idx in range(S):
#    1563     _meta = _cs_metas[_s_idx] if _s_idx < len(_cs_metas) else {}
# -> 1564     _dual = _meta.get("dual_bound", None)
#    1565     _prim = _meta.get("primal_obj", None)
#    1566     _status = _meta.get("status", "?")
#
# AttributeError: 'NoneType' object has no attribute 'get'
