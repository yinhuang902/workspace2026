# %%
from time import perf_counter  

from modeling import build_models_from_csv
from bundles import BaseBundle, MSBundle
from utils import (
    tighten_bounds_one_model,
    MIN_DIST, ACTIVE_TOL, GAP_STOP_TOL,
)
from simplex_specialstart import run_pid_simplex_3d

# setup scenario number and target_nodesk
csv_path       = "data.csv"
max_scenarios  = 3
target_nodes   = 1000

bounds={
    "Kp": (-10.0, 10.0),
    "Ki": (-100.0, 100.0),
    "Kd": (-100.0, 100.0),
    "x": (-2.5, 2.5),
    "u": (-5.0, 5.0),
    "e": (None, None),
    "I": (None, None),
}

weights = (10.0, 0.01)


# ====== stage 1：load data and generate models ======
T   = 15.0          
nfe = 20            

t_load0 = perf_counter()
model_list, first_stg_vars_list, m_tmpl_list, nfe = build_models_from_csv(
    csv_path=csv_path,
    T=T,
    nfe=nfe,
    weights=weights,
    bounds=bounds,
    sp0=0.0,
    sp1=0.5,
    tau_xs_col="tau_xs",
    tau_us_col="tau_us",
    tau_ds_col="tau_ds",          
    disturb_prefix="disturbance_",
    setpoint_change_col="setpoint_change",
    max_scenarios=max_scenarios,
    skip=0,
)
t_load1 = perf_counter()
print(f"[Time] Data load & scenario build: {t_load1 - t_load0:.3f}s")


# ====== stage 1.5：FBBT / OBBT ======
# same as snog: FBBT open,OBBT open
obbt_solver_opts = {
    "NonConvex": 2,
    "MIPGap": 1,     
    "TimeLimit": 15   
}
for m, yvars in zip(model_list, first_stg_vars_list):
    tighten_bounds_one_model(m, yvars,
                             use_fbbt=False,
                             use_obbt=False,
                             obbt_solver_name="gurobi",
                             obbt_solver_opts=obbt_solver_opts,
                             max_rounds=3, tol=1e-6, verbose=True)

# ====== stage 2: Persistent Solver Packaging ======
ub_options = {
    'NonConvex': 2,      
}
lb_options = {
    'NonConvex': 2,
    'MIPGap': 1e-1,            
    'TimeLimit': 15 
}

t_wrap0 = perf_counter()
base_bundles = [BaseBundle(m, ub_options) for m in model_list]  
ms_bundles   = [MSBundle(m, yvars, lb_options) for m, yvars in zip(model_list, first_stg_vars_list)]  
t_wrap1 = perf_counter()
print(f"[Time] Persistent wrapper (GurobiPersistent) setup: {t_wrap1 - t_wrap0:.3f}s")

# ====== stage 3：main loop ======
agg_bundle = None  

t_run0 = perf_counter()
hist = run_pid_simplex_3d(
    base_bundles=base_bundles,
    ms_bundles=ms_bundles,
    model_list=model_list,
    first_vars_list=first_stg_vars_list,
    target_nodes=target_nodes,
    min_dist=0,
    active_tol=ACTIVE_TOL,
    verbose=True,
    agg_bundle=agg_bundle,
    gap_stop_tol=1e-6,
    use_exact_opt=False,
    exact_solver_name="gurobi",
    exact_solver_opts={"NonConvex": 2, "TimeLimit": 60},
    time_limit=60*60*7,
    enable_3d_plot=False,   
    plot_every=None,        
)
t_run1 = perf_counter()
print(f"[Time] Main loop total: {t_run1 - t_run0:.3f}s")

# ====== print output ======
print("\n==== Done ====")
print(f"Total nodes: {len(hist['nodes'])}")
print(f"Best UB: {min(hist['UB_hist']) if hist['UB_hist'] else None}")
print(f"Last LB: {hist['LB_hist'][-1] if hist['LB_hist'] else None}")
# Out:
# [Time] Data load & scenario build: 0.024s
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2689754
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 15
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 15
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 15
# [Time] Persistent wrapper (GurobiPersistent) setup: 0.911s
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=warning, term=infeasibleOrUnbounded
# [TIMING] Pre-loop vertex Q evals: 0.47s  (8 nodes x 3 scenarios = 24 solves)
# [EF-UB] Initialized ipopt EF with 3 scenarios, time_ub=60.0s
#
# ======================================================================
# [TIMING] === Pre-loop phase summary ===
#   corners_and_mesh               :       0.00s
#   vertex_Q_evals                 :       0.47s
#   exact_optima                   :       0.00s
#   ef_init                        :       0.04s
#   TOTAL                          :       0.51s
# ======================================================================
#
# [Iter 0] MIPGap overridden to 0.1 (original: 0.1)
# Discarded solution information
# [Invariant] MS scen None: dual=-5.500707e+09 > primal=-5.500707e+09
# Discarded solution information
# Discarded solution information
# [Invariant] MS scen None: dual=-5.481254e+09 > primal=-5.481254e+09
# [Invariant] MS scen None: dual=-5.806922e+09 > primal=-5.806922e+09
# [Invariant] MS scen None: dual=-5.817119e+09 > primal=-5.817119e+09
# [Invariant] MS scen None: dual=-5.596691e+09 > primal=-5.596691e+09
# [Invariant] MS scen None: dual=-5.719282e+09 > primal=-5.719282e+09
# [Invariant] MS scen None: dual=-5.724298e+09 > primal=-5.724298e+09
# [Bundle] MS scen None: infeasibleOrUnbounded. ms_val=nan.
# [Bundle] MS scen None: not optimal. Status=warning, Term=infeasibleOrUnbounded.
# [Iter 0] MIPGap restored to 0.1
# [Iter 0] #simplices = 6, #active = 6, bad-quality cut = 0, bad-shape cut = 0
# == [Iter 0] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            9.835946e-01      4.607881e+09     -1.617636e+10      2.950784e+00     [6.69e+00, 3.00e+10]    [-1.62e+10, 1.38e+10]     1
# T1            9.656874e-01      4.116368e+09     -1.765089e+10      2.897062e+00     [6.69e+00, 3.00e+10]    [-1.77e+10, 1.23e+10]     1
# T2            9.692412e-01      4.393099e+09     -1.682070e+10      2.907724e+00     [6.56e+00, 3.00e+10]    [-1.68e+10, 1.32e+10]     1
# T3            9.664856e-01      4.221519e+09     -1.733544e+10      2.899457e+00     [6.56e+00, 3.00e+10]    [-1.73e+10, 1.27e+10]     1
# T4            9.725695e-01      4.270667e+09     -1.718800e+10      2.917708e+00     [8.03e+00, 3.00e+10]    [-1.72e+10, 1.28e+10]     2
# T5            9.667879e-01               inf               inf      2.900364e+00     [8.03e+00, 3.00e+10]               [inf, inf]     2
#
# == [Iter 0] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
#   (none)
# [Iter 0] created=6 (cum=6), active=6, active+UB=2, ms_recomputed=6
# [Iter 0] EF-ipopt: ok=True, ef_obj=0.9658017308039795, true_obj=9.658018e-01, time=0.075s
# [Iter 0] EF-UB improved by ipopt: 9.658018e-01 (per-scen), K=(-9.99986116041655, -99.99974003986114, 1.1158019841600832)
# [Iter 0] Pre-split gap: 3.431352e-04 (0.012%)
# [Iter 0] Active simplex ratio = 1.000000
# [Iter 0] UB point (-9.99986116041655, -99.99974003986114, 1.1158019841600832) is geometrically in simplices [1]
#   T1 verts=[3, 1, 4, 0]: λ=[0.000001, 0.505578, 0.000007, 0.494414], LB=2.897062327, c_s=[0.9960029117495633, 0.9451261065634194, 0.9559333091533598]
#
# == [Iter 0] CS DUAL vs PRIMAL diagnostic (simplices containing UB point) ==
#   --- T1 ---
#     scen 0: status=time_limit, dual=0.996002912, primal=0.996002912  ✓ dual ≤ primal (gap=1.110223e-16)
#              cs_primal_K=(-9.999216646683243, -99.99852406033013, 0.9388331317148486)
#              indep_Q(cs_K)=0.996002918  → dual ≤ indep_Q (consistent, diff=5.926596e-09)
#     scen 1: status=time_limit, dual=0.945126107, primal=0.945126107  ✓ dual ≤ primal (gap=-2.220446e-16)
#              cs_primal_K=(-9.989915094616153, -99.98054975791798, 0.7895639143766731)
#              indep_Q(cs_K)=0.945126107  → dual ≤ indep_Q (consistent, diff=8.471402e-10)
#     scen 2: status=time_limit, dual=0.955933309, primal=0.955933309  ✓ dual ≤ primal (gap=0.000000e+00)
#              cs_primal_K=(-9.993954386431088, -99.99022196398693, 1.6482743345387214)
#              indep_Q(cs_K)=0.955933425  → dual ≤ indep_Q (consistent, diff=1.157402e-07)
#   sum(c_s_dual)=2.897062327, UB_total=8.692216388, UB_per_scen=2.897405463
#
#   == Per-scenario Q_s at K_EF = (-9.99986116041655, -99.99974003986114, 1.1158019841600832) ==
#     scen 0: Q_s(K_EF)=0.996028692, c_s_dual=0.996002912  ✓ Q_s(K_EF) > c_s_dual (diff=2.578070e-05)
#     scen 1: Q_s(K_EF)=0.945215075, c_s_dual=0.945126107  ✓ Q_s(K_EF) > c_s_dual (diff=8.896800e-05)
#     scen 2: Q_s(K_EF)=0.956161696, c_s_dual=0.955933309  ✓ Q_s(K_EF) > c_s_dual (diff=2.283865e-04)
#     SUM Q_s(K_EF)=2.897405463, sum(c_s)=2.897062327, diff=3.431352e-04
#
# [Iter 0] LB = 2.897062 = UB(2.897405) + ms_b(-1.765e+10) from T1
# [Iter 0] Scene 0: Switched to c_s point. dist_ms_c=1.71e+01 < 1000.0, dist_c_verts=9.91e+01 > 1e-06
# [Iter 0] Scene 1: Switched to c_s point. dist_ms_c=1.57e+01 < 1000.0, dist_c_verts=9.92e+01 > 1e-06
# [Iter 0] Scene 2: Switched to c_s point. dist_ms_c=1.89e+01 < 1000.0, dist_c_verts=9.84e+01 > 1e-06
# Chosen node (-9.993954386431088, -99.99022196398693, 1.6482743345387214) with ms=-6.027e+09 (simp T1, scene 2, rank #1, source=c_s)
# [Iter 0] LB simplex = T1, next node simplex = T1, scene 2
# [Selected Simp Info] Iter 0 | Simplex T1 Vertices:
#   v0: (-10.0, 100.0, 100.0)
#   v1: (-10.0, -100.0, 100.0)
#   v2: (10.0, -100.0, -100.0)
#   v3: (-10.0, -100.0, -100.0)
#   -> New Point: (-9.993954386431088, -99.99022196398693, 1.6482743345387214)
# [Iter 0] candidate rank #1: T1, scene=2, ms=-6.027e+09
# == ms candidates (sorted by (ms, -dist)) ==
# rank   simp   scene           ms    mind(all)                             pt
# ----------------------------------------------------------------------------
#    1     T1       2  -6.0269e+09     9.84e+01    (-9.9940, -99.9902, 1.6483)
#    2     T1       1  -5.8171e+09     9.92e+01    (-9.9899, -99.9805, 0.7896)
#    3     T1       0  -5.8069e+09     9.91e+01    (-9.9992, -99.9985, 0.9388)
#
# [Iter 0] per_tet=6, active after q_cut=6, tri_is_None=False
# [Iter 0] bad-quality active simplices (q < 0): 0
# [Iter 0] evaluating Q for scenario 0
# [Iter 0] evaluating Q for scenario 1
# [Iter 0] evaluating Q for scenario 2
#
# [Iter 0] Next Point Details:
# Simplex   Scene   Type    As             ms             As+ms          Q              (Kp, Ki, Kd)
# --------------------------------------------------------------------------------------------------------------------
# T1        2       c_s     5.0819e+09     -6.0269e+09    -9.4493e+08    9.5593e-01     (-9.9940, -99.9902, 1.6483)
#
# [Iter 0] subdivision type = interior (code=1) on simplex T1
# [Iter 0] Elapsed: 58.027s
# [Invariant] MS scen None: dual=-5.870800e+09 > primal=-5.870800e+09
# [Invariant] MS scen None: dual=-5.895913e+09 > primal=-5.895913e+09
# [Invariant] MS scen None: dual=-5.959128e+09 > primal=-5.959128e+09
# ======================================================================
# [Iter 0] LB SPLIT DIAGNOSTIC
#   Selected (parent) simplex: (0, 1, 3, 4)
#   Parent LB: 0.965687442 (per-scen)
#   EF ef_obj(IPOPT): 0.321933910, true_obj(recalc): 0.965801821, used=min=0.321933910 (per-scen)
#   Simplex volume: 1.333333e+05
#   Children (4):
#     T5 (0, 1, 4, 8): LB = 0.965687198
#     T6 (0, 3, 4, 8): LB = 0.965688068
#     T7 (0, 1, 3, 8): LB = 0.965687284
#     T8 (1, 3, 4, 8): LB = 0.965698676
#   New global LB: 0.965687198 (from T5 (0, 1, 4, 8))
#   Location: INSIDE
#   Avg CS point Q-value: 0.965802809 (per-scen), point=(np.float64(-9.994362042576828), np.float64(-99.989765260745), np.float64(1.1255571268767477))
#   Current UB: 0.965801821 (per-scen)
#   UB point: (-9.99986116041655, -99.99974003986114, 1.1158019841600832)
#   UB source: EF_ipopt
#   UB simplex: (0, 1, 3, 4)
#   EF-IPOPT: ok=True, status=ok, term=optimal, time=0.075s, ef_obj=0.9658017308039795, true_obj(per-scen)=0.965801821
# ======================================================================
# [BaseBundle.eval_at] Infeasible/Error for K=(-1.7336372428464808, -99.99997947511173, 17.130051105637264): status=warning, term=infeasibleOrUnbounded
# [Iter 0] UB_global_end improved by EF: 3.219339e-01 (per-scen), ef_obj=0.9658017308039795, true_obj=2.8974054626197185
#
# ======================================================================
# [TIMING] === Iter 0 phase breakdown (total 135.15s) ===
#   1_vertex_UB                    :       0.00s  (  0.0%)
#   2_evaluate_all_tetra           :      57.83s  ( 42.8%)  #####################
#   3_active_filter_print          :       0.00s  (  0.0%)
#   4_LB_selection                 :       0.00s  (  0.0%)
#   5_EF_UB_solve                  :       0.16s  (  0.1%)
#   6_candidate_selection          :       0.00s  (  0.0%)
#   7_Q_eval_new_node              :       0.03s  (  0.0%)
#   8_mesh_subdivide               :       0.00s  (  0.0%)
#   9_end_of_iter_reeval           :      77.12s  ( 57.1%)  ############################
#   TOTAL                          :     135.15s
#   #simplices=6, #scenarios=3, total_ms_pairs=18
#   fresh ms solves=18, cache hits=0
# ======================================================================
#
# [Iter 0] Stop: UB-LB gap -1.999644e+00 <= tol 1.000000e-06.
#
# ===== Simplex search summary (per-scenario) =====
#   Time (s)  # Nodes             LB             UB   Rel. Gap   Abs. Gap   #simplex    #active   Split       Selection
# ---------------------------------------------------------------------------------------------------------------------
#     57.984        8    0.965687198    0.321933910 -199.9644%   -0.64375          6          6    none             c_s
# [Time] Main loop total: 135.678s
#
# ==== Done ====
# Total nodes: 9
# Best UB: 0.9658017308039795
# Last LB: 2.8970615931706853
