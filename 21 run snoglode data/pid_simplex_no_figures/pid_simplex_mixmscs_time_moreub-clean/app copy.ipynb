# *   33    18               5    -5.00000e+09 -8.084e+09  61.7%   151    0s
# *  125    19              12    -5.19403e+09 -6.510e+09  25.3%  89.1    0s
# *  165     5              15    -5.19438e+09 -5.971e+09  14.9%  72.1    0s
# *  199    13              18    -5.19440e+09 -5.960e+09  14.7%  71.2    0s
# *  257    10              15    -5.47941e+09 -5.840e+09  6.58%  68.6    0s
# *  262    10              16    -5.55988e+09 -5.561e+09  0.02%  67.7    0s
#
# Explored 281 nodes (20004 simplex iterations) in 0.24 seconds (0.20 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 10: -5.55988e+09 -5.47941e+09 -5.1944e+09 ... -4.64145e+09
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective -5.559875921495e+09, best bound -5.560871232495e+09, gap 0.0179%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: AMD Ryzen 9 7900X 12-Core Processor, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 12 physical cores, 24 logical processors, using up to 24 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 108 rows, 134 columns and 308 nonzeros
# Model fingerprint: 0x95e2d99d
# Model has 42 quadratic objective terms
# Model has 21 quadratic constraints
# Coefficient statistics:
#   Matrix range     [5e-01, 1e+10]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [7e-03, 2e+01]
#   Bounds range     [2e+00, 1e+10]
#   RHS range        [4e-03, 1e+00]
# Warning: Model contains large matrix coefficients
# Warning: Model contains large bounds
# Presolve removed 23 rows and 24 columns
#
# Continuous model is non-convex -- solving as a MIP
#
#
# MIP start from previous solve produced solution with objective 2.65445 (0.02s)
# MIP start from previous solve produced solution with objective 1.10065 (0.08s)
# MIP start from previous solve produced solution with objective 1.10064 (0.08s)
# Loaded MIP start from previous solve with objective 1.10064
#
# Presolve removed 48 rows and 49 columns
# Presolve time: 0.00s
# Presolved: 324 rows, 146 columns, 991 nonzeros
# Presolved model has 41 quadratic objective terms
# Presolved model has 61 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 146 continuous, 0 integer (0 binary)
# Root relaxation presolved: 319 rows, 142 columns, 977 nonzeros
# Root relaxation presolved model has 40 quadratic objective terms
#
#
# Root relaxation: objective 9.446426e-01, 248 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.94464    0   61    1.10064    0.94464  14.2%     -    0s
#      0     0    0.94464    0   61    1.10064    0.94464  14.2%     -    0s
#      0     0    0.94464    0   61    1.10064    0.94464  14.2%     -    0s
#      0     0    0.94464    0   61    1.10064    0.94464  14.2%     -    0s
# H    0     0                       0.9990900    0.94464  5.45%     -    0s
#
# Cutting planes:
#   RLT: 5
#
# Explored 1 nodes (261 simplex iterations) in 0.20 seconds (0.15 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 4: 0.99909 1.10064 1.10065 2.65445
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 9.990900168711e-01, best bound 9.446426107010e-01, gap 5.4497%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: AMD Ryzen 9 7900X 12-Core Processor, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 12 physical cores, 24 logical processors, using up to 24 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 5 rows, 6 columns and 16 nonzeros
# Model fingerprint: 0x65c95b03
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+09]
# Warning: Model contains large matrix coefficients
# Warning: Model contains large rhs
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 2 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 6 columns, 14 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.0041054e+00   0.000000e+00   0.000000e+00      0s
#        0    2.0041054e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  2.004105428e+00
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: AMD Ryzen 9 7900X 12-Core Processor, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 12 physical cores, 24 logical processors, using up to 24 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 108 rows, 134 columns and 308 nonzeros
# Model fingerprint: 0x7a915df3
# Model has 42 quadratic objective terms
# Model has 21 quadratic constraints
# Coefficient statistics:
#   Matrix range     [6e-01, 1e+10]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [7e-03, 2e+01]
#   Bounds range     [2e+00, 1e+10]
#   RHS range        [6e-02, 1e+00]
# Warning: Model contains large matrix coefficients
# Warning: Model contains large bounds
# Presolve removed 23 rows and 24 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 48 rows and 49 columns
# Presolve time: 0.00s
# Presolved: 324 rows, 146 columns, 991 nonzeros
# Presolved model has 41 quadratic objective terms
# Presolved model has 61 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 146 continuous, 0 integer (0 binary)
# Root relaxation presolved: 319 rows, 142 columns, 977 nonzeros
# Root relaxation presolved model has 40 quadratic objective terms
#
#
# Root relaxation: objective -9.396866e+09, 1012 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 -9.397e+09    0   41          - -9.397e+09      -     -    0s
#      0     0 -9.379e+09    0   41          - -9.379e+09      -     -    0s
# H    0     0                    -5.00000e+09 -9.379e+09  87.6%     -    0s
#      0     0 -8.567e+09    0   41 -5.000e+09 -8.567e+09  71.3%     -    0s
#      0     2 -8.567e+09    0   41 -5.000e+09 -8.567e+09  71.3%     -    0s
# *    6     6               2    -5.00000e+09 -8.567e+09  71.3%   240    0s
# *   67    18               8    -5.01174e+09 -6.881e+09  37.3%   112    0s
# *  295    46              16    -5.01227e+09 -6.569e+09  31.0%  69.5    0s
# *  887   347              37    -5.86658e+09 -6.178e+09  5.31%  48.2    0s
#
# Cutting planes:
#   RLT: 3
#
# Explored 987 nodes (44551 simplex iterations) in 0.40 seconds (0.30 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 5: -5.86658e+09 -5.01227e+09 -5.01174e+09 ... -5e+09
#
# Optimal solution found (tolerance 1.00e-01)
# Warning: max constraint violation (2.4559e-06) exceeds tolerance
# Best objective -5.866575858276e+09, best bound -6.178311415363e+09, gap 5.3138%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: AMD Ryzen 9 7900X 12-Core Processor, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 12 physical cores, 24 logical processors, using up to 24 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 108 rows, 134 columns and 308 nonzeros
# Model fingerprint: 0xf54f6c82
# Model has 42 quadratic objective terms
# Model has 21 quadratic constraints
# Coefficient statistics:
#   Matrix range     [6e-01, 1e+10]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [7e-03, 2e+01]
#   Bounds range     [2e+00, 1e+10]
#   RHS range        [6e-02, 1e+00]
# Warning: Model contains large matrix coefficients
# Warning: Model contains large bounds
# Presolve removed 23 rows and 24 columns
#
# Continuous model is non-convex -- solving as a MIP
#
#
# MIP start from previous solve produced solution with objective 2.3862 (0.02s)
# MIP start from previous solve produced solution with objective 1.77345 (0.08s)
# MIP start from previous solve produced solution with objective 1.43006 (0.08s)
# Loaded MIP start from previous solve with objective 1.43006
#
# Presolve removed 48 rows and 49 columns
# Presolve time: 0.00s
# Presolved: 324 rows, 146 columns, 991 nonzeros
# Presolved model has 41 quadratic objective terms
# Presolved model has 61 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 146 continuous, 0 integer (0 binary)
# Found heuristic solution: objective 0.9960029
#
# Explored 0 nodes (0 simplex iterations) in 0.12 seconds (0.08 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 4: 0.996003 1.43006 1.77345 2.3862
#
# Optimal solution found (tolerance 1.00e-01)
# Warning: max constraint violation (1.2727e-06) exceeds tolerance
# Best objective 9.960029127022e-01, best bound 9.375000000000e-01, gap 5.8738%
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: AMD Ryzen 9 7900X 12-Core Processor, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 12 physical cores, 24 logical processors, using up to 24 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 108 rows, 134 columns and 308 nonzeros
# Model fingerprint: 0x016cf7c0
# Model has 42 quadratic objective terms
# Model has 21 quadratic constraints
# Coefficient statistics:
#   Matrix range     [5e-01, 1e+10]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [7e-03, 2e+01]
#   Bounds range     [2e+00, 1e+10]
#   RHS range        [4e-03, 1e+00]
# Warning: Model contains large matrix coefficients
# Warning: Model contains large bounds
# Presolve removed 23 rows and 24 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 48 rows and 49 columns
# Presolve time: 0.00s
# Presolved: 324 rows, 146 columns, 991 nonzeros
# Presolved model has 41 quadratic objective terms
# Presolved model has 61 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 146 continuous, 0 integer (0 binary)
# Root relaxation presolved: 319 rows, 142 columns, 977 nonzeros
# Root relaxation presolved model has 40 quadratic objective terms
#
#
# Root relaxation: objective -9.396488e+09, 954 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 -9
work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 4: -5.59669e+09 -5e+09 -5e+09 -3.58567e+08
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective -5.596691281503e+09, best bound -5.895447334588e+09, gap 5.3381%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: AMD Ryzen 9 7900X 12-Core Processor, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 12 physical cores, 24 logical processors, using up to 24 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 108 rows, 134 columns and 308 nonzeros
# Model fingerprint: 0x2b55166f
# Model has 42 quadratic objective terms
# Model has 21 quadratic constraints
# Coefficient statistics:
#   Matrix range     [5e-01, 1e+10]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [7e-03, 2e+01]
#   Bounds range     [2e+00, 1e+10]
#   RHS range        [4e-03, 1e+00]
# Warning: Model contains large matrix coefficients
# Warning: Model contains large bounds
# Presolve removed 23 rows and 24 columns
#
# Continuous model is non-convex -- solving as a MIP
#
#
# MIP start from previous solve produced solution with objective 2.1343 (0.02s)
# MIP start from previous solve produced solution with objective 1.5941 (0.07s)
# Loaded MIP start from previous solve with objective 1.5941
#
# Presolve removed 48 rows and 50 columns
# Presolve time: 0.00s
# Presolved: 324 rows, 145 columns, 990 nonzeros
# Presolved model has 41 quadratic objective terms
# Presolved model has 61 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 145 continuous, 0 integer (0 binary)
# Root relaxation presolved: 319 rows, 141 columns, 976 nonzeros
# Root relaxation presolved model has 40 quadratic objective terms
#
#
# Root relaxation: objective 9.446426e-01, 301 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.94464    0   61    1.59410    0.94464  40.7%     -    0s
#      0     0    0.94464    0   61    1.59410    0.94464  40.7%     -    0s
#      0     0    0.94464    0   61    1.59410    0.94464  40.7%     -    0s
#      0     0    0.94464    0   61    1.59410    0.94464  40.7%     -    0s
# H    0     0                       1.0376192    0.94464  8.96%     -    0s
#
# Cutting planes:
#   RLT: 4
#
# Explored 1 nodes (312 simplex iterations) in 0.18 seconds (0.14 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 3: 1.03762 1.5941 2.1343
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 1.037619152997e+00, best bound 9.446426107010e-01, gap 8.9606%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: AMD Ryzen 9 7900X 12-Core Processor, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 12 physical cores, 24 logical processors, using up to 24 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 5 rows, 6 columns and 16 nonzeros
# Model fingerprint: 0xe2368ddc
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+09]
# Warning: Model contains large matrix coefficients
# Warning: Model contains large rhs
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 2 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 3 rows, 6 columns, 14 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.0489994e+00   0.000000e+00   0.000000e+00      0s
#        0    2.0489994e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  2.048999370e+00
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: AMD Ryzen 9 7900X 12-Core Processor, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 12 physical cores, 24 logical processors, using up to 24 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 108 rows, 134 columns and 308 nonzeros
# Model fingerprint: 0xfaa31140
# Model has 42 quadratic objective terms
# Model has 21 quadratic constraints
# Coefficient statistics:
#   Matrix range     [6e-01, 1e+10]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [7e-03, 2e+01]
#   Bounds range     [2e+00, 1e+10]
#   RHS range        [6e-02, 1e+00]
# Warning: Model contains large matrix coefficients
# Warning: Model contains large bounds
# Presolve removed 23 rows and 24 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 48 rows and 50 columns
# Presolve time: 0.00s
# Presolved: 324 rows, 145 columns, 990 nonzeros
# Presolved model has 41 quadratic objective terms
# Presolved model has 61 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 145 continuous, 0 integer (0 binary)
# Root relaxation presolved: 319 rows, 141 columns, 976 nonzeros
# Root relaxation presolved model has 40 quadratic objective terms
#
#
# Root relaxation: objective -9.382426e+09, 794 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 -9.382e+09    0   41          - -9.382e+09      -     -    0s
#      0     0 -9.363e+09    0   41          - -9.363e+09      -     -    0s
# H    0     0                    -5.00000e+09 -9.363e+09  87.3%     -    0s
#      0     0 -8.540e+09    0   41 -5.000e+09 -8.540e+09  70.8%     -    0s
#      0     2 -8.540e+09    0   41 -5.000e+09 -8.540e+09  70.8%     -    0s
# *    8    12               3    -5.00000e+09 -8.540e+09  70.8%   122    0s
# *   42    14               7    -5.01440e+09 -7.090e+09  41.4%   127    0s
# *   82    22               9    -5.01484e+09 -6.567e+09  31.0%   118    0s
# *  102    24              11    -5.01485e+09 -6.567e+09  31.0%   102    0s
# *  225    19              17    -5.69958e+09 -6.567e+09  15.2%  81.9    0s
# *  266    13              19    -5.72123e+09 -6.567e+09  14.8%  79.2    0s
# *  277    13              20    -5.77654e+09 -6.567e+09  13.7%  78.3    0s
#
# Cutting planes:
#   RLT: 3
#
# Explored 317 nodes (24098 simplex iterations) in 0.24 seconds (0.21 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 8: -5.77654e+09 -5.72123e+09 -5.69958e+09 ... -5e+09
#
# Optimal solution found (tolerance 1.00e-01)
# Warning: max constraint violation (1.6047e-06) exceeds tolerance
# Best objective -5.776540149947e+09, best bound -6.327883593171e+09, gap 9.5445%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: AMD Ryzen 9 7900X 12-Core Processor, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 12 physical cores, 24 logical processors, using up to 24 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 108 rows, 134 columns and 308 nonzeros
# Model fingerprint: 0xcc934c1a
# Model has 42 quadratic objective terms
# Model has 21 quadratic constraints
# Coefficient statistics:
#   Matrix range     [6e-01, 1e+10]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [7e-03, 2e+01]
#   Bounds range     [2e+00, 1e+10]
#   RHS range        [6e-02, 1e+00]
# Warning: Model contains large matrix coefficients
# Warning: Model contains large bounds
# Presolve removed 23 rows and 24 columns
#
# Continuous model is non-convex -- solving as a MIP
#
#
# MIP start from previous solve produced solution with objective 1.74738 (0.02s)
# Loaded MIP start from previous solve with objective 1.74738
#
# Presolve removed 48 rows and 50 columns
# Presolve time: 0.00s
# Presolved: 324 rows, 145 columns, 990 nonzeros
# Presolved model has 41 quadratic objective terms
# Presolved model has 61 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 145 continuous, 0 integer (0 binary)
# Root relaxation presolved: 319 rows, 141 columns, 976 nonzeros
# Root relaxation presolved model has 40 quadratic objective terms
#
#
# Root relaxation: objective 9.896966e-01, 299 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.98970    0   61    1.74738    0.98970  43.4%     -    0s
#      0     0    0.98970    0   61    1.74738    0.98970  43.4%     -    0s
#      0     0    0.98970    0   61    1.74738    0.98970  43.4%     -    0s
#      0     0    0.98970    0   61    1.74738    0.98970  43.4%     -    0s
#      0     0    0.98970    0   61    1.74738    0.98970  43.4%     -    0s
# H    0     0                       1.6497574    0.98970  40.0%     -    0s
# H    0     0                       0.9973765    0.98970  0.77%     -    0s
#
# Cutting planes:
#   RLT: 16
#
# Explored 1 nodes (383 simplex iterations) in 0.22 seconds (0.15 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 3: 0.997377 1.64976 1.74738
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 9.973765252119e-01, best bound 9.896966096528e-01, gap 0.7700%
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: AMD Ryzen 9 7900X 12-Core Processor, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 12 physical cores, 24 logical processors, using up to 24 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 108 rows, 134 columns and 308 nonzeros
# Model fingerprint: 0x40f413f3
# Model has 42 quadratic objective terms
# Model has 21 quadratic constraints
# Coefficient statistics:
#   Matrix range     [5e-01, 1e+10]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [7e-03, 2e+01]
#   Bounds range     [2e+00, 1e+10]
#   RHS range        [4e-03, 1e+00]
# Warning: Model contains large matrix coefficients
# Warning: Model contains large bounds
# Presolve removed 23 rows and 24 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 48 rows and 50 columns
# Presolve time: 0.00s
# Presolved: 324 rows, 145 columns, 990 nonzeros
# Presolved model has 41 quadratic objective terms
# Presolved model has 61 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
# ...
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: AMD Ryzen 9 7900X 12-Core Processor, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 12 physical cores, 24 logical processors, using up to 24 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 108 rows, 134 columns and 308 nonzeros
# Model fingerprint: 0x1c97c894
# Model has 42 quadratic objective terms
# Model has 21 quadratic constraints
# Coefficient statistics:
#   Matrix range     [6e-01, 1e+10]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [7e-03, 2e+01]
#   Bounds range     [2e+00, 1e+10]
#   RHS range        [6e-02, 1e+00]
# Warning: Model contains large matrix coefficients
# Warning: Model contains large bounds
# Presolve removed 23 rows and 24 columns
#
# Continuous model is non-convex -- solving as a MIP
#
#
# Loaded MIP start from previous solve with objective 7.06501
#
# Presolve removed 45 rows and 46 columns
# Presolve time: 0.00s
# Presolved: 327 rows, 149 columns, 1004 nonzeros
# Presolved model has 41 quadratic objective terms
# Presolved model has 61 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 149 continuous, 0 integer (0 binary)
# Root relaxation presolved: 322 rows, 145 columns, 990 nonzeros
# Root relaxation presolved model has 40 quadratic objective terms
#
#
# Root relaxation: objective 9.896966e-01, 305 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.98970    0   61    7.06501    0.98970  86.0%     -    0s
#      0     0    0.98970    0   61    7.06501    0.98970  86.0%     -    0s
#      0     0    0.98970    0   61    7.06501    0.98970  86.0%     -    0s
#      0     0    0.98970    0   61    7.06501    0.98970  86.0%     -    0s
#      0     0    0.98970    0   61    7.06501    0.98970  86.0%     -    0s
# H    0     0                       3.4248019    0.98970  71.1%     -    0s
#      0     0    0.98970    0   61    3.42480    0.98970  71.1%     -    0s
# H    0     0                       0.9991513    0.98970  0.95%     -    0s
#
# Cutting planes:
#   RLT: 28
#
# Explored 1 nodes (390 simplex iterations) in 0.22 seconds (0.17 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 3: 0.999151 3.4248 7.06501
#
# Optimal solution found (tolerance 1.00e-01)
# Warning: max constraint violation (1.2026e-06) exceeds tolerance
# Best objective 9.991513143948e-01, best bound 9.896966096528e-01, gap 0.9463%
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: AMD Ryzen 9 7900X 12-Core Processor, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 12 physical cores, 24 logical processors, using up to 24 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 108 rows, 134 columns and 308 nonzeros
# Model fingerprint: 0x224cf63f
# Model has 42 quadratic objective terms
# Model has 21 quadratic constraints
# Coefficient statistics:
#   Matrix range     [5e-01, 1e+02]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [7e-03, 2e+01]
#   Bounds range     [2e+00, 1e+02]
#   RHS range        [4e-03, 1e+00]
# Presolve removed 23 rows and 24 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 46 rows and 47 columns
# Presolve time: 0.00s
# Presolved: 326 rows, 148 columns, 1000 nonzeros
# Presolved model has 41 quadratic objective terms
# Presolved model has 61 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 148 continuous, 0 integer (0 binary)
# Found heuristic solution: objective -139.0873975
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 1: -139.087
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective -1.390873975353e+02, best bound -1.473950754180e+02, gap 5.9730%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: AMD Ryzen 9 7900X 12-Core Processor, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 12 physical cores, 24 logical processors, using up to 24 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 108 rows, 134 columns and 308 nonzeros
# Model fingerprint: 0x955b0a84
# Model has 42 quadratic objective terms
# Model has 21 quadratic constraints
# Coefficient statistics:
#   Matrix range     [5e-01, 1e+02]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [7e-03, 2e+01]
#   Bounds range     [2e+00, 1e+02]
#   RHS range        [4e-03, 1e+00]
# Presolve removed 23 rows and 24 columns
#
# Continuous model is non-convex -- solving as a MIP
#
#
# MIP start from previous solve produced solution with objective 3.34039 (0.03s)
# MIP start from previous solve produced solution with objective 2.74701 (0.09s)
# MIP start from previous solve produced solution with objective 1.47545 (0.09s)
# MIP start from previous solve produced solution with objective 1.31318 (0.09s)
# MIP start from previous solve produced solution with objective 1.29845 (0.09s)
# MIP start from previous solve produced solution with objective 0.963846 (0.10s)
# Loaded MIP start from previous solve with objective 0.963846
#
# Presolve removed 46 rows and 47 columns
# Presolve time: 0.00s
# Presolved: 326 rows, 148 columns, 1000 nonzeros
# Presolved model has 41 quadratic objective terms
# Presolved model has 61 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 148 continuous, 0 integer (0 binary)
#
# Explored 0 nodes (0 simplex iterations) in 0.10 seconds (0.10 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 6: 0.963846 1.29845 1.31318 ... 3.34039
#
# Optimal solution found (tolerance 1.00e-01)
# Warning: max constraint violation (1.1452e-06) exceeds tolerance
# Best objective 9.638464958285e-01, best bound 9.375000000000e-01, gap 2.7335%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: AMD Ryzen 9 7900X 12-Core Processor, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 12 physical cores, 24 logical processors, using up to 24 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 5 rows, 6 columns and 16 nonzeros
# Model fingerprint: 0x88317ff6
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+10]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+10]
# Warning: Model contains large matrix coefficients
# Warning: Model contains large rhs
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 2 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 6 columns, 14 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9629978e+00   0.000000e+00   0.000000e+00      0s
#        0    1.9629978e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.962997810e+00
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: AMD Ryzen 9 7900X 12-Core Processor, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 12 physical cores, 24 logical processors, using up to 24 threads
#
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Optimize a model with 108 rows, 134 columns and 308 nonzeros
# Model fingerprint: 0xc80fab4d
# Model has 42 quadratic objective terms
# Model has 21 quadratic constraints
# Coefficient statistics:
#   Matrix range     [6e-01, 1e+02]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [7e-03, 2e+01]
#   Bounds range     [2e+00, 1e+02]
#   RHS range        [6e-02, 1e+00]
# Presolve removed 23 rows and 24 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 46 rows and 48 columns
# Presolve time: 0.00s
# Presolved: 326 rows, 147 columns, 998 nonzeros
# Presolved model has 41 quadratic objective terms
# Presolved model has 61 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 147 continuous, 0 integer (0 binary)
# Found heuristic solution: objective -0.0649106
# Root relaxation presolved: 321 rows, 143 columns, 984 nonzeros
# Root relaxation presolved model has 40 quadratic objective terms
#
#
# Root relaxation: objective -5.912303e+00, 355 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   -5.91230    0   61   -0.06491   -5.91230  9008%     -    0s
#      0     0   -5.91230    0   56   -0.06491   -5.91230  9008%     -    0s
#      0     0   -5.91230    0   54   -0.06491   -5.91230  9008%     -    0s
#      0     0   -5.91230    0   51   -0.06491   -5.91230  9008%     -    0s
#      0     0   -5.91230    0   51   -0.06491   -5.91230  9008%     -    0s
#      0     0   -5.91230    0   50   -0.06491   -5.91230  9008%     -    0s
# H    0     0                      -4.5953705   -5.83891  27.1%     -    0s
#      0     2   -5.83891    0   51   -4.59537   -5.83891  27.1%     -    0s
# *  194   140              11      -4.9413480   -5.54258  12.2%  47.5    0s
# *  217   168              14      -5.2220258   -5.54258  6.14%  50.9    0s
#
# Cutting planes:
#   RLT: 27
#
# Explored 255 nodes (12598 simplex iterations) in 0.20 seconds (0.16 work units)
# Thread count was 24 (of 24 available processors)
#
# Solution count 4: -5.22203 -4.94135 -4.59537 -0.0649106
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective -5.222025840713e+00, best bound -5.542578593531e+00, gap 6.1385%
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 89
#      86 agg_bundle = None
#      88 t_run0 = perf_counter()
# ---> 89 hist = run_pid_simplex_3d(
#      90     base_bundles=base_bundles,
#      91     ms_bundles=ms_bundles,
#      92     model_list=model_list,
#      93     first_vars_list=first_stg_vars_list,
#      94     target_nodes=target_nodes,
#      95     min_dist=0,
#      96     active_tol=ACTIVE_TOL,
#      97     verbose=True,
#      98     agg_bundle=agg_bundle,
#      99     gap_stop_tol=1e-4,
#     100     use_exact_opt=False,
#     101     exact_solver_name="gurobi",
#     102     exact_solver_opts={"NonConvex": 2, "TimeLimit": 60},
#     103     time_limit=60*20*1,
#     104     enable_3d_plot=False,
#     105     plot_every=None,
#     106 )
#     107 t_run1 = perf_counter()
#     108 print(f"[Time] Main loop total: {t_run1 - t_run0:.3f}s")
#
# File c:\Users\Administrator\OneDrive\Desktop\workspace2026\21 run snoglode data\pid_simplex_no_figures\pid_simplex_mixmscs_time_moreub-clean\simplex_specialstart.py:1606, in run_pid_simplex_3d(base_bundles, ms_bundles, model_list, first_vars_list, target_nodes, min_dist, active_tol, verbose, agg_bundle, gap_stop_tol, tracker, enable_3d_plot, plot_every, use_exact_opt, exact_solver_name, exact_solver_opts, time_limit)
#    1603 new_simplex_indices = list(range(n_simplices_after - n_children, n_simplices_after))
#    1605 # Re-evaluate per_tet for ALL simplices after split (to get updated LB_local values)
# -> 1606 _, per_tet_end = evaluate_all_tetra(
#    1607     nodes, scen_values, ms_bundles, first_vars_list,
#    1608     ms_cache=ms_cache, cache_on=True, tracker=tracker,
#    1609     tet_mesh=tet_mesh,
#    1610     lb_sur_cache=lb_sur_cache,  # LB surrogate cache
#    1611 )
#    1613 # Build per_tet dict for quick lookup
#    1614 per_tet_dict = {r["simplex_index"]: r for r in per_tet_end}
#
# File c:\Users\Administrator\OneDrive\Desktop\workspace2026\21 run snoglode data\pid_simplex_no_figures\pid_simplex_mixmscs_time_moreub-clean\simplex_specialstart.py:383, in evaluate_all_tetra(nodes, scen_values, ms_bundles, first_vars_list, ms_cache, cache_on, tracker, tet_mesh, lb_sur_cache)
#     381     cs_meta_per_scene.append(None)
#     382 else:
# --> 383     ms_val, new_pt_ms, c_val, c_pt = ms_on_tetra_for_scene(
#     384         ms_bundles[ω], verts, fverts_per_scene[ω]
#     385     )
#     386     # Capture solve metadata from the bundle
#     387     ms_meta_per_scene.append(getattr(ms_bundles[ω], 'last_solve_meta', None))
#
# File c:\Users\Administrator\OneDrive\Desktop\workspace2026\21 run snoglode data\pid_simplex_no_figures\pid_simplex_mixmscs_time_moreub-clean\simplex_specialstart.py:271, in ms_on_tetra_for_scene(ms_bundle, tet_vertices, fverts_scene)
#     268     new_pt_ms = None
#     270 # 2) Try solving constant cut regardless of ms success
# --> 271 ok_c, c_val, c_pt = ms_bundle.solve_const_cut()
#     272 if not ok_c:
#     273     print("c_s solve wrong")
#
# File c:\Users\Administrator\OneDrive\Desktop\workspace2026\21 run snoglode data\pid_simplex_no_figures\pid_simplex_mixmscs_time_moreub-clean\bundles.py:427, in MSBundle.solve_const_cut(self)
#     424 self.gp.set_objective(self.obj_const)
#     426 t0 = perf_counter()
# --> 427 res = self.gp.solve(load_solutions=True, tee=True)
#     428 dt = perf_counter() - t0
#     429 self.solve_const_time_hist.append(dt)  # Record c_s solve time
#
# File c:\ProgramData\anaconda3\envs\pidsp-sim-win\Lib\site-packages\pyomo\solvers\plugins\solvers\persistent_solver.py:457, in PersistentSolver.solve(self, *args, **kwds)
#     452         msg += (
#     453             ' to the set_instance method in the persistent solver interface. '
#     454         )
#     455         raise ValueError(msg)
# --> 457 self.available(exception_flag=True)
#     459 # Collect suffix names to try and import from solution.
#     460 if isinstance(self._pyomo_model, BlockData):
#
# File c:\ProgramData\anaconda3\envs\pidsp-sim-win\Lib\site-packages\pyomo\solvers\plugins\solvers\gurobi_direct.py:221, in GurobiDirect.available(self, exception_flag)
#     218     return False
#     220 # Ensure environment is started to check for a valid license
# --> 221 with capture_output(capture_fd=True) as OUT:
#     222     try:
#     223         self._init_env()
#
# File c:\ProgramData\anaconda3\envs\pidsp-sim-win\Lib\site-packages\pyomo\common\tee.py:371, in capture_output.__exit__(self, et, ev, tb)
#     369     raise DeveloperError("Deadlock closing capture_output")
#     370 try:
# --> 371     return self._exit_impl(et, ev, tb)
#     372 finally:
#     373     capture_output.startup_shutdown.release()
#
# File c:\ProgramData\anaconda3\envs\pidsp-sim-win\Lib\site-packages\pyomo\common\tee.py:520, in capture_output._exit_impl(self, et, ev, tb)
#     518 self.output_stream = None
#     519 if FAIL:
# --> 520     raise RuntimeError("\n".join(FAIL))
#
# RuntimeError: KeyboardInterrupt:  (4: <pyomo.common.tee.TeeStream object at 0x00000263620CBFD0>@263620cbfd0)
