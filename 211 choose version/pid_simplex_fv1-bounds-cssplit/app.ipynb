# %%
from time import perf_counter  

from modeling import build_models_from_csv
from bundles import BaseBundle, MSBundle
from utils import (
    tighten_bounds_one_model,
    MIN_DIST, ACTIVE_TOL, GAP_STOP_TOL,
)
from simplex_specialstart import run_pid_simplex_3d

# setup scenario number and target_nodesk
csv_path       = "data.csv"
max_scenarios  = 10
target_nodes   = 1000

bounds={
    "Kp": (-10.0, 10.0),
    "Ki": (-100.0, 100.0),
    "Kd": (-100.0, 100.0),
    "x": (-2.5, 2.5),
    "u": (-5.0, 5.0),
    "e": (None, None),
    "I": (None, None),
}

weights = (10.0, 0.01)


# ====== stage 1：load data and generate models ======
T   = 15.0          
nfe = 20            

t_load0 = perf_counter()
model_list, first_stg_vars_list, m_tmpl_list, nfe = build_models_from_csv(
    csv_path=csv_path,
    T=T,
    nfe=nfe,
    weights=weights,
    bounds=bounds,
    sp0=0.0,
    sp1=0.5,
    tau_xs_col="tau_xs",
    tau_us_col="tau_us",
    tau_ds_col="tau_ds",          
    disturb_prefix="disturbance_",
    setpoint_change_col="setpoint_change",
    max_scenarios=max_scenarios,
    skip=0,
)
t_load1 = perf_counter()
print(f"[Time] Data load & scenario build: {t_load1 - t_load0:.3f}s")


# ====== stage 1.5：FBBT / OBBT ======
# same as snog: FBBT open,OBBT open
obbt_solver_opts = {
    "NonConvex": 2,
    "MIPGap": 1,     
    "TimeLimit": 15   
}
for m, yvars in zip(model_list, first_stg_vars_list):
    tighten_bounds_one_model(m, yvars,
                             use_fbbt=False,
                             use_obbt=False,
                             obbt_solver_name="gurobi",
                             obbt_solver_opts=obbt_solver_opts,
                             max_rounds=3, tol=1e-6, verbose=True)

# ====== stage 2: Persistent Solver Packaging ======
ub_options = {
    'NonConvex': 2,      
}
lb_options = {
    'NonConvex': 2,
    'MIPGap': 1e-1,            
    'TimeLimit': 60 
}

t_wrap0 = perf_counter()
base_bundles = [BaseBundle(m, ub_options) for m in model_list]  
ms_bundles   = [MSBundle(m, yvars, lb_options) for m, yvars in zip(model_list, first_stg_vars_list)]  
t_wrap1 = perf_counter()
print(f"[Time] Persistent wrapper (GurobiPersistent) setup: {t_wrap1 - t_wrap0:.3f}s")

# ====== stage 3：main loop ======
agg_bundle = None  

t_run0 = perf_counter()
hist = run_pid_simplex_3d(
    base_bundles=base_bundles,
    ms_bundles=ms_bundles,
    model_list=model_list,
    first_vars_list=first_stg_vars_list,
    target_nodes=target_nodes,
    min_dist=0,
    active_tol=ACTIVE_TOL,
    verbose=True,
    agg_bundle=agg_bundle,
    gap_stop_tol=1e-6,
    use_exact_opt=False,
    exact_solver_name="gurobi",
    exact_solver_opts={"NonConvex": 2, "TimeLimit": 60},
    time_limit=60*30*1,
    enable_3d_plot=False,   
    plot_every=None,        
)
t_run1 = perf_counter()
print(f"[Time] Main loop total: {t_run1 - t_run0:.3f}s")

# ====== print output ======
print("\n==== Done ====")
print(f"Total nodes: {len(hist['nodes'])}")
print(f"Best UB: {min(hist['UB_hist']) if hist['UB_hist'] else None}")
print(f"Last LB: {hist['LB_hist'][-1] if hist['LB_hist'] else None}")
# Out:
# [Time] Data load & scenario build: 0.150s
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2689754
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 60
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 60
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 60
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 60
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 60
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 60
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 60
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 60
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 60
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 60
# [Time] Persistent wrapper (GurobiPersistent) setup: 2.980s
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [TIMING] Pre-loop vertex Q evals: 1.63s  (8 nodes x 10 scenarios = 80 solves)
# [EF-UB] Initialized ipopt EF with 10 scenarios, time_ub=60.0s
#
# ======================================================================
# [TIMING] === Pre-loop phase summary ===
#   corners_and_mesh               :       0.00s
#   vertex_Q_evals                 :       1.63s
#   exact_optima                   :       0.00s
#   ef_init                        :       0.07s
#   TOTAL                          :       1.71s
# ======================================================================
#
# [Iter 0] MIPGap overridden to 0.1 (original: 0.1)
# Discarded solution information
# [Invariant] MS scen None: dual=-5.500707e+09 > primal=-5.500707e+09
# Discarded solution information
# Discarded solution information
# [Invariant] MS scen None: dual=-5.481254e+09 > primal=-5.481254e+09
# Discarded solution information
# Discarded solution information
# [Invariant] MS scen None: dual=-5.194287e+09 > primal=-5.194287e+09
# Discarded solution information
# Discarded solution information
# Discarded solution information
# Discarded solution information
# Discarded solution information
# [Invariant] MS scen None: dual=-5.806922e+09 > primal=-5.806922e+09
# [Invariant] MS scen None: dual=-5.817119e+09 > primal=-5.817119e+09
# [Invariant] MS scen None: dual=-6.005622e+09 > primal=-6.005622e+09
# [Invariant] MS scen None: dual=-5.982090e+09 > primal=-5.982090e+09
# [Invariant] MS scen None: dual=-5.596691e+09 > primal=-5.596691e+09
# [Invariant] MS scen None: dual=-5.628277e+09 > primal=-5.628277e+09
# [Invariant] MS scen None: dual=-5.719282e+09 > primal=-5.719282e+09
# [Invariant] MS scen None: dual=-5.735561e+09 > primal=-5.735561e+09
# [Invariant] MS scen None: dual=-5.718800e+09 > primal=-5.718800e+09
# [Invariant] MS scen None: dual=-5.912410e+09 > primal=-5.912410e+09
# [Invariant] MS scen None: dual=-5.724298e+09 > primal=-5.724298e+09
# [Invariant] MS scen None: dual=-5.679468e+09 > primal=-5.679468e+09
# [Invariant] MS scen None: dual=-5.610143e+09 > primal=-5.610143e+09
# [Bundle] MS scen None: infeasibleOrUnbounded. ms_val=nan.
# [Bundle] MS scen None: not optimal. Status=warning, Term=infeasibleOrUnbounded.
# [Invariant] MS scen None: dual=-5.870800e+09 > primal=-5.870800e+09
# [Invariant] MS scen None: dual=-5.766877e+09 > primal=-5.766877e+09
# [Invariant] MS scen None: dual=-5.000000e+09 > primal=-5.000000e+09
# [Invariant] MS scen None: dual=-5.788922e+09 > primal=-5.788922e+09
# [Iter 0] MIPGap restored to 0.1
# [Iter 0] #simplices = 6, #active = 6, bad-quality cut = 0, bad-shape cut = 0
# == [Iter 0] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.031046e+00      4.639037e+09     -5.360963e+10      1.031046e+01     [2.23e+01, 1.00e+11]    [-5.36e+10, 4.64e+10]     1
# T1            9.937735e-01      4.082672e+09     -5.917328e+10      9.937735e+00     [2.23e+01, 1.00e+11]    [-5.92e+10, 4.08e+10]     1
# T2            1.024926e+00      4.371904e+09     -5.628096e+10      1.024926e+01     [2.21e+01, 1.00e+11]    [-5.63e+10, 4.37e+10]     1
# T3            1.000442e+00      4.209123e+09     -5.790877e+10      1.000442e+01     [2.21e+01, 1.00e+11]    [-5.79e+10, 4.21e+10]     1
# T4            1.020419e+00      4.317584e+09     -5.682416e+10      1.020419e+01     [2.71e+01, 1.00e+11]    [-5.68e+10, 4.32e+10]     2
# T5            1.015549e+00               inf               inf      1.015549e+01     [2.71e+01, 1.00e+11]               [inf, inf]     2
#
# == [Iter 0] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
#   (none)
# [Iter 0] created=6 (cum=6), active=6, active+UB=2, ms_recomputed=6
# [Iter 0] EF-ipopt: ok=True, ef_obj=0.9796536626177266, true_obj=1.073400e+00, time=0.416s
# [Iter 0] EF-UB improved by ipopt: 1.073400e+00 (per-scen), K=(-9.999826181219058, -99.99967151846334, -5.8938009680806095e-12)
# [Iter 0] Pre-split gap: 7.962695e-01 (7.418%)
# [Iter 0] Active simplex ratio = 1.000000
# [Iter 0] UB point (-9.999826181219058, -99.99967151846334, -5.8938009680806095e-12) is geometrically in simplices [1]
#   T1 verts=[3, 1, 4, 0]: λ=[0.000002, 0.499998, 0.000009, 0.499991], LB=9.937734530, c_s=[0.9960029127022256, 1.0001366770450069, 0.9579954878938712, 1.0551989733060005, 0.9683379558464811, 0.9880759501728958, 1.0108195608832988, 0.9912890927655227, 1.01296369143852, 0.9569142275119016]
#
# == [Iter 0] CS DUAL vs PRIMAL diagnostic (simplices containing UB point) ==
#   --- T1 ---
#     scen 0: status=optimal, dual=0.996002913, primal=0.996002913  ✓ dual ≤ primal (gap=1.110223e-16)
#              cs_primal_K=(-9.999216646683243, -99.99852406033013, 0.9388331317148486)
#              indep_Q(cs_K)=0.996002918  → dual ≤ indep_Q (consistent, diff=4.973934e-09)
#     scen 1: status=optimal, dual=1.000136677, primal=1.000136677  ✓ dual ≤ primal (gap=-2.220446e-16)
#              cs_primal_K=(-9.999983393339464, -0.15781395634996587, 0.00040036514586223133)
#              indep_Q(cs_K)=1.000136678  → dual ≤ indep_Q (consistent, diff=1.132161e-09)
#     scen 2: status=optimal, dual=0.957995488, primal=0.957995488  ✓ dual ≤ primal (gap=-2.220446e-16)
#              cs_primal_K=(-9.998442794608906, -99.99686925671598, -2.736029187431506e-10)
#              indep_Q(cs_K)=0.957995515  → dual ≤ indep_Q (consistent, diff=2.714000e-08)
#     scen 3: status=optimal, dual=1.055198973, primal=1.055198973  ✓ dual ≤ primal (gap=2.220446e-16)
#              cs_primal_K=(-9.233467561678685, -98.4408518452537, 0.32994040845543465)
#              indep_Q(cs_K)=1.055198979  → dual ≤ indep_Q (consistent, diff=5.506025e-09)
#     scen 4: status=optimal, dual=0.968337956, primal=0.968337956  ✓ dual ≤ primal (gap=0.000000e+00)
#              cs_primal_K=(-9.998518091599312, -99.9972050307925, 0.39376151703840556)
#              indep_Q(cs_K)=0.968337957  → dual ≤ indep_Q (consistent, diff=1.643293e-09)
#     scen 5: status=optimal, dual=0.988075950, primal=0.988075950  ✓ dual ≤ primal (gap=-1.110223e-16)
#              cs_primal_K=(-9.628868037677085, -0.004403023617462816, 0.000584032228044548)
#              indep_Q(cs_K)=0.988075957  → dual ≤ indep_Q (consistent, diff=7.198358e-09)
#     scen 6: status=optimal, dual=1.010819561, primal=1.010819561  ✓ dual ≤ primal (gap=-2.220446e-16)
#              cs_primal_K=(-9.999258333905566, -99.99876016143422, 1.9640715296828297)
#              indep_Q(cs_K)=1.010819562  → dual ≤ indep_Q (consistent, diff=1.096565e-09)
#     scen 7: status=optimal, dual=0.991289093, primal=0.991289093  ✓ dual ≤ primal (gap=0.000000e+00)
#              cs_primal_K=(-9.987990535473328, -75.22276794488953, -6.309053858324999)
#              indep_Q(cs_K)=0.991289096  → dual ≤ indep_Q (consistent, diff=3.050211e-09)
#     scen 8: status=optimal, dual=1.012963691, primal=1.012963691  ✓ dual ≤ primal (gap=-2.220446e-16)
#              cs_primal_K=(-10.0, -90.12358626125518, 0.5687336812924049)
#              indep_Q(cs_K)=1.012963693  → dual ≤ indep_Q (consistent, diff=1.468491e-09)
#     scen 9: status=optimal, dual=0.956914228, primal=0.956914228  ✓ dual ≤ primal (gap=-1.110223e-16)
#              cs_primal_K=(-9.997407327768787, -99.99533837759942, 1.2699015901737298)
#              indep_Q(cs_K)=0.956914233  → dual ≤ indep_Q (consistent, diff=5.864871e-09)
#   sum(c_s_dual)=9.937734530, UB_total=107.340040355, UB_per_scen=10.734004035
#
#   == Per-scenario Q_s at K_EF = (-9.999826181219058, -99.99967151846334, -5.8938009680806095e-12) ==
#     scen 0: Q_s(K_EF)=1.090435851, c_s_dual=0.996002913  ✓ Q_s(K_EF) > c_s_dual (diff=9.443294e-02)
#     scen 1: Q_s(K_EF)=1.039363470, c_s_dual=1.000136677  ✓ Q_s(K_EF) > c_s_dual (diff=3.922679e-02)
#     scen 2: Q_s(K_EF)=1.051741935, c_s_dual=0.957995488  ✓ Q_s(K_EF) > c_s_dual (diff=9.374645e-02)
#     scen 3: Q_s(K_EF)=1.148392308, c_s_dual=1.055198973  ✓ Q_s(K_EF) > c_s_dual (diff=9.319333e-02)
#     scen 4: Q_s(K_EF)=1.062205005, c_s_dual=0.968337956  ✓ Q_s(K_EF) > c_s_dual (diff=9.386705e-02)
#     scen 5: Q_s(K_EF)=1.036712249, c_s_dual=0.988075950  ✓ Q_s(K_EF) > c_s_dual (diff=4.863630e-02)
#     scen 6: Q_s(K_EF)=1.107378750, c_s_dual=1.010819561  ✓ Q_s(K_EF) > c_s_dual (diff=9.655919e-02)
#     scen 7: Q_s(K_EF)=1.040982650, c_s_dual=0.991289093  ✓ Q_s(K_EF) > c_s_dual (diff=4.969356e-02)
#     scen 8: Q_s(K_EF)=1.104837983, c_s_dual=1.012963691  ✓ Q_s(K_EF) > c_s_dual (diff=9.187429e-02)
#     scen 9: Q_s(K_EF)=1.051953835, c_s_dual=0.956914228  ✓ Q_s(K_EF) > c_s_dual (diff=9.503961e-02)
#     SUM Q_s(K_EF)=10.734004035, sum(c_s)=9.937734530, diff=7.962695e-01
#
# [Iter 0] LB = 9.937735 = UB(10.734004) + ms_b(-5.917e+10) from T1
# [Iter 0] Split point (avgCS): (-9.884315, -76.393612, -0.084283)
#   -> Accepted. loc_type=interior
# [Iter 0] per_tet=6, active after q_cut=6, tri_is_None=False
# [Iter 0] bad-quality active simplices (q < 0): 0
# [Iter 0] evaluating Q for scenario 0
# [Iter 0] evaluating Q for scenario 1
# [Iter 0] evaluating Q for scenario 2
# [Iter 0] evaluating Q for scenario 3
# [Iter 0] evaluating Q for scenario 4
# [Iter 0] evaluating Q for scenario 5
# [Iter 0] evaluating Q for scenario 6
# [Iter 0] evaluating Q for scenario 7
# [Iter 0] evaluating Q for scenario 8
# [Iter 0] evaluating Q for scenario 9
# [Iter 0] subdivision type = interior (code=1) on simplex T1
# [Iter 0] Elapsed: 66.470s
# [Invariant] MS scen None: dual=-5.977595e+09 > primal=-5.977595e+09
# [Invariant] MS scen None: dual=-6.039530e+09 > primal=-6.039530e+09
# [Invariant] MS scen None: dual=-5.878482e+09 > primal=-5.878482e+09
# [Invariant] MS scen None: dual=-5.954183e+09 > primal=-5.954183e+09
# [Invariant] MS scen None: dual=-6.037884e+09 > primal=-6.037884e+09
# [Invariant] MS scen None: dual=-5.954546e+09 > primal=-5.954546e+09
# [Invariant] MS scen None: dual=-5.495750e+09 > primal=-5.495750e+09
# [Invariant] MS scen None: dual=-5.833499e+09 > primal=-5.833499e+09
# [Iter 0] UB candidate from new simplex 5 (avgCS): 9.793882e-01 (per scenario)
#
# ======================================================================
# [TIMING] === Iter 0 phase breakdown (total 729.99s) ===
#   1_vertex_UB                    :       0.00s  (  0.0%)
#   2_evaluate_all_tetra           :      65.03s  (  8.9%)  ####
#   3_active_filter_print          :       0.00s  (  0.0%)
#   4_LB_selection                 :       0.00s  (  0.0%)
#   5_EF_UB_solve                  :       0.81s  (  0.1%)
#   6_candidate_selection          :       0.54s  (  0.1%)
#   7_Q_eval_new_node              :       0.09s  (  0.0%)
#   8_mesh_subdivide               :       0.00s  (  0.0%)
#   9_end_of_iter_reeval           :     663.52s  ( 90.9%)  #############################################
#   TOTAL                          :     729.99s
#   #simplices=6, #scenarios=10, total_ms_pairs=60
#   fresh ms solves=60, cache hits=0
# ======================================================================
#
# ======================================================================
# [Iter 0] LB SPLIT DIAGNOSTIC
#   Selected (parent) simplex: (0, 1, 3, 4)
#   Parent LB: 0.993773453 (per-scen)
#   Parent avg constant cut: 0.993773453 (per-scen)
#   Parent avg c_s Q-value: 0.982897054 (per-scen), point=(np.float64(-9.884315272273437), np.float64(-76.3936119918238), np.float64(-0.08428276028670419))
#   EF ef_obj(IPOPT): 0.097965366, true_obj(recalc): 1.073400404, used=min=0.097965366 (per-scen)
#   Simplex volume: 1.333333e+05
#   Children (4):
#     T5 (0, 1, 4, 8): LB=0.978954000, avg_cut=0.978954000, avg_cs_Q=0.979388215
#     T6 (0, 3, 4, 8): LB=0.993063312, avg_cut=0.993063312, avg_cs_Q=0.987312634
#     T7 (0, 1, 3, 8): LB=0.990763557, avg_cut=0.990763557, avg_cs_Q=0.980090431
#     T8 (1, 3, 4, 8): LB=0.994909268, avg_cut=0.994909268, avg_cs_Q=0.984047082
#   New global LB: 0.978954000 (from T5 (0, 1, 4, 8))
#   Location: INSIDE
#   EF-IPOPT: ok=True, status=ok, term=optimal, time=0.416s, ef_obj=0.9796536626177266, true_obj(per-scen)=1.073400404
#   Current UB (end-of-iter): 0.979388215 (per-scen)
#   UB point: (np.float64(-7.677925048130189), np.float64(-99.9999195327648), np.float64(0.8498417048863379))
#   UB source: avgCS_new_simplex
#   UB simplex: (0, 1, 4, 8)
#   UB updated this iter: True
# ======================================================================
# [Iter 1] #simplices = 9, #active = 1, bad-quality cut = 0, bad-shape cut = 0
# == [Iter 1] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T5            9.789540e-01      4.060386e+09     -5.939614e+10      9.789540e+00     [9.83e+00, 1.00e+11]    [-5.94e+10, 4.06e+10]     1
#
# == [Iter 1] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.031046e+00      4.639037e+09     -5.360963e+10      1.031046e+01     [2.23e+01, 1.00e+11]    [-5.36e+10, 4.64e+10]     1
# T1            1.024926e+00      4.371904e+09     -5.628096e+10      1.024926e+01     [2.21e+01, 1.00e+11]    [-5.63e+10, 4.37e+10]     1
# T2            1.000442e+00      4.209123e+09     -5.790877e+10      1.000442e+01     [2.21e+01, 1.00e+11]    [-5.79e+10, 4.21e+10]     1
# T3            1.020419e+00      4.317584e+09     -5.682416e+10      1.020419e+01     [2.71e+01, 1.00e+11]    [-5.68e+10, 4.32e+10]     2
# T4            1.015549e+00               inf               inf      1.015549e+01     [2.71e+01, 1.00e+11]               [inf, inf]     2
# T6            9.930633e-01      1.390801e+00     -1.338196e+01      9.930633e+00     [9.83e+00, 2.73e+01]    [-3.55e+00, 1.39e+01]     0
# T7            9.907636e-01      4.017732e+09     -5.982268e+10      9.907636e+00     [9.83e+00, 1.00e+11]    [-5.98e+10, 4.02e+10]     1
# T8            9.949093e-01      4.329639e+09     -5.670361e+10      9.949093e+00     [9.83e+00, 1.00e+11]    [-5.67e+10, 4.33e+10]     1
#
# [Iter 1] created=9 (cum=19), active=1, active+UB=1, ms_recomputed=0
# [Iter 1] EF-ipopt: ok=True, ef_obj=0.9817861081388635, true_obj=9.823345e-01, time=0.594s
# [Iter 1] Pre-split gap: 4.342152e-03 (0.044%)
# [Iter 1] Active simplex ratio = 0.019672
# [Iter 1] UB point (-9.884315272273437, -76.3936119918238, -0.08428276028670419) is geometrically in simplices [5, 6, 7, 8]
#   T5 verts=[8, 1, 4, 0]: λ=[1.000000, 0.000000, -0.000000, -0.000000], LB=9.789539997, c_s=[0.996002579128584, 0.9451351114402776, 0.955933926220587, 1.0545523581981517, 0.9683380862296587, 0.9429431837145341, 1.0119627568342409, 0.9467965779831465, 1.0107750085368468, 0.9571004082226424]
#   T6 verts=[3, 8, 4, 0]: λ=[0.000000, 1.000000, 0.000000, -0.000000], LB=9.930633122, c_s=[1.0007971488138345, 0.9621802542339802, 0.9888154908523229, 1.0627244994460652, 0.970408957557059, 0.9429888195118473, 1.016357935844177, 0.9662904625801005, 1.0176534384137643, 1.0024161149163526]
#   T7 verts=[3, 1, 8, 0]: λ=[0.000000, -0.000000, 1.000000, -0.000000], LB=9.907635573, c_s=[0.9960718434755081, 0.9464843442659023, 0.9561329398187755, 1.1555742896892416, 0.9712547431607108, 0.9433861608681668, 1.0190039671941398, 0.9509505144384885, 1.0107666926147145, 0.9580100778056406]
#   T8 verts=[3, 1, 4, 8]: λ=[0.000000, -0.000000, -0.000000, 1.000000], LB=9.949092678, c_s=[0.9996230854254845, 0.9479000523951582, 0.9567511814950647, 1.085097894575337, 1.0152729655192732, 0.9429416111335351, 1.0780867733312454, 0.9475534560579179, 1.0160161467762652, 0.9598495112485249]
#
# == [Iter 1] CS DUAL vs PRIMAL diagnostic (simplices containing UB point) ==
#   --- T5 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 0.9401331985529987)
#              indep_Q(cs_K)=0.996002589
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 0.8957219337704976)
#              indep_Q(cs_K)=0.945135113
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 1.6144819309355232)
#              indep_Q(cs_K)=0.955933942
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999167507678752, -99.999195327648, 0.34762461115314874)
#              indep_Q(cs_K)=1.054552379
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 0.3696675450969663)
#              indep_Q(cs_K)=0.968338087
#     scen 5: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-0.04680282161004651, -100.0, 0.468028216100465)
#              indep_Q(cs_K)=0.942941134
#     scen 6: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-5.604797787749602, -100.0, 1.7017972638155483)
#              indep_Q(cs_K)=1.011962757
#     scen 7: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-1.128482364263496, -100.0, 0.8068492844829918)
#              indep_Q(cs_K)=0.946796578
#     scen 8: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 0.5559170205031332)
#              indep_Q(cs_K)=1.010775009
#     scen 9: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 0.7981960444521071)
#              indep_Q(cs_K)=0.957100453
#   sum(c_s_dual)=0.000000000, UB_total=97.938821489, UB_per_scen=9.793882149
#
#   == Per-scenario Q_s at K_EF = (-9.884315272273437, -76.3936119918238, -0.08428276028670419) ==
#     scen 0: Q_s(K_EF)=1.000947298, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.946335886, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.960072565, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.061544488, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.970565859, c_s_dual=N/A
#     scen 5: Q_s(K_EF)=0.943376422, c_s_dual=N/A
#     scen 6: Q_s(K_EF)=1.020075354, c_s_dual=N/A
#     scen 7: Q_s(K_EF)=0.947864769, c_s_dual=N/A
#     scen 8: Q_s(K_EF)=1.017797877, c_s_dual=N/A
#     scen 9: Q_s(K_EF)=0.960390021, c_s_dual=N/A
#     SUM Q_s(K_EF)=9.828970540, sum(c_s)=0.000000000, diff=9.828971e+00
#   --- T6 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.884412781637057, -76.24493178839494, 7.716268783823588e-05)
#              indep_Q(cs_K)=1.000797170
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-7.913744493078466, -55.535343474609526, 3.109828191827834)
#              indep_Q(cs_K)=0.962180277
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-5.385159806923184, -44.11646214116626, -1.454883830543384)
#              indep_Q(cs_K)=0.988815495
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.711441840784017, -73.74251999929285, 0.010630106483435169)
#              indep_Q(cs_K)=1.062724504
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.884736061550532, -75.7506629695711, 0.2805125645360021)
#              indep_Q(cs_K)=0.970409269
#     scen 5: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.884957292212981, -75.4016496380971, 0.4784632634472055)
#              indep_Q(cs_K)=0.942988825
#     scen 6: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.88647107433647, -73.10560648127795, 1.7812986970999272)
#              indep_Q(cs_K)=1.016357938
#     scen 7: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-2.1881171275076645, -11.490374937400516, 0.5261777824664762)
#              indep_Q(cs_K)=0.966290523
#     scen 8: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.884735201063995, -75.75290949702399, 0.27924392653831775)
#              indep_Q(cs_K)=1.017653443
#     scen 9: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.985565850441246, -8.951225687802527, 0.5699988722770668)
#              indep_Q(cs_K)=1.002416115
#   sum(c_s_dual)=0.000000000, UB_total=97.938821489, UB_per_scen=9.793882149
#
#   == Per-scenario Q_s at K_EF = (-9.884315272273437, -76.3936119918238, -0.08428276028670419) ==
#     scen 0: Q_s(K_EF)=1.000947298, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.946335886, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.960072565, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.061544488, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.970565859, c_s_dual=N/A
#     scen 5: Q_s(K_EF)=0.943376422, c_s_dual=N/A
#     scen 6: Q_s(K_EF)=1.020075354, c_s_dual=N/A
#     scen 7: Q_s(K_EF)=0.947864769, c_s_dual=N/A
#     scen 8: Q_s(K_EF)=1.017797877, c_s_dual=N/A
#     scen 9: Q_s(K_EF)=0.960390021, c_s_dual=N/A
#     SUM Q_s(K_EF)=9.828970540, sum(c_s)=0.000000000, diff=9.828971e+00
#   --- T7 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 1.2275754739209848)
#              indep_Q(cs_K)=0.996071863
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -99.44723342413963, 2.020340368174946)
#              indep_Q(cs_K)=0.946484346
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 2.1317569021082736)
#              indep_Q(cs_K)=0.956132940
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.970934057465271, -19.433749943220132, -0.0012035355234585746)
#              indep_Q(cs_K)=1.155574290
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 2.210462274295284)
#              indep_Q(cs_K)=0.971254743
#     scen 5: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -99.10247403223181, 1.3157347531077357)
#              indep_Q(cs_K)=0.943386161
#     scen 6: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, -1.5034087611504918)
#              indep_Q(cs_K)=1.019003974
#     scen 7: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 2.9606346565209263)
#              indep_Q(cs_K)=0.950950517
#     scen 8: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999993845015231, -99.99746917167155, 0.6636600565617389)
#              indep_Q(cs_K)=1.010766694
#     scen 9: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -78.35916128373219, 1.455834492190522)
#              indep_Q(cs_K)=0.958010078
#   sum(c_s_dual)=0.000000000, UB_total=97.938821489, UB_per_scen=9.793882149
#
#   == Per-scenario Q_s at K_EF = (-9.884315272273437, -76.3936119918238, -0.08428276028670419) ==
#     scen 0: Q_s(K_EF)=1.000947298, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.946335886, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.960072565, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.061544488, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.970565859, c_s_dual=N/A
#     scen 5: Q_s(K_EF)=0.943376422, c_s_dual=N/A
#     scen 6: Q_s(K_EF)=1.020075354, c_s_dual=N/A
#     scen 7: Q_s(K_EF)=0.947864769, c_s_dual=N/A
#     scen 8: Q_s(K_EF)=1.017797877, c_s_dual=N/A
#     scen 9: Q_s(K_EF)=0.960390021, c_s_dual=N/A
#     SUM Q_s(K_EF)=9.828970540, sum(c_s)=0.000000000, diff=9.828971e+00
#   --- T8 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-0.0032120009964145485, -99.99142677598051, -1.8209512858750664e-07)
#              indep_Q(cs_K)=0.999623088
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-0.22049541647393384, -100.0, 2.204954164739325)
#              indep_Q(cs_K)=0.947900053
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-7.023437522961332, -82.76926910900244, 1.1880757622665319)
#              indep_Q(cs_K)=0.956751183
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-0.6558471432168037, -61.665607724745456, 0.0)
#              indep_Q(cs_K)=1.085097895
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(0.0, -37.000524496243415, -1.454417814365302)
#              indep_Q(cs_K)=1.015272967
#     scen 5: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-0.1390688872566398, -99.76382343173415, 0.47179956018642555)
#              indep_Q(cs_K)=0.942941611
#     scen 6: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-4.398575390069775, -35.47845120258173, 0.03694727792653009)
#              indep_Q(cs_K)=1.078086774
#     scen 7: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(0.0, -100.0, 0.0)
#              indep_Q(cs_K)=0.947553457
#     scen 8: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-0.06680897470538481, -99.99224586590418, 0.6377754289172889)
#              indep_Q(cs_K)=1.016016150
#     scen 9: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-0.25057459004720406, -100.0, 2.505745900472039)
#              indep_Q(cs_K)=0.959849576
#   sum(c_s_dual)=0.000000000, UB_total=97.938821489, UB_per_scen=9.793882149
#
#   == Per-scenario Q_s at K_EF = (-9.884315272273437, -76.3936119918238, -0.08428276028670419) ==
#     scen 0: Q_s(K_EF)=1.000947298, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.946335886, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.960072565, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.061544488, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.970565859, c_s_dual=N/A
#     scen 5: Q_s(K_EF)=0.943376422, c_s_dual=N/A
#     scen 6: Q_s(K_EF)=1.020075354, c_s_dual=N/A
#     scen 7: Q_s(K_EF)=0.947864769, c_s_dual=N/A
#     scen 8: Q_s(K_EF)=1.017797877, c_s_dual=N/A
#     scen 9: Q_s(K_EF)=0.960390021, c_s_dual=N/A
#     SUM Q_s(K_EF)=9.828970540, sum(c_s)=0.000000000, diff=9.828971e+00
#
# [Iter 1] LB = 9.789540 = UB(9.793882) + ms_b(-5.940e+10) from T5
# [Iter 1] Split point (avgCS): (-7.677925, -99.99992, 0.849842)
#   -> Accepted. loc_type=interior
# [Iter 1] per_tet=9, active after q_cut=1, tri_is_None=False
# [Iter 1] bad-quality active simplices (q < 0): 0
# [Iter 1] evaluating Q for scenario 0
# [Iter 1] evaluating Q for scenario 1
# [Iter 1] evaluating Q for scenario 2
# [Iter 1] evaluating Q for scenario 3
# [Iter 1] evaluating Q for scenario 4
# [Iter 1] evaluating Q for scenario 5
# [Iter 1] evaluating Q for scenario 6
# [Iter 1] evaluating Q for scenario 7
# [Iter 1] evaluating Q for scenario 8
# [Iter 1] evaluating Q for scenario 9
# [Iter 1] subdivision type = interior (code=1) on simplex T5
# [Iter 1] Elapsed: 4.188s
# [Invariant] MS scen None: dual=-5.872330e+09 > primal=-5.872330e+09
# [Invariant] MS scen None: dual=-5.895504e+09 > primal=-5.895504e+09
# [Invariant] MS scen None: dual=-5.903774e+09 > primal=-5.903774e+09
# [Invariant] MS scen None: dual=-5.915451e+09 > primal=-5.915451e+09
# [Invariant] MS scen None: dual=-5.886392e+09 > primal=-5.886392e+09
# [Invariant] MS scen None: dual=-5.888275e+09 > primal=-5.888275e+09
# [Invariant] MS scen None: dual=-5.979210e+09 > primal=-5.979210e+09
# [Invariant] MS scen None: dual=-5.968851e+09 > primal=-5.968851e+09
# [Invariant] MS scen None: dual=-5.970140e+09 > primal=-5.970140e+09
# [Invariant] MS scen None: dual=-5.978327e+09 > primal=-5.978327e+09
# [Invariant] MS scen None: dual=-5.603023e+09 > primal=-5.603023e+09
# [Invariant] MS scen None: dual=-5.770817e+09 > primal=-5.770817e+09
# [Invariant] MS scen None: dual=-5.849186e+09 > primal=-5.849186e+09
# [BaseBundle.eval_at] Infeasible/Error for K=(-3.583549187176962, -100.0, 17.972498526141415): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-3.583549187176962, -100.0, 17.972498526141415): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-3.583549187176962, -100.0, 17.972498526141415): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-3.583549187176962, -100.0, 17.972498526141415): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-3.583549187176962, -100.0, 17.972498526141415): status=warning, term=infeasibleOrUnbounded
# [Iter 1] UB candidate from new simplex 8 (avgCS): 9.790097e-01 (per scenario)
#
# ======================================================================
# [TIMING] === Iter 1 phase breakdown (total 195.49s) ===
#   1_vertex_UB                    :       0.00s  (  0.0%)
#   2_evaluate_all_tetra           :       0.00s  (  0.0%)
#   3_active_filter_print          :       0.00s  (  0.0%)
#   4_LB_selection                 :       0.00s  (  0.0%)
#   5_EF_UB_solve                  :       3.39s  (  1.7%)
#   6_candidate_selection          :       0.00s  (  0.0%)
#   7_Q_eval_new_node              :       0.79s  (  0.4%)
#   8_mesh_subdivide               :       0.00s  (  0.0%)
#   9_end_of_iter_reeval           :     191.30s  ( 97.9%)  ################################################
#   TOTAL                          :     195.49s
#   #simplices=9, #scenarios=10, total_ms_pairs=90
#   fresh ms solves=0, cache hits=90
# ======================================================================
#
# ======================================================================
# [Iter 1] LB SPLIT DIAGNOSTIC
#   Selected (parent) simplex: (0, 1, 4, 8)
#   Parent LB: 0.978954000 (per-scen)
#   Parent avg constant cut: 0.978954000 (per-scen)
#   Parent avg c_s Q-value: 0.979388215 (per-scen), point=(np.float64(-7.677925048130189), np.float64(-99.9999195327648), np.float64(0.8498417048863379))
#   EF ef_obj(IPOPT): 0.098178611, true_obj(recalc): 0.982334472, used=min=0.098178611 (per-scen)
#   Simplex volume: 1.573759e+04
#   Children (4):
#     T8 (0, 1, 4, 9): LB=0.978827678, avg_cut=0.978827678, avg_cs_Q=0.979009717
#     T9 (0, 4, 8, 9): LB=0.979344071, avg_cut=0.979344071, avg_cs_Q=0.979448395
#     T10 (0, 1, 8, 9): LB=0.978849186, avg_cut=0.978849186, avg_cs_Q=0.979283538
#     T11 (1, 4, 8, 9): LB=0.979928814, avg_cut=0.979928814, avg_cs_Q=0.979736452
#   New global LB: 0.978827678 (from T8 (0, 1, 4, 9))
#   Location: INSIDE
#   EF-IPOPT: ok=True, status=ok, term=optimal, time=0.594s, ef_obj=0.9817861081388635, true_obj(per-scen)=0.982334472
#   Current UB (end-of-iter): 0.979009717 (per-scen)
#   UB point: (np.float64(-9.959113411333826), np.float64(-100.0), np.float64(0.8810626333082169))
#   UB source: avgCS_new_simplex
#   UB simplex: (0, 1, 4, 9)
#   UB updated this iter: True
# ======================================================================
# [Iter 2] #simplices = 12, #active = 2, bad-quality cut = 0, bad-shape cut = 0
# == [Iter 2] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T8            9.788277e-01      4.101375e+09     -5.898625e+10      9.788277e+00     [9.79e+00, 1.00e+11]    [-5.90e+10, 4.10e+10]     1
# T10           9.788492e-01      4.025127e+09     -5.974873e+10      9.788492e+00     [9.79e+00, 1.00e+11]    [-5.97e+10, 4.03e+10]     1
#
# == [Iter 2] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.031046e+00      4.639037e+09     -5.360963e+10      1.031046e+01     [2.23e+01, 1.00e+11]    [-5.36e+10, 4.64e+10]     1
# T1            1.024926e+00      4.371904e+09     -5.628096e+10      1.024926e+01     [2.21e+01, 1.00e+11]    [-5.63e+10, 4.37e+10]     1
# T2            1.000442e+00      4.209123e+09     -5.790877e+10      1.000442e+01     [2.21e+01, 1.00e+11]    [-5.79e+10, 4.21e+10]     1
# T3            1.020419e+00      4.317584e+09     -5.682416e+10      1.020419e+01     [2.71e+01, 1.00e+11]    [-5.68e+10, 4.32e+10]     2
# T4            1.015549e+00               inf               inf      1.015549e+01     [2.71e+01, 1.00e+11]               [inf, inf]     2
# T5            9.930633e-01      1.390801e+00     -1.338196e+01      9.930633e+00     [9.83e+00, 2.73e+01]    [-3.55e+00, 1.39e+01]     0
# T6            9.907636e-01      4.017732e+09     -5.982268e+10      9.907636e+00     [9.83e+00, 1.00e+11]    [-5.98e+10, 4.02e+10]     1
# T7            9.949093e-01      4.329639e+09     -5.670361e+10      9.949093e+00     [9.83e+00, 1.00e+11]    [-5.67e+10, 4.33e+10]     1
# T9            9.793441e-01      2.521195e+00     -2.078012e+00      9.793441e+00     [9.79e+00, 2.73e+01]     [7.72e+00, 2.52e+01]     0
# T11           9.799288e-01      4.227320e+09     -5.772680e+10      9.799288e+00     [9.79e+00, 1.00e+11]    [-5.77e+10, 4.23e+10]     1
#
# [Iter 2] created=12 (cum=35), active=2, active+UB=2, ms_recomputed=0
# [Iter 2] EF-ipopt: ok=True, ef_obj=0.9817860765320464, true_obj=9.823345e-01, time=0.318s
# [Iter 2] Pre-split gap: 1.820392e-03 (0.019%)
# [Iter 2] Active simplex ratio = 0.002284
# [Iter 2] UB point (-7.677925048130189, -99.9999195327648, 0.8498417048863379) is geometrically in simplices [8, 9, 10, 11]
#   T8 verts=[9, 1, 4, 0]: λ=[1.000000, 0.000000, 0.000000, -0.000000], LB=9.788276777, c_s=[0.9961356651877146, 0.945131943792999, 0.9560615302612147, 1.054552522386956, 0.968337627175378, 0.9427911815673652, 1.0108506899143037, 0.9467301443414103, 1.0107674411329275, 0.9569180309315676]
#   T9 verts=[8, 9, 4, 0]: λ=[0.000000, 1.000000, 0.000000, -0.000000], LB=9.793440713, c_s=[0.9965309018977573, 0.9451661307474667, 0.9565678037681715, 1.0555225025260138, 0.9687330738010722, 0.9428090739366616, 1.012386939274432, 0.9467308508557845, 1.0117454013104852, 0.9572480344371782]
#   T10 verts=[8, 1, 9, 0]: λ=[0.000000, 0.000000, 1.000000, -0.000000], LB=9.788491864, c_s=[0.9960282565413208, 0.9451328584824872, 0.9562709321141116, 1.054552738985068, 0.9683399772591049, 0.9428565207617621, 1.0108468172061849, 0.9467772148057133, 1.0107722321426078, 0.9569143154948279]
#   T11 verts=[8, 1, 4, 9]: λ=[0.000000, 0.000000, -0.000000, 1.000000], LB=9.799288136, c_s=[0.9966546314252177, 0.9452313088214509, 0.9560543947356935, 1.056431356490113, 0.968633944495933, 0.9428507870168371, 1.0169497132839498, 0.9467442484825023, 1.0125774076486873, 0.9571603435138514]
#
# == [Iter 2] CS DUAL vs PRIMAL diagnostic (simplices containing UB point) ==
#   --- T8 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 1.3378762867027563)
#              indep_Q(cs_K)=0.996135668
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 0.7027648037358979)
#              indep_Q(cs_K)=0.945131945
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.592792983754194, -100.0, 1.2732557542818992)
#              indep_Q(cs_K)=0.956061532
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.998341129584063, -100.0, 0.34761536601368936)
#              indep_Q(cs_K)=1.054552544
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 0.3950790616831352)
#              indep_Q(cs_K)=0.968337629
#     scen 5: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 0.36016930518907986)
#              indep_Q(cs_K)=0.942791185
#     scen 6: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 1.7652631851400036)
#              indep_Q(cs_K)=1.010850706
#     scen 7: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 0.6663037579831321)
#              indep_Q(cs_K)=0.946730144
#     scen 8: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 0.6232558569816946)
#              indep_Q(cs_K)=1.010767449
#     scen 9: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 1.3390429553708798)
#              indep_Q(cs_K)=0.956918033
#   sum(c_s_dual)=0.000000000, UB_total=97.900971684, UB_per_scen=9.790097168
#
#   == Per-scenario Q_s at K_EF = (-7.677925048130189, -99.9999195327648, 0.8498417048863379) ==
#     scen 0: Q_s(K_EF)=0.996526401, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945168992, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.956564190, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.055779008, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968794231, c_s_dual=N/A
#     scen 5: Q_s(K_EF)=0.942931731, c_s_dual=N/A
#     scen 6: Q_s(K_EF)=1.012386949, c_s_dual=N/A
#     scen 7: Q_s(K_EF)=0.946730713, c_s_dual=N/A
#     scen 8: Q_s(K_EF)=1.011772295, c_s_dual=N/A
#     scen 9: Q_s(K_EF)=0.957227639, c_s_dual=N/A
#     SUM Q_s(K_EF)=9.793882149, sum(c_s)=0.000000000, diff=9.793882e+00
#   --- T9 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-7.678599333687491, -99.99991955613093, 0.8205568656251911)
#              indep_Q(cs_K)=0.996530909
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-7.6791017663441785, -99.99991957354182, 0.7987357552198143)
#              indep_Q(cs_K)=0.945166137
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-7.68229367513465, -99.95317903956796, 0.8479932691291939)
#              indep_Q(cs_K)=0.956567851
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-7.690461954777151, -99.99991996720824, 0.3053523679693998)
#              indep_Q(cs_K)=1.055522505
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-7.808745310591322, -98.01224109891356, 0.45764686350299516)
#              indep_Q(cs_K)=0.968733102
#     scen 5: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-7.686335431783635, -99.99991982421118, 0.484571040627886)
#              indep_Q(cs_K)=0.942809077
#     scen 6: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-7.67792513437267, -99.99991861005108, 0.8498416683736623)
#              indep_Q(cs_K)=1.012386949
#     scen 7: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-7.683518765051969, -99.94007200420246, 0.84747348018578)
#              indep_Q(cs_K)=0.946730852
#     scen 8: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-7.684709225619063, -99.99991976785799, 0.5551986636271192)
#              indep_Q(cs_K)=1.011745402
#     scen 9: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-7.678535387578963, -99.99991955391499, 0.8233341036801374)
#              indep_Q(cs_K)=0.957248236
#   sum(c_s_dual)=0.000000000, UB_total=97.900971684, UB_per_scen=9.790097168
#
#   == Per-scenario Q_s at K_EF = (-7.677925048130189, -99.9999195327648, 0.8498417048863379) ==
#     scen 0: Q_s(K_EF)=0.996526401, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945168992, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.956564190, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.055779008, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968794231, c_s_dual=N/A
#     scen 5: Q_s(K_EF)=0.942931731, c_s_dual=N/A
#     scen 6: Q_s(K_EF)=1.012386949, c_s_dual=N/A
#     scen 7: Q_s(K_EF)=0.946730713, c_s_dual=N/A
#     scen 8: Q_s(K_EF)=1.011772295, c_s_dual=N/A
#     scen 9: Q_s(K_EF)=0.957227639, c_s_dual=N/A
#     SUM Q_s(K_EF)=9.793882149, sum(c_s)=0.000000000, diff=9.793882e+00
#   --- T10 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 0.760828163255195)
#              indep_Q(cs_K)=0.996028289
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 0.882061939638992)
#              indep_Q(cs_K)=0.945132860
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.952154408277995, -90.236726793012, 1.2675065723922225)
#              indep_Q(cs_K)=0.956270953
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 0.314258629240746)
#              indep_Q(cs_K)=1.054552740
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 0.448082794595395)
#              indep_Q(cs_K)=0.968339978
#     scen 5: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.945144897911957, -88.80638050011929, 0.4827333040783662)
#              indep_Q(cs_K)=0.942856521
#     scen 6: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 1.7779641405476412)
#              indep_Q(cs_K)=1.010846836
#     scen 7: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-8.511032275338518, -91.18693635059515, 0.8922578625187461)
#              indep_Q(cs_K)=0.946777217
#     scen 8: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 0.5745394735734828)
#              indep_Q(cs_K)=1.010772243
#     scen 9: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 1.291920067382963)
#              indep_Q(cs_K)=0.956914321
#   sum(c_s_dual)=0.000000000, UB_total=97.900971684, UB_per_scen=9.790097168
#
#   == Per-scenario Q_s at K_EF = (-7.677925048130189, -99.9999195327648, 0.8498417048863379) ==
#     scen 0: Q_s(K_EF)=0.996526401, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945168992, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.956564190, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.055779008, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968794231, c_s_dual=N/A
#     scen 5: Q_s(K_EF)=0.942931731, c_s_dual=N/A
#     scen 6: Q_s(K_EF)=1.012386949, c_s_dual=N/A
#     scen 7: Q_s(K_EF)=0.946730713, c_s_dual=N/A
#     scen 8: Q_s(K_EF)=1.011772295, c_s_dual=N/A
#     scen 9: Q_s(K_EF)=0.957227639, c_s_dual=N/A
# ...
#              cs_primal_K=(-9.879770741922856, -100.0, 0.48003415887725276)
#              indep_Q(cs_K)=0.942780197
#     scen 6: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-5.151616758713902, -99.99994761846365, 2.0886077004635784)
#              indep_Q(cs_K)=1.012024958
#     scen 7: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.895381364466106, -100.0, 0.5589362703125396)
#              indep_Q(cs_K)=0.946766833
#     scen 8: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.924026296366762, -100.0, 0.7037188119837551)
#              indep_Q(cs_K)=1.010797442
#     scen 9: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-8.511091424443634, -99.99994891204189, 1.5520469992805779)
#              indep_Q(cs_K)=0.957086521
#   sum(c_s_dual)=0.000000000, UB_total=97.900226658, UB_per_scen=9.790022666
#
#   == Per-scenario Q_s at K_EF = (-9.959113411333826, -100.0, 0.8810626333082254) ==
#     scen 0: Q_s(K_EF)=0.996013914, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945133376, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.956403537, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054799003, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968536412, c_s_dual=N/A
#     scen 5: Q_s(K_EF)=0.942911218, c_s_dual=N/A
#     scen 6: Q_s(K_EF)=1.011722163, c_s_dual=N/A
#     scen 7: Q_s(K_EF)=0.946714552, c_s_dual=N/A
#     scen 8: Q_s(K_EF)=1.010818911, c_s_dual=N/A
#     scen 9: Q_s(K_EF)=0.957044081, c_s_dual=N/A
#     SUM Q_s(K_EF)=9.790097167, sum(c_s)=0.000000000, diff=9.790097e+00
#   --- T165 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.957325062775858, -100.0, 0.8810370610621693)
#              indep_Q(cs_K)=0.996014293
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.959151091633156, -100.0, 0.7880925724412587)
#              indep_Q(cs_K)=0.945126448
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-8.822665788981007, -99.99995991264922, 0.8655089199695895)
#              indep_Q(cs_K)=0.956480944
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.959330666182217, -100.0, 0.3450213375490428)
#              indep_Q(cs_K)=1.054568210
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.959311560941513, -100.0, 0.3921604373582728)
#              indep_Q(cs_K)=0.968342163
#     scen 5: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.959286436551432, -100.0, 0.4541508173838549)
#              indep_Q(cs_K)=0.942779935
#     scen 6: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.959113411333826, -100.0, 0.8810626333082254)
#              indep_Q(cs_K)=1.011722163
#     scen 7: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-8.010293211720079, -99.99993125547837, 0.7614997181057277)
#              indep_Q(cs_K)=0.946730078
#     scen 8: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.959201652225937, -100.0, 0.6633424650506186)
#              indep_Q(cs_K)=1.010782292
#     scen 9: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.911875853004128, -100.0, 0.8798350221164815)
#              indep_Q(cs_K)=0.957048057
#   sum(c_s_dual)=0.000000000, UB_total=97.900226658, UB_per_scen=9.790022666
#
#   == Per-scenario Q_s at K_EF = (-9.959113411333826, -100.0, 0.8810626333082254) ==
#     scen 0: Q_s(K_EF)=0.996013914, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945133376, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.956403537, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054799003, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968536412, c_s_dual=N/A
#     scen 5: Q_s(K_EF)=0.942911218, c_s_dual=N/A
#     scen 6: Q_s(K_EF)=1.011722163, c_s_dual=N/A
#     scen 7: Q_s(K_EF)=0.946714552, c_s_dual=N/A
#     scen 8: Q_s(K_EF)=1.010818911, c_s_dual=N/A
#     scen 9: Q_s(K_EF)=0.957044081, c_s_dual=N/A
#     SUM Q_s(K_EF)=9.790097167, sum(c_s)=0.000000000, diff=9.790097e+00
#
# [Iter 65] LB = 9.788208 = UB(9.790023) + ms_b(inf) from T198
# [Iter 65] Split point (avgCS): (-9.999241, -99.959199, 0.941032)
#   -> Accepted. loc_type=interior
# [Iter 65] per_tet=90, active after q_cut=40, tri_is_None=False
# [Iter 65] bad-quality active simplices (q < 0): 0
# [Iter 65] evaluating Q for scenario 0
# [Iter 65] evaluating Q for scenario 1
# [Iter 65] evaluating Q for scenario 2
# [Iter 65] evaluating Q for scenario 3
# [Iter 65] evaluating Q for scenario 4
# [Iter 65] evaluating Q for scenario 5
# [Iter 65] evaluating Q for scenario 6
# [Iter 65] evaluating Q for scenario 7
# [Iter 65] evaluating Q for scenario 8
# [Iter 65] evaluating Q for scenario 9
# [Iter 65] subdivision type = interior (code=1) on simplex T198
# [Iter 65] Elapsed: 1.048s
# [Bundle] MS scen None: infeasibleOrUnbounded. ms_val=nan.
# [Bundle] MS scen None: not optimal. Status=warning, Term=infeasibleOrUnbounded.
# [Bundle] MS scen None: infeasibleOrUnbounded. ms_val=nan.
# [Bundle] MS scen None: not optimal. Status=warning, Term=infeasibleOrUnbounded.
# [Bundle] MS scen None: infeasibleOrUnbounded. ms_val=nan.
# [Bundle] MS scen None: not optimal. Status=warning, Term=infeasibleOrUnbounded.
# [Bundle] MS scen None: infeasibleOrUnbounded. ms_val=nan.
# [Bundle] MS scen None: not optimal. Status=warning, Term=infeasibleOrUnbounded.
# [Invariant] MS scen None: dual=-6.043457e+09 > primal=-6.043457e+09
# [Invariant] MS scen None: dual=-1.852236e+09 > primal=-1.852236e+09
# [Invariant] MS scen None: dual=-1.947912e+09 > primal=-1.947912e+09
# [Bundle] MS scen None: infeasibleOrUnbounded. ms_val=nan.
# [Bundle] MS scen None: not optimal. Status=warning, Term=infeasibleOrUnbounded.
# [Invariant] MS scen None: dual=-1.999030e+09 > primal=-1.999030e+09
#
# ======================================================================
# [TIMING] === Iter 65 phase breakdown (total 22.07s) ===
#   1_vertex_UB                    :       0.00s  (  0.0%)
#   2_evaluate_all_tetra           :       0.01s  (  0.0%)
#   3_active_filter_print          :       0.00s  (  0.0%)
#   4_LB_selection                 :       0.00s  (  0.0%)
#   5_EF_UB_solve                  :       0.91s  (  4.1%)  ##
#   6_candidate_selection          :       0.00s  (  0.0%)
#   7_Q_eval_new_node              :       0.12s  (  0.6%)
#   8_mesh_subdivide               :       0.00s  (  0.0%)
#   9_end_of_iter_reeval           :      21.02s  ( 95.3%)  ###############################################
#   TOTAL                          :      22.07s
#   #simplices=90, #scenarios=10, total_ms_pairs=900
#   fresh ms solves=0, cache hits=900
# ======================================================================
#
# ======================================================================
# [Iter 65] LB SPLIT DIAGNOSTIC
#   Selected (parent) simplex: (0, 1, 71, 72)
#   Parent LB: 0.978820825 (per-scen)
#   Parent avg constant cut: 0.978820825 (per-scen)
#   Parent avg c_s Q-value: 0.979006122 (per-scen), point=(np.float64(-9.999241391927635), np.float64(-99.95919870833261), np.float64(0.9410317252306205))
#   EF ef_obj(IPOPT): 0.097900230, true_obj(recalc): 0.979002305, used=min=0.097900230 (per-scen)
#   Simplex volume: 1.728242e-03
#   Children (4):
#     T199 (0, 1, 72, 73): LB=0.978813684, avg_cut=0.978813684, avg_cs_Q=0.979005703
#     T200 (0, 71, 72, 73): LB=0.978897301, avg_cut=0.978897301, avg_cs_Q=0.979028350
#     T201 (0, 1, 71, 73): LB=0.978830888, avg_cut=0.978830888, avg_cs_Q=0.979006794
#     T202 (1, 71, 72, 73): LB=0.978867763, avg_cut=0.978867763, avg_cs_Q=0.979050838
#   New global LB: 0.978813684 (from T199 (0, 1, 72, 73))
#   Location: INSIDE
#   EF-IPOPT: ok=True, status=ok, term=optimal, time=0.164s, ef_obj=0.9790022963590352, true_obj(per-scen)=0.979002305
#   Current UB (end-of-iter): 0.979002267 (per-scen)
#   UB point: (-9.959113411333826, -100.0, 0.8810626333082254)
#   UB source: avgCS_new_simplex
#   UB simplex: (0, 1, 4, 9)
#   UB updated this iter: False
# ======================================================================
# [Iter 65] Stop: Time limit reached (1810.60s >= 1800.00s).
#
# ===== Simplex search summary (per-scenario) =====
#   Time (s)  # Nodes             LB             UB   Rel. Gap   Abs. Gap   #simplex    #active   Split       Selection
# ---------------------------------------------------------------------------------------------------------------------
#     65.629        8    0.978954000    0.979388215    0.0443%    0.00043          6          6    none           avgCS
#    731.065        9    0.978827678    0.979009717    0.0186%    0.00018          9          1interior           avgCS
#    925.975       10    0.978849186    0.979009717    0.0164%    0.00016         12          2interior           avgCS
#    953.308       11    0.978839708    0.979009717    0.0174%    0.00017         14          4    face           avgCS
#    997.970       12    0.978882863    0.979009717    0.0130%    0.00013         17          5interior           avgCS
#   1032.596       13    0.978887513    0.979009717    0.0125%    0.00012         20          7interior           avgCS
#   1067.432       14    0.978891410    0.979009717    0.0121%    0.00012         23         10interior           avgCS
#   1096.287       15    0.978887571    0.979009717    0.0125%    0.00012         26         13interior           avgCS
#   1124.865       16    0.978898690    0.979009717    0.0113%    0.00011         28         15interior           avgCS
#   1143.309       17    0.978900250    0.979009717    0.0112%    0.00011         29         15interior           avgCS
#   1149.751       18    0.978901151    0.979009717    0.0111%    0.00011         29         15interior           avgCS
#   1170.249       19    0.978898996    0.979009717    0.0113%    0.00011         32         17interior           avgCS
#   1191.528       20    0.978894720    0.979009717    0.0117%    0.00011         35         19interior           avgCS
#   1211.767       21    0.978893702    0.979009717    0.0119%    0.00012         38         21interior           avgCS
#   1229.837       22    0.978901190    0.979009717    0.0111%    0.00011         40         23interior           avgCS
#   1230.887       23    0.978899462    0.979009717    0.0113%    0.00011         39         22interior           avgCS
#   1247.891       24    0.978894368    0.979009717    0.0118%    0.00012         41         23interior           avgCS
#   1259.861       25    0.978902688    0.979009717    0.0109%    0.00011         42         24interior           avgCS
#   1266.178       26    0.978903852    0.979009717    0.0108%    0.00011         42         23interior           avgCS
#   1272.992       27    0.978894930    0.979009717    0.0117%    0.00011         42         22interior           avgCS
#   1284.854       28    0.978905034    0.979009717    0.0107%    0.00010         43         22interior           avgCS
#   1286.221       29    0.978905463    0.979009717    0.0106%    0.00010         42         21interior           avgCS
#   1293.426       30    0.978899653    0.979009717    0.0112%    0.00011         42         20interior           avgCS
#   1311.558       31    0.978894785    0.979009717    0.0117%    0.00011         45         21interior           avgCS
#   1327.861       32    0.978891995    0.979009717    0.0120%    0.00012         47         22interior           avgCS
#   1338.817       33    0.978901103    0.979009717    0.0111%    0.00011         48         22interior           avgCS
#   1344.550       34    0.978894527    0.979009717    0.0118%    0.00012         48         21interior           avgCS
#   1361.070       35    0.978891968    0.979009717    0.0120%    0.00012         50         22interior           avgCS
#   1376.643       36    0.978893954    0.979009717    0.0118%    0.00012         52         23interior           avgCS
#   1377.718       37    0.978899209    0.979009717    0.0113%    0.00011         51         22interior           avgCS
#   1383.378       38    0.978902417    0.979009717    0.0110%    0.00011         51         21interior           avgCS
#   1384.658       39    0.978894840    0.979009717    0.0117%    0.00011         50         20interior           avgCS
#   1396.267       40    0.978909927    0.979009717    0.0102%    0.00010         51         21interior           avgCS
#   1402.958       41    0.978893015    0.979009717    0.0119%    0.00012         51         20interior           avgCS
#   1421.131       42    0.978891407    0.979009717    0.0121%    0.00012         54         22interior           avgCS
#   1438.798       43    0.978892370    0.979009717    0.0120%    0.00012         57         23interior           avgCS
#   1454.128       44    0.978895075    0.979009717    0.0117%    0.00011         59         24interior           avgCS
#   1455.350       45    0.978892394    0.979009717    0.0120%    0.00012         58         23interior           avgCS
#   1470.483       46    0.978896663    0.979009717    0.0115%    0.00011         60         24interior           avgCS
#   1475.973       47    0.978894910    0.979009717    0.0117%    0.00011         60         23interior           avgCS
#   1486.429       48    0.978897527    0.979009717    0.0115%    0.00011         61         23interior           avgCS
#   1492.281       49    0.978902210    0.979009717    0.0110%    0.00011         61         22interior           avgCS
#   1497.747       50    0.978892394    0.979009717    0.0120%    0.00012         61         21interior           avgCS
#   1514.612       51    0.978891889    0.979009717    0.0120%    0.00012         64         23interior           avgCS
#   1529.405       52    0.978891282    0.979009717    0.0121%    0.00012         66         24interior           avgCS
#   1544.033       53    0.978891374    0.979009717    0.0121%    0.00012         68         25interior           avgCS
#   1554.166       54    0.978894786    0.979009717    0.0117%    0.00011         69         25interior           avgCS
#   1555.446       55    0.978896362    0.979009717    0.0116%    0.00011         68         24interior           avgCS
#   1565.420       56    0.978898641    0.979009717    0.0113%    0.00011         69         24interior           avgCS
#   1571.017       57    0.978894501    0.979009717    0.0118%    0.00012         69         23interior           avgCS
#   1586.330       58    0.978894659    0.979009717    0.0118%    0.00012         71         25interior           avgCS
#   1597.464       59    0.978900403    0.979009717    0.0112%    0.00011         72         25interior           avgCS
#   1598.818       60    0.978904330    0.979009717    0.0108%    0.00011         71         24interior           avgCS
#   1604.939       61    0.978911703    0.979009717    0.0100%    0.00010         71         24interior           avgCS
#   1606.385       62    0.978854944    0.979002276    0.0150%    0.00015         70         23interior           avgCS
#   1625.355       63    0.978913955    0.979002276    0.0090%    0.00009         72         23interior           avgCS
#   1626.877       64    0.978833715    0.979002276    0.0172%    0.00017         71         22interior           avgCS
#   1654.263       65    0.978851857    0.979002267    0.0154%    0.00015         74         25interior           avgCS
#   1683.027       66    0.978850499    0.979002267    0.0155%    0.00015         77         28interior           avgCS
#   1700.419       67    0.978850592    0.979002267    0.0155%    0.00015         80         30interior           avgCS
#   1714.905       68    0.978853612    0.979002267    0.0152%    0.00015         82         32interior           avgCS
#   1724.878       69    0.978853671    0.979002267    0.0152%    0.00015         83         33interior           avgCS
#   1741.042       70    0.978854329    0.979002267    0.0151%    0.00015         85         35interior           avgCS
#   1742.272       71    0.978851953    0.979002267    0.0154%    0.00015         84         34interior           avgCS
#   1765.865       72    0.978820825    0.979002267    0.0185%    0.00018         87         37interior           avgCS
#   1788.794       73    0.978813684    0.979002267    0.0193%    0.00019         90         40interior           avgCS
# [Time] Main loop total: 1812.242s
#
# ==== Done ====
# Total nodes: 74
# Best UB: 9.790022665839167
# Last LB: 9.78813683714085
