# %%
from time import perf_counter  

from modeling import build_models_from_csv
from bundles import BaseBundle, MSBundle
from utils import (
    tighten_bounds_one_model,
    MIN_DIST, ACTIVE_TOL, GAP_STOP_TOL,
)
from simplex_specialstart import run_pid_simplex_3d

# setup scenario number and target_nodesk
csv_path       = "data.csv"
max_scenarios  = 5
target_nodes   = 1000

bounds={
    "Kp": (-10.0, 10.0),
    "Ki": (-100.0, 100.0),
    "Kd": (-100.0, 100.0),
    "x": (-2.5, 2.5),
    "u": (-5.0, 5.0),
    "e": (None, None),
    "I": (None, None),
}

weights = (10.0, 0.01)


# ====== stage 1：load data and generate models ======
T   = 15.0          
nfe = 20            

t_load0 = perf_counter()
model_list, first_stg_vars_list, m_tmpl_list, nfe = build_models_from_csv(
    csv_path=csv_path,
    T=T,
    nfe=nfe,
    weights=weights,
    bounds=bounds,
    sp0=0.0,
    sp1=0.5,
    tau_xs_col="tau_xs",
    tau_us_col="tau_us",
    tau_ds_col="tau_ds",          
    disturb_prefix="disturbance_",
    setpoint_change_col="setpoint_change",
    max_scenarios=max_scenarios,
    skip=0,
)
t_load1 = perf_counter()
print(f"[Time] Data load & scenario build: {t_load1 - t_load0:.3f}s")


# ====== stage 1.5：FBBT / OBBT ======
# same as snog: FBBT open,OBBT open
obbt_solver_opts = {
    "NonConvex": 2,
    "MIPGap": 1,     
    "TimeLimit": 15   
}
for m, yvars in zip(model_list, first_stg_vars_list):
    tighten_bounds_one_model(m, yvars,
                             use_fbbt=False,
                             use_obbt=False,
                             obbt_solver_name="gurobi",
                             obbt_solver_opts=obbt_solver_opts,
                             max_rounds=3, tol=1e-6, verbose=True)

# ====== stage 2: Persistent Solver Packaging ======
ub_options = {
    'NonConvex': 2,      
}
lb_options = {
    'NonConvex': 2,
    'MIPGap': 1e-1,            
    'TimeLimit': 60 
}

t_wrap0 = perf_counter()
base_bundles = [BaseBundle(m, ub_options) for m in model_list]  
ms_bundles   = [MSBundle(m, yvars, lb_options) for m, yvars in zip(model_list, first_stg_vars_list)]  
t_wrap1 = perf_counter()
print(f"[Time] Persistent wrapper (GurobiPersistent) setup: {t_wrap1 - t_wrap0:.3f}s")

# ====== stage 3：main loop ======
agg_bundle = None  

t_run0 = perf_counter()
hist = run_pid_simplex_3d(
    base_bundles=base_bundles,
    ms_bundles=ms_bundles,
    model_list=model_list,
    first_vars_list=first_stg_vars_list,
    target_nodes=target_nodes,
    min_dist=0,
    active_tol=ACTIVE_TOL,
    verbose=True,
    agg_bundle=agg_bundle,
    gap_stop_tol=1e-6,
    use_exact_opt=False,
    exact_solver_name="gurobi",
    exact_solver_opts={"NonConvex": 2, "TimeLimit": 60},
    time_limit=60*30*1,
    enable_3d_plot=False,   
    plot_every=None,        
)
t_run1 = perf_counter()
print(f"[Time] Main loop total: {t_run1 - t_run0:.3f}s")

# ====== print output ======
print("\n==== Done ====")
print(f"Total nodes: {len(hist['nodes'])}")
print(f"Best UB: {min(hist['UB_hist']) if hist['UB_hist'] else None}")
print(f"Last LB: {hist['LB_hist'][-1] if hist['LB_hist'] else None}")
# Out:
# [Time] Data load & scenario build: 0.025s
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2689754
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 60
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 60
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 60
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 60
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 60
# [Time] Persistent wrapper (GurobiPersistent) setup: 2.063s
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [TIMING] Pre-loop vertex Q evals: 0.92s  (8 nodes x 5 scenarios = 40 solves)
# [EF-UB] Initialized ipopt EF with 5 scenarios, time_ub=60.0s
#
# ======================================================================
# [TIMING] === Pre-loop phase summary ===
#   corners_and_mesh               :       0.00s
#   vertex_Q_evals                 :       0.92s
#   exact_optima                   :       0.00s
#   ef_init                        :       0.04s
#   TOTAL                          :       0.96s
# ======================================================================
#
# [Iter 0] MIPGap overridden to 0.1 (original: 0.1)
# Discarded solution information
# [Invariant] MS scen None: dual=-5.500707e+09 > primal=-5.500707e+09
# Discarded solution information
# Discarded solution information
# [Invariant] MS scen None: dual=-5.481254e+09 > primal=-5.481254e+09
# Discarded solution information
# Discarded solution information
# [Invariant] MS scen None: dual=-5.194287e+09 > primal=-5.194287e+09
# [Invariant] MS scen None: dual=-5.806922e+09 > primal=-5.806922e+09
# [Invariant] MS scen None: dual=-5.817119e+09 > primal=-5.817119e+09
# [Invariant] MS scen None: dual=-5.596691e+09 > primal=-5.596691e+09
# [Invariant] MS scen None: dual=-5.719282e+09 > primal=-5.719282e+09
# [Invariant] MS scen None: dual=-5.735561e+09 > primal=-5.735561e+09
# [Invariant] MS scen None: dual=-5.718800e+09 > primal=-5.718800e+09
# [Invariant] MS scen None: dual=-5.724298e+09 > primal=-5.724298e+09
# [Bundle] MS scen None: infeasibleOrUnbounded. ms_val=nan.
# [Bundle] MS scen None: not optimal. Status=warning, Term=infeasibleOrUnbounded.
# [Invariant] MS scen None: dual=-5.870800e+09 > primal=-5.870800e+09
# [Iter 0] MIPGap restored to 0.1
# [Iter 0] #simplices = 6, #active = 6, bad-quality cut = 0, bad-shape cut = 0
# == [Iter 0] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.023823e+00      4.725871e+09     -2.637064e+10      5.119117e+00     [1.12e+01, 5.00e+10]    [-2.64e+10, 2.36e+10]     1
# T1            9.955344e-01      4.065069e+09     -2.967466e+10      4.977672e+00     [1.12e+01, 5.00e+10]    [-2.97e+10, 2.03e+10]     1
# T2            1.026329e+00      4.382643e+09     -2.808678e+10      5.131646e+00     [1.11e+01, 5.00e+10]    [-2.81e+10, 2.19e+10]     1
# T3            1.001069e+00      4.242039e+09     -2.878981e+10      5.005344e+00     [1.11e+01, 5.00e+10]    [-2.88e+10, 2.12e+10]     1
# T4            1.023670e+00      4.317792e+09     -2.841104e+10      5.118349e+00     [1.36e+01, 5.00e+10]    [-2.84e+10, 2.16e+10]     2
# T5            1.043636e+00               inf               inf      5.218179e+00     [1.36e+01, 5.00e+10]               [inf, inf]     2
#
# == [Iter 0] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
#   (none)
# [Iter 0] created=6 (cum=6), active=6, active+UB=2, ms_recomputed=6
# [Iter 0] EF-ipopt: ok=True, ef_obj=0.9841670257415726, true_obj=9.841670e-01, time=0.176s
# [Iter 0] EF-UB improved by ipopt: 9.841670e-01 (per-scen), K=(-9.999891529588373, -99.99979183385918, 0.8142777652971412)
# [Iter 0] Pre-split gap: -5.683677e-02 (-1.155%)
# [Iter 0] Active simplex ratio = 1.000000
# [Iter 0] UB point (-9.999891529588373, -99.99979183385918, 0.8142777652971412) is geometrically in simplices [1]
#   T1 verts=[3, 1, 4, 0]: λ=[0.000001, 0.504070, 0.000005, 0.495923], LB=4.977672007, c_s=[0.9960029127022256, 1.0001366770450069, 0.9579954878938712, 1.0551989733060005, 0.9683379558464811]
#
# == [Iter 0] CS DUAL vs PRIMAL diagnostic (simplices containing UB point) ==
#   --- T1 ---
#     scen 0: status=optimal, dual=0.996002913, primal=0.996002913  ✓ dual ≤ primal (gap=1.110223e-16)
#              cs_primal_K=(-9.999216646683243, -99.99852406033013, 0.9388331317148486)
#              indep_Q(cs_K)=0.996002918  → dual ≤ indep_Q (consistent, diff=4.973934e-09)
#     scen 1: status=optimal, dual=1.000136677, primal=1.000136677  ✓ dual ≤ primal (gap=-2.220446e-16)
#              cs_primal_K=(-9.999983393339464, -0.15781395634996587, 0.00040036514586223133)
#              indep_Q(cs_K)=1.000136678  → dual ≤ indep_Q (consistent, diff=1.132161e-09)
#     scen 2: status=optimal, dual=0.957995488, primal=0.957995488  ✓ dual ≤ primal (gap=-2.220446e-16)
#              cs_primal_K=(-9.998442794608906, -99.99686925671598, -2.736029187431506e-10)
#              indep_Q(cs_K)=0.957995515  → dual ≤ indep_Q (consistent, diff=2.714000e-08)
#     scen 3: status=optimal, dual=1.055198973, primal=1.055198973  ✓ dual ≤ primal (gap=2.220446e-16)
#              cs_primal_K=(-9.233467561678685, -98.4408518452537, 0.32994040845543465)
#              indep_Q(cs_K)=1.055198979  → dual ≤ indep_Q (consistent, diff=5.506025e-09)
#     scen 4: status=optimal, dual=0.968337956, primal=0.968337956  ✓ dual ≤ primal (gap=0.000000e+00)
#              cs_primal_K=(-9.998518091599312, -99.9972050307925, 0.39376151703840556)
#              indep_Q(cs_K)=0.968337957  → dual ≤ indep_Q (consistent, diff=1.643293e-09)
#   sum(c_s_dual)=4.977672007, UB_total=24.604176169, UB_per_scen=4.920835234
#
#   == Per-scenario Q_s at K_EF = (-9.999891529588373, -99.99979183385918, 0.8142777652971412) ==
#     scen 0: Q_s(K_EF)=0.996015235, c_s_dual=0.996002913  ✓ Q_s(K_EF) > c_s_dual (diff=1.232267e-05)
#     scen 1: Q_s(K_EF)=0.945126284, c_s_dual=1.000136677  ⚠ Q_s(K_EF) < c_s_dual → GUROBI CS DUAL IS WRONG
#     scen 2: Q_s(K_EF)=0.956484730, c_s_dual=0.957995488  ⚠ Q_s(K_EF) < c_s_dual → GUROBI CS DUAL IS WRONG
#     scen 3: Q_s(K_EF)=1.054727427, c_s_dual=1.055198973  ⚠ Q_s(K_EF) < c_s_dual → GUROBI CS DUAL IS WRONG
#     scen 4: Q_s(K_EF)=0.968481558, c_s_dual=0.968337956  ✓ Q_s(K_EF) > c_s_dual (diff=1.436021e-04)
#     SUM Q_s(K_EF)=4.920835234, sum(c_s)=4.977672007, diff=-5.683677e-02
#
# [Iter 0] LB = 4.977672 = UB(4.920835) + ms_b(-2.967e+10) from T1
# [Iter 0] Scene 0: Switched to c_s point. dist_ms_c=1.71e+01 < 1000.0, dist_c_verts=9.91e+01 > 1e-06
# [Iter 0] Scene 1: Switched to c_s point. dist_ms_c=1.01e+02 < 1000.0, dist_c_verts=1.41e+02 > 1e-06
# [Iter 0] Scene 2: Switched to c_s point. dist_ms_c=2.05e+01 < 1000.0, dist_c_verts=1.00e+02 > 1e-06
# [Iter 0] Scene 3: Switched to c_s point. dist_ms_c=2.06e+01 < 1000.0, dist_c_verts=9.97e+01 > 1e-06
# [Iter 0] Scene 4: Switched to c_s point. dist_ms_c=1.92e+01 < 1000.0, dist_c_verts=9.96e+01 > 1e-06
# Chosen node (-9.233467561678685, -98.4408518452537, 0.32994040845543465) with ms=-6.045e+09 (simp T1, scene 3, rank #1, source=c_s)
# [Iter 0] LB simplex = T1, next node simplex = T1, scene 3
# [Selected Simp Info] Iter 0 | Simplex T1 Vertices:
#   v0: (-10.0, 100.0, 100.0)
#   v1: (-10.0, -100.0, 100.0)
#   v2: (10.0, -100.0, -100.0)
#   v3: (-10.0, -100.0, -100.0)
#   -> New Point: (-9.233467561678685, -98.4408518452537, 0.32994040845543465)
# [Iter 0] candidate rank #1: T1, scene=3, ms=-6.045e+09
# == ms candidates (sorted by (ms, -dist)) ==
# rank   simp   scene           ms    mind(all)                             pt
# ----------------------------------------------------------------------------
#    1     T1       3  -6.0448e+09     9.97e+01    (-9.2335, -98.4409, 0.3299)
#    2     T1       2  -6.0269e+09     1.00e+02   (-9.9984, -99.9969, -0.0000)
#    3     T1       4  -5.9790e+09     9.96e+01    (-9.9985, -99.9972, 0.3938)
#    4     T1       1  -5.8171e+09     1.41e+02    (-10.0000, -0.1578, 0.0004)
#    5     T1       0  -5.8069e+09     9.91e+01    (-9.9992, -99.9985, 0.9388)
#
# [Iter 0] per_tet=6, active after q_cut=6, tri_is_None=False
# [Iter 0] bad-quality active simplices (q < 0): 0
# [Iter 0] evaluating Q for scenario 0
# [Iter 0] evaluating Q for scenario 1
# [Iter 0] evaluating Q for scenario 2
# [Iter 0] evaluating Q for scenario 3
# [Iter 0] evaluating Q for scenario 4
#
# [Iter 0] Next Point Details:
# Simplex   Scene   Type    As             ms             As+ms          Q              (Kp, Ki, Kd)
# --------------------------------------------------------------------------------------------------------------------
# T1        3       c_s     4.9385e+09     -6.0448e+09    -1.1063e+09    1.0552e+00     (-9.2335, -98.4409, 0.3299)
#
# [Iter 0] subdivision type = interior (code=1) on simplex T1
# [Iter 0] Elapsed: 108.672s
# [Invariant] MS scen None: dual=-6.034060e+09 > primal=-6.034060e+09
# [Invariant] MS scen None: dual=-5.838964e+09 > primal=-5.838964e+09
# [Invariant] MS scen None: dual=-5.688783e+09 > primal=-5.688783e+09
# [BaseBundle.eval_at] Infeasible/Error for K=(-1.8791755128385712, -99.54188147604654, 16.90885917695564): status=warning, term=infeasibleOrUnbounded
#
# ======================================================================
# [TIMING] === Iter 0 phase breakdown (total 435.55s) ===
#   1_vertex_UB                    :       0.00s  (  0.0%)
#   2_evaluate_all_tetra           :     107.75s  ( 24.7%)  ############
#   3_active_filter_print          :       0.00s  (  0.0%)
#   4_LB_selection                 :       0.00s  (  0.0%)
#   5_EF_UB_solve                  :       0.52s  (  0.1%)
#   6_candidate_selection          :       0.35s  (  0.1%)
#   7_Q_eval_new_node              :       0.05s  (  0.0%)
#   8_mesh_subdivide               :       0.00s  (  0.0%)
#   9_end_of_iter_reeval           :     326.88s  ( 75.0%)  #####################################
#   TOTAL                          :     435.55s
#   #simplices=6, #scenarios=5, total_ms_pairs=30
#   fresh ms solves=30, cache hits=0
# ======================================================================
#
# ======================================================================
# [Iter 0] LB SPLIT DIAGNOSTIC
#   Selected (parent) simplex: (0, 1, 3, 4)
#   Parent LB: 0.995534401 (per-scen)
#   Parent avg constant cut: 0.995534401 (per-scen)
#   Parent avg c_s Q-value: 0.986724037 (per-scen), point=(np.float64(-9.845925697581922), np.float64(-79.71825282988846), np.float64(0.3325870844161896))
#   EF ef_obj(IPOPT): 0.196833405, true_obj(recalc): 0.984167047, used=min=0.196833405 (per-scen)
#   Simplex volume: 1.333333e+05
#   Children (4):
#     T5 (0, 1, 4, 8): LB=0.984138838, avg_cut=0.984138838, avg_cs_Q=0.984361942
#     T6 (0, 3, 4, 8): LB=0.993970895, avg_cut=0.993970895, avg_cs_Q=0.985885574
#     T7 (0, 1, 3, 8): LB=0.989997739, avg_cut=0.989997739, avg_cs_Q=0.988595719
#     T8 (1, 3, 4, 8): LB=0.988355350, avg_cut=0.988355350, avg_cs_Q=0.986768054
#   New global LB: 0.984138838 (from T5 (0, 1, 4, 8))
#   Location: INSIDE
#   EF-IPOPT: ok=True, status=ok, term=optimal, time=0.176s, ef_obj=0.9841670257415726, true_obj(per-scen)=0.984167047
#   Current UB (end-of-iter): 0.984167047 (per-scen)
#   UB point: (-9.999891529588373, -99.99979183385918, 0.8142777652971412)
#   UB source: EF_ipopt
#   UB simplex: (0, 1, 3, 4)
#   UB updated this iter: True
# ======================================================================
# [Iter 1] #simplices = 9, #active = 1, bad-quality cut = 0, bad-shape cut = 0
# == [Iter 1] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T5            9.841388e-01      4.057385e+09     -2.971307e+10      4.920694e+00     [4.92e+00, 5.00e+10]    [-2.97e+10, 2.03e+10]     1
#
# == [Iter 1] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.023823e+00      4.725871e+09     -2.637064e+10      5.119117e+00     [1.12e+01, 5.00e+10]    [-2.64e+10, 2.36e+10]     1
# T1            1.026329e+00      4.382643e+09     -2.808678e+10      5.131646e+00     [1.11e+01, 5.00e+10]    [-2.81e+10, 2.19e+10]     1
# T2            1.001069e+00      4.242039e+09     -2.878981e+10      5.005344e+00     [1.11e+01, 5.00e+10]    [-2.88e+10, 2.12e+10]     1
# T3            1.023670e+00      4.317792e+09     -2.841104e+10      5.118349e+00     [1.36e+01, 5.00e+10]    [-2.84e+10, 2.16e+10]     2
# T4            1.043636e+00               inf               inf      5.218179e+00     [1.36e+01, 5.00e+10]               [inf, inf]     2
# T6            9.939709e-01      1.385630e+00     -6.711390e+00      4.969854e+00     [4.92e+00, 1.36e+01]    [-1.79e+00, 6.93e+00]     0
# T7            9.899977e-01      4.017689e+09     -2.991155e+10      4.949989e+00     [4.92e+00, 5.00e+10]    [-2.99e+10, 2.01e+10]     1
# T8            9.883553e-01      4.278531e+09     -2.860734e+10      4.941777e+00     [4.92e+00, 5.00e+10]    [-2.86e+10, 2.14e+10]     1
#
# [Iter 1] created=9 (cum=19), active=1, active+UB=1, ms_recomputed=0
# [Iter 1] EF-ipopt: ok=True, ef_obj=0.9841670252034732, true_obj=9.841670e-01, time=0.116s
# [Iter 1] EF-UB improved by ipopt: 9.841670e-01 (per-scen), K=(-9.999868030729937, -99.99984336305558, 0.8142777531758495)
# [Iter 1] Pre-split gap: 1.410402e-04 (0.003%)
# [Iter 1] Active simplex ratio = 0.001299
# [Iter 1] UB point (-9.999868030729937, -99.99984336305558, 0.8142777531758495) is geometrically in simplices [5]
#   T5 verts=[8, 1, 4, 0]: λ=[0.000100, 0.504021, 0.000003, 0.495876], LB=4.920694191, c_s=[0.996005370497984, 0.9452595803485847, 0.9564957702968899, 1.0545523581483314, 0.9683811117280262]
#
# == [Iter 1] CS DUAL vs PRIMAL diagnostic (simplices containing UB point) ==
#   --- T5 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 0.8803662835224104)
#              indep_Q(cs_K)=0.996005375
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 0.3816748632549367)
#              indep_Q(cs_K)=0.945259594
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-4.1453914214428575, -100.0, 2.276255451699071)
#              indep_Q(cs_K)=0.956495771
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999022057536129, -99.99947878853936, 0.3476234904818926)
#              indep_Q(cs_K)=1.054552379
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 0.15833275475759467)
#              indep_Q(cs_K)=0.968381112
#   sum(c_s_dual)=0.000000000, UB_total=24.604176156, UB_per_scen=4.920835231
#
#   == Per-scenario Q_s at K_EF = (-9.999868030729937, -99.99984336305558, 0.8142777531758495) ==
#     scen 0: Q_s(K_EF)=0.996015235, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945126284, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.956484729, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054727425, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968481557, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.920835231, sum(c_s)=0.000000000, diff=4.920835e+00
#
# [Iter 1] LB = 4.920694 = UB(4.920835) + ms_b(-2.971e+10) from T5
# [Iter 1] Scene 0: Switched to c_s point. dist_ms_c=1.87e+01 < 1000.0, dist_c_verts=1.82e+00 > 1e-06
# [Iter 1] Scene 1: Switched to c_s point. dist_ms_c=1.84e+01 < 1000.0, dist_c_verts=1.74e+00 > 1e-06
# [Iter 1] Scene 2: Switched to c_s point. dist_ms_c=1.56e+01 < 1000.0, dist_c_verts=5.67e+00 > 1e-06
# [Iter 1] Scene 3: Switched to c_s point. dist_ms_c=2.03e+01 < 1000.0, dist_c_verts=1.74e+00 > 1e-06
# [Iter 1] Scene 4: Switched to c_s point. dist_ms_c=1.84e+01 < 1000.0, dist_c_verts=1.75e+00 > 1e-06
# Chosen node (-9.999022057536129, -99.99947878853936, 0.3476234904818926) with ms=-6.034e+09 (simp T5, scene 3, rank #1, source=c_s)
# [Iter 1] LB simplex = T5, next node simplex = T5, scene 3
# [Selected Simp Info] Iter 1 | Simplex T5 Vertices:
#   v0: (-9.233467561678685, -98.4408518452537, 0.32994040845543465)
#   v1: (-10.0, -100.0, 100.0)
#   v2: (10.0, -100.0, -100.0)
#   v3: (-10.0, -100.0, -100.0)
#   -> New Point: (-9.999022057536129, -99.99947878853936, 0.3476234904818926)
# [Iter 1] candidate rank #1: T5, scene=3, ms=-6.034e+09
# == ms candidates (sorted by (ms, -dist)) ==
# rank   simp   scene           ms    mind(all)                             pt
# ----------------------------------------------------------------------------
#    1     T5       3  -6.0341e+09     1.74e+00    (-9.9990, -99.9995, 0.3476)
#    2     T5       0  -5.9800e+09     1.82e+00  (-10.0000, -100.0000, 0.8804)
#    3     T5       4  -5.9290e+09     1.75e+00  (-10.0000, -100.0000, 0.1583)
#    4     T5       2  -5.8929e+09     5.67e+00   (-4.1454, -100.0000, 2.2763)
#    5     T5       1  -5.8771e+09     1.74e+00  (-10.0000, -100.0000, 0.3817)
#
# [Iter 1] per_tet=9, active after q_cut=1, tri_is_None=False
# [Iter 1] bad-quality active simplices (q < 0): 0
# [Iter 1] evaluating Q for scenario 0
# [Iter 1] evaluating Q for scenario 1
# [Iter 1] evaluating Q for scenario 2
# [Iter 1] evaluating Q for scenario 3
# [Iter 1] evaluating Q for scenario 4
#
# [Iter 1] Next Point Details:
# Simplex   Scene   Type    As             ms             As+ms          Q              (Kp, Ki, Kd)
# --------------------------------------------------------------------------------------------------------------------
# T5        3       c_s     5.0157e+09     -6.0341e+09    -1.0184e+09    1.0546e+00     (-9.9990, -99.9995, 0.3476)
#
# [Iter 1] subdivision type = interior (code=1) on simplex T5
# [Iter 1] Elapsed: 0.313s
# [Invariant] MS scen None: dual=-5.961202e+09 > primal=-5.961202e+09
# [Invariant] MS scen None: dual=-5.669856e+09 > primal=-5.669856e+09
# [BaseBundle.eval_at] Infeasible/Error for K=(-6.092607178058077, -100.0, 18.794359698534446): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-6.092607178058077, -100.0, 18.794359698534446): status=warning, term=infeasibleOrUnbounded
#
# ======================================================================
# [TIMING] === Iter 1 phase breakdown (total 18.53s) ===
#   1_vertex_UB                    :       0.00s  (  0.0%)
#   2_evaluate_all_tetra           :       0.00s  (  0.0%)
#   3_active_filter_print          :       0.00s  (  0.0%)
#   4_LB_selection                 :       0.00s  (  0.0%)
#   5_EF_UB_solve                  :       0.25s  (  1.4%)
#   6_candidate_selection          :       0.00s  (  0.0%)
#   7_Q_eval_new_node              :       0.06s  (  0.3%)
#   8_mesh_subdivide               :       0.00s  (  0.0%)
#   9_end_of_iter_reeval           :      18.22s  ( 98.3%)  #################################################
#   TOTAL                          :      18.53s
#   #simplices=9, #scenarios=5, total_ms_pairs=45
#   fresh ms solves=0, cache hits=45
# ======================================================================
#
# ======================================================================
# [Iter 1] LB SPLIT DIAGNOSTIC
#   Selected (parent) simplex: (0, 1, 4, 8)
#   Parent LB: 0.984138838 (per-scen)
#   Parent avg constant cut: 0.984138838 (per-scen)
#   Parent avg c_s Q-value: 0.984361942 (per-scen), point=(np.float64(-8.828882695795798), np.float64(-99.99989575770788), np.float64(0.8088505687431811))
#   EF ef_obj(IPOPT): 0.196833405, true_obj(recalc): 0.984167046, used=min=0.196833405 (per-scen)
#   Simplex volume: 1.039432e+03
#   Children (4):
#     T8 (0, 1, 4, 9): LB=0.984065828, avg_cut=0.984065828, avg_cs_Q=0.984182772
#     T9 (0, 4, 8, 9): LB=0.984339101, avg_cut=0.984339101, avg_cs_Q=0.984339310
#     T10 (0, 1, 8, 9): LB=0.984067029, avg_cut=0.984067029, avg_cs_Q=0.984215609
#     T11 (1, 4, 8, 9): LB=0.984029313, avg_cut=0.984029313, avg_cs_Q=0.984212420
#   New global LB: 0.984029313 (from T11 (1, 4, 8, 9))
#   Location: INSIDE
#   EF-IPOPT: ok=True, status=ok, term=optimal, time=0.116s, ef_obj=0.9841670252034732, true_obj(per-scen)=0.984167046
#   Current UB (end-of-iter): 0.984167046 (per-scen)
#   UB point: (-9.999868030729937, -99.99984336305558, 0.8142777531758495)
#   UB source: EF_ipopt
#   UB simplex: (0, 1, 4, 8)
#   UB updated this iter: True
# ======================================================================
# [Iter 2] #simplices = 12, #active = 3, bad-quality cut = 0, bad-shape cut = 0
# == [Iter 2] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T8            9.840658e-01      4.060282e+09     -2.969859e+10      4.920329e+00     [4.92e+00, 5.00e+10]    [-2.97e+10, 2.03e+10]     1
# T10           9.840670e-01      4.034003e+09     -2.982999e+10      4.920335e+00     [4.92e+00, 5.00e+10]    [-2.98e+10, 2.02e+10]     1
# T11           9.840293e-01      4.372534e+09     -2.813733e+10      4.920147e+00     [4.92e+00, 5.00e+10]    [-2.81e+10, 2.19e+10]     1
#
# == [Iter 2] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.023823e+00      4.725871e+09     -2.637064e+10      5.119117e+00     [1.12e+01, 5.00e+10]    [-2.64e+10, 2.36e+10]     1
# T1            1.026329e+00      4.382643e+09     -2.808678e+10      5.131646e+00     [1.11e+01, 5.00e+10]    [-2.81e+10, 2.19e+10]     1
# T2            1.001069e+00      4.242039e+09     -2.878981e+10      5.005344e+00     [1.11e+01, 5.00e+10]    [-2.88e+10, 2.12e+10]     1
# T3            1.023670e+00      4.317792e+09     -2.841104e+10      5.118349e+00     [1.36e+01, 5.00e+10]    [-2.84e+10, 2.16e+10]     2
# T4            1.043636e+00               inf               inf      5.218179e+00     [1.36e+01, 5.00e+10]               [inf, inf]     2
# T5            9.939709e-01      1.385630e+00     -6.711390e+00      4.969854e+00     [4.92e+00, 1.36e+01]    [-1.79e+00, 6.93e+00]     0
# T6            9.899977e-01      4.017689e+09     -2.991155e+10      4.949989e+00     [4.92e+00, 5.00e+10]    [-2.99e+10, 2.01e+10]     1
# T7            9.883553e-01      4.278531e+09     -2.860734e+10      4.941777e+00     [4.92e+00, 5.00e+10]    [-2.86e+10, 2.14e+10]     1
# T9            9.843391e-01      2.510715e+00     -1.085964e+00      4.921696e+00     [4.92e+00, 1.36e+01]     [3.84e+00, 1.26e+01]     0
#
# [Iter 2] created=12 (cum=35), active=3, active+UB=3, ms_recomputed=0
# [Iter 2] EF-ipopt: ok=True, ef_obj=0.9841671975905564, true_obj=9.841672e-01, time=0.110s
# [Iter 2] Pre-split gap: 6.886648e-04 (0.014%)
# [Iter 2] Active simplex ratio = 0.000648
# [Iter 2] UB point (-9.999022057536129, -99.99947878853936, 0.3476234904818926) is geometrically in simplices [8, 9, 10, 11]
#   T8 verts=[9, 1, 4, 0]: λ=[1.000000, 0.000000, 0.000000, -0.000000], LB=4.920329140, c_s=[0.9960059485416161, 0.9451455956752572, 0.9562855603248932, 1.0545522879751763, 0.9683397473109455]
#   T9 verts=[8, 9, 4, 0]: λ=[0.000000, 1.000000, 0.000000, -0.000000], LB=4.921695505, c_s=[0.9962799762933386, 0.9452825841125264, 0.9572411326639916, 1.0545523617094508, 0.9683394501062152]
#   T10 verts=[8, 1, 9, 0]: λ=[0.000000, 0.000000, 1.000000, -0.000000], LB=4.920335144, c_s=[0.9960764457501945, 0.9452229354478225, 0.9560865702052059, 1.0545523587026253, 0.9683968343587215]
#   T11 verts=[8, 1, 4, 9]: λ=[0.000000, 0.000000, 0.000000, 1.000000], LB=4.920146566, c_s=[0.9960042755939317, 0.9451415231584118, 0.9560127778372718, 1.054552361731593, 0.9684356280801443]
#
# == [Iter 2] CS DUAL vs PRIMAL diagnostic (simplices containing UB point) ==
#   --- T8 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999028464402706, -99.99948220319044, 1.0004834530132063)
#              indep_Q(cs_K)=0.996005965
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999024865574523, -99.99948028513231, 0.633762715976422)
#              indep_Q(cs_K)=0.945145610
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.929863443145829, -99.99949254132785, 2.2852265824027866)
#              indep_Q(cs_K)=0.956285563
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.99901151131146, -99.99984311379745, 0.3476258135518927)
#              indep_Q(cs_K)=1.054552309
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999023000679479, -99.99947929120403, 0.4437298359579913)
#              indep_Q(cs_K)=0.968339755
#   sum(c_s_dual)=0.000000000, UB_total=24.604176156, UB_per_scen=4.920835231
#
#   == Per-scenario Q_s at K_EF = (-9.999022057536129, -99.99947878853936, 0.3476234904818926) ==
#     scen 0: Q_s(K_EF)=0.996279979, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945282584, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.957241134, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054552379, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968339481, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.921695558, sum(c_s)=0.000000000, diff=4.921696e+00
#   --- T9 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999022057536129, -99.99947878853936, 0.3476234904818926)
#              indep_Q(cs_K)=0.996279979
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999022057536129, -99.99947878853936, 0.3476234904818926)
#              indep_Q(cs_K)=0.945282584
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999022057536129, -99.99947878853936, 0.3476234904818926)
#              indep_Q(cs_K)=0.957241134
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.99901818811014, -99.99947597920865, 0.34626661323255026)
#              indep_Q(cs_K)=1.054552489
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999022057536129, -99.99947878853936, 0.3476234904818926)
#              indep_Q(cs_K)=0.968339481
#   sum(c_s_dual)=0.000000000, UB_total=24.604176156, UB_per_scen=4.920835231
#
#   == Per-scenario Q_s at K_EF = (-9.999022057536129, -99.99947878853936, 0.3476234904818926) ==
#     scen 0: Q_s(K_EF)=0.996279979, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945282584, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.957241134, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054552379, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968339481, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.921695558, sum(c_s)=0.000000000, diff=4.921696e+00
#   --- T10 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999030779674314, -99.99948343715475, 1.2364127961766183)
#              indep_Q(cs_K)=0.996076478
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999022989791971, -99.99947928540135, 0.44262039835695793)
#              indep_Q(cs_K)=0.945222937
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.419018760344231, -98.81826810912887, 1.2812327538045327)
#              indep_Q(cs_K)=0.956086571
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999021714721495, -99.99947674262326, 0.3475998056698346)
#              indep_Q(cs_K)=1.054552380
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.87132943712529, -99.7395000932448, 0.5838243987045667)
#              indep_Q(cs_K)=0.968396846
#   sum(c_s_dual)=0.000000000, UB_total=24.604176156, UB_per_scen=4.920835231
#
#   == Per-scenario Q_s at K_EF = (-9.999022057536129, -99.99947878853936, 0.3476234904818926) ==
#     scen 0: Q_s(K_EF)=0.996279979, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945282584, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.957241134, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054552379, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968339481, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.921695558, sum(c_s)=0.000000000, diff=4.921696e+00
#   --- T11 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999027447195733, -99.99948166105227, 0.896830021496215)
#              indep_Q(cs_K)=0.996004285
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.062596797165444, -99.99953012896741, 0.7983768355734024)
#              indep_Q(cs_K)=0.945141523
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999038579850618, -99.99948871579171, 1.9552186683763046)
#              indep_Q(cs_K)=0.956012781
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999018076338729, -99.99947598470527, 0.34897056554021433)
#              indep_Q(cs_K)=1.054552386
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999025920525563, -99.99948084738683, 0.741262269620894)
#              indep_Q(cs_K)=0.968435634
#   sum(c_s_dual)=0.000000000, UB_total=24.604176156, UB_per_scen=4.920835231
#
#   == Per-scenario Q_s at K_EF = (-9.999022057536129, -99.99947878853936, 0.3476234904818926) ==
#     scen 0: Q_s(K_EF)=0.996279979, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945282584, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.957241134, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054552379, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968339481, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.921695558, sum(c_s)=0.000000000, diff=4.921696e+00
#
# [Iter 2] LB = 4.920147 = UB(4.920835) + ms_b(-2.814e+10) from T11
# [Iter 2] Scene 0: Switched to c_s point. dist_ms_c=1.67e+01 < 1000.0, dist_c_verts=5.49e-01 > 1e-06
# [Iter 2] Scene 1: Switched to c_s point. dist_ms_c=1.68e+01 < 1000.0, dist_c_verts=1.04e+00 > 1e-06
# [Iter 2] Scene 2: Switched to c_s point. dist_ms_c=1.58e+01 < 1000.0, dist_c_verts=1.61e+00 > 1e-06
# [Iter 2] Scene 3: Switched to c_s point. dist_ms_c=1.68e+01 < 1000.0, dist_c_verts=1.35e-03 > 1e-06
# [Iter 2] Scene 4: Switched to c_s point. dist_ms_c=1.73e+01 < 1000.0, dist_c_verts=3.94e-01 > 1e-06
# Chosen node (-9.999025920525565, -99.99948084738683, 0.7412622696209015) with ms=-5.715e+09 (simp T11, scene 4, rank #1, source=c_s)
# [Iter 2] LB simplex = T11, next node simplex = T11, scene 4
# [Selected Simp Info] Iter 2 | Simplex T11 Vertices:
#   v0: (-9.233467561678685, -98.4408518452537, 0.32994040845543465)
#   v1: (-10.0, -100.0, 100.0)
#   v2: (10.0, -100.0, -100.0)
#   v3: (-9.999022057536129, -99.99947878853936, 0.3476234904818926)
#   -> New Point: (-9.999025920525565, -99.99948084738683, 0.7412622696209015)
# [Iter 2] candidate rank #1: T11, scene=4, ms=-5.715e+09
# == ms candidates (sorted by (ms, -dist)) ==
# rank   simp   scene           ms    mind(all)                             pt
# ----------------------------------------------------------------------------
#    1    T11       4  -5.7149e+09     3.94e-01    (-9.9990, -99.9995, 0.7413)
#    2    T11       1  -5.6699e+09     1.04e+00    (-9.0626, -99.9995, 0.7984)
#    3    T11       0  -5.5901e+09     5.49e-01    (-9.9990, -99.9995, 0.8968)
#    4    T11       2  -5.5866e+09     1.61e+00    (-9.9990, -99.9995, 1.9552)
#    5    T11       3  -5.5759e+09     1.35e-03    (-9.9990, -99.9995, 0.3490)
#
# [Iter 2] per_tet=12, active after q_cut=3, tri_is_None=False
# [Iter 2] bad-quality active simplices (q < 0): 0
# [Iter 2] evaluating Q for scenario 0
# [Iter 2] evaluating Q for scenario 1
# [Iter 2] evaluating Q for scenario 2
# [Iter 2] evaluating Q for scenario 3
# [Iter 2] evaluating Q for scenario 4
#
# [Iter 2] Next Point Details:
# Simplex   Scene   Type    As             ms             As+ms          Q              (Kp, Ki, Kd)
# --------------------------------------------------------------------------------------------------------------------
# T11       4       c_s     3.9501e+07     -5.7149e+09    -5.6754e+09    9.6844e-01     (-9.9990, -99.9995, 0.7413)
#
# [Iter 2] subdivision type = edge (code=2) on simplex T11
#            edge local verts = (1, 9)
# [Iter 2] Elapsed: 0.584s
# [Invariant] MS scen None: dual=-5.669239e+09 > primal=-5.669239e+09
# [Invariant] MS scen None: dual=-5.575038e+09 > primal=-5.575038e+09
#
# ======================================================================
# [TIMING] === Iter 2 phase breakdown (total 9.54s) ===
#   1_vertex_UB                    :       0.00s  (  0.0%)
#   2_evaluate_all_tetra           :       0.00s  (  0.0%)
#   3_active_filter_print          :       0.00s  (  0.0%)
#   4_LB_selection                 :       0.00s  (  0.0%)
#   5_EF_UB_solve                  :       0.54s  (  5.7%)  ##
#   6_candidate_selection          :       0.00s  (  0.0%)
#   7_Q_eval_new_node              :       0.04s  (  0.4%)
#   8_mesh_subdivide               :       0.00s  (  0.0%)
#   9_end_of_iter_reeval           :       8.96s  ( 93.9%)  ##############################################
#   TOTAL                          :       9.54s
#   #simplices=12, #scenarios=5, total_ms_pairs=60
#   fresh ms solves=0, cache hits=60
# ======================================================================
#
# ======================================================================
# [Iter 2] LB SPLIT DIAGNOSTIC
#   Selected (parent) simplex: (1, 4, 8, 9)
#   Parent LB: 0.984029313 (per-scen)
#   Parent avg constant cut: 0.984029313 (per-scen)
#   Parent avg c_s Q-value: 0.984212420 (per-scen), point=(np.float64(-9.811741364215218), np.float64(-99.9994914675807), np.float64(0.948131672121406))
#   EF ef_obj(IPOPT): 0.196833440, true_obj(recalc): 0.984167219, used=min=0.196833440 (per-scen)
#   Simplex volume: 5.176987e+02
#   Children (2):
#     T11 (4, 8, 9, 10): LB=0.984129971, avg_cut=0.984129971, avg_cs_Q=0.984209180
#     T12 (1, 4, 8, 10): LB=0.984023740, avg_cut=0.984023740, avg_cs_Q=0.984186205
#   New global LB: 0.984023740 (from T12 (1, 4, 8, 10))
#   Location: INSIDE
#   EF-IPOPT: ok=True, status=ok, term=optimal, time=0.110s, ef_obj=0.9841671975905564, true_obj(per-scen)=0.984167219
#   Current UB (end-of-iter): 0.984167046 (per-scen)
#   UB point: (-9.999022057536129, -99.99947878853936, 0.3476234904818926)
#   UB source: unknown
#   UB simplex: None
#   UB updated this iter: False
# ======================================================================
# [Iter 3] #simplices = 13, #active = 4, bad-quality cut = 0, bad-shape cut = 0
# == [Iter 3] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T8            9.840658e-01      4.060282e+09     -2.969859e+10      4.920329e+00     [4.92e+00, 5.00e+10]    [-2.97e+10, 2.03e+10]     1
# T10           9.840670e-01      4.034003e+09     -2.982999e+10      4.920335e+00     [4.92e+00, 5.00e+10]    [-2.98e+10, 2.02e+10]     1
# T11           9.841300e-01      2.507411e+00     -1.102484e+00      4.920650e+00     [4.92e+00, 1.36e+01]     [3.82e+00, 1.25e+01]     0
# T12           9.840237e-01      4.356265e+09     -2.821867e+10      4.920119e+00     [4.92e+00, 5.00e+10]    [-2.82e+10, 2.18e+10]     1
#
# == [Iter 3] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.023823e+00      4.725871e+09     -2.637064e+10      5.119117e+00     [1.12e+01, 5.00e+10]    [-2.64e+10, 2.36e+10]     1
# T1            1.026329e+00      4.382643e+09     -2.808678e+10      5.131646e+00     [1.11e+01, 5.00e+10]    [-2.81e+10, 2.19e+10]     1
# T2            1.001069e+00      4.242039e+09     -2.878981e+10      5.005344e+00     [1.11e+01, 5.00e+10]    [-2.88e+10, 2.12e+10]     1
# T3            1.023670e+00      4.317792e+09     -2.841104e+10      5.118349e+00     [1.36e+01, 5.00e+10]    [-2.84e+10, 2.16e+10]     2
# T4            1.043636e+00               inf               inf      5.218179e+00     [1.36e+01, 5.00e+10]               [inf, inf]     2
# T5            9.939709e-01      1.385630e+00     -6.711390e+00      4.969854e+00     [4.92e+00, 1.36e+01]    [-1.79e+00, 6.93e+00]     0
# T6            9.899977e-01      4.017689e+09     -2.991155e+10      4.949989e+00     [4.92e+00, 5.00e+10]    [-2.99e+10, 2.01e+10]     1
# T7            9.883553e-01      4.278531e+09     -2.860734e+10      4.941777e+00     [4.92e+00, 5.00e+10]    [-2.86e+10, 2.14e+10]     1
# T9            9.843391e-01      2.510715e+00     -1.085964e+00      4.921696e+00     [4.92e+00, 1.36e+01]     [3.84e+00, 1.26e+01]     0
#
# [Iter 3] created=13 (cum=50), active=4, active+UB=2, ms_recomputed=0
# [Iter 3] EF-ipopt: ok=True, ef_obj=0.9841671976516855, true_obj=9.841672e-01, time=0.110s
# [Iter 3] Pre-split gap: 7.165315e-04 (0.015%)
# [Iter 3] Active simplex ratio = 0.000648
# [Iter 3] UB point (-9.999025920525565, -99.99948084738683, 0.7412622696209015) is geometrically in simplices [8, 10, 11, 12]
#   T8 verts=[9, 1, 4, 0]: λ=[0.996050, 0.003950, 0.000000, 0.000000], LB=4.920329140, c_s=[0.9960059485416161, 0.9451455956752572, 0.9562855603248932, 1.0545522879751763, 0.9683397473109455]
#   T10 verts=[8, 1, 9, 0]: λ=[-0.000000, 0.003950, 0.996050, 0.000000], LB=4.920335144, c_s=[0.9960764457501945, 0.9452229354478225, 0.9560865702052059, 1.0545523587026253, 0.9683968343587215]
#   T11 verts=[10, 9, 8, 4]: λ=[1.000000, -0.000000, 0.000000, 0.000000], LB=4.920649857, c_s=[0.996049136312928, 0.9451277096392667, 0.9565828915982816, 1.0545523574789781, 0.9683377623141298]
#   T12 verts=[1, 10, 8, 4]: λ=[0.000000, 1.000000, -0.000000, 0.000000], LB=4.920118700, c_s=[0.9960032207063211, 0.9451832615020266, 0.9560050617381062, 1.054581571497583, 0.9683455842939538]
#
# == [Iter 3] CS DUAL vs PRIMAL diagnostic (simplices containing UB point) ==
#   --- T8 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999028464402706, -99.99948220319044, 1.0004834530132063)
#              indep_Q(cs_K)=0.996005965
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999024865574523, -99.99948028513231, 0.633762715976422)
#              indep_Q(cs_K)=0.945145610
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.929863443145829, -99.99949254132785, 2.2852265824027866)
#              indep_Q(cs_K)=0.956285563
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.99901151131146, -99.99984311379745, 0.3476258135518927)
#              indep_Q(cs_K)=1.054552309
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999023000679479, -99.99947929120403, 0.4437298359579913)
#              indep_Q(cs_K)=0.968339755
#   sum(c_s_dual)=0.000000000, UB_total=24.604176156, UB_per_scen=4.920835231
#
#   == Per-scenario Q_s at K_EF = (-9.999025920525565, -99.99948084738683, 0.7412622696209015) ==
#     scen 0: Q_s(K_EF)=0.996034443, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945127713, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.956582895, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054676789, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968435634, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.920857473, sum(c_s)=0.000000000, diff=4.920857e+00
#   --- T10 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999030779674314, -99.99948343715475, 1.2364127961766183)
#              indep_Q(cs_K)=0.996076478
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999022989791971, -99.99947928540135, 0.44262039835695793)
#              indep_Q(cs_K)=0.945222937
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.419018760344231, -98.81826810912887, 1.2812327538045327)
#              indep_Q(cs_K)=0.956086571
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999021714721495, -99.99947674262326, 0.3475998056698346)
#              indep_Q(cs_K)=1.054552380
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.87132943712529, -99.7395000932448, 0.5838243987045667)
#              indep_Q(cs_K)=0.968396846
#   sum(c_s_dual)=0.000000000, UB_total=24.604176156, UB_per_scen=4.920835231
#
#   == Per-scenario Q_s at K_EF = (-9.999025920525565, -99.99948084738683, 0.7412622696209015) ==
#     scen 0: Q_s(K_EF)=0.996034443, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945127713, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.956582895, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054676789, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968435634, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.920857473, sum(c_s)=0.000000000, diff=4.920857e+00
#   --- T11 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.998821702982886, -99.99906568536278, 0.6996503874880243)
#              indep_Q(cs_K)=0.996049147
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999025920525565, -99.99948084738683, 0.7412622696209015)
#              indep_Q(cs_K)=0.945127713
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999025721670726, -99.99948126324091, 0.7412622696209015)
#              indep_Q(cs_K)=0.956582895
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999022071684943, -99.99947879608023, 0.3490652552040779)
#              indep_Q(cs_K)=1.054552382
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999022519466347, -99.99947903473311, 0.39469419828871355)
#              indep_Q(cs_K)=0.968337769
#   sum(c_s_dual)=0.000000000, UB_total=24.604176156, UB_per_scen=4.920835231
#
#   == Per-scenario Q_s at K_EF = (-9.999025920525565, -99.99948084738683, 0.7412622696209015) ==
#     scen 0: Q_s(K_EF)=0.996034443, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945127713, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.956582895, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054676789, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968435634, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.920857473, sum(c_s)=0.000000000, diff=4.920857e+00
#   --- T12 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999027646925825, -99.9994817675019, 0.9171825257002797)
#              indep_Q(cs_K)=0.996003229
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.94005343144746, -99.99948554413491, 1.0494381570298992)
#              indep_Q(cs_K)=0.945183286
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999037801772289, -99.99948711790871, 1.94014805774434)
#              indep_Q(cs_K)=0.956005078
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.930625033272023, -99.9994799755338, 0.3967369486682253)
#              indep_Q(cs_K)=1.054581573
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.929084325699629, -99.99948266299334, 0.38894488296840213)
#              indep_Q(cs_K)=0.968345585
#   sum(c_s_dual)=0.000000000, UB_total=24.604176156, UB_per_scen=4.920835231
#
#   == Per-scenario Q_s at K_EF = (-9.999025920525565, -99.99948084738683, 0.7412622696209015) ==
#     scen 0: Q_s(K_EF)=0.996034443, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945127713, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.956582895, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054676789, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968435634, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.920857473, sum(c_s)=0.000000000, diff=4.920857e+00
#
# [Iter 3] LB = 4.920119 = UB(4.920835) + ms_b(-2.822e+10) from T12
# [Iter 3] Scene 0: Switched to c_s point. dist_ms_c=1.67e+01 < 1000.0, dist_c_verts=1.76e-01 > 1e-06
# [Iter 3] Scene 1: Switched to c_s point. dist_ms_c=1.70e+01 < 1000.0, dist_c_verts=3.14e-01 > 1e-06
# [Iter 3] Scene 2: Switched to c_s point. dist_ms_c=1.58e+01 < 1000.0, dist_c_verts=1.20e+00 > 1e-06
# [Iter 3] Scene 3: Switched to c_s point. dist_ms_c=1.67e+01 < 1000.0, dist_c_verts=3.51e-01 > 1e-06
# [Iter 3] Scene 4: Switched to c_s point. dist_ms_c=1.77e+01 < 1000.0, dist_c_verts=3.59e-01 > 1e-06
# Chosen node (-9.92908432569963, -99.99948266299334, 0.3889448829684094) with ms=-5.799e+09 (simp T12, scene 4, rank #1, source=c_s)
# [Iter 3] LB simplex = T12, next node simplex = T12, scene 4
# [Selected Simp Info] Iter 3 | Simplex T12 Vertices:
#   v0: (-10.0, -100.0, 100.0)
#   v1: (-9.999025920525565, -99.99948084738683, 0.7412622696209015)
#   v2: (-9.233467561678685, -98.4408518452537, 0.32994040845543465)
#   v3: (10.0, -100.0, -100.0)
#   -> New Point: (-9.92908432569963, -99.99948266299334, 0.3889448829684094)
# [Iter 3] candidate rank #1: T12, scene=4, ms=-5.799e+09
# == ms candidates (sorted by (ms, -dist)) ==
# rank   simp   scene           ms    mind(all)                             pt
# ----------------------------------------------------------------------------
# ...
# T231          9.840037e-01      1.007494e+00     -5.809906e-02      4.920019e+00     [4.92e+00, 5.10e+00]     [4.86e+00, 5.04e+00]     0
# T232          9.840037e-01      1.007494e+00     -5.809941e-02      4.920019e+00     [4.92e+00, 5.10e+00]     [4.86e+00, 5.04e+00]     0
# T233          9.840037e-01      1.007494e+00     -5.809975e-02      4.920019e+00     [4.92e+00, 5.10e+00]     [4.86e+00, 5.04e+00]     0
# T234          9.840037e-01      1.007494e+00     -5.810009e-02      4.920019e+00     [4.92e+00, 5.10e+00]     [4.86e+00, 5.04e+00]     0
# T235          9.840037e-01      1.007494e+00     -5.810042e-02      4.920019e+00     [4.92e+00, 5.10e+00]     [4.86e+00, 5.04e+00]     0
# T236          9.840037e-01      1.007494e+00     -5.810075e-02      4.920019e+00     [4.92e+00, 5.10e+00]     [4.86e+00, 5.04e+00]     0
# T237          9.840037e-01      1.007493e+00     -5.810107e-02      4.920019e+00     [4.92e+00, 5.10e+00]     [4.86e+00, 5.04e+00]     0
# T238          9.840037e-01      1.007493e+00     -5.810139e-02      4.920019e+00     [4.92e+00, 5.10e+00]     [4.86e+00, 5.04e+00]     0
# T239          9.840037e-01      1.007493e+00     -5.810170e-02      4.920019e+00     [4.92e+00, 5.10e+00]     [4.86e+00, 5.04e+00]     0
# T240          9.840037e-01      1.007493e+00     -5.810200e-02      4.920019e+00     [4.92e+00, 5.10e+00]     [4.86e+00, 5.04e+00]     0
# T241          9.840037e-01      1.007493e+00     -5.810231e-02      4.920019e+00     [4.92e+00, 5.10e+00]     [4.86e+00, 5.04e+00]     0
# T242          9.840037e-01      1.007493e+00     -5.810260e-02      4.920019e+00     [4.92e+00, 5.10e+00]     [4.86e+00, 5.04e+00]     0
# T254          9.840037e-01      1.007495e+00     -5.809451e-02      4.920019e+00     [4.92e+00, 5.10e+00]     [4.86e+00, 5.04e+00]     0
# T274          9.840037e-01      1.007495e+00     -5.809346e-02      4.920018e+00     [4.92e+00, 5.10e+00]     [4.86e+00, 5.04e+00]     0
# T275          9.840037e-01      1.007495e+00     -5.809391e-02      4.920019e+00     [4.92e+00, 5.10e+00]     [4.86e+00, 5.04e+00]     0
# T290          9.840037e-01      1.007489e+00     -5.812201e-02      4.920018e+00     [4.92e+00, 5.10e+00]     [4.86e+00, 5.04e+00]     0
#
# == [Iter 193] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.023823e+00      4.725871e+09     -2.637064e+10      5.119117e+00     [1.12e+01, 5.00e+10]    [-2.64e+10, 2.36e+10]     1
# T1            1.026329e+00      4.382643e+09     -2.808678e+10      5.131646e+00     [1.11e+01, 5.00e+10]    [-2.81e+10, 2.19e+10]     1
# T2            1.001069e+00      4.242039e+09     -2.878981e+10      5.005344e+00     [1.11e+01, 5.00e+10]    [-2.88e+10, 2.12e+10]     1
# T3            1.023670e+00      4.317792e+09     -2.841104e+10      5.118349e+00     [1.36e+01, 5.00e+10]    [-2.84e+10, 2.16e+10]     2
# T4            1.043636e+00               inf               inf      5.218179e+00     [1.36e+01, 5.00e+10]               [inf, inf]     2
# T5            9.939709e-01      1.385630e+00     -6.711390e+00      4.969854e+00     [4.92e+00, 1.36e+01]    [-1.79e+00, 6.93e+00]     0
# T6            9.899977e-01      4.017689e+09     -2.991155e+10      4.949989e+00     [4.92e+00, 5.00e+10]    [-2.99e+10, 2.01e+10]     1
# T7            9.883553e-01      4.278531e+09     -2.860734e+10      4.941777e+00     [4.92e+00, 5.00e+10]    [-2.86e+10, 2.14e+10]     1
# T9            9.843391e-01      2.510715e+00     -1.085964e+00      4.921696e+00     [4.92e+00, 1.36e+01]     [3.84e+00, 1.26e+01]     0
# T69           9.840071e-01      8.108772e+09     -9.456142e+09      4.920035e+00     [4.92e+00, 5.00e+10]    [-9.46e+09, 4.05e+10]     1
# T70           9.840096e-01      8.109877e+09     -9.450613e+09      4.920048e+00     [4.92e+00, 5.00e+10]    [-9.45e+09, 4.05e+10]     1
# T71           9.840096e-01      8.108338e+09     -9.458312e+09      4.920048e+00     [4.92e+00, 5.00e+10]    [-9.46e+09, 4.05e+10]     1
# T72           9.840096e-01      8.109878e+09     -9.450612e+09      4.920048e+00     [4.92e+00, 5.00e+10]    [-9.45e+09, 4.05e+10]     1
# T73           9.840071e-01      8.108338e+09     -9.458311e+09      4.920035e+00     [4.92e+00, 5.00e+10]    [-9.46e+09, 4.05e+10]     1
# T74           9.840045e-01      8.108773e+09     -9.456134e+09      4.920022e+00     [4.92e+00, 5.00e+10]    [-9.46e+09, 4.05e+10]     1
# T75           9.840045e-01      8.108773e+09     -9.456133e+09      4.920022e+00     [4.92e+00, 5.00e+10]    [-9.46e+09, 4.05e+10]     1
# T76           9.840045e-01      8.109878e+09     -9.450609e+09      4.920022e+00     [4.92e+00, 5.00e+10]    [-9.45e+09, 4.05e+10]     1
# T77           9.840045e-01      8.109878e+09     -9.450609e+09      4.920022e+00     [4.92e+00, 5.00e+10]    [-9.45e+09, 4.05e+10]     1
# T78           9.840020e-01      8.109878e+09     -9.450608e+09      4.920010e+00     [4.92e+00, 5.00e+10]    [-9.45e+09, 4.05e+10]     1
# T79           9.840045e-01      8.109879e+09     -9.450607e+09      4.920022e+00     [4.92e+00, 5.00e+10]    [-9.45e+09, 4.05e+10]     1
# T80           9.840045e-01      8.108339e+09     -9.458307e+09      4.920023e+00     [4.92e+00, 5.00e+10]    [-9.46e+09, 4.05e+10]     1
# T81           9.840045e-01      8.108775e+09     -9.456125e+09      4.920023e+00     [4.92e+00, 5.00e+10]    [-9.46e+09, 4.05e+10]     1
# T82           9.840045e-01      8.108775e+09     -9.456123e+09      4.920022e+00     [4.92e+00, 5.00e+10]    [-9.46e+09, 4.05e+10]     1
# T83           9.840045e-01      8.108776e+09     -9.456122e+09      4.920023e+00     [4.92e+00, 5.00e+10]    [-9.46e+09, 4.05e+10]     1
# T84           9.840045e-01      8.108776e+09     -9.456121e+09      4.920022e+00     [4.92e+00, 5.00e+10]    [-9.46e+09, 4.05e+10]     1
# T85           9.840045e-01      8.108776e+09     -9.456120e+09      4.920023e+00     [4.92e+00, 5.00e+10]    [-9.46e+09, 4.05e+10]     1
# T86           9.840045e-01      8.109879e+09     -9.450603e+09      4.920023e+00     [4.92e+00, 5.00e+10]    [-9.45e+09, 4.05e+10]     1
# T87           9.840020e-01      8.108777e+09     -9.456117e+09      4.920010e+00     [4.92e+00, 5.00e+10]    [-9.46e+09, 4.05e+10]     1
# T88           9.840045e-01      8.108777e+09     -9.456116e+09      4.920022e+00     [4.92e+00, 5.00e+10]    [-9.46e+09, 4.05e+10]     1
# T89           9.840045e-01      8.109880e+09     -9.450602e+09      4.920023e+00     [4.92e+00, 5.00e+10]    [-9.45e+09, 4.05e+10]     1
# T90           9.840045e-01      8.109880e+09     -9.450601e+09      4.920023e+00     [4.92e+00, 5.00e+10]    [-9.45e+09, 4.05e+10]     1
# T91           9.840045e-01      8.108777e+09     -9.456113e+09      4.920022e+00     [4.92e+00, 5.00e+10]    [-9.46e+09, 4.05e+10]     1
# T106          6.436832e+01               inf               inf              -inf     [1.00e+10, 5.00e+10]               [inf, inf]     4
# T214          9.842335e-01      1.080106e+00     -2.762761e-01      4.921168e+00     [4.92e+00, 5.68e+00]     [4.65e+00, 5.40e+00]     0
#
# [Iter 193] created=149 (cum=18942), active=115, active+UB=1, ms_recomputed=0
# [Iter 193] EF-ipopt: ok=True, ef_obj=0.9841821627217104, true_obj=9.841822e-01, time=0.096s
# [Iter 193] Pre-split gap: 8.167687e-04 (0.017%)
# [Iter 193] Active simplex ratio = 0.000648
# [Iter 193] UB point (-9.997086636427499, -99.99553168492136, 0.8013184440036956) is geometrically in simplices [10, 93, 94, 112]
#   T10 verts=[8, 1, 9, 0]: λ=[0.002534, 0.004553, 0.992913, -0.000000], LB=4.920335144, c_s=[0.9960764457501945, 0.9452229354478225, 0.9560865702052059, 1.0545523587026253, 0.9683968343587215]
#   T93 verts=[1, 56, 10, 57]: λ=[-0.000000, 0.003149, 0.996851, 0.000000], LB=4.920212947, c_s=[0.9960033314818318, 0.9451477992999695, 0.9559494509736319, 1.0546767476240066, 0.9684356179831483]
#   T94 verts=[56, 58, 57, 10]: λ=[0.003149, 0.000000, 0.000000, 0.996851], LB=4.920180920, c_s=[0.9960055268362888, 0.9451279338831116, 0.9559350527818643, 1.0546767729595774, 0.968435633955268]
#   T112 verts=[70, 71, 69, 8]: λ=[1.000000, -0.000000, 0.000000, 0.000000], LB=4.920233123, c_s=[0.9960139820807139, 0.94512601009914, 0.955938156441168, 1.0547095023121589, 0.9684454722512492]
#
# == [Iter 193] CS DUAL vs PRIMAL diagnostic (simplices containing UB point) ==
#   --- T10 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999030779674314, -99.99948343715475, 1.2364127961766183)
#              indep_Q(cs_K)=0.996076478
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999022989791971, -99.99947928540135, 0.44262039835695793)
#              indep_Q(cs_K)=0.945222937
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.419018760344231, -98.81826810912887, 1.2812327538045327)
#              indep_Q(cs_K)=0.956086571
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999021714721495, -99.99947674262326, 0.3475998056698346)
#              indep_Q(cs_K)=1.054552380
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.87132943712529, -99.7395000932448, 0.5838243987045667)
#              indep_Q(cs_K)=0.968396846
#   sum(c_s_dual)=0.000000000, UB_total=24.604176156, UB_per_scen=4.920835231
#
#   == Per-scenario Q_s at K_EF = (-9.997086636427499, -99.99553168492136, 0.8013184440036956) ==
#     scen 0: Q_s(K_EF)=0.996019050, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945125977, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.956501764, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054719758, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968473314, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.920839862, sum(c_s)=0.000000000, diff=4.920840e+00
#   --- T93 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999027620008938, -99.99948175337741, 0.9144246625955705)
#              indep_Q(cs_K)=0.996003333
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999027991426006, -99.99948195110927, 0.9522871081654843)
#              indep_Q(cs_K)=0.945147800
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.974191668447114, -99.94892433283681, 1.514139612062942)
#              indep_Q(cs_K)=0.955949452
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999025920525565, -99.99948084738683, 0.7412622696209015)
#              indep_Q(cs_K)=1.054676789
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999025920525565, -99.99948084738683, 0.7412622696209015)
#              indep_Q(cs_K)=0.968435634
#   sum(c_s_dual)=0.000000000, UB_total=24.604176156, UB_per_scen=4.920835231
#
#   == Per-scenario Q_s at K_EF = (-9.997086636427499, -99.99553168492136, 0.8013184440036956) ==
#     scen 0: Q_s(K_EF)=0.996019050, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945125977, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.956501764, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054719758, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968473314, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.920839862, sum(c_s)=0.000000000, diff=4.920840e+00
#   --- T94 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.993006709235443, -99.98723869884965, 0.9313227863926612)
#              indep_Q(cs_K)=0.996005533
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.921439314451172, -99.97307634913447, 0.8175308232346176)
#              indep_Q(cs_K)=0.945127934
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.970298658176665, -99.94099567354364, 1.630627686649016)
#              indep_Q(cs_K)=0.955935054
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999025920525565, -99.99948084738683, 0.7412622696209015)
#              indep_Q(cs_K)=1.054676789
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999025920525565, -99.99948084738683, 0.7412622696209006)
#              indep_Q(cs_K)=0.968435634
#   sum(c_s_dual)=0.000000000, UB_total=24.604176156, UB_per_scen=4.920835231
#
#   == Per-scenario Q_s at K_EF = (-9.997086636427499, -99.99553168492136, 0.8013184440036956) ==
#     scen 0: Q_s(K_EF)=0.996019050, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945125977, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.956501764, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054719758, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968473314, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.920839862, sum(c_s)=0.000000000, diff=4.920840e+00
#   --- T112 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.989662420660224, -99.98041299536317, 1.0312331827566847)
#              indep_Q(cs_K)=0.996013986
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.996206627978605, -99.99523347605756, 0.8021609060282542)
#              indep_Q(cs_K)=0.945126010
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.971817321490896, -99.94407319558718, 1.5838641194303993)
#              indep_Q(cs_K)=0.955938178
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.994546314641568, -99.99568639746266, 0.7857962951291801)
#              indep_Q(cs_K)=1.054709505
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.749359472242173, -99.49478557369707, 0.6389391334917125)
#              indep_Q(cs_K)=0.968445475
#   sum(c_s_dual)=0.000000000, UB_total=24.604176156, UB_per_scen=4.920835231
#
#   == Per-scenario Q_s at K_EF = (-9.997086636427499, -99.99553168492136, 0.8013184440036956) ==
#     scen 0: Q_s(K_EF)=0.996019050, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945125977, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.956501764, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054719758, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968473314, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.920839862, sum(c_s)=0.000000000, diff=4.920840e+00
#
# [Iter 193] LB = 4.920018 = UB(4.920835) + ms_b(-5.812e-02) from T290
# [Iter 193] Scene 0: Switched to c_s point. dist_ms_c=2.83e+00 < 1000.0, dist_c_verts=4.79e-01 > 1e-06
# [Iter 193] Scene 1: Switched to c_s point. dist_ms_c=2.96e+00 < 1000.0, dist_c_verts=3.66e-01 > 1e-06
# [Iter 193] Scene 2: Switched to c_s point. dist_ms_c=2.14e+00 < 1000.0, dist_c_verts=1.22e+00 > 1e-06
# [Iter 193] Scene 3: Kept ms point (c_s too close to verts). dist_ms_c=3.19e+00 < 1000.0 BUT dist_c_verts=0.00e+00 <= 1e-06
# [Iter 193] Scene 4: Switched to c_s point. dist_ms_c=3.31e+00 < 1000.0, dist_c_verts=4.80e-05 > 1e-06
# Chosen node (-9.932483912822946, -99.99700846787356, 0.41315309984063875) with ms=-1.250e-02 (simp T290, scene 4, rank #1, source=c_s)
# [Iter 193] LB simplex = T290, next node simplex = T290, scene 4
# [Selected Simp Info] Iter 193 | Simplex T290 Vertices:
#   v0: (-9.931915873016571, -99.99702969907936, 0.4095783536547357)
#   v1: (-9.932491447213264, -99.99700818626619, 0.41320051470972985)
#   v2: (-9.233467561678685, -98.4408518452537, 0.32994040845543465)
#   v3: (-9.7668022139006, -99.619707519511, 6.2714164723728)
#   -> New Point: (-9.932483912822946, -99.99700846787356, 0.41315309984063875)
# [Iter 193] candidate rank #1: T290, scene=4, ms=-1.250e-02
# == ms candidates (sorted by (ms, -dist)) ==
# rank   simp   scene           ms    mind(all)                             pt
# ----------------------------------------------------------------------------
#    1   T290       4  -1.2499e-02     4.80e-05    (-9.9325, -99.9970, 0.4132)
#    2   T290       1  -1.2248e-02     2.45e-02    (-9.9222, -99.9735, 0.7785)
#    3   T290       3  -1.1473e-02     5.51e-02    (-9.8422, -99.7921, 3.5930)
#    4   T290       0  -1.1382e-02     3.74e-02    (-9.9190, -99.9662, 0.8912)
#    5   T290       2  -1.0520e-02     3.34e-01    (-9.8975, -99.9184, 1.6306)
#
# [Iter 193] per_tet=149, active after q_cut=115, tri_is_None=False
# [Iter 193] bad-quality active simplices (q < 0): 0
# [Iter 193] evaluating Q for scenario 0
# [Iter 193] evaluating Q for scenario 1
# [Iter 193] evaluating Q for scenario 2
# [Iter 193] evaluating Q for scenario 3
# [Iter 193] evaluating Q for scenario 4
