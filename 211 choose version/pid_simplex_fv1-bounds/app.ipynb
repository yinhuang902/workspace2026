# %%
from time import perf_counter  

from modeling import build_models_from_csv
from bundles import BaseBundle, MSBundle
from utils import (
    tighten_bounds_one_model,
    MIN_DIST, ACTIVE_TOL, GAP_STOP_TOL,
)
from simplex_specialstart import run_pid_simplex_3d

# setup scenario number and target_nodesk
csv_path       = "data.csv"
max_scenarios  = 5
target_nodes   = 1000

bounds={
    "Kp": (-10.0, 10.0),
    "Ki": (-100.0, 100.0),
    "Kd": (-100.0, 100.0),
    "x": (-2.5, 2.5),
    "u": (-5.0, 5.0),
    "e": (None, None),
    "I": (None, None),
}

weights = (10.0, 0.01)


# ====== stage 1：load data and generate models ======
T   = 15.0          
nfe = 20            

t_load0 = perf_counter()
model_list, first_stg_vars_list, m_tmpl_list, nfe = build_models_from_csv(
    csv_path=csv_path,
    T=T,
    nfe=nfe,
    weights=weights,
    bounds=bounds,
    sp0=0.0,
    sp1=0.5,
    tau_xs_col="tau_xs",
    tau_us_col="tau_us",
    tau_ds_col="tau_ds",          
    disturb_prefix="disturbance_",
    setpoint_change_col="setpoint_change",
    max_scenarios=max_scenarios,
    skip=0,
)
t_load1 = perf_counter()
print(f"[Time] Data load & scenario build: {t_load1 - t_load0:.3f}s")


# ====== stage 1.5：FBBT / OBBT ======
# same as snog: FBBT open,OBBT open
obbt_solver_opts = {
    "NonConvex": 2,
    "MIPGap": 1,     
    "TimeLimit": 15   
}
for m, yvars in zip(model_list, first_stg_vars_list):
    tighten_bounds_one_model(m, yvars,
                             use_fbbt=False,
                             use_obbt=False,
                             obbt_solver_name="gurobi",
                             obbt_solver_opts=obbt_solver_opts,
                             max_rounds=3, tol=1e-6, verbose=True)

# ====== stage 2: Persistent Solver Packaging ======
ub_options = {
    'NonConvex': 2,      
}
lb_options = {
    'NonConvex': 2,
    'MIPGap': 1e-1,            
    'TimeLimit': 60 
}

t_wrap0 = perf_counter()
base_bundles = [BaseBundle(m, ub_options) for m in model_list]  
ms_bundles   = [MSBundle(m, yvars, lb_options) for m, yvars in zip(model_list, first_stg_vars_list)]  
t_wrap1 = perf_counter()
print(f"[Time] Persistent wrapper (GurobiPersistent) setup: {t_wrap1 - t_wrap0:.3f}s")

# ====== stage 3：main loop ======
agg_bundle = None  

t_run0 = perf_counter()
hist = run_pid_simplex_3d(
    base_bundles=base_bundles,
    ms_bundles=ms_bundles,
    model_list=model_list,
    first_vars_list=first_stg_vars_list,
    target_nodes=target_nodes,
    min_dist=0,
    active_tol=ACTIVE_TOL,
    verbose=True,
    agg_bundle=agg_bundle,
    gap_stop_tol=1e-6,
    use_exact_opt=False,
    exact_solver_name="gurobi",
    exact_solver_opts={"NonConvex": 2, "TimeLimit": 60},
    time_limit=60*30*1,
    enable_3d_plot=False,   
    plot_every=None,        
)
t_run1 = perf_counter()
print(f"[Time] Main loop total: {t_run1 - t_run0:.3f}s")

# ====== print output ======
print("\n==== Done ====")
print(f"Total nodes: {len(hist['nodes'])}")
print(f"Best UB: {min(hist['UB_hist']) if hist['UB_hist'] else None}")
print(f"Last LB: {hist['LB_hist'][-1] if hist['LB_hist'] else None}")
# Out:
# [Time] Data load & scenario build: 0.020s
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2689754
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 60
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 60
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 60
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 60
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 60
# [Time] Persistent wrapper (GurobiPersistent) setup: 1.091s
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [TIMING] Pre-loop vertex Q evals: 0.50s  (8 nodes x 5 scenarios = 40 solves)
# [EF-UB] Initialized ipopt EF with 5 scenarios, time_ub=60.0s
#
# ======================================================================
# [TIMING] === Pre-loop phase summary ===
#   corners_and_mesh               :       0.00s
#   vertex_Q_evals                 :       0.50s
#   exact_optima                   :       0.00s
#   ef_init                        :       0.02s
#   TOTAL                          :       0.52s
# ======================================================================
#
# [Iter 0] MIPGap overridden to 0.1 (original: 0.1)
# Discarded solution information
# [Invariant] MS scen None: dual=-5.500707e+09 > primal=-5.500707e+09
# Discarded solution information
# Discarded solution information
# [Invariant] MS scen None: dual=-5.175167e+09 > primal=-5.175167e+09
# Discarded solution information
# Discarded solution information
# [Invariant] MS scen None: dual=-5.866576e+09 > primal=-5.866576e+09
# [Invariant] MS scen None: dual=-6.008581e+09 > primal=-6.008581e+09
# [Invariant] MS scen None: dual=-5.596691e+09 > primal=-5.596691e+09
# [Invariant] MS scen None: dual=-5.776540e+09 > primal=-5.776540e+09
# [Invariant] MS scen None: dual=-5.849076e+09 > primal=-5.849076e+09
# [Invariant] MS scen None: dual=-5.747261e+09 > primal=-5.747261e+09
# [Bundle] MS scen None: infeasibleOrUnbounded. ms_val=nan.
# [Bundle] MS scen None: not optimal. Status=warning, Term=infeasibleOrUnbounded.
# [Invariant] MS scen None: dual=-5.835166e+09 > primal=-5.835166e+09
# [Invariant] MS scen None: dual=-5.856066e+09 > primal=-5.856066e+09
# [Iter 0] MIPGap restored to 0.1
# [Iter 0] #simplices = 6, #active = 6, bad-quality cut = 0, bad-shape cut = 0
# == [Iter 0] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.016493e+00      4.567702e+09     -2.716149e+10      5.082465e+00     [1.12e+01, 5.00e+10]    [-2.72e+10, 2.28e+10]     1
# T1            1.002945e+00      4.012097e+09     -2.993951e+10      5.014724e+00     [1.12e+01, 5.00e+10]    [-2.99e+10, 2.01e+10]     1
# T2            1.041760e+00      4.395550e+09     -2.802225e+10      5.208798e+00     [1.11e+01, 5.00e+10]    [-2.80e+10, 2.20e+10]     1
# T3            1.004007e+00      4.193778e+09     -2.903111e+10      5.020037e+00     [1.11e+01, 5.00e+10]    [-2.90e+10, 2.10e+10]     1
# T4            1.027262e+00      4.274322e+09     -2.862839e+10      5.136312e+00     [1.36e+01, 5.00e+10]    [-2.86e+10, 2.14e+10]     2
# T5            1.035581e+00               inf               inf      5.177904e+00     [1.36e+01, 5.00e+10]               [inf, inf]     2
#
# == [Iter 0] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
#   (none)
# [Iter 0] created=6 (cum=6), active=6, active+UB=2, ms_recomputed=6
# [Iter 0] EF-ipopt: ok=True, ef_obj=0.9841670257415724, true_obj=9.841670e-01, time=0.092s
# [Iter 0] EF-UB improved by ipopt: 9.841670e-01 (per-scen), K=(-9.99989152958837, -99.99979183386104, 0.814277765297143)
# [Iter 0] Pre-split gap: -9.388874e-02 (-1.908%)
# [Iter 0] Active simplex ratio = 1.000000
# [Iter 0] UB point (-9.99989152958837, -99.99979183386104, 0.814277765297143) is geometrically in simplices [1]
#   T1 verts=[3, 1, 4, 0]: λ=[0.000001, 0.504070, 0.000005, 0.495923], LB=5.014723969, c_s=[0.9960029127022256, 1.038030098197515, 0.9571540289698489, 1.0551989733060005, 0.9683379558464811]
#
# == [Iter 0] CS DUAL vs PRIMAL diagnostic (simplices containing UB point) ==
#   --- T1 ---
#     scen 0: status=optimal, dual=0.996002913, primal=0.996002913  ✓ dual ≤ primal (gap=1.110223e-16)
#              cs_primal_K=(-9.999216646683243, -99.99852406033013, 0.9388331317148486)
#              indep_Q(cs_K)=0.996002918  → dual ≤ indep_Q (consistent, diff=4.973934e-09)
#     scen 1: status=optimal, dual=1.038030098, primal=1.038030098  ✓ dual ≤ primal (gap=-4.440892e-16)
#              cs_primal_K=(-8.088273951123846, 0.0, -5.582080575550208e-09)
#              indep_Q(cs_K)=1.038030100  → dual ≤ indep_Q (consistent, diff=2.183044e-09)
#     scen 2: status=optimal, dual=0.957154029, primal=0.957154029  ✓ dual ≤ primal (gap=2.220446e-16)
#              cs_primal_K=(-10.0, -71.04038079399149, 2.221249662676794)
#              indep_Q(cs_K)=0.957154117  → dual ≤ indep_Q (consistent, diff=8.791048e-08)
#     scen 3: status=optimal, dual=1.055198973, primal=1.055198973  ✓ dual ≤ primal (gap=2.220446e-16)
#              cs_primal_K=(-9.233467561678685, -98.4408518452537, 0.32994040845543465)
#              indep_Q(cs_K)=1.055198979  → dual ≤ indep_Q (consistent, diff=5.506025e-09)
#     scen 4: status=optimal, dual=0.968337956, primal=0.968337956  ✓ dual ≤ primal (gap=0.000000e+00)
#              cs_primal_K=(-9.998518091599312, -99.9972050307925, 0.39376151703840556)
#              indep_Q(cs_K)=0.968337957  → dual ≤ indep_Q (consistent, diff=1.643293e-09)
#   sum(c_s_dual)=5.014723969, UB_total=24.604176169, UB_per_scen=4.920835234
#
#   == Per-scenario Q_s at K_EF = (-9.99989152958837, -99.99979183386104, 0.814277765297143) ==
#     scen 0: Q_s(K_EF)=0.996015235, c_s_dual=0.996002913  ✓ Q_s(K_EF) > c_s_dual (diff=1.232268e-05)
#     scen 1: Q_s(K_EF)=0.945126284, c_s_dual=1.038030098  ⚠ Q_s(K_EF) < c_s_dual → GUROBI CS DUAL IS WRONG
#     scen 2: Q_s(K_EF)=0.956484730, c_s_dual=0.957154029  ⚠ Q_s(K_EF) < c_s_dual → GUROBI CS DUAL IS WRONG
#     scen 3: Q_s(K_EF)=1.054727427, c_s_dual=1.055198973  ⚠ Q_s(K_EF) < c_s_dual → GUROBI CS DUAL IS WRONG
#     scen 4: Q_s(K_EF)=0.968481558, c_s_dual=0.968337956  ✓ Q_s(K_EF) > c_s_dual (diff=1.436021e-04)
#     SUM Q_s(K_EF)=4.920835234, sum(c_s)=5.014723969, diff=-9.388874e-02
#
# [Iter 0] LB = 5.014724 = UB(4.920835) + ms_b(-2.994e+10) from T1
# [Iter 0] Scene 0: Switched to c_s point. dist_ms_c=1.81e+01 < 1000.0, dist_c_verts=9.91e+01 > 1e-06
# [Iter 0] Scene 1: Switched to c_s point. dist_ms_c=1.02e+02 < 1000.0, dist_c_verts=1.41e+02 > 1e-06
# [Iter 0] Scene 2: Switched to c_s point. dist_ms_c=3.43e+01 < 1000.0, dist_c_verts=1.02e+02 > 1e-06
# [Iter 0] Scene 3: Switched to c_s point. dist_ms_c=2.06e+01 < 1000.0, dist_c_verts=9.97e+01 > 1e-06
# [Iter 0] Scene 4: Switched to c_s point. dist_ms_c=1.98e+01 < 1000.0, dist_c_verts=9.96e+01 > 1e-06
# Chosen node (-9.233467561678685, -98.4408518452537, 0.32994040845543465) with ms=-6.045e+09 (simp T1, scene 3, rank #1, source=c_s)
# [Iter 0] LB simplex = T1, next node simplex = T1, scene 3
# [Selected Simp Info] Iter 0 | Simplex T1 Vertices:
#   v0: (-10.0, 100.0, 100.0)
#   v1: (-10.0, -100.0, 100.0)
#   v2: (10.0, -100.0, -100.0)
#   v3: (-10.0, -100.0, -100.0)
#   -> New Point: (-9.233467561678685, -98.4408518452537, 0.32994040845543465)
# [Iter 0] candidate rank #1: T1, scene=3, ms=-6.045e+09
# == ms candidates (sorted by (ms, -dist)) ==
# rank   simp   scene           ms    mind(all)                             pt
# ----------------------------------------------------------------------------
#    1     T1       3  -6.0450e+09     9.97e+01    (-9.2335, -98.4409, 0.3299)
#    2     T1       2  -6.0269e+09     1.02e+02   (-10.0000, -71.0404, 2.2212)
#    3     T1       4  -6.0086e+09     9.96e+01    (-9.9985, -99.9972, 0.3938)
#    4     T1       1  -5.9925e+09     1.41e+02     (-8.0883, 0.0000, -0.0000)
#    5     T1       0  -5.8666e+09     9.91e+01    (-9.9992, -99.9985, 0.9388)
#
# [Iter 0] per_tet=6, active after q_cut=6, tri_is_None=False
# [Iter 0] bad-quality active simplices (q < 0): 0
# [Iter 0] evaluating Q for scenario 0
# [Iter 0] evaluating Q for scenario 1
# [Iter 0] evaluating Q for scenario 2
# [Iter 0] evaluating Q for scenario 3
# [Iter 0] evaluating Q for scenario 4
#
# [Iter 0] Next Point Details:
# Simplex   Scene   Type    As             ms             As+ms          Q              (Kp, Ki, Kd)
# --------------------------------------------------------------------------------------------------------------------
# T1        3       c_s     4.9385e+09     -6.0450e+09    -1.1065e+09    1.0552e+00     (-9.2335, -98.4409, 0.3299)
#
# [Iter 0] subdivision type = interior (code=1) on simplex T1
# [Iter 0] Elapsed: 17.266s
# [Invariant] MS scen None: dual=-5.664126e+09 > primal=-5.664126e+09
# [Invariant] MS scen None: dual=-5.762388e+09 > primal=-5.762388e+09
# [Invariant] MS scen None: dual=-5.508409e+09 > primal=-5.508409e+09
# ======================================================================
# [Iter 0] LB SPLIT DIAGNOSTIC
#   Selected (parent) simplex: (0, 1, 3, 4)
#   Parent LB: 1.002944794 (per-scen)
#   EF ef_obj(IPOPT): 0.196833405, true_obj(recalc): 0.984167047, used=min=0.196833405 (per-scen)
#   Simplex volume: 1.333333e+05
#   Children (4):
#     T5 (0, 1, 4, 8): LB = 0.984085913
#     T6 (0, 3, 4, 8): LB = 0.986564090
#     T7 (0, 1, 3, 8): LB = 1.000397133
#     T8 (1, 3, 4, 8): LB = 0.984266905
#   New global LB: 0.984085913 (from T5 (0, 1, 4, 8))
#   Location: INSIDE
#   Avg CS point Q-value: 0.987575289 (per-scen), point=(np.float64(-9.463895250217018), np.float64(-73.89539234607356), np.float64(0.7767569428606804))
#   Current UB: 0.984167047 (per-scen)
#   UB point: (-9.99989152958837, -99.99979183386104, 0.814277765297143)
#   UB source: EF_ipopt
#   UB simplex: (0, 1, 3, 4)
#   EF-IPOPT: ok=True, status=ok, term=optimal, time=0.092s, ef_obj=0.9841670257415724, true_obj(per-scen)=0.984167047
# ======================================================================
#
# ======================================================================
# [TIMING] === Iter 0 phase breakdown (total 327.27s) ===
#   1_vertex_UB                    :       0.00s  (  0.0%)
#   2_evaluate_all_tetra           :      16.88s  (  5.2%)  ##
#   3_active_filter_print          :       0.00s  (  0.0%)
#   4_LB_selection                 :       0.00s  (  0.0%)
#   5_EF_UB_solve                  :       0.19s  (  0.1%)
#   6_candidate_selection          :       0.17s  (  0.1%)
#   7_Q_eval_new_node              :       0.03s  (  0.0%)
#   8_mesh_subdivide               :       0.00s  (  0.0%)
#   9_end_of_iter_reeval           :     310.01s  ( 94.7%)  ###############################################
#   TOTAL                          :     327.27s
#   #simplices=6, #scenarios=5, total_ms_pairs=30
#   fresh ms solves=30, cache hits=0
# ======================================================================
#
# [Iter 1] #simplices = 9, #active = 1, bad-quality cut = 0, bad-shape cut = 0
# == [Iter 1] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T5            9.840859e-01      4.114231e+09     -2.942885e+10      4.920430e+00     [4.92e+00, 5.00e+10]    [-2.94e+10, 2.06e+10]     1
#
# == [Iter 1] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.016493e+00      4.567702e+09     -2.716149e+10      5.082465e+00     [1.12e+01, 5.00e+10]    [-2.72e+10, 2.28e+10]     1
# T1            1.041760e+00      4.395550e+09     -2.802225e+10      5.208798e+00     [1.11e+01, 5.00e+10]    [-2.80e+10, 2.20e+10]     1
# T2            1.004007e+00      4.193778e+09     -2.903111e+10      5.020037e+00     [1.11e+01, 5.00e+10]    [-2.90e+10, 2.10e+10]     1
# T3            1.027262e+00      4.274322e+09     -2.862839e+10      5.136312e+00     [1.36e+01, 5.00e+10]    [-2.86e+10, 2.14e+10]     2
# T4            1.035581e+00               inf               inf      5.177904e+00     [1.36e+01, 5.00e+10]               [inf, inf]     2
# T6            9.865641e-01      1.385630e+00     -6.711390e+00      4.932820e+00     [4.92e+00, 1.36e+01]    [-1.79e+00, 6.93e+00]     0
# T7            1.000397e+00      4.005557e+09     -2.997221e+10      5.001986e+00     [4.92e+00, 5.00e+10]    [-3.00e+10, 2.00e+10]     1
# T8            9.842669e-01      4.319191e+09     -2.840404e+10      4.921335e+00     [4.92e+00, 5.00e+10]    [-2.84e+10, 2.16e+10]     1
#
# [Iter 1] created=9 (cum=19), active=1, active+UB=1, ms_recomputed=0
# [Iter 1] EF-ipopt: ok=True, ef_obj=0.9841670252034732, true_obj=9.841670e-01, time=0.131s
# [Iter 1] EF-UB improved by ipopt: 9.841670e-01 (per-scen), K=(-9.999868030729935, -99.99984336305558, 0.8142777531758494)
# [Iter 1] Pre-split gap: 4.056682e-04 (0.008%)
# [Iter 1] Active simplex ratio = 0.001299
# [Iter 1] UB point (-9.999868030729935, -99.99984336305558, 0.8142777531758494) is geometrically in simplices [5]
#   T5 verts=[8, 1, 4, 0]: λ=[0.000100, 0.504021, 0.000003, 0.495876], LB=4.920429563, c_s=[0.9960031107379561, 0.9452697109883083, 0.9562292881494647, 1.0545523581483314, 0.968375095022594]
#
# == [Iter 1] CS DUAL vs PRIMAL diagnostic (simplices containing UB point) ==
#   --- T5 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 0.9134094278217795)
#              indep_Q(cs_K)=0.996003112
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 0.36633507986468417)
#              indep_Q(cs_K)=0.945269711
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 1.0408548481984807)
#              indep_Q(cs_K)=0.956229288
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999022057536129, -99.99947878853936, 0.3476234904818926)
#              indep_Q(cs_K)=1.054552379
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 0.17532773291335785)
#              indep_Q(cs_K)=0.968375107
#   sum(c_s_dual)=0.000000000, UB_total=24.604176156, UB_per_scen=4.920835231
#
#   == Per-scenario Q_s at K_EF = (-9.999868030729935, -99.99984336305558, 0.8142777531758494) ==
#     scen 0: Q_s(K_EF)=0.996015235, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945126284, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.956484729, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054727426, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968481557, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.920835231, sum(c_s)=0.000000000, diff=4.920835e+00
#
# [Iter 1] LB = 4.920430 = UB(4.920835) + ms_b(-2.943e+10) from T5
# [Iter 1] Scene 0: Switched to c_s point. dist_ms_c=1.87e+01 < 1000.0, dist_c_verts=1.83e+00 > 1e-06
# [Iter 1] Scene 1: Switched to c_s point. dist_ms_c=1.84e+01 < 1000.0, dist_c_verts=1.74e+00 > 1e-06
# [Iter 1] Scene 2: Switched to c_s point. dist_ms_c=1.81e+01 < 1000.0, dist_c_verts=1.88e+00 > 1e-06
# [Iter 1] Scene 3: Switched to c_s point. dist_ms_c=2.00e+01 < 1000.0, dist_c_verts=1.74e+00 > 1e-06
# [Iter 1] Scene 4: Switched to c_s point. dist_ms_c=1.47e+01 < 1000.0, dist_c_verts=1.74e+00 > 1e-06
# Chosen node (-9.999022057536129, -99.99947878853936, 0.3476234904818926) with ms=-6.015e+09 (simp T5, scene 3, rank #1, source=c_s)
# [Iter 1] LB simplex = T5, next node simplex = T5, scene 3
# [Selected Simp Info] Iter 1 | Simplex T5 Vertices:
#   v0: (-9.233467561678685, -98.4408518452537, 0.32994040845543465)
#   v1: (-10.0, -100.0, 100.0)
#   v2: (10.0, -100.0, -100.0)
#   v3: (-10.0, -100.0, -100.0)
#   -> New Point: (-9.999022057536129, -99.99947878853936, 0.3476234904818926)
# [Iter 1] candidate rank #1: T5, scene=3, ms=-6.015e+09
# == ms candidates (sorted by (ms, -dist)) ==
# rank   simp   scene           ms    mind(all)                             pt
# ----------------------------------------------------------------------------
#    1     T5       3  -6.0147e+09     1.74e+00    (-9.9990, -99.9995, 0.3476)
#    2     T5       0  -5.9800e+09     1.83e+00  (-10.0000, -100.0000, 0.9134)
#    3     T5       2  -5.8929e+09     1.88e+00  (-10.0000, -100.0000, 1.0409)
#    4     T5       1  -5.8771e+09     1.74e+00  (-10.0000, -100.0000, 0.3663)
#    5     T5       4  -5.6641e+09     1.74e+00  (-10.0000, -100.0000, 0.1753)
#
# [Iter 1] per_tet=9, active after q_cut=1, tri_is_None=False
# [Iter 1] bad-quality active simplices (q < 0): 0
# [Iter 1] evaluating Q for scenario 0
# [Iter 1] evaluating Q for scenario 1
# [Iter 1] evaluating Q for scenario 2
# [Iter 1] evaluating Q for scenario 3
# [Iter 1] evaluating Q for scenario 4
#
# [Iter 1] Next Point Details:
# Simplex   Scene   Type    As             ms             As+ms          Q              (Kp, Ki, Kd)
# --------------------------------------------------------------------------------------------------------------------
# T5        3       c_s     5.0157e+09     -6.0147e+09    -9.9899e+08    1.0546e+00     (-9.9990, -99.9995, 0.3476)
#
# [Iter 1] subdivision type = interior (code=1) on simplex T5
# [Iter 1] Elapsed: 0.355s
# [Invariant] MS scen None: dual=-5.961202e+09 > primal=-5.961202e+09
# [Invariant] MS scen None: dual=-5.669856e+09 > primal=-5.669856e+09
# [Invariant] MS scen None: dual=-5.541664e+09 > primal=-5.541664e+09
# ======================================================================
# [Iter 1] LB SPLIT DIAGNOSTIC
#   Selected (parent) simplex: (0, 1, 4, 8)
#   Parent LB: 0.984085913 (per-scen)
#   EF ef_obj(IPOPT): 0.196833405, true_obj(recalc): 0.984167046, used=min=0.196833405 (per-scen)
#   Simplex volume: 1.039432e+03
#   Children (4):
#     T8 (0, 1, 4, 9): LB = 0.984074967
#     T9 (0, 4, 8, 9): LB = 0.984339101
#     T10 (0, 1, 8, 9): LB = 0.984034724
#     T11 (1, 4, 8, 9): LB = 0.984038333
#   New global LB: 0.984034724 (from T10 (0, 1, 8, 9))
#   Location: INSIDE
#   Avg CS point Q-value: 0.984215218 (per-scen), point=(np.float64(-9.999804411507226), np.float64(-99.99989575770788), np.float64(0.5687101158560389))
#   Current UB: 0.984167046 (per-scen)
#   UB point: (-9.999868030729935, -99.99984336305558, 0.8142777531758494)
#   UB source: EF_ipopt
#   UB simplex: (0, 1, 4, 8)
#   EF-IPOPT: ok=True, status=ok, term=optimal, time=0.131s, ef_obj=0.9841670252034732, true_obj(per-scen)=0.984167046
# ======================================================================
# [BaseBundle.eval_at] Infeasible/Error for K=(-5.698973136888684, -100.0, 18.533215698887894): status=warning, term=infeasibleOrUnbounded
#
# ======================================================================
# [TIMING] === Iter 1 phase breakdown (total 11.89s) ===
#   1_vertex_UB                    :       0.00s  (  0.0%)
#   2_evaluate_all_tetra           :       0.00s  (  0.0%)
#   3_active_filter_print          :       0.00s  (  0.0%)
#   4_LB_selection                 :       0.00s  (  0.0%)
#   5_EF_UB_solve                  :       0.30s  (  2.5%)  #
#   6_candidate_selection          :       0.00s  (  0.0%)
#   7_Q_eval_new_node              :       0.05s  (  0.4%)
#   8_mesh_subdivide               :       0.00s  (  0.0%)
#   9_end_of_iter_reeval           :      11.54s  ( 97.0%)  ################################################
#   TOTAL                          :      11.89s
#   #simplices=9, #scenarios=5, total_ms_pairs=45
#   fresh ms solves=0, cache hits=45
# ======================================================================
#
# [Iter 2] #simplices = 12, #active = 3, bad-quality cut = 0, bad-shape cut = 0
# == [Iter 2] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T8            9.840750e-01      4.073339e+09     -2.963330e+10      4.920375e+00     [4.92e+00, 5.00e+10]    [-2.96e+10, 2.04e+10]     1
# T10           9.840347e-01      4.034003e+09     -2.982999e+10      4.920174e+00     [4.92e+00, 5.00e+10]    [-2.98e+10, 2.02e+10]     1
# T11           9.840383e-01      4.407186e+09     -2.796407e+10      4.920192e+00     [4.92e+00, 5.00e+10]    [-2.80e+10, 2.20e+10]     1
#
# == [Iter 2] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.016493e+00      4.567702e+09     -2.716149e+10      5.082465e+00     [1.12e+01, 5.00e+10]    [-2.72e+10, 2.28e+10]     1
# T1            1.041760e+00      4.395550e+09     -2.802225e+10      5.208798e+00     [1.11e+01, 5.00e+10]    [-2.80e+10, 2.20e+10]     1
# T2            1.004007e+00      4.193778e+09     -2.903111e+10      5.020037e+00     [1.11e+01, 5.00e+10]    [-2.90e+10, 2.10e+10]     1
# T3            1.027262e+00      4.274322e+09     -2.862839e+10      5.136312e+00     [1.36e+01, 5.00e+10]    [-2.86e+10, 2.14e+10]     2
# T4            1.035581e+00               inf               inf      5.177904e+00     [1.36e+01, 5.00e+10]               [inf, inf]     2
# T5            9.865641e-01      1.385630e+00     -6.711390e+00      4.932820e+00     [4.92e+00, 1.36e+01]    [-1.79e+00, 6.93e+00]     0
# T6            1.000397e+00      4.005557e+09     -2.997221e+10      5.001986e+00     [4.92e+00, 5.00e+10]    [-3.00e+10, 2.00e+10]     1
# T7            9.842669e-01      4.319191e+09     -2.840404e+10      4.921335e+00     [4.92e+00, 5.00e+10]    [-2.84e+10, 2.16e+10]     1
# T9            9.843391e-01      2.510715e+00     -1.085964e+00      4.921696e+00     [4.92e+00, 1.36e+01]     [3.84e+00, 1.26e+01]     0
#
# [Iter 2] created=12 (cum=35), active=3, active+UB=3, ms_recomputed=0
# [Iter 2] EF-ipopt: ok=True, ef_obj=0.9841670226961443, true_obj=9.841670e-01, time=0.088s
# [Iter 2] EF-UB improved by ipopt: 9.841670e-01 (per-scen), K=(-9.99990061910784, -99.99981068463768, 0.8142778071696543)
# [Iter 2] Pre-split gap: 6.616007e-04 (0.013%)
# [Iter 2] Active simplex ratio = 0.000648
# [Iter 2] UB point (-9.99990061910784, -99.99981068463768, 0.8142778071696543) is geometrically in simplices [10]
#   T10 verts=[8, 1, 9, 0]: λ=[0.000119, 0.499627, 0.008739, 0.491515], LB=4.920173618, c_s=[0.9960028513956714, 0.9451370945412669, 0.9560865702052059, 1.0545523587026253, 0.9683947430671415]
#
# == [Iter 2] CS DUAL vs PRIMAL diagnostic (simplices containing UB point) ==
#   --- T10 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999027829390139, -99.99948186474944, 0.9357756468444853)
#              indep_Q(cs_K)=0.996002857
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999027540288179, -99.99948171066752, 0.9063161455872306)
#              indep_Q(cs_K)=0.945137096
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.419018760344231, -98.81826810912887, 1.2812327538045327)
#              indep_Q(cs_K)=0.956086571
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999021714721495, -99.99947674262326, 0.3475998056698346)
#              indep_Q(cs_K)=1.054552380
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.839900337572434, -99.67551265894205, 0.5500328421776295)
#              indep_Q(cs_K)=0.968394792
#   sum(c_s_dual)=0.000000000, UB_total=24.604176093, UB_per_scen=4.920835219
#
#   == Per-scenario Q_s at K_EF = (-9.99990061910784, -99.99981068463768, 0.8142778071696543) ==
#     scen 0: Q_s(K_EF)=0.996015231, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945126284, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.956484729, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054727419, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968481556, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.920835219, sum(c_s)=0.000000000, diff=4.920835e+00
#
# [Iter 2] LB = 4.920174 = UB(4.920835) + ms_b(-2.983e+10) from T10
# [Iter 2] Scene 0: Switched to c_s point. dist_ms_c=1.84e+01 < 1000.0, dist_c_verts=5.88e-01 > 1e-06
# [Iter 2] Scene 1: Switched to c_s point. dist_ms_c=1.82e+01 < 1000.0, dist_c_verts=5.59e-01 > 1e-06
# [Iter 2] Scene 2: Switched to c_s point. dist_ms_c=1.80e+01 < 1000.0, dist_c_verts=1.04e+00 > 1e-06
# [Iter 2] Scene 3: Switched to c_s point. dist_ms_c=1.96e+01 < 1000.0, dist_c_verts=2.38e-05 > 1e-06
# [Iter 2] Scene 4: Switched to c_s point. dist_ms_c=1.85e+01 < 1000.0, dist_c_verts=4.14e-01 > 1e-06
# Chosen node (-9.999021714721495, -99.99947674262326, 0.3475998056698346) with ms=-5.995e+09 (simp T10, scene 3, rank #1, source=c_s)
# [Iter 2] LB simplex = T10, next node simplex = T10, scene 3
# [Selected Simp Info] Iter 2 | Simplex T10 Vertices:
#   v0: (-9.233467561678685, -98.4408518452537, 0.32994040845543465)
#   v1: (-10.0, -100.0, 100.0)
#   v2: (-9.999022057536129, -99.99947878853936, 0.3476234904818926)
#   v3: (-10.0, -100.0, -100.0)
#   -> New Point: (-9.999021714721495, -99.99947674262326, 0.3475998056698346)
# [Iter 2] candidate rank #1: T10, scene=3, ms=-5.995e+09
# == ms candidates (sorted by (ms, -dist)) ==
# rank   simp   scene           ms    mind(all)                             pt
# ----------------------------------------------------------------------------
#    1    T10       3  -5.9955e+09     2.38e-05    (-9.9990, -99.9995, 0.3476)
#    2    T10       0  -5.9661e+09     5.88e-01    (-9.9990, -99.9995, 0.9358)
#    3    T10       2  -5.9612e+09     1.04e+00    (-9.4190, -98.8183, 1.2812)
#    4    T10       4  -5.9544e+09     4.14e-01    (-9.8399, -99.6755, 0.5500)
#    5    T10       1  -5.9528e+09     5.59e-01    (-9.9990, -99.9995, 0.9063)
#
# [Iter 2] per_tet=12, active after q_cut=3, tri_is_None=False
# [Iter 2] bad-quality active simplices (q < 0): 0
# [Iter 2] evaluating Q for scenario 0
# [Iter 2] evaluating Q for scenario 1
# [Iter 2] evaluating Q for scenario 2
# [Iter 2] evaluating Q for scenario 3
# [Iter 2] evaluating Q for scenario 4
#
# [Iter 2] Next Point Details:
# Simplex   Scene   Type    As             ms             As+ms          Q              (Kp, Ki, Kd)
# --------------------------------------------------------------------------------------------------------------------
# T10       3       c_s     4.6002e+06     -5.9955e+09    -5.9909e+09    1.0546e+00     (-9.9990, -99.9995, 0.3476)
#
# [Iter 2] subdivision type = interior (code=1) on simplex T10
# [Iter 2] Elapsed: 0.264s
# [Invariant] MS scen None: dual=-5.961202e+09 > primal=-5.961202e+09
# [Invariant] MS scen None: dual=-5.954414e+09 > primal=-5.954414e+09
# ======================================================================
# [Iter 2] LB SPLIT DIAGNOSTIC
#   Selected (parent) simplex: (0, 1, 8, 9)
#   Parent LB: 0.984034724 (per-scen)
#   EF ef_obj(IPOPT): 0.196833405, true_obj(recalc): 0.984167044, used=min=0.196833405 (per-scen)
#   Simplex volume: 3.750772e-02
#   Children (4):
#     T13 (0, 1, 8, 10): LB = 0.984071668
#   New global LB: 0.984038333 (from T10 (1, 4, 8, 9))
#   Location: OUTSIDE
#   Avg CS point Q-value: 0.984216782 (per-scen), point=(np.float64(-9.851199236463296), np.float64(-99.69844421722223), np.float64(0.8041914388167426))
#   Current UB: 0.984167044 (per-scen)
#   UB point: (-9.99990061910784, -99.99981068463768, 0.8142778071696543)
#   UB source: EF_ipopt
#   UB simplex: (0, 1, 8, 9)
#   EF-IPOPT: ok=True, status=ok, term=optimal, time=0.088s, ef_obj=0.9841670226961443, true_obj(per-scen)=0.984167044
# ======================================================================
#
# ======================================================================
# [TIMING] === Iter 2 phase breakdown (total 2.54s) ===
#   1_vertex_UB                    :       0.00s  (  0.0%)
#   2_evaluate_all_tetra           :       0.00s  (  0.0%)
#   3_active_filter_print          :       0.00s  (  0.0%)
#   4_LB_selection                 :       0.00s  (  0.0%)
#   5_EF_UB_solve                  :       0.21s  (  8.5%)  ####
#   6_candidate_selection          :       0.00s  (  0.0%)
#   7_Q_eval_new_node              :       0.05s  (  1.8%)
#   8_mesh_subdivide               :       0.00s  (  0.0%)
#   9_end_of_iter_reeval           :       2.27s  ( 89.6%)  ############################################
#   TOTAL                          :       2.54s
#   #simplices=12, #scenarios=5, total_ms_pairs=60
#   fresh ms solves=0, cache hits=60
# ======================================================================
#
# [Iter 3] #simplices = 12, #active = 3, bad-quality cut = 0, bad-shape cut = 0
# == [Iter 3] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T8            9.840750e-01      4.073339e+09     -2.963330e+10      4.920375e+00     [4.92e+00, 5.00e+10]    [-2.96e+10, 2.04e+10]     1
# T10           9.840383e-01      4.407186e+09     -2.796407e+10      4.920192e+00     [4.92e+00, 5.00e+10]    [-2.80e+10, 2.20e+10]     1
# T13           9.840717e-01      4.042876e+09     -2.978562e+10      4.920358e+00     [4.92e+00, 5.00e+10]    [-2.98e+10, 2.02e+10]     1
#
# == [Iter 3] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.016493e+00      4.567702e+09     -2.716149e+10      5.082465e+00     [1.12e+01, 5.00e+10]    [-2.72e+10, 2.28e+10]     1
# T1            1.041760e+00      4.395550e+09     -2.802225e+10      5.208798e+00     [1.11e+01, 5.00e+10]    [-2.80e+10, 2.20e+10]     1
# T2            1.004007e+00      4.193778e+09     -2.903111e+10      5.020037e+00     [1.11e+01, 5.00e+10]    [-2.90e+10, 2.10e+10]     1
# T3            1.027262e+00      4.274322e+09     -2.862839e+10      5.136312e+00     [1.36e+01, 5.00e+10]    [-2.86e+10, 2.14e+10]     2
# T4            1.035581e+00               inf               inf      5.177904e+00     [1.36e+01, 5.00e+10]               [inf, inf]     2
# T5            9.865641e-01      1.385630e+00     -6.711390e+00      4.932820e+00     [4.92e+00, 1.36e+01]    [-1.79e+00, 6.93e+00]     0
# T6            1.000397e+00      4.005557e+09     -2.997221e+10      5.001986e+00     [4.92e+00, 5.00e+10]    [-3.00e+10, 2.00e+10]     1
# T7            9.842669e-01      4.319191e+09     -2.840404e+10      4.921335e+00     [4.92e+00, 5.00e+10]    [-2.84e+10, 2.16e+10]     1
# T9            9.843391e-01      2.510715e+00     -1.085964e+00      4.921696e+00     [4.92e+00, 1.36e+01]     [3.84e+00, 1.26e+01]     0
#
# [Iter 3] created=12 (cum=48), active=3, active+UB=2, ms_recomputed=0
# [Iter 3] EF-ipopt: ok=True, ef_obj=0.9841671975905564, true_obj=9.841672e-01, time=0.108s
# [Iter 3] Pre-split gap: 6.435519e-04 (0.013%)
# [Iter 3] Active simplex ratio = 0.000648
# [Iter 3] UB point (-9.999022057536129, -99.99947878853936, 0.3476234904818926) is geometrically in simplices [8, 9, 10]
#   T8 verts=[9, 1, 4, 0]: λ=[1.000000, 0.000000, 0.000000, -0.000000], LB=4.920374836, c_s=[0.9960400120219969, 0.9451544959852746, 0.9562843442917788, 1.0545522879751763, 0.968343695371421]
#   T9 verts=[8, 9, 4, 0]: λ=[0.000000, 1.000000, -0.000000, -0.000000], LB=4.921695505, c_s=[0.9962799762933386, 0.9452825841125264, 0.9572411326639916, 1.0545523617094508, 0.9683394501062152]
#   T10 verts=[8, 1, 4, 9]: λ=[0.000000, 0.000000, 0.000000, 1.000000], LB=4.920191667, c_s=[0.9960098351549802, 0.9451739803964943, 0.9561054525015523, 1.054552361731593, 0.9683500368994875]
#
# == [Iter 3] CS DUAL vs PRIMAL diagnostic (simplices containing UB point) ==
#   --- T8 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999025755237996, -99.99948075929395, 0.7244194598399203)
#              indep_Q(cs_K)=0.996040259
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.99902455209528, -99.99948011805809, 0.6018191686863619)
#              indep_Q(cs_K)=0.945154519
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.966273244604025, -99.99949063680043, 2.2852265824027866)
#              indep_Q(cs_K)=0.956284347
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.99901151131146, -99.99984311379745, 0.3476258135518927)
#              indep_Q(cs_K)=1.054552309
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999022452525537, -99.99947899905584, 0.30709324460604703)
#              indep_Q(cs_K)=0.968343731
#   sum(c_s_dual)=0.000000000, UB_total=24.604176093, UB_per_scen=4.920835219
#
#   == Per-scenario Q_s at K_EF = (-9.999022057536129, -99.99947878853936, 0.3476234904818926) ==
#     scen 0: Q_s(K_EF)=0.996279979, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945282584, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.957241134, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054552379, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968339481, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.921695558, sum(c_s)=0.000000000, diff=4.921696e+00
#   --- T9 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999022057536129, -99.99947878853936, 0.3476234904818926)
#              indep_Q(cs_K)=0.996279979
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999022057536129, -99.99947878853936, 0.3476234904818926)
#              indep_Q(cs_K)=0.945282584
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999022057536129, -99.99947878853936, 0.3476234904818926)
#              indep_Q(cs_K)=0.957241134
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.99901818811014, -99.99947597920865, 0.34626661323255026)
#              indep_Q(cs_K)=1.054552489
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999022057536129, -99.99947878853936, 0.3476234904818926)
#              indep_Q(cs_K)=0.968339481
#   sum(c_s_dual)=0.000000000, UB_total=24.604176093, UB_per_scen=4.920835219
#
#   == Per-scenario Q_s at K_EF = (-9.999022057536129, -99.99947878853936, 0.3476234904818926) ==
#     scen 0: Q_s(K_EF)=0.996279979, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945282584, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.957241134, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054552379, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968339481, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.921695558, sum(c_s)=0.000000000, diff=4.921696e+00
#   --- T10 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999026949573796, -99.999481395836, 0.8461223262483301)
#              indep_Q(cs_K)=0.996009848
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999028752531265, -99.99948235675357, 1.0298437647660037)
#              indep_Q(cs_K)=0.945173983
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999040400517528, -99.99948794190242, 2.0977010335177932)
#              indep_Q(cs_K)=0.956105454
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999018076338729, -99.99947598470527, 0.34897056554021433)
#              indep_Q(cs_K)=1.054552386
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.910627456670742, -99.99948394091464, 0.4486827877424299)
#              indep_Q(cs_K)=0.968350081
#   sum(c_s_dual)=0.000000000, UB_total=24.604176093, UB_per_scen=4.920835219
#
#   == Per-scenario Q_s at K_EF = (-9.999022057536129, -99.99947878853936, 0.3476234904818926) ==
#     scen 0: Q_s(K_EF)=0.996279979, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945282584, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.957241134, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054552379, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968339481, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.921695558, sum(c_s)=0.000000000, diff=4.921696e+00
#
# [Iter 3] LB = 4.920192 = UB(4.920835) + ms_b(-2.796e+10) from T10
# [Iter 3] Scene 0: Switched to c_s point. dist_ms_c=1.68e+01 < 1000.0, dist_c_verts=4.98e-01 > 1e-06
# [Iter 3] Scene 1: Switched to c_s point. dist_ms_c=1.70e+01 < 1000.0, dist_c_verts=6.82e-01 > 1e-06
# [Iter 3] Scene 2: Switched to c_s point. dist_ms_c=1.57e+01 < 1000.0, dist_c_verts=1.75e+00 > 1e-06
# [Iter 3] Scene 3: Switched to c_s point. dist_ms_c=1.68e+01 < 1000.0, dist_c_verts=1.35e-03 > 1e-06
# [Iter 3] Scene 4: Switched to c_s point. dist_ms_c=1.61e+01 < 1000.0, dist_c_verts=1.34e-01 > 1e-06
# Chosen node (-9.999028752531263, -99.99948235675356, 1.029843764766007) with ms=-5.670e+09 (simp T10, scene 1, rank #1, source=c_s)
# [Iter 3] LB simplex = T10, next node simplex = T10, scene 1
# [Selected Simp Info] Iter 3 | Simplex T10 Vertices:
#   v0: (-9.233467561678685, -98.4408518452537, 0.32994040845543465)
#   v1: (-10.0, -100.0, 100.0)
#   v2: (10.0, -100.0, -100.0)
#   v3: (-9.999022057536129, -99.99947878853936, 0.3476234904818926)
#   -> New Point: (-9.999028752531263, -99.99948235675356, 1.029843764766007)
# [Iter 3] candidate rank #1: T10, scene=1, ms=-5.670e+09
# == ms candidates (sorted by (ms, -dist)) ==
# rank   simp   scene           ms    mind(all)                             pt
# ----------------------------------------------------------------------------
#    1    T10       1  -5.6699e+09     6.82e-01    (-9.9990, -99.9995, 1.0298)
#    2    T10       0  -5.5901e+09     4.98e-01    (-9.9990, -99.9995, 0.8461)
#    3    T10       2  -5.5866e+09     1.75e+00    (-9.9990, -99.9995, 2.0977)
#    4    T10       3  -5.5759e+09     1.35e-03    (-9.9990, -99.9995, 0.3490)
#    5    T10       4  -5.5417e+09     1.34e-01    (-9.9106, -99.9995, 0.4487)
#
# [Iter 3] per_tet=12, active after q_cut=3, tri_is_None=False
# [Iter 3] bad-quality active simplices (q < 0): 0
# [Iter 3] evaluating Q for scenario 0
# [Iter 3] evaluating Q for scenario 1
# [Iter 3] evaluating Q for scenario 2
# [Iter 3] evaluating Q for scenario 3
# [Iter 3] evaluating Q for scenario 4
#
# [Iter 3] Next Point Details:
# Simplex   Scene   Type    As             ms             As+ms          Q              (Kp, Ki, Kd)
# --------------------------------------------------------------------------------------------------------------------
# T10       1       c_s     6.8460e+07     -5.6699e+09    -5.6014e+09    9.4517e-01     (-9.9990, -99.9995, 1.0298)
#
# [Iter 3] subdivision type = edge (code=2) on simplex T10
#            edge local verts = (1, 9)
# [Iter 3] Elapsed: 0.447s
# [Invariant] MS scen None: dual=-5.574731e+09 > primal=-5.574731e+09
# [Invariant] MS scen None: dual=-5.540552e+09 > primal=-5.540552e+09
# ======================================================================
# [Iter 3] LB SPLIT DIAGNOSTIC
#   Selected (parent) simplex: (1, 4, 8, 9)
#   Parent LB: 0.984038333 (per-scen)
#   EF ef_obj(IPOPT): 0.196833440, true_obj(recalc): 0.984167219, used=min=0.196833440 (per-scen)
#   Simplex volume: 5.176987e+02
#   Children (2):
#     T14 (4, 8, 9, 11): LB = 0.984051769
#     T15 (1, 4, 8, 11): LB = 0.984030711
#   New global LB: 0.984030711 (from T15 (1, 4, 8, 11))
#   Location: INSIDE
#   Avg CS point Q-value: 0.984186058 (per-scen), point=(np.float64(-9.981348327126412), np.float64(-99.9994823240224), np.float64(0.9542640955629544))
#   Current UB: 0.984167044 (per-scen)
#   UB point: (-9.999022057536129, -99.99947878853936, 0.3476234904818926)
#   UB source: unknown
#   UB simplex: None
#   EF-IPOPT: ok=True, status=ok, term=optimal, time=0.108s, ef_obj=0.9841671975905564, true_obj(per-scen)=0.984167219
# ======================================================================
#
# ======================================================================
# [TIMING] === Iter 3 phase breakdown (total 6.43s) ===
#   1_vertex_UB                    :       0.00s  (  0.0%)
#   2_evaluate_all_tetra           :       0.00s  (  0.0%)
#   3_active_filter_print          :       0.00s  (  0.0%)
#   4_LB_selection                 :       0.00s  (  0.0%)
#   5_EF_UB_solve                  :       0.40s  (  6.3%)  ###
#   6_candidate_selection          :       0.00s  (  0.0%)
#   7_Q_eval_new_node              :       0.04s  (  0.6%)
#   8_mesh_subdivide               :       0.00s  (  0.0%)
#   9_end_of_iter_reeval           :       5.99s  ( 93.1%)  ##############################################
#   TOTAL                          :       6.43s
#   #simplices=12, #scenarios=5, total_ms_pairs=60
#   fresh ms solves=0, cache hits=60
# ======================================================================
#
# [Iter 4] #simplices = 13, #active = 4, bad-quality cut = 0, bad-shape cut = 0
# == [Iter 4] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T8            9.840750e-01      4.073339e+09     -2.963330e+10      4.920375e+00     [4.92e+00, 5.00e+10]    [-2.96e+10, 2.04e+10]     1
# T12           9.840717e-01      4.042876e+09     -2.978562e+10      4.920358e+00     [4.92e+00, 5.00e+10]    [-2.98e+10, 2.02e+10]     1
# T14           9.840518e-01      2.504893e+00     -1.115075e+00      4.920259e+00     [4.92e+00, 1.36e+01]     [3.81e+00, 1.25e+01]     0
# T15           9.840307e-01      4.385454e+09     -2.807273e+10      4.920154e+00     [4.92e+00, 5.00e+10]    [-2.81e+10, 2.19e+10]     1
#
# == [Iter 4] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.016493e+00      4.567702e+09     -2.716149e+10      5.082465e+00     [1.12e+01, 5.00e+10]    [-2.72e+10, 2.28e+10]     1
# T1            1.041760e+00      4.395550e+09     -2.802225e+10      5.208798e+00     [1.11e+01, 5.00e+10]    [-2.80e+10, 2.20e+10]     1
# T2            1.004007e+00      4.193778e+09     -2.903111e+10      5.020037e+00     [1.11e+01, 5.00e+10]    [-2.90e+10, 2.10e+10]     1
# T3            1.027262e+00      4.274322e+09     -2.862839e+10      5.136312e+00     [1.36e+01, 5.00e+10]    [-2.86e+10, 2.14e+10]     2
# T4            1.035581e+00               inf               inf      5.177904e+00     [1.36e+01, 5.00e+10]               [inf, inf]     2
# T5            9.865641e-01      1.385630e+00     -6.711390e+00      4.932820e+00     [4.92e+00, 1.36e+01]    [-1.79e+00, 6.93e+00]     0
# T6            1.000397e+00      4.005557e+09     -2.997221e+10      5.001986e+00     [4.92e+00, 5.00e+10]    [-3.00e+10, 2.00e+10]     1
# T7            9.842669e-01      4.319191e+09     -2.840404e+10      4.921335e+00     [4.92e+00, 5.00e+10]    [-2.84e+10, 2.16e+10]     1
# T9            9.843391e-01      2.510715e+00     -1.085964e+00      4.921696e+00     [4.92e+00, 1.36e+01]     [3.84e+00, 1.26e+01]     0
#
# [Iter 4] created=13 (cum=63), active=4, active+UB=2, ms_recomputed=0
# [Iter 4] EF-ipopt: ok=True, ef_obj=0.9841737852571211, true_obj=9.841738e-01, time=0.093s
# [Iter 4] Pre-split gap: 6.816640e-04 (0.014%)
# [Iter 4] Active simplex ratio = 0.000648
# [Iter 4] UB point (-9.999028752531263, -99.99948235675356, 1.029843764766007) is geometrically in simplices [8, 14, 15]
#   T8 verts=[9, 1, 4, 0]: λ=[0.993154, 0.006846, -0.000000, -0.000000], LB=4.920374836, c_s=[0.9960400120219969, 0.9451544959852746, 0.9562843442917788, 1.0545522879751763, 0.968343695371421]
#   T14 verts=[11, 9, 8, 4]: λ=[1.000000, -0.000000, 0.000000, 0.000000], LB=4.920258843, c_s=[0.9960028396419306, 0.945125870518334, 0.9562399926197916, 1.0545523615768722, 0.9683377785664646]
#   T15 verts=[1, 11, 8, 4]: λ=[0.000000, 1.000000, 0.000000, 0.000000], LB=4.920153555, c_s=[0.9960257820332752, 0.9452117100312839, 0.9559567544107913, 1.0546043685000746, 0.9683549396031296]
#
# == [Iter 4] CS DUAL vs PRIMAL diagnostic (simplices containing UB point) ==
#   --- T8 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999025755237996, -99.99948075929395, 0.7244194598399203)
#              indep_Q(cs_K)=0.996040259
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.99902455209528, -99.99948011805809, 0.6018191686863619)
#              indep_Q(cs_K)=0.945154519
#     scen 2: status=?, dual=N/A, primal=N/A
# ...
# T0            1.016493e+00      4.567702e+09     -2.716149e+10      5.082465e+00     [1.12e+01, 5.00e+10]    [-2.72e+10, 2.28e+10]     1
# T1            1.041760e+00      4.395550e+09     -2.802225e+10      5.208798e+00     [1.11e+01, 5.00e+10]    [-2.80e+10, 2.20e+10]     1
# T2            1.004007e+00      4.193778e+09     -2.903111e+10      5.020037e+00     [1.11e+01, 5.00e+10]    [-2.90e+10, 2.10e+10]     1
# T3            1.027262e+00      4.274322e+09     -2.862839e+10      5.136312e+00     [1.36e+01, 5.00e+10]    [-2.86e+10, 2.14e+10]     2
# T4            1.035581e+00               inf               inf      5.177904e+00     [1.36e+01, 5.00e+10]               [inf, inf]     2
# T5            9.865641e-01      1.385630e+00     -6.711390e+00      4.932820e+00     [4.92e+00, 1.36e+01]    [-1.79e+00, 6.93e+00]     0
# T6            1.000397e+00      4.005557e+09     -2.997221e+10      5.001986e+00     [4.92e+00, 5.00e+10]    [-3.00e+10, 2.00e+10]     1
# T7            9.842669e-01      4.319191e+09     -2.840404e+10      4.921335e+00     [4.92e+00, 5.00e+10]    [-2.84e+10, 2.16e+10]     1
# T9            9.843391e-01      2.510715e+00     -1.085964e+00      4.921696e+00     [4.92e+00, 1.36e+01]     [3.84e+00, 1.26e+01]     0
# T15           9.844372e-01      4.362402e+09     -2.818799e+10      4.922186e+00     [4.92e+00, 5.00e+10]    [-2.82e+10, 2.18e+10]     1
# T17           9.843103e-01      2.510377e+00     -1.087653e+00      4.921552e+00     [4.92e+00, 1.36e+01]     [3.83e+00, 1.26e+01]     0
# T18           9.842983e-01      2.510211e+00     -1.088482e+00      4.921491e+00     [4.92e+00, 1.36e+01]     [3.83e+00, 1.26e+01]     0
# T19           9.842964e-01      2.510198e+00     -1.088549e+00      4.921482e+00     [4.92e+00, 1.36e+01]     [3.83e+00, 1.26e+01]     0
# T20           9.842964e-01      2.510198e+00     -1.088549e+00      4.921482e+00     [4.92e+00, 1.36e+01]     [3.83e+00, 1.26e+01]     0
# T26           9.842993e-01      1.431722e+00     -3.608250e-01      4.921497e+00     [4.92e+00, 7.52e+00]     [4.56e+00, 7.16e+00]     0
# T42           9.843058e-01      1.092056e+00     -1.112784e-01      4.921529e+00     [4.92e+00, 5.57e+00]     [4.81e+00, 5.46e+00]     0
#
# [Iter 43] created=24 (cum=989), active=8, active+UB=6, ms_recomputed=0
# [Iter 43] EF-ipopt: ok=True, ef_obj=1.0422115158577328, true_obj=9.849660e-01, time=0.110s
# [Iter 43] Pre-split gap: 5.705419e-04 (0.012%)
# [Iter 43] Active simplex ratio = 0.000153
# [Iter 43] UB point (-9.999028752531263, -99.99948235675356, 1.029843764766007) is geometrically in simplices [8, 14, 16, 23, 28, 29, 92]
#   T8 verts=[9, 1, 4, 0]: λ=[0.993154, 0.006846, -0.000000, -0.000000], LB=4.920374836, c_s=[0.9960400120219969, 0.9451544959852746, 0.9562843442917788, 1.0545522879751763, 0.968343695371421]
#   T14 verts=[12, 11, 4, 8]: λ=[0.000000, 1.000000, -0.000000, 0.000000], LB=4.920332258, c_s=[0.9960061035841458, 0.9451265767315171, 0.9562435376802266, 1.0546043674590215, 0.9683516729188357]
#   T16 verts=[1, 11, 12, 8]: λ=[0.000000, 1.000000, 0.000000, 0.000000], LB=4.920602554, c_s=[0.9961056776692035, 0.9451424839802833, 0.9559493738707757, 1.0549205269507234, 0.9684844914047674]
#   T23 verts=[15, 17, 11, 8]: λ=[0.000000, -0.000000, 1.000000, -0.000000], LB=4.920684897, c_s=[0.9960029038335125, 0.9451257998412276, 0.956239993678145, 1.0545554069741137, 0.9683379847509965]
#   T28 verts=[18, 20, 11, 8]: λ=[0.000000, -0.000000, 1.000000, 0.000000], LB=4.920685724, c_s=[0.9960029406284827, 0.9451258055049335, 0.956239993678145, 1.054555368035272, 0.9683379825026801]
#   T29 verts=[20, 21, 11, 8]: λ=[0.000000, -0.000000, 1.000000, 0.000000], LB=4.920687038, c_s=[0.9960029954951338, 0.9451258146284501, 0.956239993678145, 1.0545553647703516, 0.9683380495932514]
#   T92 verts=[50, 33, 11, 8]: λ=[0.000000, -0.000000, 1.000000, 0.000000], LB=4.920264677, c_s=[0.9960049274859624, 0.9451260069100229, 0.9562399930256221, 1.0545554439003668, 0.9683383053431746]
#
# == [Iter 43] CS DUAL vs PRIMAL diagnostic (simplices containing UB point) ==
#   --- T8 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999025755237996, -99.99948075929395, 0.7244194598399203)
#              indep_Q(cs_K)=0.996040259
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.99902455209528, -99.99948011805809, 0.6018191686863619)
#              indep_Q(cs_K)=0.945154519
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.966273244604025, -99.99949063680043, 2.2852265824027866)
#              indep_Q(cs_K)=0.956284347
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.99901151131146, -99.99984311379745, 0.3476258135518927)
#              indep_Q(cs_K)=1.054552309
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999022452525537, -99.99947899905584, 0.30709324460604703)
#              indep_Q(cs_K)=0.968343731
#   sum(c_s_dual)=0.000000000, UB_total=24.604176093, UB_per_scen=4.920835219
#
#   == Per-scenario Q_s at K_EF = (-9.999028752531263, -99.99948235675356, 1.029843764766007) ==
#     scen 0: Q_s(K_EF)=0.996009654, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945173983, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.956240036, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054931519, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968671125, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.921026317, sum(c_s)=0.000000000, diff=4.921026e+00
#   --- T14 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.985255025646733, -99.99948271326471, 0.9602625119750929)
#              indep_Q(cs_K)=0.996006137
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.952354529712533, -99.99948356484204, 0.7940578424810906)
#              indep_Q(cs_K)=0.945126577
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.931881507030598, -99.99948586550289, 1.0291564367668806)
#              indep_Q(cs_K)=0.956243575
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.873516980454488, -99.99948449779518, 0.39580505784012976)
#              indep_Q(cs_K)=1.054604369
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.875021437843747, -99.99948556648688, 0.4033913613220588)
#              indep_Q(cs_K)=0.968351687
#   sum(c_s_dual)=0.000000000, UB_total=24.604176093, UB_per_scen=4.920835219
#
#   == Per-scenario Q_s at K_EF = (-9.999028752531263, -99.99948235675356, 1.029843764766007) ==
#     scen 0: Q_s(K_EF)=0.996009654, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945173983, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.956240036, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054931519, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968671125, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.921026317, sum(c_s)=0.000000000, diff=4.921026e+00
#   --- T16 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.99903130611445, -99.99948371773017, 1.290053994585849)
#              indep_Q(cs_K)=0.996105684
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.424786538193992, -99.2088068902098, 0.775286475255981)
#              indep_Q(cs_K)=0.945142490
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.470462435763949, -99.99201823848517, 1.6069952839139616)
#              indep_Q(cs_K)=0.955949398
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.8716925537617, -99.74023451740108, 0.9134284684271305)
#              indep_Q(cs_K)=1.054920532
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.524802184528145, -99.03398932094494, 0.596288915639725)
#              indep_Q(cs_K)=0.968484494
#   sum(c_s_dual)=0.000000000, UB_total=24.604176093, UB_per_scen=4.920835219
#
#   == Per-scenario Q_s at K_EF = (-9.999028752531263, -99.99948235675356, 1.029843764766007) ==
#     scen 0: Q_s(K_EF)=0.996009654, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945173983, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.956240036, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054931519, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968671125, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.921026317, sum(c_s)=0.000000000, diff=4.921026e+00
#   --- T23 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999027942361135, -99.99948192495928, 0.9472873960248492)
#              indep_Q(cs_K)=0.996002911
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999026412414779, -99.99948110954774, 0.7913858006902503)
#              indep_Q(cs_K)=0.945125801
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999028752531263, -99.99948235675356, 1.029843764766007)
#              indep_Q(cs_K)=0.956240036
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.99821536256192, -99.99947487868856, 0.40637822382046934)
#              indep_Q(cs_K)=1.054555412
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999022673293254, -99.99947911671782, 0.4103691665152251)
#              indep_Q(cs_K)=0.968337985
#   sum(c_s_dual)=0.000000000, UB_total=24.604176093, UB_per_scen=4.920835219
#
#   == Per-scenario Q_s at K_EF = (-9.999028752531263, -99.99948235675356, 1.029843764766007) ==
#     scen 0: Q_s(K_EF)=0.996009654, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945173983, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.956240036, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054931519, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968671125, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.921026317, sum(c_s)=0.000000000, diff=4.921026e+00
#   --- T28 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.998910077981877, -99.99948193543291, 0.9481111925645369)
#              indep_Q(cs_K)=0.996002948
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.998682537024578, -99.99948112761264, 0.7914010317308736)
#              indep_Q(cs_K)=0.945125806
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999028752531263, -99.99948235675356, 1.029843764766007)
#              indep_Q(cs_K)=0.956240036
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.996941120850543, -99.99947500084241, 0.40016386899216755)
#              indep_Q(cs_K)=1.054555370
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.998122778349584, -99.99947914034666, 0.4058885814535501)
#              indep_Q(cs_K)=0.968337983
#   sum(c_s_dual)=0.000000000, UB_total=24.604176093, UB_per_scen=4.920835219
#
#   == Per-scenario Q_s at K_EF = (-9.999028752531263, -99.99948235675356, 1.029843764766007) ==
#     scen 0: Q_s(K_EF)=0.996009654, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945173983, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.956240036, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054931519, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968671125, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.921026317, sum(c_s)=0.000000000, diff=4.921026e+00
#   --- T29 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.998723477450827, -99.9994819502708, 0.9490833329825077)
#              indep_Q(cs_K)=0.996003003
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.998127506816186, -99.99948115671835, 0.7914194787456975)
#              indep_Q(cs_K)=0.945125815
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999028752531263, -99.99948235675356, 1.029843764766007)
#              indep_Q(cs_K)=0.956240036
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.996642962676521, -99.9994791800041, 0.3986837678923254)
#              indep_Q(cs_K)=1.054555366
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.996642962676521, -99.9994791800041, 0.3986837678923254)
#              indep_Q(cs_K)=0.968338050
#   sum(c_s_dual)=0.000000000, UB_total=24.604176093, UB_per_scen=4.920835219
#
#   == Per-scenario Q_s at K_EF = (-9.999028752531263, -99.99948235675356, 1.029843764766007) ==
#     scen 0: Q_s(K_EF)=0.996009654, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945173983, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.956240036, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054931519, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968671125, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.921026317, sum(c_s)=0.000000000, diff=4.921026e+00
#   --- T92 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.998294477666505, -99.99947148478982, 0.890237102037635)
#              indep_Q(cs_K)=0.996004930
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.996126894588436, -99.99946322278628, 0.7755050927266535)
#              indep_Q(cs_K)=0.945126007
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999028752531263, -99.99948235675356, 1.029843764766007)
#              indep_Q(cs_K)=0.956240036
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.995662675055296, -99.99943020741046, 0.3945328559834081)
#              indep_Q(cs_K)=1.054555445
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.99576104189174, -99.99943397373886, 0.4085584681538875)
#              indep_Q(cs_K)=0.968338305
#   sum(c_s_dual)=0.000000000, UB_total=24.604176093, UB_per_scen=4.920835219
#
#   == Per-scenario Q_s at K_EF = (-9.999028752531263, -99.99948235675356, 1.029843764766007) ==
#     scen 0: Q_s(K_EF)=0.996009654, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945173983, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.956240036, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054931519, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968671125, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.921026317, sum(c_s)=0.000000000, diff=4.921026e+00
#
# [Iter 43] LB = 4.920265 = UB(4.920835) + ms_b(-3.591e-02) from T92
# [Iter 43] Scene 0: Switched to c_s point. dist_ms_c=3.35e+00 < 1000.0, dist_c_verts=1.40e-01 > 1e-06
# [Iter 43] Scene 1: Switched to c_s point. dist_ms_c=3.22e+00 < 1000.0, dist_c_verts=2.54e-01 > 1e-06
# [Iter 43] Scene 2: Kept ms point (c_s too close to verts). dist_ms_c=3.48e+00 < 1000.0 BUT dist_c_verts=0.00e+00 <= 1e-06
# [Iter 43] Scene 3: Switched to c_s point. dist_ms_c=2.87e+00 < 1000.0, dist_c_verts=9.11e-05 > 1e-06
# [Iter 43] Scene 4: Switched to c_s point. dist_ms_c=2.86e+00 < 1000.0, dist_c_verts=1.39e-02 > 1e-06
# Chosen node (-9.995662675055296, -99.99943020741046, 0.3945328559834081) with ms=-7.621e-03 (simp T92, scene 3, rank #1, source=c_s)
# [Iter 43] LB simplex = T92, next node simplex = T92, scene 3
# [Selected Simp Info] Iter 43 | Simplex T92 Vertices:
#   v0: (-9.995687733182109, -99.99943288830114, 0.3946203847579752)
#   v1: (-8.539398193669264, -99.99951931887631, -6.343826232813843)
#   v2: (-9.999028752531263, -99.99948235675356, 1.029843764766007)
#   v3: (-9.233467561678685, -98.4408518452537, 0.32994040845543465)
#   -> New Point: (-9.995662675055296, -99.99943020741046, 0.3945328559834081)
# [Iter 43] candidate rank #1: T92, scene=3, ms=-7.621e-03
# == ms candidates (sorted by (ms, -dist)) ==
# rank   simp   scene           ms    mind(all)                             pt
# ----------------------------------------------------------------------------
#    1    T92       3  -7.6212e-03     9.11e-05    (-9.9957, -99.9994, 0.3945)
#    2    T92       4  -7.4008e-03     3.27e-03    (-9.9958, -99.9994, 0.4086)
#    3    T92       1  -7.2111e-03     2.54e-01    (-9.9961, -99.9995, 0.7755)
#    4    T92       0  -7.2012e-03     1.40e-01    (-9.9983, -99.9995, 0.8902)
#    5    T92       2  -6.4792e-03     2.81e+00   (-9.3236, -99.9995, -2.3823)
#
# [Iter 43] per_tet=24, active after q_cut=8, tri_is_None=False
# [Iter 43] bad-quality active simplices (q < 0): 0
# [Iter 43] evaluating Q for scenario 0
# [Iter 43] evaluating Q for scenario 1
# [Iter 43] evaluating Q for scenario 2
# [Iter 43] evaluating Q for scenario 3
# [Iter 43] evaluating Q for scenario 4
#
# [Iter 43] Next Point Details:
# Simplex   Scene   Type    As             ms             As+ms          Q              (Kp, Ki, Kd)
# --------------------------------------------------------------------------------------------------------------------
# T92       3       c_s     1.0546e+00     -7.6212e-03    1.0469e+00     1.0546e+00     (-9.9957, -99.9994, 0.3945)
#
# [Iter 43] subdivision type = interior (code=1) on simplex T92
# [Iter 43] Elapsed: 0.722s
