# %%
from time import perf_counter  

from modeling import build_models_from_csv
from bundles import BaseBundle, MSBundle
from utils import (
    tighten_bounds_one_model,
    MIN_DIST, ACTIVE_TOL, GAP_STOP_TOL,
)
from simplex_specialstart import run_pid_simplex_3d

# setup scenario number and target_nodesk
csv_path       = "data.csv"
max_scenarios  = 5
target_nodes   = 1000

bounds={
    "Kp": (-10.0, 10.0),
    "Ki": (-100.0, 100.0),
    "Kd": (-100.0, 100.0),
    "x": (-2.5, 2.5),
    "u": (-5.0, 5.0),
    "e": (None, None),
    "I": (None, None),
}

weights = (10.0, 0.01)


# ====== stage 1：load data and generate models ======
T   = 15.0          
nfe = 20            

t_load0 = perf_counter()
model_list, first_stg_vars_list, m_tmpl_list, nfe = build_models_from_csv(
    csv_path=csv_path,
    T=T,
    nfe=nfe,
    weights=weights,
    bounds=bounds,
    sp0=0.0,
    sp1=0.5,
    tau_xs_col="tau_xs",
    tau_us_col="tau_us",
    tau_ds_col="tau_ds",          
    disturb_prefix="disturbance_",
    setpoint_change_col="setpoint_change",
    max_scenarios=max_scenarios,
    skip=0,
)
t_load1 = perf_counter()
print(f"[Time] Data load & scenario build: {t_load1 - t_load0:.3f}s")


# ====== stage 1.5：FBBT / OBBT ======
# same as snog: FBBT open,OBBT open
obbt_solver_opts = {
    "NonConvex": 2,
    "MIPGap": 1,     
    "TimeLimit": 15   
}
for m, yvars in zip(model_list, first_stg_vars_list):
    tighten_bounds_one_model(m, yvars,
                             use_fbbt=False,
                             use_obbt=False,
                             obbt_solver_name="gurobi",
                             obbt_solver_opts=obbt_solver_opts,
                             max_rounds=3, tol=1e-6, verbose=True)

# ====== stage 2: Persistent Solver Packaging ======
ub_options = {
    'NonConvex': 2,      
}
lb_options = {
    'NonConvex': 2,
    'MIPGap': 1e-1,            
    'TimeLimit': 15 
}

t_wrap0 = perf_counter()
base_bundles = [BaseBundle(m, ub_options) for m in model_list]  
ms_bundles   = [MSBundle(m, yvars, lb_options) for m, yvars in zip(model_list, first_stg_vars_list)]  
t_wrap1 = perf_counter()
print(f"[Time] Persistent wrapper (GurobiPersistent) setup: {t_wrap1 - t_wrap0:.3f}s")

# ====== stage 3：main loop ======
agg_bundle = None  

t_run0 = perf_counter()
hist = run_pid_simplex_3d(
    base_bundles=base_bundles,
    ms_bundles=ms_bundles,
    model_list=model_list,
    first_vars_list=first_stg_vars_list,
    target_nodes=target_nodes,
    min_dist=0,
    active_tol=ACTIVE_TOL,
    verbose=True,
    agg_bundle=agg_bundle,
    gap_stop_tol=1e-6,
    use_exact_opt=False,
    exact_solver_name="gurobi",
    exact_solver_opts={"NonConvex": 2, "TimeLimit": 60},
    time_limit=60*15*1,
    enable_3d_plot=False,   
    plot_every=None,        
)
t_run1 = perf_counter()
print(f"[Time] Main loop total: {t_run1 - t_run0:.3f}s")

# ====== print output ======
print("\n==== Done ====")
print(f"Total nodes: {len(hist['nodes'])}")
print(f"Best UB: {min(hist['UB_hist']) if hist['UB_hist'] else None}")
print(f"Last LB: {hist['LB_hist'][-1] if hist['LB_hist'] else None}")
# Out:
# [Time] Data load & scenario build: 0.108s
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2689754
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 15
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 15
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 15
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 15
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 15
# [Time] Persistent wrapper (GurobiPersistent) setup: 3.685s
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [TIMING] Pre-loop vertex Q evals: 2.77s  (8 nodes x 5 scenarios = 40 solves)
# [EF-UB] Initialized ipopt EF with 5 scenarios, time_ub=60.0s
#
# ======================================================================
# [TIMING] === Pre-loop phase summary ===
#   corners_and_mesh               :       0.00s
#   vertex_Q_evals                 :       2.77s
#   exact_optima                   :       0.00s
#   ef_init                        :       0.03s
#   TOTAL                          :       2.81s
# ======================================================================
#
# [Iter 0] MIPGap overridden to 0.1 (original: 0.1)
# Discarded solution information
# [Invariant] MS scen None: dual=-5.500707e+09 > primal=-5.500707e+09
# Discarded solution information
# Discarded solution information
# [Invariant] MS scen None: dual=-5.175167e+09 > primal=-5.175167e+09
# Discarded solution information
# Discarded solution information
# [Invariant] MS scen None: dual=-5.866576e+09 > primal=-5.866576e+09
# [Invariant] MS scen None: dual=-6.008581e+09 > primal=-6.008581e+09
# [Invariant] MS scen None: dual=-5.596691e+09 > primal=-5.596691e+09
# [Invariant] MS scen None: dual=-5.776540e+09 > primal=-5.776540e+09
# [Invariant] MS scen None: dual=-5.849076e+09 > primal=-5.849076e+09
# [Invariant] MS scen None: dual=-5.747261e+09 > primal=-5.747261e+09
# [Bundle] MS scen None: infeasibleOrUnbounded. ms_val=nan.
# [Bundle] MS scen None: not optimal. Status=warning, Term=infeasibleOrUnbounded.
# [Invariant] MS scen None: dual=-5.835166e+09 > primal=-5.835166e+09
# [Invariant] MS scen None: dual=-5.856066e+09 > primal=-5.856066e+09
# [Iter 0] MIPGap restored to 0.1
# [Iter 0] #simplices = 6, #active = 6, bad-quality cut = 0, bad-shape cut = 0
# == [Iter 0] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.016493e+00      4.567702e+09     -2.716149e+10      5.082465e+00     [1.12e+01, 5.00e+10]    [-2.72e+10, 2.28e+10]     1
# T1            1.002945e+00      4.012097e+09     -2.993951e+10      5.014724e+00     [1.12e+01, 5.00e+10]    [-2.99e+10, 2.01e+10]     1
# T2            1.041760e+00      4.395550e+09     -2.802225e+10      5.208798e+00     [1.11e+01, 5.00e+10]    [-2.80e+10, 2.20e+10]     1
# T3            1.004007e+00      4.193778e+09     -2.903111e+10      5.020037e+00     [1.11e+01, 5.00e+10]    [-2.90e+10, 2.10e+10]     1
# T4            1.027262e+00      4.274322e+09     -2.862839e+10      5.136312e+00     [1.36e+01, 5.00e+10]    [-2.86e+10, 2.14e+10]     2
# T5            1.035581e+00               inf               inf      5.177904e+00     [1.36e+01, 5.00e+10]               [inf, inf]     2
#
# == [Iter 0] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
#   (none)
# [Iter 0] created=6 (cum=6), active=6, active+UB=2, ms_recomputed=6
# [Iter 0] EF-ipopt: ok=True, ef_obj=0.9841670257415724, true_obj=9.841670e-01, time=0.492s
# [Iter 0] EF-UB improved by ipopt: 9.841670e-01 (per-scen), K=(-9.99989152958837, -99.99979183386104, 0.814277765297143)
# [Iter 0] Pre-split gap: -9.388874e-02 (-1.908%)
# [Iter 0] Active simplex ratio = 1.000000
# [Iter 0] UB point (-9.99989152958837, -99.99979183386104, 0.814277765297143) is geometrically in simplices [1]
#   T1 verts=[3, 1, 4, 0]: λ=[0.000001, 0.504070, 0.000005, 0.495923], LB=5.014723969, c_s=[0.9960029127022256, 1.038030098197515, 0.9571540289698489, 1.0551989733060005, 0.9683379558464811]
#
# == [Iter 0] CS DUAL vs PRIMAL diagnostic (simplices containing UB point) ==
#   --- T1 ---
#     scen 0: status=optimal, dual=0.996002913, primal=0.996002913  ✓ dual ≤ primal (gap=1.110223e-16)
#              cs_primal_K=(-9.999216646683243, -99.99852406033013, 0.9388331317148486)
#              indep_Q(cs_K)=0.996002918  → dual ≤ indep_Q (consistent, diff=4.973934e-09)
#     scen 1: status=optimal, dual=1.038030098, primal=1.038030098  ✓ dual ≤ primal (gap=-4.440892e-16)
#              cs_primal_K=(-8.088273951123846, 0.0, -5.582080575550208e-09)
#              indep_Q(cs_K)=1.038030100  → dual ≤ indep_Q (consistent, diff=2.183044e-09)
#     scen 2: status=optimal, dual=0.957154029, primal=0.957154029  ✓ dual ≤ primal (gap=2.220446e-16)
#              cs_primal_K=(-10.0, -71.04038079399149, 2.221249662676794)
#              indep_Q(cs_K)=0.957154117  → dual ≤ indep_Q (consistent, diff=8.791048e-08)
#     scen 3: status=optimal, dual=1.055198973, primal=1.055198973  ✓ dual ≤ primal (gap=2.220446e-16)
#              cs_primal_K=(-9.233467561678685, -98.4408518452537, 0.32994040845543465)
#              indep_Q(cs_K)=1.055198979  → dual ≤ indep_Q (consistent, diff=5.506025e-09)
#     scen 4: status=optimal, dual=0.968337956, primal=0.968337956  ✓ dual ≤ primal (gap=0.000000e+00)
#              cs_primal_K=(-9.998518091599312, -99.9972050307925, 0.39376151703840556)
#              indep_Q(cs_K)=0.968337957  → dual ≤ indep_Q (consistent, diff=1.643293e-09)
#   sum(c_s_dual)=5.014723969, UB_total=24.604176169, UB_per_scen=4.920835234
#
#   == Per-scenario Q_s at K_EF = (-9.99989152958837, -99.99979183386104, 0.814277765297143) ==
#     scen 0: Q_s(K_EF)=0.996015235, c_s_dual=0.996002913  ✓ Q_s(K_EF) > c_s_dual (diff=1.232268e-05)
#     scen 1: Q_s(K_EF)=0.945126284, c_s_dual=1.038030098  ⚠ Q_s(K_EF) < c_s_dual → GUROBI CS DUAL IS WRONG
#     scen 2: Q_s(K_EF)=0.956484730, c_s_dual=0.957154029  ⚠ Q_s(K_EF) < c_s_dual → GUROBI CS DUAL IS WRONG
#     scen 3: Q_s(K_EF)=1.054727427, c_s_dual=1.055198973  ⚠ Q_s(K_EF) < c_s_dual → GUROBI CS DUAL IS WRONG
#     scen 4: Q_s(K_EF)=0.968481558, c_s_dual=0.968337956  ✓ Q_s(K_EF) > c_s_dual (diff=1.436021e-04)
#     SUM Q_s(K_EF)=4.920835234, sum(c_s)=5.014723969, diff=-9.388874e-02
#
# [Iter 0] LB = 5.014724 = UB(4.920835) + ms_b(-2.994e+10) from T1
# [Iter 0] Scene 0: Switched to c_s point. dist_ms_c=1.81e+01 < 1000.0, dist_c_verts=9.91e+01 > 1e-06
# [Iter 0] Scene 1: Switched to c_s point. dist_ms_c=1.02e+02 < 1000.0, dist_c_verts=1.41e+02 > 1e-06
# [Iter 0] Scene 2: Switched to c_s point. dist_ms_c=3.43e+01 < 1000.0, dist_c_verts=1.02e+02 > 1e-06
# [Iter 0] Scene 3: Switched to c_s point. dist_ms_c=2.06e+01 < 1000.0, dist_c_verts=9.97e+01 > 1e-06
# [Iter 0] Scene 4: Switched to c_s point. dist_ms_c=1.98e+01 < 1000.0, dist_c_verts=9.96e+01 > 1e-06
# Chosen node (-9.233467561678685, -98.4408518452537, 0.32994040845543465) with ms=-6.045e+09 (simp T1, scene 3, rank #1, source=c_s)
# [Iter 0] LB simplex = T1, next node simplex = T1, scene 3
# [Selected Simp Info] Iter 0 | Simplex T1 Vertices:
#   v0: (-10.0, 100.0, 100.0)
#   v1: (-10.0, -100.0, 100.0)
#   v2: (10.0, -100.0, -100.0)
#   v3: (-10.0, -100.0, -100.0)
#   -> New Point: (-9.233467561678685, -98.4408518452537, 0.32994040845543465)
# [Iter 0] candidate rank #1: T1, scene=3, ms=-6.045e+09
# == ms candidates (sorted by (ms, -dist)) ==
# rank   simp   scene           ms    mind(all)                             pt
# ----------------------------------------------------------------------------
#    1     T1       3  -6.0450e+09     9.97e+01    (-9.2335, -98.4409, 0.3299)
#    2     T1       2  -6.0269e+09     1.02e+02   (-10.0000, -71.0404, 2.2212)
#    3     T1       4  -6.0086e+09     9.96e+01    (-9.9985, -99.9972, 0.3938)
#    4     T1       1  -5.9925e+09     1.41e+02     (-8.0883, 0.0000, -0.0000)
#    5     T1       0  -5.8666e+09     9.91e+01    (-9.9992, -99.9985, 0.9388)
#
# [Iter 0] per_tet=6, active after q_cut=6, tri_is_None=False
# [Iter 0] bad-quality active simplices (q < 0): 0
# [Iter 0] evaluating Q for scenario 0
# [Iter 0] evaluating Q for scenario 1
# [Iter 0] evaluating Q for scenario 2
# [Iter 0] evaluating Q for scenario 3
# [Iter 0] evaluating Q for scenario 4
#
# [Iter 0] Next Point Details:
# Simplex   Scene   Type    As             ms             As+ms          Q              (Kp, Ki, Kd)
# --------------------------------------------------------------------------------------------------------------------
# T1        3       c_s     4.9385e+09     -6.0450e+09    -1.1065e+09    1.0552e+00     (-9.2335, -98.4409, 0.3299)
#
# [Iter 0] subdivision type = interior (code=1) on simplex T1
# [Iter 0] Elapsed: 111.194s
# [Invariant] MS scen None: dual=-5.901902e+09 > primal=-5.901902e+09
# [Invariant] MS scen None: dual=-5.664126e+09 > primal=-5.664126e+09
# [Invariant] MS scen None: dual=-5.762388e+09 > primal=-5.762388e+09
# [Invariant] MS scen None: dual=-5.508409e+09 > primal=-5.508409e+09
# ======================================================================
# [Iter 0] LB SPLIT DIAGNOSTIC
#   Selected (parent) simplex: (0, 1, 3, 4)
#   Parent LB: 1.002944794 (per-scen)
#   EF ef_obj(IPOPT): 0.196833405, true_obj(recalc): 0.984167047, used=min=0.196833405 (per-scen)
#   Simplex volume: 1.333333e+05
#   Children (4):
#     T5 (0, 1, 4, 8): LB = 0.984150141
#     T6 (0, 3, 4, 8): LB = 0.986564090
#     T7 (0, 1, 3, 8): LB = 1.000397133
#     T8 (1, 3, 4, 8): LB = 0.984266905
#   New global LB: 0.984150141 (from T5 (0, 1, 4, 8))
#   Location: INSIDE
#   Avg CS point Q-value: 0.987575289 (per-scen), point=(np.float64(-9.463895250217018), np.float64(-73.89539234607356), np.float64(0.7767569428606804))
#   Current UB: 0.984167047 (per-scen)
#   UB point: (-9.99989152958837, -99.99979183386104, 0.814277765297143)
#   UB source: EF_ipopt
#   UB simplex: (0, 1, 3, 4)
#   EF-IPOPT: ok=True, status=ok, term=optimal, time=0.492s, ef_obj=0.9841670257415724, true_obj(per-scen)=0.984167047
# ======================================================================
#
# ======================================================================
# [TIMING] === Iter 0 phase breakdown (total 245.00s) ===
#   1_vertex_UB                    :       0.00s  (  0.0%)
#   2_evaluate_all_tetra           :     109.23s  ( 44.6%)  ######################
#   3_active_filter_print          :       0.00s  (  0.0%)
#   4_LB_selection                 :       0.00s  (  0.0%)
#   5_EF_UB_solve                  :       1.48s  (  0.6%)
#   6_candidate_selection          :       0.00s  (  0.0%)
#   7_Q_eval_new_node              :       0.48s  (  0.2%)
#   8_mesh_subdivide               :       0.00s  (  0.0%)
#   9_end_of_iter_reeval           :     133.81s  ( 54.6%)  ###########################
#   TOTAL                          :     245.00s
#   #simplices=6, #scenarios=5, total_ms_pairs=30
#   fresh ms solves=30, cache hits=0
# ======================================================================
#
# [Iter 1] #simplices = 9, #active = 1, bad-quality cut = 0, bad-shape cut = 0
# == [Iter 1] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T5            9.841501e-01      4.109276e+09     -2.945362e+10      4.920751e+00     [4.92e+00, 5.00e+10]    [-2.95e+10, 2.05e+10]     1
#
# == [Iter 1] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.016493e+00      4.567702e+09     -2.716149e+10      5.082465e+00     [1.12e+01, 5.00e+10]    [-2.72e+10, 2.28e+10]     1
# T1            1.041760e+00      4.395550e+09     -2.802225e+10      5.208798e+00     [1.11e+01, 5.00e+10]    [-2.80e+10, 2.20e+10]     1
# T2            1.004007e+00      4.193778e+09     -2.903111e+10      5.020037e+00     [1.11e+01, 5.00e+10]    [-2.90e+10, 2.10e+10]     1
# T3            1.027262e+00      4.274322e+09     -2.862839e+10      5.136312e+00     [1.36e+01, 5.00e+10]    [-2.86e+10, 2.14e+10]     2
# T4            1.035581e+00               inf               inf      5.177904e+00     [1.36e+01, 5.00e+10]               [inf, inf]     2
# T6            9.865641e-01      1.385630e+00     -6.711390e+00      4.932820e+00     [4.92e+00, 1.36e+01]    [-1.79e+00, 6.93e+00]     0
# T7            1.000397e+00      4.005557e+09     -2.997221e+10      5.001986e+00     [4.92e+00, 5.00e+10]    [-3.00e+10, 2.00e+10]     1
# T8            9.842669e-01      4.319191e+09     -2.840404e+10      4.921335e+00     [4.92e+00, 5.00e+10]    [-2.84e+10, 2.16e+10]     1
#
# [Iter 1] created=9 (cum=19), active=1, active+UB=1, ms_recomputed=0
# [Iter 1] EF-ipopt: ok=True, ef_obj=0.9841670252034732, true_obj=9.841670e-01, time=0.502s
# [Iter 1] EF-UB improved by ipopt: 9.841670e-01 (per-scen), K=(-9.999868030729932, -99.99984336305558, 0.8142777531758495)
# [Iter 1] Pre-split gap: 8.452590e-05 (0.002%)
# [Iter 1] Active simplex ratio = 0.001299
# [Iter 1] UB point (-9.999868030729932, -99.99984336305558, 0.8142777531758495) is geometrically in simplices [5]
#   T5 verts=[8, 1, 4, 0]: λ=[0.000100, 0.504021, 0.000003, 0.495876], LB=4.920750705, c_s=[0.9960985083033715, 0.9455329335744131, 0.9562292881494647, 1.0545523557729262, 0.9683376195254861]
#
# == [Iter 1] CS DUAL vs PRIMAL diagnostic (simplices containing UB point) ==
#   --- T5 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 0.593226426321745)
#              indep_Q(cs_K)=0.996098520
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 0.07193484508115591)
#              indep_Q(cs_K)=0.945532934
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 1.0408548481985058)
#              indep_Q(cs_K)=0.956229288
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999024438505662, -99.99948567065238, 0.3476235438684009)
#              indep_Q(cs_K)=1.054552377
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 0.3939701326269869)
#              indep_Q(cs_K)=0.968337626
#   sum(c_s_dual)=0.000000000, UB_total=24.604176156, UB_per_scen=4.920835231
#
#   == Per-scenario Q_s at K_EF = (-9.999868030729932, -99.99984336305558, 0.8142777531758495) ==
#     scen 0: Q_s(K_EF)=0.996015235, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945126284, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.956484729, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054727425, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968481557, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.920835231, sum(c_s)=0.000000000, diff=4.920835e+00
#
# [Iter 1] LB = 4.920751 = UB(4.920835) + ms_b(-2.945e+10) from T5
# [Iter 1] Scene 0: Switched to c_s point. dist_ms_c=1.90e+01 < 1000.0, dist_c_verts=1.76e+00 > 1e-06
# [Iter 1] Scene 1: Switched to c_s point. dist_ms_c=1.80e+01 < 1000.0, dist_c_verts=1.76e+00 > 1e-06
# [Iter 1] Scene 2: Switched to c_s point. dist_ms_c=1.81e+01 < 1000.0, dist_c_verts=1.88e+00 > 1e-06
# [Iter 1] Scene 3: Switched to c_s point. dist_ms_c=2.00e+01 < 1000.0, dist_c_verts=1.74e+00 > 1e-06
# [Iter 1] Scene 4: Switched to c_s point. dist_ms_c=1.45e+01 < 1000.0, dist_c_verts=1.74e+00 > 1e-06
# Chosen node (-9.999024438505662, -99.99948567065238, 0.3476235438684009) with ms=-6.015e+09 (simp T5, scene 3, rank #1, source=c_s)
# [Iter 1] LB simplex = T5, next node simplex = T5, scene 3
# [Selected Simp Info] Iter 1 | Simplex T5 Vertices:
#   v0: (-9.233467561678685, -98.4408518452537, 0.32994040845543465)
#   v1: (-10.0, -100.0, 100.0)
#   v2: (10.0, -100.0, -100.0)
#   v3: (-10.0, -100.0, -100.0)
#   -> New Point: (-9.999024438505662, -99.99948567065238, 0.3476235438684009)
# [Iter 1] candidate rank #1: T5, scene=3, ms=-6.015e+09
# == ms candidates (sorted by (ms, -dist)) ==
# rank   simp   scene           ms    mind(all)                             pt
# ----------------------------------------------------------------------------
#    1     T5       3  -6.0147e+09     1.74e+00    (-9.9990, -99.9995, 0.3476)
#    2     T5       0  -5.9800e+09     1.76e+00  (-10.0000, -100.0000, 0.5932)
#    3     T5       1  -5.9019e+09     1.76e+00  (-10.0000, -100.0000, 0.0719)
#    4     T5       2  -5.8929e+09     1.88e+00  (-10.0000, -100.0000, 1.0409)
#    5     T5       4  -5.6641e+09     1.74e+00  (-10.0000, -100.0000, 0.3940)
#
# [Iter 1] per_tet=9, active after q_cut=1, tri_is_None=False
# [Iter 1] bad-quality active simplices (q < 0): 0
# [Iter 1] evaluating Q for scenario 0
# [Iter 1] evaluating Q for scenario 1
# [Iter 1] evaluating Q for scenario 2
# [Iter 1] evaluating Q for scenario 3
# [Iter 1] evaluating Q for scenario 4
#
# [Iter 1] Next Point Details:
# Simplex   Scene   Type    As             ms             As+ms          Q              (Kp, Ki, Kd)
# --------------------------------------------------------------------------------------------------------------------
# T5        3       c_s     5.0157e+09     -6.0147e+09    -9.9897e+08    1.0546e+00     (-9.9990, -99.9995, 0.3476)
#
# [Iter 1] subdivision type = interior (code=1) on simplex T5
# [Iter 1] Elapsed: 2.223s
# [Invariant] MS scen None: dual=-5.898543e+09 > primal=-5.898543e+09
# [Invariant] MS scen None: dual=-5.961202e+09 > primal=-5.961202e+09
# [Invariant] MS scen None: dual=-5.586644e+09 > primal=-5.586644e+09
# [Invariant] MS scen None: dual=-5.541664e+09 > primal=-5.541664e+09
# ======================================================================
# [Iter 1] LB SPLIT DIAGNOSTIC
#   Selected (parent) simplex: (0, 1, 4, 8)
#   Parent LB: 0.984150141 (per-scen)
#   EF ef_obj(IPOPT): 0.196833405, true_obj(recalc): 0.984167046, used=min=0.196833405 (per-scen)
#   Simplex volume: 1.039432e+03
#   Children (4):
#     T8 (0, 1, 4, 9): LB = 0.984124982
#     T9 (0, 4, 8, 9): LB = 0.984339100
#     T10 (0, 1, 8, 9): LB = 0.984116973
#     T11 (1, 4, 8, 9): LB = 0.984055121
#   New global LB: 0.984055121 (from T11 (1, 4, 8, 9))
#   Location: INSIDE
#   Avg CS point Q-value: 0.984250987 (per-scen), point=(np.float64(-9.999804887701133), np.float64(-99.99989713413046), np.float64(0.4895219592193589))
#   Current UB: 0.984167046 (per-scen)
#   UB point: (-9.999868030729932, -99.99984336305558, 0.8142777531758495)
#   UB source: EF_ipopt
#   UB simplex: (0, 1, 4, 8)
#   EF-IPOPT: ok=True, status=ok, term=optimal, time=0.502s, ef_obj=0.9841670252034732, true_obj(per-scen)=0.984167046
# ======================================================================
# [BaseBundle.eval_at] Infeasible/Error for K=(-5.698973141808191, -100.0, 18.53321547043472): status=warning, term=infeasibleOrUnbounded
#
# ======================================================================
# [TIMING] === Iter 1 phase breakdown (total 58.27s) ===
#   1_vertex_UB                    :       0.00s  (  0.0%)
#   2_evaluate_all_tetra           :       0.00s  (  0.0%)
#   3_active_filter_print          :       0.00s  (  0.0%)
#   4_LB_selection                 :       0.00s  (  0.0%)
#   5_EF_UB_solve                  :       1.73s  (  3.0%)  #
#   6_candidate_selection          :       0.00s  (  0.0%)
#   7_Q_eval_new_node              :       0.49s  (  0.8%)
#   8_mesh_subdivide               :       0.00s  (  0.0%)
#   9_end_of_iter_reeval           :      56.05s  ( 96.2%)  ################################################
#   TOTAL                          :      58.27s
#   #simplices=9, #scenarios=5, total_ms_pairs=45
#   fresh ms solves=0, cache hits=45
# ======================================================================
#
# [Iter 2] #simplices = 12, #active = 3, bad-quality cut = 0, bad-shape cut = 0
# == [Iter 2] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T8            9.841250e-01      4.073339e+09     -2.963330e+10      4.920625e+00     [4.92e+00, 5.00e+10]    [-2.96e+10, 2.04e+10]     1
# T10           9.841170e-01      4.034003e+09     -2.982999e+10      4.920585e+00     [4.92e+00, 5.00e+10]    [-2.98e+10, 2.02e+10]     1
# T11           9.840551e-01      4.407186e+09     -2.796407e+10      4.920276e+00     [4.92e+00, 5.00e+10]    [-2.80e+10, 2.20e+10]     1
#
# == [Iter 2] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.016493e+00      4.567702e+09     -2.716149e+10      5.082465e+00     [1.12e+01, 5.00e+10]    [-2.72e+10, 2.28e+10]     1
# T1            1.041760e+00      4.395550e+09     -2.802225e+10      5.208798e+00     [1.11e+01, 5.00e+10]    [-2.80e+10, 2.20e+10]     1
# T2            1.004007e+00      4.193778e+09     -2.903111e+10      5.020037e+00     [1.11e+01, 5.00e+10]    [-2.90e+10, 2.10e+10]     1
# T3            1.027262e+00      4.274322e+09     -2.862839e+10      5.136312e+00     [1.36e+01, 5.00e+10]    [-2.86e+10, 2.14e+10]     2
# T4            1.035581e+00               inf               inf      5.177904e+00     [1.36e+01, 5.00e+10]               [inf, inf]     2
# T5            9.865641e-01      1.385630e+00     -6.711390e+00      4.932820e+00     [4.92e+00, 1.36e+01]    [-1.79e+00, 6.93e+00]     0
# T6            1.000397e+00      4.005557e+09     -2.997221e+10      5.001986e+00     [4.92e+00, 5.00e+10]    [-3.00e+10, 2.00e+10]     1
# T7            9.842669e-01      4.319191e+09     -2.840404e+10      4.921335e+00     [4.92e+00, 5.00e+10]    [-2.84e+10, 2.16e+10]     1
# T9            9.843391e-01      2.510715e+00     -1.085964e+00      4.921695e+00     [4.92e+00, 1.36e+01]     [3.84e+00, 1.26e+01]     0
#
# [Iter 2] created=12 (cum=35), active=3, active+UB=3, ms_recomputed=0
# [Iter 2] EF-ipopt: ok=True, ef_obj=0.9841671966447082, true_obj=9.841672e-01, time=0.668s
# [Iter 2] Pre-split gap: 5.596272e-04 (0.011%)
# [Iter 2] Active simplex ratio = 0.000648
# [Iter 2] UB point (-9.999024438505662, -99.99948567065238, 0.3476235438684009) is geometrically in simplices [8, 9, 10, 11]
#   T8 verts=[9, 1, 4, 0]: λ=[1.000000, 0.000000, 0.000000, -0.000000], LB=4.920624910, c_s=[0.9960397795711942, 0.9454047890601088, 0.9562855646180515, 1.054552287644563, 0.9683424890794531]
#   T9 verts=[8, 9, 4, 0]: λ=[0.000000, 1.000000, -0.000000, 0.000000], LB=4.921695500, c_s=[0.9962799749248459, 0.9452825839449608, 0.9572411321042049, 1.0545523593585613, 0.968339449454651]
#   T10 verts=[8, 1, 9, 0]: λ=[0.000000, 0.000000, 1.000000, -0.000000], LB=4.920584867, c_s=[0.9960350095644578, 0.9453346628205078, 0.9563232400081809, 1.0545523563538273, 0.9683395978579611]
#   T11 verts=[8, 1, 4, 9]: λ=[0.000000, 0.000000, 0.000000, 1.000000], LB=4.920275604, c_s=[0.9961043080508033, 0.9451488500155165, 0.9561307849832763, 1.0545523593806891, 0.9683393015684187]
#
# == [Iter 2] CS DUAL vs PRIMAL diagnostic (simplices containing UB point) ==
#   --- T8 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999028133785826, -99.99948761885456, 0.7250917528733738)
#              indep_Q(cs_K)=0.996040015
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-2.0042611651436637, -99.99990234208214, 1.1230401211739602)
#              indep_Q(cs_K)=0.945404861
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.929724312898895, -99.99949924914802, 2.285226392626316)
#              indep_Q(cs_K)=0.956285567
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.99901145451161, -99.99984484415484, 0.34762582010310356)
#              indep_Q(cs_K)=1.054552309
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.99902474195845, -99.99948583063683, 0.31640996444928354)
#              indep_Q(cs_K)=0.968342504
#   sum(c_s_dual)=0.000000000, UB_total=24.604176156, UB_per_scen=4.920835231
#
#   == Per-scenario Q_s at K_EF = (-9.999024438505662, -99.99948567065238, 0.3476235438684009) ==
#     scen 0: Q_s(K_EF)=0.996279978, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945282584, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.957241133, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054552377, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968339480, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.921695553, sum(c_s)=0.000000000, diff=4.921696e+00
#   --- T9 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999024438505662, -99.99948567065238, 0.34762354386839434)
#              indep_Q(cs_K)=0.996279978
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999024438505662, -99.99948567065238, 0.34762354386839434)
#              indep_Q(cs_K)=0.945282584
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999024438505662, -99.99948567065238, 0.3476235438684009)
#              indep_Q(cs_K)=0.957241133
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999020568929364, -99.99948286101699, 0.3462666779229522)
#              indep_Q(cs_K)=1.054552486
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999024438505662, -99.99948567065238, 0.34762354386839434)
#              indep_Q(cs_K)=0.968339480
#   sum(c_s_dual)=0.000000000, UB_total=24.604176156, UB_per_scen=4.920835231
#
#   == Per-scenario Q_s at K_EF = (-9.999024438505662, -99.99948567065238, 0.3476235438684009) ==
#     scen 0: Q_s(K_EF)=0.996279978, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945282584, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.957241133, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054552377, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968339480, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.921695553, sum(c_s)=0.000000000, diff=4.921696e+00
#   --- T10 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.960916436087814, -99.92188900829619, 1.0752045788033524)
#              indep_Q(cs_K)=0.996035012
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.547714550529832, -99.08064185234777, 0.3063236172857691)
#              indep_Q(cs_K)=0.945334664
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.47028712401834, -98.92297533538397, 2.28345416468709)
#              indep_Q(cs_K)=0.956323242
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999024093468384, -99.9994836182758, 0.3475998810479236)
#              indep_Q(cs_K)=1.054552378
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999025360137718, -99.99948615654938, 0.4417670961795307)
#              indep_Q(cs_K)=0.968339604
#   sum(c_s_dual)=0.000000000, UB_total=24.604176156, UB_per_scen=4.920835231
#
#   == Per-scenario Q_s at K_EF = (-9.999024438505662, -99.99948567065238, 0.3476235438684009) ==
#     scen 0: Q_s(K_EF)=0.996279978, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945282584, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.957241133, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054552377, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968339480, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.921695553, sum(c_s)=0.000000000, diff=4.921696e+00
#   --- T11 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999026745570662, -99.99948688696855, 0.5832873243817545)
#              indep_Q(cs_K)=0.996104315
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999031141279087, -99.999490329713, 0.9561172967403674)
#              indep_Q(cs_K)=0.945148852
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-4.56657907155549, -99.99977205311272, 1.5049327641836125)
#              indep_Q(cs_K)=0.956130786
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999020457157568, -99.99948286651271, 0.34897061295835036)
#              indep_Q(cs_K)=1.054552383
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999025321124499, -99.99948613598109, 0.4377819450309552)
#              indep_Q(cs_K)=0.968339309
#   sum(c_s_dual)=0.000000000, UB_total=24.604176156, UB_per_scen=4.920835231
#
#   == Per-scenario Q_s at K_EF = (-9.999024438505662, -99.99948567065238, 0.3476235438684009) ==
#     scen 0: Q_s(K_EF)=0.996279978, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945282584, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.957241133, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054552377, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968339480, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.921695553, sum(c_s)=0.000000000, diff=4.921696e+00
#
# [Iter 2] LB = 4.920276 = UB(4.920835) + ms_b(-2.796e+10) from T11
# [Iter 2] Scene 0: Switched to c_s point. dist_ms_c=1.70e+01 < 1000.0, dist_c_verts=2.36e-01 > 1e-06
# [Iter 2] Scene 1: Switched to c_s point. dist_ms_c=1.71e+01 < 1000.0, dist_c_verts=6.08e-01 > 1e-06
# [Iter 2] Scene 2: Switched to c_s point. dist_ms_c=1.43e+01 < 1000.0, dist_c_verts=5.06e+00 > 1e-06
# [Iter 2] Scene 3: Switched to c_s point. dist_ms_c=1.68e+01 < 1000.0, dist_c_verts=1.35e-03 > 1e-06
# [Iter 2] Scene 4: Switched to c_s point. dist_ms_c=1.61e+01 < 1000.0, dist_c_verts=9.02e-02 > 1e-06
# Chosen node (-9.999030395438158, -99.99948881122856, 0.9561166866952173) with ms=-5.670e+09 (simp T11, scene 1, rank #1, source=c_s)
# [Iter 2] LB simplex = T11, next node simplex = T11, scene 1
# [Selected Simp Info] Iter 2 | Simplex T11 Vertices:
#   v0: (-9.233467561678685, -98.4408518452537, 0.32994040845543465)
#   v1: (-10.0, -100.0, 100.0)
#   v2: (10.0, -100.0, -100.0)
#   v3: (-9.999024438505662, -99.99948567065238, 0.3476235438684009)
#   -> New Point: (-9.999030395438158, -99.99948881122856, 0.9561166866952173)
# [Iter 2] candidate rank #1: T11, scene=1, ms=-5.670e+09
# == ms candidates (sorted by (ms, -dist)) ==
# rank   simp   scene           ms    mind(all)                             pt
# ----------------------------------------------------------------------------
#    1    T11       1  -5.6699e+09     6.08e-01    (-9.9990, -99.9995, 0.9561)
#    2    T11       0  -5.5901e+09     2.36e-01    (-9.9990, -99.9995, 0.5833)
#    3    T11       2  -5.5866e+09     5.06e+00    (-4.5666, -99.9998, 1.5049)
#    4    T11       3  -5.5759e+09     1.35e-03    (-9.9990, -99.9995, 0.3490)
#    5    T11       4  -5.5417e+09     9.02e-02    (-9.9990, -99.9995, 0.4378)
#
# [Iter 2] per_tet=12, active after q_cut=3, tri_is_None=False
# [Iter 2] bad-quality active simplices (q < 0): 0
# [Iter 2] evaluating Q for scenario 0
# [Iter 2] evaluating Q for scenario 1
# [Iter 2] evaluating Q for scenario 2
# [Iter 2] evaluating Q for scenario 3
# [Iter 2] evaluating Q for scenario 4
#
# [Iter 2] Next Point Details:
# Simplex   Scene   Type    As             ms             As+ms          Q              (Kp, Ki, Kd)
# --------------------------------------------------------------------------------------------------------------------
# T11       1       c_s     6.1062e+07     -5.6699e+09    -5.6088e+09    9.4515e-01     (-9.9990, -99.9995, 0.9561)
#
# [Iter 2] subdivision type = edge (code=2) on simplex T11
#            edge local verts = (1, 9)
# [Iter 2] Elapsed: 3.779s
# [Invariant] MS scen None: dual=-5.588694e+09 > primal=-5.588694e+09
# [Invariant] MS scen None: dual=-5.540707e+09 > primal=-5.540707e+09
# ======================================================================
# [Iter 2] LB SPLIT DIAGNOSTIC
#   Selected (parent) simplex: (1, 4, 8, 9)
#   Parent LB: 0.984055121 (per-scen)
#   EF ef_obj(IPOPT): 0.196833439, true_obj(recalc): 0.984167218, used=min=0.196833439 (per-scen)
#   Simplex volume: 5.177010e+02
#   Children (2):
#     T11 (4, 8, 9, 10): LB = 0.984068433
#     T12 (1, 4, 8, 10): LB = 0.984078856
#   New global LB: 0.984068433 (from T11 (4, 8, 9, 10))
#   Location: INSIDE
#   Avg CS point Q-value: 0.984349369 (per-scen), point=(np.float64(-8.912536547337462), np.float64(-99.99954365445763), np.float64(0.7662179886590079))
#   Current UB: 0.984167046 (per-scen)
#   UB point: (-9.999024438505662, -99.99948567065238, 0.3476235438684009)
#   UB source: unknown
#   UB simplex: None
#   EF-IPOPT: ok=True, status=ok, term=optimal, time=0.668s, ef_obj=0.9841671966447082, true_obj(per-scen)=0.984167218
# ======================================================================
#
# ======================================================================
# [TIMING] === Iter 2 phase breakdown (total 36.34s) ===
#   1_vertex_UB                    :       0.00s  (  0.0%)
#   2_evaluate_all_tetra           :       0.00s  (  0.0%)
#   3_active_filter_print          :       0.00s  (  0.0%)
#   4_LB_selection                 :       0.00s  (  0.0%)
#   5_EF_UB_solve                  :       3.56s  (  9.8%)  ####
#   6_candidate_selection          :       0.00s  (  0.0%)
#   7_Q_eval_new_node              :       0.21s  (  0.6%)
#   8_mesh_subdivide               :       0.00s  (  0.0%)
#   9_end_of_iter_reeval           :      32.56s  ( 89.6%)  ############################################
#   TOTAL                          :      36.34s
#   #simplices=12, #scenarios=5, total_ms_pairs=60
#   fresh ms solves=0, cache hits=60
# ======================================================================
#
# [Iter 3] #simplices = 13, #active = 4, bad-quality cut = 0, bad-shape cut = 0
# == [Iter 3] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T8            9.841250e-01      4.073339e+09     -2.963330e+10      4.920625e+00     [4.92e+00, 5.00e+10]    [-2.96e+10, 2.04e+10]     1
# T10           9.841170e-01      4.034003e+09     -2.982999e+10      4.920585e+00     [4.92e+00, 5.00e+10]    [-2.98e+10, 2.02e+10]     1
# T11           9.840684e-01      2.505544e+00     -1.111818e+00      4.920342e+00     [4.92e+00, 1.36e+01]     [3.81e+00, 1.25e+01]     0
# T12           9.840789e-01      4.385320e+09     -2.807340e+10      4.920394e+00     [4.92e+00, 5.00e+10]    [-2.81e+10, 2.19e+10]     1
#
# == [Iter 3] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.016493e+00      4.567702e+09     -2.716149e+10      5.082465e+00     [1.12e+01, 5.00e+10]    [-2.72e+10, 2.28e+10]     1
# T1            1.041760e+00      4.395550e+09     -2.802225e+10      5.208798e+00     [1.11e+01, 5.00e+10]    [-2.80e+10, 2.20e+10]     1
# T2            1.004007e+00      4.193778e+09     -2.903111e+10      5.020037e+00     [1.11e+01, 5.00e+10]    [-2.90e+10, 2.10e+10]     1
# T3            1.027262e+00      4.274322e+09     -2.862839e+10      5.136312e+00     [1.36e+01, 5.00e+10]    [-2.86e+10, 2.14e+10]     2
# T4            1.035581e+00               inf               inf      5.177904e+00     [1.36e+01, 5.00e+10]               [inf, inf]     2
# T5            9.865641e-01      1.385630e+00     -6.711390e+00      4.932820e+00     [4.92e+00, 1.36e+01]    [-1.79e+00, 6.93e+00]     0
# T6            1.000397e+00      4.005557e+09     -2.997221e+10      5.001986e+00     [4.92e+00, 5.00e+10]    [-3.00e+10, 2.00e+10]     1
# T7            9.842669e-01      4.319191e+09     -2.840404e+10      4.921335e+00     [4.92e+00, 5.00e+10]    [-2.84e+10, 2.16e+10]     1
# T9            9.843391e-01      2.510715e+00     -1.085964e+00      4.921695e+00     [4.92e+00, 1.36e+01]     [3.84e+00, 1.26e+01]     0
#
# [Iter 3] created=13 (cum=50), active=4, active+UB=2, ms_recomputed=0
# [Iter 3] EF-ipopt: ok=True, ef_obj=0.9841671964588048, true_obj=9.841672e-01, time=0.477s
# [Iter 3] Pre-split gap: 4.930669e-04 (0.010%)
# [Iter 3] Active simplex ratio = 0.000648
# [Iter 3] UB point (-9.999030395438158, -99.99948881122856, 0.9561166866952173) is geometrically in simplices [8, 10, 11, 12]
#   T8 verts=[9, 1, 4, 0]: λ=[0.993894, 0.006106, -0.000000, -0.000000], LB=4.920624910, c_s=[0.9960397795711942, 0.9454047890601088, 0.9562855646180515, 1.054552287644563, 0.9683424890794531]
#   T10 verts=[8, 1, 9, 0]: λ=[0.000000, 0.006106, 0.993894, 0.000000], LB=4.920584867, c_s=[0.9960350095644578, 0.9453346628205078, 0.9563232400081809, 1.0545523563538273, 0.9683395978579611]
#   T11 verts=[10, 9, 8, 4]: λ=[1.000000, -0.000000, 0.000000, 0.000000], LB=4.920342164, c_s=[0.9960054718949284, 0.9451258615820799, 0.9563207172045871, 1.0545523592582235, 0.9683377543649725]
#   T12 verts=[1, 10, 8, 4]: λ=[0.000000, 1.000000, -0.000000, -0.000000], LB=4.920394281, c_s=[0.9961121020304616, 0.9452306870193738, 0.9561022733012126, 1.0545985483190843, 0.9683506701741358]
#
# == [Iter 3] CS DUAL vs PRIMAL diagnostic (simplices containing UB point) ==
#   --- T8 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999028133785826, -99.99948761885456, 0.7250917528733738)
#              indep_Q(cs_K)=0.996040015
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-2.0042611651436637, -99.99990234208214, 1.1230401211739602)
#              indep_Q(cs_K)=0.945404861
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.929724312898895, -99.99949924914802, 2.285226392626316)
#              indep_Q(cs_K)=0.956285567
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.99901145451161, -99.99984484415484, 0.34762582010310356)
#              indep_Q(cs_K)=1.054552309
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.99902474195845, -99.99948583063683, 0.31640996444928354)
#              indep_Q(cs_K)=0.968342504
#   sum(c_s_dual)=0.000000000, UB_total=24.604176156, UB_per_scen=4.920835231
#
#   == Per-scenario Q_s at K_EF = (-9.999030395438158, -99.99948881122856, 0.9561166866952173) ==
#     scen 0: Q_s(K_EF)=0.996003098, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945148852, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.956315980, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054852872, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968597244, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.920918046, sum(c_s)=0.000000000, diff=4.920918e+00
#   --- T10 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.960916436087814, -99.92188900829619, 1.0752045788033524)
#              indep_Q(cs_K)=0.996035012
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.547714550529832, -99.08064185234777, 0.3063236172857691)
#              indep_Q(cs_K)=0.945334664
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.47028712401834, -98.92297533538397, 2.28345416468709)
#              indep_Q(cs_K)=0.956323242
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999024093468384, -99.9994836182758, 0.3475998810479236)
#              indep_Q(cs_K)=1.054552378
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999025360137718, -99.99948615654938, 0.4417670961795307)
#              indep_Q(cs_K)=0.968339604
#   sum(c_s_dual)=0.000000000, UB_total=24.604176156, UB_per_scen=4.920835231
#
#   == Per-scenario Q_s at K_EF = (-9.999030395438158, -99.99948881122856, 0.9561166866952173) ==
#     scen 0: Q_s(K_EF)=0.996003098, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945148852, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.956315980, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054852872, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968597244, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.920918046, sum(c_s)=0.000000000, diff=4.920918e+00
#   --- T11 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999029670470545, -99.99948842901573, 0.8820621591852025)
#              indep_Q(cs_K)=0.996005477
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999028851571694, -99.99948799728107, 0.7984126741700395)
#              indep_Q(cs_K)=0.945125862
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.994232259682748, -99.9897201138302, 0.9521838621554867)
#              indep_Q(cs_K)=0.956320721
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.99901966578278, -99.99948282974167, 0.3487415935963156)
#              indep_Q(cs_K)=1.054552387
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.99902488472483, -99.99948590590522, 0.39320426922145557)
#              indep_Q(cs_K)=0.968337766
#   sum(c_s_dual)=0.000000000, UB_total=24.604176156, UB_per_scen=4.920835231
#
#   == Per-scenario Q_s at K_EF = (-9.999030395438158, -99.99948881122856, 0.9561166866952173) ==
#     scen 0: Q_s(K_EF)=0.996003098, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945148852, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.956315980, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054852872, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968597244, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.920918046, sum(c_s)=0.000000000, diff=4.920918e+00
#   --- T12 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.927763072910604, -99.99949063286493, 0.5963565652726941)
#              indep_Q(cs_K)=0.996112124
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999032224154073, -99.99948977535257, 1.1429177113814972)
#              indep_Q(cs_K)=0.945231124
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.62734315205584, -99.24274878571244, 1.232348326380813)
#              indep_Q(cs_K)=0.956102274
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.888076747907203, -99.99949058381966, 0.39604381684304873)
#              indep_Q(cs_K)=1.054598550
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.884831827233011, -99.99949173022138, 0.37963653994756946)
#              indep_Q(cs_K)=0.968350681
#   sum(c_s_dual)=0.000000000, UB_total=24.604176156, UB_per_scen=4.920835231
#
#   == Per-scenario Q_s at K_EF = (-9.999030395438158, -99.99948881122856, 0.9561166866952173) ==
#     scen 0: Q_s(K_EF)=0.996003098, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945148852, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.956315980, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054852872, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968597244, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.920918046, sum(c_s)=0.000000000, diff=4.920918e+00
#
# [Iter 3] LB = 4.920342 = UB(4.920835) + ms_b(-1.112e+00) from T11
# [Iter 3] Scene 0: Switched to c_s point. dist_ms_c=4.46e+01 < 1000.0, dist_c_verts=7.41e-02 > 1e-06
# [Iter 3] Scene 1: Switched to c_s point. dist_ms_c=4.44e+01 < 1000.0, dist_c_verts=1.58e-01 > 1e-06
# [Iter 3] Scene 2: Switched to c_s point. dist_ms_c=4.59e+01 < 1000.0, dist_c_verts=1.16e-02 > 1e-06
# [Iter 3] Scene 3: Switched to c_s point. dist_ms_c=4.20e+01 < 1000.0, dist_c_verts=1.12e-03 > 1e-06
# [Iter 3] Scene 4: Switched to c_s point. dist_ms_c=4.33e+01 < 1000.0, dist_c_verts=4.56e-02 > 1e-06
# Chosen node (-9.99902488472483, -99.99948590590522, 0.393204269221456) with ms=-2.320e-01 (simp T11, scene 4, rank #1, source=c_s)
# [Iter 3] LB simplex = T11, next node simplex = T11, scene 4
# [Selected Simp Info] Iter 3 | Simplex T11 Vertices:
#   v0: (-9.999030395438158, -99.99948881122856, 0.9561166866952173)
#   v1: (-9.999024438505662, -99.99948567065238, 0.3476235438684009)
#   v2: (-9.233467561678685, -98.4408518452537, 0.32994040845543465)
#   v3: (10.0, -100.0, -100.0)
#   -> New Point: (-9.99902488472483, -99.99948590590522, 0.393204269221456)
# [Iter 3] candidate rank #1: T11, scene=4, ms=-2.320e-01
# == ms candidates (sorted by (ms, -dist)) ==
# rank   simp   scene           ms    mind(all)                             pt
# ----------------------------------------------------------------------------
#    1    T11       4  -2.3199e-01     4.56e-02    (-9.9990, -99.9995, 0.3932)
#    2    T11       1  -2.2983e-01     1.58e-01    (-9.9990, -99.9995, 0.7984)
#    3    T11       0  -2.2843e-01     7.41e-02    (-9.9990, -99.9995, 0.8821)
#    4    T11       2  -2.1595e-01     1.16e-02    (-9.9942, -99.9897, 0.9522)
#    5    T11       3  -2.0562e-01     1.12e-03    (-9.9990, -99.9995, 0.3487)
#
# [Iter 3] per_tet=13, active after q_cut=4, tri_is_None=False
# [Iter 3] bad-quality active simplices (q < 0): 0
# [Iter 3] evaluating Q for scenario 0
# [Iter 3] evaluating Q for scenario 1
# [Iter 3] evaluating Q for scenario 2
# [Iter 3] evaluating Q for scenario 3
# [Iter 3] evaluating Q for scenario 4
#
# [Iter 3] Next Point Details:
# Simplex   Scene   Type    As             ms             As+ms          Q              (Kp, Ki, Kd)
# ...
#              indep_Q(cs_K)=0.968339604
#   sum(c_s_dual)=0.000000000, UB_total=24.604176156, UB_per_scen=4.920835231
#
#   == Per-scenario Q_s at K_EF = (-9.999030395438158, -99.99948881122856, 0.9561166866952173) ==
#     scen 0: Q_s(K_EF)=0.996003098, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945148852, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.956315980, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054852872, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968597244, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.920918046, sum(c_s)=0.000000000, diff=4.920918e+00
#   --- T11 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.927763072910604, -99.99949063286493, 0.5963565652726941)
#              indep_Q(cs_K)=0.996112124
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999032224154073, -99.99948977535257, 1.1429177113814972)
#              indep_Q(cs_K)=0.945231124
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.62734315205584, -99.24274878571244, 1.232348326380813)
#              indep_Q(cs_K)=0.956102274
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.888076747907203, -99.99949058381966, 0.39604381684304873)
#              indep_Q(cs_K)=1.054598550
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.884831827233011, -99.99949173022138, 0.37963653994756946)
#              indep_Q(cs_K)=0.968350681
#   sum(c_s_dual)=0.000000000, UB_total=24.604176156, UB_per_scen=4.920835231
#
#   == Per-scenario Q_s at K_EF = (-9.999030395438158, -99.99948881122856, 0.9561166866952173) ==
#     scen 0: Q_s(K_EF)=0.996003098, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945148852, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.956315980, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054852872, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968597244, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.920918046, sum(c_s)=0.000000000, diff=4.920918e+00
#   --- T22 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999007910325888, -99.99948867636317, 0.9297639737430663)
#              indep_Q(cs_K)=0.996002916
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999027217216677, -99.99948794032464, 0.7873619838160445)
#              indep_Q(cs_K)=0.945125802
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999030395438158, -99.99948881122856, 0.9561166866952173)
#              indep_Q(cs_K)=0.956315980
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.998925756375451, -99.99948157377017, 0.39474090258452493)
#              indep_Q(cs_K)=1.054554149
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999019831029063, -99.99948591634369, 0.3951760070793032)
#              indep_Q(cs_K)=0.968337768
#   sum(c_s_dual)=0.000000000, UB_total=24.604176156, UB_per_scen=4.920835231
#
#   == Per-scenario Q_s at K_EF = (-9.999030395438158, -99.99948881122856, 0.9561166866952173) ==
#     scen 0: Q_s(K_EF)=0.996003098, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945148852, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.956315980, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054852872, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968597244, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.920918046, sum(c_s)=0.000000000, diff=4.920918e+00
#   --- T39 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.998959958012955, -99.99947061551427, 0.9298221255832768)
#              indep_Q(cs_K)=0.996002927
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.998886421710958, -99.99948794767614, 0.7873784451433832)
#              indep_Q(cs_K)=0.945125804
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999030395438158, -99.99948881122856, 0.9561166866952173)
#              indep_Q(cs_K)=0.956315980
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.998537491637478, -99.9994785101489, 0.39287790734372624)
#              indep_Q(cs_K)=1.054554168
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.998549842392366, -99.99948592887807, 0.39290506818466264)
#              indep_Q(cs_K)=0.968337818
#   sum(c_s_dual)=0.000000000, UB_total=24.604176156, UB_per_scen=4.920835231
#
#   == Per-scenario Q_s at K_EF = (-9.999030395438158, -99.99948881122856, 0.9561166866952173) ==
#     scen 0: Q_s(K_EF)=0.996003098, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945148852, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.956315980, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054852872, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968597244, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.920918046, sum(c_s)=0.000000000, diff=4.920918e+00
#   --- T40 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999016057521363, -99.9994965503736, 0.9393125453112117)
#              indep_Q(cs_K)=0.996002851
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.958901481082533, -99.99948983517193, 0.7535439002947839)
#              indep_Q(cs_K)=0.945127530
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999030395438158, -99.99948881122856, 0.9561166866952178)
#              indep_Q(cs_K)=0.956315980
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.998519853626817, -99.99948206609488, 0.3927831871137525)
#              indep_Q(cs_K)=1.054554167
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.998533651910732, -99.99948592930501, 0.3928260134389012)
#              indep_Q(cs_K)=0.968337821
#   sum(c_s_dual)=0.000000000, UB_total=24.604176156, UB_per_scen=4.920835231
#
#   == Per-scenario Q_s at K_EF = (-9.999030395438158, -99.99948881122856, 0.9561166866952173) ==
#     scen 0: Q_s(K_EF)=0.996003098, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945148852, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.956315980, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054852872, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968597244, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.920918046, sum(c_s)=0.000000000, diff=4.920918e+00
#   --- T45 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.998911155065915, -99.99947792549753, 0.9399937439660784)
#              indep_Q(cs_K)=0.996002877
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.998582810447527, -99.99937318904918, 0.7890314922097287)
#              indep_Q(cs_K)=0.945125806
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999030395438158, -99.99948881122856, 0.9561166866952173)
#              indep_Q(cs_K)=0.956315980
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.997511383593196, -99.9990964132177, 0.38906373618617324)
#              indep_Q(cs_K)=1.054554395
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.997537614340047, -99.99910318926288, 0.3988557746388172)
#              indep_Q(cs_K)=0.968337974
#   sum(c_s_dual)=0.000000000, UB_total=24.604176156, UB_per_scen=4.920835231
#
#   == Per-scenario Q_s at K_EF = (-9.999030395438158, -99.99948881122856, 0.9561166866952173) ==
#     scen 0: Q_s(K_EF)=0.996003098, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945148852, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.956315980, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054852872, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968597244, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.920918046, sum(c_s)=0.000000000, diff=4.920918e+00
#
# [Iter 31] LB = 4.920337 = UB(4.920835) + ms_b(-1.239e-01) from T45
# [Iter 31] Scene 0: Switched to c_s point. dist_ms_c=7.56e+00 < 1000.0, dist_c_verts=1.61e-02 > 1e-06
# [Iter 31] Scene 1: Switched to c_s point. dist_ms_c=7.34e+00 < 1000.0, dist_c_verts=1.67e-01 > 1e-06
# [Iter 31] Scene 2: Kept ms point (c_s too close to verts). dist_ms_c=7.53e+00 < 1000.0 BUT dist_c_verts=0.00e+00 <= 1e-06
# [Iter 31] Scene 3: Switched to c_s point. dist_ms_c=6.98e+00 < 1000.0, dist_c_verts=2.18e-05 > 1e-06
# [Iter 31] Scene 4: Switched to c_s point. dist_ms_c=6.95e+00 < 1000.0, dist_c_verts=9.81e-03 > 1e-06
# Chosen node (-9.997511383593194, -99.9990964132177, 0.3890637361861576) with ms=-2.649e-02 (simp T45, scene 3, rank #1, source=c_s)
# [Iter 31] LB simplex = T45, next node simplex = T45, scene 3
# [Selected Simp Info] Iter 31 | Simplex T45 Vertices:
#   v0: (-9.997511325156678, -99.99909639812212, 0.3890419216099985)
#   v1: (-9.999030395438158, -99.99948881122856, 0.9561166866952173)
#   v2: (-6.605175375706384, -99.99957541001604, -16.176234861454045)
#   v3: (-9.233467561678685, -98.4408518452537, 0.32994040845543465)
#   -> New Point: (-9.997511383593194, -99.9990964132177, 0.3890637361861576)
# [Iter 31] candidate rank #1: T45, scene=3, ms=-2.649e-02
# == ms candidates (sorted by (ms, -dist)) ==
# rank   simp   scene           ms    mind(all)                             pt
# ----------------------------------------------------------------------------
#    1    T45       3  -2.6488e-02     2.18e-05    (-9.9975, -99.9991, 0.3891)
#    2    T45       4  -2.5235e-02     3.96e-03    (-9.9975, -99.9991, 0.3989)
#    3    T45       0  -2.5192e-02     1.61e-02    (-9.9989, -99.9995, 0.9400)
#    4    T45       1  -2.4640e-02     1.67e-01    (-9.9986, -99.9994, 0.7890)
#    5    T45       2  -2.2339e-02     6.93e+00   (-8.5363, -99.9995, -6.4278)
#
# [Iter 31] per_tet=25, active after q_cut=7, tri_is_None=False
# [Iter 31] bad-quality active simplices (q < 0): 0
# [Iter 31] evaluating Q for scenario 0
# [Iter 31] evaluating Q for scenario 1
# [Iter 31] evaluating Q for scenario 2
# [Iter 31] evaluating Q for scenario 3
# [Iter 31] evaluating Q for scenario 4
#
# [Iter 31] Next Point Details:
# Simplex   Scene   Type    As             ms             As+ms          Q              (Kp, Ki, Kd)
# --------------------------------------------------------------------------------------------------------------------
# T45       3       c_s     1.0546e+00     -2.6488e-02    1.0281e+00     1.0546e+00     (-9.9975, -99.9991, 0.3891)
#
# [Iter 31] subdivision type = edge (code=2) on simplex T45
#            edge local verts = (38, 10)
# [Iter 31] Elapsed: 3.835s
# ======================================================================
# [Iter 31] LB SPLIT DIAGNOSTIC
#   Selected (parent) simplex: (8, 10, 20, 38)
#   Parent LB: 0.984067401 (per-scen)
#   EF ef_obj(IPOPT): 0.196833453, true_obj(recalc): 0.984167286, used=min=0.196833453 (per-scen)
#   Simplex volume: 4.939153e-01
#   Children (2):
#     T46 (8, 10, 20, 39): LB = 0.984067420
#   New global LB: 0.984067420 (from T46 (8, 10, 20, 39))
#   Location: INSIDE
#   Avg CS point Q-value: 0.984178852 (per-scen), point=(np.float64(-9.998314671776969), np.float64(-99.99930790565118), np.float64(0.6946122867392029))
#   Current UB: 0.984167046 (per-scen)
#   UB point: (-9.999030395438158, -99.99948881122856, 0.9561166866952173)
#   UB source: unknown
#   UB simplex: None
#   EF-IPOPT: ok=True, status=ok, term=optimal, time=0.693s, ef_obj=0.98416726559873, true_obj(per-scen)=0.984167286
# ======================================================================
#
# ======================================================================
# [TIMING] === Iter 31 phase breakdown (total 17.21s) ===
#   1_vertex_UB                    :       0.00s  (  0.0%)
#   2_evaluate_all_tetra           :       0.00s  (  0.0%)
#   3_active_filter_print          :       0.00s  (  0.0%)
#   4_LB_selection                 :       0.00s  (  0.0%)
#   5_EF_UB_solve                  :       3.63s  ( 21.1%)  ##########
#   6_candidate_selection          :       0.00s  (  0.0%)
#   7_Q_eval_new_node              :       0.20s  (  1.2%)
#   8_mesh_subdivide               :       0.00s  (  0.0%)
#   9_end_of_iter_reeval           :      13.37s  ( 77.7%)  ######################################
#   TOTAL                          :      17.21s
#   #simplices=25, #scenarios=5, total_ms_pairs=125
#   fresh ms solves=0, cache hits=125
# ======================================================================
#
# [Iter 31] Stop: Time limit reached (910.24s >= 900.00s).
#
# ===== Simplex search summary (per-scenario) =====
#   Time (s)  # Nodes             LB             UB   Rel. Gap   Abs. Gap   #simplex    #active   Split       Selection
# ---------------------------------------------------------------------------------------------------------------------
#    110.075        8    0.984150141    0.984167047    0.0017%    0.00002          6          6    none             c_s
#    245.992        9    0.984055121    0.984167046    0.0114%    0.00011          9          1interior             c_s
#    304.571       10    0.984068433    0.984167046    0.0100%    0.00010         12          3interior             c_s
#    340.317       11    0.984068941    0.984167046    0.0100%    0.00010         13          4    edge             c_s
#    380.466       12    0.984068976    0.984167046    0.0100%    0.00010         14          4    edge             c_s
#    409.999       13    0.984068976    0.984167046    0.0100%    0.00010         15          4    edge             c_s
#    431.119       14    0.984067304    0.984167046    0.0101%    0.00010         15          4    edge        ms(vert)
#    469.394       15    0.984067304    0.984167046    0.0101%    0.00010         16          4interior             c_s
#    491.428       16    0.984067303    0.984167046    0.0101%    0.00010         16          4    edge             c_s
#    512.625       17    0.984067303    0.984167046    0.0101%    0.00010         16          4    edge             c_s
#    534.546       18    0.984067314    0.984167046    0.0101%    0.00010         16          4    edge             c_s
#    556.111       19    0.984067434    0.984167046    0.0101%    0.00010         16          4    edge             c_s
#    584.260       20    0.984067345    0.984167046    0.0101%    0.00010         17          5    edge        ms(vert)
#    599.095       21    0.984067345    0.984167046    0.0101%    0.00010         18          5interior             c_s
#    605.844       22    0.984067363    0.984167046    0.0101%    0.00010         18          5    edge             c_s
#    615.625       23    0.984067363    0.984167046    0.0101%    0.00010         18          5    edge             c_s
#    624.137       24    0.984067346    0.984167046    0.0101%    0.00010         18          5    edge             c_s
#    631.494       25    0.984067346    0.984167046    0.0101%    0.00010         18          5    edge             c_s
#    640.499       26    0.984067371    0.984167046    0.0101%    0.00010         18          5    edge             c_s
#    648.254       27    0.984067346    0.984167046    0.0101%    0.00010         18          5    edge             c_s
#    657.619       28    0.984067346    0.984167046    0.0101%    0.00010         18          5    edge             c_s
#    663.330       29    0.984067363    0.984167046    0.0101%    0.00010         18          5    edge             c_s
#    672.718       30    0.984067346    0.984167046    0.0101%    0.00010         18          5    edge             c_s
#    679.879       31    0.984067363    0.984167046    0.0101%    0.00010         18          5    edge             c_s
#    687.585       32    0.984067892    0.984167046    0.0101%    0.00010         18          5    edge             c_s
#    694.664       33    0.984067399    0.984167046    0.0101%    0.00010         18          5    edge             c_s
#    733.390       34    0.984067400    0.984167046    0.0101%    0.00010         21          7interior             c_s
#    761.864       35    0.984067415    0.984167046    0.0101%    0.00010         22          7    edge             c_s
#    800.688       36    0.984067396    0.984167046    0.0101%    0.00010         23          7    edge             c_s
#    835.970       37    0.984067401    0.984167046    0.0101%    0.00010         24          7    edge             c_s
#    873.084       38    0.984067401    0.984167046    0.0101%    0.00010         25          7    edge             c_s
#    894.162       39    0.984067420    0.984167046    0.0101%    0.00010         25          7    edge             c_s
# [Time] Main loop total: 913.011s
#
# ==== Done ====
# Total nodes: 40
# Best UB: 4.920835231228621
# Last LB: 4.920337098348276
