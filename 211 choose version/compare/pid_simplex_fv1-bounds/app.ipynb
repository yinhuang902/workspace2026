# %%
from time import perf_counter  

from modeling import build_models_from_csv
from bundles import BaseBundle, MSBundle
from utils import (
    tighten_bounds_one_model,
    MIN_DIST, ACTIVE_TOL, GAP_STOP_TOL,
)
from simplex_specialstart import run_pid_simplex_3d

# setup scenario number and target_nodesk
csv_path       = "data.csv"
max_scenarios  = 10
target_nodes   = 1000

bounds={
    "Kp": (-10.0, 10.0),
    "Ki": (-100.0, 100.0),
    "Kd": (-100.0, 100.0),
    "x": (-2.5, 2.5),
    "u": (-5.0, 5.0),
    "e": (None, None),
    "I": (None, None),
}

weights = (10.0, 0.01)


# ====== stage 1：load data and generate models ======
T   = 15.0          
nfe = 20            

t_load0 = perf_counter()
model_list, first_stg_vars_list, m_tmpl_list, nfe = build_models_from_csv(
    csv_path=csv_path,
    T=T,
    nfe=nfe,
    weights=weights,
    bounds=bounds,
    sp0=0.0,
    sp1=0.5,
    tau_xs_col="tau_xs",
    tau_us_col="tau_us",
    tau_ds_col="tau_ds",          
    disturb_prefix="disturbance_",
    setpoint_change_col="setpoint_change",
    max_scenarios=max_scenarios,
    skip=0,
)
t_load1 = perf_counter()
print(f"[Time] Data load & scenario build: {t_load1 - t_load0:.3f}s")


# ====== stage 1.5：FBBT / OBBT ======
# same as snog: FBBT open,OBBT open
obbt_solver_opts = {
    "NonConvex": 2,
    "MIPGap": 1,     
    "TimeLimit": 15   
}
for m, yvars in zip(model_list, first_stg_vars_list):
    tighten_bounds_one_model(m, yvars,
                             use_fbbt=False,
                             use_obbt=False,
                             obbt_solver_name="gurobi",
                             obbt_solver_opts=obbt_solver_opts,
                             max_rounds=3, tol=1e-6, verbose=True)

# ====== stage 2: Persistent Solver Packaging ======
ub_options = {
    'NonConvex': 2,      
}
lb_options = {
    'NonConvex': 2,
    'MIPGap': 1e-1,            
    'TimeLimit': 60 
}

t_wrap0 = perf_counter()
base_bundles = [BaseBundle(m, ub_options) for m in model_list]  
ms_bundles   = [MSBundle(m, yvars, lb_options) for m, yvars in zip(model_list, first_stg_vars_list)]  
t_wrap1 = perf_counter()
print(f"[Time] Persistent wrapper (GurobiPersistent) setup: {t_wrap1 - t_wrap0:.3f}s")

# ====== stage 3：main loop ======
agg_bundle = None  

t_run0 = perf_counter()
hist = run_pid_simplex_3d(
    base_bundles=base_bundles,
    ms_bundles=ms_bundles,
    model_list=model_list,
    first_vars_list=first_stg_vars_list,
    target_nodes=target_nodes,
    min_dist=0,
    active_tol=ACTIVE_TOL,
    verbose=True,
    agg_bundle=agg_bundle,
    gap_stop_tol=1e-6,
    use_exact_opt=False,
    exact_solver_name="gurobi",
    exact_solver_opts={"NonConvex": 2, "TimeLimit": 60},
    time_limit=60*30*1,
    enable_3d_plot=False,   
    plot_every=None,        
)
t_run1 = perf_counter()
print(f"[Time] Main loop total: {t_run1 - t_run0:.3f}s")

# ====== print output ======
print("\n==== Done ====")
print(f"Total nodes: {len(hist['nodes'])}")
print(f"Best UB: {min(hist['UB_hist']) if hist['UB_hist'] else None}")
print(f"Last LB: {hist['LB_hist'][-1] if hist['LB_hist'] else None}")
# Out:
# [Time] Data load & scenario build: 0.118s
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2689754
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 60
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 60
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 60
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 60
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 60
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 60
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 60
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 60
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 60
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 60
# [Time] Persistent wrapper (GurobiPersistent) setup: 3.674s
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [TIMING] Pre-loop vertex Q evals: 6.09s  (8 nodes x 10 scenarios = 80 solves)
# [EF-UB] Initialized ipopt EF with 10 scenarios, time_ub=60.0s
#
# ======================================================================
# [TIMING] === Pre-loop phase summary ===
#   corners_and_mesh               :       0.00s
#   vertex_Q_evals                 :       6.09s
#   exact_optima                   :       0.00s
#   ef_init                        :       0.14s
#   TOTAL                          :       6.23s
# ======================================================================
#
# [Iter 0] MIPGap overridden to 0.1 (original: 0.1)
# Discarded solution information
# [Invariant] MS scen None: dual=-5.500707e+09 > primal=-5.500707e+09
# Discarded solution information
# Discarded solution information
# [Invariant] MS scen None: dual=-5.481254e+09 > primal=-5.481254e+09
# Discarded solution information
# Discarded solution information
# [Invariant] MS scen None: dual=-5.194287e+09 > primal=-5.194287e+09
# Discarded solution information
# Discarded solution information
# Discarded solution information
# Discarded solution information
# Discarded solution information
# [Invariant] MS scen None: dual=-5.806922e+09 > primal=-5.806922e+09
# [Invariant] MS scen None: dual=-5.817119e+09 > primal=-5.817119e+09
# [Invariant] MS scen None: dual=-6.005622e+09 > primal=-6.005622e+09
# [Invariant] MS scen None: dual=-5.982090e+09 > primal=-5.982090e+09
# [Invariant] MS scen None: dual=-5.596691e+09 > primal=-5.596691e+09
# [Invariant] MS scen None: dual=-5.628277e+09 > primal=-5.628277e+09
# [Invariant] MS scen None: dual=-5.719282e+09 > primal=-5.719282e+09
# [Invariant] MS scen None: dual=-5.735561e+09 > primal=-5.735561e+09
# [Invariant] MS scen None: dual=-5.718800e+09 > primal=-5.718800e+09
# [Invariant] MS scen None: dual=-5.912410e+09 > primal=-5.912410e+09
# [Invariant] MS scen None: dual=-5.724298e+09 > primal=-5.724298e+09
# [Invariant] MS scen None: dual=-5.679468e+09 > primal=-5.679468e+09
# [Invariant] MS scen None: dual=-5.610143e+09 > primal=-5.610143e+09
# [Bundle] MS scen None: infeasibleOrUnbounded. ms_val=nan.
# [Bundle] MS scen None: not optimal. Status=warning, Term=infeasibleOrUnbounded.
# [Invariant] MS scen None: dual=-5.870800e+09 > primal=-5.870800e+09
# [Invariant] MS scen None: dual=-5.766877e+09 > primal=-5.766877e+09
# [Invariant] MS scen None: dual=-5.000000e+09 > primal=-5.000000e+09
# [Invariant] MS scen None: dual=-5.788922e+09 > primal=-5.788922e+09
# [Iter 0] MIPGap restored to 0.1
# [Iter 0] #simplices = 6, #active = 6, bad-quality cut = 0, bad-shape cut = 0
# == [Iter 0] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.031046e+00      4.639037e+09     -5.360963e+10      1.031046e+01     [2.23e+01, 1.00e+11]    [-5.36e+10, 4.64e+10]     1
# T1            9.937735e-01      4.082672e+09     -5.917328e+10      9.937735e+00     [2.23e+01, 1.00e+11]    [-5.92e+10, 4.08e+10]     1
# T2            1.024926e+00      4.371904e+09     -5.628096e+10      1.024926e+01     [2.21e+01, 1.00e+11]    [-5.63e+10, 4.37e+10]     1
# T3            1.000442e+00      4.209123e+09     -5.790877e+10      1.000442e+01     [2.21e+01, 1.00e+11]    [-5.79e+10, 4.21e+10]     1
# T4            1.020419e+00      4.317584e+09     -5.682416e+10      1.020419e+01     [2.71e+01, 1.00e+11]    [-5.68e+10, 4.32e+10]     2
# T5            1.015549e+00               inf               inf      1.015549e+01     [2.71e+01, 1.00e+11]               [inf, inf]     2
#
# == [Iter 0] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
#   (none)
# [Iter 0] created=6 (cum=6), active=6, active+UB=2, ms_recomputed=6
# [Iter 0] EF-ipopt: ok=True, ef_obj=0.9796536626177266, true_obj=1.073400e+00, time=0.506s
# [Iter 0] EF-UB improved by ipopt: 1.073400e+00 (per-scen), K=(-9.999826181219058, -99.99967151846334, -5.8938009680806095e-12)
# [Iter 0] Pre-split gap: 7.962695e-01 (7.418%)
# [Iter 0] Active simplex ratio = 1.000000
# [Iter 0] UB point (-9.999826181219058, -99.99967151846334, -5.8938009680806095e-12) is geometrically in simplices [1]
#   T1 verts=[3, 1, 4, 0]: λ=[0.000002, 0.499998, 0.000009, 0.499991], LB=9.937734530, c_s=[0.9960029127022256, 1.0001366770450069, 0.9579954878938712, 1.0551989733060005, 0.9683379558464811, 0.9880759501728958, 1.0108195608832988, 0.9912890927655227, 1.01296369143852, 0.9569142275119016]
#
# == [Iter 0] CS DUAL vs PRIMAL diagnostic (simplices containing UB point) ==
#   --- T1 ---
#     scen 0: status=optimal, dual=0.996002913, primal=0.996002913  ✓ dual ≤ primal (gap=1.110223e-16)
#              cs_primal_K=(-9.999216646683243, -99.99852406033013, 0.9388331317148486)
#              indep_Q(cs_K)=0.996002918  → dual ≤ indep_Q (consistent, diff=4.973934e-09)
#     scen 1: status=optimal, dual=1.000136677, primal=1.000136677  ✓ dual ≤ primal (gap=-2.220446e-16)
#              cs_primal_K=(-9.999983393339464, -0.15781395634996587, 0.00040036514586223133)
#              indep_Q(cs_K)=1.000136678  → dual ≤ indep_Q (consistent, diff=1.132161e-09)
#     scen 2: status=optimal, dual=0.957995488, primal=0.957995488  ✓ dual ≤ primal (gap=-2.220446e-16)
#              cs_primal_K=(-9.998442794608906, -99.99686925671598, -2.736029187431506e-10)
#              indep_Q(cs_K)=0.957995515  → dual ≤ indep_Q (consistent, diff=2.714000e-08)
#     scen 3: status=optimal, dual=1.055198973, primal=1.055198973  ✓ dual ≤ primal (gap=2.220446e-16)
#              cs_primal_K=(-9.233467561678685, -98.4408518452537, 0.32994040845543465)
#              indep_Q(cs_K)=1.055198979  → dual ≤ indep_Q (consistent, diff=5.506025e-09)
#     scen 4: status=optimal, dual=0.968337956, primal=0.968337956  ✓ dual ≤ primal (gap=0.000000e+00)
#              cs_primal_K=(-9.998518091599312, -99.9972050307925, 0.39376151703840556)
#              indep_Q(cs_K)=0.968337957  → dual ≤ indep_Q (consistent, diff=1.643293e-09)
#     scen 5: status=optimal, dual=0.988075950, primal=0.988075950  ✓ dual ≤ primal (gap=-1.110223e-16)
#              cs_primal_K=(-9.628868037677085, -0.004403023617462816, 0.000584032228044548)
#              indep_Q(cs_K)=0.988075957  → dual ≤ indep_Q (consistent, diff=7.198358e-09)
#     scen 6: status=optimal, dual=1.010819561, primal=1.010819561  ✓ dual ≤ primal (gap=-2.220446e-16)
#              cs_primal_K=(-9.999258333905566, -99.99876016143422, 1.9640715296828297)
#              indep_Q(cs_K)=1.010819562  → dual ≤ indep_Q (consistent, diff=1.096565e-09)
#     scen 7: status=optimal, dual=0.991289093, primal=0.991289093  ✓ dual ≤ primal (gap=0.000000e+00)
#              cs_primal_K=(-9.987990535473328, -75.22276794488953, -6.309053858324999)
#              indep_Q(cs_K)=0.991289096  → dual ≤ indep_Q (consistent, diff=3.050211e-09)
#     scen 8: status=optimal, dual=1.012963691, primal=1.012963691  ✓ dual ≤ primal (gap=-2.220446e-16)
#              cs_primal_K=(-10.0, -90.12358626125518, 0.5687336812924049)
#              indep_Q(cs_K)=1.012963693  → dual ≤ indep_Q (consistent, diff=1.468491e-09)
#     scen 9: status=optimal, dual=0.956914228, primal=0.956914228  ✓ dual ≤ primal (gap=-1.110223e-16)
#              cs_primal_K=(-9.997407327768787, -99.99533837759942, 1.2699015901737298)
#              indep_Q(cs_K)=0.956914233  → dual ≤ indep_Q (consistent, diff=5.864871e-09)
#   sum(c_s_dual)=9.937734530, UB_total=107.340040355, UB_per_scen=10.734004035
#
#   == Per-scenario Q_s at K_EF = (-9.999826181219058, -99.99967151846334, -5.8938009680806095e-12) ==
#     scen 0: Q_s(K_EF)=1.090435851, c_s_dual=0.996002913  ✓ Q_s(K_EF) > c_s_dual (diff=9.443294e-02)
#     scen 1: Q_s(K_EF)=1.039363470, c_s_dual=1.000136677  ✓ Q_s(K_EF) > c_s_dual (diff=3.922679e-02)
#     scen 2: Q_s(K_EF)=1.051741935, c_s_dual=0.957995488  ✓ Q_s(K_EF) > c_s_dual (diff=9.374645e-02)
#     scen 3: Q_s(K_EF)=1.148392308, c_s_dual=1.055198973  ✓ Q_s(K_EF) > c_s_dual (diff=9.319333e-02)
#     scen 4: Q_s(K_EF)=1.062205005, c_s_dual=0.968337956  ✓ Q_s(K_EF) > c_s_dual (diff=9.386705e-02)
#     scen 5: Q_s(K_EF)=1.036712249, c_s_dual=0.988075950  ✓ Q_s(K_EF) > c_s_dual (diff=4.863630e-02)
#     scen 6: Q_s(K_EF)=1.107378750, c_s_dual=1.010819561  ✓ Q_s(K_EF) > c_s_dual (diff=9.655919e-02)
#     scen 7: Q_s(K_EF)=1.040982650, c_s_dual=0.991289093  ✓ Q_s(K_EF) > c_s_dual (diff=4.969356e-02)
#     scen 8: Q_s(K_EF)=1.104837983, c_s_dual=1.012963691  ✓ Q_s(K_EF) > c_s_dual (diff=9.187429e-02)
#     scen 9: Q_s(K_EF)=1.051953835, c_s_dual=0.956914228  ✓ Q_s(K_EF) > c_s_dual (diff=9.503961e-02)
#     SUM Q_s(K_EF)=10.734004035, sum(c_s)=9.937734530, diff=7.962695e-01
#
# [Iter 0] LB = 9.937735 = UB(10.734004) + ms_b(-5.917e+10) from T1
# [Iter 0] Scene 0: Switched to c_s point. dist_ms_c=1.71e+01 < 1000.0, dist_c_verts=9.91e+01 > 1e-06
# [Iter 0] Scene 1: Switched to c_s point. dist_ms_c=1.01e+02 < 1000.0, dist_c_verts=1.41e+02 > 1e-06
# [Iter 0] Scene 2: Switched to c_s point. dist_ms_c=2.05e+01 < 1000.0, dist_c_verts=1.00e+02 > 1e-06
# [Iter 0] Scene 3: Switched to c_s point. dist_ms_c=2.06e+01 < 1000.0, dist_c_verts=9.97e+01 > 1e-06
# [Iter 0] Scene 4: Switched to c_s point. dist_ms_c=1.92e+01 < 1000.0, dist_c_verts=9.96e+01 > 1e-06
# [Iter 0] Scene 5: Switched to c_s point. dist_ms_c=1.02e+02 < 1000.0, dist_c_verts=1.41e+02 > 1e-06
# [Iter 0] Scene 6: Switched to c_s point. dist_ms_c=1.77e+01 < 1000.0, dist_c_verts=9.80e+01 > 1e-06
# [Iter 0] Scene 7: Switched to c_s point. dist_ms_c=3.03e+01 < 1000.0, dist_c_verts=9.69e+01 > 1e-06
# [Iter 0] Scene 8: Switched to c_s point. dist_ms_c=2.15e+01 < 1000.0, dist_c_verts=9.99e+01 > 1e-06
# [Iter 0] Scene 9: Switched to c_s point. dist_ms_c=1.85e+01 < 1000.0, dist_c_verts=9.87e+01 > 1e-06
# Chosen node (-9.233467561678685, -98.4408518452537, 0.32994040845543465) with ms=-6.045e+09 (simp T1, scene 3, rank #1, source=c_s)
# [Iter 0] LB simplex = T1, next node simplex = T1, scene 3
# [Selected Simp Info] Iter 0 | Simplex T1 Vertices:
#   v0: (-10.0, 100.0, 100.0)
#   v1: (-10.0, -100.0, 100.0)
#   v2: (10.0, -100.0, -100.0)
#   v3: (-10.0, -100.0, -100.0)
#   -> New Point: (-9.233467561678685, -98.4408518452537, 0.32994040845543465)
# [Iter 0] candidate rank #1: T1, scene=3, ms=-6.045e+09
# == ms candidates (sorted by (ms, -dist)) ==
# rank   simp   scene           ms    mind(all)                             pt
# ----------------------------------------------------------------------------
#    1     T1       3  -6.0448e+09     9.97e+01    (-9.2335, -98.4409, 0.3299)
#    2     T1       2  -6.0269e+09     1.00e+02   (-9.9984, -99.9969, -0.0000)
#    3     T1       5  -6.0056e+09     1.41e+02     (-9.6289, -0.0044, 0.0006)
#    4     T1       6  -5.9849e+09     9.80e+01    (-9.9993, -99.9988, 1.9641)
#    5     T1       9  -5.9821e+09     9.87e+01    (-9.9974, -99.9953, 1.2699)
#    6     T1       8  -5.9795e+09     9.99e+01   (-10.0000, -90.1236, 0.5687)
#    7     T1       4  -5.9790e+09     9.96e+01    (-9.9985, -99.9972, 0.3938)
#    8     T1       1  -5.8171e+09     1.41e+02    (-10.0000, -0.1578, 0.0004)
#    9     T1       0  -5.8069e+09     9.91e+01    (-9.9992, -99.9985, 0.9388)
#   10     T1       7  -5.5465e+09     9.69e+01   (-9.9880, -75.2228, -6.3091)
#
# [Iter 0] per_tet=6, active after q_cut=6, tri_is_None=False
# [Iter 0] bad-quality active simplices (q < 0): 0
# [Iter 0] evaluating Q for scenario 0
# [Iter 0] evaluating Q for scenario 1
# [Iter 0] evaluating Q for scenario 2
# [Iter 0] evaluating Q for scenario 3
# [Iter 0] evaluating Q for scenario 4
# [Iter 0] evaluating Q for scenario 5
# [Iter 0] evaluating Q for scenario 6
# [Iter 0] evaluating Q for scenario 7
# [Iter 0] evaluating Q for scenario 8
# [Iter 0] evaluating Q for scenario 9
#
# [Iter 0] Next Point Details:
# Simplex   Scene   Type    As             ms             As+ms          Q              (Kp, Ki, Kd)
# --------------------------------------------------------------------------------------------------------------------
# T1        3       c_s     4.9385e+09     -6.0448e+09    -1.1063e+09    1.0552e+00     (-9.2335, -98.4409, 0.3299)
#
# [Iter 0] subdivision type = interior (code=1) on simplex T1
# [Iter 0] Elapsed: 234.865s
# [Invariant] MS scen None: dual=-6.034060e+09 > primal=-6.034060e+09
# [Invariant] MS scen None: dual=-5.999233e+09 > primal=-5.999233e+09
# [Invariant] MS scen None: dual=-5.890951e+09 > primal=-5.890951e+09
# [Invariant] MS scen None: dual=-6.009497e+09 > primal=-6.009497e+09
# [Invariant] MS scen None: dual=-5.838964e+09 > primal=-5.838964e+09
# [Invariant] MS scen None: dual=-5.688783e+09 > primal=-5.688783e+09
# [Invariant] MS scen None: dual=-5.777795e+09 > primal=-5.777795e+09
# [Invariant] MS scen None: dual=-5.517359e+09 > primal=-5.517359e+09
# [Invariant] MS scen None: dual=-5.838152e+09 > primal=-5.838152e+09
# ======================================================================
# [Iter 0] LB SPLIT DIAGNOSTIC
#   Selected (parent) simplex: (0, 1, 3, 4)
#   Parent LB: 0.993773453 (per-scen)
#   EF ef_obj(IPOPT): 0.097965366, true_obj(recalc): 1.073400404, used=min=0.097965366 (per-scen)
#   Simplex volume: 1.333333e+05
#   Children (4):
#     T5 (0, 1, 4, 8): LB = 0.978933941
#     T6 (0, 3, 4, 8): LB = 0.983962673
#     T7 (0, 1, 3, 8): LB = 1.008364824
#     T8 (1, 3, 4, 8): LB = 0.982562774
#   New global LB: 0.978933941 (from T5 (0, 1, 4, 8))
#   Location: INSIDE
#   Avg CS point Q-value: 0.982897054 (per-scen), point=(np.float64(-9.884315272273437), np.float64(-76.3936119918238), np.float64(-0.08428276028670419))
#   Current UB: 1.073400404 (per-scen)
#   UB point: (-9.999826181219058, -99.99967151846334, -5.8938009680806095e-12)
#   UB source: EF_ipopt
#   UB simplex: (0, 1, 3, 4)
#   EF-IPOPT: ok=True, status=ok, term=optimal, time=0.506s, ef_obj=0.9796536626177266, true_obj(per-scen)=1.073400404
# ======================================================================
# [BaseBundle.eval_at] Infeasible/Error for K=(-6.632423620859237, -100.00000000000061, 18.874020555529913): status=warning, term=infeasibleOrUnbounded
# [Iter 0] UB candidate from new simplex 5 (avgCS): 9.791470e-01 (per scenario)
#
# ======================================================================
# [TIMING] === Iter 0 phase breakdown (total 816.57s) ===
#   1_vertex_UB                    :       0.00s  (  0.0%)
#   2_evaluate_all_tetra           :     233.22s  ( 28.6%)  ##############
#   3_active_filter_print          :       0.00s  (  0.0%)
#   4_LB_selection                 :       0.00s  (  0.0%)
#   5_EF_UB_solve                  :       0.82s  (  0.1%)
#   6_candidate_selection          :       0.70s  (  0.1%)
#   7_Q_eval_new_node              :       0.12s  (  0.0%)
#   8_mesh_subdivide               :       0.00s  (  0.0%)
#   9_end_of_iter_reeval           :     581.70s  ( 71.2%)  ###################################
#   TOTAL                          :     816.57s
#   #simplices=6, #scenarios=10, total_ms_pairs=60
#   fresh ms solves=60, cache hits=0
# ======================================================================
#
# [Iter 1] #simplices = 9, #active = 1, bad-quality cut = 0, bad-shape cut = 0
# == [Iter 1] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T5            9.789339e-01      4.056299e+09     -5.943701e+10      9.789339e+00     [9.80e+00, 1.00e+11]    [-5.94e+10, 4.06e+10]     1
#
# == [Iter 1] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.031046e+00      4.639037e+09     -5.360963e+10      1.031046e+01     [2.23e+01, 1.00e+11]    [-5.36e+10, 4.64e+10]     1
# T1            1.024926e+00      4.371904e+09     -5.628096e+10      1.024926e+01     [2.21e+01, 1.00e+11]    [-5.63e+10, 4.37e+10]     1
# T2            1.000442e+00      4.209123e+09     -5.790877e+10      1.000442e+01     [2.21e+01, 1.00e+11]    [-5.79e+10, 4.21e+10]     1
# T3            1.020419e+00      4.317584e+09     -5.682416e+10      1.020419e+01     [2.71e+01, 1.00e+11]    [-5.68e+10, 4.32e+10]     2
# T4            1.015549e+00               inf               inf      1.015549e+01     [2.71e+01, 1.00e+11]               [inf, inf]     2
# T6            9.839627e-01      1.372149e+00     -1.356848e+01      9.839627e+00     [9.80e+00, 2.73e+01]    [-3.77e+00, 1.37e+01]     0
# T7            1.008365e+00      4.017814e+09     -5.982186e+10      1.008365e+01     [9.80e+00, 1.00e+11]    [-5.98e+10, 4.02e+10]     1
# T8            9.825628e-01      4.292210e+09     -5.707790e+10      9.825628e+00     [9.80e+00, 1.00e+11]    [-5.71e+10, 4.29e+10]     1
#
# [Iter 1] created=9 (cum=19), active=1, active+UB=1, ms_recomputed=0
# [Iter 1] EF-ipopt: ok=True, ef_obj=0.9796536242935225, true_obj=1.073402e+00, time=0.194s
# [Iter 1] Pre-split gap: 2.130173e-03 (0.022%)
# [Iter 1] Active simplex ratio = 0.001299
# [Iter 1] UB point (-9.233467561678685, -98.4408518452537, 0.32994040845543465) is geometrically in simplices [5, 6, 7, 8]
#   T5 verts=[8, 1, 4, 0]: λ=[1.000000, 0.000000, 0.000000, -0.000000], LB=9.789339411, c_s=[0.996005370497984, 0.9452595803485847, 0.9564957702968899, 1.0545523581483314, 0.9683811117280262, 0.9428274976917447, 1.010824427746365, 0.9471386180388108, 1.010776480683583, 0.957078195665968]
#   T6 verts=[3, 8, 4, 0]: λ=[0.000000, 1.000000, 0.000000, 0.000000], LB=9.839626728, c_s=[0.9964804763189644, 0.9452075438707042, 0.9560310067435366, 1.1036101077826106, 0.9685253396580769, 0.9428000674438131, 1.0116719715665465, 0.9467296104810701, 1.0114775453652625, 0.957093059039426]
#   T7 verts=[3, 1, 8, 0]: λ=[0.000000, -0.000000, 1.000000, -0.000000], LB=10.083648241, c_s=[0.9973247431766652, 0.9514457805678668, 0.9656198753319554, 1.0672606687074229, 0.968337628799988, 1.0374245479772295, 1.0136465207395813, 1.0226914248653836, 1.1029826587665512, 0.956914392178161]
#   T8 verts=[3, 1, 4, 8]: λ=[0.000000, -0.000000, -0.000000, 1.000000], LB=9.825627739, c_s=[0.9963496140225404, 0.9451524351349165, 0.9698865096745042, 1.0551989613974155, 0.9751892290372399, 0.9442113411165541, 1.0244998663067293, 0.9467246518796341, 1.0113942757451981, 0.9570208551646008]
#
# == [Iter 1] CS DUAL vs PRIMAL diagnostic (simplices containing UB point) ==
#   --- T5 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 0.8803662835224104)
#              indep_Q(cs_K)=0.996005375
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 0.3816748632549367)
#              indep_Q(cs_K)=0.945259594
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-4.1453914214428575, -100.0, 2.276255451699071)
#              indep_Q(cs_K)=0.956495771
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999022057536129, -99.99947878853936, 0.3476234904818926)
#              indep_Q(cs_K)=1.054552379
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 0.15833275475759467)
#              indep_Q(cs_K)=0.968381112
#     scen 5: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.20189446137141, -100.0, 0.26720658026027283)
#              indep_Q(cs_K)=0.942827500
#     scen 6: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 1.8835164695665434)
#              indep_Q(cs_K)=1.010824429
#     scen 7: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 0.08144986943727282)
#              indep_Q(cs_K)=0.947138619
#     scen 8: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 0.5472420838323773)
#              indep_Q(cs_K)=1.010776496
#     scen 9: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-8.460502943733642, -100.0, 1.0024781256921333)
#              indep_Q(cs_K)=0.957078455
#   sum(c_s_dual)=0.000000000, UB_total=97.914695840, UB_per_scen=9.791469584
#
#   == Per-scenario Q_s at K_EF = (-9.233467561678685, -98.4408518452537, 0.32994040845543465) ==
#     scen 0: Q_s(K_EF)=0.996654491, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945331903, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.957406451, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.055198979, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968525339, c_s_dual=N/A
#     scen 5: Q_s(K_EF)=0.942818281, c_s_dual=N/A
#     scen 6: Q_s(K_EF)=1.013296278, c_s_dual=N/A
#     scen 7: Q_s(K_EF)=0.946925796, c_s_dual=N/A
#     scen 8: Q_s(K_EF)=1.011480417, c_s_dual=N/A
#     scen 9: Q_s(K_EF)=0.957780386, c_s_dual=N/A
#     SUM Q_s(K_EF)=9.795418321, sum(c_s)=0.000000000, diff=9.795418e+00
#   --- T6 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.23700466778097, -97.52488482382559, 0.7899867334739011)
#              indep_Q(cs_K)=0.996480476
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.238684762012054, -97.09021666447985, 1.0083183115050685)
#              indep_Q(cs_K)=0.945207544
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.243502686123637, -95.84118419904618, 1.6355834325786414)
#              indep_Q(cs_K)=0.956031137
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.34963323319087, -43.62721731904094, 2.264240236918686)
#              indep_Q(cs_K)=1.103610108
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.233466476504931, -98.44075973545351, 0.3299691309095486)
#              indep_Q(cs_K)=0.968525343
#     scen 5: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.234580881861424, -98.14963772549002, 0.47606606594512035)
#              indep_Q(cs_K)=0.942800068
#     scen 6: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.244731495282917, -95.52461211844559, 1.7946579929763422)
#              indep_Q(cs_K)=1.011671993
#     scen 7: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.237182677330463, -97.47505122986146, 0.8148456674336909)
#              indep_Q(cs_K)=0.946729611
#     scen 8: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.233936563205308, -98.3193409727966, 0.3909667503983829)
#              indep_Q(cs_K)=1.011477545
#     scen 9: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.240363151761883, -96.6548605923135, 1.226943895001533)
#              indep_Q(cs_K)=0.957093084
#   sum(c_s_dual)=0.000000000, UB_total=97.914695840, UB_per_scen=9.791469584
#
#   == Per-scenario Q_s at K_EF = (-9.233467561678685, -98.4408518452537, 0.32994040845543465) ==
#     scen 0: Q_s(K_EF)=0.996654491, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945331903, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.957406451, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.055198979, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968525339, c_s_dual=N/A
#     scen 5: Q_s(K_EF)=0.942818281, c_s_dual=N/A
#     scen 6: Q_s(K_EF)=1.013296278, c_s_dual=N/A
#     scen 7: Q_s(K_EF)=0.946925796, c_s_dual=N/A
#     scen 8: Q_s(K_EF)=1.011480417, c_s_dual=N/A
#     scen 9: Q_s(K_EF)=0.957780386, c_s_dual=N/A
#     SUM Q_s(K_EF)=9.795418321, sum(c_s)=0.000000000, diff=9.795418e+00
#   --- T7 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 2.1676799423834154)
#              indep_Q(cs_K)=0.997324744
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.617994172427158, -50.001281835653685, -0.7782922417189333)
#              indep_Q(cs_K)=0.951445782
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.825718594425771, -28.889709546347166, 0.7828811823885088)
#              indep_Q(cs_K)=0.965619880
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -65.22017252671591, -0.4347417883351457)
#              indep_Q(cs_K)=1.067260672
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999994478062833, -99.9999596096791, 0.3937636071576867)
#              indep_Q(cs_K)=0.968337630
#     scen 5: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999999885493708, 0.8996446573692363, 1.2163985318896746)
#              indep_Q(cs_K)=1.037424585
#     scen 6: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, -0.00535021042350296)
#              indep_Q(cs_K)=1.013646523
#     scen 7: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, 0.0, -1.358366521465961e-06)
#              indep_Q(cs_K)=1.022691607
#     scen 8: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.811091959578757, -27.081633859604153, -2.7400719338443844)
#              indep_Q(cs_K)=1.102982688
#     scen 9: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.998440553657284, -99.98882990189593, 1.269904238896632)
#              indep_Q(cs_K)=0.956914399
#   sum(c_s_dual)=0.000000000, UB_total=97.914695840, UB_per_scen=9.791469584
#
#   == Per-scenario Q_s at K_EF = (-9.233467561678685, -98.4408518452537, 0.32994040845543465) ==
#     scen 0: Q_s(K_EF)=0.996654491, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945331903, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.957406451, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.055198979, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968525339, c_s_dual=N/A
#     scen 5: Q_s(K_EF)=0.942818281, c_s_dual=N/A
#     scen 6: Q_s(K_EF)=1.013296278, c_s_dual=N/A
#     scen 7: Q_s(K_EF)=0.946925796, c_s_dual=N/A
#     scen 8: Q_s(K_EF)=1.011480417, c_s_dual=N/A
#     scen 9: Q_s(K_EF)=0.957780386, c_s_dual=N/A
#     SUM Q_s(K_EF)=9.795418321, sum(c_s)=0.000000000, diff=9.795418e+00
#   --- T8 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.238113046310767, -98.45028329239896, 0.9350306993869928)
#              indep_Q(cs_K)=0.996349626
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.236954039581867, -98.44794727991618, 0.7910318521803711)
#              indep_Q(cs_K)=0.945152436
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-2.9043843876495243, -28.631416720001962, 1.2289708168043416)
#              indep_Q(cs_K)=0.969886523
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.233516690215653, -98.44095319440851, 0.33667777401285565)
#              indep_Q(cs_K)=1.055198962
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-8.946996232393476, -90.49868934500577, 2.700852900574613)
#              indep_Q(cs_K)=0.975189230
#     scen 5: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-8.073014737766531, -83.5866195886286, 1.4855983721276451)
#              indep_Q(cs_K)=0.944211351
#     scen 6: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-0.33596291089658614, -69.86182372314593, 1.8323931498115233)
#              indep_Q(cs_K)=1.024499871
#     scen 7: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.237140819827871, -98.44818168738996, 0.820426686952687)
#              indep_Q(cs_K)=0.946724652
#     scen 8: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.23600751422537, -98.4460190650005, 0.6605356999832156)
#              indep_Q(cs_K)=1.011394278
#     scen 9: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.240679403357394, -98.45553023311267, 1.269769896114846)
#              indep_Q(cs_K)=0.957020928
#   sum(c_s_dual)=0.000000000, UB_total=97.914695840, UB_per_scen=9.791469584
#
#   == Per-scenario Q_s at K_EF = (-9.233467561678685, -98.4408518452537, 0.32994040845543465) ==
#     scen 0: Q_s(K_EF)=0.996654491, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945331903, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.957406451, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.055198979, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968525339, c_s_dual=N/A
#     scen 5: Q_s(K_EF)=0.942818281, c_s_dual=N/A
#     scen 6: Q_s(K_EF)=1.013296278, c_s_dual=N/A
#     scen 7: Q_s(K_EF)=0.946925796, c_s_dual=N/A
#     scen 8: Q_s(K_EF)=1.011480417, c_s_dual=N/A
#     scen 9: Q_s(K_EF)=0.957780386, c_s_dual=N/A
#     SUM Q_s(K_EF)=9.795418321, sum(c_s)=0.000000000, diff=9.795418e+00
#
# [Iter 1] LB = 9.789339 = UB(9.791470) + ms_b(-5.944e+10) from T5
# [Iter 1] Scene 0: Switched to c_s point. dist_ms_c=1.87e+01 < 1000.0, dist_c_verts=1.82e+00 > 1e-06
# [Iter 1] Scene 1: Switched to c_s point. dist_ms_c=1.84e+01 < 1000.0, dist_c_verts=1.74e+00 > 1e-06
# [Iter 1] Scene 2: Switched to c_s point. dist_ms_c=1.56e+01 < 1000.0, dist_c_verts=5.67e+00 > 1e-06
# [Iter 1] Scene 3: Switched to c_s point. dist_ms_c=2.03e+01 < 1000.0, dist_c_verts=1.74e+00 > 1e-06
# [Iter 1] Scene 4: Switched to c_s point. dist_ms_c=1.84e+01 < 1000.0, dist_c_verts=1.75e+00 > 1e-06
# [Iter 1] Scene 5: Switched to c_s point. dist_ms_c=1.85e+01 < 1000.0, dist_c_verts=1.56e+00 > 1e-06
# [Iter 1] Scene 6: Switched to c_s point. dist_ms_c=1.81e+01 < 1000.0, dist_c_verts=2.33e+00 > 1e-06
# [Iter 1] Scene 7: Switched to c_s point. dist_ms_c=1.90e+01 < 1000.0, dist_c_verts=1.76e+00 > 1e-06
# [Iter 1] Scene 8: Switched to c_s point. dist_ms_c=2.01e+01 < 1000.0, dist_c_verts=1.75e+00 > 1e-06
# [Iter 1] Scene 9: Switched to c_s point. dist_ms_c=1.75e+01 < 1000.0, dist_c_verts=1.87e+00 > 1e-06
# Chosen node (-9.999022057536129, -99.99947878853936, 0.3476234904818926) with ms=-6.034e+09 (simp T5, scene 3, rank #1, source=c_s)
# [Iter 1] LB simplex = T5, next node simplex = T5, scene 3
# [Selected Simp Info] Iter 1 | Simplex T5 Vertices:
#   v0: (-9.233467561678685, -98.4408518452537, 0.32994040845543465)
#   v1: (-10.0, -100.0, 100.0)
#   v2: (10.0, -100.0, -100.0)
#   v3: (-10.0, -100.0, -100.0)
#   -> New Point: (-9.999022057536129, -99.99947878853936, 0.3476234904818926)
# [Iter 1] candidate rank #1: T5, scene=3, ms=-6.034e+09
# == ms candidates (sorted by (ms, -dist)) ==
# rank   simp   scene           ms    mind(all)                             pt
# ----------------------------------------------------------------------------
#    1     T5       3  -6.0341e+09     1.74e+00    (-9.9990, -99.9995, 0.3476)
#    2     T5       8  -6.0317e+09     1.75e+00  (-10.0000, -100.0000, 0.5472)
#    3     T5       6  -5.9992e+09     2.33e+00  (-10.0000, -100.0000, 1.8835)
#    4     T5       0  -5.9800e+09     1.82e+00  (-10.0000, -100.0000, 0.8804)
#    5     T5       4  -5.9290e+09     1.75e+00  (-10.0000, -100.0000, 0.1583)
#    6     T5       5  -5.9169e+09     1.56e+00   (-9.2019, -100.0000, 0.2672)
#    7     T5       2  -5.8929e+09     5.67e+00   (-4.1454, -100.0000, 2.2763)
#    8     T5       7  -5.8910e+09     1.76e+00  (-10.0000, -100.0000, 0.0814)
#    9     T5       9  -5.8852e+09     1.87e+00   (-8.4605, -100.0000, 1.0025)
#   10     T5       1  -5.8771e+09     1.74e+00  (-10.0000, -100.0000, 0.3817)
#
# [Iter 1] per_tet=9, active after q_cut=1, tri_is_None=False
# [Iter 1] bad-quality active simplices (q < 0): 0
# [Iter 1] evaluating Q for scenario 0
# [Iter 1] evaluating Q for scenario 1
# [Iter 1] evaluating Q for scenario 2
# [Iter 1] evaluating Q for scenario 3
# [Iter 1] evaluating Q for scenario 4
# [Iter 1] evaluating Q for scenario 5
# [Iter 1] evaluating Q for scenario 6
# [Iter 1] evaluating Q for scenario 7
# [Iter 1] evaluating Q for scenario 8
# [Iter 1] evaluating Q for scenario 9
#
# [Iter 1] Next Point Details:
# Simplex   Scene   Type    As             ms             As+ms          Q              (Kp, Ki, Kd)
# --------------------------------------------------------------------------------------------------------------------
# T5        3       c_s     5.0157e+09     -6.0341e+09    -1.0184e+09    1.0546e+00     (-9.9990, -99.9995, 0.3476)
#
# [Iter 1] subdivision type = interior (code=1) on simplex T5
# [Iter 1] Elapsed: 1.191s
# [Invariant] MS scen None: dual=-5.890545e+09 > primal=-5.890545e+09
# [Invariant] MS scen None: dual=-5.887693e+09 > primal=-5.887693e+09
# [Invariant] MS scen None: dual=-5.961202e+09 > primal=-5.961202e+09
# [Invariant] MS scen None: dual=-5.957716e+09 > primal=-5.957716e+09
# [Invariant] MS scen None: dual=-6.013736e+09 > primal=-6.013736e+09
# [Invariant] MS scen None: dual=-5.957171e+09 > primal=-5.957171e+09
# [Invariant] MS scen None: dual=-5.669856e+09 > primal=-5.669856e+09
# [Invariant] MS scen None: dual=-5.607165e+09 > primal=-5.607165e+09
# ======================================================================
# [Iter 1] LB SPLIT DIAGNOSTIC
#   Selected (parent) simplex: (0, 1, 4, 8)
#   Parent LB: 0.978933941 (per-scen)
#   EF ef_obj(IPOPT): 0.097965362, true_obj(recalc): 1.073402251, used=min=0.097965362 (per-scen)
#   Simplex volume: 1.039432e+03
#   Children (4):
#     T8 (0, 1, 4, 9): LB = 0.978912802
#     T9 (0, 4, 8, 9): LB = 0.979258532
#     T10 (0, 1, 8, 9): LB = 0.978849419
#     T11 (1, 4, 8, 9): LB = 0.978911348
#   New global LB: 0.978849419 (from T10 (0, 1, 8, 9))
#   Location: INSIDE
#   Avg CS point Q-value: 0.979146958 (per-scen), point=(np.float64(-9.180681088408404), np.float64(-99.99994787885393), np.float64(0.7826145972504504))
#   Current UB: 0.979146958 (per-scen)
#   UB point: (-9.233467561678685, -98.4408518452537, 0.32994040845543465)
#   UB source: avgCS_new_simplex
#   UB simplex: (0, 1, 4, 8)
#   EF-IPOPT: ok=True, status=ok, term=optimal, time=0.194s, ef_obj=0.9796536242935225, true_obj(per-scen)=1.073402251
# ======================================================================
# [BaseBundle.eval_at] Infeasible/Error for K=(-4.447054232084908, -100.0, 18.266888996701166): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-4.447054232084908, -100.0, 18.266888996701166): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-4.447054232084908, -100.0, 18.266888996701166): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-4.447054232084908, -100.0, 18.266888996701166): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-4.447054232084908, -100.0, 18.266888996701166): status=warning, term=infeasibleOrUnbounded
# [Iter 1] UB candidate from new simplex 8 (avgCS): 9.790048e-01 (per scenario)
#
# ======================================================================
# [TIMING] === Iter 1 phase breakdown (total 26.70s) ===
#   1_vertex_UB                    :       0.00s  (  0.0%)
#   2_evaluate_all_tetra           :       0.00s  (  0.0%)
#   3_active_filter_print          :       0.00s  (  0.0%)
#   4_LB_selection                 :       0.00s  (  0.0%)
#   5_EF_UB_solve                  :       1.05s  (  3.9%)  #
#   6_candidate_selection          :       0.00s  (  0.0%)
#   7_Q_eval_new_node              :       0.14s  (  0.5%)
#   8_mesh_subdivide               :       0.00s  (  0.0%)
#   9_end_of_iter_reeval           :      25.51s  ( 95.5%)  ###############################################
#   TOTAL                          :      26.70s
#   #simplices=9, #scenarios=10, total_ms_pairs=90
#   fresh ms solves=0, cache hits=90
# ======================================================================
#
# [Iter 2] #simplices = 12, #active = 3, bad-quality cut = 0, bad-shape cut = 0
# == [Iter 2] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T8            9.789128e-01      4.086656e+09     -5.913344e+10      9.789128e+00     [9.79e+00, 1.00e+11]    [-5.91e+10, 4.09e+10]     1
# T10           9.788494e-01      4.033100e+09     -5.966900e+10      9.788494e+00     [9.79e+00, 1.00e+11]    [-5.97e+10, 4.03e+10]     1
# T11           9.789113e-01      4.394000e+09     -5.606000e+10      9.789113e+00     [9.79e+00, 1.00e+11]    [-5.61e+10, 4.39e+10]     1
#
# == [Iter 2] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.031046e+00      4.639037e+09     -5.360963e+10      1.031046e+01     [2.23e+01, 1.00e+11]    [-5.36e+10, 4.64e+10]     1
# T1            1.024926e+00      4.371904e+09     -5.628096e+10      1.024926e+01     [2.21e+01, 1.00e+11]    [-5.63e+10, 4.37e+10]     1
# T2            1.000442e+00      4.209123e+09     -5.790877e+10      1.000442e+01     [2.21e+01, 1.00e+11]    [-5.79e+10, 4.21e+10]     1
# T3            1.020419e+00      4.317584e+09     -5.682416e+10      1.020419e+01     [2.71e+01, 1.00e+11]    [-5.68e+10, 4.32e+10]     2
# T4            1.015549e+00               inf               inf      1.015549e+01     [2.71e+01, 1.00e+11]               [inf, inf]     2
# T5            9.839627e-01      1.372149e+00     -1.356848e+01      9.839627e+00     [9.80e+00, 2.73e+01]    [-3.77e+00, 1.37e+01]     0
# T6            1.008365e+00      4.017814e+09     -5.982186e+10      1.008365e+01     [9.80e+00, 1.00e+11]    [-5.98e+10, 4.02e+10]     1
# T7            9.825628e-01      4.292210e+09     -5.707790e+10      9.825628e+00     [9.80e+00, 1.00e+11]    [-5.71e+10, 4.29e+10]     1
# T9            9.792585e-01      2.511520e+00     -2.174763e+00      9.792585e+00     [9.79e+00, 2.73e+01]     [7.62e+00, 2.51e+01]     0
#
# [Iter 2] created=12 (cum=35), active=3, active+UB=3, ms_recomputed=0
# [Iter 2] EF-ipopt: ok=True, ef_obj=0.9796536619394399, true_obj=1.073400e+00, time=0.153s
# [Iter 2] Pre-split gap: 1.553430e-03 (0.016%)
# [Iter 2] Active simplex ratio = 0.000648
# [Iter 2] UB point (-9.999022057536129, -99.99947878853936, 0.3476234904818926) is geometrically in simplices [8, 9, 10, 11]
#   T8 verts=[9, 1, 4, 0]: λ=[1.000000, 0.000000, 0.000000, -0.000000], LB=9.789128024, c_s=[0.9960059485416161, 0.9451455956752572, 0.9562855603248932, 1.0545522879751763, 0.9683397473109455, 0.9427787571324385, 1.011125900417213, 0.946758319385733, 1.0107673033536582, 0.9573686036730439]
#   T9 verts=[8, 9, 4, 0]: λ=[0.000000, 1.000000, 0.000000, -0.000000], LB=9.792585320, c_s=[0.9962799762933386, 0.9452825841125264, 0.9572411326639916, 1.0545523617094508, 0.9683394501062152, 0.9427938418277491, 1.0127566647362078, 0.9468884223357369, 1.010841676361471, 0.9576092103371402]
#   T10 verts=[8, 1, 9, 0]: λ=[0.000000, 0.000000, 1.000000, -0.000000], LB=9.788494188, c_s=[0.9960764457501945, 0.9452229354478225, 0.9560865702052059, 1.0545523587026253, 0.9683968343587215, 0.9427924918133483, 1.0108402917765569, 0.9467148181384328, 1.010889662079762, 0.9569217797409603]
#   T11 verts=[8, 1, 4, 9]: λ=[0.000000, 0.000000, 0.000000, 1.000000], LB=9.789113478, c_s=[0.9960042755939317, 0.9451415231584118, 0.9560127778372718, 1.054552361731593, 0.9684356280801443, 0.9428500233282022, 1.0109000157104988, 0.9467131691070664, 1.0107730118754286, 0.9577306917237756]
#
# == [Iter 2] CS DUAL vs PRIMAL diagnostic (simplices containing UB point) ==
#   --- T8 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999028464402706, -99.99948220319044, 1.0004834530132063)
#              indep_Q(cs_K)=0.996005965
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999024865574523, -99.99948028513231, 0.633762715976422)
#              indep_Q(cs_K)=0.945145610
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.929863443145829, -99.99949254132785, 2.2852265824027866)
#              indep_Q(cs_K)=0.956285563
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.99901151131146, -99.99984311379745, 0.3476258135518927)
#              indep_Q(cs_K)=1.054552309
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999023000679479, -99.99947929120403, 0.4437298359579913)
#              indep_Q(cs_K)=0.968339755
#     scen 5: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999023473632224, -99.99947954327243, 0.49192373975233)
#              indep_Q(cs_K)=0.942778758
#     scen 6: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999043879482851, -99.99949041892576, 2.5712807415939207)
#              indep_Q(cs_K)=1.011125913
#     scen 7: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.998926037089538, -99.99947999660414, 0.5776150602307006)
#              indep_Q(cs_K)=0.946758322
#     scen 8: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.99902544005345, -99.99948059131086, 0.6923021418465423)
#              indep_Q(cs_K)=1.010767314
#     scen 9: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999023825960911, -99.99947973105213, 0.5278260471816993)
#              indep_Q(cs_K)=0.957368693
#   sum(c_s_dual)=0.000000000, UB_total=97.900476175, UB_per_scen=9.790047618
#
#   == Per-scenario Q_s at K_EF = (-9.999022057536129, -99.99947878853936, 0.3476234904818926) ==
# ...
#    1   T261       3  -4.6054e-02     1.68e-05    (-9.9977, -99.9967, 0.3449)
#    2   T261       5  -4.4845e-02     1.20e-01    (-9.9582, -99.9164, 0.4541)
#    3   T261       4  -4.4548e-02     2.44e-02    (-9.9963, -99.9940, 0.3999)
#    4   T261       0  -4.3982e-02     5.03e-01    (-9.9846, -99.9702, 0.8783)
#    5   T261       7  -4.3105e-02     4.64e-01    (-9.9856, -99.9721, 0.8387)
#    6   T261       1  -4.3008e-02     4.01e-01    (-9.9871, -99.9753, 0.7756)
#    7   T261       8  -4.2923e-02     2.77e-01    (-9.9902, -99.9815, 0.6518)
#    8   T261       9  -4.0612e-02     7.63e-01    (-9.9762, -99.9531, 1.2217)
#    9   T261       6  -3.9221e-02     1.25e-01    (-9.9607, -99.9213, 1.8580)
#   10   T261       2  -3.8076e-02     3.37e-01    (-9.9658, -99.9319, 1.6465)
#
# [Iter 88] per_tet=15, active after q_cut=5, tri_is_None=False
# [Iter 88] bad-quality active simplices (q < 0): 0
# [Iter 88] evaluating Q for scenario 0
# [Iter 88] evaluating Q for scenario 1
# [Iter 88] evaluating Q for scenario 2
# [Iter 88] evaluating Q for scenario 3
# [Iter 88] evaluating Q for scenario 4
# [Iter 88] evaluating Q for scenario 5
# [Iter 88] evaluating Q for scenario 6
# [Iter 88] evaluating Q for scenario 7
# [Iter 88] evaluating Q for scenario 8
# [Iter 88] evaluating Q for scenario 9
#
# [Iter 88] Next Point Details:
# Simplex   Scene   Type    As             ms             As+ms          Q              (Kp, Ki, Kd)
# --------------------------------------------------------------------------------------------------------------------
# T261      3       c_s     1.0546e+00     -4.6054e-02    1.0085e+00     1.0546e+00     (-9.9977, -99.9967, 0.3449)
#
# [Iter 88] subdivision type = interior (code=1) on simplex T261
# [Iter 88] Elapsed: 0.749s
# ======================================================================
# [Iter 88] LB SPLIT DIAGNOSTIC
#   Selected (parent) simplex: (8, 10, 13, 95)
#   Parent LB: 0.978799764 (per-scen)
#   EF ef_obj(IPOPT): 0.097900736, true_obj(recalc): 0.979007365, used=min=0.097900736 (per-scen)
#   Simplex volume: 1.664627e-04
#   Children (4):
#     T264 (8, 10, 13, 96): LB = 0.978799766
#   New global LB: 0.978799766 (from T264 (8, 10, 13, 96))
#   Location: INSIDE
#   Avg CS point Q-value: 0.979008574 (per-scen), point=(np.float64(-9.98025086983528), np.float64(-99.96124817946108), np.float64(0.906939878465279))
#   Current UB: 0.979004762 (per-scen)
#   UB point: (-9.998306873782116, -99.99802229697578, 0.37585780207052066)
#   UB source: avgCS_new_simplex
#   UB simplex: (0, 1, 4, 9)
#   EF-IPOPT: ok=True, status=ok, term=optimal, time=0.177s, ef_obj=0.9790073605915999, true_obj(per-scen)=0.979007365
# ======================================================================
#
# ======================================================================
# [TIMING] === Iter 88 phase breakdown (total 6.34s) ===
#   1_vertex_UB                    :       0.00s  (  0.0%)
#   2_evaluate_all_tetra           :       0.00s  (  0.1%)
#   3_active_filter_print          :       0.00s  (  0.0%)
#   4_LB_selection                 :       0.00s  (  0.0%)
#   5_EF_UB_solve                  :       0.64s  ( 10.1%)  #####
#   6_candidate_selection          :       0.00s  (  0.0%)
#   7_Q_eval_new_node              :       0.10s  (  1.6%)
#   8_mesh_subdivide               :       0.00s  (  0.0%)
#   9_end_of_iter_reeval           :       5.59s  ( 88.2%)  ############################################
#   TOTAL                          :       6.34s
#   #simplices=15, #scenarios=10, total_ms_pairs=150
#   fresh ms solves=0, cache hits=150
# ======================================================================
#
# [Iter 89] #simplices = 15, #active = 5, bad-quality cut = 0, bad-shape cut = 0
# == [Iter 89] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T8            9.789128e-01      4.086656e+09     -5.913344e+10      9.789128e+00     [9.79e+00, 1.00e+11]    [-5.91e+10, 4.09e+10]     1
# T10           9.789113e-01      4.394000e+09     -5.606000e+10      9.789113e+00     [9.79e+00, 1.00e+11]    [-5.61e+10, 4.39e+10]     1
# T11           9.789195e-01      4.151457e+09     -5.848543e+10      9.789195e+00     [9.79e+00, 1.00e+11]    [-5.85e+10, 4.15e+10]     1
# T12           9.788638e-01      4.132611e+09     -5.867389e+10      9.788638e+00     [9.80e+00, 1.00e+11]    [-5.87e+10, 4.13e+10]     1
# T264          9.787998e-01      1.179113e+00     -4.263749e-01      9.787998e+00     [9.79e+00, 1.22e+01]     [9.37e+00, 1.18e+01]     0
#
# == [Iter 89] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.031046e+00      4.639037e+09     -5.360963e+10      1.031046e+01     [2.23e+01, 1.00e+11]    [-5.36e+10, 4.64e+10]     1
# T1            1.024926e+00      4.371904e+09     -5.628096e+10      1.024926e+01     [2.21e+01, 1.00e+11]    [-5.63e+10, 4.37e+10]     1
# T2            1.000442e+00      4.209123e+09     -5.790877e+10      1.000442e+01     [2.21e+01, 1.00e+11]    [-5.79e+10, 4.21e+10]     1
# T3            1.020419e+00      4.317584e+09     -5.682416e+10      1.020419e+01     [2.71e+01, 1.00e+11]    [-5.68e+10, 4.32e+10]     2
# T4            1.015549e+00               inf               inf      1.015549e+01     [2.71e+01, 1.00e+11]               [inf, inf]     2
# T5            9.839627e-01      1.372149e+00     -1.356848e+01      9.839627e+00     [9.80e+00, 2.73e+01]    [-3.77e+00, 1.37e+01]     0
# T6            1.008365e+00      4.017814e+09     -5.982186e+10      1.008365e+01     [9.80e+00, 1.00e+11]    [-5.98e+10, 4.02e+10]     1
# T7            9.825628e-01      4.292210e+09     -5.707790e+10      9.825628e+00     [9.80e+00, 1.00e+11]    [-5.71e+10, 4.29e+10]     1
# T9            9.792585e-01      2.511520e+00     -2.174763e+00      9.792585e+00     [9.79e+00, 2.73e+01]     [7.62e+00, 2.51e+01]     0
# T19           9.792394e-01      2.140853e+00     -9.262532e-01      9.792394e+00     [9.79e+00, 2.23e+01]     [8.87e+00, 2.14e+01]     0
#
# [Iter 89] created=15 (cum=1427), active=5, active+UB=0, ms_recomputed=0
# [Iter 89] EF-ipopt: ok=True, ef_obj=0.9790073621426238, true_obj=9.790074e-01, time=0.171s
# [Iter 89] Pre-split gap: 2.049956e-03 (0.021%)
# [Iter 89] Active simplex ratio = 0.000648
# [Iter 89] UB point (-9.998306873782116, -99.99802229697578, 0.37585780207052066) is geometrically in simplices [10, 11]
#   T10 verts=[8, 1, 4, 9]: λ=[0.000935, 0.000283, 0.000000, 0.998782], LB=9.789113478, c_s=[0.9960042755939317, 0.9451415231584118, 0.9560127778372718, 1.054552361731593, 0.9684356280801443, 0.9428500233282022, 1.0109000157104988, 0.9467131691070664, 1.0107730118754286, 0.9577306917237756]
#   T11 verts=[10, 1, 9, 0]: λ=[0.017263, -0.000000, 0.982737, -0.000000], LB=9.789195263, c_s=[0.996006409775432, 0.9451860167997975, 0.9565645993942454, 1.0545523610900562, 0.9684393056440299, 0.9428851213255381, 1.0109069285468821, 0.9467460822530172, 1.0109893237753624, 0.956919113910664]
#
# == [Iter 89] CS DUAL vs PRIMAL diagnostic (simplices containing UB point) ==
#   --- T10 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999027447195733, -99.99948166105227, 0.896830021496215)
#              indep_Q(cs_K)=0.996004285
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.062596797165444, -99.99953012896741, 0.7983768355734024)
#              indep_Q(cs_K)=0.945141523
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999038579850618, -99.99948871579171, 1.9552186683763046)
#              indep_Q(cs_K)=0.956012781
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999018076338729, -99.99947598470527, 0.34897056554021433)
#              indep_Q(cs_K)=1.054552386
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999025920525563, -99.99948084738683, 0.741262269620894)
#              indep_Q(cs_K)=0.968435634
#     scen 5: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-7.48942143644345, -99.99960966933064, 0.27275157142410067)
#              indep_Q(cs_K)=0.942850088
#     scen 6: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.99904216720765, -99.99948888402339, 2.2778286709965863)
#              indep_Q(cs_K)=1.010900040
#     scen 7: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999026196205241, -99.99948099431512, 0.7693540399706714)
#              indep_Q(cs_K)=0.946713170
#     scen 8: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999024263260605, -99.99947996411862, 0.5723869035067319)
#              indep_Q(cs_K)=1.010773037
#     scen 9: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-0.13167587849078197, -100.0, 1.3043100996445007)
#              indep_Q(cs_K)=0.957714441
#   sum(c_s_dual)=0.000000000, UB_total=97.900476175, UB_per_scen=9.790047618
#
#   == Per-scenario Q_s at K_EF = (-9.998306873782116, -99.99802229697578, 0.37585780207052066) ==
#     scen 0: Q_s(K_EF)=0.996254846, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945263442, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.957186974, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054553569, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968338200, c_s_dual=N/A
#     scen 5: Q_s(K_EF)=0.942788265, c_s_dual=N/A
#     scen 6: Q_s(K_EF)=1.012692595, c_s_dual=N/A
#     scen 7: Q_s(K_EF)=0.946868105, c_s_dual=N/A
#     scen 8: Q_s(K_EF)=1.010829537, c_s_dual=N/A
#     scen 9: Q_s(K_EF)=0.957568449, c_s_dual=N/A
#     SUM Q_s(K_EF)=9.792343981, sum(c_s)=0.000000000, diff=9.792344e+00
#   --- T11 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.9934350155293, -99.98809570113453, 0.9018490126752552)
#              indep_Q(cs_K)=0.996006412
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.978417305352288, -99.95750722365804, 0.5187690553108169)
#              indep_Q(cs_K)=0.945186062
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.970154596338883, -99.94067869542522, 0.756827786692427)
#              indep_Q(cs_K)=0.956564691
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.99902208241631, -99.99947880179968, 0.34507051099931046)
#              indep_Q(cs_K)=1.054552537
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 0.03252109007591031)
#              indep_Q(cs_K)=0.968439306
#     scen 5: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.975970693057223, -99.95251738541154, 0.1211507114505258)
#              indep_Q(cs_K)=0.942885124
#     scen 6: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999041127952252, -99.99948895244962, 2.290899662423945)
#              indep_Q(cs_K)=1.010906939
#     scen 7: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999024647372181, -99.99948016883756, 0.6115278886943234)
#              indep_Q(cs_K)=0.946746083
#     scen 8: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999024315772234, -99.9994799921056, 0.11590369629511348)
#              indep_Q(cs_K)=1.010989326
#     scen 9: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999030348735188, -99.99948320747824, 1.192497008971435)
#              indep_Q(cs_K)=0.956919116
#   sum(c_s_dual)=0.000000000, UB_total=97.900476175, UB_per_scen=9.790047618
#
#   == Per-scenario Q_s at K_EF = (-9.998306873782116, -99.99802229697578, 0.37585780207052066) ==
#     scen 0: Q_s(K_EF)=0.996254846, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945263442, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.957186974, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054553569, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968338200, c_s_dual=N/A
#     scen 5: Q_s(K_EF)=0.942788265, c_s_dual=N/A
#     scen 6: Q_s(K_EF)=1.012692595, c_s_dual=N/A
#     scen 7: Q_s(K_EF)=0.946868105, c_s_dual=N/A
#     scen 8: Q_s(K_EF)=1.010829537, c_s_dual=N/A
#     scen 9: Q_s(K_EF)=0.957568449, c_s_dual=N/A
#     SUM Q_s(K_EF)=9.792343981, sum(c_s)=0.000000000, diff=9.792344e+00
#
# [Iter 89] LB = 9.787998 = UB(9.790048) + ms_b(-4.264e-01) from T264
# [Iter 89] Scene 0: Switched to c_s point. dist_ms_c=9.72e+00 < 1000.0, dist_c_verts=5.34e-01 > 1e-06
# [Iter 89] Scene 1: Switched to c_s point. dist_ms_c=9.56e+00 < 1000.0, dist_c_verts=4.36e-01 > 1e-06
# [Iter 89] Scene 2: Switched to c_s point. dist_ms_c=1.04e+01 < 1000.0, dist_c_verts=3.36e-01 > 1e-06
# [Iter 89] Scene 3: Switched to c_s point. dist_ms_c=9.02e+00 < 1000.0, dist_c_verts=1.68e-05 > 1e-06
# [Iter 89] Scene 4: Switched to c_s point. dist_ms_c=9.20e+00 < 1000.0, dist_c_verts=5.51e-02 > 1e-06
# [Iter 89] Scene 5: Switched to c_s point. dist_ms_c=9.16e+00 < 1000.0, dist_c_verts=1.09e-01 > 1e-06
# [Iter 89] Scene 6: Switched to c_s point. dist_ms_c=1.08e+01 < 1000.0, dist_c_verts=1.16e-01 > 1e-06
# [Iter 89] Scene 7: Switched to c_s point. dist_ms_c=9.59e+00 < 1000.0, dist_c_verts=6.15e-01 > 1e-06
# [Iter 89] Scene 8: Switched to c_s point. dist_ms_c=9.50e+00 < 1000.0, dist_c_verts=3.07e-01 > 1e-06
# [Iter 89] Scene 9: Switched to c_s point. dist_ms_c=9.85e+00 < 1000.0, dist_c_verts=7.63e-01 > 1e-06
# Chosen node (-9.997671805420183, -99.99672831982065, 0.3448522909753579) with ms=-4.605e-02 (simp T264, scene 3, rank #1, source=c_s)
# [Iter 89] LB simplex = T264, next node simplex = T264, scene 3
# [Selected Simp Info] Iter 89 | Simplex T264 Vertices:
#   v0: (-9.997679186606327, -99.99674335391862, 0.34485196601555224)
#   v1: (-9.233467561678685, -98.4408518452537, 0.32994040845543465)
#   v2: (-9.969398658088817, -99.9387405510254, -26.409218061864642)
#   v3: (-9.95759225435638, -99.91510584455915, 1.983205918616312)
#   -> New Point: (-9.997671805420183, -99.99672831982065, 0.3448522909753579)
# [Iter 89] candidate rank #1: T264, scene=3, ms=-4.605e-02
# == ms candidates (sorted by (ms, -dist)) ==
# rank   simp   scene           ms    mind(all)                             pt
# ----------------------------------------------------------------------------
#    1   T264       3  -4.6054e-02     1.68e-05    (-9.9977, -99.9967, 0.3449)
#    2   T264       5  -4.4845e-02     7.86e-02    (-9.9950, -99.9913, 0.4541)
#    3   T264       4  -4.4548e-02     2.44e-02    (-9.9963, -99.9940, 0.3999)
#    4   T264       0  -4.3982e-02     5.03e-01    (-9.9846, -99.9702, 0.8783)
#    5   T264       7  -4.3105e-02     5.91e-01    (-9.8369, -99.6693, 0.8395)
#    6   T264       1  -4.3008e-02     4.06e-01    (-9.9870, -99.9750, 0.7806)
#    7   T264       8  -4.2923e-02     2.77e-01    (-9.9902, -99.9814, 0.6518)
#    8   T264       9  -4.0612e-02     7.63e-01    (-9.9762, -99.9530, 1.2217)
#    9   T264       6  -3.9221e-02     1.16e-01    (-9.9604, -99.9209, 1.8676)
#   10   T264       2  -3.8076e-02     3.36e-01    (-9.9658, -99.9318, 1.6478)
#
# [Iter 89] per_tet=15, active after q_cut=5, tri_is_None=False
# [Iter 89] bad-quality active simplices (q < 0): 0
# [Iter 89] evaluating Q for scenario 0
# [Iter 89] evaluating Q for scenario 1
# [Iter 89] evaluating Q for scenario 2
# [Iter 89] evaluating Q for scenario 3
# [Iter 89] evaluating Q for scenario 4
# [Iter 89] evaluating Q for scenario 5
# [Iter 89] evaluating Q for scenario 6
# [Iter 89] evaluating Q for scenario 7
# [Iter 89] evaluating Q for scenario 8
# [Iter 89] evaluating Q for scenario 9
#
# [Iter 89] Next Point Details:
# Simplex   Scene   Type    As             ms             As+ms          Q              (Kp, Ki, Kd)
# --------------------------------------------------------------------------------------------------------------------
# T264      3       c_s     1.0546e+00     -4.6054e-02    1.0085e+00     1.0546e+00     (-9.9977, -99.9967, 0.3449)
#
# [Iter 89] subdivision type = interior (code=1) on simplex T264
# [Iter 89] Elapsed: 0.842s
