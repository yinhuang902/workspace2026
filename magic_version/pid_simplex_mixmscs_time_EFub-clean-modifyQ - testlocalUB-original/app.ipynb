# %%
from time import perf_counter  

from modeling import build_models_from_csv
from bundles import BaseBundle, MSBundle
from utils import (
    tighten_bounds_one_model,
    MIN_DIST, ACTIVE_TOL, GAP_STOP_TOL,
)
from simplex_specialstart import run_pid_simplex_3d

# setup scenario number and target_nodesk
csv_path       = "data.csv"
max_scenarios  = 5
target_nodes   = 1000

bounds={
    "Kp": (-10.0, 10.0),
    "Ki": (-100.0, 100.0),
    "Kd": (-100.0, 100.0),
    "x": (-2.5, 2.5),
    "u": (-5.0, 5.0),
    "e": (None, None),
    "I": (None, None),
}

weights = (10.0, 0.01)


# ====== stage 1：load data and generate models ======
T   = 15.0          
nfe = 20            

t_load0 = perf_counter()
model_list, first_stg_vars_list, m_tmpl_list, nfe = build_models_from_csv(
    csv_path=csv_path,
    T=T,
    nfe=nfe,
    weights=weights,
    bounds=bounds,
    sp0=0.0,
    sp1=0.5,
    tau_xs_col="tau_xs",
    tau_us_col="tau_us",
    tau_ds_col="tau_ds",          
    disturb_prefix="disturbance_",
    setpoint_change_col="setpoint_change",
    max_scenarios=max_scenarios,
    skip=0,
)
t_load1 = perf_counter()
print(f"[Time] Data load & scenario build: {t_load1 - t_load0:.3f}s")


# ====== stage 1.5：FBBT / OBBT ======
# same as snog: FBBT open,OBBT open
obbt_solver_opts = {
    "NonConvex": 2,
    "MIPGap": 1,     
    "TimeLimit": 15   
}
for m, yvars in zip(model_list, first_stg_vars_list):
    tighten_bounds_one_model(m, yvars,
                             use_fbbt=False,
                             use_obbt=False,
                             obbt_solver_name="gurobi",
                             obbt_solver_opts=obbt_solver_opts,
                             max_rounds=3, tol=1e-6, verbose=True)

# ====== stage 2: Persistent Solver Packaging ======
ub_options = {
    'NonConvex': 2,      
}
lb_options = {
    'NonConvex': 2,
    'MIPGap': 1e-1,            
    'TimeLimit': 15
}

t_wrap0 = perf_counter()
base_bundles = [BaseBundle(m, ub_options) for m in model_list]  
ms_bundles   = [MSBundle(m, yvars, lb_options) for m, yvars in zip(model_list, first_stg_vars_list)]  
t_wrap1 = perf_counter()
print(f"[Time] Persistent wrapper (GurobiPersistent) setup: {t_wrap1 - t_wrap0:.3f}s")

# ====== stage 3：main loop ======
agg_bundle = None  

t_run0 = perf_counter()
hist = run_pid_simplex_3d(
    base_bundles=base_bundles,
    ms_bundles=ms_bundles,
    model_list=model_list,
    first_vars_list=first_stg_vars_list,
    target_nodes=target_nodes,
    min_dist=0,
    active_tol=ACTIVE_TOL,
    verbose=True,
    agg_bundle=agg_bundle,
    gap_stop_tol=1e-6,
    use_exact_opt=False,
    exact_solver_name="gurobi",
    exact_solver_opts={"NonConvex": 2, "TimeLimit": 60},
    time_limit=60*60*2,
    enable_3d_plot=False,   
    plot_every=None,        
)
t_run1 = perf_counter()
print(f"[Time] Main loop total: {t_run1 - t_run0:.3f}s")

# ====== print output ======
print("\n==== Done ====")
print(f"Total nodes: {len(hist['nodes'])}")
print(f"Best UB: {min(hist['UB_hist']) if hist['UB_hist'] else None}")
print(f"Last LB: {hist['LB_hist'][-1] if hist['LB_hist'] else None}")
# Out:
# [Time] Data load & scenario build: 0.017s
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# Set parameter Username
# Set parameter LicenseID to value 2689755
# Academic license - for non-commercial use only - expires 2026-07-21
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 15
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 15
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 15
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 15
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 15
# [Time] Persistent wrapper (GurobiPersistent) setup: 1.654s
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=warning, term=other
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [TIMING] Pre-loop vertex Q evals: 0.95s  (8 nodes x 5 scenarios = 40 solves)
# [EF-UB] Initialized ipopt EF with 5 scenarios, time_ub=60.0s
#
# ======================================================================
# [TIMING] === Pre-loop phase summary ===
#   corners_and_mesh               :       0.00s
#   vertex_Q_evals                 :       0.95s
#   exact_optima                   :       0.00s
#   ef_init                        :       0.03s
#   TOTAL                          :       0.98s
# ======================================================================
#
# [Iter 0] MIPGap overridden to 0.1 (original: 0.1)
# Discarded solution information
# Discarded solution information
# [Invariant] MS scen None: dual=-5.482342e+09 > primal=-5.482342e+09
# Discarded solution information
# [Invariant] MS scen None: dual=-5.520747e+09 > primal=-5.520747e+09
# Discarded solution information
# Discarded solution information
# [Invariant] MS scen None: dual=-5.782267e+09 > primal=-5.782267e+09
# [Invariant] MS scen None: dual=-5.879453e+09 > primal=-5.879453e+09
# [Invariant] MS scen None: dual=-5.752537e+09 > primal=-5.752537e+09
# [Invariant] MS scen None: dual=-5.673500e+09 > primal=-5.673500e+09
# [Invariant] MS scen None: dual=-5.786091e+09 > primal=-5.786091e+09
# [Invariant] MS scen None: dual=-5.607264e+09 > primal=-5.607264e+09
# [Invariant] MS scen None: dual=-5.626301e+09 > primal=-5.626301e+09
# [Invariant] MS scen None: dual=-5.742972e+09 > primal=-5.742972e+09
# [Bundle] MS scen None: infeasibleOrUnbounded. ms_val=nan.
# [Bundle] MS scen None: not optimal. Status=warning, Term=infeasibleOrUnbounded.
# [Invariant] MS scen None: dual=-5.810805e+09 > primal=-5.810805e+09
# [Invariant] MS scen None: dual=-5.868426e+09 > primal=-5.868426e+09
# [Iter 0] MIPGap restored to 0.1
# [Iter 0] #simplices = 6, #active = 6, bad-quality cut = 0, bad-shape cut = 0
# == [Iter 0] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.000986e+00      4.574690e+09     -2.712655e+10      5.004929e+00     [1.12e+01, 5.00e+10]    [-2.71e+10, 2.29e+10]     1
# T1            9.956027e-01      4.060486e+09     -2.969757e+10      4.978014e+00     [1.12e+01, 5.00e+10]    [-2.97e+10, 2.03e+10]     1
# T2            1.025007e+00      4.471772e+09     -2.764114e+10      5.125034e+00     [1.11e+01, 5.00e+10]    [-2.76e+10, 2.24e+10]     1
# T3            1.006635e+00      4.219633e+09     -2.890183e+10      5.033173e+00     [1.11e+01, 5.00e+10]    [-2.89e+10, 2.11e+10]     1
# T4            1.123946e+00      4.332879e+09     -2.833561e+10      5.619732e+00     [1.36e+01, 5.00e+10]    [-2.83e+10, 2.17e+10]     2
# T5            1.039181e+00               inf               inf      5.195905e+00     [1.36e+01, 5.00e+10]               [inf, inf]     2
#
# == [Iter 0] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
#   (none)
# [Iter 0] created=6 (cum=6), active=6, active+UB=2, ms_recomputed=6
# [Iter 0] UB-simplex selection: UB_node in simplices [2, 3], chose T3 (LB=1.006634653)
# [Iter 0] EF-ipopt: ok=False, ef_obj=nan, true_obj=N/A, time=1.548s
# [Iter 0] EF-UB: both solvers failed
# [Iter 0] Pre-split gap: 6.141461e+00 (55.232%)
# [Iter 0] Active simplex ratio = 1.000000
# [Iter 0] UB point (10.0, 100.0, 100.0) is geometrically in simplices [2, 3]
#   T2 verts=[3, 5, 7, 4]: λ=[0.000000, -0.000000, 1.000000, -0.000000], LB=5.125034445, c_s=[1.0619646213750884, 0.9701148580842887, 1.012319954298818, 1.0687384131728885, 1.0118965983842654]
#   T3 verts=[3, 6, 7, 4]: λ=[0.000000, -0.000000, 1.000000, -0.000000], LB=5.033173265, c_s=[0.9973765252125791, 0.9632727899553029, 0.9559885161504325, 1.147424038906536, 0.9691113942881817]
#
# == [Iter 0] CS DUAL vs PRIMAL diagnostic (simplices containing UB point) ==
#   --- T2 ---
#     scen 0: status=optimal, dual=1.061964621, primal=1.061964621  ✓ dual ≤ primal (gap=4.440892e-16)
#              cs_primal_K=(10.0, -100.0, -6.61954562903385)
#              indep_Q(cs_K)=1.061964627  → dual ≤ indep_Q (consistent, diff=5.395622e-09)
#     scen 1: status=optimal, dual=0.970114858, primal=0.970114858  ✓ dual ≤ primal (gap=-2.220446e-16)
#              cs_primal_K=(9.999999594206525, 0.9866207247408044, 1.0643934752246185)
#              indep_Q(cs_K)=0.970115257  → dual ≤ indep_Q (consistent, diff=3.989788e-07)
#     scen 2: status=optimal, dual=1.012319954, primal=1.012319954  ✓ dual ≤ primal (gap=-2.220446e-16)
#              cs_primal_K=(3.4160765728331377, -34.16076572833138, -0.1333514170148284)
#              indep_Q(cs_K)=1.012320002  → dual ≤ indep_Q (consistent, diff=4.733003e-08)
#     scen 3: status=optimal, dual=1.068738413, primal=1.068738413  ✓ dual ≤ primal (gap=-4.440892e-16)
#              cs_primal_K=(9.999947658154277, -99.99909920111641, 5.505484866903614e-09)
#              indep_Q(cs_K)=1.068738413  → dual ≤ indep_Q (consistent, diff=1.037235e-10)
#     scen 4: status=optimal, dual=1.011896598, primal=1.011896598  ✓ dual ≤ primal (gap=0.000000e+00)
#              cs_primal_K=(3.9605368283930398, -39.605368283930396, 0.001976599330060753)
#              indep_Q(cs_K)=1.011896608  → dual ≤ indep_Q (consistent, diff=9.564114e-09)
#   sum(c_s_dual)=5.125034445, UB_total=55.597371111, UB_per_scen=11.119474222
#
#   == Per-scenario Q_s at K_EF = (10.0, 100.0, 100.0) ==
#     scen 0: Q_s(K_EF)=2.194572859, c_s_dual=1.061964621  ✓ Q_s(K_EF) > c_s_dual (diff=1.132608e+00)
#     scen 1: Q_s(K_EF)=2.178377902, c_s_dual=0.970114858  ✓ Q_s(K_EF) > c_s_dual (diff=1.208263e+00)
#     scen 2: Q_s(K_EF)=2.188377472, c_s_dual=1.012319954  ✓ Q_s(K_EF) > c_s_dual (diff=1.176058e+00)
#     scen 3: Q_s(K_EF)=2.339403430, c_s_dual=1.068738413  ✓ Q_s(K_EF) > c_s_dual (diff=1.270665e+00)
#     scen 4: Q_s(K_EF)=2.218742559, c_s_dual=1.011896598  ✓ Q_s(K_EF) > c_s_dual (diff=1.206846e+00)
#     SUM Q_s(K_EF)=11.119474222, sum(c_s)=5.125034445, diff=5.994440e+00
#   --- T3 ---
#     scen 0: status=optimal, dual=0.997376525, primal=0.997376525  ✓ dual ≤ primal (gap=-1.110223e-16)
#              cs_primal_K=(9.99923165569858, 99.99864221309052, 1.395794796781228)
#              indep_Q(cs_K)=0.997376525  → dual ≤ indep_Q (consistent, diff=5.538170e-11)
#     scen 1: status=optimal, dual=0.963272790, primal=0.963272790  ✓ dual ≤ primal (gap=-1.110223e-16)
#              cs_primal_K=(9.999999436980861, 2.2542349630472027, 0.9570637044372343)
#              indep_Q(cs_K)=0.963272793  → dual ≤ indep_Q (consistent, diff=3.538892e-09)
#     scen 2: status=optimal, dual=0.955988516, primal=0.955988516  ✓ dual ≤ primal (gap=-2.220446e-16)
#              cs_primal_K=(9.993045203208826, 99.9903288635917, 2.0319550327665548)
#              indep_Q(cs_K)=0.955988518  → dual ≤ indep_Q (consistent, diff=1.879947e-09)
#     scen 3: status=optimal, dual=1.147424039, primal=1.147424039  ✓ dual ≤ primal (gap=1.110223e-15)
#              cs_primal_K=(4.46578295802099, 64.95101740451302, -1.7866386940385905)
#              indep_Q(cs_K)=1.147424132  → dual ≤ indep_Q (consistent, diff=9.354697e-08)
#     scen 4: status=optimal, dual=0.969111394, primal=0.969111394  ✓ dual ≤ primal (gap=0.000000e+00)
#              cs_primal_K=(9.998630746909807, 99.99755347536319, 0.6671121890397128)
#              indep_Q(cs_K)=0.969111395  → dual ≤ indep_Q (consistent, diff=2.146726e-10)
#   sum(c_s_dual)=5.033173265, UB_total=55.597371111, UB_per_scen=11.119474222
#
#   == Per-scenario Q_s at K_EF = (10.0, 100.0, 100.0) ==
#     scen 0: Q_s(K_EF)=2.194572859, c_s_dual=0.997376525  ✓ Q_s(K_EF) > c_s_dual (diff=1.197196e+00)
#     scen 1: Q_s(K_EF)=2.178377902, c_s_dual=0.963272790  ✓ Q_s(K_EF) > c_s_dual (diff=1.215105e+00)
#     scen 2: Q_s(K_EF)=2.188377472, c_s_dual=0.955988516  ✓ Q_s(K_EF) > c_s_dual (diff=1.232389e+00)
#     scen 3: Q_s(K_EF)=2.339403430, c_s_dual=1.147424039  ✓ Q_s(K_EF) > c_s_dual (diff=1.191979e+00)
#     scen 4: Q_s(K_EF)=2.218742559, c_s_dual=0.969111394  ✓ Q_s(K_EF) > c_s_dual (diff=1.249631e+00)
#     SUM Q_s(K_EF)=11.119474222, sum(c_s)=5.033173265, diff=6.086301e+00
#
# [Iter 0] LB = 4.978014 = UB(11.119474) + ms_b(-2.890e+10) from T3
# [Iter 0] Scene 0: Switched to c_s point. dist_ms_c=1.85e+01 < 1000.0, dist_c_verts=9.86e+01 > 1e-06
# [Iter 0] Scene 1: Switched to c_s point. dist_ms_c=9.94e+01 < 1000.0, dist_c_verts=1.39e+02 > 1e-06
# [Iter 0] Scene 2: Switched to c_s point. dist_ms_c=1.90e+01 < 1000.0, dist_c_verts=9.80e+01 > 1e-06
# [Iter 0] Scene 3: Switched to c_s point. dist_ms_c=3.70e+01 < 1000.0, dist_c_verts=1.04e+02 > 1e-06
# [Iter 0] Scene 4: Switched to c_s point. dist_ms_c=1.82e+01 < 1000.0, dist_c_verts=9.93e+01 > 1e-06
# Chosen node (9.993045203208826, 99.9903288635917, 2.0319550327665548) with ms=-5.849e+09 (simp T3, scene 2, rank #1, source=c_s)
# [Iter 0] LB simplex = T3, next node simplex = T3, scene 2
# [Selected Simp Info] Iter 0 | Simplex T3 Vertices:
#   v0: (-10.0, 100.0, 100.0)
#   v1: (10.0, 100.0, -100.0)
#   v2: (10.0, 100.0, 100.0)
#   v3: (10.0, -100.0, -100.0)
#   -> New Point: (9.993045203208826, 99.9903288635917, 2.0319550327665548)
# [Iter 0] candidate rank #1: T3, scene=2, ms=-5.849e+09
# == ms candidates (sorted by (ms, -dist)) ==
# rank   simp   scene           ms    mind(all)                             pt
# ----------------------------------------------------------------------------
#    1     T3       2  -5.8491e+09     9.80e+01      (9.9930, 99.9903, 2.0320)
#    2     T3       0  -5.8406e+09     9.86e+01      (9.9992, 99.9986, 1.3958)
#    3     T3       4  -5.7861e+09     9.93e+01      (9.9986, 99.9976, 0.6671)
#    4     T3       1  -5.7525e+09     1.39e+02      (10.0000, 2.2542, 0.9571)
#    5     T3       3  -5.6735e+09     1.04e+02     (4.4658, 64.9510, -1.7866)
#
# [Iter 0] per_tet=6, active after q_cut=6, tri_is_None=False
# [Iter 0] bad-quality active simplices (q < 0): 0
# [Iter 0] evaluating Q for scenario 0
# [Iter 0] evaluating Q for scenario 1
# [Iter 0] evaluating Q for scenario 2
# [Iter 0] evaluating Q for scenario 3
# [Iter 0] evaluating Q for scenario 4
#
# [Iter 0] Next Point Details:
# Simplex   Scene   Type    As             ms             As+ms          Q              (Kp, Ki, Kd)
# --------------------------------------------------------------------------------------------------------------------
# T3        2       c_s     4.8979e+09     -5.8491e+09    -9.5116e+08    9.5599e-01     (9.9930, 99.9903, 2.0320)
#
# [Iter 0] subdivision type = interior (code=1) on simplex T3
# [Iter 0] Elapsed: 58.245s
# [Invariant] MS scen None: dual=-5.878357e+09 > primal=-5.878357e+09
# [Invariant] MS scen None: dual=-5.902921e+09 > primal=-5.902921e+09
# [Invariant] MS scen None: dual=-5.673056e+09 > primal=-5.673056e+09
# [Invariant] MS scen None: dual=-5.731268e+09 > primal=-5.731268e+09
# [Invariant] MS scen None: dual=-5.673635e+09 > primal=-5.673635e+09
# ======================================================================
# [Iter 0] LB SPLIT DIAGNOSTIC
#   Selected (parent) simplex: (3, 4, 6, 7)
#   Parent LB: 1.006634653 (per-scen)
#   UB in parent (pre-split): True  λ=[0.00000000, -0.00000000, 1.00000000, -0.00000000]
#   EF: N/A
#   Simplex volume: 1.333333e+05
#   Children (4):
#     T5 (4, 6, 7, 8): LB = 1.005686509, avg_cs = 1.005686509
#     T6 (3, 4, 7, 8): LB = 1.018612604, avg_cs = 1.018612604
#     T7 (3, 4, 6, 8): LB = 0.995120642, avg_cs = 0.995120642
#     T8 (3, 6, 7, 8): LB = 0.987736176, avg_cs = 0.987736176
#   New global LB: 0.987736176 (from T8 (3, 6, 7, 8))
#   Location: INSIDE
#   Avg CS point Q-value: 0.993777731 (per-scen), point=(np.float64(8.891338000163813), np.float64(73.43835538392112), np.float64(0.6530574057972279))
#   Current UB: 2.223894844 (per-scen)
#   UB point: (10.0, 100.0, 100.0)
#   UB source: unknown
#   UB simplex: None
#   EF-IPOPT: ok=False, status=warning, term=infeasible, time=1.548s, ef_obj=nan, true_obj(per-scen)=N/A
#   UB in child simplex (post-split): True
#     CHILD: T5 (4, 6, 7, 8) (LB=1.005686509, λ=[0.00000000, -0.00000000, 1.00000000, 0.00000000])
#     CHILD: T6 (3, 4, 7, 8) (LB=1.018612604, λ=[0.00000000, -0.00000000, 1.00000000, -0.00000000])
#     CHILD: T8 (3, 6, 7, 8) (LB=0.987736176, λ=[0.00000000, -0.00000000, 1.00000000, -0.00000000])
#     OLD:   T2 (3, 4, 5, 7) (LB=1.025006889, λ=[0.00000000, -0.00000000, 1.00000000, -0.00000000])
# ======================================================================
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -17.451227624085988): status=warning, term=infeasibleOrUnbounded
# [Iter 0] UB candidate from new simplex 5 (avgCS): 9.924050e-01 (per scenario)
# [BaseBundle.eval_at] Infeasible/Error for K=(1.343055760671519, 99.99999999425626, -13.43049705066646): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(3.302158982934305, 99.9999999999801, -15.51915017365572): status=warning, term=infeasibleOrUnbounded
# [Iter 0] UB candidate from new simplex 8 (avgCS): 9.882503e-01 (per scenario)
#
# ======================================================================
# [TIMING] === Iter 0 phase breakdown (total 154.39s) ===
#   1_vertex_UB                    :       0.00s  (  0.0%)
#   2_evaluate_all_tetra           :      56.35s  ( 36.5%)  ##################
#   3_active_filter_print          :       0.00s  (  0.0%)
#   4_LB_selection                 :       0.00s  (  0.0%)
#   5_EF_UB_solve                  :       1.81s  (  1.2%)
#   6_candidate_selection          :       0.00s  (  0.0%)
#   7_Q_eval_new_node              :       0.08s  (  0.1%)
#   8_mesh_subdivide               :       0.00s  (  0.0%)
#   9_end_of_iter_reeval           :      96.14s  ( 62.3%)  ###############################
#   TOTAL                          :     154.39s
#   #simplices=6, #scenarios=5, total_ms_pairs=30
#   fresh ms solves=30, cache hits=0
# ======================================================================
#
# [Iter 1] #simplices = 9, #active = 1, bad-quality cut = 0, bad-shape cut = 0
# == [Iter 1] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T8            9.877362e-01      4.224043e+09     -2.887979e+10      4.938681e+00     [4.94e+00, 5.00e+10]    [-2.89e+10, 2.11e+10]     1
#
# == [Iter 1] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.000986e+00      4.574690e+09     -2.712655e+10      5.004929e+00     [1.12e+01, 5.00e+10]    [-2.71e+10, 2.29e+10]     1
# T1            9.956027e-01      4.060486e+09     -2.969757e+10      4.978014e+00     [1.12e+01, 5.00e+10]    [-2.97e+10, 2.03e+10]     1
# T2            1.025007e+00      4.471772e+09     -2.764114e+10      5.125034e+00     [1.11e+01, 5.00e+10]    [-2.76e+10, 2.24e+10]     1
# T3            1.123946e+00      4.332879e+09     -2.833561e+10      5.619732e+00     [1.36e+01, 5.00e+10]    [-2.83e+10, 2.17e+10]     2
# T4            1.039181e+00               inf               inf      5.195905e+00     [1.36e+01, 5.00e+10]               [inf, inf]     2
# T5            1.005687e+00      4.127439e+09     -2.936281e+10      5.028433e+00     [4.94e+00, 5.00e+10]    [-2.94e+10, 2.06e+10]     1
# T6            1.018613e+00      1.391250e+00     -6.683287e+00      5.093063e+00     [4.94e+00, 1.36e+01]    [-1.74e+00, 6.96e+00]     0
# T7            9.951206e-01      4.328478e+09     -2.835761e+10      4.975603e+00     [4.94e+00, 5.00e+10]    [-2.84e+10, 2.16e+10]     1
#
# [Iter 1] created=9 (cum=19), active=1, active+UB=1, ms_recomputed=0
# [Iter 1] UB-simplex selection: UB_node in simplices [5, 6, 7, 8], chose T8 (LB=0.987736176)
# [Iter 1] EF-ipopt: ok=True, ef_obj=0.9890592459943466, true_obj=1.082808e+00, time=1.426s
# [Iter 1] Pre-split gap: 2.570421e-03 (0.052%)
# [Iter 1] Active simplex ratio = 0.000008
# [Iter 1] UB point (9.993045203208826, 99.9903288635917, 2.0319550327665548) is geometrically in simplices [5, 6, 7, 8]
#   T5 verts=[8, 6, 7, 4]: λ=[1.000000, -0.000000, 0.000000, 0.000000], LB=5.028432544, c_s=[0.9973769506449589, 0.9452014962811051, 1.0245790965070065, 1.0921635046417981, 0.9691114963492606]
#   T6 verts=[3, 8, 7, 4]: λ=[0.000000, 1.000000, 0.000000, -0.000000], LB=5.093063018, c_s=[1.0617851082727405, 0.9460209522710308, 0.9613896633164892, 1.070715702147588, 1.0531515915427918]
#   T7 verts=[3, 6, 8, 4]: λ=[0.000000, -0.000000, 1.000000, 0.000000], LB=4.975603208, c_s=[0.9991217757689878, 0.9620830306798327, 0.9583854838865904, 1.074967104962017, 0.9810458122214656]
#   T8 verts=[3, 6, 7, 8]: λ=[0.000000, -0.000000, 0.000000, 1.000000], LB=4.938680882, c_s=[0.9973783713134937, 0.9455041502905644, 0.9559915674037619, 1.0701042769095899, 0.9697025162185301]
#
# == [Iter 1] CS DUAL vs PRIMAL diagnostic (simplices containing UB point) ==
#   --- T5 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.998033675753613, 99.9972592588862, 1.3958140796520118)
#              indep_Q(cs_K)=0.997376951
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.998496652185112, 99.99778327447453, 0.8992708742191792)
#              indep_Q(cs_K)=0.945201497
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.998386425522307, 22.10948784185654, -0.6177228352710529)
#              indep_Q(cs_K)=1.024579168
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.994414283554141, 77.5170124725964, -1.1578526791596222)
#              indep_Q(cs_K)=1.092163515
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.997986478133914, 99.99719287601873, 0.6671224011826632)
#              indep_Q(cs_K)=0.969111497
#   sum(c_s_dual)=0.000000000, UB_total=24.706256518, UB_per_scen=4.941251304
#
#   == Per-scenario Q_s at K_EF = (9.993045203208826, 99.9903288635917, 2.0319550327665548) ==
#     scen 0: Q_s(K_EF)=0.997699827, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.946195233, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.955988518, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.070978040, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.970568348, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.941429966, sum(c_s)=0.000000000, diff=4.941430e+00
#   --- T6 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(7.507778421286112, 68.51000037466231, 0.0)
#              indep_Q(cs_K)=1.061785108
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.99324498156313, 95.13633810501062, -0.008155852411067222)
#              indep_Q(cs_K)=0.946020960
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.994015405512764, 84.24258469532647, -0.050481171177406324)
#              indep_Q(cs_K)=0.961389670
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.993083030184579, 98.8964547253114, 1.4738797460251147)
#              indep_Q(cs_K)=1.070715704
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(7.5386160227135175, 16.137961341500645, -0.36385224398083393)
#              indep_Q(cs_K)=1.053151595
#   sum(c_s_dual)=0.000000000, UB_total=24.706256518, UB_per_scen=4.941251304
#
#   == Per-scenario Q_s at K_EF = (9.993045203208826, 99.9903288635917, 2.0319550327665548) ==
#     scen 0: Q_s(K_EF)=0.997699827, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.946195233, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.955988518, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.070978040, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.970568348, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.941429966, sum(c_s)=0.000000000, diff=4.941430e+00
#   --- T7 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.993183753590436, 99.99052152768817, -0.0006803886125672228)
#              indep_Q(cs_K)=0.999121884
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(5.071140501589126, 46.90377893563921, -0.9262897458072619)
#              indep_Q(cs_K)=0.962083032
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(3.424875621608243, 58.41452119097115, 1.6676768139286249)
#              indep_Q(cs_K)=0.958385560
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.192267450740088, 91.12763178979797, 1.4355534887196468)
#              indep_Q(cs_K)=1.074967108
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(5.881358576403716, 55.83257412105498, -0.3424334893473854)
#              indep_Q(cs_K)=0.981045813
#   sum(c_s_dual)=0.000000000, UB_total=24.706256518, UB_per_scen=4.941251304
#
#   == Per-scenario Q_s at K_EF = (9.993045203208826, 99.9903288635917, 2.0319550327665548) ==
#     scen 0: Q_s(K_EF)=0.997699827, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.946195233, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.955988518, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.070978040, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.970568348, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.941429966, sum(c_s)=0.000000000, diff=4.941430e+00
#   --- T8 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.992758530279694, 100.0, 1.3683248538778885)
#              indep_Q(cs_K)=0.997378375
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(0.01751990384739394, 99.99992258749859, 0.6409578894551288)
#              indep_Q(cs_K)=0.945503866
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.993049432149812, 99.99033474423298, 1.969913375834067)
#              indep_Q(cs_K)=0.955991633
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.99480504284134, 99.99277604496217, 1.1672255523086479)
#              indep_Q(cs_K)=1.070104337
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.92709311961624, 99.99955340165522, -0.14528781885233658)
#              indep_Q(cs_K)=0.969702516
#   sum(c_s_dual)=0.000000000, UB_total=24.706256518, UB_per_scen=4.941251304
#
#   == Per-scenario Q_s at K_EF = (9.993045203208826, 99.9903288635917, 2.0319550327665548) ==
#     scen 0: Q_s(K_EF)=0.997699827, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.946195233, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.955988518, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.070978040, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.970568348, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.941429966, sum(c_s)=0.000000000, diff=4.941430e+00
#
# [Iter 1] LB = 4.938681 = UB(4.941251) + ms_b(-2.888e+10) from T8
# [Iter 1] Scene 0: Switched to c_s point. dist_ms_c=1.86e+01 < 1000.0, dist_c_verts=6.64e-01 > 1e-06
# [Iter 1] Scene 1: Switched to c_s point. dist_ms_c=1.73e+01 < 1000.0, dist_c_verts=1.01e+01 > 1e-06
# [Iter 1] Scene 2: Switched to c_s point. dist_ms_c=1.88e+01 < 1000.0, dist_c_verts=6.20e-02 > 1e-06
# [Iter 1] Scene 3: Switched to c_s point. dist_ms_c=1.61e+01 < 1000.0, dist_c_verts=8.65e-01 > 1e-06
# [Iter 1] Scene 4: Switched to c_s point. dist_ms_c=1.74e+01 < 1000.0, dist_c_verts=2.18e+00 > 1e-06
# Chosen node (0.017519903848822807, 99.99992258749859, 0.6409578894693698) with ms=-5.815e+09 (simp T8, scene 1, rank #1, source=c_s)
# [Iter 1] LB simplex = T8, next node simplex = T8, scene 1
# [Selected Simp Info] Iter 1 | Simplex T8 Vertices:
#   v0: (-10.0, 100.0, 100.0)
#   v1: (10.0, 100.0, -100.0)
#   v2: (10.0, 100.0, 100.0)
#   v3: (9.993045203208826, 99.9903288635917, 2.0319550327665548)
#   -> New Point: (0.017519903848822807, 99.99992258749859, 0.6409578894693698)
# [Iter 1] candidate rank #1: T8, scene=1, ms=-5.815e+09
# == ms candidates (sorted by (ms, -dist)) ==
# rank   simp   scene           ms    mind(all)                             pt
# ----------------------------------------------------------------------------
#    1     T8       1  -5.8154e+09     1.01e+01      (0.0175, 99.9999, 0.6410)
#    2     T8       4  -5.8092e+09     2.18e+00     (9.9271, 99.9996, -0.1453)
#    3     T8       0  -5.7981e+09     6.64e-01     (9.9928, 100.0000, 1.3683)
#    4     T8       2  -5.7792e+09     6.20e-02      (9.9930, 99.9903, 1.9699)
#    5     T8       3  -5.6778e+09     8.65e-01      (9.9948, 99.9928, 1.1672)
#
# [Iter 1] per_tet=9, active after q_cut=1, tri_is_None=False
# [Iter 1] bad-quality active simplices (q < 0): 0
# [Iter 1] evaluating Q for scenario 0
# [Iter 1] evaluating Q for scenario 1
# [Iter 1] evaluating Q for scenario 2
# [Iter 1] evaluating Q for scenario 3
# [Iter 1] evaluating Q for scenario 4
#
# [Iter 1] Next Point Details:
# Simplex   Scene   Type    As             ms             As+ms          Q              (Kp, Ki, Kd)
# --------------------------------------------------------------------------------------------------------------------
# T8        1       c_s     4.9287e+09     -5.8154e+09    -8.8668e+08    9.4550e-01     (0.0175, 99.9999, 0.6410)
#
# [Iter 1] subdivision type = face (code=3) on simplex T8
#            face local verts = (3, 6, 8)
# [Iter 1] Elapsed: 1.849s
# [Bundle] MS scen None: infeasibleOrUnbounded. ms_val=nan.
# [Bundle] MS scen None: not optimal. Status=warning, Term=infeasibleOrUnbounded.
# [Invariant] MS scen None: dual=-5.731420e+09 > primal=-5.731420e+09
# [Bundle] MS scen None: infeasibleOrUnbounded. ms_val=nan.
# [Bundle] MS scen None: not optimal. Status=warning, Term=infeasibleOrUnbounded.
# [Invariant] MS scen None: dual=-5.778560e+09 > primal=-5.778560e+09
# ======================================================================
# [Iter 1] LB SPLIT DIAGNOSTIC
#   Selected (parent) simplex: (3, 6, 7, 8)
#   Parent LB: 0.987736176 (per-scen)
#   UB in parent (pre-split): True  λ=[0.00000000, -0.00000000, 0.00000000, 1.00000000]
#   EF ef_obj(IPOPT): 0.197811849, true_obj(recalc): 1.082807683, used=min=0.197811849 (per-scen)
#   Simplex volume: 6.447424e+00
#   Children (3):
#     T8 (6, 7, 8, 9): LB = 0.987869014, avg_cs = 0.987869014
#     T9 (3, 7, 8, 9): LB = 0.988113767, avg_cs = 0.988113767
#     T10 (3, 6, 7, 9): LB = 0.987565458, avg_cs = 0.987565458
#   New global LB: 0.987565458 (from T10 (3, 6, 7, 9))
#   Location: INSIDE
#   Avg CS point Q-value: 0.988250261 (per-scen), point=(np.float64(7.9850452057468955), np.float64(99.9965173556698), np.float64(1.000226770524679))
#   Current UB: 0.988250261 (per-scen)
#   UB point: (9.993045203208826, 99.9903288635917, 2.0319550327665548)
#   UB source: avgCS_new_simplex
#   UB simplex: (3, 6, 7, 8)
#   EF-IPOPT: ok=True, status=ok, term=optimal, time=1.426s, ef_obj=0.9890592459943466, true_obj(per-scen)=1.082807683
#   UB in child simplex (post-split): True
#     CHILD: T8 (6, 7, 8, 9) (LB=0.987869014, λ=[0.00000000, 0.00000000, 1.00000000, 0.00000000])
#     CHILD: T9 (3, 7, 8, 9) (LB=0.988113767, λ=[0.00000000, -0.00000000, 1.00000000, 0.00000000])
#     OLD:   T5 (4, 6, 7, 8) (LB=1.005686509, λ=[1.00000000, -0.00000000, 0.00000000, 0.00000000])
#     OLD:   T6 (3, 4, 7, 8) (LB=1.018612604, λ=[0.00000000, 1.00000000, 0.00000000, -0.00000000])
#     OLD:   T7 (3, 4, 6, 8) (LB=0.995120642, λ=[0.00000000, -0.00000000, 1.00000000, 0.00000000])
# ======================================================================
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -16.763530182828056): status=warning, term=infeasibleOrUnbounded
# [Iter 1] UB candidate from new simplex 8 (avgCS): 9.881035e-01 (per scenario)
# [BaseBundle.eval_at] Infeasible/Error for K=(3.3223642879813204, 100.00000000287136, -15.418245117108636): status=warning, term=infeasibleOrUnbounded
# [Iter 1] UB candidate from new simplex 10 (avgCS): 9.878333e-01 (per scenario)
#
# ======================================================================
# [TIMING] === Iter 1 phase breakdown (total 20.50s) ===
#   1_vertex_UB                    :       0.00s  (  0.0%)
#   2_evaluate_all_tetra           :       0.00s  (  0.0%)
#   3_active_filter_print          :       0.00s  (  0.0%)
#   4_LB_selection                 :       0.00s  (  0.0%)
#   5_EF_UB_solve                  :       1.81s  (  8.8%)  ####
#   6_candidate_selection          :       0.00s  (  0.0%)
#   7_Q_eval_new_node              :       0.04s  (  0.2%)
#   8_mesh_subdivide               :       0.00s  (  0.0%)
#   9_end_of_iter_reeval           :      18.65s  ( 91.0%)  #############################################
#   TOTAL                          :      20.50s
#   #simplices=9, #scenarios=5, total_ms_pairs=45
#   fresh ms solves=0, cache hits=45
# ======================================================================
#
# [Iter 2] #simplices = 11, #active = 1, bad-quality cut = 0, bad-shape cut = 0
# == [Iter 2] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T10           9.875655e-01      4.229088e+09     -2.885456e+10      4.937827e+00     [4.96e+00, 5.00e+10]    [-2.89e+10, 2.11e+10]     1
#
# == [Iter 2] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.000986e+00      4.574690e+09     -2.712655e+10      5.004929e+00     [1.12e+01, 5.00e+10]    [-2.71e+10, 2.29e+10]     1
# T1            9.956027e-01      4.060486e+09     -2.969757e+10      4.978014e+00     [1.12e+01, 5.00e+10]    [-2.97e+10, 2.03e+10]     1
# T2            1.025007e+00      4.471772e+09     -2.764114e+10      5.125034e+00     [1.11e+01, 5.00e+10]    [-2.76e+10, 2.24e+10]     1
# T3            1.123946e+00      4.332879e+09     -2.833561e+10      5.619732e+00     [1.36e+01, 5.00e+10]    [-2.83e+10, 2.17e+10]     2
# T4            1.039181e+00               inf               inf      5.195905e+00     [1.36e+01, 5.00e+10]               [inf, inf]     2
# T5            1.005687e+00      4.127439e+09     -2.936281e+10      5.028433e+00     [4.94e+00, 5.00e+10]    [-2.94e+10, 2.06e+10]     1
# T6            1.018613e+00      1.391250e+00     -6.683287e+00      5.093063e+00     [4.94e+00, 1.36e+01]    [-1.74e+00, 6.96e+00]     0
# T7            9.951206e-01      4.328478e+09     -2.835761e+10      4.975603e+00     [4.94e+00, 5.00e+10]    [-2.84e+10, 2.16e+10]     1
# T8            9.878690e-01               inf               inf      4.939345e+00     [4.94e+00, 5.00e+10]               [inf, inf]     1
# T9            9.881138e-01      2.501997e+00     -1.102184e+00      4.940569e+00     [4.94e+00, 1.36e+01]     [3.84e+00, 1.25e+01]     0
#
# [Iter 2] created=11 (cum=33), active=1, active+UB=0, ms_recomputed=0
# [Iter 2] UB-simplex selection: UB_node in simplices [5, 6, 7, 8, 9], chose T8 (LB=0.987869014)
# [Iter 2] EF-ipopt: ok=True, ef_obj=0.987738748626042, true_obj=9.877388e-01, time=0.275s
# [Iter 2] EF-UB improved by ipopt: 9.877388e-01 (per-scen), K=(9.99991083013093, 99.99995189827571, 1.2086480063581697)
# [Iter 2] Pre-split gap: 8.665198e-04 (0.018%)
# [Iter 2] Active simplex ratio = 0.000000
# [Iter 2] UB point (9.99991083013093, 99.99995189827571, 1.2086480063581697) is geometrically in simplices [8]
#   T8 verts=[9, 6, 8, 7]: λ=[0.000005, 0.491518, 0.004974, 0.503503], LB=4.939345072, c_s=[0.9975076035331948, 0.9456250316722468, 0.9559885802089038, 1.0700791517255208, 0.9701447047157419]
#
# == [Iter 2] CS DUAL vs PRIMAL diagnostic (simplices containing UB point) ==
#   --- T8 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(10.0, 100.0, 1.8002848462732284)
#              indep_Q(cs_K)=0.997507610
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.07104095109926, 99.99999279607444, 1.6075844694719035)
#              indep_Q(cs_K)=0.945625036
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.985234441635571, 99.9974257439501, 2.0319502244441185)
#              indep_Q(cs_K)=0.955988581
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(10.0, 100.0, 1.0000969031285272)
#              indep_Q(cs_K)=1.070079235
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(5.084032984139485, 99.99505428104024, 1.3021916414847763)
#              indep_Q(cs_K)=0.970144723
#   sum(c_s_dual)=0.000000000, UB_total=24.693469055, UB_per_scen=4.938693811
#
#   == Per-scenario Q_s at K_EF = (9.99991083013093, 99.99995189827571, 1.2086480063581697) ==
#     scen 0: Q_s(K_EF)=0.997405344, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945278840, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.956548976, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.070110282, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.969350369, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.938693811, sum(c_s)=0.000000000, diff=4.938694e+00
#
# [Iter 2] LB = 4.937827 = UB(4.938694) + ms_b(inf) from T8
# [Iter 2] Scene 0: Switched to c_s point. dist_ms_c=1.95e+01 < 1000.0, dist_c_verts=2.32e-01 > 1e-06
# [Iter 2] Scene 1: Switched to c_s point. dist_ms_c=1.96e+01 < 1000.0, dist_c_verts=1.02e+00 > 1e-06
# [Iter 2] Scene 3: Switched to c_s point. dist_ms_c=1.56e+01 < 1000.0, dist_c_verts=1.03e+00 > 1e-06
# Chosen node (9.0710409511006, 99.99999279607441, 1.6075844694725205) with ms=-5.900e+09 (simp T8, scene 1, rank #1, source=c_s)
# [Iter 2] LB simplex = T8, next node simplex = T8, scene 1
# [Selected Simp Info] Iter 2 | Simplex T8 Vertices:
#   v0: (0.017519903848822807, 99.99992258749859, 0.6409578894693698)
#   v1: (10.0, 100.0, -100.0)
#   v2: (9.993045203208826, 99.9903288635917, 2.0319550327665548)
#   v3: (10.0, 100.0, 100.0)
#   -> New Point: (9.0710409511006, 99.99999279607441, 1.6075844694725205)
# [Iter 2] candidate rank #1: T8, scene=1, ms=-5.900e+09
# == ms candidates (sorted by (ms, -dist)) ==
# rank   simp   scene           ms    mind(all)                             pt
# ----------------------------------------------------------------------------
#    1     T8       1  -5.9003e+09     1.02e+00     (9.0710, 100.0000, 1.6076)
#    2     T8       0  -5.8828e+09     2.32e-01    (10.0000, 100.0000, 1.8003)
#    3     T8       3  -5.7314e+09     1.03e+00    (10.0000, 100.0000, 1.0001)
#    4     T8       2          inf          nan                           None
#    5     T8       4          inf          nan                           None
#
# [Iter 2] per_tet=11, active after q_cut=1, tri_is_None=False
# [Iter 2] bad-quality active simplices (q < 0): 0
# [Iter 2] evaluating Q for scenario 0
# [Iter 2] evaluating Q for scenario 1
# [Iter 2] evaluating Q for scenario 2
# [Iter 2] evaluating Q for scenario 3
# [Iter 2] evaluating Q for scenario 4
#
# [Iter 2] Next Point Details:
# Simplex   Scene   Type    As             ms             As+ms          Q              (Kp, Ki, Kd)
# --------------------------------------------------------------------------------------------------------------------
# T8        1       c_s     4.4573e+09     -5.9003e+09    -1.4430e+09    9.4563e-01     (9.0710, 100.0000, 1.6076)
#
# [Iter 2] subdivision type = face (code=3) on simplex T8
#            face local verts = (9, 6, 7)
# [Iter 2] Elapsed: 0.490s
# [Invariant] MS scen None: dual=-5.851543e+09 > primal=-5.851543e+09
# [Invariant] MS scen None: dual=-1.590836e+09 > primal=-1.590836e+09
# [Bundle] MS scen None: infeasibleOrUnbounded. ms_val=nan.
# [Bundle] MS scen None: not optimal. Status=warning, Term=infeasibleOrUnbounded.
# [Bundle] MS scen None: infeasibleOrUnbounded. ms_val=nan.
# [Bundle] MS scen None: not optimal. Status=warning, Term=infeasibleOrUnbounded.
# [Invariant] MS scen None: dual=-1.944323e+09 > primal=-1.944323e+09
# ======================================================================
# [Iter 2] LB SPLIT DIAGNOSTIC
#   Selected (parent) simplex: (6, 7, 8, 9)
#   Parent LB: 0.987869014 (per-scen)
#   UB in parent (pre-split): True  λ=[0.00000547, 0.49151773, 0.00497370, 0.50350311]
#   EF ef_obj(IPOPT): 0.197547750, true_obj(recalc): 0.987738762, used=min=0.197547750 (per-scen)
#   Simplex volume: 3.218046e+00
#   Children (3):
#     T10 (6, 7, 8, 10): LB = 0.987554023, avg_cs = 0.987554023
#     T11 (7, 8, 9, 10): LB = 0.987980954, avg_cs = 0.987980954
#     T12 (6, 8, 9, 10): LB = 0.987553839, avg_cs = 0.987553839
#   New global LB: 0.987553839 (from T12 (6, 8, 9, 10))
#   Location: INSIDE
#   Avg CS point Q-value: 0.988103533 (per-scen), point=(np.float64(8.828061675374864), np.float64(99.99849456421296), np.float64(1.5484216169605107))
#   Current UB: 0.987738762 (per-scen)
#   UB point: (9.99991083013093, 99.99995189827571, 1.2086480063581697)
#   UB source: EF_ipopt
#   UB simplex: (6, 7, 8, 9)
#   EF-IPOPT: ok=True, status=ok, term=optimal, time=0.275s, ef_obj=0.987738748626042, true_obj(per-scen)=0.987738762
#   UB in child simplex (post-split): True
#     CHILD: T10 (6, 7, 8, 10) (LB=0.987554023, λ=[0.00005875, 0.49149154, 0.50347601, 0.00497370])
# ======================================================================
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -17.05709411967405): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(8.459337457672602, 99.99357821140113, -16.83454134145622): status=warning, term=infeasibleOrUnbounded
#
# ======================================================================
# [TIMING] === Iter 2 phase breakdown (total 15.95s) ===
#   1_vertex_UB                    :       0.00s  (  0.0%)
#   2_evaluate_all_tetra           :       0.00s  (  0.0%)
#   3_active_filter_print          :       0.00s  (  0.0%)
#   4_LB_selection                 :       0.00s  (  0.0%)
#   5_EF_UB_solve                  :       0.40s  (  2.5%)  #
#   6_candidate_selection          :       0.00s  (  0.0%)
#   7_Q_eval_new_node              :       0.08s  (  0.5%)
#   8_mesh_subdivide               :       0.00s  (  0.0%)
#   9_end_of_iter_reeval           :      15.46s  ( 96.9%)  ################################################
#   TOTAL                          :      15.95s
#   #simplices=11, #scenarios=5, total_ms_pairs=55
#   fresh ms solves=0, cache hits=55
# ======================================================================
#
# [Iter 3] #simplices = 13, #active = 3, bad-quality cut = 0, bad-shape cut = 0
# == [Iter 3] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T9            9.875655e-01      4.229088e+09     -2.885456e+10      4.937827e+00     [4.96e+00, 5.00e+10]    [-2.89e+10, 2.11e+10]     1
# T10           9.875540e-01      4.147145e+09     -2.926427e+10      4.937770e+00     [4.94e+00, 5.00e+10]    [-2.93e+10, 2.07e+10]     1
# T12           9.875538e-01               inf               inf      4.937769e+00     [4.94e+00, 5.00e+10]               [inf, inf]     1
#
# == [Iter 3] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.000986e+00      4.574690e+09     -2.712655e+10      5.004929e+00     [1.12e+01, 5.00e+10]    [-2.71e+10, 2.29e+10]     1
# T1            9.956027e-01      4.060486e+09     -2.969757e+10      4.978014e+00     [1.12e+01, 5.00e+10]    [-2.97e+10, 2.03e+10]     1
# T2            1.025007e+00      4.471772e+09     -2.764114e+10      5.125034e+00     [1.11e+01, 5.00e+10]    [-2.76e+10, 2.24e+10]     1
# T3            1.123946e+00      4.332879e+09     -2.833561e+10      5.619732e+00     [1.36e+01, 5.00e+10]    [-2.83e+10, 2.17e+10]     2
# T4            1.039181e+00               inf               inf      5.195905e+00     [1.36e+01, 5.00e+10]               [inf, inf]     2
# T5            1.005687e+00      4.127439e+09     -2.936281e+10      5.028433e+00     [4.94e+00, 5.00e+10]    [-2.94e+10, 2.06e+10]     1
# T6            1.018613e+00      1.391250e+00     -6.683287e+00      5.093063e+00     [4.94e+00, 1.36e+01]    [-1.74e+00, 6.96e+00]     0
# T7            9.951206e-01      4.328478e+09     -2.835761e+10      4.975603e+00     [4.94e+00, 5.00e+10]    [-2.84e+10, 2.16e+10]     1
# T8            9.881138e-01      2.501997e+00     -1.102184e+00      4.940569e+00     [4.94e+00, 1.36e+01]     [3.84e+00, 1.25e+01]     0
# T11           9.879810e-01      2.132127e+00     -4.588398e-01      4.939905e+00     [4.94e+00, 1.11e+01]     [4.48e+00, 1.07e+01]     0
#
# [Iter 3] created=13 (cum=49), active=3, active+UB=2, ms_recomputed=0
# [Iter 3] UB-simplex selection: UB_node in simplices [9, 10, 11, 12], chose T12 (LB=0.987553839)
# [Iter 3] EF-ipopt: ok=True, ef_obj=0.987741467137919, true_obj=9.877415e-01, time=0.290s
# [Iter 3] Pre-split gap: 9.246176e-04 (0.019%)
# [Iter 3] Active simplex ratio = 0.000002
# [Iter 3] UB point (9.0710409511006, 99.99999279607441, 1.6075844694725205) is geometrically in simplices [9, 10, 11, 12]
#   T9 verts=[3, 6, 9, 7]: λ=[-0.000000, 0.445731, 0.093059, 0.461210], LB=4.937827291, c_s=[0.9974035412378067, 0.9452440551740191, 0.9559899879602668, 1.0700786411560856, 0.9691110656112437]
#   T10 verts=[10, 6, 7, 8]: λ=[1.000000, -0.000000, 0.000000, -0.000000], LB=4.937770114, c_s=[0.9973801853482098, 0.9452096911484275, 0.9559882379206053, 1.0700794290654756, 0.9691125703703852]
#   T11 verts=[9, 10, 7, 8]: λ=[0.000000, 1.000000, 0.000000, -0.000000], LB=4.939904770, c_s=[0.9976173675615393, 0.9453389081484384, 0.9560375371710687, 1.0709719400880733, 0.9699390166996165]
#   T12 verts=[9, 6, 10, 8]: λ=[0.000000, -0.000000, 1.000000, 0.000000], LB=4.937769193, c_s=[0.997379076535772, 0.9452016897126039, 0.9559885220613606, 1.0700873899809813, 0.9691125150055346]
#
# == [Iter 3] CS DUAL vs PRIMAL diagnostic (simplices containing UB point) ==
#   --- T9 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(10.0, 100.0, 1.579167063516439)
#              indep_Q(cs_K)=0.997403549
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(7.891690123150027, 99.99998365040153, 0.8172865454335699)
#              indep_Q(cs_K)=0.945244055
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(10.0, 100.0, 1.98431085543865)
#              indep_Q(cs_K)=0.955989996
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.999993015352814, 100.0, 1.0237374485394808)
#              indep_Q(cs_K)=1.070078650
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(10.0, 100.0, 0.66568242036274)
#              indep_Q(cs_K)=0.969111231
#   sum(c_s_dual)=0.000000000, UB_total=24.693469055, UB_per_scen=4.938693811
#
#   == Per-scenario Q_s at K_EF = (9.0710409511006, 99.99999279607441, 1.6075844694725205) ==
#     scen 0: Q_s(K_EF)=0.997616919, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945625036, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.956160101, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.071063436, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.969948176, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.940413668, sum(c_s)=0.000000000, diff=4.940414e+00
#   --- T10 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(10.0, 100.0, 1.4656100355545856)
#              indep_Q(cs_K)=0.997380186
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.997175274428017, 100.0, 0.9993648750951148)
#              indep_Q(cs_K)=0.945209691
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(10.0, 100.0, 2.040055041477374)
#              indep_Q(cs_K)=0.955988243
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(10.0, 100.0, 1.0533424789141574)
#              indep_Q(cs_K)=1.070079454
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.993138682563675, 99.99045885324047, 0.6605445348268153)
#              indep_Q(cs_K)=0.969112594
#   sum(c_s_dual)=0.000000000, UB_total=24.693469055, UB_per_scen=4.938693811
#
#   == Per-scenario Q_s at K_EF = (9.0710409511006, 99.99999279607441, 1.6075844694725205) ==
#     scen 0: Q_s(K_EF)=0.997616919, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945625036, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.956160101, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.071063436, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.969948176, c_s_dual=N/A
# ...
# T464          9.876059e-01      1.494332e+00     -2.546784e+00      4.938029e+00     [4.94e+00, 1.00e+01]     [2.39e+00, 7.47e+00]     0
# T605          9.876060e-01      1.126269e+00     -4.325288e-01      4.938030e+00     [4.94e+00, 6.06e+00]     [4.51e+00, 5.63e+00]     0
# T1543         9.875544e-01      1.020090e+00     -9.336648e-02      4.937772e+00     [4.94e+00, 5.19e+00]     [4.85e+00, 5.10e+00]     0
#
# == [Iter 611] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.000986e+00      4.574690e+09     -2.712655e+10      5.004929e+00     [1.12e+01, 5.00e+10]    [-2.71e+10, 2.29e+10]     1
# T1            9.956027e-01      4.060486e+09     -2.969757e+10      4.978014e+00     [1.12e+01, 5.00e+10]    [-2.97e+10, 2.03e+10]     1
# T2            1.025007e+00      4.471772e+09     -2.764114e+10      5.125034e+00     [1.11e+01, 5.00e+10]    [-2.76e+10, 2.24e+10]     1
# T3            1.123946e+00      4.332879e+09     -2.833561e+10      5.619732e+00     [1.36e+01, 5.00e+10]    [-2.83e+10, 2.17e+10]     2
# T4            1.039181e+00               inf               inf      5.195905e+00     [1.36e+01, 5.00e+10]               [inf, inf]     2
# T5            1.005687e+00      4.127439e+09     -2.936281e+10      5.028433e+00     [4.94e+00, 5.00e+10]    [-2.94e+10, 2.06e+10]     1
# T6            1.018613e+00      1.391250e+00     -6.683287e+00      5.093063e+00     [4.94e+00, 1.36e+01]    [-1.74e+00, 6.96e+00]     0
# T7            9.951206e-01      4.328478e+09     -2.835761e+10      4.975603e+00     [4.94e+00, 5.00e+10]    [-2.84e+10, 2.16e+10]     1
# T8            9.881138e-01      2.501997e+00     -1.102184e+00      4.940569e+00     [4.94e+00, 1.36e+01]     [3.84e+00, 1.25e+01]     0
# T10           9.879810e-01      2.132127e+00     -4.588398e-01      4.939905e+00     [4.94e+00, 1.11e+01]     [4.48e+00, 1.07e+01]     0
# T11           9.878003e-01               inf               inf      4.939002e+00     [4.94e+00, 5.00e+10]               [inf, inf]     1
# T21           9.877645e-01      6.823152e+09     -1.588424e+10      4.938823e+00     [4.94e+00, 5.00e+10]    [-1.59e+10, 3.41e+10]     2
# T625          9.878108e-01               inf               inf      4.939054e+00     [4.94e+00, 5.00e+10]               [inf, inf]     1
# T1253         9.878110e-01               inf               inf      4.939055e+00     [4.94e+00, 5.00e+10]               [inf, inf]     1
#
# [Iter 611] created=31 (cum=16770), active=17, active+UB=0, ms_recomputed=0
# [Iter 611] UB-simplex selection: UB_node OUTSIDE mesh, fallback to min-LB simplex T1543 (LB=0.987554412)
# [Iter 611] EF-ipopt: ok=True, ef_obj=0.9877412602954312, true_obj=9.877413e-01, time=0.158s
# [Iter 611] Pre-split gap: 9.217494e-04 (0.019%)
# [Iter 611] Active simplex ratio = 0.000000
# [Iter 611] UB point (9.998429730840359, 99.99856400416506, 1.0256504538614293) is NOT inside any simplex (outside mesh)
# [Iter 611] LB = 4.937772 = UB(4.938694) + ms_b(-9.337e-02) from T1543
# [Iter 611] Scene 0: Switched to c_s point. dist_ms_c=3.40e+00 < 1000.0, dist_c_verts=4.37e-01 > 1e-06
# [Iter 611] Scene 1: Switched to c_s point. dist_ms_c=2.80e+00 < 1000.0, dist_c_verts=1.31e-01 > 1e-06
# [Iter 611] Scene 2: Kept ms point (c_s too close to verts). dist_ms_c=3.94e+00 < 1000.0 BUT dist_c_verts=0.00e+00 <= 1e-06
# [Iter 611] Scene 3: Switched to c_s point. dist_ms_c=3.01e+00 < 1000.0, dist_c_verts=7.22e-06 > 1e-06
# [Iter 611] Scene 4: Switched to c_s point. dist_ms_c=2.59e+00 < 1000.0, dist_c_verts=3.48e-01 > 1e-06
# Chosen node (9.993280249899737, 99.99210911751145, 1.0236973288086249) with ms=-2.176e-02 (simp T1543, scene 3, rank #1, source=c_s)
# [Iter 611] LB simplex = T1543, next node simplex = T1543, scene 3
# [Selected Simp Info] Iter 611 | Simplex T1543 Vertices:
#   v0: (9.993283679984865, 99.99211543036718, 1.0236966543608812)
#   v1: (9.99304451035731, 99.99033093414042, 2.0103488983077398)
#   v2: (9.992818679095118, 99.991005556505, -5.029310496394301)
#   v3: (9.0710409511006, 99.99999279607441, 1.6075844694725205)
#   -> New Point: (9.993280249899737, 99.99210911751145, 1.0236973288086249)
# [Iter 611] candidate rank #1: T1543, scene=3, ms=-2.176e-02
# == ms candidates (sorted by (ms, -dist)) ==
# rank   simp   scene           ms    mind(all)                             pt
# ----------------------------------------------------------------------------
#    1  T1543       3  -2.1759e-02     7.22e-06      (9.9933, 99.9921, 1.0237)
#    2  T1543       2  -1.9731e-02     2.57e+00     (9.9929, 99.9907, -1.9253)
#    3  T1543       0  -1.8885e-02     3.94e-02      (9.9930, 99.9904, 1.4605)
#    4  T1543       1  -1.6589e-02     1.40e-03      (9.9930, 99.9904, 0.8932)
#    5  T1543       4  -1.6403e-02     8.90e-03      (9.9930, 99.9905, 0.6759)
#
# [Iter 611] per_tet=31, active after q_cut=17, tri_is_None=False
# [Iter 611] bad-quality active simplices (q < 0): 0
# [Iter 611] evaluating Q for scenario 0
# [Iter 611] evaluating Q for scenario 1
# [Iter 611] evaluating Q for scenario 2
# [Iter 611] evaluating Q for scenario 3
# [Iter 611] evaluating Q for scenario 4
#
# [Iter 611] Next Point Details:
# Simplex   Scene   Type    As             ms             As+ms          Q              (Kp, Ki, Kd)
# --------------------------------------------------------------------------------------------------------------------
# T1543     3       c_s     1.0701e+00     -2.1759e-02    1.0484e+00     1.0701e+00     (9.9933, 99.9921, 1.0237)
#
# [Iter 611] subdivision type = interior (code=1) on simplex T1543
# [Iter 611] Elapsed: 0.276s
# ======================================================================
# [Iter 611] LB SPLIT DIAGNOSTIC
#   Selected (parent) simplex: (10, 203, 297, 618)
#   Parent LB: 0.987554412 (per-scen)
#   UB in parent (pre-split): False  λ=[4.84131970, -3.29845892, -0.53840772, -0.00445306]
#   EF ef_obj(IPOPT): 0.197548252, true_obj(recalc): 0.987741274, used=min=0.197548252 (per-scen)
#   Simplex volume: 1.831154e-03
#   Children (4):
#     T1546 (10, 203, 297, 619): LB = 0.987554413, avg_cs = 0.987554413
#   New global LB: 0.987554413 (from T1546 (10, 203, 297, 619))
#   Location: INSIDE
#   Avg CS point Q-value: 0.987741452 (per-scen), point=(np.float64(9.993072401066685), np.float64(99.99074409755858), np.float64(1.2127291412277814))
#   Current UB: 0.987738762 (per-scen)
#   UB point: (9.998429730840359, 99.99856400416506, 1.0256504538614293)
#   UB source: avgCS_new_simplex
#   UB simplex: (3, 6, 7, 9)
#   EF-IPOPT: ok=True, status=ok, term=optimal, time=0.158s, ef_obj=0.9877412602954312, true_obj(per-scen)=0.987741274
#   UB in child simplex (post-split): False
#     (UB point is outside mesh)
# ======================================================================
#
# ======================================================================
# [TIMING] === Iter 611 phase breakdown (total 2.63s) ===
#   1_vertex_UB                    :       0.00s  (  0.0%)
#   2_evaluate_all_tetra           :       0.02s  (  0.9%)
#   3_active_filter_print          :       0.00s  (  0.1%)
#   4_LB_selection                 :       0.00s  (  0.0%)
#   5_EF_UB_solve                  :       0.18s  (  6.9%)  ###
#   6_candidate_selection          :       0.00s  (  0.1%)
#   7_Q_eval_new_node              :       0.07s  (  2.6%)  #
#   8_mesh_subdivide               :       0.00s  (  0.0%)
#   9_end_of_iter_reeval           :       2.35s  ( 89.5%)  ############################################
#   TOTAL                          :       2.63s
#   #simplices=31, #scenarios=5, total_ms_pairs=155
#   fresh ms solves=0, cache hits=155
# ======================================================================
#
# [Iter 612] #simplices = 31, #active = 17, bad-quality cut = 0, bad-shape cut = 0
# == [Iter 612] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T9            9.875655e-01      4.229088e+09     -2.885456e+10      4.937827e+00     [4.96e+00, 5.00e+10]    [-2.89e+10, 2.11e+10]     1
# T12           9.875737e-01      2.123477e+00     -5.020887e-01      4.937869e+00     [4.94e+00, 1.11e+01]     [4.44e+00, 1.06e+01]     0
# T14           9.875737e-01      2.122544e+00     -5.067531e-01      4.937869e+00     [4.94e+00, 1.11e+01]     [4.43e+00, 1.06e+01]     0
# T424          9.875773e-01      9.903914e-01     -3.404907e-03      4.937887e+00     [4.94e+00, 4.96e+00]     [4.94e+00, 4.95e+00]     0
# T425          9.876231e-01      9.906263e-01     -2.230595e-03      4.938080e+00     [4.94e+00, 4.96e+00]     [4.94e+00, 4.95e+00]     0
# T429          9.876423e-01      9.880159e-01     -1.350218e-03      4.937796e+00     [4.94e+00, 4.94e+00]     [4.94e+00, 4.94e+00]     0
# T430          9.875869e-01      8.878832e+09     -5.605839e+09      4.937934e+00     [4.94e+00, 5.00e+10]    [-5.61e+09, 4.44e+10]     1
# T432          9.875632e-01      9.878870e-01     -1.994898e-03      4.937764e+00     [4.94e+00, 4.94e+00]     [4.94e+00, 4.94e+00]     0
# T433          9.876135e-01      8.140240e+09     -9.298799e+09      4.938067e+00     [4.94e+00, 5.00e+10]    [-9.30e+09, 4.07e+10]     1
# T435          9.876142e-01      6.848303e+09     -1.575849e+10      4.938071e+00     [4.94e+00, 5.00e+10]    [-1.58e+10, 3.42e+10]     2
# T447          9.876060e-01      1.961890e+08     -9.019055e+09      4.938030e+00     [4.94e+00, 1.00e+10]    [-9.02e+09, 9.81e+08]     1
# T448          9.876058e-01      1.938449e+08     -9.030776e+09      4.938029e+00     [4.94e+00, 1.00e+10]    [-9.03e+09, 9.69e+08]     1
# T454          9.876059e-01      2.564305e+08     -8.717848e+09      4.938030e+00     [4.94e+00, 1.00e+10]    [-8.72e+09, 1.28e+09]     1
# T459          9.876059e-01      2.714316e+00     -1.988349e+01      4.938030e+00     [4.94e+00, 3.35e+01]    [-1.49e+01, 1.36e+01]     0
# T464          9.876059e-01      1.494332e+00     -2.546784e+00      4.938029e+00     [4.94e+00, 1.00e+01]     [2.39e+00, 7.47e+00]     0
# T605          9.876060e-01      1.126269e+00     -4.325288e-01      4.938030e+00     [4.94e+00, 6.06e+00]     [4.51e+00, 5.63e+00]     0
# T1546         9.875544e-01      1.020090e+00     -9.336648e-02      4.937772e+00     [4.94e+00, 5.19e+00]     [4.85e+00, 5.10e+00]     0
#
# == [Iter 612] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.000986e+00      4.574690e+09     -2.712655e+10      5.004929e+00     [1.12e+01, 5.00e+10]    [-2.71e+10, 2.29e+10]     1
# T1            9.956027e-01      4.060486e+09     -2.969757e+10      4.978014e+00     [1.12e+01, 5.00e+10]    [-2.97e+10, 2.03e+10]     1
# T2            1.025007e+00      4.471772e+09     -2.764114e+10      5.125034e+00     [1.11e+01, 5.00e+10]    [-2.76e+10, 2.24e+10]     1
# T3            1.123946e+00      4.332879e+09     -2.833561e+10      5.619732e+00     [1.36e+01, 5.00e+10]    [-2.83e+10, 2.17e+10]     2
# T4            1.039181e+00               inf               inf      5.195905e+00     [1.36e+01, 5.00e+10]               [inf, inf]     2
# T5            1.005687e+00      4.127439e+09     -2.936281e+10      5.028433e+00     [4.94e+00, 5.00e+10]    [-2.94e+10, 2.06e+10]     1
# T6            1.018613e+00      1.391250e+00     -6.683287e+00      5.093063e+00     [4.94e+00, 1.36e+01]    [-1.74e+00, 6.96e+00]     0
# T7            9.951206e-01      4.328478e+09     -2.835761e+10      4.975603e+00     [4.94e+00, 5.00e+10]    [-2.84e+10, 2.16e+10]     1
# T8            9.881138e-01      2.501997e+00     -1.102184e+00      4.940569e+00     [4.94e+00, 1.36e+01]     [3.84e+00, 1.25e+01]     0
# T10           9.879810e-01      2.132127e+00     -4.588398e-01      4.939905e+00     [4.94e+00, 1.11e+01]     [4.48e+00, 1.07e+01]     0
# T11           9.878003e-01               inf               inf      4.939002e+00     [4.94e+00, 5.00e+10]               [inf, inf]     1
# T21           9.877645e-01      6.823152e+09     -1.588424e+10      4.938823e+00     [4.94e+00, 5.00e+10]    [-1.59e+10, 3.41e+10]     2
# T625          9.878108e-01               inf               inf      4.939054e+00     [4.94e+00, 5.00e+10]               [inf, inf]     1
# T1253         9.878110e-01               inf               inf      4.939055e+00     [4.94e+00, 5.00e+10]               [inf, inf]     1
#
# [Iter 612] created=31 (cum=16802), active=17, active+UB=0, ms_recomputed=0
# [Iter 612] UB-simplex selection: UB_node OUTSIDE mesh, fallback to min-LB simplex T1546 (LB=0.987554413)
# [Iter 612] EF-ipopt: ok=True, ef_obj=0.9877412615604331, true_obj=9.877413e-01, time=0.211s
# [Iter 612] Pre-split gap: 9.217444e-04 (0.019%)
# [Iter 612] Active simplex ratio = 0.000000
# [Iter 612] UB point (9.998429730840359, 99.99856400416506, 1.0256504538614293) is NOT inside any simplex (outside mesh)
# [Iter 612] LB = 4.937772 = UB(4.938694) + ms_b(-9.337e-02) from T1546
# [Iter 612] Scene 0: Switched to c_s point. dist_ms_c=3.40e+00 < 1000.0, dist_c_verts=4.37e-01 > 1e-06
# [Iter 612] Scene 1: Switched to c_s point. dist_ms_c=2.80e+00 < 1000.0, dist_c_verts=1.31e-01 > 1e-06
# [Iter 612] Scene 2: Kept ms point (c_s too close to verts). dist_ms_c=3.94e+00 < 1000.0 BUT dist_c_verts=0.00e+00 <= 1e-06
# [Iter 612] Scene 3: Switched to c_s point. dist_ms_c=3.01e+00 < 1000.0, dist_c_verts=7.22e-06 > 1e-06
# [Iter 612] Scene 4: Switched to c_s point. dist_ms_c=2.59e+00 < 1000.0, dist_c_verts=3.48e-01 > 1e-06
# Chosen node (9.993276824977153, 99.99210279602012, 1.0236980030834042) with ms=-2.176e-02 (simp T1546, scene 3, rank #1, source=c_s)
# [Iter 612] LB simplex = T1546, next node simplex = T1546, scene 3
# [Selected Simp Info] Iter 612 | Simplex T1546 Vertices:
#   v0: (9.993280249899737, 99.99210911751145, 1.0236973288086249)
#   v1: (9.99304451035731, 99.99033093414042, 2.0103488983077398)
#   v2: (9.992818679095118, 99.991005556505, -5.029310496394301)
#   v3: (9.0710409511006, 99.99999279607441, 1.6075844694725205)
#   -> New Point: (9.993276824977153, 99.99210279602012, 1.0236980030834042)
# [Iter 612] candidate rank #1: T1546, scene=3, ms=-2.176e-02
# == ms candidates (sorted by (ms, -dist)) ==
# rank   simp   scene           ms    mind(all)                             pt
# ----------------------------------------------------------------------------
#    1  T1546       3  -2.1759e-02     7.22e-06      (9.9933, 99.9921, 1.0237)
#    2  T1546       2  -1.9731e-02     2.57e+00     (9.9929, 99.9907, -1.9253)
#    3  T1546       0  -1.8885e-02     3.94e-02      (9.9930, 99.9904, 1.4605)
#    4  T1546       1  -1.6589e-02     1.40e-03      (9.9930, 99.9904, 0.8932)
#    5  T1546       4  -1.6403e-02     8.90e-03      (9.9930, 99.9905, 0.6759)
#
# [Iter 612] per_tet=31, active after q_cut=17, tri_is_None=False
# [Iter 612] bad-quality active simplices (q < 0): 0
# [Iter 612] evaluating Q for scenario 0
# [Iter 612] evaluating Q for scenario 1
# [Iter 612] evaluating Q for scenario 2
# [Iter 612] evaluating Q for scenario 3
# [Iter 612] evaluating Q for scenario 4
#
# [Iter 612] Next Point Details:
# Simplex   Scene   Type    As             ms             As+ms          Q              (Kp, Ki, Kd)
# --------------------------------------------------------------------------------------------------------------------
# T1546     3       c_s     1.0701e+00     -2.1759e-02    1.0484e+00     1.0701e+00     (9.9933, 99.9921, 1.0237)
#
# [Iter 612] subdivision type = interior (code=1) on simplex T1546
# [Iter 612] Elapsed: 0.350s
