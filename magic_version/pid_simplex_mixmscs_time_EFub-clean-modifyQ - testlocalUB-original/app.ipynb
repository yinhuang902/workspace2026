# %%
from time import perf_counter  

from modeling import build_models_from_csv
from bundles import BaseBundle, MSBundle
from utils import (
    tighten_bounds_one_model,
    MIN_DIST, ACTIVE_TOL, GAP_STOP_TOL,
)
from simplex_specialstart import run_pid_simplex_3d

# setup scenario number and target_nodesk
csv_path       = "data.csv"
max_scenarios  = 10
target_nodes   = 1000

bounds={
    "Kp": (-10.0, 10.0),
    "Ki": (-100.0, 100.0),
    "Kd": (-100.0, 100.0),
    "x": (-2.5, 2.5),
    "u": (-5.0, 5.0),
    "e": (None, None),
    "I": (None, None),
}

weights = (10.0, 0.01)


# ====== stage 1：load data and generate models ======
T   = 15.0          
nfe = 20            

t_load0 = perf_counter()
model_list, first_stg_vars_list, m_tmpl_list, nfe = build_models_from_csv(
    csv_path=csv_path,
    T=T,
    nfe=nfe,
    weights=weights,
    bounds=bounds,
    sp0=0.0,
    sp1=0.5,
    tau_xs_col="tau_xs",
    tau_us_col="tau_us",
    tau_ds_col="tau_ds",          
    disturb_prefix="disturbance_",
    setpoint_change_col="setpoint_change",
    max_scenarios=max_scenarios,
    skip=0,
)
t_load1 = perf_counter()
print(f"[Time] Data load & scenario build: {t_load1 - t_load0:.3f}s")


# ====== stage 1.5：FBBT / OBBT ======
# same as snog: FBBT open,OBBT open
obbt_solver_opts = {
    "NonConvex": 2,
    "MIPGap": 1,     
    "TimeLimit": 15   
}
for m, yvars in zip(model_list, first_stg_vars_list):
    tighten_bounds_one_model(m, yvars,
                             use_fbbt=False,
                             use_obbt=False,
                             obbt_solver_name="gurobi",
                             obbt_solver_opts=obbt_solver_opts,
                             max_rounds=3, tol=1e-6, verbose=True)

# ====== stage 2: Persistent Solver Packaging ======
ub_options = {
    'NonConvex': 2,      
}
lb_options = {
    'NonConvex': 2,
    'MIPGap': 1e-1,            
    'TimeLimit': 15
}

t_wrap0 = perf_counter()
base_bundles = [BaseBundle(m, ub_options) for m in model_list]  
ms_bundles   = [MSBundle(m, yvars, lb_options) for m, yvars in zip(model_list, first_stg_vars_list)]  
t_wrap1 = perf_counter()
print(f"[Time] Persistent wrapper (GurobiPersistent) setup: {t_wrap1 - t_wrap0:.3f}s")

# ====== stage 3：main loop ======
agg_bundle = None  

t_run0 = perf_counter()
hist = run_pid_simplex_3d(
    base_bundles=base_bundles,
    ms_bundles=ms_bundles,
    model_list=model_list,
    first_vars_list=first_stg_vars_list,
    target_nodes=target_nodes,
    min_dist=0,
    active_tol=ACTIVE_TOL,
    verbose=True,
    agg_bundle=agg_bundle,
    gap_stop_tol=1e-6,
    use_exact_opt=False,
    exact_solver_name="gurobi",
    exact_solver_opts={"NonConvex": 2, "TimeLimit": 60},
    time_limit=60*60*2,
    enable_3d_plot=False,   
    plot_every=None,        
)
t_run1 = perf_counter()
print(f"[Time] Main loop total: {t_run1 - t_run0:.3f}s")

# ====== print output ======
print("\n==== Done ====")
print(f"Total nodes: {len(hist['nodes'])}")
print(f"Best UB: {min(hist['UB_hist']) if hist['UB_hist'] else None}")
print(f"Last LB: {hist['LB_hist'][-1] if hist['LB_hist'] else None}")
# Out:
# [Time] Data load & scenario build: 0.077s
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2689754
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 15
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 15
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 15
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 15
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 15
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 15
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 15
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 15
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 15
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 15
# [Time] Persistent wrapper (GurobiPersistent) setup: 1.039s
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [TIMING] Pre-loop vertex Q evals: 1.20s  (8 nodes x 10 scenarios = 80 solves)
# [EF-UB] Initialized ipopt EF with 10 scenarios, time_ub=60.0s
#
# ======================================================================
# [TIMING] === Pre-loop phase summary ===
#   corners_and_mesh               :       0.00s
#   vertex_Q_evals                 :       1.20s
#   exact_optima                   :       0.00s
#   ef_init                        :       0.05s
#   TOTAL                          :       1.25s
# ======================================================================
#
# [Iter 0] MIPGap overridden to 0.1 (original: 0.1)
# Discarded solution information
# [Invariant] MS scen None: dual=-5.500707e+09 > primal=-5.500707e+09
# Discarded solution information
# Discarded solution information
# [Invariant] MS scen None: dual=-5.481254e+09 > primal=-5.481254e+09
# Discarded solution information
# Discarded solution information
# [Invariant] MS scen None: dual=-5.194287e+09 > primal=-5.194287e+09
# Discarded solution information
# Discarded solution information
# Discarded solution information
# Discarded solution information
# Discarded solution information
# [Invariant] MS scen None: dual=-5.806922e+09 > primal=-5.806922e+09
# [Invariant] MS scen None: dual=-5.817119e+09 > primal=-5.817119e+09
# [Invariant] MS scen None: dual=-6.005622e+09 > primal=-6.005622e+09
# [Invariant] MS scen None: dual=-5.982090e+09 > primal=-5.982090e+09
# [Invariant] MS scen None: dual=-5.596691e+09 > primal=-5.596691e+09
# [Invariant] MS scen None: dual=-5.628277e+09 > primal=-5.628277e+09
# [Invariant] MS scen None: dual=-5.719282e+09 > primal=-5.719282e+09
# [Invariant] MS scen None: dual=-5.735561e+09 > primal=-5.735561e+09
# [Invariant] MS scen None: dual=-5.718800e+09 > primal=-5.718800e+09
# [Invariant] MS scen None: dual=-5.912410e+09 > primal=-5.912410e+09
# [Invariant] MS scen None: dual=-5.724298e+09 > primal=-5.724298e+09
# [Invariant] MS scen None: dual=-5.679468e+09 > primal=-5.679468e+09
# [Invariant] MS scen None: dual=-5.610143e+09 > primal=-5.610143e+09
# [Bundle] MS scen None: infeasibleOrUnbounded. ms_val=nan.
# [Bundle] MS scen None: not optimal. Status=warning, Term=infeasibleOrUnbounded.
# [Invariant] MS scen None: dual=-5.870800e+09 > primal=-5.870800e+09
# [Invariant] MS scen None: dual=-5.766877e+09 > primal=-5.766877e+09
# [Invariant] MS scen None: dual=-5.000000e+09 > primal=-5.000000e+09
# [Invariant] MS scen None: dual=-5.788922e+09 > primal=-5.788922e+09
# [Iter 0] MIPGap restored to 0.1
# [Iter 0] #simplices = 6, #active = 6, bad-quality cut = 0, bad-shape cut = 0
# == [Iter 0] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.031046e+00      4.639037e+09     -5.360963e+10      1.031046e+01     [2.23e+01, 1.00e+11]    [-5.36e+10, 4.64e+10]     1
# T1            9.937735e-01      4.082672e+09     -5.917328e+10      9.937735e+00     [2.23e+01, 1.00e+11]    [-5.92e+10, 4.08e+10]     1
# T2            1.024926e+00      4.371904e+09     -5.628096e+10      1.024926e+01     [2.21e+01, 1.00e+11]    [-5.63e+10, 4.37e+10]     1
# T3            1.000442e+00      4.209123e+09     -5.790877e+10      1.000442e+01     [2.21e+01, 1.00e+11]    [-5.79e+10, 4.21e+10]     1
# T4            1.020419e+00      4.317584e+09     -5.682416e+10      1.020419e+01     [2.71e+01, 1.00e+11]    [-5.68e+10, 4.32e+10]     2
# T5            1.015549e+00               inf               inf      1.015549e+01     [2.71e+01, 1.00e+11]               [inf, inf]     2
#
# == [Iter 0] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
#   (none)
# [Iter 0] created=6 (cum=6), active=6, active+UB=2, ms_recomputed=6
# [Iter 0] UB-simplex selection: UB_node in simplices [2, 3], chose T3 (LB=1.000442251)
# [Iter 0] EF-ipopt: ok=True, ef_obj=0.9835205133382454, true_obj=9.835205e-01, time=0.391s
# [Iter 0] EF-UB improved by ipopt: 9.835205e-01 (per-scen), K=(9.999958540637026, 99.99992566031773, -7.049643270657257e-10)
# [Iter 0] Pre-split gap: -1.025294e-01 (-1.042%)
# [Iter 0] Active simplex ratio = 1.000000
# [Iter 0] UB point (9.999958540637026, 99.99992566031773, -7.049643270657257e-10) is geometrically in simplices [3]
#   T3 verts=[3, 6, 7, 4]: λ=[0.000002, 0.500000, 0.499998, 0.000000], LB=10.004422514, c_s=[0.9973765252119483, 0.9689626047948585, 0.9989072529234528, 1.0700789662624872, 0.9700182463479814, 1.0047487588156836, 1.013053930372056, 0.981013774823401, 1.042956669655777, 0.9573057849019528]
#
# == [Iter 0] CS DUAL vs PRIMAL diagnostic (simplices containing UB point) ==
#   --- T3 ---
#     scen 0: status=optimal, dual=0.997376525, primal=0.997376525  ✓ dual ≤ primal (gap=1.110223e-16)
#              cs_primal_K=(9.999231675757967, 99.99864227385171, 1.3957947968559532)
#              indep_Q(cs_K)=0.997376525  → dual ≤ indep_Q (consistent, diff=2.363576e-11)
#     scen 1: status=optimal, dual=0.968962605, primal=0.968962605  ✓ dual ≤ primal (gap=-3.330669e-16)
#              cs_primal_K=(9.999999572689289, 1.1097568111452458, 1.0423394345803618)
#              indep_Q(cs_K)=0.968962976  → dual ≤ indep_Q (consistent, diff=3.712762e-07)
#     scen 2: status=optimal, dual=0.998907253, primal=0.998907253  ✓ dual ≤ primal (gap=0.000000e+00)
#              cs_primal_K=(9.999999771711662, 2.491993667591921, 1.859476284515915)
#              indep_Q(cs_K)=0.998907251  → dual ≤ indep_Q (consistent, diff=-1.950279e-09)
#     scen 3: status=optimal, dual=1.070078966, primal=1.070078966  ✓ dual ≤ primal (gap=0.000000e+00)
#              cs_primal_K=(9.999767793104557, 99.99959011225656, 1.0237424050442065)
#              indep_Q(cs_K)=1.070078975  → dual ≤ indep_Q (consistent, diff=8.972497e-09)
#     scen 4: status=optimal, dual=0.970018246, primal=0.970018246  ✓ dual ≤ primal (gap=2.220446e-16)
#              cs_primal_K=(9.866175222295812, 99.52985603445731, -0.30916151291187327)
#              indep_Q(cs_K)=0.970018250  → dual ≤ indep_Q (consistent, diff=4.100260e-09)
#     scen 5: status=optimal, dual=1.004748759, primal=1.004748759  ✓ dual ≤ primal (gap=0.000000e+00)
#              cs_primal_K=(9.877598344943978, -0.01161207510126663, -0.011612070022654939)
#              indep_Q(cs_K)=1.004748839  → dual ≤ indep_Q (consistent, diff=8.036176e-08)
#     scen 6: status=optimal, dual=1.013053930, primal=1.013053930  ✓ dual ≤ primal (gap=2.220446e-16)
#              cs_primal_K=(9.999220491647536, 99.99893376588902, 2.6318398488971173)
#              indep_Q(cs_K)=1.013053940  → dual ≤ indep_Q (consistent, diff=9.362785e-09)
#     scen 7: status=optimal, dual=0.981013775, primal=0.981013775  ✓ dual ≤ primal (gap=-1.110223e-16)
#              cs_primal_K=(7.323316842461316, 14.48184422613067, -0.2554187825837147)
#              indep_Q(cs_K)=0.981013776  → dual ≤ indep_Q (consistent, diff=7.248879e-10)
#     scen 8: status=optimal, dual=1.042956670, primal=1.042956670  ✓ dual ≤ primal (gap=-2.220446e-16)
#              cs_primal_K=(8.516370645134204, 66.27525695317497, -0.16189361862791743)
#              indep_Q(cs_K)=1.042956674  → dual ≤ indep_Q (consistent, diff=4.512491e-09)
#     scen 9: status=optimal, dual=0.957305785, primal=0.957305785  ✓ dual ≤ primal (gap=-1.110223e-16)
#              cs_primal_K=(9.9974342985267, 99.99567975787635, 1.4998092832885586)
#              indep_Q(cs_K)=0.957305786  → dual ≤ indep_Q (consistent, diff=1.134159e-09)
#   sum(c_s_dual)=10.004422514, UB_total=98.352051730, UB_per_scen=9.835205173
#
#   == Per-scenario Q_s at K_EF = (9.999958540637026, 99.99992566031773, -7.049643270657257e-10) ==
#     scen 0: Q_s(K_EF)=0.999116649, c_s_dual=0.997376525  ✓ Q_s(K_EF) > c_s_dual (diff=1.740124e-03)
#     scen 1: Q_s(K_EF)=0.945900803, c_s_dual=0.968962605  ⚠ Q_s(K_EF) < c_s_dual → GUROBI CS DUAL IS WRONG
#     scen 2: Q_s(K_EF)=0.959650851, c_s_dual=0.998907253  ⚠ Q_s(K_EF) < c_s_dual → GUROBI CS DUAL IS WRONG
#     scen 3: Q_s(K_EF)=1.071128443, c_s_dual=1.070078966  ✓ Q_s(K_EF) > c_s_dual (diff=1.049477e-03)
#     scen 4: Q_s(K_EF)=0.969499444, c_s_dual=0.970018246  ⚠ Q_s(K_EF) < c_s_dual → GUROBI CS DUAL IS WRONG
#     scen 5: Q_s(K_EF)=0.943144820, c_s_dual=1.004748759  ⚠ Q_s(K_EF) < c_s_dual → GUROBI CS DUAL IS WRONG
#     scen 6: Q_s(K_EF)=1.019693814, c_s_dual=1.013053930  ✓ Q_s(K_EF) > c_s_dual (diff=6.639884e-03)
#     scen 7: Q_s(K_EF)=0.947579028, c_s_dual=0.981013775  ⚠ Q_s(K_EF) < c_s_dual → GUROBI CS DUAL IS WRONG
#     scen 8: Q_s(K_EF)=1.020298677, c_s_dual=1.042956670  ⚠ Q_s(K_EF) < c_s_dual → GUROBI CS DUAL IS WRONG
#     scen 9: Q_s(K_EF)=0.959192644, c_s_dual=0.957305785  ✓ Q_s(K_EF) > c_s_dual (diff=1.886859e-03)
#     SUM Q_s(K_EF)=9.835205173, sum(c_s)=10.004422514, diff=-1.692173e-01
#
# [Iter 0] LB = 9.937735 = UB(9.835205) + ms_b(-5.791e+10) from T3
# [Iter 0] Scene 0: Switched to c_s point. dist_ms_c=1.87e+01 < 1000.0, dist_c_verts=9.86e+01 > 1e-06
# [Iter 0] Scene 1: Switched to c_s point. dist_ms_c=1.00e+02 < 1000.0, dist_c_verts=1.40e+02 > 1e-06
# [Iter 0] Scene 2: Switched to c_s point. dist_ms_c=9.93e+01 < 1000.0, dist_c_verts=1.38e+02 > 1e-06
# [Iter 0] Scene 3: Switched to c_s point. dist_ms_c=1.57e+01 < 1000.0, dist_c_verts=9.90e+01 > 1e-06
# [Iter 0] Scene 4: Switched to c_s point. dist_ms_c=1.64e+01 < 1000.0, dist_c_verts=9.97e+01 > 1e-06
# [Iter 0] Scene 5: Switched to c_s point. dist_ms_c=1.01e+02 < 1000.0, dist_c_verts=1.41e+02 > 1e-06
# [Iter 0] Scene 6: Switched to c_s point. dist_ms_c=1.96e+01 < 1000.0, dist_c_verts=9.74e+01 > 1e-06
# [Iter 0] Scene 7: Switched to c_s point. dist_ms_c=8.74e+01 < 1000.0, dist_c_verts=1.31e+02 > 1e-06
# [Iter 0] Scene 8: Switched to c_s point. dist_ms_c=3.74e+01 < 1000.0, dist_c_verts=1.05e+02 > 1e-06
# [Iter 0] Scene 9: Switched to c_s point. dist_ms_c=1.89e+01 < 1000.0, dist_c_verts=9.85e+01 > 1e-06
# Chosen node (7.323316842461316, 14.48184422613067, -0.2554187825837147) with ms=-5.912e+09 (simp T3, scene 7, rank #1, source=c_s)
# [Iter 0] LB simplex = T3, next node simplex = T3, scene 7
# [Selected Simp Info] Iter 0 | Simplex T3 Vertices:
#   v0: (-10.0, 100.0, 100.0)
#   v1: (10.0, 100.0, -100.0)
#   v2: (10.0, 100.0, 100.0)
#   v3: (10.0, -100.0, -100.0)
#   -> New Point: (7.323316842461316, 14.48184422613067, -0.2554187825837147)
# [Iter 0] candidate rank #1: T3, scene=7, ms=-5.912e+09
# == ms candidates (sorted by (ms, -dist)) ==
# rank   simp   scene           ms    mind(all)                             pt
# ----------------------------------------------------------------------------
#    1     T3       7  -5.9124e+09     1.31e+02     (7.3233, 14.4818, -0.2554)
#    2     T3       9  -5.8460e+09     9.85e+01      (9.9974, 99.9957, 1.4998)
#    3     T3       6  -5.8452e+09     9.74e+01      (9.9992, 99.9989, 2.6318)
#    4     T3       2  -5.8396e+09     1.38e+02      (10.0000, 2.4920, 1.8595)
#    5     T3       5  -5.7776e+09     1.41e+02     (9.8776, -0.0116, -0.0116)
#    6     T3       0  -5.7766e+09     9.86e+01      (9.9992, 99.9986, 1.3958)
#    7     T3       8  -5.7378e+09     1.05e+02     (8.5164, 66.2753, -0.1619)
#    8     T3       3  -5.7356e+09     9.90e+01      (9.9998, 99.9996, 1.0237)
#    9     T3       1  -5.7193e+09     1.40e+02      (10.0000, 1.1098, 1.0423)
#   10     T3       4  -5.7188e+09     9.97e+01     (9.8662, 99.5299, -0.3092)
#
# [Iter 0] per_tet=6, active after q_cut=6, tri_is_None=False
# [Iter 0] bad-quality active simplices (q < 0): 0
# [Iter 0] evaluating Q for scenario 0
# [Iter 0] evaluating Q for scenario 1
# [Iter 0] evaluating Q for scenario 2
# [Iter 0] evaluating Q for scenario 3
# [Iter 0] evaluating Q for scenario 4
# [Iter 0] evaluating Q for scenario 5
# [Iter 0] evaluating Q for scenario 6
# [Iter 0] evaluating Q for scenario 7
# [Iter 0] evaluating Q for scenario 8
# [Iter 0] evaluating Q for scenario 9
#
# [Iter 0] Next Point Details:
# Simplex   Scene   Type    As             ms             As+ms          Q              (Kp, Ki, Kd)
# --------------------------------------------------------------------------------------------------------------------
# T3        7       c_s     7.3686e+08     -5.9124e+09    -5.1755e+09    9.8101e-01     (7.3233, 14.4818, -0.2554)
#
# [Iter 0] subdivision type = interior (code=1) on simplex T3
# [Iter 0] Elapsed: 46.403s
# [Invariant] MS scen None: dual=-5.881979e+09 > primal=-5.881979e+09
# [Invariant] MS scen None: dual=-5.903047e+09 > primal=-5.903047e+09
# [Invariant] MS scen None: dual=-5.791876e+09 > primal=-5.791876e+09
# [Invariant] MS scen None: dual=-5.831236e+09 > primal=-5.831236e+09
# [Invariant] MS scen None: dual=-5.399000e+09 > primal=-5.399000e+09
# [Invariant] MS scen None: dual=-5.598779e+09 > primal=-5.598779e+09
# [Invariant] MS scen None: dual=-5.535988e+09 > primal=-5.535988e+09
# [Invariant] MS scen None: dual=-5.552550e+09 > primal=-5.552550e+09
# [Invariant] MS scen None: dual=-5.456614e+09 > primal=-5.456614e+09
# [Invariant] MS scen None: dual=-5.655904e+09 > primal=-5.655904e+09
# [Invariant] MS scen None: dual=-5.778877e+09 > primal=-5.778877e+09
# [Invariant] MS scen None: dual=-5.837837e+09 > primal=-5.837837e+09
# [Invariant] MS scen None: dual=-5.760327e+09 > primal=-5.760327e+09
# [Invariant] MS scen None: dual=-5.891628e+09 > primal=-5.891628e+09
# ======================================================================
# [Iter 0] LB SPLIT DIAGNOSTIC
#   Selected (parent) simplex: (3, 4, 6, 7)
#   Parent LB: 1.000442251 (per-scen)
#   UB in parent (pre-split): True  λ=[0.00000207, 0.49999963, 0.49999793, 0.00000037]
#   EF ef_obj(IPOPT): 0.098352051, true_obj(recalc): 0.983520517, used=min=0.098352051 (per-scen)
#   Simplex volume: 1.333333e+05
#   Children (4):
#     T5 (4, 6, 7, 8): LB = 1.025384737, avg_cs = 1.025384737
#     T6 (3, 4, 7, 8): LB = 1.085742137, avg_cs = 1.085742137
#     T7 (3, 4, 6, 8): LB = 0.988529172, avg_cs = 0.988529172
#     T8 (3, 6, 7, 8): LB = 0.997949317, avg_cs = 0.997949317
#   New global LB: 0.988529172 (from T7 (3, 4, 6, 8))
#   Location: INSIDE
#   Avg CS point Q-value: 0.991928489 (per-scen), point=(np.float64(9.5579114658273), np.float64(58.38699415272724), np.float64(0.8714916069035951))
#   Current UB: 0.983520517 (per-scen)
#   UB point: (9.999958540637026, 99.99992566031773, -7.049643270657257e-10)
#   UB source: EF_ipopt
#   UB simplex: (3, 4, 6, 7)
#   EF-IPOPT: ok=True, status=ok, term=optimal, time=0.391s, ef_obj=0.9835205133382454, true_obj(per-scen)=0.983520517
#   UB in child simplex (post-split): True
#     CHILD: T8 (3, 6, 7, 8) (LB=0.997949317, λ=[0.00000196, 0.49999956, 0.49999761, 0.00000087])
# ======================================================================
# [BaseBundle.eval_at] Infeasible/Error for K=(10.000000000000002, 100.00000000000001, -17.323265753052972): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(1.4507197035153323, 98.52499633628024, -13.800202748889472): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(3.741632859473526, 99.99999999999999, -15.208922291275565): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(3.741632859473526, 99.99999999999999, -15.208922291275565): status=warning, term=infeasibleOrUnbounded
# [Iter 0] WARNING: UB candidate (avgCS) 9.845014e-01 < LB 9.885292e-01 (potential invalid LB)
#
# ======================================================================
# [TIMING] === Iter 0 phase breakdown (total 265.91s) ===
#   1_vertex_UB                    :       0.00s  (  0.0%)
#   2_evaluate_all_tetra           :      45.63s  ( 17.2%)  ########
#   3_active_filter_print          :       0.00s  (  0.0%)
#   4_LB_selection                 :       0.00s  (  0.0%)
#   5_EF_UB_solve                  :       0.69s  (  0.3%)
#   6_candidate_selection          :       0.00s  (  0.0%)
#   7_Q_eval_new_node              :       0.07s  (  0.0%)
#   8_mesh_subdivide               :       0.00s  (  0.0%)
#   9_end_of_iter_reeval           :     219.50s  ( 82.5%)  #########################################
#   TOTAL                          :     265.91s
#   #simplices=6, #scenarios=10, total_ms_pairs=60
#   fresh ms solves=60, cache hits=0
# ======================================================================
#
# [Iter 0] Stop: UB-LB gap -5.092578e-03 <= tol 1.000000e-06.
#
# ===== Simplex search summary (per-scenario) =====
#   Time (s)  # Nodes             LB             UB   Rel. Gap   Abs. Gap   #simplex    #active   Split       Selection
# ---------------------------------------------------------------------------------------------------------------------
#     46.155        8    0.988529172    0.983520517   -0.5093%   -0.00501          6          6    none             c_s
# [Time] Main loop total: 267.168s
#
# ==== Done ====
# Total nodes: 9
# Best UB: 9.835205172962867
# Last LB: 9.885291722570347
