# %%
from time import perf_counter  

from modeling import build_models_from_csv
from bundles import BaseBundle, MSBundle
from utils import (
    tighten_bounds_one_model,
    MIN_DIST, ACTIVE_TOL, GAP_STOP_TOL,
)
from simplex_specialstart import run_pid_simplex_3d

# setup scenario number and target_nodesk
csv_path       = "data.csv"
max_scenarios  = 5
target_nodes   = 1000

bounds={
    "Kp": (-10.0, 10.0),
    "Ki": (-100.0, 100.0),
    "Kd": (-100.0, 100.0),
    "x": (-2.5, 2.5),
    "u": (-5.0, 5.0),
    "e": (None, None),
    "I": (None, None),
}

weights = (10.0, 0.01)


# ====== stage 1：load data and generate models ======
T   = 15.0          
nfe = 20            

t_load0 = perf_counter()
model_list, first_stg_vars_list, m_tmpl_list, nfe = build_models_from_csv(
    csv_path=csv_path,
    T=T,
    nfe=nfe,
    weights=weights,
    bounds=bounds,
    sp0=0.0,
    sp1=0.5,
    tau_xs_col="tau_xs",
    tau_us_col="tau_us",
    tau_ds_col="tau_ds",          
    disturb_prefix="disturbance_",
    setpoint_change_col="setpoint_change",
    max_scenarios=max_scenarios,
    skip=0,
)
t_load1 = perf_counter()
print(f"[Time] Data load & scenario build: {t_load1 - t_load0:.3f}s")


# ====== stage 1.5：FBBT / OBBT ======
# same as snog: FBBT open,OBBT open
obbt_solver_opts = {
    "NonConvex": 2,
    "MIPGap": 1,     
    "TimeLimit": 15   
}
for m, yvars in zip(model_list, first_stg_vars_list):
    tighten_bounds_one_model(m, yvars,
                             use_fbbt=False,
                             use_obbt=False,
                             obbt_solver_name="gurobi",
                             obbt_solver_opts=obbt_solver_opts,
                             max_rounds=3, tol=1e-6, verbose=True)

# ====== stage 2: Persistent Solver Packaging ======
ub_options = {
    'NonConvex': 2,      
}
lb_options = {
    'NonConvex': 2,
    'MIPGap': 1e-1,            
    'TimeLimit': 15
}

t_wrap0 = perf_counter()
base_bundles = [BaseBundle(m, ub_options) for m in model_list]  
ms_bundles   = [MSBundle(m, yvars, lb_options) for m, yvars in zip(model_list, first_stg_vars_list)]  
t_wrap1 = perf_counter()
print(f"[Time] Persistent wrapper (GurobiPersistent) setup: {t_wrap1 - t_wrap0:.3f}s")

# ====== stage 3：main loop ======
agg_bundle = None  

t_run0 = perf_counter()
hist = run_pid_simplex_3d(
    base_bundles=base_bundles,
    ms_bundles=ms_bundles,
    model_list=model_list,
    first_vars_list=first_stg_vars_list,
    target_nodes=target_nodes,
    min_dist=0,
    active_tol=ACTIVE_TOL,
    verbose=True,
    agg_bundle=agg_bundle,
    gap_stop_tol=1e-6,
    use_exact_opt=False,
    exact_solver_name="gurobi",
    exact_solver_opts={"NonConvex": 2, "TimeLimit": 60},
    time_limit=60*30*1,
    enable_3d_plot=False,   
    plot_every=None,        
)
t_run1 = perf_counter()
print(f"[Time] Main loop total: {t_run1 - t_run0:.3f}s")

# ====== print output ======
print("\n==== Done ====")
print(f"Total nodes: {len(hist['nodes'])}")
print(f"Best UB: {min(hist['UB_hist']) if hist['UB_hist'] else None}")
print(f"Last LB: {hist['LB_hist'][-1] if hist['LB_hist'] else None}")
# Out:
# [Time] Data load & scenario build: 0.138s
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 15
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 15
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 15
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 15
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 15
# [Time] Persistent wrapper (GurobiPersistent) setup: 0.405s
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=warning, term=other
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [TIMING] Pre-loop vertex Q evals: 0.77s  (8 nodes x 5 scenarios = 40 solves)
# [EF-UB] Initialized ipopt EF with 5 scenarios, time_ub=60.0s
#
# ======================================================================
# [TIMING] === Pre-loop phase summary ===
#   corners_and_mesh               :       0.04s
#   vertex_Q_evals                 :       0.77s
#   exact_optima                   :       0.00s
#   ef_init                        :       0.02s
#   TOTAL                          :       0.83s
# ======================================================================
#
# [Iter 0] MIPGap overridden to 0.1 (original: 0.1)
# Discarded solution information
# Discarded solution information
# [Invariant] MS scen None: dual=-5.482342e+09 > primal=-5.482342e+09
# Discarded solution information
# [Invariant] MS scen None: dual=-5.520747e+09 > primal=-5.520747e+09
# Discarded solution information
# Discarded solution information
# [Invariant] MS scen None: dual=-5.782267e+09 > primal=-5.782267e+09
# [Invariant] MS scen None: dual=-5.879453e+09 > primal=-5.879453e+09
# [Invariant] MS scen None: dual=-5.752537e+09 > primal=-5.752537e+09
# [Invariant] MS scen None: dual=-5.673500e+09 > primal=-5.673500e+09
# [Invariant] MS scen None: dual=-5.786091e+09 > primal=-5.786091e+09
# [Invariant] MS scen None: dual=-5.607264e+09 > primal=-5.607264e+09
# [Invariant] MS scen None: dual=-5.626301e+09 > primal=-5.626301e+09
# [Invariant] MS scen None: dual=-5.742972e+09 > primal=-5.742972e+09
# [Bundle] MS scen None: infeasibleOrUnbounded. ms_val=nan.
# [Bundle] MS scen None: not optimal. Status=warning, Term=infeasibleOrUnbounded.
# [Invariant] MS scen None: dual=-5.810805e+09 > primal=-5.810805e+09
# [Invariant] MS scen None: dual=-5.868426e+09 > primal=-5.868426e+09
# [Iter 0] MIPGap restored to 0.1
# [Iter 0] #simplices = 6, #active = 6, bad-quality cut = 0, bad-shape cut = 0
# == [Iter 0] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.000986e+00      4.574690e+09     -2.712655e+10      5.004929e+00     [1.12e+01, 5.00e+10]    [-2.71e+10, 2.29e+10]     1
# T1            9.956027e-01      4.060486e+09     -2.969757e+10      4.978014e+00     [1.12e+01, 5.00e+10]    [-2.97e+10, 2.03e+10]     1
# T2            1.025007e+00      4.471772e+09     -2.764114e+10      5.125034e+00     [1.11e+01, 5.00e+10]    [-2.76e+10, 2.24e+10]     1
# T3            1.006635e+00      4.219633e+09     -2.890183e+10      5.033173e+00     [1.11e+01, 5.00e+10]    [-2.89e+10, 2.11e+10]     1
# T4            1.123946e+00      4.332879e+09     -2.833561e+10      5.619732e+00     [1.36e+01, 5.00e+10]    [-2.83e+10, 2.17e+10]     2
# T5            1.039181e+00               inf               inf      5.195905e+00     [1.36e+01, 5.00e+10]               [inf, inf]     2
#
# == [Iter 0] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
#   (none)
# [Iter 0] created=6 (cum=6), active=6, active+UB=2, ms_recomputed=6
# [Iter 0] UB-simplex selection: UB_node in simplices [2, 3], chose T3 (LB=1.006634653)
# [Iter 0] EF-ipopt: ok=False, ef_obj=nan, true_obj=N/A, time=1.443s
# [Iter 0] EF-UB: both solvers failed
# [Iter 0] Pre-split gap: 6.141461e+00 (55.232%)
# [Iter 0] Active simplex ratio = 1.000000
# [Iter 0] UB point (10.0, 100.0, 100.0) is geometrically in simplices [2, 3]
#   T2 verts=[3, 5, 7, 4]: λ=[0.000000, -0.000000, 1.000000, -0.000000], LB=5.125034445, c_s=[1.0619646213750884, 0.9701148580842887, 1.012319954298818, 1.0687384131728885, 1.0118965983842654]
#   T3 verts=[3, 6, 7, 4]: λ=[0.000000, -0.000000, 1.000000, -0.000000], LB=5.033173265, c_s=[0.9973765252125791, 0.9632727899553029, 0.9559885161504325, 1.147424038906536, 0.9691113942881817]
#
# == [Iter 0] CS DUAL vs PRIMAL diagnostic (simplices containing UB point) ==
#   --- T2 ---
#     scen 0: status=optimal, dual=1.061964621, primal=1.061964621  ✓ dual ≤ primal (gap=4.440892e-16)
#              cs_primal_K=(10.0, -100.0, -6.61954562903385)
#              indep_Q(cs_K)=1.061964627  → dual ≤ indep_Q (consistent, diff=5.395622e-09)
#     scen 1: status=optimal, dual=0.970114858, primal=0.970114858  ✓ dual ≤ primal (gap=-2.220446e-16)
#              cs_primal_K=(9.999999594206525, 0.9866207247408044, 1.0643934752246185)
#              indep_Q(cs_K)=0.970115257  → dual ≤ indep_Q (consistent, diff=3.989788e-07)
#     scen 2: status=optimal, dual=1.012319954, primal=1.012319954  ✓ dual ≤ primal (gap=-2.220446e-16)
#              cs_primal_K=(3.4160765728331377, -34.16076572833138, -0.1333514170148284)
#              indep_Q(cs_K)=1.012320002  → dual ≤ indep_Q (consistent, diff=4.733003e-08)
#     scen 3: status=optimal, dual=1.068738413, primal=1.068738413  ✓ dual ≤ primal (gap=-4.440892e-16)
#              cs_primal_K=(9.999947658154277, -99.99909920111641, 5.505484866903614e-09)
#              indep_Q(cs_K)=1.068738413  → dual ≤ indep_Q (consistent, diff=1.037235e-10)
#     scen 4: status=optimal, dual=1.011896598, primal=1.011896598  ✓ dual ≤ primal (gap=0.000000e+00)
#              cs_primal_K=(3.9605368283930398, -39.605368283930396, 0.001976599330060753)
#              indep_Q(cs_K)=1.011896608  → dual ≤ indep_Q (consistent, diff=9.564114e-09)
#   sum(c_s_dual)=5.125034445, UB_total=55.597371111, UB_per_scen=11.119474222
#
#   == Per-scenario Q_s at K_EF = (10.0, 100.0, 100.0) ==
#     scen 0: Q_s(K_EF)=2.194572859, c_s_dual=1.061964621  ✓ Q_s(K_EF) > c_s_dual (diff=1.132608e+00)
#     scen 1: Q_s(K_EF)=2.178377902, c_s_dual=0.970114858  ✓ Q_s(K_EF) > c_s_dual (diff=1.208263e+00)
#     scen 2: Q_s(K_EF)=2.188377472, c_s_dual=1.012319954  ✓ Q_s(K_EF) > c_s_dual (diff=1.176058e+00)
#     scen 3: Q_s(K_EF)=2.339403430, c_s_dual=1.068738413  ✓ Q_s(K_EF) > c_s_dual (diff=1.270665e+00)
#     scen 4: Q_s(K_EF)=2.218742559, c_s_dual=1.011896598  ✓ Q_s(K_EF) > c_s_dual (diff=1.206846e+00)
#     SUM Q_s(K_EF)=11.119474222, sum(c_s)=5.125034445, diff=5.994440e+00
#   --- T3 ---
#     scen 0: status=optimal, dual=0.997376525, primal=0.997376525  ✓ dual ≤ primal (gap=-1.110223e-16)
#              cs_primal_K=(9.99923165569858, 99.99864221309052, 1.395794796781228)
#              indep_Q(cs_K)=0.997376525  → dual ≤ indep_Q (consistent, diff=5.538170e-11)
#     scen 1: status=optimal, dual=0.963272790, primal=0.963272790  ✓ dual ≤ primal (gap=-1.110223e-16)
#              cs_primal_K=(9.999999436980861, 2.2542349630472027, 0.9570637044372343)
#              indep_Q(cs_K)=0.963272793  → dual ≤ indep_Q (consistent, diff=3.538892e-09)
#     scen 2: status=optimal, dual=0.955988516, primal=0.955988516  ✓ dual ≤ primal (gap=-2.220446e-16)
#              cs_primal_K=(9.993045203208826, 99.9903288635917, 2.0319550327665548)
#              indep_Q(cs_K)=0.955988518  → dual ≤ indep_Q (consistent, diff=1.879947e-09)
#     scen 3: status=optimal, dual=1.147424039, primal=1.147424039  ✓ dual ≤ primal (gap=1.110223e-15)
#              cs_primal_K=(4.46578295802099, 64.95101740451302, -1.7866386940385905)
#              indep_Q(cs_K)=1.147424132  → dual ≤ indep_Q (consistent, diff=9.354697e-08)
#     scen 4: status=optimal, dual=0.969111394, primal=0.969111394  ✓ dual ≤ primal (gap=0.000000e+00)
#              cs_primal_K=(9.998630746909807, 99.99755347536319, 0.6671121890397128)
#              indep_Q(cs_K)=0.969111395  → dual ≤ indep_Q (consistent, diff=2.146726e-10)
#   sum(c_s_dual)=5.033173265, UB_total=55.597371111, UB_per_scen=11.119474222
#
#   == Per-scenario Q_s at K_EF = (10.0, 100.0, 100.0) ==
#     scen 0: Q_s(K_EF)=2.194572859, c_s_dual=0.997376525  ✓ Q_s(K_EF) > c_s_dual (diff=1.197196e+00)
#     scen 1: Q_s(K_EF)=2.178377902, c_s_dual=0.963272790  ✓ Q_s(K_EF) > c_s_dual (diff=1.215105e+00)
#     scen 2: Q_s(K_EF)=2.188377472, c_s_dual=0.955988516  ✓ Q_s(K_EF) > c_s_dual (diff=1.232389e+00)
#     scen 3: Q_s(K_EF)=2.339403430, c_s_dual=1.147424039  ✓ Q_s(K_EF) > c_s_dual (diff=1.191979e+00)
#     scen 4: Q_s(K_EF)=2.218742559, c_s_dual=0.969111394  ✓ Q_s(K_EF) > c_s_dual (diff=1.249631e+00)
#     SUM Q_s(K_EF)=11.119474222, sum(c_s)=5.033173265, diff=6.086301e+00
#
# [Iter 0] LB = 4.978014 = UB(11.119474) + ms_b(-2.890e+10) from T3
# [Iter 0] Scene 0: Switched to c_s point. dist_ms_c=1.85e+01 < 1000.0, dist_c_verts=9.86e+01 > 1e-06
# [Iter 0] Scene 1: Switched to c_s point. dist_ms_c=9.94e+01 < 1000.0, dist_c_verts=1.39e+02 > 1e-06
# [Iter 0] Scene 2: Switched to c_s point. dist_ms_c=1.90e+01 < 1000.0, dist_c_verts=9.80e+01 > 1e-06
# [Iter 0] Scene 3: Switched to c_s point. dist_ms_c=3.70e+01 < 1000.0, dist_c_verts=1.04e+02 > 1e-06
# [Iter 0] Scene 4: Switched to c_s point. dist_ms_c=1.82e+01 < 1000.0, dist_c_verts=9.93e+01 > 1e-06
# Chosen node (9.993045203208826, 99.9903288635917, 2.0319550327665548) with ms=-5.849e+09 (simp T3, scene 2, rank #1, source=c_s)
# [Iter 0] LB simplex = T3, next node simplex = T3, scene 2
# [Selected Simp Info] Iter 0 | Simplex T3 Vertices:
#   v0: (-10.0, 100.0, 100.0)
#   v1: (10.0, 100.0, -100.0)
#   v2: (10.0, 100.0, 100.0)
#   v3: (10.0, -100.0, -100.0)
#   -> New Point: (9.993045203208826, 99.9903288635917, 2.0319550327665548)
# [Iter 0] candidate rank #1: T3, scene=2, ms=-5.849e+09
# == ms candidates (sorted by (ms, -dist)) ==
# rank   simp   scene           ms    mind(all)                             pt
# ----------------------------------------------------------------------------
#    1     T3       2  -5.8491e+09     9.80e+01      (9.9930, 99.9903, 2.0320)
#    2     T3       0  -5.8406e+09     9.86e+01      (9.9992, 99.9986, 1.3958)
#    3     T3       4  -5.7861e+09     9.93e+01      (9.9986, 99.9976, 0.6671)
#    4     T3       1  -5.7525e+09     1.39e+02      (10.0000, 2.2542, 0.9571)
#    5     T3       3  -5.6735e+09     1.04e+02     (4.4658, 64.9510, -1.7866)
#
# [Iter 0] per_tet=6, active after q_cut=6, tri_is_None=False
# [Iter 0] bad-quality active simplices (q < 0): 0
# [Iter 0] evaluating Q for scenario 0
# [Iter 0] evaluating Q for scenario 1
# [Iter 0] evaluating Q for scenario 2
# [Iter 0] evaluating Q for scenario 3
# [Iter 0] evaluating Q for scenario 4
#
# [Iter 0] Next Point Details:
# Simplex   Scene   Type    As             ms             As+ms          Q              (Kp, Ki, Kd)
# --------------------------------------------------------------------------------------------------------------------
# T3        2       c_s     4.8979e+09     -5.8491e+09    -9.5116e+08    9.5599e-01     (9.9930, 99.9903, 2.0320)
#
# [Iter 0] subdivision type = interior (code=1) on simplex T3
# [Iter 0] Elapsed: 43.038s
# [Invariant] MS scen None: dual=-5.878357e+09 > primal=-5.878357e+09
# [Invariant] MS scen None: dual=-5.902921e+09 > primal=-5.902921e+09
# [Invariant] MS scen None: dual=-5.673056e+09 > primal=-5.673056e+09
# [Invariant] MS scen None: dual=-5.731268e+09 > primal=-5.731268e+09
# [Invariant] MS scen None: dual=-5.673635e+09 > primal=-5.673635e+09
# [Invariant] MS scen None: dual=-5.769661e+09 > primal=-5.769661e+09
# ======================================================================
# [Iter 0] LB SPLIT DIAGNOSTIC
#   Selected (parent) simplex: (3, 4, 6, 7)
#   Parent LB: 1.006634653 (per-scen)
#   UB in parent (pre-split): True  λ=[0.00000000, -0.00000000, 1.00000000, -0.00000000]
#   EF: N/A
#   Simplex volume: 1.333333e+05
#   Children (4):
#     T5 (4, 6, 7, 8): LB = 1.005686509, avg_cs = 1.005686509
#     T6 (3, 4, 7, 8): LB = 1.018612604, avg_cs = 1.018612604
#     T7 (3, 4, 6, 8): LB = 0.995120642, avg_cs = 0.995120642
#     T8 (3, 6, 7, 8): LB = 0.987769769, avg_cs = 0.987769769
#   New global LB: 0.987769769 (from T8 (3, 6, 7, 8))
#   Location: INSIDE
#   Avg CS point Q-value: 0.993777731 (per-scen), point=(np.float64(8.891338000163813), np.float64(73.43835538392112), np.float64(0.6530574057972279))
#   Current UB: 2.223894844 (per-scen)
#   UB point: (10.0, 100.0, 100.0)
#   UB source: unknown
#   UB simplex: None
#   EF-IPOPT: ok=False, status=warning, term=infeasible, time=1.443s, ef_obj=nan, true_obj(per-scen)=N/A
#   UB in child simplex (post-split): True
#     CHILD: T5 (4, 6, 7, 8) (LB=1.005686509, λ=[0.00000000, -0.00000000, 1.00000000, 0.00000000])
#     CHILD: T6 (3, 4, 7, 8) (LB=1.018612604, λ=[0.00000000, -0.00000000, 1.00000000, -0.00000000])
#     CHILD: T8 (3, 6, 7, 8) (LB=0.987769769, λ=[0.00000000, -0.00000000, 1.00000000, -0.00000000])
#     OLD:   T2 (3, 4, 5, 7) (LB=1.025006889, λ=[0.00000000, -0.00000000, 1.00000000, -0.00000000])
# ======================================================================
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -17.451227624085988): status=warning, term=infeasibleOrUnbounded
# [Iter 0] UB candidate from new simplex 5 (avgCS): 9.924050e-01 (per scenario)
# [BaseBundle.eval_at] Infeasible/Error for K=(1.343055760671519, 99.99999999425626, -13.43049705066646): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(3.4341102956362617, 99.9999999999802, -15.40531626635672): status=warning, term=infeasibleOrUnbounded
# [Iter 0] UB candidate from new simplex 8 (avgCS): 9.878874e-01 (per scenario)
#
# ======================================================================
# [TIMING] === Iter 0 phase breakdown (total 135.62s) ===
#   1_vertex_UB                    :       0.00s  (  0.0%)
#   2_evaluate_all_tetra           :      41.47s  ( 30.6%)  ###############
#   3_active_filter_print          :       0.00s  (  0.0%)
#   4_LB_selection                 :       0.00s  (  0.0%)
#   5_EF_UB_solve                  :       1.54s  (  1.1%)
#   6_candidate_selection          :       0.00s  (  0.0%)
#   7_Q_eval_new_node              :       0.02s  (  0.0%)
#   8_mesh_subdivide               :       0.00s  (  0.0%)
#   9_end_of_iter_reeval           :      92.58s  ( 68.3%)  ##################################
#   TOTAL                          :     135.62s
#   #simplices=6, #scenarios=5, total_ms_pairs=30
#   fresh ms solves=30, cache hits=0
# ======================================================================
#
# [Iter 1] #simplices = 9, #active = 1, bad-quality cut = 0, bad-shape cut = 0
# == [Iter 1] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T8            9.877698e-01      4.229734e+09     -2.885133e+10      4.938849e+00     [4.94e+00, 5.00e+10]    [-2.89e+10, 2.11e+10]     1
#
# == [Iter 1] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.000986e+00      4.574690e+09     -2.712655e+10      5.004929e+00     [1.12e+01, 5.00e+10]    [-2.71e+10, 2.29e+10]     1
# T1            9.956027e-01      4.060486e+09     -2.969757e+10      4.978014e+00     [1.12e+01, 5.00e+10]    [-2.97e+10, 2.03e+10]     1
# T2            1.025007e+00      4.471772e+09     -2.764114e+10      5.125034e+00     [1.11e+01, 5.00e+10]    [-2.76e+10, 2.24e+10]     1
# T3            1.123946e+00      4.332879e+09     -2.833561e+10      5.619732e+00     [1.36e+01, 5.00e+10]    [-2.83e+10, 2.17e+10]     2
# T4            1.039181e+00               inf               inf      5.195905e+00     [1.36e+01, 5.00e+10]               [inf, inf]     2
# T5            1.005687e+00      4.127439e+09     -2.936281e+10      5.028433e+00     [4.94e+00, 5.00e+10]    [-2.94e+10, 2.06e+10]     1
# T6            1.018613e+00      1.390491e+00     -6.687083e+00      5.093063e+00     [4.94e+00, 1.36e+01]    [-1.75e+00, 6.95e+00]     0
# T7            9.951206e-01      4.328478e+09     -2.835761e+10      4.975603e+00     [4.94e+00, 5.00e+10]    [-2.84e+10, 2.16e+10]     1
#
# [Iter 1] created=9 (cum=19), active=1, active+UB=1, ms_recomputed=0
# [Iter 1] UB-simplex selection: UB_node in simplices [5, 6, 7, 8], chose T8 (LB=0.987769769)
# [Iter 1] EF-ipopt: ok=True, ef_obj=0.9877387353522377, true_obj=9.877387e-01, time=0.401s
# [Iter 1] EF-UB improved by ipopt: 9.877387e-01 (per-scen), K=(9.999964806659976, 99.9999622054673, 1.2086478532983607)
# [Iter 1] Pre-split gap: -1.551022e-04 (-0.003%)
# [Iter 1] Active simplex ratio = 0.000008
# [Iter 1] UB point (9.999964806659976, 99.9999622054673, 1.2086478532983607) is geometrically in simplices [8]
#   T8 verts=[3, 6, 7, 8]: λ=[0.000000, 0.492042, 0.504049, 0.003908], LB=4.938848847, c_s=[0.9973768584212954, 0.9452253247776758, 0.956041655197767, 1.0700976874833594, 0.9701073209112815]
#
# == [Iter 1] CS DUAL vs PRIMAL diagnostic (simplices containing UB point) ==
#   --- T8 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(10.0, 100.0, 1.4242228284468403)
#              indep_Q(cs_K)=0.997376981
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(8.756526140698986, 99.99160356239553, 0.9580467935631037)
#              indep_Q(cs_K)=0.945225327
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(8.364108032607922, 99.99186211073949, 2.1563629523093892)
#              indep_Q(cs_K)=0.956041663
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(10.0, 100.0, 1.1672255523086477)
#              indep_Q(cs_K)=1.070097765
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(10.0, 100.0, -0.3892788630403822)
#              indep_Q(cs_K)=0.970107323
#   sum(c_s_dual)=0.000000000, UB_total=24.693468723, UB_per_scen=4.938693745
#
#   == Per-scenario Q_s at K_EF = (9.999964806659976, 99.9999622054673, 1.2086478532983607) ==
#     scen 0: Q_s(K_EF)=0.997405332, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945278839, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.956548974, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.070110239, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.969350361, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.938693745, sum(c_s)=0.000000000, diff=4.938694e+00
#
# [Iter 1] LB = 4.938849 = UB(4.938694) + ms_b(-2.885e+10) from T8
# [Iter 1] Scene 0: Switched to c_s point. dist_ms_c=1.79e+01 < 1000.0, dist_c_verts=6.08e-01 > 1e-06
# [Iter 1] Scene 1: Switched to c_s point. dist_ms_c=1.81e+01 < 1000.0, dist_c_verts=1.64e+00 > 1e-06
# [Iter 1] Scene 2: Switched to c_s point. dist_ms_c=1.84e+01 < 1000.0, dist_c_verts=1.63e+00 > 1e-06
# [Iter 1] Scene 3: Switched to c_s point. dist_ms_c=1.61e+01 < 1000.0, dist_c_verts=8.65e-01 > 1e-06
# [Iter 1] Scene 4: Switched to c_s point. dist_ms_c=1.72e+01 < 1000.0, dist_c_verts=2.42e+00 > 1e-06
# Chosen node (8.756526140699322, 99.99160356239554, 0.9580467935897272) with ms=-5.815e+09 (simp T8, scene 1, rank #1, source=c_s)
# [Iter 1] LB simplex = T8, next node simplex = T8, scene 1
# [Selected Simp Info] Iter 1 | Simplex T8 Vertices:
#   v0: (-10.0, 100.0, 100.0)
#   v1: (10.0, 100.0, -100.0)
#   v2: (10.0, 100.0, 100.0)
#   v3: (9.993045203208826, 99.9903288635917, 2.0319550327665548)
#   -> New Point: (8.756526140699322, 99.99160356239554, 0.9580467935897272)
# [Iter 1] candidate rank #1: T8, scene=1, ms=-5.815e+09
# == ms candidates (sorted by (ms, -dist)) ==
# rank   simp   scene           ms    mind(all)                             pt
# ----------------------------------------------------------------------------
#    1     T8       1  -5.8154e+09     1.64e+00      (8.7565, 99.9916, 0.9580)
#    2     T8       4  -5.8092e+09     2.42e+00   (10.0000, 100.0000, -0.3893)
#    3     T8       2  -5.7792e+09     1.63e+00      (8.3641, 99.9919, 2.1564)
#    4     T8       0  -5.7697e+09     6.08e-01    (10.0000, 100.0000, 1.4242)
#    5     T8       3  -5.6778e+09     8.65e-01    (10.0000, 100.0000, 1.1672)
#
# [Iter 1] per_tet=9, active after q_cut=1, tri_is_None=False
# [Iter 1] bad-quality active simplices (q < 0): 0
# [Iter 1] evaluating Q for scenario 0
# [Iter 1] evaluating Q for scenario 1
# [Iter 1] evaluating Q for scenario 2
# [Iter 1] evaluating Q for scenario 3
# [Iter 1] evaluating Q for scenario 4
#
# [Iter 1] Next Point Details:
# Simplex   Scene   Type    As             ms             As+ms          Q              (Kp, Ki, Kd)
# --------------------------------------------------------------------------------------------------------------------
# T8        1       c_s     6.9933e+08     -5.8154e+09    -5.1161e+09    9.4523e-01     (8.7565, 99.9916, 0.9580)
#
# [Iter 1] subdivision type = face (code=3) on simplex T8
#            face local verts = (3, 6, 8)
# [Iter 1] Elapsed: 0.621s
# [Invariant] MS scen None: dual=-5.857185e+09 > primal=-5.857185e+09
# [Invariant] MS scen None: dual=-5.675880e+09 > primal=-5.675880e+09
# [Invariant] MS scen None: dual=-5.899787e+09 > primal=-5.899787e+09
# [Invariant] MS scen None: dual=-5.855362e+09 > primal=-5.855362e+09
# ======================================================================
# [Iter 1] LB SPLIT DIAGNOSTIC
#   Selected (parent) simplex: (3, 6, 7, 8)
#   Parent LB: 0.987769769 (per-scen)
#   UB in parent (pre-split): True  λ=[0.00000040, 0.49204248, 0.50404915, 0.00390797]
#   EF ef_obj(IPOPT): 0.197547747, true_obj(recalc): 0.987738749, used=min=0.197547747 (per-scen)
#   Simplex volume: 6.447424e+00
#   Children (3):
#     T8 (6, 7, 8, 9): LB = 0.987578960, avg_cs = 0.987578960
#     T9 (3, 7, 8, 9): LB = 0.987765715, avg_cs = 0.987765715
#     T10 (3, 6, 7, 9): LB = 0.987710112, avg_cs = 0.987710112
#   New global LB: 0.987578960 (from T8 (6, 7, 8, 9))
#   Location: INSIDE
#   Avg CS point Q-value: 0.987887377 (per-scen), point=(np.float64(9.424126834661383), np.float64(99.99669313462701), np.float64(1.0633158527175197))
#   Current UB: 0.987738749 (per-scen)
#   UB point: (9.999964806659976, 99.9999622054673, 1.2086478532983607)
#   UB source: EF_ipopt
#   UB simplex: (3, 6, 7, 8)
#   EF-IPOPT: ok=True, status=ok, term=optimal, time=0.401s, ef_obj=0.9877387353522377, true_obj(per-scen)=0.987738749
#   UB in child simplex (post-split): True
#     CHILD: T8 (6, 7, 8, 9) (LB=0.987578960, λ=[0.00000648, 0.49204203, 0.00390235, 0.50404915])
# ======================================================================
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -16.87240145827088): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(7.253051741121958, 100.00000000004121, -16.86471404747839): status=warning, term=infeasibleOrUnbounded
#
# ======================================================================
# [TIMING] === Iter 1 phase breakdown (total 19.51s) ===
#   1_vertex_UB                    :       0.00s  (  0.0%)
#   2_evaluate_all_tetra           :       0.00s  (  0.0%)
#   3_active_filter_print          :       0.00s  (  0.0%)
#   4_LB_selection                 :       0.00s  (  0.0%)
#   5_EF_UB_solve                  :       0.58s  (  2.9%)  #
#   6_candidate_selection          :       0.00s  (  0.0%)
#   7_Q_eval_new_node              :       0.04s  (  0.2%)
#   8_mesh_subdivide               :       0.00s  (  0.0%)
#   9_end_of_iter_reeval           :      18.89s  ( 96.8%)  ################################################
#   TOTAL                          :      19.51s
#   #simplices=9, #scenarios=5, total_ms_pairs=45
#   fresh ms solves=0, cache hits=45
# ======================================================================
#
# [Iter 2] #simplices = 11, #active = 2, bad-quality cut = 0, bad-shape cut = 0
# == [Iter 2] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T8            9.875790e-01      4.156380e+09     -2.921810e+10      4.937895e+00     [4.94e+00, 5.00e+10]    [-2.92e+10, 2.08e+10]     1
# T10           9.877101e-01      4.156764e+09     -2.921618e+10      4.938551e+00     [4.94e+00, 5.00e+10]    [-2.92e+10, 2.08e+10]     1
#
# == [Iter 2] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.000986e+00      4.574690e+09     -2.712655e+10      5.004929e+00     [1.12e+01, 5.00e+10]    [-2.71e+10, 2.29e+10]     1
# T1            9.956027e-01      4.060486e+09     -2.969757e+10      4.978014e+00     [1.12e+01, 5.00e+10]    [-2.97e+10, 2.03e+10]     1
# T2            1.025007e+00      4.471772e+09     -2.764114e+10      5.125034e+00     [1.11e+01, 5.00e+10]    [-2.76e+10, 2.24e+10]     1
# T3            1.123946e+00      4.332879e+09     -2.833561e+10      5.619732e+00     [1.36e+01, 5.00e+10]    [-2.83e+10, 2.17e+10]     2
# T4            1.039181e+00               inf               inf      5.195905e+00     [1.36e+01, 5.00e+10]               [inf, inf]     2
# T5            1.005687e+00      4.127439e+09     -2.936281e+10      5.028433e+00     [4.94e+00, 5.00e+10]    [-2.94e+10, 2.06e+10]     1
# T6            1.018613e+00      1.390491e+00     -6.687083e+00      5.093063e+00     [4.94e+00, 1.36e+01]    [-1.75e+00, 6.95e+00]     0
# T7            9.951206e-01      4.328478e+09     -2.835761e+10      4.975603e+00     [4.94e+00, 5.00e+10]    [-2.84e+10, 2.16e+10]     1
# T9            9.877657e-01      2.500265e+00     -1.110847e+00      4.938829e+00     [4.94e+00, 1.36e+01]     [3.83e+00, 1.25e+01]     0
#
# [Iter 2] created=11 (cum=33), active=2, active+UB=2, ms_recomputed=0
# [Iter 2] UB-simplex selection: UB_node in simplices [7, 8, 9, 10], chose T8 (LB=0.987578960)
# [Iter 2] EF-ipopt: ok=True, ef_obj=0.987738757405091, true_obj=9.877388e-01, time=0.179s
# [Iter 2] Pre-split gap: 7.989433e-04 (0.016%)
# [Iter 2] Active simplex ratio = 0.000007
# [Iter 2] UB point (8.756526140699322, 99.99160356239554, 0.9580467935897272) is geometrically in simplices [7, 8, 9, 10]
#   T7 verts=[3, 6, 8, 4]: λ=[0.061872, 0.069933, 0.868196, -0.000000], LB=4.975603208, c_s=[0.9991217757689878, 0.9620830306798327, 0.9583854838865904, 1.074967104962017, 0.9810458122214656]
#   T8 verts=[9, 6, 8, 7]: λ=[1.000000, -0.000000, 0.000000, 0.000000], LB=4.937894801, c_s=[0.9974199124385996, 0.9452196141426574, 0.955996139598982, 1.070080597343867, 0.9691785377229587]
#   T9 verts=[3, 9, 8, 7]: λ=[0.000000, 1.000000, 0.000000, 0.000000], LB=4.938828574, c_s=[0.9975257763945318, 0.94522532278269, 0.9560054489150611, 1.070735249325236, 0.9693367761102449]
#   T10 verts=[3, 6, 9, 7]: λ=[0.000000, -0.000000, 1.000000, 0.000000], LB=4.938550558, c_s=[0.9974157026466834, 0.9452030940548032, 0.9560182434370159, 1.0700821110144987, 0.9698314069431353]
#
# == [Iter 2] CS DUAL vs PRIMAL diagnostic (simplices containing UB point) ==
#   --- T7 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.993183753590436, 99.99052152768817, -0.0006803886125672228)
#              indep_Q(cs_K)=0.999121884
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(5.071140501589126, 46.90377893563921, -0.9262897458072619)
#              indep_Q(cs_K)=0.962083032
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(3.424875621608243, 58.41452119097115, 1.6676768139286249)
#              indep_Q(cs_K)=0.958385560
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.192267450740088, 91.12763178979797, 1.4355534887196468)
#              indep_Q(cs_K)=1.074967108
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(5.881358576403716, 55.83257412105498, -0.3424334893473854)
#              indep_Q(cs_K)=0.981045813
#   sum(c_s_dual)=0.000000000, UB_total=24.693468723, UB_per_scen=4.938693745
#
#   == Per-scenario Q_s at K_EF = (8.756526140699322, 99.99160356239554, 0.9580467935897272) ==
#     scen 0: Q_s(K_EF)=0.997822755, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945225327, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.957024724, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.070998084, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.969336788, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.940407678, sum(c_s)=0.000000000, diff=4.940408e+00
#   --- T8 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(10.0, 100.0, 1.627965097339546)
#              indep_Q(cs_K)=0.997419914
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.069027256296748, 99.9913177903563, 0.8459188978127973)
#              indep_Q(cs_K)=0.945219615
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(10.0, 100.0, 1.9319694119738815)
#              indep_Q(cs_K)=0.955996141
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.998426692390018, 99.9978122045884, 1.0278589191151661)
#              indep_Q(cs_K)=1.070080651
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(10.0, 100.0, 0.9527009296387625)
#              indep_Q(cs_K)=0.969178567
#   sum(c_s_dual)=0.000000000, UB_total=24.693468723, UB_per_scen=4.938693745
#
#   == Per-scenario Q_s at K_EF = (8.756526140699322, 99.99160356239554, 0.9580467935897272) ==
#     scen 0: Q_s(K_EF)=0.997822755, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945225327, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.957024724, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.070998084, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.969336788, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.940407678, sum(c_s)=0.000000000, diff=4.940408e+00
#   --- T9 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.543796512498657, 99.99079198364058, 1.6417856572828315)
#              indep_Q(cs_K)=0.997525782
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(8.756526140699322, 99.99160356239554, 0.9580467935897272)
#              indep_Q(cs_K)=0.945225327
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.993055628591666, 99.99034336082326, 2.1788111387785984)
#              indep_Q(cs_K)=0.956005456
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.36990315425757, 99.99097124626779, 1.4907604803848429)
#              indep_Q(cs_K)=1.070735256
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(8.756526140699322, 99.99160356239554, 0.9580467935897272)
#              indep_Q(cs_K)=0.969336788
#   sum(c_s_dual)=0.000000000, UB_total=24.693468723, UB_per_scen=4.938693745
#
#   == Per-scenario Q_s at K_EF = (8.756526140699322, 99.99160356239554, 0.9580467935897272) ==
#     scen 0: Q_s(K_EF)=0.997822755, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945225327, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.957024724, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.070998084, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.969336788, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.940407678, sum(c_s)=0.000000000, diff=4.940408e+00
#   --- T10 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.914072717204894, 99.99958017811977, 1.237190646887888)
#              indep_Q(cs_K)=0.997415728
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(10.0, 100.0, 0.8546220163941842)
#              indep_Q(cs_K)=0.945203095
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(8.770016998401555, 99.99169465811426, 2.03258558473292)
#              indep_Q(cs_K)=0.956018243
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(10.0, 100.0, 0.9628317441115433)
#              indep_Q(cs_K)=1.070082116
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(10.0, 100.0, -0.23524045674529653)
#              indep_Q(cs_K)=0.969831413
#   sum(c_s_dual)=0.000000000, UB_total=24.693468723, UB_per_scen=4.938693745
#
#   == Per-scenario Q_s at K_EF = (8.756526140699322, 99.99160356239554, 0.9580467935897272) ==
#     scen 0: Q_s(K_EF)=0.997822755, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945225327, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.957024724, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.070998084, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.969336788, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.940407678, sum(c_s)=0.000000000, diff=4.940408e+00
#
# [Iter 2] LB = 4.937895 = UB(4.938694) + ms_b(-2.922e+10) from T8
# [Iter 2] Scene 0: Switched to c_s point. dist_ms_c=1.93e+01 < 1000.0, dist_c_verts=4.04e-01 > 1e-06
# [Iter 2] Scene 1: Switched to c_s point. dist_ms_c=1.89e+01 < 1000.0, dist_c_verts=3.32e-01 > 1e-06
# [Iter 2] Scene 2: Switched to c_s point. dist_ms_c=1.91e+01 < 1000.0, dist_c_verts=1.01e-01 > 1e-06
# [Iter 2] Scene 3: Switched to c_s point. dist_ms_c=1.45e+01 < 1000.0, dist_c_verts=1.00e+00 > 1e-06
# [Iter 2] Scene 4: Switched to c_s point. dist_ms_c=1.89e+01 < 1000.0, dist_c_verts=1.08e+00 > 1e-06
# Chosen node (9.069027256296836, 99.9913177903563, 0.8459188978224403) with ms=-5.900e+09 (simp T8, scene 1, rank #1, source=c_s)
# [Iter 2] LB simplex = T8, next node simplex = T8, scene 1
# [Selected Simp Info] Iter 2 | Simplex T8 Vertices:
#   v0: (8.756526140699322, 99.99160356239554, 0.9580467935897272)
#   v1: (10.0, 100.0, -100.0)
#   v2: (9.993045203208826, 99.9903288635917, 2.0319550327665548)
#   v3: (10.0, 100.0, 100.0)
#   -> New Point: (9.069027256296836, 99.9913177903563, 0.8459188978224403)
# [Iter 2] candidate rank #1: T8, scene=1, ms=-5.900e+09
# == ms candidates (sorted by (ms, -dist)) ==
# rank   simp   scene           ms    mind(all)                             pt
# ----------------------------------------------------------------------------
#    1     T8       1  -5.9005e+09     3.32e-01      (9.0690, 99.9913, 0.8459)
#    2     T8       4  -5.8998e+09     1.08e+00    (10.0000, 100.0000, 0.9527)
#    3     T8       0  -5.8848e+09     4.04e-01    (10.0000, 100.0000, 1.6280)
#    4     T8       2  -5.8572e+09     1.01e-01    (10.0000, 100.0000, 1.9320)
#    5     T8       3  -5.6759e+09     1.00e+00      (9.9984, 99.9978, 1.0279)
#
# [Iter 2] per_tet=11, active after q_cut=2, tri_is_None=False
# [Iter 2] bad-quality active simplices (q < 0): 0
# [Iter 2] evaluating Q for scenario 0
# [Iter 2] evaluating Q for scenario 1
# [Iter 2] evaluating Q for scenario 2
# [Iter 2] evaluating Q for scenario 3
# [Iter 2] evaluating Q for scenario 4
#
# [Iter 2] Next Point Details:
# Simplex   Scene   Type    As             ms             As+ms          Q              (Kp, Ki, Kd)
# --------------------------------------------------------------------------------------------------------------------
# T8        1       c_s     3.7587e+07     -5.9005e+09    -5.8629e+09    9.4522e-01     (9.0690, 99.9913, 0.8459)
#
# [Iter 2] subdivision type = face (code=3) on simplex T8
#            face local verts = (9, 6, 8)
# [Iter 2] Elapsed: 0.875s
# [Invariant] MS scen None: dual=-5.884145e+09 > primal=-5.884145e+09
# [Invariant] MS scen None: dual=-5.851542e+09 > primal=-5.851542e+09
# [Invariant] MS scen None: dual=-5.899783e+09 > primal=-5.899783e+09
# [Invariant] MS scen None: dual=-5.900459e+09 > primal=-5.900459e+09
# [Invariant] MS scen None: dual=-5.857183e+09 > primal=-5.857183e+09
# [Invariant] MS scen None: dual=-5.730775e+09 > primal=-5.730775e+09
# ======================================================================
# [Iter 2] LB SPLIT DIAGNOSTIC
#   Selected (parent) simplex: (6, 7, 8, 9)
#   Parent LB: 0.987578960 (per-scen)
#   UB in parent (pre-split): True  λ=[1.00000000, -0.00000000, 0.00000000, 0.00000000]
#   EF ef_obj(IPOPT): 0.197547751, true_obj(recalc): 0.987738771, used=min=0.197547751 (per-scen)
#   Simplex volume: 3.989137e-01
#   Children (3):
#     T10 (6, 7, 8, 10): LB = 0.987555020, avg_cs = 0.987555020
#     T11 (7, 8, 9, 10): LB = 0.987716633, avg_cs = 0.987716633
#     T12 (6, 7, 9, 10): LB = 0.987567301, avg_cs = 0.987567301
#   New global LB: 0.987555020 (from T10 (6, 7, 8, 10))
#   Location: INSIDE
#   Avg CS point Q-value: 0.987784502 (per-scen), point=(np.float64(9.813490789737354), np.float64(99.99782599898894), np.float64(1.2772826511760307))
#   Current UB: 0.987738749 (per-scen)
#   UB point: (8.756526140699322, 99.99160356239554, 0.9580467935897272)
#   UB source: avgCS_new_simplex
#   UB simplex: (3, 6, 7, 8)
#   EF-IPOPT: ok=True, status=ok, term=optimal, time=0.179s, ef_obj=0.987738757405091, true_obj(per-scen)=0.987738771
#   UB in child simplex (post-split): True
#     CHILD: T11 (7, 8, 9, 10) (LB=0.987716633, λ=[1.00000000, 0.00000000, 0.00000000, 0.00000000])
#     CHILD: T12 (6, 7, 9, 10) (LB=0.987567301, λ=[1.00000000, -0.00000000, 0.00000000, 0.00000000])
#     OLD:   T7 (3, 4, 6, 8) (LB=0.995120642, λ=[0.06187179, 0.06993266, 0.86819555, -0.00000000])
#     OLD:   T8 (3, 7, 8, 9) (LB=0.987765715, λ=[0.00000000, 1.00000000, 0.00000000, 0.00000000])
#     OLD:   T9 (3, 6, 7, 9) (LB=0.987710112, λ=[0.00000000, -0.00000000, 1.00000000, 0.00000000])
# ======================================================================
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -17.05729651549223): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -17.093354182942214): status=warning, term=infeasibleOrUnbounded
#
# ======================================================================
# [TIMING] === Iter 2 phase breakdown (total 20.30s) ===
#   1_vertex_UB                    :       0.00s  (  0.0%)
#   2_evaluate_all_tetra           :       0.00s  (  0.0%)
#   3_active_filter_print          :       0.00s  (  0.0%)
#   4_LB_selection                 :       0.00s  (  0.0%)
#   5_EF_UB_solve                  :       0.82s  (  4.0%)  ##
#   6_candidate_selection          :       0.00s  (  0.0%)
#   7_Q_eval_new_node              :       0.05s  (  0.3%)
#   8_mesh_subdivide               :       0.00s  (  0.0%)
#   9_end_of_iter_reeval           :      19.43s  ( 95.7%)  ###############################################
#   TOTAL                          :      20.30s
#   #simplices=11, #scenarios=5, total_ms_pairs=55
#   fresh ms solves=0, cache hits=55
# ======================================================================
#
# [Iter 3] #simplices = 13, #active = 4, bad-quality cut = 0, bad-shape cut = 0
# == [Iter 3] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T9            9.877101e-01      4.156764e+09     -2.921618e+10      4.938551e+00     [4.94e+00, 5.00e+10]    [-2.92e+10, 2.08e+10]     1
# T10           9.875550e-01      4.147135e+09     -2.926432e+10      4.937775e+00     [4.94e+00, 5.00e+10]    [-2.93e+10, 2.07e+10]     1
# T11           9.877166e-01      2.125370e+00     -4.926256e-01      4.938583e+00     [4.94e+00, 1.11e+01]     [4.45e+00, 1.06e+01]     0
# T12           9.875673e-01      4.145332e+09     -2.927334e+10      4.937837e+00     [4.94e+00, 5.00e+10]    [-2.93e+10, 2.07e+10]     1
#
# == [Iter 3] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.000986e+00      4.574690e+09     -2.712655e+10      5.004929e+00     [1.12e+01, 5.00e+10]    [-2.71e+10, 2.29e+10]     1
# T1            9.956027e-01      4.060486e+09     -2.969757e+10      4.978014e+00     [1.12e+01, 5.00e+10]    [-2.97e+10, 2.03e+10]     1
# T2            1.025007e+00      4.471772e+09     -2.764114e+10      5.125034e+00     [1.11e+01, 5.00e+10]    [-2.76e+10, 2.24e+10]     1
# T3            1.123946e+00      4.332879e+09     -2.833561e+10      5.619732e+00     [1.36e+01, 5.00e+10]    [-2.83e+10, 2.17e+10]     2
# T4            1.039181e+00               inf               inf      5.195905e+00     [1.36e+01, 5.00e+10]               [inf, inf]     2
# T5            1.005687e+00      4.127439e+09     -2.936281e+10      5.028433e+00     [4.94e+00, 5.00e+10]    [-2.94e+10, 2.06e+10]     1
# T6            1.018613e+00      1.390491e+00     -6.687083e+00      5.093063e+00     [4.94e+00, 1.36e+01]    [-1.75e+00, 6.95e+00]     0
# T7            9.951206e-01      4.328478e+09     -2.835761e+10      4.975603e+00     [4.94e+00, 5.00e+10]    [-2.84e+10, 2.16e+10]     1
# T8            9.877657e-01      2.500265e+00     -1.110847e+00      4.938829e+00     [4.94e+00, 1.36e+01]     [3.83e+00, 1.25e+01]     0
#
# [Iter 3] created=13 (cum=49), active=4, active+UB=3, ms_recomputed=0
# [Iter 3] UB-simplex selection: UB_node in simplices [7, 10, 11, 12], chose T10 (LB=0.987555020)
# [Iter 3] EF-ipopt: ok=True, ef_obj=0.9877387572750509, true_obj=9.877388e-01, time=0.326s
# [Iter 3] Pre-split gap: 9.186467e-04 (0.019%)
# [Iter 3] Active simplex ratio = 0.000007
# [Iter 3] UB point (9.069027256296836, 99.9913177903563, 0.8459188978224403) is geometrically in simplices [7, 10, 11, 12]
#   T7 verts=[3, 6, 8, 4]: λ=[0.046236, 0.056019, 0.897745, -0.000000], LB=4.975603208, c_s=[0.9991217757689878, 0.9620830306798327, 0.9583854838865904, 1.074967104962017, 0.9810458122214656]
#   T10 verts=[10, 6, 8, 7]: λ=[1.000000, -0.000000, 0.000000, 0.000000], LB=4.937775098, c_s=[0.9973836195987477, 0.9452016592026994, 0.9559986453030728, 1.0700786401962321, 0.969112533548863]
#   T11 verts=[9, 10, 8, 7]: λ=[0.000000, 1.000000, 0.000000, -0.000000], LB=4.938583167, c_s=[0.9975260173015925, 0.9452171639995697, 0.956002493281176, 1.0705665775665385, 0.9692709144907724]
#   T12 verts=[9, 6, 10, 7]: λ=[0.000000, 0.000000, 1.000000, 0.000000], LB=4.937836504, c_s=[0.9973873304728187, 0.9452178584161786, 0.9560368668292794, 1.0700827373652813, 0.969111711123752]
#
# == [Iter 3] CS DUAL vs PRIMAL diagnostic (simplices containing UB point) ==
#   --- T7 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.993183753590436, 99.99052152768817, -0.0006803886125672228)
#              indep_Q(cs_K)=0.999121884
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(5.071140501589126, 46.90377893563921, -0.9262897458072619)
#              indep_Q(cs_K)=0.962083032
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(3.424875621608243, 58.41452119097115, 1.6676768139286249)
#              indep_Q(cs_K)=0.958385560
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.192267450740088, 91.12763178979797, 1.4355534887196468)
#              indep_Q(cs_K)=1.074967108
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(5.881358576403716, 55.83257412105498, -0.3424334893473854)
#              indep_Q(cs_K)=0.981045813
#   sum(c_s_dual)=0.000000000, UB_total=24.693468723, UB_per_scen=4.938693745
#
#   == Per-scenario Q_s at K_EF = (9.069027256296836, 99.9913177903563, 0.8459188978224403) ==
#     scen 0: Q_s(K_EF)=0.997848448, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945219615, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.957234230, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.070792042, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.969252841, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.940347176, sum(c_s)=0.000000000, diff=4.940347e+00
#   --- T10 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(10.0, 100.0, 1.4911009442000296)
#              indep_Q(cs_K)=0.997383621
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.993122643538236, 99.99043654984217, 0.8958487675139519)
#              indep_Q(cs_K)=0.945201660
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.879443948866541, 99.99045530532352, 1.9353339044889206)
#              indep_Q(cs_K)=0.955998646
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.99999610241347, 99.99999694639853, 1.0237374463891926)
#              indep_Q(cs_K)=1.070078649
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.993138209737953, 99.99045819574289, 0.6674812339390632)
#              indep_Q(cs_K)=0.969112539
#   sum(c_s_dual)=0.000000000, UB_total=24.693468723, UB_per_scen=4.938693745
#
#   == Per-scenario Q_s at K_EF = (9.069027256296836, 99.9913177903563, 0.8459188978224403) ==
#     scen 0: Q_s(K_EF)=0.997848448, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945219615, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.957234230, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.070792042, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.969252841, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.940347176, sum(c_s)=0.000000000, diff=4.940347e+00
#   --- T11 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(9.34095075820563, 99.99103912265178, 1.3200222776437833)
#              indep_Q(cs_K)=0.997526021
# ...
#   1009.203      149    0.987591510    0.987738746    0.0149%    0.00015         64         21    face             c_s
#   1013.724      150    0.987591518    0.987738746    0.0149%    0.00015         64         21    face             c_s
#   1018.525      151    0.987591527    0.987738746    0.0149%    0.00015         64         21    face             c_s
#   1024.691      152    0.987591484    0.987738746    0.0149%    0.00015         64         21    face             c_s
#   1029.347      153    0.987591531    0.987738746    0.0149%    0.00015         64         21    face             c_s
#   1034.179      154    0.987591524    0.987738746    0.0149%    0.00015         64         21    edge             c_s
#   1039.304      155    0.987617526    0.987738746    0.0123%    0.00012         64         21    edge             c_s
#   1043.468      156    0.987617622    0.987738746    0.0123%    0.00012         64         20    face             c_s
#   1049.761      157    0.987619407    0.987738746    0.0121%    0.00012         65         21    edge             c_s
#   1054.672      158    0.987617628    0.987738746    0.0123%    0.00012         65         21    edge             c_s
#   1067.074      159    0.987618699    0.987738746    0.0122%    0.00012         67         22    face             c_s
#   1071.775      160    0.987618528    0.987738746    0.0122%    0.00012         67         22    edge             c_s
#   1080.320      161    0.987620371    0.987738746    0.0120%    0.00012         68         22interior             c_s
#   1085.135      162    0.987617993    0.987738746    0.0122%    0.00012         68         22    face             c_s
#   1097.611      163    0.987618225    0.987738746    0.0122%    0.00012         70         23interior             c_s
#   1106.806      164    0.987618261    0.987738746    0.0122%    0.00012         71         24    face             c_s
#   1114.877      165    0.987618468    0.987738746    0.0122%    0.00012         72         24    face             c_s
#   1124.276      166    0.987619283    0.987738746    0.0121%    0.00012         73         24    face             c_s
#   1131.865      167    0.987619837    0.987738746    0.0120%    0.00012         74         24interior             c_s
#   1140.868      168    0.987617380    0.987738746    0.0123%    0.00012         75         24interior             c_s
#   1145.429      169    0.987616992    0.987738746    0.0123%    0.00012         75         24    edge             c_s
#   1154.045      170    0.987619017    0.987738746    0.0121%    0.00012         76         24    face             c_s
#   1162.506      171    0.987617529    0.987738746    0.0123%    0.00012         77         24interior             c_s
#   1167.534      172    0.987617543    0.987738746    0.0123%    0.00012         77         24interior             c_s
#   1172.052      173    0.987617668    0.987738746    0.0123%    0.00012         77         24    face             c_s
#   1180.217      174    0.987618300    0.987738746    0.0122%    0.00012         78         24    face             c_s
#   1184.712      175    0.987619387    0.987738746    0.0121%    0.00012         78         24    edge             c_s
#   1192.694      176    0.987618988    0.987738746    0.0121%    0.00012         79         24interior             c_s
#   1201.852      177    0.987619906    0.987738746    0.0120%    0.00012         80         24interior             c_s
#   1211.005      178    0.987620055    0.987738746    0.0120%    0.00012         81         24    face             c_s
#   1215.929      179    0.987619922    0.987738746    0.0120%    0.00012         81         24    face             c_s
#   1220.577      180    0.987619212    0.987738746    0.0121%    0.00012         81         24    face             c_s
#   1245.301      181    0.987619304    0.987738746    0.0121%    0.00012         82         24    face             c_s
#   1250.646      182    0.987620130    0.987738746    0.0120%    0.00012         82         24    face             c_s
#   1257.221      183    0.987620298    0.987738746    0.0120%    0.00012         82         24    face             c_s
#   1266.467      184    0.987619675    0.987738746    0.0121%    0.00012         83         24    face             c_s
#   1271.064      185    0.987620300    0.987738746    0.0120%    0.00012         83         24    edge             c_s
#   1276.118      186    0.987620298    0.987738746    0.0120%    0.00012         83         24    edge             c_s
#   1280.778      187    0.987620039    0.987738746    0.0120%    0.00012         83         24    face             c_s
#   1286.374      188    0.987618903    0.987738746    0.0121%    0.00012         83         24    edge             c_s
#   1291.256      189    0.987618850    0.987738746    0.0121%    0.00012         83         24    edge             c_s
#   1295.849      190    0.987618773    0.987738746    0.0121%    0.00012         83         24    edge             c_s
#   1304.218      191    0.987619866    0.987738746    0.0120%    0.00012         84         24    face             c_s
#   1313.117      192    0.987620348    0.987738746    0.0120%    0.00012         86         25interior             c_s
#   1321.666      193    0.987620566    0.987738746    0.0120%    0.00012         87         25interior             c_s
#   1325.904      194    0.987620844    0.987738746    0.0119%    0.00012         87         25    edge             c_s
#   1336.585      195    0.987620125    0.987738746    0.0120%    0.00012         89         26interior             c_s
#   1343.759      196    0.987620110    0.987738746    0.0120%    0.00012         90         26interior             c_s
#   1348.448      197    0.987620513    0.987738746    0.0120%    0.00012         90         26    face             c_s
#   1353.152      198    0.987620330    0.987738746    0.0120%    0.00012         90         26    edge             c_s
#   1357.622      199    0.987621895    0.987738746    0.0118%    0.00012         90         26    face             c_s
#   1361.870      200    0.987621138    0.987738746    0.0119%    0.00012         90         26    edge             c_s
#   1370.177      201    0.987620313    0.987738746    0.0120%    0.00012         91         26    edge             c_s
#   1378.030      202    0.987620389    0.987738746    0.0120%    0.00012         92         27    edge             c_s
#   1386.840      203    0.987620224    0.987738746    0.0120%    0.00012         93         27    face             c_s
#   1397.296      204    0.987620682    0.987738746    0.0120%    0.00012         95         28    face             c_s
#   1401.510      205    0.987620260    0.987738746    0.0120%    0.00012         95         28    face             c_s
#   1405.859      206    0.987620370    0.987738746    0.0120%    0.00012         95         28    face             c_s
#   1410.096      207    0.987620308    0.987738746    0.0120%    0.00012         95         28    edge             c_s
#   1418.143      208    0.987620359    0.987738746    0.0120%    0.00012         96         29    edge             c_s
#   1422.318      209    0.987620358    0.987738746    0.0120%    0.00012         96         29    edge             c_s
#   1426.304      210    0.987620428    0.987738746    0.0120%    0.00012         96         29    edge             c_s
#   1430.578      211    0.987621001    0.987738746    0.0119%    0.00012         96         29    face             c_s
#   1431.513      212    0.987621295    0.987738746    0.0119%    0.00012         95         28    face             c_s
#   1439.742      213    0.987620321    0.987738746    0.0120%    0.00012         96         28    face             c_s
#   1444.075      214    0.987621052    0.987738746    0.0119%    0.00012         96         28interior             c_s
#   1448.237      215    0.987620405    0.987738746    0.0120%    0.00012         96         28    face             c_s
#   1453.400      216    0.987620440    0.987738746    0.0120%    0.00012         96         28    face             c_s
#   1457.779      217    0.987621509    0.987738746    0.0119%    0.00012         96         28    edge             c_s
#   1462.039      218    0.987620464    0.987738746    0.0120%    0.00012         96         28    edge             c_s
#   1466.634      219    0.987620386    0.987738746    0.0120%    0.00012         96         28    face             c_s
#   1471.463      220    0.987621767    0.987738746    0.0118%    0.00012         96         28interior             c_s
#   1472.535      221    0.987622144    0.987738746    0.0118%    0.00012         95         27    edge             c_s
#   1477.005      222    0.987627825    0.987738746    0.0112%    0.00011         95         27    edge             c_s
#   1488.826      223    0.987617526    0.987738746    0.0123%    0.00012         97         29    face             c_s
#   1499.761      224    0.987625021    0.987738746    0.0115%    0.00011         99         31    face             c_s
#   1510.265      225    0.987623805    0.987738746    0.0116%    0.00011        101         33    face             c_s
#   1519.358      226    0.987629974    0.987738746    0.0110%    0.00011        102         34interior             c_s
#   1525.516      227    0.987629776    0.987738746    0.0110%    0.00011        103         35    edge             c_s
#   1530.020      228    0.987615443    0.987738746    0.0125%    0.00012        103         35    face        ms(vert)
#   1536.868      229    0.987615423    0.987738746    0.0125%    0.00012        104         35interior             c_s
#   1540.976      230    0.987615983    0.987738746    0.0124%    0.00012        104         35    edge             c_s
#   1544.918      231    0.987616037    0.987738746    0.0124%    0.00012        104         35    face             c_s
#   1548.726      232    0.987616228    0.987738746    0.0124%    0.00012        104         35    edge             c_s
#   1552.078      233    0.987615977    0.987738746    0.0124%    0.00012        104         35    face        ms(vert)
#   1557.525      234    0.987616007    0.987738746    0.0124%    0.00012        105         35interior             c_s
#   1562.894      235    0.987615982    0.987738746    0.0124%    0.00012        105         35    face             c_s
#   1566.341      236    0.987615994    0.987738746    0.0124%    0.00012        105         35    edge             c_s
#   1570.000      237    0.987615991    0.987738746    0.0124%    0.00012        105         35    edge             c_s
#   1574.103      238    0.987615994    0.987738746    0.0124%    0.00012        105         35    edge             c_s
#   1577.590      239    0.987616006    0.987738746    0.0124%    0.00012        105         35    edge             c_s
#   1581.119      240    0.987616002    0.987738746    0.0124%    0.00012        105         35    edge             c_s
#   1585.044      241    0.987616195    0.987738746    0.0124%    0.00012        105         35interior        ms(vert)
#   1590.368      242    0.987616712    0.987738746    0.0124%    0.00012        106         35interior             c_s
#   1593.218      243    0.987630136    0.987738746    0.0110%    0.00011        106         35interior             c_s
#   1593.742      244    0.987630371    0.987738746    0.0110%    0.00011        105         34    face             c_s
#   1597.955      245    0.987630520    0.987738746    0.0110%    0.00011        105         34    face             c_s
#   1606.016      246    0.987630836    0.987738746    0.0109%    0.00011        106         34    face             c_s
#   1614.548      247    0.987616970    0.987738746    0.0123%    0.00012        107         34    face             c_s
#   1625.733      248    0.987616937    0.987738746    0.0123%    0.00012        108         34interior             c_s
#   1630.764      249    0.987617001    0.987738746    0.0123%    0.00012        108         34interior             c_s
#   1635.137      250    0.987617082    0.987738746    0.0123%    0.00012        108         34    edge             c_s
#   1639.302      251    0.987617125    0.987738746    0.0123%    0.00012        108         34    edge             c_s
#   1644.215      252    0.987617124    0.987738746    0.0123%    0.00012        108         34    face             c_s
#   1648.853      253    0.987617143    0.987738746    0.0123%    0.00012        108         34    edge             c_s
#   1653.686      254    0.987616983    0.987738746    0.0123%    0.00012        108         34    face        ms(vert)
#   1660.574      255    0.987616964    0.987738746    0.0123%    0.00012        109         34interior             c_s
#   1664.898      256    0.987617050    0.987738746    0.0123%    0.00012        109         34    edge             c_s
#   1668.603      257    0.987616998    0.987738746    0.0123%    0.00012        109         34    edge        ms(vert)
#   1673.955      258    0.987617007    0.987738746    0.0123%    0.00012        110         34interior             c_s
#   1677.396      259    0.987617082    0.987738746    0.0123%    0.00012        110         34    face             c_s
#   1681.866      260    0.987617082    0.987738746    0.0123%    0.00012        110         34    face             c_s
#   1685.873      261    0.987617082    0.987738746    0.0123%    0.00012        110         34    edge             c_s
#   1689.515      262    0.987617577    0.987738746    0.0123%    0.00012        110         34    edge             c_s
#   1692.872      263    0.987617108    0.987738746    0.0123%    0.00012        110         34    edge             c_s
#   1698.562      264    0.987617109    0.987738746    0.0123%    0.00012        111         34    face             c_s
#   1701.977      265    0.987630912    0.987738746    0.0109%    0.00011        111         34    face        ms(vert)
#   1702.836      266    0.987627711    0.987738746    0.0112%    0.00011        110         33interior             c_s
#   1707.617      267    0.987626526    0.987738746    0.0114%    0.00011        110         33    face             c_s
#   1712.571      268    0.987630921    0.987738746    0.0109%    0.00011        110         33    face             c_s
#   1717.261      269    0.987631009    0.987738746    0.0109%    0.00011        110         33    edge             c_s
#   1722.761      270    0.987631059    0.987738746    0.0109%    0.00011        110         33    face             c_s
#   1730.712      271    0.987630550    0.987738746    0.0110%    0.00011        111         33    face             c_s
#   1735.030      272    0.987631137    0.987738746    0.0109%    0.00011        111         33    face             c_s
#   1744.543      273    0.987631142    0.987738746    0.0109%    0.00011        112         33interior             c_s
#   1752.410      274    0.987618708    0.987738746    0.0122%    0.00012        113         33    face             c_s
#   1757.622      275    0.987617205    0.987738746    0.0123%    0.00012        113         33    face             c_s
#   1765.579      276    0.987626814    0.987738746    0.0113%    0.00011        114         33    face             c_s
#   1770.666      277    0.987617267    0.987738746    0.0123%    0.00012        114         33interior             c_s
#   1775.504      278    0.987618266    0.987738746    0.0122%    0.00012        114         33    face             c_s
#   1780.068      279    0.987631247    0.987738746    0.0109%    0.00011        114         33    edge             c_s
#   1785.468      280    0.987631709    0.987738746    0.0108%    0.00011        114         33    edge             c_s
#   1790.063      281    0.987631788    0.987738746    0.0108%    0.00011        114         33    face             c_s
#   1797.938      282    0.987631761    0.987738746    0.0108%    0.00011        115         33interior             c_s
# [Time] Main loop total: 1803.376s
#
# ==== Done ====
# Total nodes: 283
# Best UB: 4.938693727803518
# Last LB: 4.9381588062922255
